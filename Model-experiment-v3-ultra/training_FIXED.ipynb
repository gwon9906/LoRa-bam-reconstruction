# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거
# - 노이즈 범위 줄임(5~-5db)

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'nfft': 512,      
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    nfft     = STFT_PARAMS['nfft']  # <--- 변수 가져오기
    window   = STFT_PARAMS['window']

    # 2. stft 호출 시 nfft 전달
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        nfft=nfft,              # <--- 꼭 넣어주세요!
        boundary=None,
        padded=False,
        return_onesided=False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        nfft=stft_params['nfft'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf=sf, bw=bw, OSF=OSF)
fs = lora.fs   # = bw * OSF
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (SNR에 집중)
SNR_MIN = -20
SNR_MAX = 0
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)
            
            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 4096, 2048, 512]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (128, 31)
# Input dim (Real+Imag): 7936
# Model architecture: 7936 → 4096 → 2048 → 512
# Compression ratio: 15.5x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 30
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 7936 → 4096 → 2048 → 512
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.024643
# Epoch 1, Batch 2/240, MSE = 0.020512
# Epoch 1, Batch 3/240, MSE = 0.018071
# Epoch 1, Batch 4/240, MSE = 0.020011
# Epoch 1, Batch 5/240, MSE = 0.022338
# Epoch 1, Batch 6/240, MSE = 0.018522
# Epoch 1, Batch 7/240, MSE = 0.018313
# Epoch 1, Batch 8/240, MSE = 0.018871
# Epoch 1, Batch 9/240, MSE = 0.020609
# Epoch 1, Batch 10/240, MSE = 0.019989
# Epoch 1, Batch 11/240, MSE = 0.020245
# Epoch 1, Batch 12/240, MSE = 0.020132
# Epoch 1, Batch 13/240, MSE = 0.018832
# Epoch 1, Batch 14/240, MSE = 0.018498
# Epoch 1, Batch 15/240, MSE = 0.021370
# Epoch 1, Batch 16/240, MSE = 0.017526
# Epoch 1, Batch 17/240, MSE = 0.018807
# Epoch 1, Batch 18/240, MSE = 0.019457
# Epoch 1, Batch 19/240, MSE = 0.017921
# Epoch 1, Batch 20/240, MSE = 0.018495
# Epoch 1, Batch 21/240, MSE = 0.018651
# Epoch 1, Batch 22/240, MSE = 0.018091
# Epoch 1, Batch 23/240, MSE = 0.019294
# Epoch 1, Batch 24/240, MSE = 0.018230
# Epoch 1, Batch 25/240, MSE = 0.019466
# Epoch 1, Batch 26/240, MSE = 0.018955
# Epoch 1, Batch 27/240, MSE = 0.019223
# Epoch 1, Batch 28/240, MSE = 0.018670
# Epoch 1, Batch 29/240, MSE = 0.017639
# Epoch 1, Batch 30/240, MSE = 0.019172
# Epoch 1, Batch 31/240, MSE = 0.017486
# Epoch 1, Batch 32/240, MSE = 0.018468
# Epoch 1, Batch 33/240, MSE = 0.016906
# Epoch 1, Batch 34/240, MSE = 0.017498
# Epoch 1, Batch 35/240, MSE = 0.016744
# Epoch 1, Batch 36/240, MSE = 0.018646
# Epoch 1, Batch 37/240, MSE = 0.019637
# Epoch 1, Batch 38/240, MSE = 0.017001
# Epoch 1, Batch 39/240, MSE = 0.018780
# Epoch 1, Batch 40/240, MSE = 0.018475
# Epoch 1, Batch 41/240, MSE = 0.017191
# Epoch 1, Batch 42/240, MSE = 0.015801
# Epoch 1, Batch 43/240, MSE = 0.018238
# Epoch 1, Batch 44/240, MSE = 0.018619
# Epoch 1, Batch 45/240, MSE = 0.017257
# Epoch 1, Batch 46/240, MSE = 0.017334
# Epoch 1, Batch 47/240, MSE = 0.018369
# Epoch 1, Batch 48/240, MSE = 0.016890
# Epoch 1, Batch 49/240, MSE = 0.017650
# Epoch 1, Batch 50/240, MSE = 0.016856
# Epoch 1, Batch 51/240, MSE = 0.017067
# Epoch 1, Batch 52/240, MSE = 0.018246
# Epoch 1, Batch 53/240, MSE = 0.016457
# Epoch 1, Batch 54/240, MSE = 0.016872
# Epoch 1, Batch 55/240, MSE = 0.017923
# Epoch 1, Batch 56/240, MSE = 0.017599
# Epoch 1, Batch 57/240, MSE = 0.018168
# Epoch 1, Batch 58/240, MSE = 0.016773
# Epoch 1, Batch 59/240, MSE = 0.016754
# Epoch 1, Batch 60/240, MSE = 0.016068
# Epoch 1, Batch 61/240, MSE = 0.017283
# Epoch 1, Batch 62/240, MSE = 0.015411
# Epoch 1, Batch 63/240, MSE = 0.016465
# Epoch 1, Batch 64/240, MSE = 0.019027
# Epoch 1, Batch 65/240, MSE = 0.016919
# Epoch 1, Batch 66/240, MSE = 0.017725
# Epoch 1, Batch 67/240, MSE = 0.017150
# Epoch 1, Batch 68/240, MSE = 0.015797
# Epoch 1, Batch 69/240, MSE = 0.016237
# Epoch 1, Batch 70/240, MSE = 0.018022
# Epoch 1, Batch 71/240, MSE = 0.018089
# Epoch 1, Batch 72/240, MSE = 0.018025
# Epoch 1, Batch 73/240, MSE = 0.016107
# Epoch 1, Batch 74/240, MSE = 0.016336
# Epoch 1, Batch 75/240, MSE = 0.017521
# Epoch 1, Batch 76/240, MSE = 0.015988
# Epoch 1, Batch 77/240, MSE = 0.015681
# Epoch 1, Batch 78/240, MSE = 0.017257
# Epoch 1, Batch 79/240, MSE = 0.016239
# Epoch 1, Batch 80/240, MSE = 0.016397
# Epoch 1, Batch 81/240, MSE = 0.016218
# Epoch 1, Batch 82/240, MSE = 0.016048
# Epoch 1, Batch 83/240, MSE = 0.017142
# Epoch 1, Batch 84/240, MSE = 0.016883
# Epoch 1, Batch 85/240, MSE = 0.015820
# Epoch 1, Batch 86/240, MSE = 0.016464
# Epoch 1, Batch 87/240, MSE = 0.017762
# Epoch 1, Batch 88/240, MSE = 0.017746
# Epoch 1, Batch 89/240, MSE = 0.015392
# Epoch 1, Batch 90/240, MSE = 0.015554
# Epoch 1, Batch 91/240, MSE = 0.016876
# Epoch 1, Batch 92/240, MSE = 0.015769
# Epoch 1, Batch 93/240, MSE = 0.016386
# Epoch 1, Batch 94/240, MSE = 0.015770
# Epoch 1, Batch 95/240, MSE = 0.014992
# Epoch 1, Batch 96/240, MSE = 0.016534
# Epoch 1, Batch 97/240, MSE = 0.014243
# Epoch 1, Batch 98/240, MSE = 0.015512
# Epoch 1, Batch 99/240, MSE = 0.015766
# Epoch 1, Batch 100/240, MSE = 0.016035
# Epoch 1, Batch 101/240, MSE = 0.016009
# Epoch 1, Batch 102/240, MSE = 0.015670
# Epoch 1, Batch 103/240, MSE = 0.014681
# Epoch 1, Batch 104/240, MSE = 0.015882
# Epoch 1, Batch 105/240, MSE = 0.015874
# Epoch 1, Batch 106/240, MSE = 0.016939
# Epoch 1, Batch 107/240, MSE = 0.015195
# Epoch 1, Batch 108/240, MSE = 0.015822
# Epoch 1, Batch 109/240, MSE = 0.015352
# Epoch 1, Batch 110/240, MSE = 0.016380
# Epoch 1, Batch 111/240, MSE = 0.014068
# Epoch 1, Batch 112/240, MSE = 0.016417
# Epoch 1, Batch 113/240, MSE = 0.016823
# Epoch 1, Batch 114/240, MSE = 0.014240
# Epoch 1, Batch 115/240, MSE = 0.014952
# Epoch 1, Batch 116/240, MSE = 0.015748
# Epoch 1, Batch 117/240, MSE = 0.015168
# Epoch 1, Batch 118/240, MSE = 0.015915
# Epoch 1, Batch 119/240, MSE = 0.013587
# Epoch 1, Batch 120/240, MSE = 0.015603
# Epoch 1, Batch 121/240, MSE = 0.013533
# Epoch 1, Batch 122/240, MSE = 0.014723
# Epoch 1, Batch 123/240, MSE = 0.015678
# Epoch 1, Batch 124/240, MSE = 0.013599
# Epoch 1, Batch 125/240, MSE = 0.015016
# Epoch 1, Batch 126/240, MSE = 0.015668
# Epoch 1, Batch 127/240, MSE = 0.015415
# Epoch 1, Batch 128/240, MSE = 0.014435
# Epoch 1, Batch 129/240, MSE = 0.014615
# Epoch 1, Batch 130/240, MSE = 0.014985
# Epoch 1, Batch 131/240, MSE = 0.014099
# Epoch 1, Batch 132/240, MSE = 0.015437
# Epoch 1, Batch 133/240, MSE = 0.014735
# Epoch 1, Batch 134/240, MSE = 0.014410
# Epoch 1, Batch 135/240, MSE = 0.015426
# Epoch 1, Batch 136/240, MSE = 0.014984
# Epoch 1, Batch 137/240, MSE = 0.013753
# Epoch 1, Batch 138/240, MSE = 0.014460
# Epoch 1, Batch 139/240, MSE = 0.014051
# Epoch 1, Batch 140/240, MSE = 0.013010
# Epoch 1, Batch 141/240, MSE = 0.013366
# Epoch 1, Batch 142/240, MSE = 0.014669
# Epoch 1, Batch 143/240, MSE = 0.013629
# Epoch 1, Batch 144/240, MSE = 0.013018
# Epoch 1, Batch 145/240, MSE = 0.013142
# Epoch 1, Batch 146/240, MSE = 0.013572
# Epoch 1, Batch 147/240, MSE = 0.014466
# Epoch 1, Batch 148/240, MSE = 0.013651
# Epoch 1, Batch 149/240, MSE = 0.014754
# Epoch 1, Batch 150/240, MSE = 0.013661
# Epoch 1, Batch 151/240, MSE = 0.014134
# Epoch 1, Batch 152/240, MSE = 0.014036
# Epoch 1, Batch 153/240, MSE = 0.012214
# Epoch 1, Batch 154/240, MSE = 0.013582
# Epoch 1, Batch 155/240, MSE = 0.014305
# Epoch 1, Batch 156/240, MSE = 0.013337
# Epoch 1, Batch 157/240, MSE = 0.013756
# Epoch 1, Batch 158/240, MSE = 0.013455
# Epoch 1, Batch 159/240, MSE = 0.012529
# Epoch 1, Batch 160/240, MSE = 0.013491
# Epoch 1, Batch 161/240, MSE = 0.012780
# Epoch 1, Batch 162/240, MSE = 0.015083
# Epoch 1, Batch 163/240, MSE = 0.013914
# Epoch 1, Batch 164/240, MSE = 0.013691
# Epoch 1, Batch 165/240, MSE = 0.012027
# Epoch 1, Batch 166/240, MSE = 0.012881
# Epoch 1, Batch 167/240, MSE = 0.012452
# Epoch 1, Batch 168/240, MSE = 0.012696
# Epoch 1, Batch 169/240, MSE = 0.012446
# Epoch 1, Batch 170/240, MSE = 0.012541
# Epoch 1, Batch 171/240, MSE = 0.013180
# Epoch 1, Batch 172/240, MSE = 0.012750
# Epoch 1, Batch 173/240, MSE = 0.012824
# Epoch 1, Batch 174/240, MSE = 0.012516
# Epoch 1, Batch 175/240, MSE = 0.011730
# Epoch 1, Batch 176/240, MSE = 0.012007
# Epoch 1, Batch 177/240, MSE = 0.012160
# Epoch 1, Batch 178/240, MSE = 0.013211
# Epoch 1, Batch 179/240, MSE = 0.013382
# Epoch 1, Batch 180/240, MSE = 0.012144
# Epoch 1, Batch 181/240, MSE = 0.011118
# Epoch 1, Batch 182/240, MSE = 0.011797
# Epoch 1, Batch 183/240, MSE = 0.012077
# Epoch 1, Batch 184/240, MSE = 0.012468
# Epoch 1, Batch 185/240, MSE = 0.011666
# Epoch 1, Batch 186/240, MSE = 0.011487
# Epoch 1, Batch 187/240, MSE = 0.012524
# Epoch 1, Batch 188/240, MSE = 0.011955
# Epoch 1, Batch 189/240, MSE = 0.012920
# Epoch 1, Batch 190/240, MSE = 0.013210
# Epoch 1, Batch 191/240, MSE = 0.011408
# Epoch 1, Batch 192/240, MSE = 0.013351
# Epoch 1, Batch 193/240, MSE = 0.012355
# Epoch 1, Batch 194/240, MSE = 0.011817
# Epoch 1, Batch 195/240, MSE = 0.011304
# Epoch 1, Batch 196/240, MSE = 0.012036
# Epoch 1, Batch 197/240, MSE = 0.011727
# Epoch 1, Batch 198/240, MSE = 0.012329
# Epoch 1, Batch 199/240, MSE = 0.012268
# Epoch 1, Batch 200/240, MSE = 0.011599
# Epoch 1, Batch 201/240, MSE = 0.011164
# Epoch 1, Batch 202/240, MSE = 0.009984
# Epoch 1, Batch 203/240, MSE = 0.010699
# Epoch 1, Batch 204/240, MSE = 0.010505
# Epoch 1, Batch 205/240, MSE = 0.012322
# Epoch 1, Batch 206/240, MSE = 0.010219
# Epoch 1, Batch 207/240, MSE = 0.011167
# Epoch 1, Batch 208/240, MSE = 0.012397
# Epoch 1, Batch 209/240, MSE = 0.011274
# Epoch 1, Batch 210/240, MSE = 0.011920
# Epoch 1, Batch 211/240, MSE = 0.010635
# Epoch 1, Batch 212/240, MSE = 0.010409
# Epoch 1, Batch 213/240, MSE = 0.012081
# Epoch 1, Batch 214/240, MSE = 0.010146
# Epoch 1, Batch 215/240, MSE = 0.009165
# Epoch 1, Batch 216/240, MSE = 0.010734
# Epoch 1, Batch 217/240, MSE = 0.010144
# Epoch 1, Batch 218/240, MSE = 0.011105
# Epoch 1, Batch 219/240, MSE = 0.010761
# Epoch 1, Batch 220/240, MSE = 0.011093
# Epoch 1, Batch 221/240, MSE = 0.011579
# Epoch 1, Batch 222/240, MSE = 0.010031
# Epoch 1, Batch 223/240, MSE = 0.010056
# Epoch 1, Batch 224/240, MSE = 0.011051
# Epoch 1, Batch 225/240, MSE = 0.010701
# Epoch 1, Batch 226/240, MSE = 0.010696
# Epoch 1, Batch 227/240, MSE = 0.010249
# Epoch 1, Batch 228/240, MSE = 0.010866
# Epoch 1, Batch 229/240, MSE = 0.010061
# Epoch 1, Batch 230/240, MSE = 0.010959
# Epoch 1, Batch 231/240, MSE = 0.010813
# Epoch 1, Batch 232/240, MSE = 0.009961
# Epoch 1, Batch 233/240, MSE = 0.010652
# Epoch 1, Batch 234/240, MSE = 0.010522
# Epoch 1, Batch 235/240, MSE = 0.009833
# Epoch 1, Batch 236/240, MSE = 0.011077
# Epoch 1, Batch 237/240, MSE = 0.010230
# Epoch 1, Batch 238/240, MSE = 0.009453
# Epoch 1, Batch 239/240, MSE = 0.011231
# Epoch 1, Batch 240/240, MSE = 0.011160
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.031025
# Epoch 1, Batch 2/240, MSE = 0.019611
# Epoch 1, Batch 3/240, MSE = 0.021104
# Epoch 1, Batch 4/240, MSE = 0.019270
# Epoch 1, Batch 5/240, MSE = 0.018022
# Epoch 1, Batch 6/240, MSE = 0.020694
# Epoch 1, Batch 7/240, MSE = 0.018742
# Epoch 1, Batch 8/240, MSE = 0.019464
# Epoch 1, Batch 9/240, MSE = 0.019556
# Epoch 1, Batch 10/240, MSE = 0.019117
# Epoch 1, Batch 11/240, MSE = 0.021768
# Epoch 1, Batch 12/240, MSE = 0.016525
# Epoch 1, Batch 13/240, MSE = 0.018311
# Epoch 1, Batch 14/240, MSE = 0.019499
# Epoch 1, Batch 15/240, MSE = 0.018764
# Epoch 1, Batch 16/240, MSE = 0.016934
# Epoch 1, Batch 17/240, MSE = 0.018473
# Epoch 1, Batch 18/240, MSE = 0.017798
# Epoch 1, Batch 19/240, MSE = 0.017651
# Epoch 1, Batch 20/240, MSE = 0.018690
# Epoch 1, Batch 21/240, MSE = 0.018323
# Epoch 1, Batch 22/240, MSE = 0.017672
# Epoch 1, Batch 23/240, MSE = 0.018527
# Epoch 1, Batch 24/240, MSE = 0.018315
# Epoch 1, Batch 25/240, MSE = 0.017918
# Epoch 1, Batch 26/240, MSE = 0.018861
# Epoch 1, Batch 27/240, MSE = 0.018253
# Epoch 1, Batch 28/240, MSE = 0.018456
# Epoch 1, Batch 29/240, MSE = 0.018576
# Epoch 1, Batch 30/240, MSE = 0.017153
# Epoch 1, Batch 31/240, MSE = 0.018002
# Epoch 1, Batch 32/240, MSE = 0.019346
# Epoch 1, Batch 33/240, MSE = 0.019773
# Epoch 1, Batch 34/240, MSE = 0.017272
# Epoch 1, Batch 35/240, MSE = 0.017261
# Epoch 1, Batch 36/240, MSE = 0.018865
# Epoch 1, Batch 37/240, MSE = 0.017160
# Epoch 1, Batch 38/240, MSE = 0.017849
# Epoch 1, Batch 39/240, MSE = 0.017530
# Epoch 1, Batch 40/240, MSE = 0.017476
# Epoch 1, Batch 41/240, MSE = 0.017872
# Epoch 1, Batch 42/240, MSE = 0.018368
# Epoch 1, Batch 43/240, MSE = 0.017503
# Epoch 1, Batch 44/240, MSE = 0.018126
# Epoch 1, Batch 45/240, MSE = 0.018586
# Epoch 1, Batch 46/240, MSE = 0.017874
# Epoch 1, Batch 47/240, MSE = 0.018776
# Epoch 1, Batch 48/240, MSE = 0.017234
# Epoch 1, Batch 49/240, MSE = 0.019023
# Epoch 1, Batch 50/240, MSE = 0.017945
# Epoch 1, Batch 51/240, MSE = 0.017393
# Epoch 1, Batch 52/240, MSE = 0.017442
# Epoch 1, Batch 53/240, MSE = 0.017866
# Epoch 1, Batch 54/240, MSE = 0.019112
# Epoch 1, Batch 55/240, MSE = 0.018806
# Epoch 1, Batch 56/240, MSE = 0.017506
# Epoch 1, Batch 57/240, MSE = 0.017330
# Epoch 1, Batch 58/240, MSE = 0.017160
# Epoch 1, Batch 59/240, MSE = 0.017785
# Epoch 1, Batch 60/240, MSE = 0.017052
# Epoch 1, Batch 61/240, MSE = 0.018009
# Epoch 1, Batch 62/240, MSE = 0.018632
# Epoch 1, Batch 63/240, MSE = 0.017817
# Epoch 1, Batch 64/240, MSE = 0.017331
# Epoch 1, Batch 65/240, MSE = 0.018097
# Epoch 1, Batch 66/240, MSE = 0.019075
# Epoch 1, Batch 67/240, MSE = 0.017241
# Epoch 1, Batch 68/240, MSE = 0.017949
# Epoch 1, Batch 69/240, MSE = 0.017051
# Epoch 1, Batch 70/240, MSE = 0.017211
# Epoch 1, Batch 71/240, MSE = 0.018985
# Epoch 1, Batch 72/240, MSE = 0.017594
# Epoch 1, Batch 73/240, MSE = 0.019412
# Epoch 1, Batch 74/240, MSE = 0.018197
# Epoch 1, Batch 75/240, MSE = 0.019100
# Epoch 1, Batch 76/240, MSE = 0.017456
# Epoch 1, Batch 77/240, MSE = 0.018585
# Epoch 1, Batch 78/240, MSE = 0.017826
# Epoch 1, Batch 79/240, MSE = 0.018152
# Epoch 1, Batch 80/240, MSE = 0.017302
# Epoch 1, Batch 81/240, MSE = 0.017504
# Epoch 1, Batch 82/240, MSE = 0.019146
# Epoch 1, Batch 83/240, MSE = 0.017260
# Epoch 1, Batch 84/240, MSE = 0.015656
# Epoch 1, Batch 85/240, MSE = 0.016538
# Epoch 1, Batch 86/240, MSE = 0.017987
# Epoch 1, Batch 87/240, MSE = 0.016731
# Epoch 1, Batch 88/240, MSE = 0.018121
# Epoch 1, Batch 89/240, MSE = 0.017257
# Epoch 1, Batch 90/240, MSE = 0.018861
# Epoch 1, Batch 91/240, MSE = 0.015344
# Epoch 1, Batch 92/240, MSE = 0.018250
# Epoch 1, Batch 93/240, MSE = 0.016551
# Epoch 1, Batch 94/240, MSE = 0.015486
# Epoch 1, Batch 95/240, MSE = 0.018032
# Epoch 1, Batch 96/240, MSE = 0.017653
# Epoch 1, Batch 97/240, MSE = 0.018275
# Epoch 1, Batch 98/240, MSE = 0.017973
# Epoch 1, Batch 99/240, MSE = 0.019559
# Epoch 1, Batch 100/240, MSE = 0.016630
# Epoch 1, Batch 101/240, MSE = 0.016528
# Epoch 1, Batch 102/240, MSE = 0.016878
# Epoch 1, Batch 103/240, MSE = 0.017377
# Epoch 1, Batch 104/240, MSE = 0.017343
# Epoch 1, Batch 105/240, MSE = 0.016899
# Epoch 1, Batch 106/240, MSE = 0.017354
# Epoch 1, Batch 107/240, MSE = 0.017201
# Epoch 1, Batch 108/240, MSE = 0.017235
# Epoch 1, Batch 109/240, MSE = 0.018137
# Epoch 1, Batch 110/240, MSE = 0.017475
# Epoch 1, Batch 111/240, MSE = 0.018214
# Epoch 1, Batch 112/240, MSE = 0.017415
# Epoch 1, Batch 113/240, MSE = 0.018627
# Epoch 1, Batch 114/240, MSE = 0.017431
# Epoch 1, Batch 115/240, MSE = 0.018951
# Epoch 1, Batch 116/240, MSE = 0.016633
# Epoch 1, Batch 117/240, MSE = 0.017060
# Epoch 1, Batch 118/240, MSE = 0.016294
# Epoch 1, Batch 119/240, MSE = 0.016171
# Epoch 1, Batch 120/240, MSE = 0.016645
# Epoch 1, Batch 121/240, MSE = 0.015954
# Epoch 1, Batch 122/240, MSE = 0.016049
# Epoch 1, Batch 123/240, MSE = 0.017055
# Epoch 1, Batch 124/240, MSE = 0.015739
# Epoch 1, Batch 125/240, MSE = 0.016560
# Epoch 1, Batch 126/240, MSE = 0.016567
# Epoch 1, Batch 127/240, MSE = 0.016167
# Epoch 1, Batch 128/240, MSE = 0.016132
# Epoch 1, Batch 129/240, MSE = 0.016366
# Epoch 1, Batch 130/240, MSE = 0.017218
# Epoch 1, Batch 131/240, MSE = 0.017871
# Epoch 1, Batch 132/240, MSE = 0.017774
# Epoch 1, Batch 133/240, MSE = 0.016917
# Epoch 1, Batch 134/240, MSE = 0.016451
# Epoch 1, Batch 135/240, MSE = 0.017395
# Epoch 1, Batch 136/240, MSE = 0.017688
# Epoch 1, Batch 137/240, MSE = 0.017132
# Epoch 1, Batch 138/240, MSE = 0.017500
# Epoch 1, Batch 139/240, MSE = 0.017027
# Epoch 1, Batch 140/240, MSE = 0.017615
# Epoch 1, Batch 141/240, MSE = 0.016127
# Epoch 1, Batch 142/240, MSE = 0.017391
# Epoch 1, Batch 143/240, MSE = 0.016720
# Epoch 1, Batch 144/240, MSE = 0.016553
# Epoch 1, Batch 145/240, MSE = 0.016833
# Epoch 1, Batch 146/240, MSE = 0.017433
# Epoch 1, Batch 147/240, MSE = 0.016863
# Epoch 1, Batch 148/240, MSE = 0.015192
# Epoch 1, Batch 149/240, MSE = 0.017606
# Epoch 1, Batch 150/240, MSE = 0.018138
# Epoch 1, Batch 151/240, MSE = 0.014311
# Epoch 1, Batch 152/240, MSE = 0.016987
# Epoch 1, Batch 153/240, MSE = 0.015422
# Epoch 1, Batch 154/240, MSE = 0.015286
# Epoch 1, Batch 155/240, MSE = 0.017248
# Epoch 1, Batch 156/240, MSE = 0.016937
# Epoch 1, Batch 157/240, MSE = 0.016768
# Epoch 1, Batch 158/240, MSE = 0.016304
# Epoch 1, Batch 159/240, MSE = 0.015678
# Epoch 1, Batch 160/240, MSE = 0.015626
# Epoch 1, Batch 161/240, MSE = 0.015802
# Epoch 1, Batch 162/240, MSE = 0.016938
# Epoch 1, Batch 163/240, MSE = 0.014983
# Epoch 1, Batch 164/240, MSE = 0.016041
# Epoch 1, Batch 165/240, MSE = 0.015054
# Epoch 1, Batch 166/240, MSE = 0.016216
# Epoch 1, Batch 167/240, MSE = 0.016009
# Epoch 1, Batch 168/240, MSE = 0.016584
# Epoch 1, Batch 169/240, MSE = 0.016663
# Epoch 1, Batch 170/240, MSE = 0.016449
# Epoch 1, Batch 171/240, MSE = 0.016702
# Epoch 1, Batch 172/240, MSE = 0.015484
# Epoch 1, Batch 173/240, MSE = 0.016024
# Epoch 1, Batch 174/240, MSE = 0.015829
# Epoch 1, Batch 175/240, MSE = 0.016232
# Epoch 1, Batch 176/240, MSE = 0.016830
# Epoch 1, Batch 177/240, MSE = 0.016797
# Epoch 1, Batch 178/240, MSE = 0.015301
# Epoch 1, Batch 179/240, MSE = 0.015184
# Epoch 1, Batch 180/240, MSE = 0.015742
# Epoch 1, Batch 181/240, MSE = 0.016511
# Epoch 1, Batch 182/240, MSE = 0.016758
# Epoch 1, Batch 183/240, MSE = 0.015174
# Epoch 1, Batch 184/240, MSE = 0.015288
# Epoch 1, Batch 185/240, MSE = 0.015023
# Epoch 1, Batch 186/240, MSE = 0.016534
# Epoch 1, Batch 187/240, MSE = 0.015853
# Epoch 1, Batch 188/240, MSE = 0.015562
# Epoch 1, Batch 189/240, MSE = 0.016108
# Epoch 1, Batch 190/240, MSE = 0.015116
# Epoch 1, Batch 191/240, MSE = 0.015117
# Epoch 1, Batch 192/240, MSE = 0.017013
# Epoch 1, Batch 193/240, MSE = 0.014525
# Epoch 1, Batch 194/240, MSE = 0.015862
# Epoch 1, Batch 195/240, MSE = 0.015668
# Epoch 1, Batch 196/240, MSE = 0.014697
# Epoch 1, Batch 197/240, MSE = 0.014902
# Epoch 1, Batch 198/240, MSE = 0.015222
# Epoch 1, Batch 199/240, MSE = 0.014577
# Epoch 1, Batch 200/240, MSE = 0.014847
# Epoch 1, Batch 201/240, MSE = 0.014768
# Epoch 1, Batch 202/240, MSE = 0.015195
# Epoch 1, Batch 203/240, MSE = 0.014261
# Epoch 1, Batch 204/240, MSE = 0.015195
# Epoch 1, Batch 205/240, MSE = 0.014599
# Epoch 1, Batch 206/240, MSE = 0.014988
# Epoch 1, Batch 207/240, MSE = 0.015483
# Epoch 1, Batch 208/240, MSE = 0.016501
# Epoch 1, Batch 209/240, MSE = 0.014596
# Epoch 1, Batch 210/240, MSE = 0.016679
# Epoch 1, Batch 211/240, MSE = 0.014267
# Epoch 1, Batch 212/240, MSE = 0.014649
# Epoch 1, Batch 213/240, MSE = 0.015354
# Epoch 1, Batch 214/240, MSE = 0.015328
# Epoch 1, Batch 215/240, MSE = 0.015154
# Epoch 1, Batch 216/240, MSE = 0.015374
# Epoch 1, Batch 217/240, MSE = 0.014669
# Epoch 1, Batch 218/240, MSE = 0.014774
# Epoch 1, Batch 219/240, MSE = 0.015196
# Epoch 1, Batch 220/240, MSE = 0.014984
# Epoch 1, Batch 221/240, MSE = 0.013627
# Epoch 1, Batch 222/240, MSE = 0.015223
# Epoch 1, Batch 223/240, MSE = 0.015050
# Epoch 1, Batch 224/240, MSE = 0.015437
# Epoch 1, Batch 225/240, MSE = 0.016139
# Epoch 1, Batch 226/240, MSE = 0.013873
# Epoch 1, Batch 227/240, MSE = 0.014845
# Epoch 1, Batch 228/240, MSE = 0.013652
# Epoch 1, Batch 229/240, MSE = 0.014527
# Epoch 1, Batch 230/240, MSE = 0.015088
# Epoch 1, Batch 231/240, MSE = 0.013685
# Epoch 1, Batch 232/240, MSE = 0.013428
# Epoch 1, Batch 233/240, MSE = 0.014521
# Epoch 1, Batch 234/240, MSE = 0.015314
# Epoch 1, Batch 235/240, MSE = 0.013735
# Epoch 1, Batch 236/240, MSE = 0.014164
# Epoch 1, Batch 237/240, MSE = 0.014903
# Epoch 1, Batch 238/240, MSE = 0.013979
# Epoch 1, Batch 239/240, MSE = 0.014742
# Epoch 1, Batch 240/240, MSE = 0.014633
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.048125
# Epoch 1, Batch 2/240, MSE = 0.010359
# Epoch 1, Batch 3/240, MSE = 0.011988
# Epoch 1, Batch 4/240, MSE = 0.010350
# Epoch 1, Batch 5/240, MSE = 0.010476
# Epoch 1, Batch 6/240, MSE = 0.010305
# Epoch 1, Batch 7/240, MSE = 0.011056
# Epoch 1, Batch 8/240, MSE = 0.010492
# Epoch 1, Batch 9/240, MSE = 0.011657
# Epoch 1, Batch 10/240, MSE = 0.010964
# Epoch 1, Batch 11/240, MSE = 0.011786
# Epoch 1, Batch 12/240, MSE = 0.009646
# Epoch 1, Batch 13/240, MSE = 0.011237
# Epoch 1, Batch 14/240, MSE = 0.011044
# Epoch 1, Batch 15/240, MSE = 0.010449
# Epoch 1, Batch 16/240, MSE = 0.010390
# Epoch 1, Batch 17/240, MSE = 0.010348
# Epoch 1, Batch 18/240, MSE = 0.009781
# Epoch 1, Batch 19/240, MSE = 0.010064
# Epoch 1, Batch 20/240, MSE = 0.009385
# Epoch 1, Batch 21/240, MSE = 0.010042
# Epoch 1, Batch 22/240, MSE = 0.008641
# Epoch 1, Batch 23/240, MSE = 0.008489
# Epoch 1, Batch 24/240, MSE = 0.009008
# Epoch 1, Batch 25/240, MSE = 0.008381
# Epoch 1, Batch 26/240, MSE = 0.007845
# Epoch 1, Batch 27/240, MSE = 0.009618
# Epoch 1, Batch 28/240, MSE = 0.009219
# Epoch 1, Batch 29/240, MSE = 0.008603
# Epoch 1, Batch 30/240, MSE = 0.008483
# Epoch 1, Batch 31/240, MSE = 0.008132
# Epoch 1, Batch 32/240, MSE = 0.007885
# Epoch 1, Batch 33/240, MSE = 0.007829
# Epoch 1, Batch 34/240, MSE = 0.008718
# Epoch 1, Batch 35/240, MSE = 0.007844
# Epoch 1, Batch 36/240, MSE = 0.009141
# Epoch 1, Batch 37/240, MSE = 0.008745
# Epoch 1, Batch 38/240, MSE = 0.007899
# Epoch 1, Batch 39/240, MSE = 0.008151
# Epoch 1, Batch 40/240, MSE = 0.008159
# Epoch 1, Batch 41/240, MSE = 0.008104
# Epoch 1, Batch 42/240, MSE = 0.008882
# Epoch 1, Batch 43/240, MSE = 0.007765
# Epoch 1, Batch 44/240, MSE = 0.008429
# Epoch 1, Batch 45/240, MSE = 0.008439
# Epoch 1, Batch 46/240, MSE = 0.008708
# Epoch 1, Batch 47/240, MSE = 0.008075
# Epoch 1, Batch 48/240, MSE = 0.008378
# Epoch 1, Batch 49/240, MSE = 0.009077
# Epoch 1, Batch 50/240, MSE = 0.008339
# Epoch 1, Batch 51/240, MSE = 0.008855
# Epoch 1, Batch 52/240, MSE = 0.008593
# Epoch 1, Batch 53/240, MSE = 0.007643
# Epoch 1, Batch 54/240, MSE = 0.008785
# Epoch 1, Batch 55/240, MSE = 0.007951
# Epoch 1, Batch 56/240, MSE = 0.008541
# Epoch 1, Batch 57/240, MSE = 0.008548
# Epoch 1, Batch 58/240, MSE = 0.008547
# Epoch 1, Batch 59/240, MSE = 0.008497
# Epoch 1, Batch 60/240, MSE = 0.008907
# Epoch 1, Batch 61/240, MSE = 0.008370
# Epoch 1, Batch 62/240, MSE = 0.008041
# Epoch 1, Batch 63/240, MSE = 0.007831
# Epoch 1, Batch 64/240, MSE = 0.008081
# Epoch 1, Batch 65/240, MSE = 0.008545
# Epoch 1, Batch 66/240, MSE = 0.008500
# Epoch 1, Batch 67/240, MSE = 0.008505
# Epoch 1, Batch 68/240, MSE = 0.007824
# Epoch 1, Batch 69/240, MSE = 0.008693
# Epoch 1, Batch 70/240, MSE = 0.008066
# Epoch 1, Batch 71/240, MSE = 0.008304
# Epoch 1, Batch 72/240, MSE = 0.008236
# Epoch 1, Batch 73/240, MSE = 0.008266
# Epoch 1, Batch 74/240, MSE = 0.008380
# Epoch 1, Batch 75/240, MSE = 0.008197
# Epoch 1, Batch 76/240, MSE = 0.008546
# Epoch 1, Batch 77/240, MSE = 0.007914
# Epoch 1, Batch 78/240, MSE = 0.008576
# Epoch 1, Batch 79/240, MSE = 0.008021
# Epoch 1, Batch 80/240, MSE = 0.008739
# Epoch 1, Batch 81/240, MSE = 0.008431
# Epoch 1, Batch 82/240, MSE = 0.007764
# Epoch 1, Batch 83/240, MSE = 0.008274
# Epoch 1, Batch 84/240, MSE = 0.008574
# Epoch 1, Batch 85/240, MSE = 0.008903
# Epoch 1, Batch 86/240, MSE = 0.008708
# Epoch 1, Batch 87/240, MSE = 0.008161
# Epoch 1, Batch 88/240, MSE = 0.008290
# Epoch 1, Batch 89/240, MSE = 0.008216
# Epoch 1, Batch 90/240, MSE = 0.008173
# Epoch 1, Batch 91/240, MSE = 0.008316
# Epoch 1, Batch 92/240, MSE = 0.008564
# Epoch 1, Batch 93/240, MSE = 0.007807
# Epoch 1, Batch 94/240, MSE = 0.008258
# Epoch 1, Batch 95/240, MSE = 0.008239
# Epoch 1, Batch 96/240, MSE = 0.008067
# Epoch 1, Batch 97/240, MSE = 0.008689
# Epoch 1, Batch 98/240, MSE = 0.007771
# Epoch 1, Batch 99/240, MSE = 0.008700
# Epoch 1, Batch 100/240, MSE = 0.008123
# Epoch 1, Batch 101/240, MSE = 0.008717
# Epoch 1, Batch 102/240, MSE = 0.008649
# Epoch 1, Batch 103/240, MSE = 0.007774
# Epoch 1, Batch 104/240, MSE = 0.008012
# Epoch 1, Batch 105/240, MSE = 0.008738
# Epoch 1, Batch 106/240, MSE = 0.008694
# Epoch 1, Batch 107/240, MSE = 0.008480
# Epoch 1, Batch 108/240, MSE = 0.008026
# Epoch 1, Batch 109/240, MSE = 0.008459
# Epoch 1, Batch 110/240, MSE = 0.008181
# Epoch 1, Batch 111/240, MSE = 0.008110
# Epoch 1, Batch 112/240, MSE = 0.008376
# Epoch 1, Batch 113/240, MSE = 0.008275
# Epoch 1, Batch 114/240, MSE = 0.008549
# Epoch 1, Batch 115/240, MSE = 0.008544
# Epoch 1, Batch 116/240, MSE = 0.008196
# Epoch 1, Batch 117/240, MSE = 0.008326
# Epoch 1, Batch 118/240, MSE = 0.007924
# Epoch 1, Batch 119/240, MSE = 0.008006
# Epoch 1, Batch 120/240, MSE = 0.007908
# Epoch 1, Batch 121/240, MSE = 0.008351
# Epoch 1, Batch 122/240, MSE = 0.008642
# Epoch 1, Batch 123/240, MSE = 0.008013
# Epoch 1, Batch 124/240, MSE = 0.008368
# Epoch 1, Batch 125/240, MSE = 0.008610
# Epoch 1, Batch 126/240, MSE = 0.008942
# Epoch 1, Batch 127/240, MSE = 0.008147
# Epoch 1, Batch 128/240, MSE = 0.007905
# Epoch 1, Batch 129/240, MSE = 0.008235
# Epoch 1, Batch 130/240, MSE = 0.008567
# Epoch 1, Batch 131/240, MSE = 0.008744
# Epoch 1, Batch 132/240, MSE = 0.008255
# Epoch 1, Batch 133/240, MSE = 0.008494
# Epoch 1, Batch 134/240, MSE = 0.008592
# Epoch 1, Batch 135/240, MSE = 0.008361
# Epoch 1, Batch 136/240, MSE = 0.008586
# Epoch 1, Batch 137/240, MSE = 0.007751
# Epoch 1, Batch 138/240, MSE = 0.009012
# Epoch 1, Batch 139/240, MSE = 0.008248
# Epoch 1, Batch 140/240, MSE = 0.007367
# Epoch 1, Batch 141/240, MSE = 0.008044
# Epoch 1, Batch 142/240, MSE = 0.007745
# Epoch 1, Batch 143/240, MSE = 0.008580
# Epoch 1, Batch 144/240, MSE = 0.007861
# Epoch 1, Batch 145/240, MSE = 0.008570
# Epoch 1, Batch 146/240, MSE = 0.008507
# Epoch 1, Batch 147/240, MSE = 0.008437
# Epoch 1, Batch 148/240, MSE = 0.008673
# Epoch 1, Batch 149/240, MSE = 0.007822
# Epoch 1, Batch 150/240, MSE = 0.008479
# Epoch 1, Batch 151/240, MSE = 0.008118
# Epoch 1, Batch 152/240, MSE = 0.008836
# Epoch 1, Batch 153/240, MSE = 0.009037
# Epoch 1, Batch 154/240, MSE = 0.008387
# Epoch 1, Batch 155/240, MSE = 0.008263
# Epoch 1, Batch 156/240, MSE = 0.009214
# Epoch 1, Batch 157/240, MSE = 0.008096
# Epoch 1, Batch 158/240, MSE = 0.008216
# Epoch 1, Batch 159/240, MSE = 0.008345
# Epoch 1, Batch 160/240, MSE = 0.008138
# Epoch 1, Batch 161/240, MSE = 0.008795
# Epoch 1, Batch 162/240, MSE = 0.008379
# Epoch 1, Batch 163/240, MSE = 0.009183
# Epoch 1, Batch 164/240, MSE = 0.007898
# Epoch 1, Batch 165/240, MSE = 0.008394
# Epoch 1, Batch 166/240, MSE = 0.008159
# Epoch 1, Batch 167/240, MSE = 0.008351
# Epoch 1, Batch 168/240, MSE = 0.009399
# Epoch 1, Batch 169/240, MSE = 0.008113
# Epoch 1, Batch 170/240, MSE = 0.008571
# Epoch 1, Batch 171/240, MSE = 0.008958
# Epoch 1, Batch 172/240, MSE = 0.008854
# Epoch 1, Batch 173/240, MSE = 0.008606
# Epoch 1, Batch 174/240, MSE = 0.008586
# Epoch 1, Batch 175/240, MSE = 0.008529
# Epoch 1, Batch 176/240, MSE = 0.008855
# Epoch 1, Batch 177/240, MSE = 0.008298
# Epoch 1, Batch 178/240, MSE = 0.007434
# Epoch 1, Batch 179/240, MSE = 0.008263
# Epoch 1, Batch 180/240, MSE = 0.007796
# Epoch 1, Batch 181/240, MSE = 0.008651
# Epoch 1, Batch 182/240, MSE = 0.008529
# Epoch 1, Batch 183/240, MSE = 0.008351
# Epoch 1, Batch 184/240, MSE = 0.008808
# Epoch 1, Batch 185/240, MSE = 0.007908
# Epoch 1, Batch 186/240, MSE = 0.007854
# Epoch 1, Batch 187/240, MSE = 0.008344
# Epoch 1, Batch 188/240, MSE = 0.008783
# Epoch 1, Batch 189/240, MSE = 0.008101
# Epoch 1, Batch 190/240, MSE = 0.008828
# Epoch 1, Batch 191/240, MSE = 0.009080
# Epoch 1, Batch 192/240, MSE = 0.008182
# Epoch 1, Batch 193/240, MSE = 0.009136
# Epoch 1, Batch 194/240, MSE = 0.008899
# Epoch 1, Batch 195/240, MSE = 0.008574
# Epoch 1, Batch 196/240, MSE = 0.008054
# Epoch 1, Batch 197/240, MSE = 0.008740
# Epoch 1, Batch 198/240, MSE = 0.008884
# Epoch 1, Batch 199/240, MSE = 0.008179
# Epoch 1, Batch 200/240, MSE = 0.008199
# Epoch 1, Batch 201/240, MSE = 0.007998
# Epoch 1, Batch 202/240, MSE = 0.008893
# Epoch 1, Batch 203/240, MSE = 0.007835
# Epoch 1, Batch 204/240, MSE = 0.008522
# Epoch 1, Batch 205/240, MSE = 0.008252
# Epoch 1, Batch 206/240, MSE = 0.008165
# Epoch 1, Batch 207/240, MSE = 0.009097
# Epoch 1, Batch 208/240, MSE = 0.007887
# Epoch 1, Batch 209/240, MSE = 0.008335
# Epoch 1, Batch 210/240, MSE = 0.008012
# Epoch 1, Batch 211/240, MSE = 0.008275
# Epoch 1, Batch 212/240, MSE = 0.008991
# Epoch 1, Batch 213/240, MSE = 0.007862
# Epoch 1, Batch 214/240, MSE = 0.008120
# Epoch 1, Batch 215/240, MSE = 0.007889
# Epoch 1, Batch 216/240, MSE = 0.007807
# Epoch 1, Batch 217/240, MSE = 0.007778
# Epoch 1, Batch 218/240, MSE = 0.008538
# Epoch 1, Batch 219/240, MSE = 0.008303
# Epoch 1, Batch 220/240, MSE = 0.009102
# Epoch 1, Batch 221/240, MSE = 0.008136
# Epoch 1, Batch 222/240, MSE = 0.007779
# Epoch 1, Batch 223/240, MSE = 0.008002
# Epoch 1, Batch 224/240, MSE = 0.007730
# Epoch 1, Batch 225/240, MSE = 0.008212
# Epoch 1, Batch 226/240, MSE = 0.007872
# Epoch 1, Batch 227/240, MSE = 0.007476
# Epoch 1, Batch 228/240, MSE = 0.008461
# Epoch 1, Batch 229/240, MSE = 0.008273
# Epoch 1, Batch 230/240, MSE = 0.008602
# Epoch 1, Batch 231/240, MSE = 0.008446
# Epoch 1, Batch 232/240, MSE = 0.008182
# Epoch 1, Batch 233/240, MSE = 0.008006
# Epoch 1, Batch 234/240, MSE = 0.008176
# Epoch 1, Batch 235/240, MSE = 0.007796
# Epoch 1, Batch 236/240, MSE = 0.007921
# Epoch 1, Batch 237/240, MSE = 0.008351
# Epoch 1, Batch 238/240, MSE = 0.008757
# Epoch 1, Batch 239/240, MSE = 0.007753
# Epoch 1, Batch 240/240, MSE = 0.009180
#
# ============================================================
# Epoch 2/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.010060
# Epoch 1, Batch 2/240, MSE = 0.011767
# Epoch 1, Batch 3/240, MSE = 0.009685
# Epoch 1, Batch 4/240, MSE = 0.009331
# Epoch 1, Batch 5/240, MSE = 0.010284
# Epoch 1, Batch 6/240, MSE = 0.010123
# Epoch 1, Batch 7/240, MSE = 0.009902
# Epoch 1, Batch 8/240, MSE = 0.009636
# Epoch 1, Batch 9/240, MSE = 0.009834
# Epoch 1, Batch 10/240, MSE = 0.009765
# Epoch 1, Batch 11/240, MSE = 0.009713
# Epoch 1, Batch 12/240, MSE = 0.009350
# Epoch 1, Batch 13/240, MSE = 0.009101
# Epoch 1, Batch 14/240, MSE = 0.008776
# Epoch 1, Batch 15/240, MSE = 0.009097
# Epoch 1, Batch 16/240, MSE = 0.009734
# Epoch 1, Batch 17/240, MSE = 0.010171
# Epoch 1, Batch 18/240, MSE = 0.009468
# Epoch 1, Batch 19/240, MSE = 0.008792
# Epoch 1, Batch 20/240, MSE = 0.009737
# Epoch 1, Batch 21/240, MSE = 0.008624
# Epoch 1, Batch 22/240, MSE = 0.010158
# Epoch 1, Batch 23/240, MSE = 0.009958
# Epoch 1, Batch 24/240, MSE = 0.008979
# Epoch 1, Batch 25/240, MSE = 0.009110
# Epoch 1, Batch 26/240, MSE = 0.009531
# Epoch 1, Batch 27/240, MSE = 0.010129
# Epoch 1, Batch 28/240, MSE = 0.009811
# Epoch 1, Batch 29/240, MSE = 0.010498
# Epoch 1, Batch 30/240, MSE = 0.008285
# Epoch 1, Batch 31/240, MSE = 0.008573
# Epoch 1, Batch 32/240, MSE = 0.009914
# Epoch 1, Batch 33/240, MSE = 0.009415
# Epoch 1, Batch 34/240, MSE = 0.008283
# Epoch 1, Batch 35/240, MSE = 0.009294
# Epoch 1, Batch 36/240, MSE = 0.008386
# Epoch 1, Batch 37/240, MSE = 0.009111
# Epoch 1, Batch 38/240, MSE = 0.008512
# Epoch 1, Batch 39/240, MSE = 0.009114
# Epoch 1, Batch 40/240, MSE = 0.010381
# Epoch 1, Batch 41/240, MSE = 0.010862
# Epoch 1, Batch 42/240, MSE = 0.009028
# Epoch 1, Batch 43/240, MSE = 0.008910
# Epoch 1, Batch 44/240, MSE = 0.009364
# Epoch 1, Batch 45/240, MSE = 0.007776
# Epoch 1, Batch 46/240, MSE = 0.008544
# Epoch 1, Batch 47/240, MSE = 0.007477
# Epoch 1, Batch 48/240, MSE = 0.007854
# Epoch 1, Batch 49/240, MSE = 0.009093
# Epoch 1, Batch 50/240, MSE = 0.008230
# Epoch 1, Batch 51/240, MSE = 0.008916
# Epoch 1, Batch 52/240, MSE = 0.008384
# Epoch 1, Batch 53/240, MSE = 0.008583
# Epoch 1, Batch 54/240, MSE = 0.008339
# Epoch 1, Batch 55/240, MSE = 0.008148
# Epoch 1, Batch 56/240, MSE = 0.009047
# Epoch 1, Batch 57/240, MSE = 0.008185
# Epoch 1, Batch 58/240, MSE = 0.007201
# Epoch 1, Batch 59/240, MSE = 0.007663
# Epoch 1, Batch 60/240, MSE = 0.008590
# Epoch 1, Batch 61/240, MSE = 0.007930
# Epoch 1, Batch 62/240, MSE = 0.007280
# Epoch 1, Batch 63/240, MSE = 0.007634
# Epoch 1, Batch 64/240, MSE = 0.008310
# Epoch 1, Batch 65/240, MSE = 0.008096
# Epoch 1, Batch 66/240, MSE = 0.007646
# Epoch 1, Batch 67/240, MSE = 0.007527
# Epoch 1, Batch 68/240, MSE = 0.006990
# Epoch 1, Batch 69/240, MSE = 0.007641
# Epoch 1, Batch 70/240, MSE = 0.007562
# Epoch 1, Batch 71/240, MSE = 0.007853
# Epoch 1, Batch 72/240, MSE = 0.007893
# Epoch 1, Batch 73/240, MSE = 0.008141
# Epoch 1, Batch 74/240, MSE = 0.006968
# Epoch 1, Batch 75/240, MSE = 0.007151
# Epoch 1, Batch 76/240, MSE = 0.007946
# Epoch 1, Batch 77/240, MSE = 0.007445
# Epoch 1, Batch 78/240, MSE = 0.008512
# Epoch 1, Batch 79/240, MSE = 0.007743
# Epoch 1, Batch 80/240, MSE = 0.007394
# Epoch 1, Batch 81/240, MSE = 0.007706
# Epoch 1, Batch 82/240, MSE = 0.007026
# Epoch 1, Batch 83/240, MSE = 0.007483
# Epoch 1, Batch 84/240, MSE = 0.008633
# Epoch 1, Batch 85/240, MSE = 0.007941
# Epoch 1, Batch 86/240, MSE = 0.008065
# Epoch 1, Batch 87/240, MSE = 0.007176
# Epoch 1, Batch 88/240, MSE = 0.008259
# Epoch 1, Batch 89/240, MSE = 0.007336
# Epoch 1, Batch 90/240, MSE = 0.007437
# Epoch 1, Batch 91/240, MSE = 0.007778
# Epoch 1, Batch 92/240, MSE = 0.006995
# Epoch 1, Batch 93/240, MSE = 0.006043
# Epoch 1, Batch 94/240, MSE = 0.006918
# Epoch 1, Batch 95/240, MSE = 0.006363
# Epoch 1, Batch 96/240, MSE = 0.007376
# Epoch 1, Batch 97/240, MSE = 0.006681
# Epoch 1, Batch 98/240, MSE = 0.007520
# Epoch 1, Batch 99/240, MSE = 0.006758
# Epoch 1, Batch 100/240, MSE = 0.006896
# Epoch 1, Batch 101/240, MSE = 0.007145
# Epoch 1, Batch 102/240, MSE = 0.006693
# Epoch 1, Batch 103/240, MSE = 0.007347
# Epoch 1, Batch 104/240, MSE = 0.007325
# Epoch 1, Batch 105/240, MSE = 0.007559
# Epoch 1, Batch 106/240, MSE = 0.007282
# Epoch 1, Batch 107/240, MSE = 0.007521
# Epoch 1, Batch 108/240, MSE = 0.006501
# Epoch 1, Batch 109/240, MSE = 0.006945
# Epoch 1, Batch 110/240, MSE = 0.006657
# Epoch 1, Batch 111/240, MSE = 0.006589
# Epoch 1, Batch 112/240, MSE = 0.006560
# Epoch 1, Batch 113/240, MSE = 0.006801
# Epoch 1, Batch 114/240, MSE = 0.007932
# Epoch 1, Batch 115/240, MSE = 0.006282
# Epoch 1, Batch 116/240, MSE = 0.006775
# Epoch 1, Batch 117/240, MSE = 0.006759
# Epoch 1, Batch 118/240, MSE = 0.006926
# Epoch 1, Batch 119/240, MSE = 0.006048
# Epoch 1, Batch 120/240, MSE = 0.006356
# Epoch 1, Batch 121/240, MSE = 0.006407
# Epoch 1, Batch 122/240, MSE = 0.007451
# Epoch 1, Batch 123/240, MSE = 0.006255
# Epoch 1, Batch 124/240, MSE = 0.005877
# Epoch 1, Batch 125/240, MSE = 0.006984
# Epoch 1, Batch 126/240, MSE = 0.006375
# Epoch 1, Batch 127/240, MSE = 0.007437
# Epoch 1, Batch 128/240, MSE = 0.006373
# Epoch 1, Batch 129/240, MSE = 0.007013
# Epoch 1, Batch 130/240, MSE = 0.006038
# Epoch 1, Batch 131/240, MSE = 0.006753
# Epoch 1, Batch 132/240, MSE = 0.006322
# Epoch 1, Batch 133/240, MSE = 0.006498
# Epoch 1, Batch 134/240, MSE = 0.006781
# Epoch 1, Batch 135/240, MSE = 0.006323
# Epoch 1, Batch 136/240, MSE = 0.005942
# Epoch 1, Batch 137/240, MSE = 0.006276
# Epoch 1, Batch 138/240, MSE = 0.005966
# Epoch 1, Batch 139/240, MSE = 0.005741
# Epoch 1, Batch 140/240, MSE = 0.006759
# Epoch 1, Batch 141/240, MSE = 0.005189
# Epoch 1, Batch 142/240, MSE = 0.006328
# Epoch 1, Batch 143/240, MSE = 0.005761
# Epoch 1, Batch 144/240, MSE = 0.005366
# Epoch 1, Batch 145/240, MSE = 0.006332
# Epoch 1, Batch 146/240, MSE = 0.006042
# Epoch 1, Batch 147/240, MSE = 0.005686
# Epoch 1, Batch 148/240, MSE = 0.006094
# Epoch 1, Batch 149/240, MSE = 0.005625
# Epoch 1, Batch 150/240, MSE = 0.006188
# Epoch 1, Batch 151/240, MSE = 0.006371
# Epoch 1, Batch 152/240, MSE = 0.006036
# Epoch 1, Batch 153/240, MSE = 0.005838
# Epoch 1, Batch 154/240, MSE = 0.006052
# Epoch 1, Batch 155/240, MSE = 0.005818
# Epoch 1, Batch 156/240, MSE = 0.006191
# Epoch 1, Batch 157/240, MSE = 0.005954
# Epoch 1, Batch 158/240, MSE = 0.005941
# Epoch 1, Batch 159/240, MSE = 0.004767
# Epoch 1, Batch 160/240, MSE = 0.005143
# Epoch 1, Batch 161/240, MSE = 0.005699
# Epoch 1, Batch 162/240, MSE = 0.005411
# Epoch 1, Batch 163/240, MSE = 0.005527
# Epoch 1, Batch 164/240, MSE = 0.005822
# Epoch 1, Batch 165/240, MSE = 0.004764
# Epoch 1, Batch 166/240, MSE = 0.005570
# Epoch 1, Batch 167/240, MSE = 0.005733
# Epoch 1, Batch 168/240, MSE = 0.005870
# Epoch 1, Batch 169/240, MSE = 0.005317
# Epoch 1, Batch 170/240, MSE = 0.005268
# Epoch 1, Batch 171/240, MSE = 0.005318
# Epoch 1, Batch 172/240, MSE = 0.005682
# Epoch 1, Batch 173/240, MSE = 0.005752
# Epoch 1, Batch 174/240, MSE = 0.005471
# Epoch 1, Batch 175/240, MSE = 0.005884
# Epoch 1, Batch 176/240, MSE = 0.005225
# Epoch 1, Batch 177/240, MSE = 0.005324
# Epoch 1, Batch 178/240, MSE = 0.005465
# Epoch 1, Batch 179/240, MSE = 0.005007
# Epoch 1, Batch 180/240, MSE = 0.005029
# Epoch 1, Batch 181/240, MSE = 0.005408
# Epoch 1, Batch 182/240, MSE = 0.005270
# Epoch 1, Batch 183/240, MSE = 0.005412
# Epoch 1, Batch 184/240, MSE = 0.006338
# Epoch 1, Batch 185/240, MSE = 0.005626
# Epoch 1, Batch 186/240, MSE = 0.004889
# Epoch 1, Batch 187/240, MSE = 0.004943
# Epoch 1, Batch 188/240, MSE = 0.004653
# Epoch 1, Batch 189/240, MSE = 0.005084
# Epoch 1, Batch 190/240, MSE = 0.004124
# Epoch 1, Batch 191/240, MSE = 0.004887
# Epoch 1, Batch 192/240, MSE = 0.005488
# Epoch 1, Batch 193/240, MSE = 0.004676
# Epoch 1, Batch 194/240, MSE = 0.004627
# Epoch 1, Batch 195/240, MSE = 0.004929
# Epoch 1, Batch 196/240, MSE = 0.004934
# Epoch 1, Batch 197/240, MSE = 0.005299
# Epoch 1, Batch 198/240, MSE = 0.004864
# Epoch 1, Batch 199/240, MSE = 0.005070
# Epoch 1, Batch 200/240, MSE = 0.004771
# Epoch 1, Batch 201/240, MSE = 0.005145
# Epoch 1, Batch 202/240, MSE = 0.005161
# Epoch 1, Batch 203/240, MSE = 0.004827
# Epoch 1, Batch 204/240, MSE = 0.004754
# Epoch 1, Batch 205/240, MSE = 0.004831
# Epoch 1, Batch 206/240, MSE = 0.004194
# Epoch 1, Batch 207/240, MSE = 0.005178
# Epoch 1, Batch 208/240, MSE = 0.004471
# Epoch 1, Batch 209/240, MSE = 0.003982
# Epoch 1, Batch 210/240, MSE = 0.004867
# Epoch 1, Batch 211/240, MSE = 0.004918
# Epoch 1, Batch 212/240, MSE = 0.004984
# Epoch 1, Batch 213/240, MSE = 0.004138
# Epoch 1, Batch 214/240, MSE = 0.004700
# Epoch 1, Batch 215/240, MSE = 0.005105
# Epoch 1, Batch 216/240, MSE = 0.004775
# Epoch 1, Batch 217/240, MSE = 0.004761
# Epoch 1, Batch 218/240, MSE = 0.004544
# Epoch 1, Batch 219/240, MSE = 0.004731
# Epoch 1, Batch 220/240, MSE = 0.004347
# Epoch 1, Batch 221/240, MSE = 0.005293
# Epoch 1, Batch 222/240, MSE = 0.004761
# Epoch 1, Batch 223/240, MSE = 0.004214
# Epoch 1, Batch 224/240, MSE = 0.004786
# Epoch 1, Batch 225/240, MSE = 0.004758
# Epoch 1, Batch 226/240, MSE = 0.004396
# Epoch 1, Batch 227/240, MSE = 0.004685
# Epoch 1, Batch 228/240, MSE = 0.004376
# Epoch 1, Batch 229/240, MSE = 0.004139
# Epoch 1, Batch 230/240, MSE = 0.004298
# Epoch 1, Batch 231/240, MSE = 0.004759
# Epoch 1, Batch 232/240, MSE = 0.004566
# Epoch 1, Batch 233/240, MSE = 0.004337
# Epoch 1, Batch 234/240, MSE = 0.004339
# Epoch 1, Batch 235/240, MSE = 0.004530
# Epoch 1, Batch 236/240, MSE = 0.004179
# Epoch 1, Batch 237/240, MSE = 0.004193
# Epoch 1, Batch 238/240, MSE = 0.004228
# Epoch 1, Batch 239/240, MSE = 0.004690
# Epoch 1, Batch 240/240, MSE = 0.004582
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.030098
# Epoch 1, Batch 2/240, MSE = 0.026900
# Epoch 1, Batch 3/240, MSE = 0.022726
# Epoch 1, Batch 4/240, MSE = 0.026923
# Epoch 1, Batch 5/240, MSE = 0.023595
# Epoch 1, Batch 6/240, MSE = 0.024387
# Epoch 1, Batch 7/240, MSE = 0.025783
# Epoch 1, Batch 8/240, MSE = 0.027192
# Epoch 1, Batch 9/240, MSE = 0.025652
# Epoch 1, Batch 10/240, MSE = 0.024452
# Epoch 1, Batch 11/240, MSE = 0.023852
# Epoch 1, Batch 12/240, MSE = 0.021516
# Epoch 1, Batch 13/240, MSE = 0.022340
# Epoch 1, Batch 14/240, MSE = 0.026245
# Epoch 1, Batch 15/240, MSE = 0.022768
# Epoch 1, Batch 16/240, MSE = 0.026282
# Epoch 1, Batch 17/240, MSE = 0.027330
# Epoch 1, Batch 18/240, MSE = 0.022526
# Epoch 1, Batch 19/240, MSE = 0.024931
# Epoch 1, Batch 20/240, MSE = 0.025447
# Epoch 1, Batch 21/240, MSE = 0.023866
# Epoch 1, Batch 22/240, MSE = 0.022422
# Epoch 1, Batch 23/240, MSE = 0.023817
# Epoch 1, Batch 24/240, MSE = 0.023209
# Epoch 1, Batch 25/240, MSE = 0.026601
# Epoch 1, Batch 26/240, MSE = 0.022838
# Epoch 1, Batch 27/240, MSE = 0.022765
# Epoch 1, Batch 28/240, MSE = 0.022970
# Epoch 1, Batch 29/240, MSE = 0.024621
# Epoch 1, Batch 30/240, MSE = 0.022382
# Epoch 1, Batch 31/240, MSE = 0.022390
# Epoch 1, Batch 32/240, MSE = 0.022341
# Epoch 1, Batch 33/240, MSE = 0.022314
# Epoch 1, Batch 34/240, MSE = 0.022536
# Epoch 1, Batch 35/240, MSE = 0.022845
# Epoch 1, Batch 36/240, MSE = 0.020868
# Epoch 1, Batch 37/240, MSE = 0.023428
# Epoch 1, Batch 38/240, MSE = 0.021520
# Epoch 1, Batch 39/240, MSE = 0.024186
# Epoch 1, Batch 40/240, MSE = 0.021705
# Epoch 1, Batch 41/240, MSE = 0.024582
# Epoch 1, Batch 42/240, MSE = 0.024970
# Epoch 1, Batch 43/240, MSE = 0.023024
# Epoch 1, Batch 44/240, MSE = 0.021195
# Epoch 1, Batch 45/240, MSE = 0.021922
# Epoch 1, Batch 46/240, MSE = 0.023380
# Epoch 1, Batch 47/240, MSE = 0.021955
# Epoch 1, Batch 48/240, MSE = 0.023557
# Epoch 1, Batch 49/240, MSE = 0.022344
# Epoch 1, Batch 50/240, MSE = 0.022638
# Epoch 1, Batch 51/240, MSE = 0.022005
# Epoch 1, Batch 52/240, MSE = 0.024811
# Epoch 1, Batch 53/240, MSE = 0.022983
# Epoch 1, Batch 54/240, MSE = 0.023112
# Epoch 1, Batch 55/240, MSE = 0.021585
# Epoch 1, Batch 56/240, MSE = 0.020254
# Epoch 1, Batch 57/240, MSE = 0.023145
# Epoch 1, Batch 58/240, MSE = 0.021915
# Epoch 1, Batch 59/240, MSE = 0.022864
# Epoch 1, Batch 60/240, MSE = 0.020014
# Epoch 1, Batch 61/240, MSE = 0.024402
# Epoch 1, Batch 62/240, MSE = 0.022234
# Epoch 1, Batch 63/240, MSE = 0.023397
# Epoch 1, Batch 64/240, MSE = 0.022470
# Epoch 1, Batch 65/240, MSE = 0.020347
# Epoch 1, Batch 66/240, MSE = 0.021329
# Epoch 1, Batch 67/240, MSE = 0.022634
# Epoch 1, Batch 68/240, MSE = 0.022294
# Epoch 1, Batch 69/240, MSE = 0.021284
# Epoch 1, Batch 70/240, MSE = 0.018839
# Epoch 1, Batch 71/240, MSE = 0.022380
# Epoch 1, Batch 72/240, MSE = 0.019054
# Epoch 1, Batch 73/240, MSE = 0.022197
# Epoch 1, Batch 74/240, MSE = 0.022291
# Epoch 1, Batch 75/240, MSE = 0.019903
# Epoch 1, Batch 76/240, MSE = 0.020056
# Epoch 1, Batch 77/240, MSE = 0.020756
# Epoch 1, Batch 78/240, MSE = 0.021567
# Epoch 1, Batch 79/240, MSE = 0.021981
# Epoch 1, Batch 80/240, MSE = 0.022757
# Epoch 1, Batch 81/240, MSE = 0.022174
# Epoch 1, Batch 82/240, MSE = 0.020755
# Epoch 1, Batch 83/240, MSE = 0.020800
# Epoch 1, Batch 84/240, MSE = 0.020704
# Epoch 1, Batch 85/240, MSE = 0.022031
# Epoch 1, Batch 86/240, MSE = 0.020208
# Epoch 1, Batch 87/240, MSE = 0.021646
# Epoch 1, Batch 88/240, MSE = 0.021473
# Epoch 1, Batch 89/240, MSE = 0.021966
# Epoch 1, Batch 90/240, MSE = 0.019904
# Epoch 1, Batch 91/240, MSE = 0.019488
# Epoch 1, Batch 92/240, MSE = 0.020081
# Epoch 1, Batch 93/240, MSE = 0.019489
# Epoch 1, Batch 94/240, MSE = 0.018733
# Epoch 1, Batch 95/240, MSE = 0.021176
# Epoch 1, Batch 96/240, MSE = 0.019305
# Epoch 1, Batch 97/240, MSE = 0.020895
# Epoch 1, Batch 98/240, MSE = 0.020671
# Epoch 1, Batch 99/240, MSE = 0.019825
# Epoch 1, Batch 100/240, MSE = 0.020168
# Epoch 1, Batch 101/240, MSE = 0.019749
# Epoch 1, Batch 102/240, MSE = 0.020805
# Epoch 1, Batch 103/240, MSE = 0.019522
# Epoch 1, Batch 104/240, MSE = 0.017780
# Epoch 1, Batch 105/240, MSE = 0.018068
# Epoch 1, Batch 106/240, MSE = 0.019640
# Epoch 1, Batch 107/240, MSE = 0.017641
# Epoch 1, Batch 108/240, MSE = 0.017813
# Epoch 1, Batch 109/240, MSE = 0.018962
# Epoch 1, Batch 110/240, MSE = 0.018576
# Epoch 1, Batch 111/240, MSE = 0.018206
# Epoch 1, Batch 112/240, MSE = 0.018754
# Epoch 1, Batch 113/240, MSE = 0.020127
# Epoch 1, Batch 114/240, MSE = 0.019285
# Epoch 1, Batch 115/240, MSE = 0.018596
# Epoch 1, Batch 116/240, MSE = 0.019588
# Epoch 1, Batch 117/240, MSE = 0.018625
# Epoch 1, Batch 118/240, MSE = 0.020605
# Epoch 1, Batch 119/240, MSE = 0.020221
# Epoch 1, Batch 120/240, MSE = 0.019497
# Epoch 1, Batch 121/240, MSE = 0.018320
# Epoch 1, Batch 122/240, MSE = 0.017483
# Epoch 1, Batch 123/240, MSE = 0.020181
# Epoch 1, Batch 124/240, MSE = 0.019491
# Epoch 1, Batch 125/240, MSE = 0.020805
# Epoch 1, Batch 126/240, MSE = 0.018734
# Epoch 1, Batch 127/240, MSE = 0.020405
# Epoch 1, Batch 128/240, MSE = 0.017351
# Epoch 1, Batch 129/240, MSE = 0.018616
# Epoch 1, Batch 130/240, MSE = 0.017466
# Epoch 1, Batch 131/240, MSE = 0.019634
# Epoch 1, Batch 132/240, MSE = 0.018981
# Epoch 1, Batch 133/240, MSE = 0.019489
# Epoch 1, Batch 134/240, MSE = 0.018611
# Epoch 1, Batch 135/240, MSE = 0.016824
# Epoch 1, Batch 136/240, MSE = 0.019387
# Epoch 1, Batch 137/240, MSE = 0.018134
# Epoch 1, Batch 138/240, MSE = 0.017790
# Epoch 1, Batch 139/240, MSE = 0.017114
# Epoch 1, Batch 140/240, MSE = 0.017848
# Epoch 1, Batch 141/240, MSE = 0.017502
# Epoch 1, Batch 142/240, MSE = 0.018502
# Epoch 1, Batch 143/240, MSE = 0.017661
# Epoch 1, Batch 144/240, MSE = 0.018486
# Epoch 1, Batch 145/240, MSE = 0.018260
# Epoch 1, Batch 146/240, MSE = 0.018634
# Epoch 1, Batch 147/240, MSE = 0.016873
# Epoch 1, Batch 148/240, MSE = 0.018268
# Epoch 1, Batch 149/240, MSE = 0.017544
# Epoch 1, Batch 150/240, MSE = 0.017692
# Epoch 1, Batch 151/240, MSE = 0.015513
# Epoch 1, Batch 152/240, MSE = 0.016704
# Epoch 1, Batch 153/240, MSE = 0.016944
# Epoch 1, Batch 154/240, MSE = 0.016134
# Epoch 1, Batch 155/240, MSE = 0.015790
# Epoch 1, Batch 156/240, MSE = 0.015962
# Epoch 1, Batch 157/240, MSE = 0.016458
# Epoch 1, Batch 158/240, MSE = 0.017365
# Epoch 1, Batch 159/240, MSE = 0.017415
# Epoch 1, Batch 160/240, MSE = 0.016210
# Epoch 1, Batch 161/240, MSE = 0.016787
# Epoch 1, Batch 162/240, MSE = 0.017414
# Epoch 1, Batch 163/240, MSE = 0.017414
# Epoch 1, Batch 164/240, MSE = 0.016772
# Epoch 1, Batch 165/240, MSE = 0.016663
# Epoch 1, Batch 166/240, MSE = 0.018720
# Epoch 1, Batch 167/240, MSE = 0.015669
# Epoch 1, Batch 168/240, MSE = 0.016542
# Epoch 1, Batch 169/240, MSE = 0.016847
# Epoch 1, Batch 170/240, MSE = 0.016112
# Epoch 1, Batch 171/240, MSE = 0.017929
# Epoch 1, Batch 172/240, MSE = 0.019310
# Epoch 1, Batch 173/240, MSE = 0.017305
# Epoch 1, Batch 174/240, MSE = 0.016495
# Epoch 1, Batch 175/240, MSE = 0.015817
# Epoch 1, Batch 176/240, MSE = 0.015812
# Epoch 1, Batch 177/240, MSE = 0.016457
# Epoch 1, Batch 178/240, MSE = 0.016376
# Epoch 1, Batch 179/240, MSE = 0.016029
# Epoch 1, Batch 180/240, MSE = 0.016269
# Epoch 1, Batch 181/240, MSE = 0.016901
# Epoch 1, Batch 182/240, MSE = 0.015682
# Epoch 1, Batch 183/240, MSE = 0.016055
# Epoch 1, Batch 184/240, MSE = 0.016007
# Epoch 1, Batch 185/240, MSE = 0.015535
# Epoch 1, Batch 186/240, MSE = 0.017752
# Epoch 1, Batch 187/240, MSE = 0.016123
# Epoch 1, Batch 188/240, MSE = 0.015999
# Epoch 1, Batch 189/240, MSE = 0.014647
# Epoch 1, Batch 190/240, MSE = 0.014838
# Epoch 1, Batch 191/240, MSE = 0.016566
# Epoch 1, Batch 192/240, MSE = 0.015930
# Epoch 1, Batch 193/240, MSE = 0.016556
# Epoch 1, Batch 194/240, MSE = 0.015537
# Epoch 1, Batch 195/240, MSE = 0.015573
# Epoch 1, Batch 196/240, MSE = 0.013883
# Epoch 1, Batch 197/240, MSE = 0.015385
# Epoch 1, Batch 198/240, MSE = 0.015946
# Epoch 1, Batch 199/240, MSE = 0.015328
# Epoch 1, Batch 200/240, MSE = 0.015869
# Epoch 1, Batch 201/240, MSE = 0.014788
# Epoch 1, Batch 202/240, MSE = 0.014811
# Epoch 1, Batch 203/240, MSE = 0.014930
# Epoch 1, Batch 204/240, MSE = 0.014696
# Epoch 1, Batch 205/240, MSE = 0.016638
# Epoch 1, Batch 206/240, MSE = 0.015775
# Epoch 1, Batch 207/240, MSE = 0.014293
# Epoch 1, Batch 208/240, MSE = 0.015254
# Epoch 1, Batch 209/240, MSE = 0.015678
# Epoch 1, Batch 210/240, MSE = 0.015354
# Epoch 1, Batch 211/240, MSE = 0.015667
# Epoch 1, Batch 212/240, MSE = 0.014638
# Epoch 1, Batch 213/240, MSE = 0.014255
# Epoch 1, Batch 214/240, MSE = 0.013407
# Epoch 1, Batch 215/240, MSE = 0.014247
# Epoch 1, Batch 216/240, MSE = 0.014997
# Epoch 1, Batch 217/240, MSE = 0.014726
# Epoch 1, Batch 218/240, MSE = 0.015178
# Epoch 1, Batch 219/240, MSE = 0.015333
# Epoch 1, Batch 220/240, MSE = 0.015671
# Epoch 1, Batch 221/240, MSE = 0.013918
# Epoch 1, Batch 222/240, MSE = 0.013108
# Epoch 1, Batch 223/240, MSE = 0.015201
# Epoch 1, Batch 224/240, MSE = 0.014412
# Epoch 1, Batch 225/240, MSE = 0.016096
# Epoch 1, Batch 226/240, MSE = 0.013162
# Epoch 1, Batch 227/240, MSE = 0.015297
# Epoch 1, Batch 228/240, MSE = 0.014885
# Epoch 1, Batch 229/240, MSE = 0.013848
# Epoch 1, Batch 230/240, MSE = 0.013417
# Epoch 1, Batch 231/240, MSE = 0.013914
# Epoch 1, Batch 232/240, MSE = 0.012203
# Epoch 1, Batch 233/240, MSE = 0.013904
# Epoch 1, Batch 234/240, MSE = 0.014202
# Epoch 1, Batch 235/240, MSE = 0.013230
# Epoch 1, Batch 236/240, MSE = 0.014018
# Epoch 1, Batch 237/240, MSE = 0.013330
# Epoch 1, Batch 238/240, MSE = 0.013714
# Epoch 1, Batch 239/240, MSE = 0.013974
# Epoch 1, Batch 240/240, MSE = 0.014593
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.034800
# Epoch 1, Batch 2/240, MSE = 0.034656
# Epoch 1, Batch 3/240, MSE = 0.033616
# Epoch 1, Batch 4/240, MSE = 0.035790
# Epoch 1, Batch 5/240, MSE = 0.032578
# Epoch 1, Batch 6/240, MSE = 0.033150
# Epoch 1, Batch 7/240, MSE = 0.033274
# Epoch 1, Batch 8/240, MSE = 0.032183
# Epoch 1, Batch 9/240, MSE = 0.032775
# Epoch 1, Batch 10/240, MSE = 0.033605
# Epoch 1, Batch 11/240, MSE = 0.032724
# Epoch 1, Batch 12/240, MSE = 0.035843
# Epoch 1, Batch 13/240, MSE = 0.032589
# Epoch 1, Batch 14/240, MSE = 0.032264
# Epoch 1, Batch 15/240, MSE = 0.033687
# Epoch 1, Batch 16/240, MSE = 0.033127
# Epoch 1, Batch 17/240, MSE = 0.031176
# Epoch 1, Batch 18/240, MSE = 0.031274
# Epoch 1, Batch 19/240, MSE = 0.035504
# Epoch 1, Batch 20/240, MSE = 0.031726
# ...
# Epoch 1, Batch 69/240, MSE = 0.000079
# Epoch 1, Batch 70/240, MSE = 0.000083
# Epoch 1, Batch 71/240, MSE = 0.000079
# Epoch 1, Batch 72/240, MSE = 0.000077
# Epoch 1, Batch 73/240, MSE = 0.000068
# Epoch 1, Batch 74/240, MSE = 0.000067
# Epoch 1, Batch 75/240, MSE = 0.000082
# Epoch 1, Batch 76/240, MSE = 0.000074
# Epoch 1, Batch 77/240, MSE = 0.000086
# Epoch 1, Batch 78/240, MSE = 0.000072
# Epoch 1, Batch 79/240, MSE = 0.000077
# Epoch 1, Batch 80/240, MSE = 0.000065
# Epoch 1, Batch 81/240, MSE = 0.000069
# Epoch 1, Batch 82/240, MSE = 0.000074
# Epoch 1, Batch 83/240, MSE = 0.000079
# Epoch 1, Batch 84/240, MSE = 0.000081
# Epoch 1, Batch 85/240, MSE = 0.000077
# Epoch 1, Batch 86/240, MSE = 0.000058
# Epoch 1, Batch 87/240, MSE = 0.000074
# Epoch 1, Batch 88/240, MSE = 0.000074
# Epoch 1, Batch 89/240, MSE = 0.000068
# Epoch 1, Batch 90/240, MSE = 0.000071
# Epoch 1, Batch 91/240, MSE = 0.000080
# Epoch 1, Batch 92/240, MSE = 0.000069
# Epoch 1, Batch 93/240, MSE = 0.000071
# Epoch 1, Batch 94/240, MSE = 0.000074
# Epoch 1, Batch 95/240, MSE = 0.000068
# Epoch 1, Batch 96/240, MSE = 0.000081
# Epoch 1, Batch 97/240, MSE = 0.000073
# Epoch 1, Batch 98/240, MSE = 0.000070
# Epoch 1, Batch 99/240, MSE = 0.000072
# Epoch 1, Batch 100/240, MSE = 0.000074
# Epoch 1, Batch 101/240, MSE = 0.000067
# Epoch 1, Batch 102/240, MSE = 0.000074
# Epoch 1, Batch 103/240, MSE = 0.000077
# Epoch 1, Batch 104/240, MSE = 0.000077
# Epoch 1, Batch 105/240, MSE = 0.000068
# Epoch 1, Batch 106/240, MSE = 0.000078
# Epoch 1, Batch 107/240, MSE = 0.000079
# Epoch 1, Batch 108/240, MSE = 0.000072
# Epoch 1, Batch 109/240, MSE = 0.000076
# Epoch 1, Batch 110/240, MSE = 0.000070
# Epoch 1, Batch 111/240, MSE = 0.000075
# Epoch 1, Batch 112/240, MSE = 0.000076
# Epoch 1, Batch 113/240, MSE = 0.000067
# Epoch 1, Batch 114/240, MSE = 0.000083
# Epoch 1, Batch 115/240, MSE = 0.000078
# Epoch 1, Batch 116/240, MSE = 0.000066
# Epoch 1, Batch 117/240, MSE = 0.000076
# Epoch 1, Batch 118/240, MSE = 0.000071
# Epoch 1, Batch 119/240, MSE = 0.000069
# Epoch 1, Batch 120/240, MSE = 0.000068
# Epoch 1, Batch 121/240, MSE = 0.000077
# Epoch 1, Batch 122/240, MSE = 0.000070
# Epoch 1, Batch 123/240, MSE = 0.000082
# Epoch 1, Batch 124/240, MSE = 0.000081
# Epoch 1, Batch 125/240, MSE = 0.000066
# Epoch 1, Batch 126/240, MSE = 0.000065
# Epoch 1, Batch 127/240, MSE = 0.000078
# Epoch 1, Batch 128/240, MSE = 0.000078
# Epoch 1, Batch 129/240, MSE = 0.000069
# Epoch 1, Batch 130/240, MSE = 0.000080
# Epoch 1, Batch 131/240, MSE = 0.000064
# Epoch 1, Batch 132/240, MSE = 0.000072
# Epoch 1, Batch 133/240, MSE = 0.000066
# Epoch 1, Batch 134/240, MSE = 0.000080
# Epoch 1, Batch 135/240, MSE = 0.000074
# Epoch 1, Batch 136/240, MSE = 0.000081
# Epoch 1, Batch 137/240, MSE = 0.000068
# Epoch 1, Batch 138/240, MSE = 0.000077
# Epoch 1, Batch 139/240, MSE = 0.000073
# Epoch 1, Batch 140/240, MSE = 0.000083
# Epoch 1, Batch 141/240, MSE = 0.000071
# Epoch 1, Batch 142/240, MSE = 0.000077
# Epoch 1, Batch 143/240, MSE = 0.000081
# Epoch 1, Batch 144/240, MSE = 0.000069
# Epoch 1, Batch 145/240, MSE = 0.000069
# Epoch 1, Batch 146/240, MSE = 0.000069
# Epoch 1, Batch 147/240, MSE = 0.000062
# Epoch 1, Batch 148/240, MSE = 0.000081
# Epoch 1, Batch 149/240, MSE = 0.000066
# Epoch 1, Batch 150/240, MSE = 0.000083
# Epoch 1, Batch 151/240, MSE = 0.000085
# Epoch 1, Batch 152/240, MSE = 0.000078
# Epoch 1, Batch 153/240, MSE = 0.000060
# Epoch 1, Batch 154/240, MSE = 0.000074
# Epoch 1, Batch 155/240, MSE = 0.000075
# Epoch 1, Batch 156/240, MSE = 0.000087
# Epoch 1, Batch 157/240, MSE = 0.000074
# Epoch 1, Batch 158/240, MSE = 0.000064
# Epoch 1, Batch 159/240, MSE = 0.000066
# Epoch 1, Batch 160/240, MSE = 0.000065
# Epoch 1, Batch 161/240, MSE = 0.000078
# Epoch 1, Batch 162/240, MSE = 0.000063
# Epoch 1, Batch 163/240, MSE = 0.000070
# Epoch 1, Batch 164/240, MSE = 0.000068
# Epoch 1, Batch 165/240, MSE = 0.000078
# Epoch 1, Batch 166/240, MSE = 0.000076
# Epoch 1, Batch 167/240, MSE = 0.000074
# Epoch 1, Batch 168/240, MSE = 0.000073
# Epoch 1, Batch 169/240, MSE = 0.000077
# Epoch 1, Batch 170/240, MSE = 0.000087
# Epoch 1, Batch 171/240, MSE = 0.000072
# Epoch 1, Batch 172/240, MSE = 0.000087
# Epoch 1, Batch 173/240, MSE = 0.000089
# Epoch 1, Batch 174/240, MSE = 0.000070
# Epoch 1, Batch 175/240, MSE = 0.000077
# Epoch 1, Batch 176/240, MSE = 0.000068
# Epoch 1, Batch 177/240, MSE = 0.000072
# Epoch 1, Batch 178/240, MSE = 0.000078
# Epoch 1, Batch 179/240, MSE = 0.000081
# Epoch 1, Batch 180/240, MSE = 0.000083
# Epoch 1, Batch 181/240, MSE = 0.000072
# Epoch 1, Batch 182/240, MSE = 0.000073
# Epoch 1, Batch 183/240, MSE = 0.000075
# Epoch 1, Batch 184/240, MSE = 0.000073
# Epoch 1, Batch 185/240, MSE = 0.000080
# Epoch 1, Batch 186/240, MSE = 0.000082
# Epoch 1, Batch 187/240, MSE = 0.000073
# Epoch 1, Batch 188/240, MSE = 0.000078
# Epoch 1, Batch 189/240, MSE = 0.000073
# Epoch 1, Batch 190/240, MSE = 0.000076
# Epoch 1, Batch 191/240, MSE = 0.000083
# Epoch 1, Batch 192/240, MSE = 0.000072
# Epoch 1, Batch 193/240, MSE = 0.000080
# Epoch 1, Batch 194/240, MSE = 0.000076
# Epoch 1, Batch 195/240, MSE = 0.000069
# Epoch 1, Batch 196/240, MSE = 0.000066
# Epoch 1, Batch 197/240, MSE = 0.000074
# Epoch 1, Batch 198/240, MSE = 0.000070
# Epoch 1, Batch 199/240, MSE = 0.000070
# Epoch 1, Batch 200/240, MSE = 0.000064
# Epoch 1, Batch 201/240, MSE = 0.000084
# Epoch 1, Batch 202/240, MSE = 0.000069
# Epoch 1, Batch 203/240, MSE = 0.000076
# Epoch 1, Batch 204/240, MSE = 0.000072
# Epoch 1, Batch 205/240, MSE = 0.000074
# Epoch 1, Batch 206/240, MSE = 0.000070
# Epoch 1, Batch 207/240, MSE = 0.000069
# Epoch 1, Batch 208/240, MSE = 0.000070
# Epoch 1, Batch 209/240, MSE = 0.000085
# Epoch 1, Batch 210/240, MSE = 0.000066
# Epoch 1, Batch 211/240, MSE = 0.000081
# Epoch 1, Batch 212/240, MSE = 0.000075
# Epoch 1, Batch 213/240, MSE = 0.000093
# Epoch 1, Batch 214/240, MSE = 0.000057
# Epoch 1, Batch 215/240, MSE = 0.000068
# Epoch 1, Batch 216/240, MSE = 0.000077
# Epoch 1, Batch 217/240, MSE = 0.000084
# Epoch 1, Batch 218/240, MSE = 0.000067
# Epoch 1, Batch 219/240, MSE = 0.000072
# Epoch 1, Batch 220/240, MSE = 0.000075
# Epoch 1, Batch 221/240, MSE = 0.000076
# Epoch 1, Batch 222/240, MSE = 0.000067
# Epoch 1, Batch 223/240, MSE = 0.000074
# Epoch 1, Batch 224/240, MSE = 0.000076
# Epoch 1, Batch 225/240, MSE = 0.000081
# Epoch 1, Batch 226/240, MSE = 0.000071
# Epoch 1, Batch 227/240, MSE = 0.000063
# Epoch 1, Batch 228/240, MSE = 0.000070
# Epoch 1, Batch 229/240, MSE = 0.000080
# Epoch 1, Batch 230/240, MSE = 0.000075
# Epoch 1, Batch 231/240, MSE = 0.000068
# Epoch 1, Batch 232/240, MSE = 0.000066
# Epoch 1, Batch 233/240, MSE = 0.000069
# Epoch 1, Batch 234/240, MSE = 0.000065
# Epoch 1, Batch 235/240, MSE = 0.000078
# Epoch 1, Batch 236/240, MSE = 0.000060
# Epoch 1, Batch 237/240, MSE = 0.000072
# Epoch 1, Batch 238/240, MSE = 0.000071
# Epoch 1, Batch 239/240, MSE = 0.000075
# Epoch 1, Batch 240/240, MSE = 0.000080
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.032724
# Epoch 1, Batch 2/240, MSE = 0.033142
# Epoch 1, Batch 3/240, MSE = 0.031820
# Epoch 1, Batch 4/240, MSE = 0.031909
# Epoch 1, Batch 5/240, MSE = 0.032982
# Epoch 1, Batch 6/240, MSE = 0.029516
# Epoch 1, Batch 7/240, MSE = 0.030637
# Epoch 1, Batch 8/240, MSE = 0.034909
# Epoch 1, Batch 9/240, MSE = 0.031936
# Epoch 1, Batch 10/240, MSE = 0.031463
# Epoch 1, Batch 11/240, MSE = 0.036802
# Epoch 1, Batch 12/240, MSE = 0.036338
# Epoch 1, Batch 13/240, MSE = 0.032284
# Epoch 1, Batch 14/240, MSE = 0.037619
# Epoch 1, Batch 15/240, MSE = 0.034715
# Epoch 1, Batch 16/240, MSE = 0.031330
# Epoch 1, Batch 17/240, MSE = 0.036527
# Epoch 1, Batch 18/240, MSE = 0.034468
# Epoch 1, Batch 19/240, MSE = 0.028632
# Epoch 1, Batch 20/240, MSE = 0.030788
# Epoch 1, Batch 21/240, MSE = 0.032036
# Epoch 1, Batch 22/240, MSE = 0.035644
# Epoch 1, Batch 23/240, MSE = 0.035105
# Epoch 1, Batch 24/240, MSE = 0.033485
# Epoch 1, Batch 25/240, MSE = 0.028617
# Epoch 1, Batch 26/240, MSE = 0.028867
# Epoch 1, Batch 27/240, MSE = 0.034893
# Epoch 1, Batch 28/240, MSE = 0.031419
# Epoch 1, Batch 29/240, MSE = 0.036476
# Epoch 1, Batch 30/240, MSE = 0.030231
# Epoch 1, Batch 31/240, MSE = 0.032544
# Epoch 1, Batch 32/240, MSE = 0.030958
# Epoch 1, Batch 33/240, MSE = 0.033281
# Epoch 1, Batch 34/240, MSE = 0.034622
# Epoch 1, Batch 35/240, MSE = 0.032397
# Epoch 1, Batch 36/240, MSE = 0.034235
# Epoch 1, Batch 37/240, MSE = 0.035376
# Epoch 1, Batch 38/240, MSE = 0.034172
# Epoch 1, Batch 39/240, MSE = 0.031843
# Epoch 1, Batch 40/240, MSE = 0.037030
# Epoch 1, Batch 41/240, MSE = 0.033733
# Epoch 1, Batch 42/240, MSE = 0.033070
# Epoch 1, Batch 43/240, MSE = 0.033289
# Epoch 1, Batch 44/240, MSE = 0.033204
# Epoch 1, Batch 45/240, MSE = 0.034505
# Epoch 1, Batch 46/240, MSE = 0.037105
# Epoch 1, Batch 47/240, MSE = 0.029322
# Epoch 1, Batch 48/240, MSE = 0.036148
# Epoch 1, Batch 49/240, MSE = 0.033022
# Epoch 1, Batch 50/240, MSE = 0.031144
# Epoch 1, Batch 51/240, MSE = 0.029422
# Epoch 1, Batch 52/240, MSE = 0.031840
# Epoch 1, Batch 53/240, MSE = 0.033672
# Epoch 1, Batch 54/240, MSE = 0.030640
# Epoch 1, Batch 55/240, MSE = 0.030443
# Epoch 1, Batch 56/240, MSE = 0.034190
# Epoch 1, Batch 57/240, MSE = 0.033985
# Epoch 1, Batch 58/240, MSE = 0.033371
# Epoch 1, Batch 59/240, MSE = 0.033939
# Epoch 1, Batch 60/240, MSE = 0.031911
# Epoch 1, Batch 61/240, MSE = 0.037962
# Epoch 1, Batch 62/240, MSE = 0.032570
# Epoch 1, Batch 63/240, MSE = 0.031011
# Epoch 1, Batch 64/240, MSE = 0.035334
# Epoch 1, Batch 65/240, MSE = 0.033697
# Epoch 1, Batch 66/240, MSE = 0.028862
# Epoch 1, Batch 67/240, MSE = 0.029626
# Epoch 1, Batch 68/240, MSE = 0.036054
# Epoch 1, Batch 69/240, MSE = 0.035723
# Epoch 1, Batch 70/240, MSE = 0.035394
# Epoch 1, Batch 71/240, MSE = 0.032804
# Epoch 1, Batch 72/240, MSE = 0.030689
# Epoch 1, Batch 73/240, MSE = 0.034730
# Epoch 1, Batch 74/240, MSE = 0.031115
# Epoch 1, Batch 75/240, MSE = 0.035831
# Epoch 1, Batch 76/240, MSE = 0.031358
# Epoch 1, Batch 77/240, MSE = 0.034335
# Epoch 1, Batch 78/240, MSE = 0.037422
# Epoch 1, Batch 79/240, MSE = 0.033853
# Epoch 1, Batch 80/240, MSE = 0.036563
# Epoch 1, Batch 81/240, MSE = 0.032224
# Epoch 1, Batch 82/240, MSE = 0.028999
# Epoch 1, Batch 83/240, MSE = 0.033505
# Epoch 1, Batch 84/240, MSE = 0.034956
# Epoch 1, Batch 85/240, MSE = 0.030066
# Epoch 1, Batch 86/240, MSE = 0.030068
# Epoch 1, Batch 87/240, MSE = 0.027497
# Epoch 1, Batch 88/240, MSE = 0.037775
# Epoch 1, Batch 89/240, MSE = 0.035060
# Epoch 1, Batch 90/240, MSE = 0.032488
# Epoch 1, Batch 91/240, MSE = 0.029763
# Epoch 1, Batch 92/240, MSE = 0.026987
# Epoch 1, Batch 93/240, MSE = 0.034171
# Epoch 1, Batch 94/240, MSE = 0.036660
# Epoch 1, Batch 95/240, MSE = 0.033478
# Epoch 1, Batch 96/240, MSE = 0.033219
# Epoch 1, Batch 97/240, MSE = 0.032866
# Epoch 1, Batch 98/240, MSE = 0.034659
# Epoch 1, Batch 99/240, MSE = 0.036018
# Epoch 1, Batch 100/240, MSE = 0.035316
# Epoch 1, Batch 101/240, MSE = 0.031856
# Epoch 1, Batch 102/240, MSE = 0.028181
# Epoch 1, Batch 103/240, MSE = 0.034751
# Epoch 1, Batch 104/240, MSE = 0.032723
# Epoch 1, Batch 105/240, MSE = 0.029793
# Epoch 1, Batch 106/240, MSE = 0.033045
# Epoch 1, Batch 107/240, MSE = 0.033649
# Epoch 1, Batch 108/240, MSE = 0.028899
# Epoch 1, Batch 109/240, MSE = 0.032480
# Epoch 1, Batch 110/240, MSE = 0.031041
# Epoch 1, Batch 111/240, MSE = 0.035530
# Epoch 1, Batch 112/240, MSE = 0.031640
# Epoch 1, Batch 113/240, MSE = 0.028740
# Epoch 1, Batch 114/240, MSE = 0.032363
# Epoch 1, Batch 115/240, MSE = 0.034384
# Epoch 1, Batch 116/240, MSE = 0.033401
# Epoch 1, Batch 117/240, MSE = 0.033398
# Epoch 1, Batch 118/240, MSE = 0.031665
# Epoch 1, Batch 119/240, MSE = 0.030712
# Epoch 1, Batch 120/240, MSE = 0.031950
# Epoch 1, Batch 121/240, MSE = 0.033843
# Epoch 1, Batch 122/240, MSE = 0.033281
# Epoch 1, Batch 123/240, MSE = 0.036427
# Epoch 1, Batch 124/240, MSE = 0.033776
# Epoch 1, Batch 125/240, MSE = 0.027372
# Epoch 1, Batch 126/240, MSE = 0.032305
# Epoch 1, Batch 127/240, MSE = 0.034168
# Epoch 1, Batch 128/240, MSE = 0.031773
# Epoch 1, Batch 129/240, MSE = 0.029517
# Epoch 1, Batch 130/240, MSE = 0.030749
# Epoch 1, Batch 131/240, MSE = 0.034686
# Epoch 1, Batch 132/240, MSE = 0.034380
# Epoch 1, Batch 133/240, MSE = 0.029208
# Epoch 1, Batch 134/240, MSE = 0.039228
# Epoch 1, Batch 135/240, MSE = 0.032560
# Epoch 1, Batch 136/240, MSE = 0.034005
# Epoch 1, Batch 137/240, MSE = 0.034341
# Epoch 1, Batch 138/240, MSE = 0.034304
# Epoch 1, Batch 139/240, MSE = 0.036465
# Epoch 1, Batch 140/240, MSE = 0.028653
# Epoch 1, Batch 141/240, MSE = 0.033823
# Epoch 1, Batch 142/240, MSE = 0.031035
# Epoch 1, Batch 143/240, MSE = 0.034151
# Epoch 1, Batch 144/240, MSE = 0.032019
# Epoch 1, Batch 145/240, MSE = 0.034405
# Epoch 1, Batch 146/240, MSE = 0.031946
# Epoch 1, Batch 147/240, MSE = 0.031589
# Epoch 1, Batch 148/240, MSE = 0.034590
# Epoch 1, Batch 149/240, MSE = 0.035278
# Epoch 1, Batch 150/240, MSE = 0.035613
# Epoch 1, Batch 151/240, MSE = 0.030540
# Epoch 1, Batch 152/240, MSE = 0.037474
# Epoch 1, Batch 153/240, MSE = 0.036711
# Epoch 1, Batch 154/240, MSE = 0.028471
# Epoch 1, Batch 155/240, MSE = 0.034143
# Epoch 1, Batch 156/240, MSE = 0.028495
# Epoch 1, Batch 157/240, MSE = 0.032475
# Epoch 1, Batch 158/240, MSE = 0.034605
# Epoch 1, Batch 159/240, MSE = 0.034773
# Epoch 1, Batch 160/240, MSE = 0.035816
# Epoch 1, Batch 161/240, MSE = 0.033830
# Epoch 1, Batch 162/240, MSE = 0.032145
# Epoch 1, Batch 163/240, MSE = 0.031691
# Epoch 1, Batch 164/240, MSE = 0.032382
# Epoch 1, Batch 165/240, MSE = 0.034712
# Epoch 1, Batch 166/240, MSE = 0.029489
# Epoch 1, Batch 167/240, MSE = 0.027820
# Epoch 1, Batch 168/240, MSE = 0.032205
# Epoch 1, Batch 169/240, MSE = 0.032276
# Epoch 1, Batch 170/240, MSE = 0.031562
# Epoch 1, Batch 171/240, MSE = 0.027898
# Epoch 1, Batch 172/240, MSE = 0.036996
# Epoch 1, Batch 173/240, MSE = 0.035562
# Epoch 1, Batch 174/240, MSE = 0.030579
# Epoch 1, Batch 175/240, MSE = 0.033477
# Epoch 1, Batch 176/240, MSE = 0.034567
# Epoch 1, Batch 177/240, MSE = 0.035548
# Epoch 1, Batch 178/240, MSE = 0.035483
# Epoch 1, Batch 179/240, MSE = 0.035335
# Epoch 1, Batch 180/240, MSE = 0.034710
# Epoch 1, Batch 181/240, MSE = 0.032651
# Epoch 1, Batch 182/240, MSE = 0.032330
# Epoch 1, Batch 183/240, MSE = 0.036084
# Epoch 1, Batch 184/240, MSE = 0.033704
# Epoch 1, Batch 185/240, MSE = 0.029243
# Epoch 1, Batch 186/240, MSE = 0.034040
# Epoch 1, Batch 187/240, MSE = 0.035898
# Epoch 1, Batch 188/240, MSE = 0.031108
# Epoch 1, Batch 189/240, MSE = 0.032256
# Epoch 1, Batch 190/240, MSE = 0.032632
# Epoch 1, Batch 191/240, MSE = 0.037329
# Epoch 1, Batch 192/240, MSE = 0.035851
# Epoch 1, Batch 193/240, MSE = 0.031343
# Epoch 1, Batch 194/240, MSE = 0.036916
# Epoch 1, Batch 195/240, MSE = 0.031908
# Epoch 1, Batch 196/240, MSE = 0.035626
# Epoch 1, Batch 197/240, MSE = 0.032038
# Epoch 1, Batch 198/240, MSE = 0.031701
# Epoch 1, Batch 199/240, MSE = 0.034125
# Epoch 1, Batch 200/240, MSE = 0.031063
# Epoch 1, Batch 201/240, MSE = 0.028789
# Epoch 1, Batch 202/240, MSE = 0.035407
# Epoch 1, Batch 203/240, MSE = 0.031332
# Epoch 1, Batch 204/240, MSE = 0.030943
# Epoch 1, Batch 205/240, MSE = 0.035225
# Epoch 1, Batch 206/240, MSE = 0.034830
# Epoch 1, Batch 207/240, MSE = 0.034850
# Epoch 1, Batch 208/240, MSE = 0.028939
# Epoch 1, Batch 209/240, MSE = 0.032649
# Epoch 1, Batch 210/240, MSE = 0.035108
# Epoch 1, Batch 211/240, MSE = 0.032871
# Epoch 1, Batch 212/240, MSE = 0.032039
# Epoch 1, Batch 213/240, MSE = 0.031623
# Epoch 1, Batch 214/240, MSE = 0.032580
# Epoch 1, Batch 215/240, MSE = 0.033400
# Epoch 1, Batch 216/240, MSE = 0.032750
# Epoch 1, Batch 217/240, MSE = 0.035153
# Epoch 1, Batch 218/240, MSE = 0.036131
# Epoch 1, Batch 219/240, MSE = 0.037952
# Epoch 1, Batch 220/240, MSE = 0.029681
# Epoch 1, Batch 221/240, MSE = 0.033561
# Epoch 1, Batch 222/240, MSE = 0.030952
# Epoch 1, Batch 223/240, MSE = 0.035477
# Epoch 1, Batch 224/240, MSE = 0.032222
# Epoch 1, Batch 225/240, MSE = 0.035293
# Epoch 1, Batch 226/240, MSE = 0.035946
# Epoch 1, Batch 227/240, MSE = 0.029835
# Epoch 1, Batch 228/240, MSE = 0.032052
# Epoch 1, Batch 229/240, MSE = 0.033388
# Epoch 1, Batch 230/240, MSE = 0.036212
# Epoch 1, Batch 231/240, MSE = 0.034708
# Epoch 1, Batch 232/240, MSE = 0.031315
# Epoch 1, Batch 233/240, MSE = 0.028171
# Epoch 1, Batch 234/240, MSE = 0.032334
# Epoch 1, Batch 235/240, MSE = 0.031975
# Epoch 1, Batch 236/240, MSE = 0.034201
# Epoch 1, Batch 237/240, MSE = 0.037063
# Epoch 1, Batch 238/240, MSE = 0.030011
# Epoch 1, Batch 239/240, MSE = 0.034215
# Epoch 1, Batch 240/240, MSE = 0.033979
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -30    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# -------------------------------------------------------------
# [최종 수정] 길이 보정 및 에너지 정규화
# -------------------------------------------------------------

# 1. 🔧 길이 보정: Resample (필수!)
# 딥러닝 모델 출력(시간축 압축됨)을 원래 LoRa 심볼 길이(2048)로 복원
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (예: 2048)
cur_len = len(iq_reconstructed)

if cur_len != target_len:
    if cur_len > target_len:
        # 🔪 TRIM: 가운데 부분만 남기기 (시간 정렬 유지)
        diff = cur_len - target_len
        start = diff // 2
        end = start + target_len
        iq_reconstructed = iq_reconstructed[start:end]
        print(f"   🔧 Trimmed: {cur_len} -> {target_len} samples (center slice)")
    else:
        # 🩹 PADDING: 앞/뒤로 0 채우기 (대칭 padding)
        diff = target_len - cur_len
        pad_left = diff // 2
        pad_right = diff - pad_left
        iq_reconstructed = np.pad(
            iq_reconstructed,
            (pad_left, pad_right),
            mode="constant",
            constant_values=0,
        )
        print(f"   🔧 Padded: {cur_len} -> {target_len} samples (zero padding)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")


# 2. ⭐ 에너지 정규화: Standardization (수정됨!)
# 기존(Noisy 에너지 기준)은 위험하므로, 통신 표준인 'Unit Power (std=1)'로 변경
# 이렇게 하면 신호 크기가 적절하게 맞춰져서 디코더가 가장 잘 인식합니다.

iq_std = np.std(iq_reconstructed)

if iq_std > 1e-12:  # 0 나누기 방지 (신호가 살아있는 경우)
    # 평균을 0으로, 표준편차를 1로 맞춤 (Z-score normalization과 유사)
    iq_reconstructed = (iq_reconstructed - np.mean(iq_reconstructed)) / iq_std
    
    print(f"   🔧 Normalized to Unit Power (std=1.0)")
    # 확인용 출력
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

else:
    # 신호가 거의 0인 경우 (복원 실패 또는 무음 구간)
    print(f"   ⚠️ Warning: Reconstructed signal is essentially silence. No scaling applied.")

# -------------------------------------------------------------

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -30 dB
#
# === Normalization Parameters ===
# Real: min=-9.076596, max=8.747767, range=17.824363
# Imag: min=-9.614443, max=8.589688, range=18.204131
# Restored norm: real_min=0.1070, real_max=0.8893
# Restored norm: imag_min=0.1386, imag_max=0.9547
# After denorm:  real_min=-7.168635, real_max=6.774720
# After denorm:  imag_min=-7.091006, imag_max=7.765606
# ✅ IQ signal reconstructed: (2048,)
#    ✅ Length already matches: 2048 samples
#    🔧 Normalized to Unit Power (std=1.0)
#    Energy after scaling:  |mean|=0.176556, |max|=42.558454
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.5190
# Restored flat: min=0.1070, max=0.9547, mean=0.5207
# Difference:    MSE=0.009118
# /tmp/ipykernel_22871/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0004, max=0.0821
# Zxx_restored (magnitude): min=0.0792, max=7.7683
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3_huber successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3_huber failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=27.5628, |max|=81.3674
# Reconstructed:   len=2048, |mean|=0.1766, |max|=42.5585
#
# MSE Comparison:
# Clean vs Noisy:        961.869852
# Clean vs Reconstructed: 2.016267
# Noisy vs Reconstructed: 961.921473
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 4194303.99
# ⚠️  Noisy signal (len=2048)    → Code: 501, Peak: 25895653.03
# 🔧 Restored (len=2048)   → Code: 325, Peak: 11540.49
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       501 ❌ WRONG
# Restored Decoded:    325 ❌ WRONG
# ============================================================
#
# Peak Comparison:
# Clean Peak:    4194303.99
# Noisy Peak:    25895653.03 (617.4% of clean)
# Restored Peak: 11540.49 (0.3% of clean)
#
# ❌ FAILURE: BAMv3_huber failed to restore the correct symbol

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)")
print("="*70)

# 1. 테스트 파라미터 설정 ( -30dB 추가 완료 )
NUM_TEST_SAMPLES = 1000  # 샘플 수
TEST_SNR_LEVELS = [-30, -25, -20, -15, -10, -5]  # ⭐ -30dB 추가됨!

# 결과 저장용 딕셔너리
results = {
    snr: {
        'bam_correct': 0, 'bam_total': 0, 'bam_mse': [], 'bam_peak_ratio': [],
        'base_correct': 0, 'base_total': 0, 'base_peak_ratio': [],
    }
    for snr in TEST_SNR_LEVELS
}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        try:
            # 랜덤 심볼 선택
            test_sym = np.random.randint(0, 512)
            
            # 1. 클린 IQ & 노이즈 추가
            clean_iq_test = X_clean_iq[test_sym]
            noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
            
            # 2. Complex 스펙트로그램 생성
            noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
            
            # 3. BAMv3 복원 (Compress -> Decompress)
            compressed = model.compress(noisy_flat.reshape(1, -1))
            restored_flat = model.decompress(compressed).flatten()
            
            # 4. IQ 신호 재구성 (1차)
            iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)

            # ====================================================
            # ⭐ [수정] 길이 보정: Trim / Padding + 에너지 정규화
            # ====================================================
            target_len = len(clean_iq_test)
            cur_len = len(iq_restored)

            # (1) 길이 보정: resample 금지, trim / padding만 사용
            if cur_len != target_len:
                if cur_len > target_len:
                    # 가운데 기준으로 잘라서 타이밍 유지
                    diff = cur_len - target_len
                    start = diff // 2
                    end = start + target_len
                    iq_restored = iq_restored[start:end]
                    # print(f"   🔧 Trimmed: {cur_len} -> {target_len}")
                else:
                    # 부족하면 앞/뒤에 0 패딩 (대칭 padding)
                    diff = target_len - cur_len
                    pad_left = diff // 2
                    pad_right = diff - pad_left
                    iq_restored = np.pad(
                        iq_restored,
                        (pad_left, pad_right),
                        mode="constant",
                        constant_values=0,
                    )
                    # print(f"   🔧 Padded: {cur_len} -> {target_len}")
            # else:
            #     print(f"   ✅ Length already matches: {target_len}")

            # (2) 에너지 정규화 (mean/std 표준화 X, power만 맞춤)
            power = np.mean(np.abs(iq_restored) ** 2)
            if power > 1e-12:
                iq_restored = iq_restored / np.sqrt(power)
            # ====================================================

            # 5. Dechirp 및 심볼 추정 (Baseline vs BAM)
            # 기준: 클린 신호
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, sf, fs, bw)
            
            # Baseline: noisy 신호
            code_base, peak_base = estimate_symbol_custom(noisy_iq_test, sf, fs, bw)
            
            # BAM 경로: 복원된 IQ
            code_bam, peak_bam = estimate_symbol_custom(iq_restored, sf, fs, bw)
            
            # -----------------------------
            # 결과 기록
            # -----------------------------
            # 1) Baseline Accuracy
            if code_base == test_sym: results[snr]['base_correct'] += 1
            results[snr]['base_total'] += 1
            
            # 2) BAM Accuracy
            if code_bam == test_sym: results[snr]['bam_correct'] += 1
            results[snr]['bam_total'] += 1
            
            # 3) Peak Ratio
            if peak_clean > 0:
                results[snr]['base_peak_ratio'].append(peak_base / peak_clean)
                results[snr]['bam_peak_ratio'].append(peak_bam / peak_clean)
            
            # 4) MSE (복원 품질)
            # MSE 계산 시에는 크기(Scale) 차이 때문에 정규화된 것끼리 비교하거나, 
            # 단순히 복원력 확인용으로만 참고합니다.
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['bam_mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['base_total'] += 1
            results[snr]['bam_total'] += 1
    
    # 중간 결과 출력
    base_acc = (results[snr]['base_correct'] / results[snr]['base_total'] * 100) if results[snr]['base_total'] > 0 else 0
    bam_acc = (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100) if results[snr]['bam_total'] > 0 else 0
    
    print(f"  ✓ Baseline Acc : {base_acc:.1f}%")
    print(f"  ✓ BAM Accuracy : {bam_acc:.1f}%")

# 최종 결과 요약 출력 및 그래프 그리기 (기존 코드와 동일)
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)
print(f"\n{'SNR':<6} {'Base Acc':<10} {'BAM Acc':<10} {'Improvement':<12}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    b_acc = results[snr]['base_correct'] / results[snr]['base_total'] * 100
    m_acc = results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
    imp = m_acc - b_acc
    print(f"{snr:<6} {b_acc:>8.1f}%  {m_acc:>8.1f}%  {imp:>+10.1f}%p")

# 그래프 그리기
plt.figure(figsize=(10, 5))
snrs = TEST_SNR_LEVELS
base_accs = [results[s]['base_correct']/results[s]['base_total']*100 for s in snrs]
bam_accs = [results[s]['bam_correct']/results[s]['bam_total']*100 for s in snrs]

plt.plot(snrs, base_accs, 'o--', label='Standard LoRa (Baseline)', color='gray')
plt.plot(snrs, bam_accs, 's-', label='Proposed BAMv3', color='red', linewidth=2)
plt.axvline(x=-20, color='orange', linestyle=':', label='LoRa Limit (-20dB)')

plt.xlabel('SNR (dB)')
plt.ylabel('Symbol Accuracy (%)')
plt.title('Decoding Performance: Baseline vs BAMv3')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)
# ======================================================================
#
# 🧪 Testing with 1000 samples at each SNR level...
# SNR levels: [-30, -25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -30 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_22871/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Baseline Acc : 3.4%
#   ✓ BAM Accuracy : 3.7%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 18.2%
#   ✓ BAM Accuracy : 19.2%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 81.2%
#   ✓ BAM Accuracy : 54.6%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 87.7%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 99.8%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 100.0%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR    Base Acc   BAM Acc    Improvement
# ──────────────────────────────────────────────────────────────────────
# -30         3.4%       3.7%        +0.3%p
# -25        18.2%      19.2%        +1.0%p
# -20        81.2%      54.6%       -26.6%p
# -15       100.0%      87.7%       -12.3%p
# -10       100.0%      99.8%        -0.2%p
# -5        100.0%     100.0%        +0.0%p
