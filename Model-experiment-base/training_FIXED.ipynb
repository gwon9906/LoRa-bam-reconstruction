# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'nfft': 512,      # <--- 여기를 다시 살려야 합니다!
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    nfft     = STFT_PARAMS['nfft']  # <--- 변수 가져오기
    window   = STFT_PARAMS['window']

    # 2. stft 호출 시 nfft 전달
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        nfft=nfft,              # <--- 꼭 넣어주세요!
        boundary=None,
        padded=False,
        return_onesided=False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        nfft=stft_params['nfft'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf, bw)
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (Ultra-low SNR에 집중)
SNR_MIN = -25
SNR_MAX = -5
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)
            
            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 1024, 512, 256]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (32, 31)
# Input dim (Real+Imag): 1984
# Model architecture: 1984 → 1024 → 512 → 256
# Compression ratio: 7.8x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True  # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 20
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 1984 → 1024 → 512 → 256
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.043225
# Epoch 1, Batch 2/240, MSE = 0.020809
# Epoch 1, Batch 3/240, MSE = 0.021725
# Epoch 1, Batch 4/240, MSE = 0.021008
# Epoch 1, Batch 5/240, MSE = 0.020476
# Epoch 1, Batch 6/240, MSE = 0.019620
# Epoch 1, Batch 7/240, MSE = 0.019987
# Epoch 1, Batch 8/240, MSE = 0.021259
# Epoch 1, Batch 9/240, MSE = 0.020753
# Epoch 1, Batch 10/240, MSE = 0.021444
# Epoch 1, Batch 11/240, MSE = 0.020346
# Epoch 1, Batch 12/240, MSE = 0.020205
# Epoch 1, Batch 13/240, MSE = 0.022018
# Epoch 1, Batch 14/240, MSE = 0.021324
# Epoch 1, Batch 15/240, MSE = 0.020961
# Epoch 1, Batch 16/240, MSE = 0.021134
# Epoch 1, Batch 17/240, MSE = 0.018486
# Epoch 1, Batch 18/240, MSE = 0.021764
# Epoch 1, Batch 19/240, MSE = 0.020916
# Epoch 1, Batch 20/240, MSE = 0.021932
# Epoch 1, Batch 21/240, MSE = 0.020365
# Epoch 1, Batch 22/240, MSE = 0.020429
# Epoch 1, Batch 23/240, MSE = 0.020400
# Epoch 1, Batch 24/240, MSE = 0.020533
# Epoch 1, Batch 25/240, MSE = 0.020327
# Epoch 1, Batch 26/240, MSE = 0.021320
# Epoch 1, Batch 27/240, MSE = 0.021043
# Epoch 1, Batch 28/240, MSE = 0.020330
# Epoch 1, Batch 29/240, MSE = 0.020292
# Epoch 1, Batch 30/240, MSE = 0.020938
# Epoch 1, Batch 31/240, MSE = 0.020721
# Epoch 1, Batch 32/240, MSE = 0.021115
# Epoch 1, Batch 33/240, MSE = 0.019479
# Epoch 1, Batch 34/240, MSE = 0.018508
# Epoch 1, Batch 35/240, MSE = 0.020471
# Epoch 1, Batch 36/240, MSE = 0.020043
# Epoch 1, Batch 37/240, MSE = 0.021784
# Epoch 1, Batch 38/240, MSE = 0.020724
# Epoch 1, Batch 39/240, MSE = 0.021353
# Epoch 1, Batch 40/240, MSE = 0.021235
# Epoch 1, Batch 41/240, MSE = 0.020749
# Epoch 1, Batch 42/240, MSE = 0.019320
# Epoch 1, Batch 43/240, MSE = 0.019534
# Epoch 1, Batch 44/240, MSE = 0.020043
# Epoch 1, Batch 45/240, MSE = 0.019690
# Epoch 1, Batch 46/240, MSE = 0.019660
# Epoch 1, Batch 47/240, MSE = 0.020157
# Epoch 1, Batch 48/240, MSE = 0.020511
# Epoch 1, Batch 49/240, MSE = 0.020360
# Epoch 1, Batch 50/240, MSE = 0.019515
# Epoch 1, Batch 51/240, MSE = 0.019563
# Epoch 1, Batch 52/240, MSE = 0.017706
# Epoch 1, Batch 53/240, MSE = 0.020303
# Epoch 1, Batch 54/240, MSE = 0.019645
# Epoch 1, Batch 55/240, MSE = 0.019354
# Epoch 1, Batch 56/240, MSE = 0.020118
# Epoch 1, Batch 57/240, MSE = 0.020554
# Epoch 1, Batch 58/240, MSE = 0.020539
# Epoch 1, Batch 59/240, MSE = 0.021194
# Epoch 1, Batch 60/240, MSE = 0.020994
# Epoch 1, Batch 61/240, MSE = 0.019215
# Epoch 1, Batch 62/240, MSE = 0.021701
# Epoch 1, Batch 63/240, MSE = 0.021162
# Epoch 1, Batch 64/240, MSE = 0.019795
# Epoch 1, Batch 65/240, MSE = 0.019026
# Epoch 1, Batch 66/240, MSE = 0.020037
# Epoch 1, Batch 67/240, MSE = 0.019541
# Epoch 1, Batch 68/240, MSE = 0.021169
# Epoch 1, Batch 69/240, MSE = 0.019542
# Epoch 1, Batch 70/240, MSE = 0.019559
# Epoch 1, Batch 71/240, MSE = 0.020518
# Epoch 1, Batch 72/240, MSE = 0.018830
# Epoch 1, Batch 73/240, MSE = 0.017792
# Epoch 1, Batch 74/240, MSE = 0.019830
# Epoch 1, Batch 75/240, MSE = 0.018743
# Epoch 1, Batch 76/240, MSE = 0.020165
# Epoch 1, Batch 77/240, MSE = 0.021770
# Epoch 1, Batch 78/240, MSE = 0.018260
# Epoch 1, Batch 79/240, MSE = 0.020739
# Epoch 1, Batch 80/240, MSE = 0.021257
# Epoch 1, Batch 81/240, MSE = 0.020018
# Epoch 1, Batch 82/240, MSE = 0.019375
# Epoch 1, Batch 83/240, MSE = 0.020153
# Epoch 1, Batch 84/240, MSE = 0.018582
# Epoch 1, Batch 85/240, MSE = 0.019741
# Epoch 1, Batch 86/240, MSE = 0.018988
# Epoch 1, Batch 87/240, MSE = 0.020190
# Epoch 1, Batch 88/240, MSE = 0.019696
# Epoch 1, Batch 89/240, MSE = 0.020472
# Epoch 1, Batch 90/240, MSE = 0.018621
# Epoch 1, Batch 91/240, MSE = 0.019988
# Epoch 1, Batch 92/240, MSE = 0.020493
# Epoch 1, Batch 93/240, MSE = 0.020106
# Epoch 1, Batch 94/240, MSE = 0.018947
# Epoch 1, Batch 95/240, MSE = 0.019101
# Epoch 1, Batch 96/240, MSE = 0.019723
# Epoch 1, Batch 97/240, MSE = 0.019854
# Epoch 1, Batch 98/240, MSE = 0.020219
# Epoch 1, Batch 99/240, MSE = 0.019650
# Epoch 1, Batch 100/240, MSE = 0.021017
# Epoch 1, Batch 101/240, MSE = 0.018554
# Epoch 1, Batch 102/240, MSE = 0.019438
# Epoch 1, Batch 103/240, MSE = 0.019855
# Epoch 1, Batch 104/240, MSE = 0.020543
# Epoch 1, Batch 105/240, MSE = 0.019065
# Epoch 1, Batch 106/240, MSE = 0.020633
# Epoch 1, Batch 107/240, MSE = 0.020432
# Epoch 1, Batch 108/240, MSE = 0.020050
# Epoch 1, Batch 109/240, MSE = 0.020094
# Epoch 1, Batch 110/240, MSE = 0.020492
# Epoch 1, Batch 111/240, MSE = 0.020874
# Epoch 1, Batch 112/240, MSE = 0.020108
# Epoch 1, Batch 113/240, MSE = 0.019243
# Epoch 1, Batch 114/240, MSE = 0.019925
# Epoch 1, Batch 115/240, MSE = 0.019436
# Epoch 1, Batch 116/240, MSE = 0.020300
# Epoch 1, Batch 117/240, MSE = 0.020800
# Epoch 1, Batch 118/240, MSE = 0.020829
# Epoch 1, Batch 119/240, MSE = 0.019706
# Epoch 1, Batch 120/240, MSE = 0.019873
# Epoch 1, Batch 121/240, MSE = 0.019406
# Epoch 1, Batch 122/240, MSE = 0.019577
# Epoch 1, Batch 123/240, MSE = 0.020525
# Epoch 1, Batch 124/240, MSE = 0.019678
# Epoch 1, Batch 125/240, MSE = 0.019371
# Epoch 1, Batch 126/240, MSE = 0.019867
# Epoch 1, Batch 127/240, MSE = 0.020046
# Epoch 1, Batch 128/240, MSE = 0.019333
# Epoch 1, Batch 129/240, MSE = 0.021420
# Epoch 1, Batch 130/240, MSE = 0.018933
# Epoch 1, Batch 131/240, MSE = 0.020026
# Epoch 1, Batch 132/240, MSE = 0.021152
# Epoch 1, Batch 133/240, MSE = 0.019940
# Epoch 1, Batch 134/240, MSE = 0.018557
# Epoch 1, Batch 135/240, MSE = 0.020724
# Epoch 1, Batch 136/240, MSE = 0.019783
# Epoch 1, Batch 137/240, MSE = 0.019541
# Epoch 1, Batch 138/240, MSE = 0.019591
# Epoch 1, Batch 139/240, MSE = 0.020789
# Epoch 1, Batch 140/240, MSE = 0.020227
# Epoch 1, Batch 141/240, MSE = 0.020019
# Epoch 1, Batch 142/240, MSE = 0.020433
# Epoch 1, Batch 143/240, MSE = 0.018807
# Epoch 1, Batch 144/240, MSE = 0.018618
# Epoch 1, Batch 145/240, MSE = 0.020349
# Epoch 1, Batch 146/240, MSE = 0.019604
# Epoch 1, Batch 147/240, MSE = 0.018970
# Epoch 1, Batch 148/240, MSE = 0.019970
# Epoch 1, Batch 149/240, MSE = 0.019593
# Epoch 1, Batch 150/240, MSE = 0.020833
# Epoch 1, Batch 151/240, MSE = 0.019352
# Epoch 1, Batch 152/240, MSE = 0.020636
# Epoch 1, Batch 153/240, MSE = 0.019698
# Epoch 1, Batch 154/240, MSE = 0.018495
# Epoch 1, Batch 155/240, MSE = 0.021238
# Epoch 1, Batch 156/240, MSE = 0.019526
# Epoch 1, Batch 157/240, MSE = 0.019492
# Epoch 1, Batch 158/240, MSE = 0.020628
# Epoch 1, Batch 159/240, MSE = 0.020413
# Epoch 1, Batch 160/240, MSE = 0.018727
# Epoch 1, Batch 161/240, MSE = 0.019177
# Epoch 1, Batch 162/240, MSE = 0.018991
# Epoch 1, Batch 163/240, MSE = 0.020162
# Epoch 1, Batch 164/240, MSE = 0.019380
# Epoch 1, Batch 165/240, MSE = 0.019495
# Epoch 1, Batch 166/240, MSE = 0.019163
# Epoch 1, Batch 167/240, MSE = 0.019573
# Epoch 1, Batch 168/240, MSE = 0.018917
# Epoch 1, Batch 169/240, MSE = 0.020161
# Epoch 1, Batch 170/240, MSE = 0.019005
# Epoch 1, Batch 171/240, MSE = 0.019001
# Epoch 1, Batch 172/240, MSE = 0.020762
# Epoch 1, Batch 173/240, MSE = 0.021855
# Epoch 1, Batch 174/240, MSE = 0.018647
# Epoch 1, Batch 175/240, MSE = 0.019757
# Epoch 1, Batch 176/240, MSE = 0.019350
# Epoch 1, Batch 177/240, MSE = 0.020399
# Epoch 1, Batch 178/240, MSE = 0.020151
# Epoch 1, Batch 179/240, MSE = 0.020171
# Epoch 1, Batch 180/240, MSE = 0.019004
# Epoch 1, Batch 181/240, MSE = 0.019578
# Epoch 1, Batch 182/240, MSE = 0.019272
# Epoch 1, Batch 183/240, MSE = 0.020080
# Epoch 1, Batch 184/240, MSE = 0.019114
# Epoch 1, Batch 185/240, MSE = 0.020204
# Epoch 1, Batch 186/240, MSE = 0.018517
# Epoch 1, Batch 187/240, MSE = 0.021006
# Epoch 1, Batch 188/240, MSE = 0.019163
# Epoch 1, Batch 189/240, MSE = 0.020111
# Epoch 1, Batch 190/240, MSE = 0.020519
# Epoch 1, Batch 191/240, MSE = 0.020004
# Epoch 1, Batch 192/240, MSE = 0.019481
# Epoch 1, Batch 193/240, MSE = 0.018907
# Epoch 1, Batch 194/240, MSE = 0.019470
# Epoch 1, Batch 195/240, MSE = 0.019192
# Epoch 1, Batch 196/240, MSE = 0.019244
# Epoch 1, Batch 197/240, MSE = 0.019222
# Epoch 1, Batch 198/240, MSE = 0.020187
# Epoch 1, Batch 199/240, MSE = 0.020134
# Epoch 1, Batch 200/240, MSE = 0.019479
# Epoch 1, Batch 201/240, MSE = 0.019564
# Epoch 1, Batch 202/240, MSE = 0.019332
# Epoch 1, Batch 203/240, MSE = 0.019665
# Epoch 1, Batch 204/240, MSE = 0.018602
# Epoch 1, Batch 205/240, MSE = 0.019371
# Epoch 1, Batch 206/240, MSE = 0.019181
# Epoch 1, Batch 207/240, MSE = 0.020226
# Epoch 1, Batch 208/240, MSE = 0.019386
# Epoch 1, Batch 209/240, MSE = 0.019846
# Epoch 1, Batch 210/240, MSE = 0.018592
# Epoch 1, Batch 211/240, MSE = 0.019215
# Epoch 1, Batch 212/240, MSE = 0.019270
# Epoch 1, Batch 213/240, MSE = 0.020072
# Epoch 1, Batch 214/240, MSE = 0.019812
# Epoch 1, Batch 215/240, MSE = 0.019526
# Epoch 1, Batch 216/240, MSE = 0.019901
# Epoch 1, Batch 217/240, MSE = 0.019896
# Epoch 1, Batch 218/240, MSE = 0.020566
# Epoch 1, Batch 219/240, MSE = 0.019083
# Epoch 1, Batch 220/240, MSE = 0.018533
# Epoch 1, Batch 221/240, MSE = 0.019477
# Epoch 1, Batch 222/240, MSE = 0.017643
# Epoch 1, Batch 223/240, MSE = 0.020724
# Epoch 1, Batch 224/240, MSE = 0.019684
# Epoch 1, Batch 225/240, MSE = 0.018886
# Epoch 1, Batch 226/240, MSE = 0.019567
# Epoch 1, Batch 227/240, MSE = 0.020311
# Epoch 1, Batch 228/240, MSE = 0.019555
# Epoch 1, Batch 229/240, MSE = 0.018528
# Epoch 1, Batch 230/240, MSE = 0.019678
# Epoch 1, Batch 231/240, MSE = 0.020081
# Epoch 1, Batch 232/240, MSE = 0.019908
# Epoch 1, Batch 233/240, MSE = 0.020349
# Epoch 1, Batch 234/240, MSE = 0.018941
# Epoch 1, Batch 235/240, MSE = 0.018481
# Epoch 1, Batch 236/240, MSE = 0.019793
# Epoch 1, Batch 237/240, MSE = 0.018761
# Epoch 1, Batch 238/240, MSE = 0.018698
# Epoch 1, Batch 239/240, MSE = 0.020372
# Epoch 1, Batch 240/240, MSE = 0.020349
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.059309
# Epoch 1, Batch 2/240, MSE = 0.003993
# Epoch 1, Batch 3/240, MSE = 0.003950
# Epoch 1, Batch 4/240, MSE = 0.003885
# Epoch 1, Batch 5/240, MSE = 0.004825
# Epoch 1, Batch 6/240, MSE = 0.004235
# Epoch 1, Batch 7/240, MSE = 0.004316
# Epoch 1, Batch 8/240, MSE = 0.003762
# Epoch 1, Batch 9/240, MSE = 0.004365
# Epoch 1, Batch 10/240, MSE = 0.004391
# Epoch 1, Batch 11/240, MSE = 0.004366
# Epoch 1, Batch 12/240, MSE = 0.004456
# Epoch 1, Batch 13/240, MSE = 0.004507
# Epoch 1, Batch 14/240, MSE = 0.003845
# Epoch 1, Batch 15/240, MSE = 0.003449
# Epoch 1, Batch 16/240, MSE = 0.004469
# Epoch 1, Batch 17/240, MSE = 0.003638
# Epoch 1, Batch 18/240, MSE = 0.004467
# Epoch 1, Batch 19/240, MSE = 0.004352
# Epoch 1, Batch 20/240, MSE = 0.004304
# Epoch 1, Batch 21/240, MSE = 0.004085
# Epoch 1, Batch 22/240, MSE = 0.003728
# Epoch 1, Batch 23/240, MSE = 0.003044
# Epoch 1, Batch 24/240, MSE = 0.003351
# Epoch 1, Batch 25/240, MSE = 0.003434
# Epoch 1, Batch 26/240, MSE = 0.004527
# Epoch 1, Batch 27/240, MSE = 0.003738
# Epoch 1, Batch 28/240, MSE = 0.003820
# Epoch 1, Batch 29/240, MSE = 0.003463
# Epoch 1, Batch 30/240, MSE = 0.003303
# Epoch 1, Batch 31/240, MSE = 0.003712
# Epoch 1, Batch 32/240, MSE = 0.003666
# Epoch 1, Batch 33/240, MSE = 0.003250
# Epoch 1, Batch 34/240, MSE = 0.002970
# Epoch 1, Batch 35/240, MSE = 0.002918
# Epoch 1, Batch 36/240, MSE = 0.003558
# Epoch 1, Batch 37/240, MSE = 0.003171
# Epoch 1, Batch 38/240, MSE = 0.003071
# Epoch 1, Batch 39/240, MSE = 0.002987
# Epoch 1, Batch 40/240, MSE = 0.003001
# Epoch 1, Batch 41/240, MSE = 0.003187
# Epoch 1, Batch 42/240, MSE = 0.002961
# Epoch 1, Batch 43/240, MSE = 0.002895
# Epoch 1, Batch 44/240, MSE = 0.002908
# Epoch 1, Batch 45/240, MSE = 0.003098
# Epoch 1, Batch 46/240, MSE = 0.002705
# Epoch 1, Batch 47/240, MSE = 0.002956
# Epoch 1, Batch 48/240, MSE = 0.002765
# Epoch 1, Batch 49/240, MSE = 0.002709
# Epoch 1, Batch 50/240, MSE = 0.002615
# Epoch 1, Batch 51/240, MSE = 0.002773
# Epoch 1, Batch 52/240, MSE = 0.002604
# Epoch 1, Batch 53/240, MSE = 0.002656
# Epoch 1, Batch 54/240, MSE = 0.002528
# Epoch 1, Batch 55/240, MSE = 0.002568
# Epoch 1, Batch 56/240, MSE = 0.002544
# Epoch 1, Batch 57/240, MSE = 0.002435
# Epoch 1, Batch 58/240, MSE = 0.002711
# Epoch 1, Batch 59/240, MSE = 0.002415
# Epoch 1, Batch 60/240, MSE = 0.002583
# Epoch 1, Batch 61/240, MSE = 0.002434
# Epoch 1, Batch 62/240, MSE = 0.002604
# Epoch 1, Batch 63/240, MSE = 0.002674
# Epoch 1, Batch 64/240, MSE = 0.002663
# Epoch 1, Batch 65/240, MSE = 0.002569
# Epoch 1, Batch 66/240, MSE = 0.002427
# Epoch 1, Batch 67/240, MSE = 0.002562
# Epoch 1, Batch 68/240, MSE = 0.002665
# Epoch 1, Batch 69/240, MSE = 0.002691
# Epoch 1, Batch 70/240, MSE = 0.002490
# Epoch 1, Batch 71/240, MSE = 0.002628
# Epoch 1, Batch 72/240, MSE = 0.002693
# Epoch 1, Batch 73/240, MSE = 0.002453
# Epoch 1, Batch 74/240, MSE = 0.002649
# Epoch 1, Batch 75/240, MSE = 0.002445
# Epoch 1, Batch 76/240, MSE = 0.002499
# Epoch 1, Batch 77/240, MSE = 0.002684
# Epoch 1, Batch 78/240, MSE = 0.002593
# Epoch 1, Batch 79/240, MSE = 0.002662
# Epoch 1, Batch 80/240, MSE = 0.002642
# Epoch 1, Batch 81/240, MSE = 0.002549
# Epoch 1, Batch 82/240, MSE = 0.002409
# Epoch 1, Batch 83/240, MSE = 0.002639
# Epoch 1, Batch 84/240, MSE = 0.002609
# Epoch 1, Batch 85/240, MSE = 0.002572
# Epoch 1, Batch 86/240, MSE = 0.002278
# Epoch 1, Batch 87/240, MSE = 0.002531
# Epoch 1, Batch 88/240, MSE = 0.002559
# Epoch 1, Batch 89/240, MSE = 0.002503
# Epoch 1, Batch 90/240, MSE = 0.002708
# Epoch 1, Batch 91/240, MSE = 0.002562
# Epoch 1, Batch 92/240, MSE = 0.002565
# Epoch 1, Batch 93/240, MSE = 0.002491
# Epoch 1, Batch 94/240, MSE = 0.002669
# Epoch 1, Batch 95/240, MSE = 0.002605
# Epoch 1, Batch 96/240, MSE = 0.002632
# Epoch 1, Batch 97/240, MSE = 0.002617
# Epoch 1, Batch 98/240, MSE = 0.002562
# Epoch 1, Batch 99/240, MSE = 0.002655
# Epoch 1, Batch 100/240, MSE = 0.002490
# Epoch 1, Batch 101/240, MSE = 0.002553
# Epoch 1, Batch 102/240, MSE = 0.002649
# Epoch 1, Batch 103/240, MSE = 0.002477
# Epoch 1, Batch 104/240, MSE = 0.002644
# Epoch 1, Batch 105/240, MSE = 0.002529
# Epoch 1, Batch 106/240, MSE = 0.002555
# Epoch 1, Batch 107/240, MSE = 0.002486
# Epoch 1, Batch 108/240, MSE = 0.002462
# Epoch 1, Batch 109/240, MSE = 0.002227
# Epoch 1, Batch 110/240, MSE = 0.002480
# Epoch 1, Batch 111/240, MSE = 0.002668
# Epoch 1, Batch 112/240, MSE = 0.002589
# Epoch 1, Batch 113/240, MSE = 0.002543
# Epoch 1, Batch 114/240, MSE = 0.002459
# Epoch 1, Batch 115/240, MSE = 0.002529
# Epoch 1, Batch 116/240, MSE = 0.002631
# Epoch 1, Batch 117/240, MSE = 0.002498
# Epoch 1, Batch 118/240, MSE = 0.002592
# Epoch 1, Batch 119/240, MSE = 0.002666
# Epoch 1, Batch 120/240, MSE = 0.002597
# Epoch 1, Batch 121/240, MSE = 0.002586
# Epoch 1, Batch 122/240, MSE = 0.002504
# Epoch 1, Batch 123/240, MSE = 0.002558
# Epoch 1, Batch 124/240, MSE = 0.002541
# Epoch 1, Batch 125/240, MSE = 0.002524
# Epoch 1, Batch 126/240, MSE = 0.002586
# Epoch 1, Batch 127/240, MSE = 0.002484
# Epoch 1, Batch 128/240, MSE = 0.002636
# Epoch 1, Batch 129/240, MSE = 0.002429
# Epoch 1, Batch 130/240, MSE = 0.002729
# Epoch 1, Batch 131/240, MSE = 0.002495
# Epoch 1, Batch 132/240, MSE = 0.002602
# Epoch 1, Batch 133/240, MSE = 0.002574
# Epoch 1, Batch 134/240, MSE = 0.002571
# Epoch 1, Batch 135/240, MSE = 0.002485
# Epoch 1, Batch 136/240, MSE = 0.002603
# Epoch 1, Batch 137/240, MSE = 0.002649
# Epoch 1, Batch 138/240, MSE = 0.002527
# Epoch 1, Batch 139/240, MSE = 0.002568
# Epoch 1, Batch 140/240, MSE = 0.002650
# Epoch 1, Batch 141/240, MSE = 0.002737
# Epoch 1, Batch 142/240, MSE = 0.002623
# Epoch 1, Batch 143/240, MSE = 0.002641
# Epoch 1, Batch 144/240, MSE = 0.002597
# Epoch 1, Batch 145/240, MSE = 0.002559
# Epoch 1, Batch 146/240, MSE = 0.002579
# Epoch 1, Batch 147/240, MSE = 0.002548
# Epoch 1, Batch 148/240, MSE = 0.002722
# Epoch 1, Batch 149/240, MSE = 0.002568
# Epoch 1, Batch 150/240, MSE = 0.002760
# Epoch 1, Batch 151/240, MSE = 0.002489
# Epoch 1, Batch 152/240, MSE = 0.002611
# Epoch 1, Batch 153/240, MSE = 0.002611
# Epoch 1, Batch 154/240, MSE = 0.002538
# Epoch 1, Batch 155/240, MSE = 0.002458
# Epoch 1, Batch 156/240, MSE = 0.002541
# Epoch 1, Batch 157/240, MSE = 0.002617
# Epoch 1, Batch 158/240, MSE = 0.002415
# Epoch 1, Batch 159/240, MSE = 0.002565
# Epoch 1, Batch 160/240, MSE = 0.002655
# Epoch 1, Batch 161/240, MSE = 0.002516
# Epoch 1, Batch 162/240, MSE = 0.002689
# Epoch 1, Batch 163/240, MSE = 0.002563
# Epoch 1, Batch 164/240, MSE = 0.002517
# Epoch 1, Batch 165/240, MSE = 0.002722
# Epoch 1, Batch 166/240, MSE = 0.002598
# Epoch 1, Batch 167/240, MSE = 0.002748
# Epoch 1, Batch 168/240, MSE = 0.002497
# Epoch 1, Batch 169/240, MSE = 0.002588
# Epoch 1, Batch 170/240, MSE = 0.002553
# Epoch 1, Batch 171/240, MSE = 0.002357
# Epoch 1, Batch 172/240, MSE = 0.002444
# Epoch 1, Batch 173/240, MSE = 0.002431
# Epoch 1, Batch 174/240, MSE = 0.002548
# Epoch 1, Batch 175/240, MSE = 0.002527
# Epoch 1, Batch 176/240, MSE = 0.002660
# Epoch 1, Batch 177/240, MSE = 0.002588
# Epoch 1, Batch 178/240, MSE = 0.002462
# Epoch 1, Batch 179/240, MSE = 0.002374
# Epoch 1, Batch 180/240, MSE = 0.002603
# Epoch 1, Batch 181/240, MSE = 0.002487
# Epoch 1, Batch 182/240, MSE = 0.002591
# Epoch 1, Batch 183/240, MSE = 0.002741
# Epoch 1, Batch 184/240, MSE = 0.002566
# Epoch 1, Batch 185/240, MSE = 0.002514
# Epoch 1, Batch 186/240, MSE = 0.002530
# Epoch 1, Batch 187/240, MSE = 0.002380
# Epoch 1, Batch 188/240, MSE = 0.002491
# Epoch 1, Batch 189/240, MSE = 0.002708
# Epoch 1, Batch 190/240, MSE = 0.002438
# Epoch 1, Batch 191/240, MSE = 0.002538
# Epoch 1, Batch 192/240, MSE = 0.002687
# Epoch 1, Batch 193/240, MSE = 0.002627
# Epoch 1, Batch 194/240, MSE = 0.002628
# Epoch 1, Batch 195/240, MSE = 0.002644
# Epoch 1, Batch 196/240, MSE = 0.002575
# Epoch 1, Batch 197/240, MSE = 0.002642
# Epoch 1, Batch 198/240, MSE = 0.002674
# Epoch 1, Batch 199/240, MSE = 0.002457
# Epoch 1, Batch 200/240, MSE = 0.002553
# Epoch 1, Batch 201/240, MSE = 0.002475
# Epoch 1, Batch 202/240, MSE = 0.002547
# Epoch 1, Batch 203/240, MSE = 0.002557
# Epoch 1, Batch 204/240, MSE = 0.002625
# Epoch 1, Batch 205/240, MSE = 0.002650
# Epoch 1, Batch 206/240, MSE = 0.002565
# Epoch 1, Batch 207/240, MSE = 0.002482
# Epoch 1, Batch 208/240, MSE = 0.002522
# Epoch 1, Batch 209/240, MSE = 0.002607
# Epoch 1, Batch 210/240, MSE = 0.002461
# Epoch 1, Batch 211/240, MSE = 0.002464
# Epoch 1, Batch 212/240, MSE = 0.002564
# Epoch 1, Batch 213/240, MSE = 0.002435
# Epoch 1, Batch 214/240, MSE = 0.002687
# Epoch 1, Batch 215/240, MSE = 0.002606
# Epoch 1, Batch 216/240, MSE = 0.002512
# Epoch 1, Batch 217/240, MSE = 0.002450
# Epoch 1, Batch 218/240, MSE = 0.002603
# Epoch 1, Batch 219/240, MSE = 0.002613
# Epoch 1, Batch 220/240, MSE = 0.002496
# Epoch 1, Batch 221/240, MSE = 0.002468
# Epoch 1, Batch 222/240, MSE = 0.002543
# Epoch 1, Batch 223/240, MSE = 0.002692
# Epoch 1, Batch 224/240, MSE = 0.002581
# Epoch 1, Batch 225/240, MSE = 0.002508
# Epoch 1, Batch 226/240, MSE = 0.002707
# Epoch 1, Batch 227/240, MSE = 0.002581
# Epoch 1, Batch 228/240, MSE = 0.002584
# Epoch 1, Batch 229/240, MSE = 0.002522
# Epoch 1, Batch 230/240, MSE = 0.002583
# Epoch 1, Batch 231/240, MSE = 0.002593
# Epoch 1, Batch 232/240, MSE = 0.002539
# Epoch 1, Batch 233/240, MSE = 0.002640
# Epoch 1, Batch 234/240, MSE = 0.002512
# Epoch 1, Batch 235/240, MSE = 0.002374
# Epoch 1, Batch 236/240, MSE = 0.002589
# Epoch 1, Batch 237/240, MSE = 0.002479
# Epoch 1, Batch 238/240, MSE = 0.002596
# Epoch 1, Batch 239/240, MSE = 0.002611
# Epoch 1, Batch 240/240, MSE = 0.002496
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.136616
# Epoch 1, Batch 2/240, MSE = 0.002731
# Epoch 1, Batch 3/240, MSE = 0.004434
# Epoch 1, Batch 4/240, MSE = 0.002066
# Epoch 1, Batch 5/240, MSE = 0.003720
# Epoch 1, Batch 6/240, MSE = 0.002526
# Epoch 1, Batch 7/240, MSE = 0.002688
# Epoch 1, Batch 8/240, MSE = 0.002986
# Epoch 1, Batch 9/240, MSE = 0.004369
# Epoch 1, Batch 10/240, MSE = 0.002354
# Epoch 1, Batch 11/240, MSE = 0.002576
# Epoch 1, Batch 12/240, MSE = 0.004397
# Epoch 1, Batch 13/240, MSE = 0.003611
# Epoch 1, Batch 14/240, MSE = 0.003066
# Epoch 1, Batch 15/240, MSE = 0.001794
# Epoch 1, Batch 16/240, MSE = 0.003382
# Epoch 1, Batch 17/240, MSE = 0.003028
# Epoch 1, Batch 18/240, MSE = 0.002926
# Epoch 1, Batch 19/240, MSE = 0.003001
# Epoch 1, Batch 20/240, MSE = 0.003937
# Epoch 1, Batch 21/240, MSE = 0.003080
# Epoch 1, Batch 22/240, MSE = 0.002655
# Epoch 1, Batch 23/240, MSE = 0.002011
# Epoch 1, Batch 24/240, MSE = 0.003205
# Epoch 1, Batch 25/240, MSE = 0.003657
# Epoch 1, Batch 26/240, MSE = 0.002199
# Epoch 1, Batch 27/240, MSE = 0.002596
# Epoch 1, Batch 28/240, MSE = 0.003036
# Epoch 1, Batch 29/240, MSE = 0.001969
# Epoch 1, Batch 30/240, MSE = 0.002272
# Epoch 1, Batch 31/240, MSE = 0.002147
# Epoch 1, Batch 32/240, MSE = 0.003788
# Epoch 1, Batch 33/240, MSE = 0.002396
# Epoch 1, Batch 34/240, MSE = 0.003193
# Epoch 1, Batch 35/240, MSE = 0.002214
# Epoch 1, Batch 36/240, MSE = 0.001937
# Epoch 1, Batch 37/240, MSE = 0.001999
# Epoch 1, Batch 38/240, MSE = 0.001574
# Epoch 1, Batch 39/240, MSE = 0.002596
# Epoch 1, Batch 40/240, MSE = 0.001575
# Epoch 1, Batch 41/240, MSE = 0.001190
# Epoch 1, Batch 42/240, MSE = 0.001506
# Epoch 1, Batch 43/240, MSE = 0.001569
# Epoch 1, Batch 44/240, MSE = 0.001951
# Epoch 1, Batch 45/240, MSE = 0.001654
# Epoch 1, Batch 46/240, MSE = 0.000735
# Epoch 1, Batch 47/240, MSE = 0.001263
# Epoch 1, Batch 48/240, MSE = 0.001985
# Epoch 1, Batch 49/240, MSE = 0.001013
# Epoch 1, Batch 50/240, MSE = 0.000887
# Epoch 1, Batch 51/240, MSE = 0.001246
# Epoch 1, Batch 52/240, MSE = 0.000744
# Epoch 1, Batch 53/240, MSE = 0.000830
# Epoch 1, Batch 54/240, MSE = 0.000846
# Epoch 1, Batch 55/240, MSE = 0.000741
# Epoch 1, Batch 56/240, MSE = 0.000459
# Epoch 1, Batch 57/240, MSE = 0.000472
# Epoch 1, Batch 58/240, MSE = 0.000621
# Epoch 1, Batch 59/240, MSE = 0.000443
# Epoch 1, Batch 60/240, MSE = 0.000424
# Epoch 1, Batch 61/240, MSE = 0.000292
# Epoch 1, Batch 62/240, MSE = 0.000275
# Epoch 1, Batch 63/240, MSE = 0.000394
# Epoch 1, Batch 64/240, MSE = 0.000288
# Epoch 1, Batch 65/240, MSE = 0.000234
# Epoch 1, Batch 66/240, MSE = 0.000218
# Epoch 1, Batch 67/240, MSE = 0.000183
# Epoch 1, Batch 68/240, MSE = 0.000164
# Epoch 1, Batch 69/240, MSE = 0.000157
# Epoch 1, Batch 70/240, MSE = 0.000182
# Epoch 1, Batch 71/240, MSE = 0.000131
# Epoch 1, Batch 72/240, MSE = 0.000140
# Epoch 1, Batch 73/240, MSE = 0.000128
# Epoch 1, Batch 74/240, MSE = 0.000121
# Epoch 1, Batch 75/240, MSE = 0.000127
# Epoch 1, Batch 76/240, MSE = 0.000130
# Epoch 1, Batch 77/240, MSE = 0.000124
# Epoch 1, Batch 78/240, MSE = 0.000109
# Epoch 1, Batch 79/240, MSE = 0.000116
# Epoch 1, Batch 80/240, MSE = 0.000109
# Epoch 1, Batch 81/240, MSE = 0.000112
# Epoch 1, Batch 82/240, MSE = 0.000099
# Epoch 1, Batch 83/240, MSE = 0.000105
# Epoch 1, Batch 84/240, MSE = 0.000104
# Epoch 1, Batch 85/240, MSE = 0.000106
# Epoch 1, Batch 86/240, MSE = 0.000100
# Epoch 1, Batch 87/240, MSE = 0.000100
# Epoch 1, Batch 88/240, MSE = 0.000094
# Epoch 1, Batch 89/240, MSE = 0.000105
# Epoch 1, Batch 90/240, MSE = 0.000093
# Epoch 1, Batch 91/240, MSE = 0.000098
# Epoch 1, Batch 92/240, MSE = 0.000100
# Epoch 1, Batch 93/240, MSE = 0.000095
# Epoch 1, Batch 94/240, MSE = 0.000097
# Epoch 1, Batch 95/240, MSE = 0.000097
# Epoch 1, Batch 96/240, MSE = 0.000093
# Epoch 1, Batch 97/240, MSE = 0.000097
# Epoch 1, Batch 98/240, MSE = 0.000100
# Epoch 1, Batch 99/240, MSE = 0.000093
# Epoch 1, Batch 100/240, MSE = 0.000091
# Epoch 1, Batch 101/240, MSE = 0.000102
# Epoch 1, Batch 102/240, MSE = 0.000090
# Epoch 1, Batch 103/240, MSE = 0.000097
# Epoch 1, Batch 104/240, MSE = 0.000098
# Epoch 1, Batch 105/240, MSE = 0.000095
# Epoch 1, Batch 106/240, MSE = 0.000091
# Epoch 1, Batch 107/240, MSE = 0.000097
# Epoch 1, Batch 108/240, MSE = 0.000100
# Epoch 1, Batch 109/240, MSE = 0.000100
# Epoch 1, Batch 110/240, MSE = 0.000095
# Epoch 1, Batch 111/240, MSE = 0.000096
# Epoch 1, Batch 112/240, MSE = 0.000099
# Epoch 1, Batch 113/240, MSE = 0.000093
# Epoch 1, Batch 114/240, MSE = 0.000096
# Epoch 1, Batch 115/240, MSE = 0.000102
# Epoch 1, Batch 116/240, MSE = 0.000100
# Epoch 1, Batch 117/240, MSE = 0.000097
# Epoch 1, Batch 118/240, MSE = 0.000097
# Epoch 1, Batch 119/240, MSE = 0.000098
# Epoch 1, Batch 120/240, MSE = 0.000097
# Epoch 1, Batch 121/240, MSE = 0.000094
# Epoch 1, Batch 122/240, MSE = 0.000092
# Epoch 1, Batch 123/240, MSE = 0.000099
# Epoch 1, Batch 124/240, MSE = 0.000096
# Epoch 1, Batch 125/240, MSE = 0.000095
# Epoch 1, Batch 126/240, MSE = 0.000102
# Epoch 1, Batch 127/240, MSE = 0.000100
# Epoch 1, Batch 128/240, MSE = 0.000101
# Epoch 1, Batch 129/240, MSE = 0.000095
# Epoch 1, Batch 130/240, MSE = 0.000100
# Epoch 1, Batch 131/240, MSE = 0.000099
# Epoch 1, Batch 132/240, MSE = 0.000096
# Epoch 1, Batch 133/240, MSE = 0.000096
# Epoch 1, Batch 134/240, MSE = 0.000092
# Epoch 1, Batch 135/240, MSE = 0.000096
# Epoch 1, Batch 136/240, MSE = 0.000100
# Epoch 1, Batch 137/240, MSE = 0.000095
# Epoch 1, Batch 138/240, MSE = 0.000100
# Epoch 1, Batch 139/240, MSE = 0.000100
# Epoch 1, Batch 140/240, MSE = 0.000104
# Epoch 1, Batch 141/240, MSE = 0.000097
# Epoch 1, Batch 142/240, MSE = 0.000093
# Epoch 1, Batch 143/240, MSE = 0.000094
# Epoch 1, Batch 144/240, MSE = 0.000093
# Epoch 1, Batch 145/240, MSE = 0.000100
# Epoch 1, Batch 146/240, MSE = 0.000092
# Epoch 1, Batch 147/240, MSE = 0.000102
# Epoch 1, Batch 148/240, MSE = 0.000094
# Epoch 1, Batch 149/240, MSE = 0.000099
# Epoch 1, Batch 150/240, MSE = 0.000099
# Epoch 1, Batch 151/240, MSE = 0.000096
# Epoch 1, Batch 152/240, MSE = 0.000093
# Epoch 1, Batch 153/240, MSE = 0.000103
# Epoch 1, Batch 154/240, MSE = 0.000098
# Epoch 1, Batch 155/240, MSE = 0.000091
# Epoch 1, Batch 156/240, MSE = 0.000094
# Epoch 1, Batch 157/240, MSE = 0.000094
# Epoch 1, Batch 158/240, MSE = 0.000091
# Epoch 1, Batch 159/240, MSE = 0.000096
# Epoch 1, Batch 160/240, MSE = 0.000097
# Epoch 1, Batch 161/240, MSE = 0.000091
# Epoch 1, Batch 162/240, MSE = 0.000094
# Epoch 1, Batch 163/240, MSE = 0.000099
# Epoch 1, Batch 164/240, MSE = 0.000099
# Epoch 1, Batch 165/240, MSE = 0.000095
# Epoch 1, Batch 166/240, MSE = 0.000099
# Epoch 1, Batch 167/240, MSE = 0.000099
# Epoch 1, Batch 168/240, MSE = 0.000094
# Epoch 1, Batch 169/240, MSE = 0.000097
# Epoch 1, Batch 170/240, MSE = 0.000098
# Epoch 1, Batch 171/240, MSE = 0.000095
# Epoch 1, Batch 172/240, MSE = 0.000099
# Epoch 1, Batch 173/240, MSE = 0.000093
# Epoch 1, Batch 174/240, MSE = 0.000090
# Epoch 1, Batch 175/240, MSE = 0.000098
# Epoch 1, Batch 176/240, MSE = 0.000097
# Epoch 1, Batch 177/240, MSE = 0.000099
# Epoch 1, Batch 178/240, MSE = 0.000096
# Epoch 1, Batch 179/240, MSE = 0.000091
# Epoch 1, Batch 180/240, MSE = 0.000094
# Epoch 1, Batch 181/240, MSE = 0.000101
# Epoch 1, Batch 182/240, MSE = 0.000098
# Epoch 1, Batch 183/240, MSE = 0.000095
# Epoch 1, Batch 184/240, MSE = 0.000096
# Epoch 1, Batch 185/240, MSE = 0.000095
# Epoch 1, Batch 186/240, MSE = 0.000095
# Epoch 1, Batch 187/240, MSE = 0.000097
# Epoch 1, Batch 188/240, MSE = 0.000094
# Epoch 1, Batch 189/240, MSE = 0.000091
# Epoch 1, Batch 190/240, MSE = 0.000093
# Epoch 1, Batch 191/240, MSE = 0.000094
# Epoch 1, Batch 192/240, MSE = 0.000093
# Epoch 1, Batch 193/240, MSE = 0.000093
# Epoch 1, Batch 194/240, MSE = 0.000088
# Epoch 1, Batch 195/240, MSE = 0.000096
# Epoch 1, Batch 196/240, MSE = 0.000091
# Epoch 1, Batch 197/240, MSE = 0.000102
# Epoch 1, Batch 198/240, MSE = 0.000100
# Epoch 1, Batch 199/240, MSE = 0.000097
# Epoch 1, Batch 200/240, MSE = 0.000098
# Epoch 1, Batch 201/240, MSE = 0.000101
# Epoch 1, Batch 202/240, MSE = 0.000093
# Epoch 1, Batch 203/240, MSE = 0.000099
# Epoch 1, Batch 204/240, MSE = 0.000104
# Epoch 1, Batch 205/240, MSE = 0.000095
# Epoch 1, Batch 206/240, MSE = 0.000097
# Epoch 1, Batch 207/240, MSE = 0.000089
# Epoch 1, Batch 208/240, MSE = 0.000090
# Epoch 1, Batch 209/240, MSE = 0.000100
# Epoch 1, Batch 210/240, MSE = 0.000096
# Epoch 1, Batch 211/240, MSE = 0.000097
# Epoch 1, Batch 212/240, MSE = 0.000089
# Epoch 1, Batch 213/240, MSE = 0.000097
# Epoch 1, Batch 214/240, MSE = 0.000094
# Epoch 1, Batch 215/240, MSE = 0.000094
# Epoch 1, Batch 216/240, MSE = 0.000093
# Epoch 1, Batch 217/240, MSE = 0.000097
# Epoch 1, Batch 218/240, MSE = 0.000102
# Epoch 1, Batch 219/240, MSE = 0.000092
# Epoch 1, Batch 220/240, MSE = 0.000106
# Epoch 1, Batch 221/240, MSE = 0.000098
# Epoch 1, Batch 222/240, MSE = 0.000101
# Epoch 1, Batch 223/240, MSE = 0.000091
# Epoch 1, Batch 224/240, MSE = 0.000098
# Epoch 1, Batch 225/240, MSE = 0.000088
# Epoch 1, Batch 226/240, MSE = 0.000092
# Epoch 1, Batch 227/240, MSE = 0.000095
# Epoch 1, Batch 228/240, MSE = 0.000098
# Epoch 1, Batch 229/240, MSE = 0.000098
# Epoch 1, Batch 230/240, MSE = 0.000093
# Epoch 1, Batch 231/240, MSE = 0.000098
# Epoch 1, Batch 232/240, MSE = 0.000100
# Epoch 1, Batch 233/240, MSE = 0.000095
# Epoch 1, Batch 234/240, MSE = 0.000086
# Epoch 1, Batch 235/240, MSE = 0.000092
# Epoch 1, Batch 236/240, MSE = 0.000093
# Epoch 1, Batch 237/240, MSE = 0.000095
# Epoch 1, Batch 238/240, MSE = 0.000100
# Epoch 1, Batch 239/240, MSE = 0.000085
# Epoch 1, Batch 240/240, MSE = 0.000095
#
# ============================================================
# Epoch 2/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.019916
# Epoch 1, Batch 2/240, MSE = 0.017850
# Epoch 1, Batch 3/240, MSE = 0.020313
# Epoch 1, Batch 4/240, MSE = 0.018932
# Epoch 1, Batch 5/240, MSE = 0.018972
# Epoch 1, Batch 6/240, MSE = 0.019301
# Epoch 1, Batch 7/240, MSE = 0.019054
# Epoch 1, Batch 8/240, MSE = 0.019444
# Epoch 1, Batch 9/240, MSE = 0.018547
# Epoch 1, Batch 10/240, MSE = 0.019736
# Epoch 1, Batch 11/240, MSE = 0.019913
# Epoch 1, Batch 12/240, MSE = 0.019137
# Epoch 1, Batch 13/240, MSE = 0.018582
# Epoch 1, Batch 14/240, MSE = 0.020140
# Epoch 1, Batch 15/240, MSE = 0.019126
# Epoch 1, Batch 16/240, MSE = 0.019354
# Epoch 1, Batch 17/240, MSE = 0.019406
# Epoch 1, Batch 18/240, MSE = 0.019092
# Epoch 1, Batch 19/240, MSE = 0.018098
# Epoch 1, Batch 20/240, MSE = 0.019878
# Epoch 1, Batch 21/240, MSE = 0.018198
# Epoch 1, Batch 22/240, MSE = 0.020108
# Epoch 1, Batch 23/240, MSE = 0.019853
# Epoch 1, Batch 24/240, MSE = 0.018567
# Epoch 1, Batch 25/240, MSE = 0.019001
# Epoch 1, Batch 26/240, MSE = 0.018899
# Epoch 1, Batch 27/240, MSE = 0.018982
# Epoch 1, Batch 28/240, MSE = 0.019078
# Epoch 1, Batch 29/240, MSE = 0.018910
# Epoch 1, Batch 30/240, MSE = 0.017726
# Epoch 1, Batch 31/240, MSE = 0.019079
# Epoch 1, Batch 32/240, MSE = 0.017106
# Epoch 1, Batch 33/240, MSE = 0.017469
# Epoch 1, Batch 34/240, MSE = 0.017876
# Epoch 1, Batch 35/240, MSE = 0.019193
# Epoch 1, Batch 36/240, MSE = 0.018874
# Epoch 1, Batch 37/240, MSE = 0.018661
# Epoch 1, Batch 38/240, MSE = 0.018300
# Epoch 1, Batch 39/240, MSE = 0.019110
# Epoch 1, Batch 40/240, MSE = 0.018540
# Epoch 1, Batch 41/240, MSE = 0.018963
# Epoch 1, Batch 42/240, MSE = 0.019002
# Epoch 1, Batch 43/240, MSE = 0.019493
# Epoch 1, Batch 44/240, MSE = 0.019583
# Epoch 1, Batch 45/240, MSE = 0.018515
# Epoch 1, Batch 46/240, MSE = 0.019033
# Epoch 1, Batch 47/240, MSE = 0.018278
# Epoch 1, Batch 48/240, MSE = 0.018092
# Epoch 1, Batch 49/240, MSE = 0.018982
# Epoch 1, Batch 50/240, MSE = 0.018059
# Epoch 1, Batch 51/240, MSE = 0.018843
# Epoch 1, Batch 52/240, MSE = 0.019906
# Epoch 1, Batch 53/240, MSE = 0.020002
# Epoch 1, Batch 54/240, MSE = 0.018162
# Epoch 1, Batch 55/240, MSE = 0.019222
# Epoch 1, Batch 56/240, MSE = 0.019687
# Epoch 1, Batch 57/240, MSE = 0.019110
# Epoch 1, Batch 58/240, MSE = 0.019022
# Epoch 1, Batch 59/240, MSE = 0.019718
# Epoch 1, Batch 60/240, MSE = 0.019005
# Epoch 1, Batch 61/240, MSE = 0.018577
# Epoch 1, Batch 62/240, MSE = 0.019555
# Epoch 1, Batch 63/240, MSE = 0.018799
# Epoch 1, Batch 64/240, MSE = 0.019667
# Epoch 1, Batch 65/240, MSE = 0.018872
# Epoch 1, Batch 66/240, MSE = 0.017503
# Epoch 1, Batch 67/240, MSE = 0.018250
# Epoch 1, Batch 68/240, MSE = 0.019450
# Epoch 1, Batch 69/240, MSE = 0.018656
# Epoch 1, Batch 70/240, MSE = 0.019224
# Epoch 1, Batch 71/240, MSE = 0.019235
# Epoch 1, Batch 72/240, MSE = 0.019134
# Epoch 1, Batch 73/240, MSE = 0.018679
# Epoch 1, Batch 74/240, MSE = 0.019278
# Epoch 1, Batch 75/240, MSE = 0.019031
# Epoch 1, Batch 76/240, MSE = 0.019574
# Epoch 1, Batch 77/240, MSE = 0.018502
# Epoch 1, Batch 78/240, MSE = 0.019093
# Epoch 1, Batch 79/240, MSE = 0.018407
# Epoch 1, Batch 80/240, MSE = 0.018952
# Epoch 1, Batch 81/240, MSE = 0.018065
# Epoch 1, Batch 82/240, MSE = 0.018953
# Epoch 1, Batch 83/240, MSE = 0.018121
# Epoch 1, Batch 84/240, MSE = 0.017729
# Epoch 1, Batch 85/240, MSE = 0.018384
# Epoch 1, Batch 86/240, MSE = 0.019749
# Epoch 1, Batch 87/240, MSE = 0.019644
# Epoch 1, Batch 88/240, MSE = 0.017815
# Epoch 1, Batch 89/240, MSE = 0.019290
# Epoch 1, Batch 90/240, MSE = 0.018317
# Epoch 1, Batch 91/240, MSE = 0.018970
# Epoch 1, Batch 92/240, MSE = 0.018930
# Epoch 1, Batch 93/240, MSE = 0.019467
# Epoch 1, Batch 94/240, MSE = 0.018319
# Epoch 1, Batch 95/240, MSE = 0.018948
# Epoch 1, Batch 96/240, MSE = 0.020207
# Epoch 1, Batch 97/240, MSE = 0.018933
# Epoch 1, Batch 98/240, MSE = 0.020091
# Epoch 1, Batch 99/240, MSE = 0.018880
# Epoch 1, Batch 100/240, MSE = 0.018695
# Epoch 1, Batch 101/240, MSE = 0.018557
# Epoch 1, Batch 102/240, MSE = 0.018336
# Epoch 1, Batch 103/240, MSE = 0.019482
# Epoch 1, Batch 104/240, MSE = 0.016740
# Epoch 1, Batch 105/240, MSE = 0.018856
# Epoch 1, Batch 106/240, MSE = 0.019824
# Epoch 1, Batch 107/240, MSE = 0.017745
# Epoch 1, Batch 108/240, MSE = 0.019910
# Epoch 1, Batch 109/240, MSE = 0.017656
# Epoch 1, Batch 110/240, MSE = 0.018805
# Epoch 1, Batch 111/240, MSE = 0.019604
# Epoch 1, Batch 112/240, MSE = 0.018223
# Epoch 1, Batch 113/240, MSE = 0.019816
# Epoch 1, Batch 114/240, MSE = 0.017837
# Epoch 1, Batch 115/240, MSE = 0.018320
# Epoch 1, Batch 116/240, MSE = 0.019484
# Epoch 1, Batch 117/240, MSE = 0.019833
# Epoch 1, Batch 118/240, MSE = 0.018818
# Epoch 1, Batch 119/240, MSE = 0.017743
# Epoch 1, Batch 120/240, MSE = 0.019627
# Epoch 1, Batch 121/240, MSE = 0.018750
# Epoch 1, Batch 122/240, MSE = 0.019184
# Epoch 1, Batch 123/240, MSE = 0.018444
# Epoch 1, Batch 124/240, MSE = 0.018330
# Epoch 1, Batch 125/240, MSE = 0.018191
# Epoch 1, Batch 126/240, MSE = 0.018075
# Epoch 1, Batch 127/240, MSE = 0.018537
# Epoch 1, Batch 128/240, MSE = 0.019186
# Epoch 1, Batch 129/240, MSE = 0.018924
# Epoch 1, Batch 130/240, MSE = 0.017897
# Epoch 1, Batch 131/240, MSE = 0.017205
# Epoch 1, Batch 132/240, MSE = 0.019224
# Epoch 1, Batch 133/240, MSE = 0.019287
# Epoch 1, Batch 134/240, MSE = 0.016724
# Epoch 1, Batch 135/240, MSE = 0.018357
# Epoch 1, Batch 136/240, MSE = 0.018476
# Epoch 1, Batch 137/240, MSE = 0.019133
# Epoch 1, Batch 138/240, MSE = 0.018718
# Epoch 1, Batch 139/240, MSE = 0.018095
# Epoch 1, Batch 140/240, MSE = 0.018346
# Epoch 1, Batch 141/240, MSE = 0.019374
# Epoch 1, Batch 142/240, MSE = 0.018516
# Epoch 1, Batch 143/240, MSE = 0.018379
# Epoch 1, Batch 144/240, MSE = 0.017905
# Epoch 1, Batch 145/240, MSE = 0.019713
# Epoch 1, Batch 146/240, MSE = 0.017811
# Epoch 1, Batch 147/240, MSE = 0.018467
# Epoch 1, Batch 148/240, MSE = 0.017241
# Epoch 1, Batch 149/240, MSE = 0.016965
# Epoch 1, Batch 150/240, MSE = 0.016716
# Epoch 1, Batch 151/240, MSE = 0.018874
# Epoch 1, Batch 152/240, MSE = 0.018152
# Epoch 1, Batch 153/240, MSE = 0.018059
# Epoch 1, Batch 154/240, MSE = 0.017445
# Epoch 1, Batch 155/240, MSE = 0.017375
# Epoch 1, Batch 156/240, MSE = 0.018725
# Epoch 1, Batch 157/240, MSE = 0.019152
# Epoch 1, Batch 158/240, MSE = 0.018162
# Epoch 1, Batch 159/240, MSE = 0.018899
# Epoch 1, Batch 160/240, MSE = 0.018641
# Epoch 1, Batch 161/240, MSE = 0.018027
# Epoch 1, Batch 162/240, MSE = 0.018141
# Epoch 1, Batch 163/240, MSE = 0.018098
# Epoch 1, Batch 164/240, MSE = 0.018784
# Epoch 1, Batch 165/240, MSE = 0.018112
# Epoch 1, Batch 166/240, MSE = 0.017458
# Epoch 1, Batch 167/240, MSE = 0.017098
# Epoch 1, Batch 168/240, MSE = 0.016802
# Epoch 1, Batch 169/240, MSE = 0.018524
# Epoch 1, Batch 170/240, MSE = 0.017204
# Epoch 1, Batch 171/240, MSE = 0.018057
# Epoch 1, Batch 172/240, MSE = 0.018170
# Epoch 1, Batch 173/240, MSE = 0.017178
# Epoch 1, Batch 174/240, MSE = 0.018320
# Epoch 1, Batch 175/240, MSE = 0.017373
# Epoch 1, Batch 176/240, MSE = 0.018524
# Epoch 1, Batch 177/240, MSE = 0.018480
# Epoch 1, Batch 178/240, MSE = 0.019245
# Epoch 1, Batch 179/240, MSE = 0.018994
# Epoch 1, Batch 180/240, MSE = 0.019958
# Epoch 1, Batch 181/240, MSE = 0.018178
# Epoch 1, Batch 182/240, MSE = 0.019504
# Epoch 1, Batch 183/240, MSE = 0.017345
# Epoch 1, Batch 184/240, MSE = 0.018296
# Epoch 1, Batch 185/240, MSE = 0.018220
# Epoch 1, Batch 186/240, MSE = 0.017539
# Epoch 1, Batch 187/240, MSE = 0.018870
# Epoch 1, Batch 188/240, MSE = 0.018651
# Epoch 1, Batch 189/240, MSE = 0.018660
# Epoch 1, Batch 190/240, MSE = 0.019069
# Epoch 1, Batch 191/240, MSE = 0.018446
# Epoch 1, Batch 192/240, MSE = 0.018129
# Epoch 1, Batch 193/240, MSE = 0.017310
# Epoch 1, Batch 194/240, MSE = 0.018266
# Epoch 1, Batch 195/240, MSE = 0.017795
# Epoch 1, Batch 196/240, MSE = 0.017627
# Epoch 1, Batch 197/240, MSE = 0.017753
# Epoch 1, Batch 198/240, MSE = 0.018521
# Epoch 1, Batch 199/240, MSE = 0.018450
# Epoch 1, Batch 200/240, MSE = 0.018289
# Epoch 1, Batch 201/240, MSE = 0.018304
# Epoch 1, Batch 202/240, MSE = 0.016883
# Epoch 1, Batch 203/240, MSE = 0.018128
# Epoch 1, Batch 204/240, MSE = 0.018744
# Epoch 1, Batch 205/240, MSE = 0.017558
# Epoch 1, Batch 206/240, MSE = 0.018042
# Epoch 1, Batch 207/240, MSE = 0.018581
# Epoch 1, Batch 208/240, MSE = 0.018239
# Epoch 1, Batch 209/240, MSE = 0.017496
# Epoch 1, Batch 210/240, MSE = 0.017598
# Epoch 1, Batch 211/240, MSE = 0.017108
# Epoch 1, Batch 212/240, MSE = 0.018551
# Epoch 1, Batch 213/240, MSE = 0.016511
# Epoch 1, Batch 214/240, MSE = 0.017165
# Epoch 1, Batch 215/240, MSE = 0.017104
# Epoch 1, Batch 216/240, MSE = 0.018444
# Epoch 1, Batch 217/240, MSE = 0.016904
# Epoch 1, Batch 218/240, MSE = 0.016976
# Epoch 1, Batch 219/240, MSE = 0.017854
# Epoch 1, Batch 220/240, MSE = 0.018242
# Epoch 1, Batch 221/240, MSE = 0.018560
# Epoch 1, Batch 222/240, MSE = 0.016589
# Epoch 1, Batch 223/240, MSE = 0.017751
# Epoch 1, Batch 224/240, MSE = 0.018196
# Epoch 1, Batch 225/240, MSE = 0.018223
# Epoch 1, Batch 226/240, MSE = 0.018565
# Epoch 1, Batch 227/240, MSE = 0.018816
# Epoch 1, Batch 228/240, MSE = 0.017252
# Epoch 1, Batch 229/240, MSE = 0.017378
# Epoch 1, Batch 230/240, MSE = 0.017692
# Epoch 1, Batch 231/240, MSE = 0.016952
# Epoch 1, Batch 232/240, MSE = 0.018518
# Epoch 1, Batch 233/240, MSE = 0.016923
# Epoch 1, Batch 234/240, MSE = 0.018118
# Epoch 1, Batch 235/240, MSE = 0.016817
# Epoch 1, Batch 236/240, MSE = 0.016539
# Epoch 1, Batch 237/240, MSE = 0.018077
# Epoch 1, Batch 238/240, MSE = 0.017720
# Epoch 1, Batch 239/240, MSE = 0.016541
# Epoch 1, Batch 240/240, MSE = 0.018916
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.004107
# Epoch 1, Batch 2/240, MSE = 0.004385
# Epoch 1, Batch 3/240, MSE = 0.004386
# Epoch 1, Batch 4/240, MSE = 0.004379
# Epoch 1, Batch 5/240, MSE = 0.004402
# Epoch 1, Batch 6/240, MSE = 0.004378
# Epoch 1, Batch 7/240, MSE = 0.004395
# Epoch 1, Batch 8/240, MSE = 0.004468
# Epoch 1, Batch 9/240, MSE = 0.004385
# Epoch 1, Batch 10/240, MSE = 0.004395
# Epoch 1, Batch 11/240, MSE = 0.004494
# Epoch 1, Batch 12/240, MSE = 0.004469
# Epoch 1, Batch 13/240, MSE = 0.004427
# Epoch 1, Batch 14/240, MSE = 0.004242
# Epoch 1, Batch 15/240, MSE = 0.004586
# Epoch 1, Batch 16/240, MSE = 0.004094
# Epoch 1, Batch 17/240, MSE = 0.004388
# Epoch 1, Batch 18/240, MSE = 0.004490
# Epoch 1, Batch 19/240, MSE = 0.004713
# Epoch 1, Batch 20/240, MSE = 0.004565
# Epoch 1, Batch 21/240, MSE = 0.004812
# Epoch 1, Batch 22/240, MSE = 0.004686
# Epoch 1, Batch 23/240, MSE = 0.004285
# Epoch 1, Batch 24/240, MSE = 0.004378
# Epoch 1, Batch 25/240, MSE = 0.004373
# Epoch 1, Batch 26/240, MSE = 0.004524
# Epoch 1, Batch 27/240, MSE = 0.004778
# Epoch 1, Batch 28/240, MSE = 0.004685
# Epoch 1, Batch 29/240, MSE = 0.004518
# Epoch 1, Batch 30/240, MSE = 0.004618
# Epoch 1, Batch 31/240, MSE = 0.004176
# Epoch 1, Batch 32/240, MSE = 0.004379
# Epoch 1, Batch 33/240, MSE = 0.004367
# Epoch 1, Batch 34/240, MSE = 0.004127
# Epoch 1, Batch 35/240, MSE = 0.004732
# Epoch 1, Batch 36/240, MSE = 0.004424
# Epoch 1, Batch 37/240, MSE = 0.004617
# Epoch 1, Batch 38/240, MSE = 0.004443
# Epoch 1, Batch 39/240, MSE = 0.004499
# Epoch 1, Batch 40/240, MSE = 0.004391
# Epoch 1, Batch 41/240, MSE = 0.004135
# Epoch 1, Batch 42/240, MSE = 0.004277
# Epoch 1, Batch 43/240, MSE = 0.004470
# Epoch 1, Batch 44/240, MSE = 0.004512
# Epoch 1, Batch 45/240, MSE = 0.004651
# Epoch 1, Batch 46/240, MSE = 0.004691
# Epoch 1, Batch 47/240, MSE = 0.004321
# Epoch 1, Batch 48/240, MSE = 0.004257
# Epoch 1, Batch 49/240, MSE = 0.004255
# Epoch 1, Batch 50/240, MSE = 0.004570
# Epoch 1, Batch 51/240, MSE = 0.004557
# Epoch 1, Batch 52/240, MSE = 0.004394
# Epoch 1, Batch 53/240, MSE = 0.004453
# Epoch 1, Batch 54/240, MSE = 0.004744
# Epoch 1, Batch 55/240, MSE = 0.004803
# Epoch 1, Batch 56/240, MSE = 0.004147
# Epoch 1, Batch 57/240, MSE = 0.004555
# Epoch 1, Batch 58/240, MSE = 0.004449
# Epoch 1, Batch 59/240, MSE = 0.004561
# Epoch 1, Batch 60/240, MSE = 0.004627
# Epoch 1, Batch 61/240, MSE = 0.004501
# Epoch 1, Batch 62/240, MSE = 0.004064
# Epoch 1, Batch 63/240, MSE = 0.004423
# Epoch 1, Batch 64/240, MSE = 0.004429
# Epoch 1, Batch 65/240, MSE = 0.004365
# Epoch 1, Batch 66/240, MSE = 0.004485
# Epoch 1, Batch 67/240, MSE = 0.004549
# Epoch 1, Batch 68/240, MSE = 0.004581
# Epoch 1, Batch 69/240, MSE = 0.004403
# Epoch 1, Batch 70/240, MSE = 0.004386
# Epoch 1, Batch 71/240, MSE = 0.004459
# Epoch 1, Batch 72/240, MSE = 0.004290
# Epoch 1, Batch 73/240, MSE = 0.004313
# Epoch 1, Batch 74/240, MSE = 0.004371
# Epoch 1, Batch 75/240, MSE = 0.004445
# Epoch 1, Batch 76/240, MSE = 0.004666
# Epoch 1, Batch 77/240, MSE = 0.004428
# Epoch 1, Batch 78/240, MSE = 0.004375
# Epoch 1, Batch 79/240, MSE = 0.004423
# Epoch 1, Batch 80/240, MSE = 0.004415
# Epoch 1, Batch 81/240, MSE = 0.004323
# Epoch 1, Batch 82/240, MSE = 0.004499
# Epoch 1, Batch 83/240, MSE = 0.004517
# Epoch 1, Batch 84/240, MSE = 0.004485
# Epoch 1, Batch 85/240, MSE = 0.004535
# Epoch 1, Batch 86/240, MSE = 0.004458
# Epoch 1, Batch 87/240, MSE = 0.004290
# Epoch 1, Batch 88/240, MSE = 0.004516
# Epoch 1, Batch 89/240, MSE = 0.004378
# Epoch 1, Batch 90/240, MSE = 0.004334
# Epoch 1, Batch 91/240, MSE = 0.004314
# Epoch 1, Batch 92/240, MSE = 0.004366
# Epoch 1, Batch 93/240, MSE = 0.004337
# Epoch 1, Batch 94/240, MSE = 0.004516
# Epoch 1, Batch 95/240, MSE = 0.004652
# Epoch 1, Batch 96/240, MSE = 0.004539
# Epoch 1, Batch 97/240, MSE = 0.004538
# Epoch 1, Batch 98/240, MSE = 0.004709
# Epoch 1, Batch 99/240, MSE = 0.004528
# Epoch 1, Batch 100/240, MSE = 0.004240
# Epoch 1, Batch 101/240, MSE = 0.004370
# Epoch 1, Batch 102/240, MSE = 0.004561
# Epoch 1, Batch 103/240, MSE = 0.004481
# Epoch 1, Batch 104/240, MSE = 0.004514
# Epoch 1, Batch 105/240, MSE = 0.004479
# Epoch 1, Batch 106/240, MSE = 0.004188
# Epoch 1, Batch 107/240, MSE = 0.004716
# Epoch 1, Batch 108/240, MSE = 0.004430
# Epoch 1, Batch 109/240, MSE = 0.004396
# Epoch 1, Batch 110/240, MSE = 0.004436
# Epoch 1, Batch 111/240, MSE = 0.004410
# Epoch 1, Batch 112/240, MSE = 0.004561
# Epoch 1, Batch 113/240, MSE = 0.004247
# Epoch 1, Batch 114/240, MSE = 0.004389
# Epoch 1, Batch 115/240, MSE = 0.004241
# Epoch 1, Batch 116/240, MSE = 0.004387
# Epoch 1, Batch 117/240, MSE = 0.004081
# Epoch 1, Batch 118/240, MSE = 0.004454
# Epoch 1, Batch 119/240, MSE = 0.004453
# Epoch 1, Batch 120/240, MSE = 0.004371
# Epoch 1, Batch 121/240, MSE = 0.004339
# Epoch 1, Batch 122/240, MSE = 0.004778
# Epoch 1, Batch 123/240, MSE = 0.004426
# Epoch 1, Batch 124/240, MSE = 0.004376
# Epoch 1, Batch 125/240, MSE = 0.004412
# Epoch 1, Batch 126/240, MSE = 0.004351
# Epoch 1, Batch 127/240, MSE = 0.004626
# Epoch 1, Batch 128/240, MSE = 0.004621
# Epoch 1, Batch 129/240, MSE = 0.004294
# Epoch 1, Batch 130/240, MSE = 0.004452
# Epoch 1, Batch 131/240, MSE = 0.004401
# Epoch 1, Batch 132/240, MSE = 0.004483
# Epoch 1, Batch 133/240, MSE = 0.004435
# Epoch 1, Batch 134/240, MSE = 0.004514
# Epoch 1, Batch 135/240, MSE = 0.004357
# Epoch 1, Batch 136/240, MSE = 0.004513
# Epoch 1, Batch 137/240, MSE = 0.004543
# Epoch 1, Batch 138/240, MSE = 0.004446
# Epoch 1, Batch 139/240, MSE = 0.004498
# Epoch 1, Batch 140/240, MSE = 0.004265
# Epoch 1, Batch 141/240, MSE = 0.004523
# Epoch 1, Batch 142/240, MSE = 0.004468
# Epoch 1, Batch 143/240, MSE = 0.004280
# Epoch 1, Batch 144/240, MSE = 0.004486
# Epoch 1, Batch 145/240, MSE = 0.004320
# Epoch 1, Batch 146/240, MSE = 0.004138
# Epoch 1, Batch 147/240, MSE = 0.004561
# Epoch 1, Batch 148/240, MSE = 0.004616
# Epoch 1, Batch 149/240, MSE = 0.004302
# Epoch 1, Batch 150/240, MSE = 0.004273
# Epoch 1, Batch 151/240, MSE = 0.004514
# Epoch 1, Batch 152/240, MSE = 0.004518
# Epoch 1, Batch 153/240, MSE = 0.004519
# Epoch 1, Batch 154/240, MSE = 0.004236
# Epoch 1, Batch 155/240, MSE = 0.004372
# Epoch 1, Batch 156/240, MSE = 0.004192
# Epoch 1, Batch 157/240, MSE = 0.004647
# Epoch 1, Batch 158/240, MSE = 0.004362
# Epoch 1, Batch 159/240, MSE = 0.004370
# Epoch 1, Batch 160/240, MSE = 0.004600
# Epoch 1, Batch 161/240, MSE = 0.004273
# Epoch 1, Batch 162/240, MSE = 0.004436
# Epoch 1, Batch 163/240, MSE = 0.004134
# Epoch 1, Batch 164/240, MSE = 0.004429
# Epoch 1, Batch 165/240, MSE = 0.004406
# Epoch 1, Batch 166/240, MSE = 0.004479
# Epoch 1, Batch 167/240, MSE = 0.004442
# Epoch 1, Batch 168/240, MSE = 0.004570
# Epoch 1, Batch 169/240, MSE = 0.004788
# Epoch 1, Batch 170/240, MSE = 0.004246
# Epoch 1, Batch 171/240, MSE = 0.004510
# Epoch 1, Batch 172/240, MSE = 0.004216
# Epoch 1, Batch 173/240, MSE = 0.004743
# Epoch 1, Batch 174/240, MSE = 0.004470
# Epoch 1, Batch 175/240, MSE = 0.004602
# Epoch 1, Batch 176/240, MSE = 0.004346
# Epoch 1, Batch 177/240, MSE = 0.004118
# Epoch 1, Batch 178/240, MSE = 0.004479
# Epoch 1, Batch 179/240, MSE = 0.004294
# Epoch 1, Batch 180/240, MSE = 0.004542
# Epoch 1, Batch 181/240, MSE = 0.004683
# Epoch 1, Batch 182/240, MSE = 0.004239
# Epoch 1, Batch 183/240, MSE = 0.004473
# Epoch 1, Batch 184/240, MSE = 0.004326
# Epoch 1, Batch 185/240, MSE = 0.004269
# Epoch 1, Batch 186/240, MSE = 0.004267
# Epoch 1, Batch 187/240, MSE = 0.004634
# Epoch 1, Batch 188/240, MSE = 0.004674
# Epoch 1, Batch 189/240, MSE = 0.004390
# Epoch 1, Batch 190/240, MSE = 0.004460
# Epoch 1, Batch 191/240, MSE = 0.004261
# Epoch 1, Batch 192/240, MSE = 0.004283
# Epoch 1, Batch 193/240, MSE = 0.004426
# Epoch 1, Batch 194/240, MSE = 0.004144
# Epoch 1, Batch 195/240, MSE = 0.004482
# Epoch 1, Batch 196/240, MSE = 0.004188
# Epoch 1, Batch 197/240, MSE = 0.004235
# Epoch 1, Batch 198/240, MSE = 0.004532
# Epoch 1, Batch 199/240, MSE = 0.004501
# Epoch 1, Batch 200/240, MSE = 0.004801
# Epoch 1, Batch 201/240, MSE = 0.004310
# Epoch 1, Batch 202/240, MSE = 0.004135
# Epoch 1, Batch 203/240, MSE = 0.004523
# Epoch 1, Batch 204/240, MSE = 0.004228
# Epoch 1, Batch 205/240, MSE = 0.004259
# Epoch 1, Batch 206/240, MSE = 0.004289
# Epoch 1, Batch 207/240, MSE = 0.004509
# Epoch 1, Batch 208/240, MSE = 0.004341
# Epoch 1, Batch 209/240, MSE = 0.004282
# Epoch 1, Batch 210/240, MSE = 0.004761
# Epoch 1, Batch 211/240, MSE = 0.004367
# Epoch 1, Batch 212/240, MSE = 0.004451
# Epoch 1, Batch 213/240, MSE = 0.004388
# Epoch 1, Batch 214/240, MSE = 0.004347
# Epoch 1, Batch 215/240, MSE = 0.004231
# Epoch 1, Batch 216/240, MSE = 0.004295
# Epoch 1, Batch 217/240, MSE = 0.004695
# Epoch 1, Batch 218/240, MSE = 0.004298
# Epoch 1, Batch 219/240, MSE = 0.004306
# Epoch 1, Batch 220/240, MSE = 0.004555
# Epoch 1, Batch 221/240, MSE = 0.004484
# Epoch 1, Batch 222/240, MSE = 0.004405
# Epoch 1, Batch 223/240, MSE = 0.004575
# Epoch 1, Batch 224/240, MSE = 0.004299
# Epoch 1, Batch 225/240, MSE = 0.004452
# Epoch 1, Batch 226/240, MSE = 0.004524
# Epoch 1, Batch 227/240, MSE = 0.004466
# Epoch 1, Batch 228/240, MSE = 0.004319
# Epoch 1, Batch 229/240, MSE = 0.004566
# Epoch 1, Batch 230/240, MSE = 0.004243
# Epoch 1, Batch 231/240, MSE = 0.004434
# Epoch 1, Batch 232/240, MSE = 0.004498
# Epoch 1, Batch 233/240, MSE = 0.004578
# Epoch 1, Batch 234/240, MSE = 0.004577
# Epoch 1, Batch 235/240, MSE = 0.004234
# Epoch 1, Batch 236/240, MSE = 0.004013
# Epoch 1, Batch 237/240, MSE = 0.004522
# Epoch 1, Batch 238/240, MSE = 0.004495
# Epoch 1, Batch 239/240, MSE = 0.004725
# Epoch 1, Batch 240/240, MSE = 0.004270
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.000178
# Epoch 1, Batch 2/240, MSE = 0.000192
# Epoch 1, Batch 3/240, MSE = 0.000201
# Epoch 1, Batch 4/240, MSE = 0.000196
# Epoch 1, Batch 5/240, MSE = 0.000185
# Epoch 1, Batch 6/240, MSE = 0.000203
# Epoch 1, Batch 7/240, MSE = 0.000189
# Epoch 1, Batch 8/240, MSE = 0.000198
# Epoch 1, Batch 9/240, MSE = 0.000187
# Epoch 1, Batch 10/240, MSE = 0.000200
# Epoch 1, Batch 11/240, MSE = 0.000184
# Epoch 1, Batch 12/240, MSE = 0.000194
# Epoch 1, Batch 13/240, MSE = 0.000191
# Epoch 1, Batch 14/240, MSE = 0.000190
# Epoch 1, Batch 15/240, MSE = 0.000188
# Epoch 1, Batch 16/240, MSE = 0.000192
# Epoch 1, Batch 17/240, MSE = 0.000193
# Epoch 1, Batch 18/240, MSE = 0.000205
# Epoch 1, Batch 19/240, MSE = 0.000181
# Epoch 1, Batch 20/240, MSE = 0.000198
# ...
# Epoch 1, Batch 69/240, MSE = 0.014611
# Epoch 1, Batch 70/240, MSE = 0.015300
# Epoch 1, Batch 71/240, MSE = 0.013993
# Epoch 1, Batch 72/240, MSE = 0.016445
# Epoch 1, Batch 73/240, MSE = 0.015498
# Epoch 1, Batch 74/240, MSE = 0.014960
# Epoch 1, Batch 75/240, MSE = 0.016269
# Epoch 1, Batch 76/240, MSE = 0.015056
# Epoch 1, Batch 77/240, MSE = 0.013159
# Epoch 1, Batch 78/240, MSE = 0.014496
# Epoch 1, Batch 79/240, MSE = 0.014029
# Epoch 1, Batch 80/240, MSE = 0.014742
# Epoch 1, Batch 81/240, MSE = 0.014603
# Epoch 1, Batch 82/240, MSE = 0.014022
# Epoch 1, Batch 83/240, MSE = 0.014794
# Epoch 1, Batch 84/240, MSE = 0.013458
# Epoch 1, Batch 85/240, MSE = 0.014965
# Epoch 1, Batch 86/240, MSE = 0.014541
# Epoch 1, Batch 87/240, MSE = 0.014882
# Epoch 1, Batch 88/240, MSE = 0.015011
# Epoch 1, Batch 89/240, MSE = 0.015197
# Epoch 1, Batch 90/240, MSE = 0.014919
# Epoch 1, Batch 91/240, MSE = 0.014981
# Epoch 1, Batch 92/240, MSE = 0.015436
# Epoch 1, Batch 93/240, MSE = 0.015849
# Epoch 1, Batch 94/240, MSE = 0.014126
# Epoch 1, Batch 95/240, MSE = 0.014704
# Epoch 1, Batch 96/240, MSE = 0.014979
# Epoch 1, Batch 97/240, MSE = 0.014867
# Epoch 1, Batch 98/240, MSE = 0.014155
# Epoch 1, Batch 99/240, MSE = 0.013887
# Epoch 1, Batch 100/240, MSE = 0.014963
# Epoch 1, Batch 101/240, MSE = 0.014911
# Epoch 1, Batch 102/240, MSE = 0.015377
# Epoch 1, Batch 103/240, MSE = 0.014694
# Epoch 1, Batch 104/240, MSE = 0.014840
# Epoch 1, Batch 105/240, MSE = 0.014908
# Epoch 1, Batch 106/240, MSE = 0.014843
# Epoch 1, Batch 107/240, MSE = 0.014883
# Epoch 1, Batch 108/240, MSE = 0.014193
# Epoch 1, Batch 109/240, MSE = 0.015489
# Epoch 1, Batch 110/240, MSE = 0.013939
# Epoch 1, Batch 111/240, MSE = 0.013188
# Epoch 1, Batch 112/240, MSE = 0.014626
# Epoch 1, Batch 113/240, MSE = 0.014138
# Epoch 1, Batch 114/240, MSE = 0.014744
# Epoch 1, Batch 115/240, MSE = 0.015328
# Epoch 1, Batch 116/240, MSE = 0.014321
# Epoch 1, Batch 117/240, MSE = 0.015006
# Epoch 1, Batch 118/240, MSE = 0.014771
# Epoch 1, Batch 119/240, MSE = 0.014146
# Epoch 1, Batch 120/240, MSE = 0.013819
# Epoch 1, Batch 121/240, MSE = 0.014975
# Epoch 1, Batch 122/240, MSE = 0.015753
# Epoch 1, Batch 123/240, MSE = 0.015476
# Epoch 1, Batch 124/240, MSE = 0.015833
# Epoch 1, Batch 125/240, MSE = 0.014591
# Epoch 1, Batch 126/240, MSE = 0.015716
# Epoch 1, Batch 127/240, MSE = 0.014433
# Epoch 1, Batch 128/240, MSE = 0.014292
# Epoch 1, Batch 129/240, MSE = 0.015497
# Epoch 1, Batch 130/240, MSE = 0.015141
# Epoch 1, Batch 131/240, MSE = 0.015055
# Epoch 1, Batch 132/240, MSE = 0.013892
# Epoch 1, Batch 133/240, MSE = 0.013575
# Epoch 1, Batch 134/240, MSE = 0.015012
# Epoch 1, Batch 135/240, MSE = 0.015484
# Epoch 1, Batch 136/240, MSE = 0.014108
# Epoch 1, Batch 137/240, MSE = 0.015661
# Epoch 1, Batch 138/240, MSE = 0.014962
# Epoch 1, Batch 139/240, MSE = 0.014217
# Epoch 1, Batch 140/240, MSE = 0.015517
# Epoch 1, Batch 141/240, MSE = 0.014637
# Epoch 1, Batch 142/240, MSE = 0.014426
# Epoch 1, Batch 143/240, MSE = 0.014378
# Epoch 1, Batch 144/240, MSE = 0.015062
# Epoch 1, Batch 145/240, MSE = 0.014740
# Epoch 1, Batch 146/240, MSE = 0.014374
# Epoch 1, Batch 147/240, MSE = 0.014006
# Epoch 1, Batch 148/240, MSE = 0.013874
# Epoch 1, Batch 149/240, MSE = 0.015433
# Epoch 1, Batch 150/240, MSE = 0.015592
# Epoch 1, Batch 151/240, MSE = 0.015035
# Epoch 1, Batch 152/240, MSE = 0.015055
# Epoch 1, Batch 153/240, MSE = 0.014872
# Epoch 1, Batch 154/240, MSE = 0.015040
# Epoch 1, Batch 155/240, MSE = 0.015281
# Epoch 1, Batch 156/240, MSE = 0.014811
# Epoch 1, Batch 157/240, MSE = 0.014300
# Epoch 1, Batch 158/240, MSE = 0.013979
# Epoch 1, Batch 159/240, MSE = 0.014687
# Epoch 1, Batch 160/240, MSE = 0.014063
# Epoch 1, Batch 161/240, MSE = 0.014732
# Epoch 1, Batch 162/240, MSE = 0.013786
# Epoch 1, Batch 163/240, MSE = 0.014870
# Epoch 1, Batch 164/240, MSE = 0.013965
# Epoch 1, Batch 165/240, MSE = 0.015468
# Epoch 1, Batch 166/240, MSE = 0.015426
# Epoch 1, Batch 167/240, MSE = 0.014367
# Epoch 1, Batch 168/240, MSE = 0.014287
# Epoch 1, Batch 169/240, MSE = 0.014674
# Epoch 1, Batch 170/240, MSE = 0.014485
# Epoch 1, Batch 171/240, MSE = 0.014115
# Epoch 1, Batch 172/240, MSE = 0.014688
# Epoch 1, Batch 173/240, MSE = 0.015154
# Epoch 1, Batch 174/240, MSE = 0.014482
# Epoch 1, Batch 175/240, MSE = 0.013497
# Epoch 1, Batch 176/240, MSE = 0.014706
# Epoch 1, Batch 177/240, MSE = 0.015721
# Epoch 1, Batch 178/240, MSE = 0.014337
# Epoch 1, Batch 179/240, MSE = 0.014767
# Epoch 1, Batch 180/240, MSE = 0.014475
# Epoch 1, Batch 181/240, MSE = 0.014639
# Epoch 1, Batch 182/240, MSE = 0.013771
# Epoch 1, Batch 183/240, MSE = 0.015490
# Epoch 1, Batch 184/240, MSE = 0.014343
# Epoch 1, Batch 185/240, MSE = 0.013507
# Epoch 1, Batch 186/240, MSE = 0.013986
# Epoch 1, Batch 187/240, MSE = 0.013996
# Epoch 1, Batch 188/240, MSE = 0.014597
# Epoch 1, Batch 189/240, MSE = 0.014922
# Epoch 1, Batch 190/240, MSE = 0.014281
# Epoch 1, Batch 191/240, MSE = 0.013986
# Epoch 1, Batch 192/240, MSE = 0.015344
# Epoch 1, Batch 193/240, MSE = 0.014006
# Epoch 1, Batch 194/240, MSE = 0.014761
# Epoch 1, Batch 195/240, MSE = 0.014434
# Epoch 1, Batch 196/240, MSE = 0.014535
# Epoch 1, Batch 197/240, MSE = 0.015011
# Epoch 1, Batch 198/240, MSE = 0.013476
# Epoch 1, Batch 199/240, MSE = 0.014560
# Epoch 1, Batch 200/240, MSE = 0.014263
# Epoch 1, Batch 201/240, MSE = 0.014327
# Epoch 1, Batch 202/240, MSE = 0.014311
# Epoch 1, Batch 203/240, MSE = 0.014793
# Epoch 1, Batch 204/240, MSE = 0.013813
# Epoch 1, Batch 205/240, MSE = 0.012185
# Epoch 1, Batch 206/240, MSE = 0.014863
# Epoch 1, Batch 207/240, MSE = 0.014197
# Epoch 1, Batch 208/240, MSE = 0.014497
# Epoch 1, Batch 209/240, MSE = 0.014742
# Epoch 1, Batch 210/240, MSE = 0.014342
# Epoch 1, Batch 211/240, MSE = 0.015075
# Epoch 1, Batch 212/240, MSE = 0.014632
# Epoch 1, Batch 213/240, MSE = 0.013326
# Epoch 1, Batch 214/240, MSE = 0.015039
# Epoch 1, Batch 215/240, MSE = 0.013477
# Epoch 1, Batch 216/240, MSE = 0.013549
# Epoch 1, Batch 217/240, MSE = 0.014369
# Epoch 1, Batch 218/240, MSE = 0.014036
# Epoch 1, Batch 219/240, MSE = 0.013423
# Epoch 1, Batch 220/240, MSE = 0.013900
# Epoch 1, Batch 221/240, MSE = 0.014877
# Epoch 1, Batch 222/240, MSE = 0.014540
# Epoch 1, Batch 223/240, MSE = 0.014602
# Epoch 1, Batch 224/240, MSE = 0.014354
# Epoch 1, Batch 225/240, MSE = 0.014558
# Epoch 1, Batch 226/240, MSE = 0.013930
# Epoch 1, Batch 227/240, MSE = 0.014408
# Epoch 1, Batch 228/240, MSE = 0.014939
# Epoch 1, Batch 229/240, MSE = 0.014395
# Epoch 1, Batch 230/240, MSE = 0.013732
# Epoch 1, Batch 231/240, MSE = 0.015174
# Epoch 1, Batch 232/240, MSE = 0.013603
# Epoch 1, Batch 233/240, MSE = 0.013907
# Epoch 1, Batch 234/240, MSE = 0.015097
# Epoch 1, Batch 235/240, MSE = 0.016518
# Epoch 1, Batch 236/240, MSE = 0.014829
# Epoch 1, Batch 237/240, MSE = 0.015033
# Epoch 1, Batch 238/240, MSE = 0.014985
# Epoch 1, Batch 239/240, MSE = 0.014471
# Epoch 1, Batch 240/240, MSE = 0.015091
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.022821
# Epoch 1, Batch 2/240, MSE = 0.023561
# Epoch 1, Batch 3/240, MSE = 0.025030
# Epoch 1, Batch 4/240, MSE = 0.024017
# Epoch 1, Batch 5/240, MSE = 0.026667
# Epoch 1, Batch 6/240, MSE = 0.024228
# Epoch 1, Batch 7/240, MSE = 0.024626
# Epoch 1, Batch 8/240, MSE = 0.022550
# Epoch 1, Batch 9/240, MSE = 0.023558
# Epoch 1, Batch 10/240, MSE = 0.023506
# Epoch 1, Batch 11/240, MSE = 0.024747
# Epoch 1, Batch 12/240, MSE = 0.025721
# Epoch 1, Batch 13/240, MSE = 0.025665
# Epoch 1, Batch 14/240, MSE = 0.022896
# Epoch 1, Batch 15/240, MSE = 0.024645
# Epoch 1, Batch 16/240, MSE = 0.023688
# Epoch 1, Batch 17/240, MSE = 0.024422
# Epoch 1, Batch 18/240, MSE = 0.023061
# Epoch 1, Batch 19/240, MSE = 0.024633
# Epoch 1, Batch 20/240, MSE = 0.023631
# Epoch 1, Batch 21/240, MSE = 0.024270
# Epoch 1, Batch 22/240, MSE = 0.025363
# Epoch 1, Batch 23/240, MSE = 0.023542
# Epoch 1, Batch 24/240, MSE = 0.025288
# Epoch 1, Batch 25/240, MSE = 0.026344
# Epoch 1, Batch 26/240, MSE = 0.025335
# Epoch 1, Batch 27/240, MSE = 0.025021
# Epoch 1, Batch 28/240, MSE = 0.024148
# Epoch 1, Batch 29/240, MSE = 0.023400
# Epoch 1, Batch 30/240, MSE = 0.025246
# Epoch 1, Batch 31/240, MSE = 0.025084
# Epoch 1, Batch 32/240, MSE = 0.024380
# Epoch 1, Batch 33/240, MSE = 0.024179
# Epoch 1, Batch 34/240, MSE = 0.023054
# Epoch 1, Batch 35/240, MSE = 0.024297
# Epoch 1, Batch 36/240, MSE = 0.023440
# Epoch 1, Batch 37/240, MSE = 0.025329
# Epoch 1, Batch 38/240, MSE = 0.023890
# Epoch 1, Batch 39/240, MSE = 0.025615
# Epoch 1, Batch 40/240, MSE = 0.024732
# Epoch 1, Batch 41/240, MSE = 0.023194
# Epoch 1, Batch 42/240, MSE = 0.024528
# Epoch 1, Batch 43/240, MSE = 0.024320
# Epoch 1, Batch 44/240, MSE = 0.026083
# Epoch 1, Batch 45/240, MSE = 0.023300
# Epoch 1, Batch 46/240, MSE = 0.024605
# Epoch 1, Batch 47/240, MSE = 0.024771
# Epoch 1, Batch 48/240, MSE = 0.023674
# Epoch 1, Batch 49/240, MSE = 0.025629
# Epoch 1, Batch 50/240, MSE = 0.025469
# Epoch 1, Batch 51/240, MSE = 0.024067
# Epoch 1, Batch 52/240, MSE = 0.024875
# Epoch 1, Batch 53/240, MSE = 0.023620
# Epoch 1, Batch 54/240, MSE = 0.024596
# Epoch 1, Batch 55/240, MSE = 0.025765
# Epoch 1, Batch 56/240, MSE = 0.024447
# Epoch 1, Batch 57/240, MSE = 0.025190
# Epoch 1, Batch 58/240, MSE = 0.022792
# Epoch 1, Batch 59/240, MSE = 0.023097
# Epoch 1, Batch 60/240, MSE = 0.024542
# Epoch 1, Batch 61/240, MSE = 0.023672
# Epoch 1, Batch 62/240, MSE = 0.024702
# Epoch 1, Batch 63/240, MSE = 0.023477
# Epoch 1, Batch 64/240, MSE = 0.023869
# Epoch 1, Batch 65/240, MSE = 0.025025
# Epoch 1, Batch 66/240, MSE = 0.024580
# Epoch 1, Batch 67/240, MSE = 0.022094
# Epoch 1, Batch 68/240, MSE = 0.025133
# Epoch 1, Batch 69/240, MSE = 0.024052
# Epoch 1, Batch 70/240, MSE = 0.022915
# Epoch 1, Batch 71/240, MSE = 0.022653
# Epoch 1, Batch 72/240, MSE = 0.023864
# Epoch 1, Batch 73/240, MSE = 0.024791
# Epoch 1, Batch 74/240, MSE = 0.024640
# Epoch 1, Batch 75/240, MSE = 0.025938
# Epoch 1, Batch 76/240, MSE = 0.024588
# Epoch 1, Batch 77/240, MSE = 0.024948
# Epoch 1, Batch 78/240, MSE = 0.025354
# Epoch 1, Batch 79/240, MSE = 0.022875
# Epoch 1, Batch 80/240, MSE = 0.022826
# Epoch 1, Batch 81/240, MSE = 0.022882
# Epoch 1, Batch 82/240, MSE = 0.023167
# Epoch 1, Batch 83/240, MSE = 0.023612
# Epoch 1, Batch 84/240, MSE = 0.025330
# Epoch 1, Batch 85/240, MSE = 0.022995
# Epoch 1, Batch 86/240, MSE = 0.023252
# Epoch 1, Batch 87/240, MSE = 0.025360
# Epoch 1, Batch 88/240, MSE = 0.023759
# Epoch 1, Batch 89/240, MSE = 0.023709
# Epoch 1, Batch 90/240, MSE = 0.025473
# Epoch 1, Batch 91/240, MSE = 0.024052
# Epoch 1, Batch 92/240, MSE = 0.023041
# Epoch 1, Batch 93/240, MSE = 0.022666
# Epoch 1, Batch 94/240, MSE = 0.024832
# Epoch 1, Batch 95/240, MSE = 0.025923
# Epoch 1, Batch 96/240, MSE = 0.025135
# Epoch 1, Batch 97/240, MSE = 0.024614
# Epoch 1, Batch 98/240, MSE = 0.024660
# Epoch 1, Batch 99/240, MSE = 0.024455
# Epoch 1, Batch 100/240, MSE = 0.024006
# Epoch 1, Batch 101/240, MSE = 0.024840
# Epoch 1, Batch 102/240, MSE = 0.023634
# Epoch 1, Batch 103/240, MSE = 0.024536
# Epoch 1, Batch 104/240, MSE = 0.024128
# Epoch 1, Batch 105/240, MSE = 0.022718
# Epoch 1, Batch 106/240, MSE = 0.024027
# Epoch 1, Batch 107/240, MSE = 0.024008
# Epoch 1, Batch 108/240, MSE = 0.023392
# Epoch 1, Batch 109/240, MSE = 0.023917
# Epoch 1, Batch 110/240, MSE = 0.025592
# Epoch 1, Batch 111/240, MSE = 0.026156
# Epoch 1, Batch 112/240, MSE = 0.024042
# Epoch 1, Batch 113/240, MSE = 0.022571
# Epoch 1, Batch 114/240, MSE = 0.022876
# Epoch 1, Batch 115/240, MSE = 0.025838
# Epoch 1, Batch 116/240, MSE = 0.023910
# Epoch 1, Batch 117/240, MSE = 0.023718
# Epoch 1, Batch 118/240, MSE = 0.024404
# Epoch 1, Batch 119/240, MSE = 0.024678
# Epoch 1, Batch 120/240, MSE = 0.022177
# Epoch 1, Batch 121/240, MSE = 0.025835
# Epoch 1, Batch 122/240, MSE = 0.024000
# Epoch 1, Batch 123/240, MSE = 0.023558
# Epoch 1, Batch 124/240, MSE = 0.023326
# Epoch 1, Batch 125/240, MSE = 0.024166
# Epoch 1, Batch 126/240, MSE = 0.023079
# Epoch 1, Batch 127/240, MSE = 0.025031
# Epoch 1, Batch 128/240, MSE = 0.024508
# Epoch 1, Batch 129/240, MSE = 0.024584
# Epoch 1, Batch 130/240, MSE = 0.023486
# Epoch 1, Batch 131/240, MSE = 0.023828
# Epoch 1, Batch 132/240, MSE = 0.024413
# Epoch 1, Batch 133/240, MSE = 0.022741
# Epoch 1, Batch 134/240, MSE = 0.023133
# Epoch 1, Batch 135/240, MSE = 0.022266
# Epoch 1, Batch 136/240, MSE = 0.023609
# Epoch 1, Batch 137/240, MSE = 0.022710
# Epoch 1, Batch 138/240, MSE = 0.024239
# Epoch 1, Batch 139/240, MSE = 0.025145
# Epoch 1, Batch 140/240, MSE = 0.024194
# Epoch 1, Batch 141/240, MSE = 0.024786
# Epoch 1, Batch 142/240, MSE = 0.023131
# Epoch 1, Batch 143/240, MSE = 0.024960
# Epoch 1, Batch 144/240, MSE = 0.022633
# Epoch 1, Batch 145/240, MSE = 0.024158
# Epoch 1, Batch 146/240, MSE = 0.024748
# Epoch 1, Batch 147/240, MSE = 0.024433
# Epoch 1, Batch 148/240, MSE = 0.021852
# Epoch 1, Batch 149/240, MSE = 0.022925
# Epoch 1, Batch 150/240, MSE = 0.024690
# Epoch 1, Batch 151/240, MSE = 0.024731
# Epoch 1, Batch 152/240, MSE = 0.024346
# Epoch 1, Batch 153/240, MSE = 0.023758
# Epoch 1, Batch 154/240, MSE = 0.022098
# Epoch 1, Batch 155/240, MSE = 0.024334
# Epoch 1, Batch 156/240, MSE = 0.024641
# Epoch 1, Batch 157/240, MSE = 0.023482
# Epoch 1, Batch 158/240, MSE = 0.024321
# Epoch 1, Batch 159/240, MSE = 0.022776
# Epoch 1, Batch 160/240, MSE = 0.023324
# Epoch 1, Batch 161/240, MSE = 0.024067
# Epoch 1, Batch 162/240, MSE = 0.023198
# Epoch 1, Batch 163/240, MSE = 0.024252
# Epoch 1, Batch 164/240, MSE = 0.023239
# Epoch 1, Batch 165/240, MSE = 0.025695
# Epoch 1, Batch 166/240, MSE = 0.022840
# Epoch 1, Batch 167/240, MSE = 0.023070
# Epoch 1, Batch 168/240, MSE = 0.023336
# Epoch 1, Batch 169/240, MSE = 0.022600
# Epoch 1, Batch 170/240, MSE = 0.025362
# Epoch 1, Batch 171/240, MSE = 0.023950
# Epoch 1, Batch 172/240, MSE = 0.026064
# Epoch 1, Batch 173/240, MSE = 0.023903
# Epoch 1, Batch 174/240, MSE = 0.023776
# Epoch 1, Batch 175/240, MSE = 0.023179
# Epoch 1, Batch 176/240, MSE = 0.023409
# Epoch 1, Batch 177/240, MSE = 0.022753
# Epoch 1, Batch 178/240, MSE = 0.024152
# Epoch 1, Batch 179/240, MSE = 0.023317
# Epoch 1, Batch 180/240, MSE = 0.025016
# Epoch 1, Batch 181/240, MSE = 0.024600
# Epoch 1, Batch 182/240, MSE = 0.024990
# Epoch 1, Batch 183/240, MSE = 0.022637
# Epoch 1, Batch 184/240, MSE = 0.022631
# Epoch 1, Batch 185/240, MSE = 0.024584
# Epoch 1, Batch 186/240, MSE = 0.022880
# Epoch 1, Batch 187/240, MSE = 0.024507
# Epoch 1, Batch 188/240, MSE = 0.023860
# Epoch 1, Batch 189/240, MSE = 0.023780
# Epoch 1, Batch 190/240, MSE = 0.024562
# Epoch 1, Batch 191/240, MSE = 0.023110
# Epoch 1, Batch 192/240, MSE = 0.023621
# Epoch 1, Batch 193/240, MSE = 0.023829
# Epoch 1, Batch 194/240, MSE = 0.025060
# Epoch 1, Batch 195/240, MSE = 0.024162
# Epoch 1, Batch 196/240, MSE = 0.022637
# Epoch 1, Batch 197/240, MSE = 0.024163
# Epoch 1, Batch 198/240, MSE = 0.023932
# Epoch 1, Batch 199/240, MSE = 0.023250
# Epoch 1, Batch 200/240, MSE = 0.022345
# Epoch 1, Batch 201/240, MSE = 0.023196
# Epoch 1, Batch 202/240, MSE = 0.022849
# Epoch 1, Batch 203/240, MSE = 0.023100
# Epoch 1, Batch 204/240, MSE = 0.024849
# Epoch 1, Batch 205/240, MSE = 0.023002
# Epoch 1, Batch 206/240, MSE = 0.022526
# Epoch 1, Batch 207/240, MSE = 0.024349
# Epoch 1, Batch 208/240, MSE = 0.025169
# Epoch 1, Batch 209/240, MSE = 0.023904
# Epoch 1, Batch 210/240, MSE = 0.023663
# Epoch 1, Batch 211/240, MSE = 0.022126
# Epoch 1, Batch 212/240, MSE = 0.023539
# Epoch 1, Batch 213/240, MSE = 0.023129
# Epoch 1, Batch 214/240, MSE = 0.024767
# Epoch 1, Batch 215/240, MSE = 0.023417
# Epoch 1, Batch 216/240, MSE = 0.023415
# Epoch 1, Batch 217/240, MSE = 0.021041
# Epoch 1, Batch 218/240, MSE = 0.023811
# Epoch 1, Batch 219/240, MSE = 0.024216
# Epoch 1, Batch 220/240, MSE = 0.023290
# Epoch 1, Batch 221/240, MSE = 0.022306
# Epoch 1, Batch 222/240, MSE = 0.023712
# Epoch 1, Batch 223/240, MSE = 0.022249
# Epoch 1, Batch 224/240, MSE = 0.021928
# Epoch 1, Batch 225/240, MSE = 0.022074
# Epoch 1, Batch 226/240, MSE = 0.023231
# Epoch 1, Batch 227/240, MSE = 0.023997
# Epoch 1, Batch 228/240, MSE = 0.024421
# Epoch 1, Batch 229/240, MSE = 0.023759
# Epoch 1, Batch 230/240, MSE = 0.023803
# Epoch 1, Batch 231/240, MSE = 0.022183
# Epoch 1, Batch 232/240, MSE = 0.023558
# Epoch 1, Batch 233/240, MSE = 0.022799
# Epoch 1, Batch 234/240, MSE = 0.022006
# Epoch 1, Batch 235/240, MSE = 0.024096
# Epoch 1, Batch 236/240, MSE = 0.022380
# Epoch 1, Batch 237/240, MSE = 0.024122
# Epoch 1, Batch 238/240, MSE = 0.023479
# Epoch 1, Batch 239/240, MSE = 0.022405
# Epoch 1, Batch 240/240, MSE = 0.022889
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -10    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# 8. 길이 맞추기
target_len = len(clean_iq)
if len(iq_reconstructed) != target_len:
    iq_reconstructed = resample(iq_reconstructed, target_len)

print(f"✅ IQ signal resampled: {iq_reconstructed.shape}")

# 🔧 길이 보정: Resample (Zero-padding 대신!)
from scipy.signal import resample
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (2048)
if len(iq_reconstructed) != target_len:
    original_len = len(iq_reconstructed)
    iq_reconstructed = resample(iq_reconstructed, target_len)
    print(f"   🔧 Resampled: {original_len} → {target_len} samples (Sinc interpolation)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")

print(f"   Energy before scaling: |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

# 8. 에너지 정규화 (Energy Normalization) ⭐
# iSTFT 후 신호 에너지가 손실되므로, 원본 noisy IQ의 에너지에 맞춰 복원
energy_noisy = np.sqrt(np.mean(np.abs(noisy_iq)**2))
energy_reconstructed = np.sqrt(np.mean(np.abs(iq_reconstructed)**2))

if energy_reconstructed > 1e-10:  # 0으로 나누기 방지
    scale_factor = energy_noisy / energy_reconstructed
    iq_reconstructed = iq_reconstructed * scale_factor
    print(f"   Energy scaling: {energy_noisy:.6f} / {energy_reconstructed:.6f} = {scale_factor:.2f}x")
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")
else:
    print(f"   ⚠️  Warning: Reconstructed signal energy too low, no scaling applied")

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -10 dB
#
# === Normalization Parameters ===
# Real: min=-1.093120, max=1.107376, range=2.200496
# Imag: min=-0.965663, max=1.052607, range=2.018270
# Restored norm: real_min=0.1698, real_max=0.8771
# Restored norm: imag_min=0.2194, imag_max=0.7845
# After denorm:  real_min=-0.719469, real_max=0.837027
# After denorm:  imag_min=-0.522906, imag_max=0.617665
# ✅ IQ signal reconstructed: (2048,)
# ✅ IQ signal resampled: (2048,)
#    ✅ Length already matches: 2048 samples
#    Energy before scaling: |mean|=1.032874, |max|=126.555911
#    Energy scaling: 3.251312 / 3.279798 = 0.99x
#    Energy after scaling:  |mean|=1.023903, |max|=125.456750
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.4877
# Restored flat: min=0.1698, max=0.8771, mean=0.4875
# Difference:    MSE=0.013517
# /tmp/ipykernel_155955/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0000, max=0.0140
# Zxx_restored (magnitude): min=0.0069, max=0.9369
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, "clean", sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, "noisy", sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, "restored", sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3 successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3 failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=2.8821, |max|=9.6186
# Reconstructed:   len=2048, |mean|=1.0239, |max|=125.4568
#
# MSE Comparison:
# Clean vs Noisy:        9.738976
# Clean vs Reconstructed: 10.861533
# Noisy vs Reconstructed: 19.621638
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 1880.00
# ⚠️  Noisy signal (len=2048)    → Code: 42, Peak: 1737.28
# 🔧 Restored (len=2048)   → Code: 42, Peak: 734.86
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       42 ✅ CORRECT
# Restored Decoded:    42 ✅ CORRECT
# ============================================================
#
# Peak Comparison:
# Clean Peak:    1880.00
# Noisy Peak:    1737.28 (92.4% of clean)
# Restored Peak: 734.86 (39.1% of clean)
#
# ✅ SUCCESS: BAMv3 successfully restored the correct symbol!

# %%
########################################
##  8. 정량적 성능 평가 (다중 샘플)  ##
########################################

def match_length(x, target_len):
    """앞쪽은 건드리지 말고, 뒤쪽만 잘라내거나 패딩해서 길이 맞춤"""
    cur_len = len(x)
    if cur_len > target_len:
        # 뒤에서 자르기
        return x[:target_len]
    elif cur_len < target_len:
        pad_len = target_len - cur_len
        # 뒤쪽에만 패딩 (0 또는 edge 중 취향)
        return np.pad(x, (0, pad_len), mode='edge')
        # 또는: return np.pad(x, (0, pad_len), mode='constant', constant_values=0)
    else:
        return x

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)")
print("="*70)

# 테스트 파라미터
NUM_TEST_SAMPLES = 100  # 테스트할 샘플 수 (각 SNR별)
TEST_SNR_LEVELS = [-25, -20, -15, -10, -5]  # 다양한 SNR 레벨

# 결과 저장용 딕셔너리
results = {
    snr: {
        # BAM 경로
        'bam_correct': 0,
        'bam_total': 0,
        'bam_mse': [],
        'bam_peak_ratio': [],

        # Baseline 경로 (noisy → dechirp+FFT)
        'base_correct': 0,
        'base_total': 0,
        'base_peak_ratio': [],
    }
    for snr in TEST_SNR_LEVELS
}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        # 랜덤 심볼 선택
        test_sym = np.random.randint(0, 512)
        
        # 1. 클린 IQ
        clean_iq_test = X_clean_iq[test_sym]
        
        # 2. 노이즈 추가
        noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
        
        # 3. Complex 스펙트로그램 생성 (noisy → BAM 입력)
        noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
        
        # 4. BAMv3 복원 (compress -> decompress)
        compressed = model.compress(noisy_flat.reshape(1, -1))
        restored_flat = model.decompress(compressed).flatten()
        
        # 5. IQ 신호 재구성 (BAM 경로)
        iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)

        target_len = len(clean_iq_test)
        iq_restored = match_length(iq_restored, target_len)
        
        # 6. Dechirp 및 심볼 추정
        try:
            # 기준: 클린 신호 (peak scale 기준용)
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, "clean", sf, fs, bw)
            
            # Baseline: noisy 신호 직접 디코딩
            code_base, peak_base = estimate_symbol_custom(noisy_iq_test, "noisy", sf, fs, bw)
            
            # BAM 경로: 복원된 IQ로 디코딩
            code_bam, peak_bam = estimate_symbol_custom(iq_restored, "restored", sf, fs, bw)
            
            # -----------------------------
            # Baseline 정확도 기록
            # -----------------------------
            if code_base == test_sym:
                results[snr]['base_correct'] += 1
            results[snr]['base_total'] += 1
            
            # -----------------------------
            # BAM 정확도 기록
            # -----------------------------
            if code_bam == test_sym:
                results[snr]['bam_correct'] += 1
            results[snr]['bam_total'] += 1
            
            # -----------------------------
            # Peak Ratio 기록 (clean 대비)
            # -----------------------------
            if peak_clean > 0:
                results[snr]['base_peak_ratio'].append(peak_base / peak_clean)
                results[snr]['bam_peak_ratio'].append(peak_bam / peak_clean)
            
            # -----------------------------
            # BAM 복원 IQ 기준 MSE (clean vs restored)
            # -----------------------------
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['bam_mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            # baseline/bam 둘 다 total 증가
            results[snr]['base_total'] += 1
            results[snr]['bam_total'] += 1
    
    # 중간 결과 출력
    base_acc = (results[snr]['base_correct'] / results[snr]['base_total'] * 100
                if results[snr]['base_total'] > 0 else 0.0)
    bam_acc = (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
               if results[snr]['bam_total'] > 0 else 0.0)
    
    avg_mse = np.mean(results[snr]['bam_mse']) if results[snr]['bam_mse'] else 0
    avg_base_peak = (np.mean(results[snr]['base_peak_ratio']) * 100
                     if results[snr]['base_peak_ratio'] else 0)
    avg_bam_peak = (np.mean(results[snr]['bam_peak_ratio']) * 100
                    if results[snr]['bam_peak_ratio'] else 0)
    
    print(f"  ✓ Baseline Accuracy (noisy→FFT): {base_acc:.1f}%")
    print(f"  ✓ BAM Accuracy      (restored): {bam_acc:.1f}%")
    print(f"  ✓ BAM Avg MSE (clean vs restored IQ): {avg_mse:.6f}")
    print(f"  ✓ Peak Ratio (Baseline/BAM vs Clean): {avg_base_peak:.1f}% / {avg_bam_peak:.1f}%")

# 최종 결과 요약
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY (Baseline vs BAM)")
print("="*70)

print(f"\n{'SNR (dB)':<8} {'Base Acc':<12} {'BAM Acc':<12} {'BAM MSE':<14} {'Base Peak%':<12} {'BAM Peak%':<12}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    base_acc = (results[snr]['base_correct'] / results[snr]['base_total'] * 100
                if results[snr]['base_total'] > 0 else 0.0)
    bam_acc = (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
               if results[snr]['bam_total'] > 0 else 0.0)
    avg_mse = np.mean(results[snr]['bam_mse']) if results[snr]['bam_mse'] else 0.0
    avg_base_peak = (np.mean(results[snr]['base_peak_ratio']) * 100
                     if results[snr]['base_peak_ratio'] else 0.0)
    avg_bam_peak = (np.mean(results[snr]['bam_peak_ratio']) * 100
                    if results[snr]['bam_peak_ratio'] else 0.0)
    
    print(f"{snr:<8} {base_acc:>7.1f}%   {bam_acc:>7.1f}%   {avg_mse:>10.6f}   {avg_base_peak:>8.1f}%   {avg_bam_peak:>8.1f}%")

# 전체 평균
total_base_correct = sum(r['base_correct'] for r in results.values())
total_base_total   = sum(r['base_total']   for r in results.values())
total_bam_correct  = sum(r['bam_correct']  for r in results.values())
total_bam_total    = sum(r['bam_total']    for r in results.values())

overall_base_acc = (total_base_correct / total_base_total * 100
                    if total_base_total > 0 else 0.0)
overall_bam_acc  = (total_bam_correct / total_bam_total * 100
                    if total_bam_total > 0 else 0.0)

print("─"*70)
print(f"{'Overall':<8} {overall_base_acc:>7.1f}%   {overall_bam_acc:>7.1f}%")
print("="*70)

# ======================
# 시각화 (Baseline vs BAM)
# ======================
snrs = TEST_SNR_LEVELS

# 1. Accuracy vs SNR
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
base_accs = [
    (results[snr]['base_correct'] / results[snr]['base_total'] * 100
     if results[snr]['base_total'] > 0 else 0.0)
    for snr in snrs
]
bam_accs = [
    (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
     if results[snr]['bam_total'] > 0 else 0.0)
    for snr in snrs
]
plt.plot(snrs, base_accs, 'o-', linewidth=2, markersize=8, label='Baseline (Noisy)')
plt.plot(snrs, bam_accs, 's-', linewidth=2, markersize=8, label='BAM (Restored)')
plt.xlabel('SNR (dB)')
plt.ylabel('Accuracy (%)')
plt.title('Symbol Classification Accuracy')
plt.grid(True, alpha=0.3)
plt.ylim([0, 105])
plt.legend()

# 2. MSE vs SNR (BAM만)
plt.subplot(1, 3, 2)
mses = [np.mean(results[snr]['bam_mse']) if results[snr]['bam_mse'] else 0.0 for snr in snrs]
plt.plot(snrs, mses, 's-', linewidth=2, markersize=8)
plt.xlabel('SNR (dB)')
plt.ylabel('MSE (Clean vs BAM IQ)')
plt.title('Reconstruction MSE (BAM)')
plt.grid(True, alpha=0.3)
plt.yscale('log')

# 3. Peak Ratio vs SNR
plt.subplot(1, 3, 3)
base_peaks = [
    (np.mean(results[snr]['base_peak_ratio']) * 100
     if results[snr]['base_peak_ratio'] else 0.0)
    for snr in snrs
]
bam_peaks = [
    (np.mean(results[snr]['bam_peak_ratio']) * 100
     if results[snr]['bam_peak_ratio'] else 0.0)
    for snr in snrs
]
plt.plot(snrs, base_peaks, 'o-', linewidth=2, markersize=8, label='Baseline Peak%')
plt.plot(snrs, bam_peaks, '^-', linewidth=2, markersize=8, label='BAM Peak%')
plt.xlabel('SNR (dB)')
plt.ylabel('Peak Ratio (%)')
plt.title('Peak Recovery Ratio (vs Clean)')
plt.grid(True, alpha=0.3)
plt.axhline(y=100, linestyle='--', alpha=0.5, label='Perfect (100%)')
plt.legend()

plt.tight_layout()
plt.show()

print("\n✅ Quantitative evaluation (Baseline vs BAM) complete!")
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)
# ======================================================================
#
# 🧪 Testing with 100 samples at each SNR level...
# SNR levels: [-25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_155955/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Baseline Accuracy (noisy→FFT): 13.0%
#   ✓ BAM Accuracy      (restored): 1.0%
#   ✓ BAM Avg MSE (clean vs restored IQ): 269.105149
#   ✓ Peak Ratio (Baseline/BAM vs Clean): 1203.0% / 978.5%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Accuracy (noisy→FFT): 40.0%
#   ✓ BAM Accuracy      (restored): 11.0%
#   ✓ BAM Avg MSE (clean vs restored IQ): 74.225616
#   ✓ Peak Ratio (Baseline/BAM vs Clean): 327.1% / 262.2%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Accuracy (noisy→FFT): 67.0%
#   ✓ BAM Accuracy      (restored): 32.0%
#   ✓ BAM Avg MSE (clean vs restored IQ): 31.947472
#   ✓ Peak Ratio (Baseline/BAM vs Clean): 177.2% / 130.1%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Accuracy (noisy→FFT): 74.0%
#   ✓ BAM Accuracy      (restored): 46.0%
#   ✓ BAM Avg MSE (clean vs restored IQ): 14.660191
#   ✓ Peak Ratio (Baseline/BAM vs Clean): 277.6% / 304.8%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Accuracy (noisy→FFT): 82.0%
#   ✓ BAM Accuracy      (restored): 54.0%
#   ✓ BAM Avg MSE (clean vs restored IQ): 10.070069
#   ✓ Peak Ratio (Baseline/BAM vs Clean): 114.5% / 91.5%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY (Baseline vs BAM)
# ======================================================================
#
# SNR (dB) Base Acc     BAM Acc      BAM MSE        Base Peak%   BAM Peak%
# ──────────────────────────────────────────────────────────────────────
# -25         13.0%       1.0%   269.105149     1203.0%      978.5%
# -20         40.0%      11.0%    74.225616      327.1%      262.2%
# -15         67.0%      32.0%    31.947472      177.2%      130.1%
# -10         74.0%      46.0%    14.660191      277.6%      304.8%
# -5          82.0%      54.0%    10.070069      114.5%       91.5%
# ──────────────────────────────────────────────────────────────────────
# Overall     55.2%      28.8%
# ======================================================================
# ✅ Quantitative evaluation (Baseline vs BAM) complete!
