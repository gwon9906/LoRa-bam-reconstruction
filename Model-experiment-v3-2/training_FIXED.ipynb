# %% [markdown]
# # BAMv3 실험: clean→clean 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    """
    복소 IQ 신호 → STFT 기반 complex 스펙트로그램 생성 (재학습용)
    - stft() / istft()가 1:1로 대응되도록 설계
    """
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    window   = STFT_PARAMS['window']

    # 1) STFT (spectrogram 대신 stft 사용)
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        boundary=None,          # padding 안 함
        padded=False,
        return_onesided=False   # 복소 baseband 이므로 False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf, bw)
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (Ultra-low SNR에 집중)
SNR_MIN = -25
SNR_MAX = -5
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(clean_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 4096, 2048, 1024]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (32, 31)
# Input dim (Real+Imag): 1984
# Model architecture: 1984 → 4096 → 2048 → 1024
# Compression ratio: 1.9x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True  # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 20
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 1984 → 4096 → 2048 → 1024
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.018837
# Epoch 1, Batch 2/240, MSE = 0.007182
# Epoch 1, Batch 3/240, MSE = 0.008369
# Epoch 1, Batch 4/240, MSE = 0.007105
# Epoch 1, Batch 5/240, MSE = 0.007551
# Epoch 1, Batch 6/240, MSE = 0.007161
# Epoch 1, Batch 7/240, MSE = 0.006615
# Epoch 1, Batch 8/240, MSE = 0.006875
# Epoch 1, Batch 9/240, MSE = 0.007264
# Epoch 1, Batch 10/240, MSE = 0.006717
# Epoch 1, Batch 11/240, MSE = 0.006867
# Epoch 1, Batch 12/240, MSE = 0.006955
# Epoch 1, Batch 13/240, MSE = 0.006851
# Epoch 1, Batch 14/240, MSE = 0.006638
# Epoch 1, Batch 15/240, MSE = 0.007077
# Epoch 1, Batch 16/240, MSE = 0.006738
# Epoch 1, Batch 17/240, MSE = 0.007027
# Epoch 1, Batch 18/240, MSE = 0.006762
# Epoch 1, Batch 19/240, MSE = 0.006732
# Epoch 1, Batch 20/240, MSE = 0.006541
# Epoch 1, Batch 21/240, MSE = 0.007037
# Epoch 1, Batch 22/240, MSE = 0.006647
# Epoch 1, Batch 23/240, MSE = 0.007045
# Epoch 1, Batch 24/240, MSE = 0.006569
# Epoch 1, Batch 25/240, MSE = 0.006180
# Epoch 1, Batch 26/240, MSE = 0.006410
# Epoch 1, Batch 27/240, MSE = 0.006551
# Epoch 1, Batch 28/240, MSE = 0.007051
# Epoch 1, Batch 29/240, MSE = 0.006701
# Epoch 1, Batch 30/240, MSE = 0.006620
# Epoch 1, Batch 31/240, MSE = 0.006735
# Epoch 1, Batch 32/240, MSE = 0.006746
# Epoch 1, Batch 33/240, MSE = 0.006531
# Epoch 1, Batch 34/240, MSE = 0.006296
# Epoch 1, Batch 35/240, MSE = 0.006652
# Epoch 1, Batch 36/240, MSE = 0.006582
# Epoch 1, Batch 37/240, MSE = 0.006445
# Epoch 1, Batch 38/240, MSE = 0.006696
# Epoch 1, Batch 39/240, MSE = 0.006188
# Epoch 1, Batch 40/240, MSE = 0.006400
# Epoch 1, Batch 41/240, MSE = 0.006521
# Epoch 1, Batch 42/240, MSE = 0.006289
# Epoch 1, Batch 43/240, MSE = 0.006437
# Epoch 1, Batch 44/240, MSE = 0.006214
# Epoch 1, Batch 45/240, MSE = 0.006647
# Epoch 1, Batch 46/240, MSE = 0.006367
# Epoch 1, Batch 47/240, MSE = 0.006397
# Epoch 1, Batch 48/240, MSE = 0.006196
# Epoch 1, Batch 49/240, MSE = 0.006419
# Epoch 1, Batch 50/240, MSE = 0.006521
# Epoch 1, Batch 51/240, MSE = 0.006439
# Epoch 1, Batch 52/240, MSE = 0.006244
# Epoch 1, Batch 53/240, MSE = 0.006051
# Epoch 1, Batch 54/240, MSE = 0.006600
# Epoch 1, Batch 55/240, MSE = 0.006266
# Epoch 1, Batch 56/240, MSE = 0.006600
# Epoch 1, Batch 57/240, MSE = 0.006283
# Epoch 1, Batch 58/240, MSE = 0.006430
# Epoch 1, Batch 59/240, MSE = 0.006295
# Epoch 1, Batch 60/240, MSE = 0.006084
# Epoch 1, Batch 61/240, MSE = 0.006169
# Epoch 1, Batch 62/240, MSE = 0.006461
# Epoch 1, Batch 63/240, MSE = 0.006343
# Epoch 1, Batch 64/240, MSE = 0.006058
# Epoch 1, Batch 65/240, MSE = 0.006105
# Epoch 1, Batch 66/240, MSE = 0.006156
# Epoch 1, Batch 67/240, MSE = 0.006220
# Epoch 1, Batch 68/240, MSE = 0.006469
# Epoch 1, Batch 69/240, MSE = 0.005909
# Epoch 1, Batch 70/240, MSE = 0.006292
# Epoch 1, Batch 71/240, MSE = 0.006230
# Epoch 1, Batch 72/240, MSE = 0.006117
# Epoch 1, Batch 73/240, MSE = 0.005981
# Epoch 1, Batch 74/240, MSE = 0.006248
# Epoch 1, Batch 75/240, MSE = 0.006028
# Epoch 1, Batch 76/240, MSE = 0.006144
# Epoch 1, Batch 77/240, MSE = 0.005926
# Epoch 1, Batch 78/240, MSE = 0.006479
# Epoch 1, Batch 79/240, MSE = 0.006507
# Epoch 1, Batch 80/240, MSE = 0.006603
# Epoch 1, Batch 81/240, MSE = 0.006480
# Epoch 1, Batch 82/240, MSE = 0.006588
# Epoch 1, Batch 83/240, MSE = 0.006857
# Epoch 1, Batch 84/240, MSE = 0.006033
# Epoch 1, Batch 85/240, MSE = 0.006096
# Epoch 1, Batch 86/240, MSE = 0.006137
# Epoch 1, Batch 87/240, MSE = 0.006628
# Epoch 1, Batch 88/240, MSE = 0.006210
# Epoch 1, Batch 89/240, MSE = 0.006292
# Epoch 1, Batch 90/240, MSE = 0.006227
# Epoch 1, Batch 91/240, MSE = 0.006032
# Epoch 1, Batch 92/240, MSE = 0.006256
# Epoch 1, Batch 93/240, MSE = 0.006156
# Epoch 1, Batch 94/240, MSE = 0.006134
# Epoch 1, Batch 95/240, MSE = 0.005990
# Epoch 1, Batch 96/240, MSE = 0.006024
# Epoch 1, Batch 97/240, MSE = 0.006260
# Epoch 1, Batch 98/240, MSE = 0.006438
# Epoch 1, Batch 99/240, MSE = 0.006050
# Epoch 1, Batch 100/240, MSE = 0.006039
# Epoch 1, Batch 101/240, MSE = 0.006207
# Epoch 1, Batch 102/240, MSE = 0.006129
# Epoch 1, Batch 103/240, MSE = 0.006078
# Epoch 1, Batch 104/240, MSE = 0.006317
# Epoch 1, Batch 105/240, MSE = 0.006274
# Epoch 1, Batch 106/240, MSE = 0.006330
# Epoch 1, Batch 107/240, MSE = 0.006241
# Epoch 1, Batch 108/240, MSE = 0.006671
# Epoch 1, Batch 109/240, MSE = 0.006436
# Epoch 1, Batch 110/240, MSE = 0.006107
# Epoch 1, Batch 111/240, MSE = 0.006141
# Epoch 1, Batch 112/240, MSE = 0.006070
# Epoch 1, Batch 113/240, MSE = 0.006031
# Epoch 1, Batch 114/240, MSE = 0.006242
# Epoch 1, Batch 115/240, MSE = 0.006525
# Epoch 1, Batch 116/240, MSE = 0.005982
# Epoch 1, Batch 117/240, MSE = 0.006048
# Epoch 1, Batch 118/240, MSE = 0.006058
# Epoch 1, Batch 119/240, MSE = 0.006013
# Epoch 1, Batch 120/240, MSE = 0.005911
# Epoch 1, Batch 121/240, MSE = 0.006394
# Epoch 1, Batch 122/240, MSE = 0.006049
# Epoch 1, Batch 123/240, MSE = 0.006129
# Epoch 1, Batch 124/240, MSE = 0.006177
# Epoch 1, Batch 125/240, MSE = 0.006095
# Epoch 1, Batch 126/240, MSE = 0.006191
# Epoch 1, Batch 127/240, MSE = 0.005892
# Epoch 1, Batch 128/240, MSE = 0.006125
# Epoch 1, Batch 129/240, MSE = 0.006073
# Epoch 1, Batch 130/240, MSE = 0.006007
# Epoch 1, Batch 131/240, MSE = 0.005768
# Epoch 1, Batch 132/240, MSE = 0.005966
# Epoch 1, Batch 133/240, MSE = 0.005947
# Epoch 1, Batch 134/240, MSE = 0.005925
# Epoch 1, Batch 135/240, MSE = 0.005628
# Epoch 1, Batch 136/240, MSE = 0.006118
# Epoch 1, Batch 137/240, MSE = 0.005787
# Epoch 1, Batch 138/240, MSE = 0.006189
# Epoch 1, Batch 139/240, MSE = 0.006058
# Epoch 1, Batch 140/240, MSE = 0.006207
# Epoch 1, Batch 141/240, MSE = 0.005717
# Epoch 1, Batch 142/240, MSE = 0.006023
# Epoch 1, Batch 143/240, MSE = 0.006468
# Epoch 1, Batch 144/240, MSE = 0.006048
# Epoch 1, Batch 145/240, MSE = 0.005820
# Epoch 1, Batch 146/240, MSE = 0.006093
# Epoch 1, Batch 147/240, MSE = 0.006006
# Epoch 1, Batch 148/240, MSE = 0.005863
# Epoch 1, Batch 149/240, MSE = 0.005728
# Epoch 1, Batch 150/240, MSE = 0.006081
# Epoch 1, Batch 151/240, MSE = 0.005752
# Epoch 1, Batch 152/240, MSE = 0.005754
# Epoch 1, Batch 153/240, MSE = 0.005930
# Epoch 1, Batch 154/240, MSE = 0.006136
# Epoch 1, Batch 155/240, MSE = 0.006400
# Epoch 1, Batch 156/240, MSE = 0.005932
# Epoch 1, Batch 157/240, MSE = 0.006099
# Epoch 1, Batch 158/240, MSE = 0.005886
# Epoch 1, Batch 159/240, MSE = 0.005875
# Epoch 1, Batch 160/240, MSE = 0.005827
# Epoch 1, Batch 161/240, MSE = 0.005836
# Epoch 1, Batch 162/240, MSE = 0.005703
# Epoch 1, Batch 163/240, MSE = 0.005945
# Epoch 1, Batch 164/240, MSE = 0.005931
# Epoch 1, Batch 165/240, MSE = 0.005586
# Epoch 1, Batch 166/240, MSE = 0.005725
# Epoch 1, Batch 167/240, MSE = 0.006073
# Epoch 1, Batch 168/240, MSE = 0.005855
# Epoch 1, Batch 169/240, MSE = 0.005708
# Epoch 1, Batch 170/240, MSE = 0.006115
# Epoch 1, Batch 171/240, MSE = 0.005537
# Epoch 1, Batch 172/240, MSE = 0.006045
# Epoch 1, Batch 173/240, MSE = 0.005753
# Epoch 1, Batch 174/240, MSE = 0.006345
# Epoch 1, Batch 175/240, MSE = 0.005825
# Epoch 1, Batch 176/240, MSE = 0.005846
# Epoch 1, Batch 177/240, MSE = 0.005886
# Epoch 1, Batch 178/240, MSE = 0.006262
# Epoch 1, Batch 179/240, MSE = 0.005910
# Epoch 1, Batch 180/240, MSE = 0.005770
# Epoch 1, Batch 181/240, MSE = 0.005714
# Epoch 1, Batch 182/240, MSE = 0.005867
# Epoch 1, Batch 183/240, MSE = 0.006051
# Epoch 1, Batch 184/240, MSE = 0.005557
# Epoch 1, Batch 185/240, MSE = 0.005598
# Epoch 1, Batch 186/240, MSE = 0.005514
# Epoch 1, Batch 187/240, MSE = 0.006058
# Epoch 1, Batch 188/240, MSE = 0.005783
# Epoch 1, Batch 189/240, MSE = 0.005714
# Epoch 1, Batch 190/240, MSE = 0.005626
# Epoch 1, Batch 191/240, MSE = 0.005997
# Epoch 1, Batch 192/240, MSE = 0.005951
# Epoch 1, Batch 193/240, MSE = 0.005641
# Epoch 1, Batch 194/240, MSE = 0.005620
# Epoch 1, Batch 195/240, MSE = 0.005957
# Epoch 1, Batch 196/240, MSE = 0.005987
# Epoch 1, Batch 197/240, MSE = 0.005699
# Epoch 1, Batch 198/240, MSE = 0.005833
# Epoch 1, Batch 199/240, MSE = 0.005714
# Epoch 1, Batch 200/240, MSE = 0.005759
# Epoch 1, Batch 201/240, MSE = 0.005572
# Epoch 1, Batch 202/240, MSE = 0.005744
# Epoch 1, Batch 203/240, MSE = 0.005681
# Epoch 1, Batch 204/240, MSE = 0.005662
# Epoch 1, Batch 205/240, MSE = 0.005754
# Epoch 1, Batch 206/240, MSE = 0.005848
# Epoch 1, Batch 207/240, MSE = 0.005998
# Epoch 1, Batch 208/240, MSE = 0.005549
# Epoch 1, Batch 209/240, MSE = 0.006033
# Epoch 1, Batch 210/240, MSE = 0.005747
# Epoch 1, Batch 211/240, MSE = 0.005601
# Epoch 1, Batch 212/240, MSE = 0.006091
# Epoch 1, Batch 213/240, MSE = 0.005404
# Epoch 1, Batch 214/240, MSE = 0.005484
# Epoch 1, Batch 215/240, MSE = 0.005537
# Epoch 1, Batch 216/240, MSE = 0.005793
# Epoch 1, Batch 217/240, MSE = 0.005933
# Epoch 1, Batch 218/240, MSE = 0.005714
# Epoch 1, Batch 219/240, MSE = 0.005328
# Epoch 1, Batch 220/240, MSE = 0.005486
# Epoch 1, Batch 221/240, MSE = 0.005758
# Epoch 1, Batch 222/240, MSE = 0.005757
# Epoch 1, Batch 223/240, MSE = 0.005505
# Epoch 1, Batch 224/240, MSE = 0.005686
# Epoch 1, Batch 225/240, MSE = 0.005768
# Epoch 1, Batch 226/240, MSE = 0.005609
# Epoch 1, Batch 227/240, MSE = 0.005409
# Epoch 1, Batch 228/240, MSE = 0.005415
# Epoch 1, Batch 229/240, MSE = 0.005832
# Epoch 1, Batch 230/240, MSE = 0.005468
# Epoch 1, Batch 231/240, MSE = 0.005664
# Epoch 1, Batch 232/240, MSE = 0.005639
# Epoch 1, Batch 233/240, MSE = 0.005669
# Epoch 1, Batch 234/240, MSE = 0.005653
# Epoch 1, Batch 235/240, MSE = 0.005408
# Epoch 1, Batch 236/240, MSE = 0.005611
# Epoch 1, Batch 237/240, MSE = 0.005944
# Epoch 1, Batch 238/240, MSE = 0.005575
# Epoch 1, Batch 239/240, MSE = 0.005489
# Epoch 1, Batch 240/240, MSE = 0.005528
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.009832
# Epoch 1, Batch 2/240, MSE = 0.001078
# Epoch 1, Batch 3/240, MSE = 0.000847
# Epoch 1, Batch 4/240, MSE = 0.001454
# Epoch 1, Batch 5/240, MSE = 0.001778
# Epoch 1, Batch 6/240, MSE = 0.001305
# Epoch 1, Batch 7/240, MSE = 0.001537
# Epoch 1, Batch 8/240, MSE = 0.001411
# Epoch 1, Batch 9/240, MSE = 0.000754
# Epoch 1, Batch 10/240, MSE = 0.001068
# Epoch 1, Batch 11/240, MSE = 0.001307
# Epoch 1, Batch 12/240, MSE = 0.001081
# Epoch 1, Batch 13/240, MSE = 0.000829
# Epoch 1, Batch 14/240, MSE = 0.000985
# Epoch 1, Batch 15/240, MSE = 0.001234
# Epoch 1, Batch 16/240, MSE = 0.000948
# Epoch 1, Batch 17/240, MSE = 0.000975
# Epoch 1, Batch 18/240, MSE = 0.001025
# Epoch 1, Batch 19/240, MSE = 0.001251
# Epoch 1, Batch 20/240, MSE = 0.000850
# Epoch 1, Batch 21/240, MSE = 0.000826
# Epoch 1, Batch 22/240, MSE = 0.001045
# Epoch 1, Batch 23/240, MSE = 0.000876
# Epoch 1, Batch 24/240, MSE = 0.000835
# Epoch 1, Batch 25/240, MSE = 0.000848
# Epoch 1, Batch 26/240, MSE = 0.000931
# Epoch 1, Batch 27/240, MSE = 0.000809
# Epoch 1, Batch 28/240, MSE = 0.000884
# Epoch 1, Batch 29/240, MSE = 0.000791
# Epoch 1, Batch 30/240, MSE = 0.000853
# Epoch 1, Batch 31/240, MSE = 0.000773
# Epoch 1, Batch 32/240, MSE = 0.000820
# Epoch 1, Batch 33/240, MSE = 0.000830
# Epoch 1, Batch 34/240, MSE = 0.000716
# Epoch 1, Batch 35/240, MSE = 0.000733
# Epoch 1, Batch 36/240, MSE = 0.000749
# Epoch 1, Batch 37/240, MSE = 0.000702
# Epoch 1, Batch 38/240, MSE = 0.000748
# Epoch 1, Batch 39/240, MSE = 0.000739
# Epoch 1, Batch 40/240, MSE = 0.000792
# Epoch 1, Batch 41/240, MSE = 0.000774
# Epoch 1, Batch 42/240, MSE = 0.000740
# Epoch 1, Batch 43/240, MSE = 0.000776
# Epoch 1, Batch 44/240, MSE = 0.000769
# Epoch 1, Batch 45/240, MSE = 0.000732
# Epoch 1, Batch 46/240, MSE = 0.000842
# Epoch 1, Batch 47/240, MSE = 0.000849
# Epoch 1, Batch 48/240, MSE = 0.000804
# Epoch 1, Batch 49/240, MSE = 0.000856
# Epoch 1, Batch 50/240, MSE = 0.000702
# Epoch 1, Batch 51/240, MSE = 0.000766
# Epoch 1, Batch 52/240, MSE = 0.000740
# Epoch 1, Batch 53/240, MSE = 0.000799
# Epoch 1, Batch 54/240, MSE = 0.000871
# Epoch 1, Batch 55/240, MSE = 0.000803
# Epoch 1, Batch 56/240, MSE = 0.000679
# Epoch 1, Batch 57/240, MSE = 0.000769
# Epoch 1, Batch 58/240, MSE = 0.000683
# Epoch 1, Batch 59/240, MSE = 0.000762
# Epoch 1, Batch 60/240, MSE = 0.000741
# Epoch 1, Batch 61/240, MSE = 0.000809
# Epoch 1, Batch 62/240, MSE = 0.000687
# Epoch 1, Batch 63/240, MSE = 0.000751
# Epoch 1, Batch 64/240, MSE = 0.000836
# Epoch 1, Batch 65/240, MSE = 0.000782
# Epoch 1, Batch 66/240, MSE = 0.000821
# Epoch 1, Batch 67/240, MSE = 0.000741
# Epoch 1, Batch 68/240, MSE = 0.000739
# Epoch 1, Batch 69/240, MSE = 0.000775
# Epoch 1, Batch 70/240, MSE = 0.000724
# Epoch 1, Batch 71/240, MSE = 0.000711
# Epoch 1, Batch 72/240, MSE = 0.000816
# Epoch 1, Batch 73/240, MSE = 0.000785
# Epoch 1, Batch 74/240, MSE = 0.000770
# Epoch 1, Batch 75/240, MSE = 0.000744
# Epoch 1, Batch 76/240, MSE = 0.000811
# Epoch 1, Batch 77/240, MSE = 0.000740
# Epoch 1, Batch 78/240, MSE = 0.000803
# Epoch 1, Batch 79/240, MSE = 0.000807
# Epoch 1, Batch 80/240, MSE = 0.000774
# Epoch 1, Batch 81/240, MSE = 0.000736
# Epoch 1, Batch 82/240, MSE = 0.000828
# Epoch 1, Batch 83/240, MSE = 0.000756
# Epoch 1, Batch 84/240, MSE = 0.000709
# Epoch 1, Batch 85/240, MSE = 0.000740
# Epoch 1, Batch 86/240, MSE = 0.000846
# Epoch 1, Batch 87/240, MSE = 0.000811
# Epoch 1, Batch 88/240, MSE = 0.000748
# Epoch 1, Batch 89/240, MSE = 0.000786
# Epoch 1, Batch 90/240, MSE = 0.000832
# Epoch 1, Batch 91/240, MSE = 0.000798
# Epoch 1, Batch 92/240, MSE = 0.000757
# Epoch 1, Batch 93/240, MSE = 0.000789
# Epoch 1, Batch 94/240, MSE = 0.000799
# Epoch 1, Batch 95/240, MSE = 0.000725
# Epoch 1, Batch 96/240, MSE = 0.000701
# Epoch 1, Batch 97/240, MSE = 0.000780
# Epoch 1, Batch 98/240, MSE = 0.000735
# Epoch 1, Batch 99/240, MSE = 0.000785
# Epoch 1, Batch 100/240, MSE = 0.000796
# Epoch 1, Batch 101/240, MSE = 0.000800
# Epoch 1, Batch 102/240, MSE = 0.000810
# Epoch 1, Batch 103/240, MSE = 0.000891
# Epoch 1, Batch 104/240, MSE = 0.000819
# Epoch 1, Batch 105/240, MSE = 0.000797
# Epoch 1, Batch 106/240, MSE = 0.000798
# Epoch 1, Batch 107/240, MSE = 0.000877
# Epoch 1, Batch 108/240, MSE = 0.000801
# Epoch 1, Batch 109/240, MSE = 0.000768
# Epoch 1, Batch 110/240, MSE = 0.000734
# Epoch 1, Batch 111/240, MSE = 0.000787
# Epoch 1, Batch 112/240, MSE = 0.000881
# Epoch 1, Batch 113/240, MSE = 0.000762
# Epoch 1, Batch 114/240, MSE = 0.000756
# Epoch 1, Batch 115/240, MSE = 0.000797
# Epoch 1, Batch 116/240, MSE = 0.000842
# Epoch 1, Batch 117/240, MSE = 0.000715
# Epoch 1, Batch 118/240, MSE = 0.000762
# Epoch 1, Batch 119/240, MSE = 0.000778
# Epoch 1, Batch 120/240, MSE = 0.000746
# Epoch 1, Batch 121/240, MSE = 0.000724
# Epoch 1, Batch 122/240, MSE = 0.000714
# Epoch 1, Batch 123/240, MSE = 0.000754
# Epoch 1, Batch 124/240, MSE = 0.000709
# Epoch 1, Batch 125/240, MSE = 0.000743
# Epoch 1, Batch 126/240, MSE = 0.000810
# Epoch 1, Batch 127/240, MSE = 0.000899
# Epoch 1, Batch 128/240, MSE = 0.000777
# Epoch 1, Batch 129/240, MSE = 0.000798
# Epoch 1, Batch 130/240, MSE = 0.000794
# Epoch 1, Batch 131/240, MSE = 0.000741
# Epoch 1, Batch 132/240, MSE = 0.000809
# Epoch 1, Batch 133/240, MSE = 0.000797
# Epoch 1, Batch 134/240, MSE = 0.000712
# Epoch 1, Batch 135/240, MSE = 0.000801
# Epoch 1, Batch 136/240, MSE = 0.000666
# Epoch 1, Batch 137/240, MSE = 0.000761
# Epoch 1, Batch 138/240, MSE = 0.000785
# Epoch 1, Batch 139/240, MSE = 0.000747
# Epoch 1, Batch 140/240, MSE = 0.000796
# Epoch 1, Batch 141/240, MSE = 0.000876
# Epoch 1, Batch 142/240, MSE = 0.000770
# Epoch 1, Batch 143/240, MSE = 0.000795
# Epoch 1, Batch 144/240, MSE = 0.000768
# Epoch 1, Batch 145/240, MSE = 0.000765
# Epoch 1, Batch 146/240, MSE = 0.000868
# Epoch 1, Batch 147/240, MSE = 0.000753
# Epoch 1, Batch 148/240, MSE = 0.000757
# Epoch 1, Batch 149/240, MSE = 0.000790
# Epoch 1, Batch 150/240, MSE = 0.000850
# Epoch 1, Batch 151/240, MSE = 0.000682
# Epoch 1, Batch 152/240, MSE = 0.000753
# Epoch 1, Batch 153/240, MSE = 0.000726
# Epoch 1, Batch 154/240, MSE = 0.000807
# Epoch 1, Batch 155/240, MSE = 0.000811
# Epoch 1, Batch 156/240, MSE = 0.000868
# Epoch 1, Batch 157/240, MSE = 0.000789
# Epoch 1, Batch 158/240, MSE = 0.000799
# Epoch 1, Batch 159/240, MSE = 0.000708
# Epoch 1, Batch 160/240, MSE = 0.000762
# Epoch 1, Batch 161/240, MSE = 0.000795
# Epoch 1, Batch 162/240, MSE = 0.000819
# Epoch 1, Batch 163/240, MSE = 0.000752
# Epoch 1, Batch 164/240, MSE = 0.000740
# Epoch 1, Batch 165/240, MSE = 0.000754
# Epoch 1, Batch 166/240, MSE = 0.000782
# Epoch 1, Batch 167/240, MSE = 0.000694
# Epoch 1, Batch 168/240, MSE = 0.000843
# Epoch 1, Batch 169/240, MSE = 0.000848
# Epoch 1, Batch 170/240, MSE = 0.000802
# Epoch 1, Batch 171/240, MSE = 0.000745
# Epoch 1, Batch 172/240, MSE = 0.000826
# Epoch 1, Batch 173/240, MSE = 0.000735
# Epoch 1, Batch 174/240, MSE = 0.000815
# Epoch 1, Batch 175/240, MSE = 0.000828
# Epoch 1, Batch 176/240, MSE = 0.000824
# Epoch 1, Batch 177/240, MSE = 0.000737
# Epoch 1, Batch 178/240, MSE = 0.000767
# Epoch 1, Batch 179/240, MSE = 0.000752
# Epoch 1, Batch 180/240, MSE = 0.000689
# Epoch 1, Batch 181/240, MSE = 0.000740
# Epoch 1, Batch 182/240, MSE = 0.000730
# Epoch 1, Batch 183/240, MSE = 0.000727
# Epoch 1, Batch 184/240, MSE = 0.000700
# Epoch 1, Batch 185/240, MSE = 0.000773
# Epoch 1, Batch 186/240, MSE = 0.000808
# Epoch 1, Batch 187/240, MSE = 0.000798
# Epoch 1, Batch 188/240, MSE = 0.000704
# Epoch 1, Batch 189/240, MSE = 0.000778
# Epoch 1, Batch 190/240, MSE = 0.000695
# Epoch 1, Batch 191/240, MSE = 0.000755
# Epoch 1, Batch 192/240, MSE = 0.000769
# Epoch 1, Batch 193/240, MSE = 0.000807
# Epoch 1, Batch 194/240, MSE = 0.000743
# Epoch 1, Batch 195/240, MSE = 0.000803
# Epoch 1, Batch 196/240, MSE = 0.000772
# Epoch 1, Batch 197/240, MSE = 0.000806
# Epoch 1, Batch 198/240, MSE = 0.000812
# Epoch 1, Batch 199/240, MSE = 0.000841
# Epoch 1, Batch 200/240, MSE = 0.000770
# Epoch 1, Batch 201/240, MSE = 0.000751
# Epoch 1, Batch 202/240, MSE = 0.000728
# Epoch 1, Batch 203/240, MSE = 0.000835
# Epoch 1, Batch 204/240, MSE = 0.000854
# Epoch 1, Batch 205/240, MSE = 0.000802
# Epoch 1, Batch 206/240, MSE = 0.000748
# Epoch 1, Batch 207/240, MSE = 0.000808
# Epoch 1, Batch 208/240, MSE = 0.000768
# Epoch 1, Batch 209/240, MSE = 0.000737
# Epoch 1, Batch 210/240, MSE = 0.000766
# Epoch 1, Batch 211/240, MSE = 0.000846
# Epoch 1, Batch 212/240, MSE = 0.000699
# Epoch 1, Batch 213/240, MSE = 0.000740
# Epoch 1, Batch 214/240, MSE = 0.000714
# Epoch 1, Batch 215/240, MSE = 0.000784
# Epoch 1, Batch 216/240, MSE = 0.000715
# Epoch 1, Batch 217/240, MSE = 0.000777
# Epoch 1, Batch 218/240, MSE = 0.000788
# Epoch 1, Batch 219/240, MSE = 0.000759
# Epoch 1, Batch 220/240, MSE = 0.000779
# Epoch 1, Batch 221/240, MSE = 0.000768
# Epoch 1, Batch 222/240, MSE = 0.000792
# Epoch 1, Batch 223/240, MSE = 0.000763
# Epoch 1, Batch 224/240, MSE = 0.000756
# Epoch 1, Batch 225/240, MSE = 0.000716
# Epoch 1, Batch 226/240, MSE = 0.000746
# Epoch 1, Batch 227/240, MSE = 0.000803
# Epoch 1, Batch 228/240, MSE = 0.000690
# Epoch 1, Batch 229/240, MSE = 0.000735
# Epoch 1, Batch 230/240, MSE = 0.000798
# Epoch 1, Batch 231/240, MSE = 0.000743
# Epoch 1, Batch 232/240, MSE = 0.000806
# Epoch 1, Batch 233/240, MSE = 0.000808
# Epoch 1, Batch 234/240, MSE = 0.000850
# Epoch 1, Batch 235/240, MSE = 0.000720
# Epoch 1, Batch 236/240, MSE = 0.000708
# Epoch 1, Batch 237/240, MSE = 0.000673
# Epoch 1, Batch 238/240, MSE = 0.000753
# Epoch 1, Batch 239/240, MSE = 0.000770
# Epoch 1, Batch 240/240, MSE = 0.000753
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.024384
# Epoch 1, Batch 2/240, MSE = 0.002206
# Epoch 1, Batch 3/240, MSE = 0.000831
# Epoch 1, Batch 4/240, MSE = 0.001423
# Epoch 1, Batch 5/240, MSE = 0.002000
# Epoch 1, Batch 6/240, MSE = 0.001031
# Epoch 1, Batch 7/240, MSE = 0.001813
# Epoch 1, Batch 8/240, MSE = 0.001003
# Epoch 1, Batch 9/240, MSE = 0.001244
# Epoch 1, Batch 10/240, MSE = 0.002243
# Epoch 1, Batch 11/240, MSE = 0.000602
# Epoch 1, Batch 12/240, MSE = 0.000984
# Epoch 1, Batch 13/240, MSE = 0.001189
# Epoch 1, Batch 14/240, MSE = 0.000959
# Epoch 1, Batch 15/240, MSE = 0.000992
# Epoch 1, Batch 16/240, MSE = 0.000513
# Epoch 1, Batch 17/240, MSE = 0.000354
# Epoch 1, Batch 18/240, MSE = 0.000713
# Epoch 1, Batch 19/240, MSE = 0.000462
# Epoch 1, Batch 20/240, MSE = 0.000285
# Epoch 1, Batch 21/240, MSE = 0.000315
# Epoch 1, Batch 22/240, MSE = 0.000411
# Epoch 1, Batch 23/240, MSE = 0.000372
# Epoch 1, Batch 24/240, MSE = 0.000215
# Epoch 1, Batch 25/240, MSE = 0.000239
# Epoch 1, Batch 26/240, MSE = 0.000162
# Epoch 1, Batch 27/240, MSE = 0.000210
# Epoch 1, Batch 28/240, MSE = 0.000141
# Epoch 1, Batch 29/240, MSE = 0.000191
# Epoch 1, Batch 30/240, MSE = 0.000148
# Epoch 1, Batch 31/240, MSE = 0.000165
# Epoch 1, Batch 32/240, MSE = 0.000148
# Epoch 1, Batch 33/240, MSE = 0.000151
# Epoch 1, Batch 34/240, MSE = 0.000129
# Epoch 1, Batch 35/240, MSE = 0.000145
# Epoch 1, Batch 36/240, MSE = 0.000132
# Epoch 1, Batch 37/240, MSE = 0.000114
# Epoch 1, Batch 38/240, MSE = 0.000119
# Epoch 1, Batch 39/240, MSE = 0.000123
# Epoch 1, Batch 40/240, MSE = 0.000138
# Epoch 1, Batch 41/240, MSE = 0.000130
# Epoch 1, Batch 42/240, MSE = 0.000135
# Epoch 1, Batch 43/240, MSE = 0.000130
# Epoch 1, Batch 44/240, MSE = 0.000119
# Epoch 1, Batch 45/240, MSE = 0.000122
# Epoch 1, Batch 46/240, MSE = 0.000138
# Epoch 1, Batch 47/240, MSE = 0.000131
# Epoch 1, Batch 48/240, MSE = 0.000131
# Epoch 1, Batch 49/240, MSE = 0.000118
# Epoch 1, Batch 50/240, MSE = 0.000150
# Epoch 1, Batch 51/240, MSE = 0.000135
# Epoch 1, Batch 52/240, MSE = 0.000132
# Epoch 1, Batch 53/240, MSE = 0.000124
# Epoch 1, Batch 54/240, MSE = 0.000130
# Epoch 1, Batch 55/240, MSE = 0.000118
# Epoch 1, Batch 56/240, MSE = 0.000121
# Epoch 1, Batch 57/240, MSE = 0.000153
# Epoch 1, Batch 58/240, MSE = 0.000130
# Epoch 1, Batch 59/240, MSE = 0.000144
# Epoch 1, Batch 60/240, MSE = 0.000147
# Epoch 1, Batch 61/240, MSE = 0.000136
# Epoch 1, Batch 62/240, MSE = 0.000128
# Epoch 1, Batch 63/240, MSE = 0.000127
# Epoch 1, Batch 64/240, MSE = 0.000133
# Epoch 1, Batch 65/240, MSE = 0.000129
# Epoch 1, Batch 66/240, MSE = 0.000124
# Epoch 1, Batch 67/240, MSE = 0.000128
# Epoch 1, Batch 68/240, MSE = 0.000144
# Epoch 1, Batch 69/240, MSE = 0.000145
# Epoch 1, Batch 70/240, MSE = 0.000128
# Epoch 1, Batch 71/240, MSE = 0.000126
# Epoch 1, Batch 72/240, MSE = 0.000115
# Epoch 1, Batch 73/240, MSE = 0.000139
# Epoch 1, Batch 74/240, MSE = 0.000134
# Epoch 1, Batch 75/240, MSE = 0.000126
# Epoch 1, Batch 76/240, MSE = 0.000133
# Epoch 1, Batch 77/240, MSE = 0.000110
# Epoch 1, Batch 78/240, MSE = 0.000143
# Epoch 1, Batch 79/240, MSE = 0.000122
# Epoch 1, Batch 80/240, MSE = 0.000115
# Epoch 1, Batch 81/240, MSE = 0.000145
# Epoch 1, Batch 82/240, MSE = 0.000152
# Epoch 1, Batch 83/240, MSE = 0.000122
# Epoch 1, Batch 84/240, MSE = 0.000125
# Epoch 1, Batch 85/240, MSE = 0.000128
# Epoch 1, Batch 86/240, MSE = 0.000134
# Epoch 1, Batch 87/240, MSE = 0.000124
# Epoch 1, Batch 88/240, MSE = 0.000126
# Epoch 1, Batch 89/240, MSE = 0.000143
# Epoch 1, Batch 90/240, MSE = 0.000119
# Epoch 1, Batch 91/240, MSE = 0.000115
# Epoch 1, Batch 92/240, MSE = 0.000117
# Epoch 1, Batch 93/240, MSE = 0.000148
# Epoch 1, Batch 94/240, MSE = 0.000135
# Epoch 1, Batch 95/240, MSE = 0.000122
# Epoch 1, Batch 96/240, MSE = 0.000134
# Epoch 1, Batch 97/240, MSE = 0.000123
# Epoch 1, Batch 98/240, MSE = 0.000117
# Epoch 1, Batch 99/240, MSE = 0.000109
# Epoch 1, Batch 100/240, MSE = 0.000134
# Epoch 1, Batch 101/240, MSE = 0.000126
# Epoch 1, Batch 102/240, MSE = 0.000121
# Epoch 1, Batch 103/240, MSE = 0.000127
# Epoch 1, Batch 104/240, MSE = 0.000122
# Epoch 1, Batch 105/240, MSE = 0.000127
# Epoch 1, Batch 106/240, MSE = 0.000140
# Epoch 1, Batch 107/240, MSE = 0.000134
# Epoch 1, Batch 108/240, MSE = 0.000137
# Epoch 1, Batch 109/240, MSE = 0.000121
# Epoch 1, Batch 110/240, MSE = 0.000138
# Epoch 1, Batch 111/240, MSE = 0.000135
# Epoch 1, Batch 112/240, MSE = 0.000130
# Epoch 1, Batch 113/240, MSE = 0.000121
# Epoch 1, Batch 114/240, MSE = 0.000121
# Epoch 1, Batch 115/240, MSE = 0.000110
# Epoch 1, Batch 116/240, MSE = 0.000128
# Epoch 1, Batch 117/240, MSE = 0.000134
# Epoch 1, Batch 118/240, MSE = 0.000153
# Epoch 1, Batch 119/240, MSE = 0.000130
# Epoch 1, Batch 120/240, MSE = 0.000133
# Epoch 1, Batch 121/240, MSE = 0.000122
# Epoch 1, Batch 122/240, MSE = 0.000124
# Epoch 1, Batch 123/240, MSE = 0.000148
# Epoch 1, Batch 124/240, MSE = 0.000130
# Epoch 1, Batch 125/240, MSE = 0.000122
# Epoch 1, Batch 126/240, MSE = 0.000151
# Epoch 1, Batch 127/240, MSE = 0.000150
# Epoch 1, Batch 128/240, MSE = 0.000131
# Epoch 1, Batch 129/240, MSE = 0.000108
# Epoch 1, Batch 130/240, MSE = 0.000141
# Epoch 1, Batch 131/240, MSE = 0.000143
# Epoch 1, Batch 132/240, MSE = 0.000132
# Epoch 1, Batch 133/240, MSE = 0.000121
# Epoch 1, Batch 134/240, MSE = 0.000129
# Epoch 1, Batch 135/240, MSE = 0.000132
# Epoch 1, Batch 136/240, MSE = 0.000144
# Epoch 1, Batch 137/240, MSE = 0.000117
# Epoch 1, Batch 138/240, MSE = 0.000133
# Epoch 1, Batch 139/240, MSE = 0.000115
# Epoch 1, Batch 140/240, MSE = 0.000125
# Epoch 1, Batch 141/240, MSE = 0.000120
# Epoch 1, Batch 142/240, MSE = 0.000132
# Epoch 1, Batch 143/240, MSE = 0.000144
# Epoch 1, Batch 144/240, MSE = 0.000131
# Epoch 1, Batch 145/240, MSE = 0.000120
# Epoch 1, Batch 146/240, MSE = 0.000125
# Epoch 1, Batch 147/240, MSE = 0.000121
# Epoch 1, Batch 148/240, MSE = 0.000118
# Epoch 1, Batch 149/240, MSE = 0.000137
# Epoch 1, Batch 150/240, MSE = 0.000120
# Epoch 1, Batch 151/240, MSE = 0.000126
# Epoch 1, Batch 152/240, MSE = 0.000138
# Epoch 1, Batch 153/240, MSE = 0.000122
# Epoch 1, Batch 154/240, MSE = 0.000122
# Epoch 1, Batch 155/240, MSE = 0.000119
# Epoch 1, Batch 156/240, MSE = 0.000125
# Epoch 1, Batch 157/240, MSE = 0.000130
# Epoch 1, Batch 158/240, MSE = 0.000126
# Epoch 1, Batch 159/240, MSE = 0.000132
# Epoch 1, Batch 160/240, MSE = 0.000122
# Epoch 1, Batch 161/240, MSE = 0.000121
# Epoch 1, Batch 162/240, MSE = 0.000129
# Epoch 1, Batch 163/240, MSE = 0.000133
# Epoch 1, Batch 164/240, MSE = 0.000121
# Epoch 1, Batch 165/240, MSE = 0.000132
# Epoch 1, Batch 166/240, MSE = 0.000123
# Epoch 1, Batch 167/240, MSE = 0.000127
# Epoch 1, Batch 168/240, MSE = 0.000126
# Epoch 1, Batch 169/240, MSE = 0.000126
# Epoch 1, Batch 170/240, MSE = 0.000124
# Epoch 1, Batch 171/240, MSE = 0.000147
# Epoch 1, Batch 172/240, MSE = 0.000130
# Epoch 1, Batch 173/240, MSE = 0.000126
# Epoch 1, Batch 174/240, MSE = 0.000135
# Epoch 1, Batch 175/240, MSE = 0.000133
# Epoch 1, Batch 176/240, MSE = 0.000134
# Epoch 1, Batch 177/240, MSE = 0.000139
# Epoch 1, Batch 178/240, MSE = 0.000117
# Epoch 1, Batch 179/240, MSE = 0.000133
# Epoch 1, Batch 180/240, MSE = 0.000140
# Epoch 1, Batch 181/240, MSE = 0.000145
# Epoch 1, Batch 182/240, MSE = 0.000115
# Epoch 1, Batch 183/240, MSE = 0.000118
# Epoch 1, Batch 184/240, MSE = 0.000125
# Epoch 1, Batch 185/240, MSE = 0.000131
# Epoch 1, Batch 186/240, MSE = 0.000111
# Epoch 1, Batch 187/240, MSE = 0.000136
# Epoch 1, Batch 188/240, MSE = 0.000127
# Epoch 1, Batch 189/240, MSE = 0.000130
# Epoch 1, Batch 190/240, MSE = 0.000117
# Epoch 1, Batch 191/240, MSE = 0.000136
# Epoch 1, Batch 192/240, MSE = 0.000135
# Epoch 1, Batch 193/240, MSE = 0.000124
# Epoch 1, Batch 194/240, MSE = 0.000113
# Epoch 1, Batch 195/240, MSE = 0.000129
# Epoch 1, Batch 196/240, MSE = 0.000131
# Epoch 1, Batch 197/240, MSE = 0.000135
# Epoch 1, Batch 198/240, MSE = 0.000136
# Epoch 1, Batch 199/240, MSE = 0.000126
# Epoch 1, Batch 200/240, MSE = 0.000117
# Epoch 1, Batch 201/240, MSE = 0.000134
# Epoch 1, Batch 202/240, MSE = 0.000121
# Epoch 1, Batch 203/240, MSE = 0.000132
# Epoch 1, Batch 204/240, MSE = 0.000137
# Epoch 1, Batch 205/240, MSE = 0.000124
# Epoch 1, Batch 206/240, MSE = 0.000119
# Epoch 1, Batch 207/240, MSE = 0.000130
# Epoch 1, Batch 208/240, MSE = 0.000123
# Epoch 1, Batch 209/240, MSE = 0.000135
# Epoch 1, Batch 210/240, MSE = 0.000137
# Epoch 1, Batch 211/240, MSE = 0.000122
# Epoch 1, Batch 212/240, MSE = 0.000149
# Epoch 1, Batch 213/240, MSE = 0.000129
# Epoch 1, Batch 214/240, MSE = 0.000139
# Epoch 1, Batch 215/240, MSE = 0.000127
# Epoch 1, Batch 216/240, MSE = 0.000128
# Epoch 1, Batch 217/240, MSE = 0.000129
# Epoch 1, Batch 218/240, MSE = 0.000124
# Epoch 1, Batch 219/240, MSE = 0.000143
# Epoch 1, Batch 220/240, MSE = 0.000120
# Epoch 1, Batch 221/240, MSE = 0.000151
# Epoch 1, Batch 222/240, MSE = 0.000140
# Epoch 1, Batch 223/240, MSE = 0.000132
# Epoch 1, Batch 224/240, MSE = 0.000134
# Epoch 1, Batch 225/240, MSE = 0.000134
# Epoch 1, Batch 226/240, MSE = 0.000132
# Epoch 1, Batch 227/240, MSE = 0.000131
# Epoch 1, Batch 228/240, MSE = 0.000125
# Epoch 1, Batch 229/240, MSE = 0.000134
# Epoch 1, Batch 230/240, MSE = 0.000145
# Epoch 1, Batch 231/240, MSE = 0.000142
# Epoch 1, Batch 232/240, MSE = 0.000132
# Epoch 1, Batch 233/240, MSE = 0.000116
# Epoch 1, Batch 234/240, MSE = 0.000136
# Epoch 1, Batch 235/240, MSE = 0.000132
# Epoch 1, Batch 236/240, MSE = 0.000154
# Epoch 1, Batch 237/240, MSE = 0.000124
# Epoch 1, Batch 238/240, MSE = 0.000122
# Epoch 1, Batch 239/240, MSE = 0.000136
# Epoch 1, Batch 240/240, MSE = 0.000148
#
# ============================================================
# Epoch 2/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.005833
# Epoch 1, Batch 2/240, MSE = 0.005490
# Epoch 1, Batch 3/240, MSE = 0.005483
# Epoch 1, Batch 4/240, MSE = 0.005378
# Epoch 1, Batch 5/240, MSE = 0.005422
# Epoch 1, Batch 6/240, MSE = 0.005554
# Epoch 1, Batch 7/240, MSE = 0.005372
# Epoch 1, Batch 8/240, MSE = 0.005364
# Epoch 1, Batch 9/240, MSE = 0.005345
# Epoch 1, Batch 10/240, MSE = 0.005616
# Epoch 1, Batch 11/240, MSE = 0.005379
# Epoch 1, Batch 12/240, MSE = 0.005510
# Epoch 1, Batch 13/240, MSE = 0.005656
# Epoch 1, Batch 14/240, MSE = 0.005388
# Epoch 1, Batch 15/240, MSE = 0.005444
# Epoch 1, Batch 16/240, MSE = 0.005591
# Epoch 1, Batch 17/240, MSE = 0.005549
# Epoch 1, Batch 18/240, MSE = 0.005381
# Epoch 1, Batch 19/240, MSE = 0.005685
# Epoch 1, Batch 20/240, MSE = 0.005450
# Epoch 1, Batch 21/240, MSE = 0.005432
# Epoch 1, Batch 22/240, MSE = 0.005418
# Epoch 1, Batch 23/240, MSE = 0.005364
# Epoch 1, Batch 24/240, MSE = 0.005447
# Epoch 1, Batch 25/240, MSE = 0.005460
# Epoch 1, Batch 26/240, MSE = 0.005292
# Epoch 1, Batch 27/240, MSE = 0.005260
# Epoch 1, Batch 28/240, MSE = 0.005269
# Epoch 1, Batch 29/240, MSE = 0.005326
# Epoch 1, Batch 30/240, MSE = 0.005360
# Epoch 1, Batch 31/240, MSE = 0.005434
# Epoch 1, Batch 32/240, MSE = 0.005451
# Epoch 1, Batch 33/240, MSE = 0.005491
# Epoch 1, Batch 34/240, MSE = 0.005320
# Epoch 1, Batch 35/240, MSE = 0.005510
# Epoch 1, Batch 36/240, MSE = 0.005613
# Epoch 1, Batch 37/240, MSE = 0.005318
# Epoch 1, Batch 38/240, MSE = 0.005257
# Epoch 1, Batch 39/240, MSE = 0.005448
# Epoch 1, Batch 40/240, MSE = 0.005207
# Epoch 1, Batch 41/240, MSE = 0.005231
# Epoch 1, Batch 42/240, MSE = 0.005498
# Epoch 1, Batch 43/240, MSE = 0.005134
# Epoch 1, Batch 44/240, MSE = 0.005519
# Epoch 1, Batch 45/240, MSE = 0.005436
# Epoch 1, Batch 46/240, MSE = 0.005572
# Epoch 1, Batch 47/240, MSE = 0.005208
# Epoch 1, Batch 48/240, MSE = 0.005217
# Epoch 1, Batch 49/240, MSE = 0.005233
# Epoch 1, Batch 50/240, MSE = 0.005267
# Epoch 1, Batch 51/240, MSE = 0.005342
# Epoch 1, Batch 52/240, MSE = 0.005185
# Epoch 1, Batch 53/240, MSE = 0.005189
# Epoch 1, Batch 54/240, MSE = 0.005411
# Epoch 1, Batch 55/240, MSE = 0.005165
# Epoch 1, Batch 56/240, MSE = 0.005137
# Epoch 1, Batch 57/240, MSE = 0.005311
# Epoch 1, Batch 58/240, MSE = 0.005366
# Epoch 1, Batch 59/240, MSE = 0.005263
# Epoch 1, Batch 60/240, MSE = 0.005461
# Epoch 1, Batch 61/240, MSE = 0.005437
# Epoch 1, Batch 62/240, MSE = 0.005468
# Epoch 1, Batch 63/240, MSE = 0.005221
# Epoch 1, Batch 64/240, MSE = 0.005131
# Epoch 1, Batch 65/240, MSE = 0.005264
# Epoch 1, Batch 66/240, MSE = 0.005188
# Epoch 1, Batch 67/240, MSE = 0.005307
# Epoch 1, Batch 68/240, MSE = 0.005386
# Epoch 1, Batch 69/240, MSE = 0.005284
# Epoch 1, Batch 70/240, MSE = 0.005175
# Epoch 1, Batch 71/240, MSE = 0.005181
# Epoch 1, Batch 72/240, MSE = 0.005014
# Epoch 1, Batch 73/240, MSE = 0.005091
# Epoch 1, Batch 74/240, MSE = 0.005041
# Epoch 1, Batch 75/240, MSE = 0.005124
# Epoch 1, Batch 76/240, MSE = 0.005231
# Epoch 1, Batch 77/240, MSE = 0.004968
# Epoch 1, Batch 78/240, MSE = 0.005106
# Epoch 1, Batch 79/240, MSE = 0.005082
# Epoch 1, Batch 80/240, MSE = 0.005132
# Epoch 1, Batch 81/240, MSE = 0.005146
# Epoch 1, Batch 82/240, MSE = 0.005106
# Epoch 1, Batch 83/240, MSE = 0.005076
# Epoch 1, Batch 84/240, MSE = 0.005252
# Epoch 1, Batch 85/240, MSE = 0.005022
# Epoch 1, Batch 86/240, MSE = 0.005056
# Epoch 1, Batch 87/240, MSE = 0.005252
# Epoch 1, Batch 88/240, MSE = 0.005107
# Epoch 1, Batch 89/240, MSE = 0.005034
# Epoch 1, Batch 90/240, MSE = 0.005080
# Epoch 1, Batch 91/240, MSE = 0.005166
# Epoch 1, Batch 92/240, MSE = 0.005007
# Epoch 1, Batch 93/240, MSE = 0.005335
# Epoch 1, Batch 94/240, MSE = 0.005162
# Epoch 1, Batch 95/240, MSE = 0.005117
# Epoch 1, Batch 96/240, MSE = 0.005133
# Epoch 1, Batch 97/240, MSE = 0.005157
# Epoch 1, Batch 98/240, MSE = 0.005003
# Epoch 1, Batch 99/240, MSE = 0.005003
# Epoch 1, Batch 100/240, MSE = 0.005156
# Epoch 1, Batch 101/240, MSE = 0.005033
# Epoch 1, Batch 102/240, MSE = 0.005117
# Epoch 1, Batch 103/240, MSE = 0.005014
# Epoch 1, Batch 104/240, MSE = 0.005005
# Epoch 1, Batch 105/240, MSE = 0.004958
# Epoch 1, Batch 106/240, MSE = 0.004821
# Epoch 1, Batch 107/240, MSE = 0.005071
# Epoch 1, Batch 108/240, MSE = 0.005001
# Epoch 1, Batch 109/240, MSE = 0.005187
# Epoch 1, Batch 110/240, MSE = 0.004954
# Epoch 1, Batch 111/240, MSE = 0.004930
# Epoch 1, Batch 112/240, MSE = 0.005133
# Epoch 1, Batch 113/240, MSE = 0.005098
# Epoch 1, Batch 114/240, MSE = 0.005065
# Epoch 1, Batch 115/240, MSE = 0.005121
# Epoch 1, Batch 116/240, MSE = 0.004917
# Epoch 1, Batch 117/240, MSE = 0.005040
# Epoch 1, Batch 118/240, MSE = 0.004878
# Epoch 1, Batch 119/240, MSE = 0.004905
# Epoch 1, Batch 120/240, MSE = 0.004872
# Epoch 1, Batch 121/240, MSE = 0.004958
# Epoch 1, Batch 122/240, MSE = 0.005036
# Epoch 1, Batch 123/240, MSE = 0.004999
# Epoch 1, Batch 124/240, MSE = 0.004971
# Epoch 1, Batch 125/240, MSE = 0.004876
# Epoch 1, Batch 126/240, MSE = 0.004959
# Epoch 1, Batch 127/240, MSE = 0.005167
# Epoch 1, Batch 128/240, MSE = 0.004936
# Epoch 1, Batch 129/240, MSE = 0.004964
# Epoch 1, Batch 130/240, MSE = 0.005141
# Epoch 1, Batch 131/240, MSE = 0.004936
# Epoch 1, Batch 132/240, MSE = 0.004931
# Epoch 1, Batch 133/240, MSE = 0.004868
# Epoch 1, Batch 134/240, MSE = 0.004838
# Epoch 1, Batch 135/240, MSE = 0.004810
# Epoch 1, Batch 136/240, MSE = 0.004908
# Epoch 1, Batch 137/240, MSE = 0.004941
# Epoch 1, Batch 138/240, MSE = 0.004857
# Epoch 1, Batch 139/240, MSE = 0.004868
# Epoch 1, Batch 140/240, MSE = 0.004969
# Epoch 1, Batch 141/240, MSE = 0.004956
# Epoch 1, Batch 142/240, MSE = 0.004942
# Epoch 1, Batch 143/240, MSE = 0.004833
# Epoch 1, Batch 144/240, MSE = 0.004882
# Epoch 1, Batch 145/240, MSE = 0.004918
# Epoch 1, Batch 146/240, MSE = 0.004737
# Epoch 1, Batch 147/240, MSE = 0.004847
# Epoch 1, Batch 148/240, MSE = 0.004886
# Epoch 1, Batch 149/240, MSE = 0.004857
# Epoch 1, Batch 150/240, MSE = 0.004928
# Epoch 1, Batch 151/240, MSE = 0.004879
# Epoch 1, Batch 152/240, MSE = 0.004856
# Epoch 1, Batch 153/240, MSE = 0.004925
# Epoch 1, Batch 154/240, MSE = 0.004737
# Epoch 1, Batch 155/240, MSE = 0.004821
# Epoch 1, Batch 156/240, MSE = 0.004829
# Epoch 1, Batch 157/240, MSE = 0.004820
# Epoch 1, Batch 158/240, MSE = 0.004778
# Epoch 1, Batch 159/240, MSE = 0.004914
# Epoch 1, Batch 160/240, MSE = 0.004780
# Epoch 1, Batch 161/240, MSE = 0.004719
# Epoch 1, Batch 162/240, MSE = 0.004776
# Epoch 1, Batch 163/240, MSE = 0.004660
# Epoch 1, Batch 164/240, MSE = 0.004654
# Epoch 1, Batch 165/240, MSE = 0.004638
# Epoch 1, Batch 166/240, MSE = 0.004800
# Epoch 1, Batch 167/240, MSE = 0.004781
# Epoch 1, Batch 168/240, MSE = 0.004860
# Epoch 1, Batch 169/240, MSE = 0.004718
# Epoch 1, Batch 170/240, MSE = 0.004680
# Epoch 1, Batch 171/240, MSE = 0.004792
# Epoch 1, Batch 172/240, MSE = 0.004862
# Epoch 1, Batch 173/240, MSE = 0.004692
# Epoch 1, Batch 174/240, MSE = 0.004632
# Epoch 1, Batch 175/240, MSE = 0.004740
# Epoch 1, Batch 176/240, MSE = 0.004628
# Epoch 1, Batch 177/240, MSE = 0.004735
# Epoch 1, Batch 178/240, MSE = 0.004741
# Epoch 1, Batch 179/240, MSE = 0.004816
# Epoch 1, Batch 180/240, MSE = 0.004733
# Epoch 1, Batch 181/240, MSE = 0.004749
# Epoch 1, Batch 182/240, MSE = 0.004739
# Epoch 1, Batch 183/240, MSE = 0.004710
# Epoch 1, Batch 184/240, MSE = 0.004653
# Epoch 1, Batch 185/240, MSE = 0.004627
# Epoch 1, Batch 186/240, MSE = 0.004766
# Epoch 1, Batch 187/240, MSE = 0.004682
# Epoch 1, Batch 188/240, MSE = 0.004649
# Epoch 1, Batch 189/240, MSE = 0.004627
# Epoch 1, Batch 190/240, MSE = 0.004705
# Epoch 1, Batch 191/240, MSE = 0.004717
# Epoch 1, Batch 192/240, MSE = 0.004674
# Epoch 1, Batch 193/240, MSE = 0.004571
# Epoch 1, Batch 194/240, MSE = 0.004662
# Epoch 1, Batch 195/240, MSE = 0.004631
# Epoch 1, Batch 196/240, MSE = 0.004658
# Epoch 1, Batch 197/240, MSE = 0.004497
# Epoch 1, Batch 198/240, MSE = 0.004582
# Epoch 1, Batch 199/240, MSE = 0.004565
# Epoch 1, Batch 200/240, MSE = 0.004621
# Epoch 1, Batch 201/240, MSE = 0.004576
# Epoch 1, Batch 202/240, MSE = 0.004565
# Epoch 1, Batch 203/240, MSE = 0.004642
# Epoch 1, Batch 204/240, MSE = 0.004496
# Epoch 1, Batch 205/240, MSE = 0.004537
# Epoch 1, Batch 206/240, MSE = 0.004514
# Epoch 1, Batch 207/240, MSE = 0.004664
# Epoch 1, Batch 208/240, MSE = 0.004554
# Epoch 1, Batch 209/240, MSE = 0.004544
# Epoch 1, Batch 210/240, MSE = 0.004522
# Epoch 1, Batch 211/240, MSE = 0.004610
# Epoch 1, Batch 212/240, MSE = 0.004608
# Epoch 1, Batch 213/240, MSE = 0.004460
# Epoch 1, Batch 214/240, MSE = 0.004514
# Epoch 1, Batch 215/240, MSE = 0.004513
# Epoch 1, Batch 216/240, MSE = 0.004584
# Epoch 1, Batch 217/240, MSE = 0.004467
# Epoch 1, Batch 218/240, MSE = 0.004429
# Epoch 1, Batch 219/240, MSE = 0.004540
# Epoch 1, Batch 220/240, MSE = 0.004531
# Epoch 1, Batch 221/240, MSE = 0.004517
# Epoch 1, Batch 222/240, MSE = 0.004514
# Epoch 1, Batch 223/240, MSE = 0.004436
# Epoch 1, Batch 224/240, MSE = 0.004556
# Epoch 1, Batch 225/240, MSE = 0.004450
# Epoch 1, Batch 226/240, MSE = 0.004466
# Epoch 1, Batch 227/240, MSE = 0.004417
# Epoch 1, Batch 228/240, MSE = 0.004420
# Epoch 1, Batch 229/240, MSE = 0.004403
# Epoch 1, Batch 230/240, MSE = 0.004434
# Epoch 1, Batch 231/240, MSE = 0.004436
# Epoch 1, Batch 232/240, MSE = 0.004439
# Epoch 1, Batch 233/240, MSE = 0.004453
# Epoch 1, Batch 234/240, MSE = 0.004430
# Epoch 1, Batch 235/240, MSE = 0.004475
# Epoch 1, Batch 236/240, MSE = 0.004453
# Epoch 1, Batch 237/240, MSE = 0.004440
# Epoch 1, Batch 238/240, MSE = 0.004452
# Epoch 1, Batch 239/240, MSE = 0.004405
# Epoch 1, Batch 240/240, MSE = 0.004349
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.001166
# Epoch 1, Batch 2/240, MSE = 0.001104
# Epoch 1, Batch 3/240, MSE = 0.001154
# Epoch 1, Batch 4/240, MSE = 0.001227
# Epoch 1, Batch 5/240, MSE = 0.001298
# Epoch 1, Batch 6/240, MSE = 0.001187
# Epoch 1, Batch 7/240, MSE = 0.001069
# Epoch 1, Batch 8/240, MSE = 0.001122
# Epoch 1, Batch 9/240, MSE = 0.001091
# Epoch 1, Batch 10/240, MSE = 0.001193
# Epoch 1, Batch 11/240, MSE = 0.001091
# Epoch 1, Batch 12/240, MSE = 0.001143
# Epoch 1, Batch 13/240, MSE = 0.001043
# Epoch 1, Batch 14/240, MSE = 0.001003
# Epoch 1, Batch 15/240, MSE = 0.001072
# Epoch 1, Batch 16/240, MSE = 0.001063
# Epoch 1, Batch 17/240, MSE = 0.001262
# Epoch 1, Batch 18/240, MSE = 0.001025
# Epoch 1, Batch 19/240, MSE = 0.001264
# Epoch 1, Batch 20/240, MSE = 0.001112
# Epoch 1, Batch 21/240, MSE = 0.001245
# Epoch 1, Batch 22/240, MSE = 0.001107
# Epoch 1, Batch 23/240, MSE = 0.001211
# Epoch 1, Batch 24/240, MSE = 0.001154
# Epoch 1, Batch 25/240, MSE = 0.001289
# Epoch 1, Batch 26/240, MSE = 0.001138
# Epoch 1, Batch 27/240, MSE = 0.001045
# Epoch 1, Batch 28/240, MSE = 0.001080
# Epoch 1, Batch 29/240, MSE = 0.001204
# Epoch 1, Batch 30/240, MSE = 0.001141
# Epoch 1, Batch 31/240, MSE = 0.001310
# Epoch 1, Batch 32/240, MSE = 0.001047
# Epoch 1, Batch 33/240, MSE = 0.001079
# Epoch 1, Batch 34/240, MSE = 0.001104
# Epoch 1, Batch 35/240, MSE = 0.001204
# Epoch 1, Batch 36/240, MSE = 0.001131
# Epoch 1, Batch 37/240, MSE = 0.001125
# Epoch 1, Batch 38/240, MSE = 0.001206
# Epoch 1, Batch 39/240, MSE = 0.001171
# Epoch 1, Batch 40/240, MSE = 0.001053
# Epoch 1, Batch 41/240, MSE = 0.001100
# Epoch 1, Batch 42/240, MSE = 0.001226
# Epoch 1, Batch 43/240, MSE = 0.000985
# Epoch 1, Batch 44/240, MSE = 0.001086
# Epoch 1, Batch 45/240, MSE = 0.001082
# Epoch 1, Batch 46/240, MSE = 0.001162
# Epoch 1, Batch 47/240, MSE = 0.001128
# Epoch 1, Batch 48/240, MSE = 0.001144
# Epoch 1, Batch 49/240, MSE = 0.001235
# Epoch 1, Batch 50/240, MSE = 0.001023
# Epoch 1, Batch 51/240, MSE = 0.001118
# Epoch 1, Batch 52/240, MSE = 0.001150
# Epoch 1, Batch 53/240, MSE = 0.001100
# Epoch 1, Batch 54/240, MSE = 0.001285
# Epoch 1, Batch 55/240, MSE = 0.001127
# Epoch 1, Batch 56/240, MSE = 0.001050
# Epoch 1, Batch 57/240, MSE = 0.001087
# Epoch 1, Batch 58/240, MSE = 0.001027
# Epoch 1, Batch 59/240, MSE = 0.001168
# Epoch 1, Batch 60/240, MSE = 0.001200
# Epoch 1, Batch 61/240, MSE = 0.000959
# Epoch 1, Batch 62/240, MSE = 0.001084
# Epoch 1, Batch 63/240, MSE = 0.001194
# Epoch 1, Batch 64/240, MSE = 0.001045
# Epoch 1, Batch 65/240, MSE = 0.001067
# Epoch 1, Batch 66/240, MSE = 0.001225
# Epoch 1, Batch 67/240, MSE = 0.001113
# Epoch 1, Batch 68/240, MSE = 0.001233
# Epoch 1, Batch 69/240, MSE = 0.001023
# Epoch 1, Batch 70/240, MSE = 0.001132
# Epoch 1, Batch 71/240, MSE = 0.001118
# Epoch 1, Batch 72/240, MSE = 0.001125
# Epoch 1, Batch 73/240, MSE = 0.001160
# Epoch 1, Batch 74/240, MSE = 0.001096
# Epoch 1, Batch 75/240, MSE = 0.001018
# Epoch 1, Batch 76/240, MSE = 0.001044
# Epoch 1, Batch 77/240, MSE = 0.001096
# Epoch 1, Batch 78/240, MSE = 0.001099
# Epoch 1, Batch 79/240, MSE = 0.001139
# Epoch 1, Batch 80/240, MSE = 0.001087
# Epoch 1, Batch 81/240, MSE = 0.001064
# Epoch 1, Batch 82/240, MSE = 0.001195
# Epoch 1, Batch 83/240, MSE = 0.000997
# Epoch 1, Batch 84/240, MSE = 0.001198
# Epoch 1, Batch 85/240, MSE = 0.001271
# Epoch 1, Batch 86/240, MSE = 0.001156
# Epoch 1, Batch 87/240, MSE = 0.001163
# Epoch 1, Batch 88/240, MSE = 0.001094
# Epoch 1, Batch 89/240, MSE = 0.001121
# Epoch 1, Batch 90/240, MSE = 0.001161
# Epoch 1, Batch 91/240, MSE = 0.001129
# Epoch 1, Batch 92/240, MSE = 0.001061
# Epoch 1, Batch 93/240, MSE = 0.001192
# Epoch 1, Batch 94/240, MSE = 0.000918
# Epoch 1, Batch 95/240, MSE = 0.001103
# Epoch 1, Batch 96/240, MSE = 0.001086
# Epoch 1, Batch 97/240, MSE = 0.001093
# Epoch 1, Batch 98/240, MSE = 0.001005
# Epoch 1, Batch 99/240, MSE = 0.001369
# Epoch 1, Batch 100/240, MSE = 0.001131
# Epoch 1, Batch 101/240, MSE = 0.001137
# Epoch 1, Batch 102/240, MSE = 0.000927
# Epoch 1, Batch 103/240, MSE = 0.001080
# Epoch 1, Batch 104/240, MSE = 0.001122
# Epoch 1, Batch 105/240, MSE = 0.001173
# Epoch 1, Batch 106/240, MSE = 0.001134
# Epoch 1, Batch 107/240, MSE = 0.001051
# Epoch 1, Batch 108/240, MSE = 0.001134
# Epoch 1, Batch 109/240, MSE = 0.001096
# Epoch 1, Batch 110/240, MSE = 0.001030
# Epoch 1, Batch 111/240, MSE = 0.001137
# Epoch 1, Batch 112/240, MSE = 0.001162
# Epoch 1, Batch 113/240, MSE = 0.001067
# Epoch 1, Batch 114/240, MSE = 0.001086
# Epoch 1, Batch 115/240, MSE = 0.001214
# Epoch 1, Batch 116/240, MSE = 0.001202
# Epoch 1, Batch 117/240, MSE = 0.001089
# Epoch 1, Batch 118/240, MSE = 0.001139
# Epoch 1, Batch 119/240, MSE = 0.000921
# Epoch 1, Batch 120/240, MSE = 0.001089
# Epoch 1, Batch 121/240, MSE = 0.001052
# Epoch 1, Batch 122/240, MSE = 0.000927
# Epoch 1, Batch 123/240, MSE = 0.001194
# Epoch 1, Batch 124/240, MSE = 0.000981
# Epoch 1, Batch 125/240, MSE = 0.001142
# Epoch 1, Batch 126/240, MSE = 0.001011
# Epoch 1, Batch 127/240, MSE = 0.001132
# Epoch 1, Batch 128/240, MSE = 0.001138
# Epoch 1, Batch 129/240, MSE = 0.001146
# Epoch 1, Batch 130/240, MSE = 0.001282
# Epoch 1, Batch 131/240, MSE = 0.001218
# Epoch 1, Batch 132/240, MSE = 0.001020
# Epoch 1, Batch 133/240, MSE = 0.001176
# Epoch 1, Batch 134/240, MSE = 0.001210
# Epoch 1, Batch 135/240, MSE = 0.001236
# Epoch 1, Batch 136/240, MSE = 0.001043
# Epoch 1, Batch 137/240, MSE = 0.001069
# Epoch 1, Batch 138/240, MSE = 0.001047
# Epoch 1, Batch 139/240, MSE = 0.001143
# Epoch 1, Batch 140/240, MSE = 0.001123
# Epoch 1, Batch 141/240, MSE = 0.001065
# Epoch 1, Batch 142/240, MSE = 0.001086
# Epoch 1, Batch 143/240, MSE = 0.001129
# Epoch 1, Batch 144/240, MSE = 0.001194
# Epoch 1, Batch 145/240, MSE = 0.001189
# Epoch 1, Batch 146/240, MSE = 0.001087
# Epoch 1, Batch 147/240, MSE = 0.000989
# Epoch 1, Batch 148/240, MSE = 0.001091
# Epoch 1, Batch 149/240, MSE = 0.000977
# Epoch 1, Batch 150/240, MSE = 0.001034
# Epoch 1, Batch 151/240, MSE = 0.000924
# Epoch 1, Batch 152/240, MSE = 0.001170
# Epoch 1, Batch 153/240, MSE = 0.001205
# Epoch 1, Batch 154/240, MSE = 0.001016
# Epoch 1, Batch 155/240, MSE = 0.001034
# Epoch 1, Batch 156/240, MSE = 0.001313
# Epoch 1, Batch 157/240, MSE = 0.001184
# Epoch 1, Batch 158/240, MSE = 0.001044
# Epoch 1, Batch 159/240, MSE = 0.001045
# Epoch 1, Batch 160/240, MSE = 0.001055
# Epoch 1, Batch 161/240, MSE = 0.001139
# Epoch 1, Batch 162/240, MSE = 0.001087
# Epoch 1, Batch 163/240, MSE = 0.001216
# Epoch 1, Batch 164/240, MSE = 0.001021
# Epoch 1, Batch 165/240, MSE = 0.001216
# Epoch 1, Batch 166/240, MSE = 0.001225
# Epoch 1, Batch 167/240, MSE = 0.001034
# Epoch 1, Batch 168/240, MSE = 0.001170
# Epoch 1, Batch 169/240, MSE = 0.001081
# Epoch 1, Batch 170/240, MSE = 0.001027
# Epoch 1, Batch 171/240, MSE = 0.001130
# Epoch 1, Batch 172/240, MSE = 0.001092
# Epoch 1, Batch 173/240, MSE = 0.001116
# Epoch 1, Batch 174/240, MSE = 0.000959
# Epoch 1, Batch 175/240, MSE = 0.001031
# Epoch 1, Batch 176/240, MSE = 0.001003
# Epoch 1, Batch 177/240, MSE = 0.001005
# Epoch 1, Batch 178/240, MSE = 0.001044
# Epoch 1, Batch 179/240, MSE = 0.001079
# Epoch 1, Batch 180/240, MSE = 0.000999
# Epoch 1, Batch 181/240, MSE = 0.001198
# Epoch 1, Batch 182/240, MSE = 0.001194
# Epoch 1, Batch 183/240, MSE = 0.001223
# Epoch 1, Batch 184/240, MSE = 0.000986
# Epoch 1, Batch 185/240, MSE = 0.001102
# Epoch 1, Batch 186/240, MSE = 0.001156
# Epoch 1, Batch 187/240, MSE = 0.001213
# Epoch 1, Batch 188/240, MSE = 0.001231
# Epoch 1, Batch 189/240, MSE = 0.001013
# Epoch 1, Batch 190/240, MSE = 0.001000
# Epoch 1, Batch 191/240, MSE = 0.001078
# Epoch 1, Batch 192/240, MSE = 0.001113
# Epoch 1, Batch 193/240, MSE = 0.001047
# Epoch 1, Batch 194/240, MSE = 0.001021
# Epoch 1, Batch 195/240, MSE = 0.001119
# Epoch 1, Batch 196/240, MSE = 0.001193
# Epoch 1, Batch 197/240, MSE = 0.001155
# Epoch 1, Batch 198/240, MSE = 0.001131
# Epoch 1, Batch 199/240, MSE = 0.001096
# Epoch 1, Batch 200/240, MSE = 0.001217
# Epoch 1, Batch 201/240, MSE = 0.001131
# Epoch 1, Batch 202/240, MSE = 0.001049
# Epoch 1, Batch 203/240, MSE = 0.001232
# Epoch 1, Batch 204/240, MSE = 0.001022
# Epoch 1, Batch 205/240, MSE = 0.001082
# Epoch 1, Batch 206/240, MSE = 0.001052
# Epoch 1, Batch 207/240, MSE = 0.001319
# Epoch 1, Batch 208/240, MSE = 0.000989
# Epoch 1, Batch 209/240, MSE = 0.001116
# Epoch 1, Batch 210/240, MSE = 0.001028
# Epoch 1, Batch 211/240, MSE = 0.001083
# Epoch 1, Batch 212/240, MSE = 0.000953
# Epoch 1, Batch 213/240, MSE = 0.001148
# Epoch 1, Batch 214/240, MSE = 0.000994
# Epoch 1, Batch 215/240, MSE = 0.001117
# Epoch 1, Batch 216/240, MSE = 0.001140
# Epoch 1, Batch 217/240, MSE = 0.001031
# Epoch 1, Batch 218/240, MSE = 0.001052
# Epoch 1, Batch 219/240, MSE = 0.001208
# Epoch 1, Batch 220/240, MSE = 0.001039
# Epoch 1, Batch 221/240, MSE = 0.001031
# Epoch 1, Batch 222/240, MSE = 0.000998
# Epoch 1, Batch 223/240, MSE = 0.001092
# Epoch 1, Batch 224/240, MSE = 0.001113
# Epoch 1, Batch 225/240, MSE = 0.000954
# Epoch 1, Batch 226/240, MSE = 0.001165
# Epoch 1, Batch 227/240, MSE = 0.000940
# Epoch 1, Batch 228/240, MSE = 0.001080
# Epoch 1, Batch 229/240, MSE = 0.001015
# Epoch 1, Batch 230/240, MSE = 0.001021
# Epoch 1, Batch 231/240, MSE = 0.001079
# Epoch 1, Batch 232/240, MSE = 0.001071
# Epoch 1, Batch 233/240, MSE = 0.001036
# Epoch 1, Batch 234/240, MSE = 0.001113
# Epoch 1, Batch 235/240, MSE = 0.001118
# Epoch 1, Batch 236/240, MSE = 0.001156
# Epoch 1, Batch 237/240, MSE = 0.001152
# Epoch 1, Batch 238/240, MSE = 0.001111
# Epoch 1, Batch 239/240, MSE = 0.001100
# Epoch 1, Batch 240/240, MSE = 0.001045
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.000207
# Epoch 1, Batch 2/240, MSE = 0.000305
# Epoch 1, Batch 3/240, MSE = 0.000259
# Epoch 1, Batch 4/240, MSE = 0.000220
# Epoch 1, Batch 5/240, MSE = 0.000241
# Epoch 1, Batch 6/240, MSE = 0.000172
# Epoch 1, Batch 7/240, MSE = 0.000242
# Epoch 1, Batch 8/240, MSE = 0.000217
# Epoch 1, Batch 9/240, MSE = 0.000265
# Epoch 1, Batch 10/240, MSE = 0.000297
# Epoch 1, Batch 11/240, MSE = 0.000250
# Epoch 1, Batch 12/240, MSE = 0.000206
# Epoch 1, Batch 13/240, MSE = 0.000228
# Epoch 1, Batch 14/240, MSE = 0.000216
# Epoch 1, Batch 15/240, MSE = 0.000260
# Epoch 1, Batch 16/240, MSE = 0.000220
# Epoch 1, Batch 17/240, MSE = 0.000225
# Epoch 1, Batch 18/240, MSE = 0.000226
# Epoch 1, Batch 19/240, MSE = 0.000225
# Epoch 1, Batch 20/240, MSE = 0.000218
# ...
# Epoch 1, Batch 69/240, MSE = 0.000125
# Epoch 1, Batch 70/240, MSE = 0.000121
# Epoch 1, Batch 71/240, MSE = 0.000127
# Epoch 1, Batch 72/240, MSE = 0.000107
# Epoch 1, Batch 73/240, MSE = 0.000115
# Epoch 1, Batch 74/240, MSE = 0.000101
# Epoch 1, Batch 75/240, MSE = 0.000127
# Epoch 1, Batch 76/240, MSE = 0.000128
# Epoch 1, Batch 77/240, MSE = 0.000111
# Epoch 1, Batch 78/240, MSE = 0.000108
# Epoch 1, Batch 79/240, MSE = 0.000102
# Epoch 1, Batch 80/240, MSE = 0.000121
# Epoch 1, Batch 81/240, MSE = 0.000125
# Epoch 1, Batch 82/240, MSE = 0.000105
# Epoch 1, Batch 83/240, MSE = 0.000113
# Epoch 1, Batch 84/240, MSE = 0.000116
# Epoch 1, Batch 85/240, MSE = 0.000111
# Epoch 1, Batch 86/240, MSE = 0.000109
# Epoch 1, Batch 87/240, MSE = 0.000116
# Epoch 1, Batch 88/240, MSE = 0.000120
# Epoch 1, Batch 89/240, MSE = 0.000108
# Epoch 1, Batch 90/240, MSE = 0.000103
# Epoch 1, Batch 91/240, MSE = 0.000118
# Epoch 1, Batch 92/240, MSE = 0.000103
# Epoch 1, Batch 93/240, MSE = 0.000108
# Epoch 1, Batch 94/240, MSE = 0.000118
# Epoch 1, Batch 95/240, MSE = 0.000110
# Epoch 1, Batch 96/240, MSE = 0.000109
# Epoch 1, Batch 97/240, MSE = 0.000130
# Epoch 1, Batch 98/240, MSE = 0.000117
# Epoch 1, Batch 99/240, MSE = 0.000111
# Epoch 1, Batch 100/240, MSE = 0.000118
# Epoch 1, Batch 101/240, MSE = 0.000118
# Epoch 1, Batch 102/240, MSE = 0.000114
# Epoch 1, Batch 103/240, MSE = 0.000114
# Epoch 1, Batch 104/240, MSE = 0.000114
# Epoch 1, Batch 105/240, MSE = 0.000114
# Epoch 1, Batch 106/240, MSE = 0.000117
# Epoch 1, Batch 107/240, MSE = 0.000114
# Epoch 1, Batch 108/240, MSE = 0.000108
# Epoch 1, Batch 109/240, MSE = 0.000121
# Epoch 1, Batch 110/240, MSE = 0.000103
# Epoch 1, Batch 111/240, MSE = 0.000109
# Epoch 1, Batch 112/240, MSE = 0.000114
# Epoch 1, Batch 113/240, MSE = 0.000116
# Epoch 1, Batch 114/240, MSE = 0.000106
# Epoch 1, Batch 115/240, MSE = 0.000107
# Epoch 1, Batch 116/240, MSE = 0.000119
# Epoch 1, Batch 117/240, MSE = 0.000118
# Epoch 1, Batch 118/240, MSE = 0.000110
# Epoch 1, Batch 119/240, MSE = 0.000106
# Epoch 1, Batch 120/240, MSE = 0.000121
# Epoch 1, Batch 121/240, MSE = 0.000106
# Epoch 1, Batch 122/240, MSE = 0.000114
# Epoch 1, Batch 123/240, MSE = 0.000104
# Epoch 1, Batch 124/240, MSE = 0.000101
# Epoch 1, Batch 125/240, MSE = 0.000109
# Epoch 1, Batch 126/240, MSE = 0.000109
# Epoch 1, Batch 127/240, MSE = 0.000114
# Epoch 1, Batch 128/240, MSE = 0.000122
# Epoch 1, Batch 129/240, MSE = 0.000112
# Epoch 1, Batch 130/240, MSE = 0.000105
# Epoch 1, Batch 131/240, MSE = 0.000110
# Epoch 1, Batch 132/240, MSE = 0.000106
# Epoch 1, Batch 133/240, MSE = 0.000101
# Epoch 1, Batch 134/240, MSE = 0.000105
# Epoch 1, Batch 135/240, MSE = 0.000123
# Epoch 1, Batch 136/240, MSE = 0.000105
# Epoch 1, Batch 137/240, MSE = 0.000110
# Epoch 1, Batch 138/240, MSE = 0.000120
# Epoch 1, Batch 139/240, MSE = 0.000104
# Epoch 1, Batch 140/240, MSE = 0.000108
# Epoch 1, Batch 141/240, MSE = 0.000120
# Epoch 1, Batch 142/240, MSE = 0.000102
# Epoch 1, Batch 143/240, MSE = 0.000113
# Epoch 1, Batch 144/240, MSE = 0.000115
# Epoch 1, Batch 145/240, MSE = 0.000112
# Epoch 1, Batch 146/240, MSE = 0.000111
# Epoch 1, Batch 147/240, MSE = 0.000118
# Epoch 1, Batch 148/240, MSE = 0.000107
# Epoch 1, Batch 149/240, MSE = 0.000119
# Epoch 1, Batch 150/240, MSE = 0.000118
# Epoch 1, Batch 151/240, MSE = 0.000097
# Epoch 1, Batch 152/240, MSE = 0.000119
# Epoch 1, Batch 153/240, MSE = 0.000105
# Epoch 1, Batch 154/240, MSE = 0.000105
# Epoch 1, Batch 155/240, MSE = 0.000116
# Epoch 1, Batch 156/240, MSE = 0.000108
# Epoch 1, Batch 157/240, MSE = 0.000108
# Epoch 1, Batch 158/240, MSE = 0.000107
# Epoch 1, Batch 159/240, MSE = 0.000116
# Epoch 1, Batch 160/240, MSE = 0.000121
# Epoch 1, Batch 161/240, MSE = 0.000102
# Epoch 1, Batch 162/240, MSE = 0.000095
# Epoch 1, Batch 163/240, MSE = 0.000109
# Epoch 1, Batch 164/240, MSE = 0.000105
# Epoch 1, Batch 165/240, MSE = 0.000101
# Epoch 1, Batch 166/240, MSE = 0.000106
# Epoch 1, Batch 167/240, MSE = 0.000097
# Epoch 1, Batch 168/240, MSE = 0.000096
# Epoch 1, Batch 169/240, MSE = 0.000119
# Epoch 1, Batch 170/240, MSE = 0.000104
# Epoch 1, Batch 171/240, MSE = 0.000099
# Epoch 1, Batch 172/240, MSE = 0.000107
# Epoch 1, Batch 173/240, MSE = 0.000109
# Epoch 1, Batch 174/240, MSE = 0.000110
# Epoch 1, Batch 175/240, MSE = 0.000096
# Epoch 1, Batch 176/240, MSE = 0.000109
# Epoch 1, Batch 177/240, MSE = 0.000113
# Epoch 1, Batch 178/240, MSE = 0.000096
# Epoch 1, Batch 179/240, MSE = 0.000099
# Epoch 1, Batch 180/240, MSE = 0.000103
# Epoch 1, Batch 181/240, MSE = 0.000104
# Epoch 1, Batch 182/240, MSE = 0.000108
# Epoch 1, Batch 183/240, MSE = 0.000095
# Epoch 1, Batch 184/240, MSE = 0.000097
# Epoch 1, Batch 185/240, MSE = 0.000103
# Epoch 1, Batch 186/240, MSE = 0.000123
# Epoch 1, Batch 187/240, MSE = 0.000106
# Epoch 1, Batch 188/240, MSE = 0.000113
# Epoch 1, Batch 189/240, MSE = 0.000108
# Epoch 1, Batch 190/240, MSE = 0.000108
# Epoch 1, Batch 191/240, MSE = 0.000109
# Epoch 1, Batch 192/240, MSE = 0.000103
# Epoch 1, Batch 193/240, MSE = 0.000106
# Epoch 1, Batch 194/240, MSE = 0.000114
# Epoch 1, Batch 195/240, MSE = 0.000118
# Epoch 1, Batch 196/240, MSE = 0.000100
# Epoch 1, Batch 197/240, MSE = 0.000092
# Epoch 1, Batch 198/240, MSE = 0.000106
# Epoch 1, Batch 199/240, MSE = 0.000108
# Epoch 1, Batch 200/240, MSE = 0.000098
# Epoch 1, Batch 201/240, MSE = 0.000107
# Epoch 1, Batch 202/240, MSE = 0.000099
# Epoch 1, Batch 203/240, MSE = 0.000113
# Epoch 1, Batch 204/240, MSE = 0.000102
# Epoch 1, Batch 205/240, MSE = 0.000101
# Epoch 1, Batch 206/240, MSE = 0.000108
# Epoch 1, Batch 207/240, MSE = 0.000109
# Epoch 1, Batch 208/240, MSE = 0.000103
# Epoch 1, Batch 209/240, MSE = 0.000110
# Epoch 1, Batch 210/240, MSE = 0.000096
# Epoch 1, Batch 211/240, MSE = 0.000101
# Epoch 1, Batch 212/240, MSE = 0.000115
# Epoch 1, Batch 213/240, MSE = 0.000107
# Epoch 1, Batch 214/240, MSE = 0.000100
# Epoch 1, Batch 215/240, MSE = 0.000103
# Epoch 1, Batch 216/240, MSE = 0.000102
# Epoch 1, Batch 217/240, MSE = 0.000104
# Epoch 1, Batch 218/240, MSE = 0.000097
# Epoch 1, Batch 219/240, MSE = 0.000115
# Epoch 1, Batch 220/240, MSE = 0.000108
# Epoch 1, Batch 221/240, MSE = 0.000099
# Epoch 1, Batch 222/240, MSE = 0.000104
# Epoch 1, Batch 223/240, MSE = 0.000098
# Epoch 1, Batch 224/240, MSE = 0.000112
# Epoch 1, Batch 225/240, MSE = 0.000095
# Epoch 1, Batch 226/240, MSE = 0.000103
# Epoch 1, Batch 227/240, MSE = 0.000108
# Epoch 1, Batch 228/240, MSE = 0.000091
# Epoch 1, Batch 229/240, MSE = 0.000113
# Epoch 1, Batch 230/240, MSE = 0.000116
# Epoch 1, Batch 231/240, MSE = 0.000107
# Epoch 1, Batch 232/240, MSE = 0.000097
# Epoch 1, Batch 233/240, MSE = 0.000109
# Epoch 1, Batch 234/240, MSE = 0.000099
# Epoch 1, Batch 235/240, MSE = 0.000110
# Epoch 1, Batch 236/240, MSE = 0.000096
# Epoch 1, Batch 237/240, MSE = 0.000105
# Epoch 1, Batch 238/240, MSE = 0.000108
# Epoch 1, Batch 239/240, MSE = 0.000090
# Epoch 1, Batch 240/240, MSE = 0.000110
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.001929
# Epoch 1, Batch 2/240, MSE = 0.001761
# Epoch 1, Batch 3/240, MSE = 0.001853
# Epoch 1, Batch 4/240, MSE = 0.001789
# Epoch 1, Batch 5/240, MSE = 0.001946
# Epoch 1, Batch 6/240, MSE = 0.001847
# Epoch 1, Batch 7/240, MSE = 0.001818
# Epoch 1, Batch 8/240, MSE = 0.001778
# Epoch 1, Batch 9/240, MSE = 0.001852
# Epoch 1, Batch 10/240, MSE = 0.001868
# Epoch 1, Batch 11/240, MSE = 0.001741
# Epoch 1, Batch 12/240, MSE = 0.001727
# Epoch 1, Batch 13/240, MSE = 0.001778
# Epoch 1, Batch 14/240, MSE = 0.001681
# Epoch 1, Batch 15/240, MSE = 0.001865
# Epoch 1, Batch 16/240, MSE = 0.001813
# Epoch 1, Batch 17/240, MSE = 0.001954
# Epoch 1, Batch 18/240, MSE = 0.001737
# Epoch 1, Batch 19/240, MSE = 0.001814
# Epoch 1, Batch 20/240, MSE = 0.001727
# Epoch 1, Batch 21/240, MSE = 0.001784
# Epoch 1, Batch 22/240, MSE = 0.001954
# Epoch 1, Batch 23/240, MSE = 0.001780
# Epoch 1, Batch 24/240, MSE = 0.001746
# Epoch 1, Batch 25/240, MSE = 0.001938
# Epoch 1, Batch 26/240, MSE = 0.001890
# Epoch 1, Batch 27/240, MSE = 0.001865
# Epoch 1, Batch 28/240, MSE = 0.001816
# Epoch 1, Batch 29/240, MSE = 0.001780
# Epoch 1, Batch 30/240, MSE = 0.001772
# Epoch 1, Batch 31/240, MSE = 0.001734
# Epoch 1, Batch 32/240, MSE = 0.001759
# Epoch 1, Batch 33/240, MSE = 0.001844
# Epoch 1, Batch 34/240, MSE = 0.001622
# Epoch 1, Batch 35/240, MSE = 0.001704
# Epoch 1, Batch 36/240, MSE = 0.001829
# Epoch 1, Batch 37/240, MSE = 0.001826
# Epoch 1, Batch 38/240, MSE = 0.001652
# Epoch 1, Batch 39/240, MSE = 0.001805
# Epoch 1, Batch 40/240, MSE = 0.001810
# Epoch 1, Batch 41/240, MSE = 0.001752
# Epoch 1, Batch 42/240, MSE = 0.001675
# Epoch 1, Batch 43/240, MSE = 0.001785
# Epoch 1, Batch 44/240, MSE = 0.001819
# Epoch 1, Batch 45/240, MSE = 0.001784
# Epoch 1, Batch 46/240, MSE = 0.001829
# Epoch 1, Batch 47/240, MSE = 0.001742
# Epoch 1, Batch 48/240, MSE = 0.001636
# Epoch 1, Batch 49/240, MSE = 0.001742
# Epoch 1, Batch 50/240, MSE = 0.001629
# Epoch 1, Batch 51/240, MSE = 0.001728
# Epoch 1, Batch 52/240, MSE = 0.001720
# Epoch 1, Batch 53/240, MSE = 0.001865
# Epoch 1, Batch 54/240, MSE = 0.001694
# Epoch 1, Batch 55/240, MSE = 0.001798
# Epoch 1, Batch 56/240, MSE = 0.001743
# Epoch 1, Batch 57/240, MSE = 0.001795
# Epoch 1, Batch 58/240, MSE = 0.001725
# Epoch 1, Batch 59/240, MSE = 0.001772
# Epoch 1, Batch 60/240, MSE = 0.001726
# Epoch 1, Batch 61/240, MSE = 0.001769
# Epoch 1, Batch 62/240, MSE = 0.001842
# Epoch 1, Batch 63/240, MSE = 0.001731
# Epoch 1, Batch 64/240, MSE = 0.001592
# Epoch 1, Batch 65/240, MSE = 0.001744
# Epoch 1, Batch 66/240, MSE = 0.001638
# Epoch 1, Batch 67/240, MSE = 0.001692
# Epoch 1, Batch 68/240, MSE = 0.001689
# Epoch 1, Batch 69/240, MSE = 0.001602
# Epoch 1, Batch 70/240, MSE = 0.001784
# Epoch 1, Batch 71/240, MSE = 0.001794
# Epoch 1, Batch 72/240, MSE = 0.001626
# Epoch 1, Batch 73/240, MSE = 0.001733
# Epoch 1, Batch 74/240, MSE = 0.001748
# Epoch 1, Batch 75/240, MSE = 0.001642
# Epoch 1, Batch 76/240, MSE = 0.001708
# Epoch 1, Batch 77/240, MSE = 0.001751
# Epoch 1, Batch 78/240, MSE = 0.001595
# Epoch 1, Batch 79/240, MSE = 0.001799
# Epoch 1, Batch 80/240, MSE = 0.001712
# Epoch 1, Batch 81/240, MSE = 0.001794
# Epoch 1, Batch 82/240, MSE = 0.001656
# Epoch 1, Batch 83/240, MSE = 0.001731
# Epoch 1, Batch 84/240, MSE = 0.001763
# Epoch 1, Batch 85/240, MSE = 0.001666
# Epoch 1, Batch 86/240, MSE = 0.001731
# Epoch 1, Batch 87/240, MSE = 0.001563
# Epoch 1, Batch 88/240, MSE = 0.001560
# Epoch 1, Batch 89/240, MSE = 0.001779
# Epoch 1, Batch 90/240, MSE = 0.001767
# Epoch 1, Batch 91/240, MSE = 0.001664
# Epoch 1, Batch 92/240, MSE = 0.001623
# Epoch 1, Batch 93/240, MSE = 0.001693
# Epoch 1, Batch 94/240, MSE = 0.001787
# Epoch 1, Batch 95/240, MSE = 0.001776
# Epoch 1, Batch 96/240, MSE = 0.001699
# Epoch 1, Batch 97/240, MSE = 0.001683
# Epoch 1, Batch 98/240, MSE = 0.001617
# Epoch 1, Batch 99/240, MSE = 0.001558
# Epoch 1, Batch 100/240, MSE = 0.001819
# Epoch 1, Batch 101/240, MSE = 0.001682
# Epoch 1, Batch 102/240, MSE = 0.001527
# Epoch 1, Batch 103/240, MSE = 0.001692
# Epoch 1, Batch 104/240, MSE = 0.001669
# Epoch 1, Batch 105/240, MSE = 0.001501
# Epoch 1, Batch 106/240, MSE = 0.001552
# Epoch 1, Batch 107/240, MSE = 0.001733
# Epoch 1, Batch 108/240, MSE = 0.001684
# Epoch 1, Batch 109/240, MSE = 0.001676
# Epoch 1, Batch 110/240, MSE = 0.001596
# Epoch 1, Batch 111/240, MSE = 0.001681
# Epoch 1, Batch 112/240, MSE = 0.001641
# Epoch 1, Batch 113/240, MSE = 0.001773
# Epoch 1, Batch 114/240, MSE = 0.001480
# Epoch 1, Batch 115/240, MSE = 0.001747
# Epoch 1, Batch 116/240, MSE = 0.001624
# Epoch 1, Batch 117/240, MSE = 0.001557
# Epoch 1, Batch 118/240, MSE = 0.001650
# Epoch 1, Batch 119/240, MSE = 0.001669
# Epoch 1, Batch 120/240, MSE = 0.001590
# Epoch 1, Batch 121/240, MSE = 0.001665
# Epoch 1, Batch 122/240, MSE = 0.001647
# Epoch 1, Batch 123/240, MSE = 0.001785
# Epoch 1, Batch 124/240, MSE = 0.001708
# Epoch 1, Batch 125/240, MSE = 0.001618
# Epoch 1, Batch 126/240, MSE = 0.001747
# Epoch 1, Batch 127/240, MSE = 0.001665
# Epoch 1, Batch 128/240, MSE = 0.001701
# Epoch 1, Batch 129/240, MSE = 0.001626
# Epoch 1, Batch 130/240, MSE = 0.001678
# Epoch 1, Batch 131/240, MSE = 0.001718
# Epoch 1, Batch 132/240, MSE = 0.001620
# Epoch 1, Batch 133/240, MSE = 0.001563
# Epoch 1, Batch 134/240, MSE = 0.001733
# Epoch 1, Batch 135/240, MSE = 0.001673
# Epoch 1, Batch 136/240, MSE = 0.001721
# Epoch 1, Batch 137/240, MSE = 0.001604
# Epoch 1, Batch 138/240, MSE = 0.001730
# Epoch 1, Batch 139/240, MSE = 0.001636
# Epoch 1, Batch 140/240, MSE = 0.001742
# Epoch 1, Batch 141/240, MSE = 0.001604
# Epoch 1, Batch 142/240, MSE = 0.001665
# Epoch 1, Batch 143/240, MSE = 0.001664
# Epoch 1, Batch 144/240, MSE = 0.001584
# Epoch 1, Batch 145/240, MSE = 0.001711
# Epoch 1, Batch 146/240, MSE = 0.001677
# Epoch 1, Batch 147/240, MSE = 0.001642
# Epoch 1, Batch 148/240, MSE = 0.001801
# Epoch 1, Batch 149/240, MSE = 0.001561
# Epoch 1, Batch 150/240, MSE = 0.001744
# Epoch 1, Batch 151/240, MSE = 0.001714
# Epoch 1, Batch 152/240, MSE = 0.001684
# Epoch 1, Batch 153/240, MSE = 0.001779
# Epoch 1, Batch 154/240, MSE = 0.001495
# Epoch 1, Batch 155/240, MSE = 0.001686
# Epoch 1, Batch 156/240, MSE = 0.001605
# Epoch 1, Batch 157/240, MSE = 0.001593
# Epoch 1, Batch 158/240, MSE = 0.001655
# Epoch 1, Batch 159/240, MSE = 0.001676
# Epoch 1, Batch 160/240, MSE = 0.001531
# Epoch 1, Batch 161/240, MSE = 0.001657
# Epoch 1, Batch 162/240, MSE = 0.001575
# Epoch 1, Batch 163/240, MSE = 0.001628
# Epoch 1, Batch 164/240, MSE = 0.001595
# Epoch 1, Batch 165/240, MSE = 0.001627
# Epoch 1, Batch 166/240, MSE = 0.001472
# Epoch 1, Batch 167/240, MSE = 0.001686
# Epoch 1, Batch 168/240, MSE = 0.001646
# Epoch 1, Batch 169/240, MSE = 0.001656
# Epoch 1, Batch 170/240, MSE = 0.001524
# Epoch 1, Batch 171/240, MSE = 0.001550
# Epoch 1, Batch 172/240, MSE = 0.001588
# Epoch 1, Batch 173/240, MSE = 0.001538
# Epoch 1, Batch 174/240, MSE = 0.001609
# Epoch 1, Batch 175/240, MSE = 0.001724
# Epoch 1, Batch 176/240, MSE = 0.001585
# Epoch 1, Batch 177/240, MSE = 0.001603
# Epoch 1, Batch 178/240, MSE = 0.001514
# Epoch 1, Batch 179/240, MSE = 0.001686
# Epoch 1, Batch 180/240, MSE = 0.001616
# Epoch 1, Batch 181/240, MSE = 0.001577
# Epoch 1, Batch 182/240, MSE = 0.001440
# Epoch 1, Batch 183/240, MSE = 0.001645
# Epoch 1, Batch 184/240, MSE = 0.001542
# Epoch 1, Batch 185/240, MSE = 0.001521
# Epoch 1, Batch 186/240, MSE = 0.001614
# Epoch 1, Batch 187/240, MSE = 0.001531
# Epoch 1, Batch 188/240, MSE = 0.001623
# Epoch 1, Batch 189/240, MSE = 0.001471
# Epoch 1, Batch 190/240, MSE = 0.001583
# Epoch 1, Batch 191/240, MSE = 0.001535
# Epoch 1, Batch 192/240, MSE = 0.001472
# Epoch 1, Batch 193/240, MSE = 0.001443
# Epoch 1, Batch 194/240, MSE = 0.001629
# Epoch 1, Batch 195/240, MSE = 0.001553
# Epoch 1, Batch 196/240, MSE = 0.001674
# Epoch 1, Batch 197/240, MSE = 0.001522
# Epoch 1, Batch 198/240, MSE = 0.001559
# Epoch 1, Batch 199/240, MSE = 0.001460
# Epoch 1, Batch 200/240, MSE = 0.001562
# Epoch 1, Batch 201/240, MSE = 0.001520
# Epoch 1, Batch 202/240, MSE = 0.001544
# Epoch 1, Batch 203/240, MSE = 0.001622
# Epoch 1, Batch 204/240, MSE = 0.001492
# Epoch 1, Batch 205/240, MSE = 0.001560
# Epoch 1, Batch 206/240, MSE = 0.001688
# Epoch 1, Batch 207/240, MSE = 0.001438
# Epoch 1, Batch 208/240, MSE = 0.001546
# Epoch 1, Batch 209/240, MSE = 0.001545
# Epoch 1, Batch 210/240, MSE = 0.001583
# Epoch 1, Batch 211/240, MSE = 0.001439
# Epoch 1, Batch 212/240, MSE = 0.001480
# Epoch 1, Batch 213/240, MSE = 0.001559
# Epoch 1, Batch 214/240, MSE = 0.001614
# Epoch 1, Batch 215/240, MSE = 0.001635
# Epoch 1, Batch 216/240, MSE = 0.001597
# Epoch 1, Batch 217/240, MSE = 0.001492
# Epoch 1, Batch 218/240, MSE = 0.001623
# Epoch 1, Batch 219/240, MSE = 0.001664
# Epoch 1, Batch 220/240, MSE = 0.001575
# Epoch 1, Batch 221/240, MSE = 0.001503
# Epoch 1, Batch 222/240, MSE = 0.001616
# Epoch 1, Batch 223/240, MSE = 0.001515
# Epoch 1, Batch 224/240, MSE = 0.001498
# Epoch 1, Batch 225/240, MSE = 0.001608
# Epoch 1, Batch 226/240, MSE = 0.001564
# Epoch 1, Batch 227/240, MSE = 0.001564
# Epoch 1, Batch 228/240, MSE = 0.001427
# Epoch 1, Batch 229/240, MSE = 0.001572
# Epoch 1, Batch 230/240, MSE = 0.001492
# Epoch 1, Batch 231/240, MSE = 0.001586
# Epoch 1, Batch 232/240, MSE = 0.001600
# Epoch 1, Batch 233/240, MSE = 0.001606
# Epoch 1, Batch 234/240, MSE = 0.001633
# Epoch 1, Batch 235/240, MSE = 0.001505
# Epoch 1, Batch 236/240, MSE = 0.001590
# Epoch 1, Batch 237/240, MSE = 0.001685
# Epoch 1, Batch 238/240, MSE = 0.001481
# Epoch 1, Batch 239/240, MSE = 0.001359
# Epoch 1, Batch 240/240, MSE = 0.001402
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -10    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# 8. 길이 맞추기
target_len = len(clean_iq)
if len(iq_reconstructed) != target_len:
    iq_reconstructed = resample(iq_reconstructed, target_len)

print(f"✅ IQ signal resampled: {iq_reconstructed.shape}")

# 🔧 길이 보정: Resample (Zero-padding 대신!)
from scipy.signal import resample
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (2048)
if len(iq_reconstructed) != target_len:
    original_len = len(iq_reconstructed)
    iq_reconstructed = resample(iq_reconstructed, target_len)
    print(f"   🔧 Resampled: {original_len} → {target_len} samples (Sinc interpolation)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")

print(f"   Energy before scaling: |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

# 8. 에너지 정규화 (Energy Normalization) ⭐
# iSTFT 후 신호 에너지가 손실되므로, 원본 noisy IQ의 에너지에 맞춰 복원
energy_noisy = np.sqrt(np.mean(np.abs(noisy_iq)**2))
energy_reconstructed = np.sqrt(np.mean(np.abs(iq_reconstructed)**2))

if energy_reconstructed > 1e-10:  # 0으로 나누기 방지
    scale_factor = energy_noisy / energy_reconstructed
    iq_reconstructed = iq_reconstructed * scale_factor
    print(f"   Energy scaling: {energy_noisy:.6f} / {energy_reconstructed:.6f} = {scale_factor:.2f}x")
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")
else:
    print(f"   ⚠️  Warning: Reconstructed signal energy too low, no scaling applied")

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -10 dB
#
# === Normalization Parameters ===
# Real: min=-1.171308, max=1.087487, range=2.258795
# Imag: min=-1.271502, max=1.373840, range=2.645343
# Restored norm: real_min=0.2328, real_max=0.7619
# Restored norm: imag_min=0.2124, imag_max=0.7798
# After denorm:  real_min=-0.645484, real_max=0.549681
# After denorm:  imag_min=-0.709681, imag_max=0.791413
# ✅ IQ signal reconstructed: (2048,)
# ✅ IQ signal resampled: (2048,)
#    ✅ Length already matches: 2048 samples
#    Energy before scaling: |mean|=1.011860, |max|=95.100450
#    Energy scaling: 3.319768 / 2.492969 = 1.33x
#    Energy after scaling:  |mean|=1.347446, |max|=126.640715
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.5000
# Restored flat: min=0.2124, max=0.7798, mean=0.4998
# Difference:    MSE=0.007467
# /tmp/ipykernel_31042/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0001, max=0.0131
# Zxx_restored (magnitude): min=0.0067, max=0.7934
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, "clean", sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, "noisy", sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, "restored", sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3 successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3 failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=2.9435, |max|=8.0505
# Reconstructed:   len=2048, |mean|=1.3474, |max|=126.6407
#
# MSE Comparison:
# Clean vs Noisy:        10.034282
# Clean vs Reconstructed: 10.476725
# Noisy vs Reconstructed: 18.494767
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 1880.00
# ⚠️  Noisy signal (len=2048)    → Code: 42, Peak: 1811.72
# 🔧 Restored (len=2048)   → Code: 42, Peak: 1473.80
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       42 ✅ CORRECT
# Restored Decoded:    42 ✅ CORRECT
# ============================================================
#
# Peak Comparison:
# Clean Peak:    1880.00
# Noisy Peak:    1811.72 (96.4% of clean)
# Restored Peak: 1473.80 (78.4% of clean)
#
# ✅ SUCCESS: BAMv3 successfully restored the correct symbol!

# %%
########################################
##  8. 정량적 성능 평가 (다중 샘플)  ##
########################################

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION")
print("="*70)

# 테스트 파라미터
NUM_TEST_SAMPLES = 100  # 테스트할 샘플 수
TEST_SNR_LEVELS = [-25, -20, -15, -10, -5]  # 다양한 SNR 레벨

results = {snr: {'correct': 0, 'total': 0, 'mse': [], 'peak_ratio': []} for snr in TEST_SNR_LEVELS}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        # 랜덤 심볼 선택
        test_sym = np.random.randint(0, 512)
        
        # 1. 클린 IQ
        clean_iq_test = X_clean_iq[test_sym]
        
        # 2. 노이즈 추가
        noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
        
        # 3. Complex 스펙트로그램 생성
        noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
        
        # 4. BAMv3 복원 (compress -> decompress)
        compressed = model.compress(noisy_flat.reshape(1, -1))
        restored_flat = model.decompress(compressed).flatten()
        
        # 5. 역변환
        mid = len(restored_flat) // 2
        real_restored_norm = restored_flat[:mid].reshape(noisy_params['shape'])
        imag_restored_norm = restored_flat[mid:].reshape(noisy_params['shape'])
        
        # 역정규화
        real_restored = real_restored_norm * (noisy_params['r_max'] - noisy_params['r_min']) + noisy_params['r_min']
        imag_restored = imag_restored_norm * (noisy_params['i_max'] - noisy_params['i_min']) + noisy_params['i_min']
        
        # Complex 재결합
        Zxx_restored = real_restored + 1j * imag_restored
        
        # 6. 역 STFT
        # ⭐ Step 1: Zero-padding으로 원래 주파수 크기 복원
        Zxx_full = np.zeros(noisy_params['original_shape'], dtype=complex)
        Zxx_full[noisy_params['freq_indices'], :] = Zxx_restored

        # ⭐ Step 2: 주파수 축 언시프트
        # IQ 신호 복원
        iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)
        
        target_len = len(clean_iq_test)
        if len(iq_restored) != target_len:
            iq_restored = resample(iq_restored, target_len)
        
        # 7. Dechirp
        try:
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, "clean", sf, fs, bw)
            code_restored, peak_restored = estimate_symbol_custom(iq_restored, "restored", sf, fs, bw)
            
            # 정확도 체크
            if code_restored == test_sym:
                results[snr]['correct'] += 1
            results[snr]['total'] += 1
            
            # Peak ratio
            if peak_clean > 0:
                results[snr]['peak_ratio'].append(peak_restored / peak_clean)
            
            # MSE 계산
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['total'] += 1
    
    # 중간 결과 출력
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"  ✓ Accuracy: {results[snr]['correct']}/{results[snr]['total']} = {acc:.1f}%")
    print(f"  ✓ Avg MSE: {avg_mse:.6f}")
    print(f"  ✓ Avg Peak Ratio: {avg_peak:.2%}")

# 최종 결과 요약
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)

print(f"\n{'SNR (dB)':<10} {'Accuracy':<15} {'MSE':<15} {'Peak Ratio':<15}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"{snr:<10} {acc:>6.1f}%{'':<8} {avg_mse:>8.6f}{'':<6} {avg_peak:>6.1%}{'':<8}")

# 전체 평균
total_correct = sum(r['correct'] for r in results.values())
total_samples = sum(r['total'] for r in results.values())
overall_acc = total_correct / total_samples * 100

print("─"*70)
print(f"{'Overall':<10} {overall_acc:>6.1f}%")
print("="*70)

# 시각화
plt.figure(figsize=(15, 4))

# 1. Accuracy vs SNR
plt.subplot(1, 3, 1)
snrs = TEST_SNR_LEVELS
accs = [results[snr]['correct'] / results[snr]['total'] * 100 for snr in snrs]
plt.plot(snrs, accs, 'o-', linewidth=2, markersize=8)
plt.xlabel('SNR (dB)')
plt.ylabel('Accuracy (%)')
plt.title('Symbol Classification Accuracy')
plt.grid(True, alpha=0.3)
plt.ylim([0, 105])

# 2. MSE vs SNR
plt.subplot(1, 3, 2)
mses = [np.mean(results[snr]['mse']) for snr in snrs]
plt.plot(snrs, mses, 's-', linewidth=2, markersize=8, color='orange')
plt.xlabel('SNR (dB)')
plt.ylabel('MSE')
plt.title('Reconstruction MSE')
plt.grid(True, alpha=0.3)
plt.yscale('log')

# 3. Peak Ratio vs SNR
plt.subplot(1, 3, 3)
peaks = [np.mean(results[snr]['peak_ratio']) * 100 for snr in snrs]
plt.plot(snrs, peaks, '^-', linewidth=2, markersize=8, color='green')
plt.xlabel('SNR (dB)')
plt.ylabel('Peak Ratio (%)')
plt.title('Peak Recovery Ratio')
plt.grid(True, alpha=0.3)
plt.axhline(y=100, color='r', linestyle='--', alpha=0.5, label='Perfect (100%)')
plt.legend()

plt.tight_layout()
plt.show()

print(f"\n✅ Quantitative evaluation complete!")
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION
# ======================================================================
#
# 🧪 Testing with 100 samples at each SNR level...
# SNR levels: [-25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 4/100 = 4.0%
#   ✓ Avg MSE: 232.505238
#   ✓ Avg Peak Ratio: 757.14%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_31042/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Accuracy: 26/100 = 26.0%
#   ✓ Avg MSE: 79.493300
#   ✓ Avg Peak Ratio: 244.65%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 44/100 = 44.0%
#   ✓ Avg MSE: 29.427250
#   ✓ Avg Peak Ratio: 283.73%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 61/100 = 61.0%
#   ✓ Avg MSE: 13.247657
#   ✓ Avg Peak Ratio: 151.89%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 70/100 = 70.0%
#   ✓ Avg MSE: 7.557354
#   ✓ Avg Peak Ratio: 105.26%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR (dB)   Accuracy        MSE             Peak Ratio
# ──────────────────────────────────────────────────────────────────────
# -25           4.0%         232.505238       757.1%
# -20          26.0%         79.493300       244.7%
# -15          44.0%         29.427250       283.7%
# -10          61.0%         13.247657       151.9%
# -5           70.0%         7.557354       105.3%
# ──────────────────────────────────────────────────────────────────────
# Overall      41.0%
# ======================================================================
# ✅ Quantitative evaluation complete!
