# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    """
    복소 IQ 신호 → STFT 기반 complex 스펙트로그램 생성 (재학습용)
    - stft() / istft()가 1:1로 대응되도록 설계
    """
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    window   = STFT_PARAMS['window']

    # 1) STFT (spectrogram 대신 stft 사용)
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        boundary=None,          # padding 안 함
        padded=False,
        return_onesided=False   # 복소 baseband 이므로 False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf, bw)
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (Ultra-low SNR에 집중)
SNR_MIN = -25
SNR_MAX = -5
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)
            
            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 4096, 2048, 1024]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (32, 31)
# Input dim (Real+Imag): 1984
# Model architecture: 1984 → 4096 → 2048 → 1024
# Compression ratio: 1.9x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True  # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 20
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 1984 → 4096 → 2048 → 1024
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.027703
# Epoch 1, Batch 2/240, MSE = 0.017839
# Epoch 1, Batch 3/240, MSE = 0.015647
# Epoch 1, Batch 4/240, MSE = 0.017595
# Epoch 1, Batch 5/240, MSE = 0.015976
# Epoch 1, Batch 6/240, MSE = 0.016586
# Epoch 1, Batch 7/240, MSE = 0.016904
# Epoch 1, Batch 8/240, MSE = 0.017906
# Epoch 1, Batch 9/240, MSE = 0.016531
# Epoch 1, Batch 10/240, MSE = 0.016958
# Epoch 1, Batch 11/240, MSE = 0.017385
# Epoch 1, Batch 12/240, MSE = 0.015757
# Epoch 1, Batch 13/240, MSE = 0.017443
# Epoch 1, Batch 14/240, MSE = 0.017218
# Epoch 1, Batch 15/240, MSE = 0.016441
# Epoch 1, Batch 16/240, MSE = 0.016951
# Epoch 1, Batch 17/240, MSE = 0.015847
# Epoch 1, Batch 18/240, MSE = 0.017103
# Epoch 1, Batch 19/240, MSE = 0.017513
# Epoch 1, Batch 20/240, MSE = 0.015719
# Epoch 1, Batch 21/240, MSE = 0.016928
# Epoch 1, Batch 22/240, MSE = 0.016382
# Epoch 1, Batch 23/240, MSE = 0.016261
# Epoch 1, Batch 24/240, MSE = 0.016648
# Epoch 1, Batch 25/240, MSE = 0.016636
# Epoch 1, Batch 26/240, MSE = 0.016433
# Epoch 1, Batch 27/240, MSE = 0.015883
# Epoch 1, Batch 28/240, MSE = 0.016498
# Epoch 1, Batch 29/240, MSE = 0.016459
# Epoch 1, Batch 30/240, MSE = 0.015655
# Epoch 1, Batch 31/240, MSE = 0.015332
# Epoch 1, Batch 32/240, MSE = 0.016652
# Epoch 1, Batch 33/240, MSE = 0.016459
# Epoch 1, Batch 34/240, MSE = 0.015509
# Epoch 1, Batch 35/240, MSE = 0.016290
# Epoch 1, Batch 36/240, MSE = 0.015897
# Epoch 1, Batch 37/240, MSE = 0.016561
# Epoch 1, Batch 38/240, MSE = 0.016333
# Epoch 1, Batch 39/240, MSE = 0.014946
# Epoch 1, Batch 40/240, MSE = 0.016983
# Epoch 1, Batch 41/240, MSE = 0.015356
# Epoch 1, Batch 42/240, MSE = 0.016718
# Epoch 1, Batch 43/240, MSE = 0.015111
# Epoch 1, Batch 44/240, MSE = 0.014236
# Epoch 1, Batch 45/240, MSE = 0.015883
# Epoch 1, Batch 46/240, MSE = 0.016193
# Epoch 1, Batch 47/240, MSE = 0.015597
# Epoch 1, Batch 48/240, MSE = 0.016143
# Epoch 1, Batch 49/240, MSE = 0.016259
# Epoch 1, Batch 50/240, MSE = 0.016016
# Epoch 1, Batch 51/240, MSE = 0.016370
# Epoch 1, Batch 52/240, MSE = 0.015696
# Epoch 1, Batch 53/240, MSE = 0.016289
# Epoch 1, Batch 54/240, MSE = 0.016076
# Epoch 1, Batch 55/240, MSE = 0.014960
# Epoch 1, Batch 56/240, MSE = 0.015390
# Epoch 1, Batch 57/240, MSE = 0.017013
# Epoch 1, Batch 58/240, MSE = 0.016548
# Epoch 1, Batch 59/240, MSE = 0.016326
# Epoch 1, Batch 60/240, MSE = 0.015345
# Epoch 1, Batch 61/240, MSE = 0.015926
# Epoch 1, Batch 62/240, MSE = 0.016280
# Epoch 1, Batch 63/240, MSE = 0.015715
# Epoch 1, Batch 64/240, MSE = 0.016061
# Epoch 1, Batch 65/240, MSE = 0.015357
# Epoch 1, Batch 66/240, MSE = 0.016519
# Epoch 1, Batch 67/240, MSE = 0.015819
# Epoch 1, Batch 68/240, MSE = 0.015799
# Epoch 1, Batch 69/240, MSE = 0.015114
# Epoch 1, Batch 70/240, MSE = 0.015644
# Epoch 1, Batch 71/240, MSE = 0.015319
# Epoch 1, Batch 72/240, MSE = 0.016134
# Epoch 1, Batch 73/240, MSE = 0.015624
# Epoch 1, Batch 74/240, MSE = 0.015314
# Epoch 1, Batch 75/240, MSE = 0.014757
# Epoch 1, Batch 76/240, MSE = 0.015594
# Epoch 1, Batch 77/240, MSE = 0.016502
# Epoch 1, Batch 78/240, MSE = 0.015086
# Epoch 1, Batch 79/240, MSE = 0.015687
# Epoch 1, Batch 80/240, MSE = 0.016279
# Epoch 1, Batch 81/240, MSE = 0.015743
# Epoch 1, Batch 82/240, MSE = 0.014551
# Epoch 1, Batch 83/240, MSE = 0.015266
# Epoch 1, Batch 84/240, MSE = 0.015548
# Epoch 1, Batch 85/240, MSE = 0.016071
# Epoch 1, Batch 86/240, MSE = 0.015248
# Epoch 1, Batch 87/240, MSE = 0.016240
# Epoch 1, Batch 88/240, MSE = 0.014646
# Epoch 1, Batch 89/240, MSE = 0.015386
# Epoch 1, Batch 90/240, MSE = 0.016024
# Epoch 1, Batch 91/240, MSE = 0.015126
# Epoch 1, Batch 92/240, MSE = 0.015581
# Epoch 1, Batch 93/240, MSE = 0.013668
# Epoch 1, Batch 94/240, MSE = 0.015210
# Epoch 1, Batch 95/240, MSE = 0.015675
# Epoch 1, Batch 96/240, MSE = 0.015489
# Epoch 1, Batch 97/240, MSE = 0.015629
# Epoch 1, Batch 98/240, MSE = 0.015125
# Epoch 1, Batch 99/240, MSE = 0.016128
# Epoch 1, Batch 100/240, MSE = 0.015960
# Epoch 1, Batch 101/240, MSE = 0.016273
# Epoch 1, Batch 102/240, MSE = 0.014648
# Epoch 1, Batch 103/240, MSE = 0.015668
# Epoch 1, Batch 104/240, MSE = 0.014829
# Epoch 1, Batch 105/240, MSE = 0.014257
# Epoch 1, Batch 106/240, MSE = 0.014115
# Epoch 1, Batch 107/240, MSE = 0.014791
# Epoch 1, Batch 108/240, MSE = 0.014512
# Epoch 1, Batch 109/240, MSE = 0.015229
# Epoch 1, Batch 110/240, MSE = 0.015471
# Epoch 1, Batch 111/240, MSE = 0.015409
# Epoch 1, Batch 112/240, MSE = 0.014862
# Epoch 1, Batch 113/240, MSE = 0.014236
# Epoch 1, Batch 114/240, MSE = 0.014774
# Epoch 1, Batch 115/240, MSE = 0.014497
# Epoch 1, Batch 116/240, MSE = 0.014845
# Epoch 1, Batch 117/240, MSE = 0.014823
# Epoch 1, Batch 118/240, MSE = 0.015207
# Epoch 1, Batch 119/240, MSE = 0.014640
# Epoch 1, Batch 120/240, MSE = 0.014557
# Epoch 1, Batch 121/240, MSE = 0.014286
# Epoch 1, Batch 122/240, MSE = 0.014353
# Epoch 1, Batch 123/240, MSE = 0.015236
# Epoch 1, Batch 124/240, MSE = 0.014688
# Epoch 1, Batch 125/240, MSE = 0.015802
# Epoch 1, Batch 126/240, MSE = 0.015353
# Epoch 1, Batch 127/240, MSE = 0.014281
# Epoch 1, Batch 128/240, MSE = 0.015323
# Epoch 1, Batch 129/240, MSE = 0.015420
# Epoch 1, Batch 130/240, MSE = 0.014377
# Epoch 1, Batch 131/240, MSE = 0.014729
# Epoch 1, Batch 132/240, MSE = 0.015057
# Epoch 1, Batch 133/240, MSE = 0.013731
# Epoch 1, Batch 134/240, MSE = 0.014817
# Epoch 1, Batch 135/240, MSE = 0.014396
# Epoch 1, Batch 136/240, MSE = 0.015757
# Epoch 1, Batch 137/240, MSE = 0.014654
# Epoch 1, Batch 138/240, MSE = 0.014273
# Epoch 1, Batch 139/240, MSE = 0.014583
# Epoch 1, Batch 140/240, MSE = 0.015503
# Epoch 1, Batch 141/240, MSE = 0.014194
# Epoch 1, Batch 142/240, MSE = 0.014716
# Epoch 1, Batch 143/240, MSE = 0.014178
# Epoch 1, Batch 144/240, MSE = 0.014628
# Epoch 1, Batch 145/240, MSE = 0.015262
# Epoch 1, Batch 146/240, MSE = 0.014480
# Epoch 1, Batch 147/240, MSE = 0.015065
# Epoch 1, Batch 148/240, MSE = 0.014161
# Epoch 1, Batch 149/240, MSE = 0.015319
# Epoch 1, Batch 150/240, MSE = 0.014853
# Epoch 1, Batch 151/240, MSE = 0.015188
# Epoch 1, Batch 152/240, MSE = 0.014555
# Epoch 1, Batch 153/240, MSE = 0.014197
# Epoch 1, Batch 154/240, MSE = 0.014055
# Epoch 1, Batch 155/240, MSE = 0.014217
# Epoch 1, Batch 156/240, MSE = 0.015369
# Epoch 1, Batch 157/240, MSE = 0.014543
# Epoch 1, Batch 158/240, MSE = 0.014467
# Epoch 1, Batch 159/240, MSE = 0.015024
# Epoch 1, Batch 160/240, MSE = 0.013789
# Epoch 1, Batch 161/240, MSE = 0.014224
# Epoch 1, Batch 162/240, MSE = 0.014111
# Epoch 1, Batch 163/240, MSE = 0.014659
# Epoch 1, Batch 164/240, MSE = 0.014982
# Epoch 1, Batch 165/240, MSE = 0.014362
# Epoch 1, Batch 166/240, MSE = 0.014465
# Epoch 1, Batch 167/240, MSE = 0.014173
# Epoch 1, Batch 168/240, MSE = 0.014285
# Epoch 1, Batch 169/240, MSE = 0.015066
# Epoch 1, Batch 170/240, MSE = 0.015079
# Epoch 1, Batch 171/240, MSE = 0.015580
# Epoch 1, Batch 172/240, MSE = 0.014578
# Epoch 1, Batch 173/240, MSE = 0.013790
# Epoch 1, Batch 174/240, MSE = 0.014129
# Epoch 1, Batch 175/240, MSE = 0.014050
# Epoch 1, Batch 176/240, MSE = 0.014057
# Epoch 1, Batch 177/240, MSE = 0.014656
# Epoch 1, Batch 178/240, MSE = 0.014442
# Epoch 1, Batch 179/240, MSE = 0.013639
# Epoch 1, Batch 180/240, MSE = 0.014252
# Epoch 1, Batch 181/240, MSE = 0.014544
# Epoch 1, Batch 182/240, MSE = 0.015000
# Epoch 1, Batch 183/240, MSE = 0.013763
# Epoch 1, Batch 184/240, MSE = 0.013753
# Epoch 1, Batch 185/240, MSE = 0.014277
# Epoch 1, Batch 186/240, MSE = 0.014830
# Epoch 1, Batch 187/240, MSE = 0.013913
# Epoch 1, Batch 188/240, MSE = 0.013828
# Epoch 1, Batch 189/240, MSE = 0.014703
# Epoch 1, Batch 190/240, MSE = 0.013877
# Epoch 1, Batch 191/240, MSE = 0.014619
# Epoch 1, Batch 192/240, MSE = 0.014497
# Epoch 1, Batch 193/240, MSE = 0.015281
# Epoch 1, Batch 194/240, MSE = 0.014707
# Epoch 1, Batch 195/240, MSE = 0.013674
# Epoch 1, Batch 196/240, MSE = 0.013690
# Epoch 1, Batch 197/240, MSE = 0.013943
# Epoch 1, Batch 198/240, MSE = 0.014183
# Epoch 1, Batch 199/240, MSE = 0.014046
# Epoch 1, Batch 200/240, MSE = 0.013782
# Epoch 1, Batch 201/240, MSE = 0.013699
# Epoch 1, Batch 202/240, MSE = 0.013915
# Epoch 1, Batch 203/240, MSE = 0.013846
# Epoch 1, Batch 204/240, MSE = 0.014812
# Epoch 1, Batch 205/240, MSE = 0.013910
# Epoch 1, Batch 206/240, MSE = 0.014149
# Epoch 1, Batch 207/240, MSE = 0.013618
# Epoch 1, Batch 208/240, MSE = 0.014501
# Epoch 1, Batch 209/240, MSE = 0.013372
# Epoch 1, Batch 210/240, MSE = 0.014748
# Epoch 1, Batch 211/240, MSE = 0.013850
# Epoch 1, Batch 212/240, MSE = 0.015026
# Epoch 1, Batch 213/240, MSE = 0.013745
# Epoch 1, Batch 214/240, MSE = 0.013638
# Epoch 1, Batch 215/240, MSE = 0.013387
# Epoch 1, Batch 216/240, MSE = 0.013950
# Epoch 1, Batch 217/240, MSE = 0.013539
# Epoch 1, Batch 218/240, MSE = 0.013678
# Epoch 1, Batch 219/240, MSE = 0.013831
# Epoch 1, Batch 220/240, MSE = 0.014254
# Epoch 1, Batch 221/240, MSE = 0.013601
# Epoch 1, Batch 222/240, MSE = 0.013815
# Epoch 1, Batch 223/240, MSE = 0.013909
# Epoch 1, Batch 224/240, MSE = 0.013704
# Epoch 1, Batch 225/240, MSE = 0.013100
# Epoch 1, Batch 226/240, MSE = 0.014205
# Epoch 1, Batch 227/240, MSE = 0.013977
# Epoch 1, Batch 228/240, MSE = 0.013166
# Epoch 1, Batch 229/240, MSE = 0.014160
# Epoch 1, Batch 230/240, MSE = 0.013628
# Epoch 1, Batch 231/240, MSE = 0.013081
# Epoch 1, Batch 232/240, MSE = 0.013812
# Epoch 1, Batch 233/240, MSE = 0.013885
# Epoch 1, Batch 234/240, MSE = 0.014278
# Epoch 1, Batch 235/240, MSE = 0.013836
# Epoch 1, Batch 236/240, MSE = 0.013213
# Epoch 1, Batch 237/240, MSE = 0.013386
# Epoch 1, Batch 238/240, MSE = 0.014534
# Epoch 1, Batch 239/240, MSE = 0.012643
# Epoch 1, Batch 240/240, MSE = 0.013194
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.010510
# Epoch 1, Batch 2/240, MSE = 0.002318
# Epoch 1, Batch 3/240, MSE = 0.002317
# Epoch 1, Batch 4/240, MSE = 0.002608
# Epoch 1, Batch 5/240, MSE = 0.002580
# Epoch 1, Batch 6/240, MSE = 0.002481
# Epoch 1, Batch 7/240, MSE = 0.002461
# Epoch 1, Batch 8/240, MSE = 0.002432
# Epoch 1, Batch 9/240, MSE = 0.002497
# Epoch 1, Batch 10/240, MSE = 0.002565
# Epoch 1, Batch 11/240, MSE = 0.002280
# Epoch 1, Batch 12/240, MSE = 0.002342
# Epoch 1, Batch 13/240, MSE = 0.002353
# Epoch 1, Batch 14/240, MSE = 0.002396
# Epoch 1, Batch 15/240, MSE = 0.002259
# Epoch 1, Batch 16/240, MSE = 0.002417
# Epoch 1, Batch 17/240, MSE = 0.002256
# Epoch 1, Batch 18/240, MSE = 0.002522
# Epoch 1, Batch 19/240, MSE = 0.002395
# Epoch 1, Batch 20/240, MSE = 0.002290
# Epoch 1, Batch 21/240, MSE = 0.002255
# Epoch 1, Batch 22/240, MSE = 0.002371
# Epoch 1, Batch 23/240, MSE = 0.002325
# Epoch 1, Batch 24/240, MSE = 0.002240
# Epoch 1, Batch 25/240, MSE = 0.002219
# Epoch 1, Batch 26/240, MSE = 0.002215
# Epoch 1, Batch 27/240, MSE = 0.002179
# Epoch 1, Batch 28/240, MSE = 0.002132
# Epoch 1, Batch 29/240, MSE = 0.002255
# Epoch 1, Batch 30/240, MSE = 0.002236
# Epoch 1, Batch 31/240, MSE = 0.002164
# Epoch 1, Batch 32/240, MSE = 0.002257
# Epoch 1, Batch 33/240, MSE = 0.002264
# Epoch 1, Batch 34/240, MSE = 0.002227
# Epoch 1, Batch 35/240, MSE = 0.002210
# Epoch 1, Batch 36/240, MSE = 0.002281
# Epoch 1, Batch 37/240, MSE = 0.002381
# Epoch 1, Batch 38/240, MSE = 0.002259
# Epoch 1, Batch 39/240, MSE = 0.002160
# Epoch 1, Batch 40/240, MSE = 0.002100
# Epoch 1, Batch 41/240, MSE = 0.002278
# Epoch 1, Batch 42/240, MSE = 0.002160
# Epoch 1, Batch 43/240, MSE = 0.002250
# Epoch 1, Batch 44/240, MSE = 0.002163
# Epoch 1, Batch 45/240, MSE = 0.002009
# Epoch 1, Batch 46/240, MSE = 0.002168
# Epoch 1, Batch 47/240, MSE = 0.002095
# Epoch 1, Batch 48/240, MSE = 0.002106
# Epoch 1, Batch 49/240, MSE = 0.002247
# Epoch 1, Batch 50/240, MSE = 0.002256
# Epoch 1, Batch 51/240, MSE = 0.002179
# Epoch 1, Batch 52/240, MSE = 0.002089
# Epoch 1, Batch 53/240, MSE = 0.002050
# Epoch 1, Batch 54/240, MSE = 0.002170
# Epoch 1, Batch 55/240, MSE = 0.002074
# Epoch 1, Batch 56/240, MSE = 0.002283
# Epoch 1, Batch 57/240, MSE = 0.002070
# Epoch 1, Batch 58/240, MSE = 0.002005
# Epoch 1, Batch 59/240, MSE = 0.002097
# Epoch 1, Batch 60/240, MSE = 0.002283
# Epoch 1, Batch 61/240, MSE = 0.002123
# Epoch 1, Batch 62/240, MSE = 0.002014
# Epoch 1, Batch 63/240, MSE = 0.002181
# Epoch 1, Batch 64/240, MSE = 0.002179
# Epoch 1, Batch 65/240, MSE = 0.002068
# Epoch 1, Batch 66/240, MSE = 0.002161
# Epoch 1, Batch 67/240, MSE = 0.002023
# Epoch 1, Batch 68/240, MSE = 0.002208
# Epoch 1, Batch 69/240, MSE = 0.002089
# Epoch 1, Batch 70/240, MSE = 0.002157
# Epoch 1, Batch 71/240, MSE = 0.002101
# Epoch 1, Batch 72/240, MSE = 0.002303
# Epoch 1, Batch 73/240, MSE = 0.002063
# Epoch 1, Batch 74/240, MSE = 0.002109
# Epoch 1, Batch 75/240, MSE = 0.002181
# Epoch 1, Batch 76/240, MSE = 0.002110
# Epoch 1, Batch 77/240, MSE = 0.002112
# Epoch 1, Batch 78/240, MSE = 0.002002
# Epoch 1, Batch 79/240, MSE = 0.002170
# Epoch 1, Batch 80/240, MSE = 0.002172
# Epoch 1, Batch 81/240, MSE = 0.002046
# Epoch 1, Batch 82/240, MSE = 0.002053
# Epoch 1, Batch 83/240, MSE = 0.002248
# Epoch 1, Batch 84/240, MSE = 0.002053
# Epoch 1, Batch 85/240, MSE = 0.002165
# Epoch 1, Batch 86/240, MSE = 0.002349
# Epoch 1, Batch 87/240, MSE = 0.002075
# Epoch 1, Batch 88/240, MSE = 0.002096
# Epoch 1, Batch 89/240, MSE = 0.002085
# Epoch 1, Batch 90/240, MSE = 0.002019
# Epoch 1, Batch 91/240, MSE = 0.002095
# Epoch 1, Batch 92/240, MSE = 0.002261
# Epoch 1, Batch 93/240, MSE = 0.002061
# Epoch 1, Batch 94/240, MSE = 0.002113
# Epoch 1, Batch 95/240, MSE = 0.002109
# Epoch 1, Batch 96/240, MSE = 0.002065
# Epoch 1, Batch 97/240, MSE = 0.002152
# Epoch 1, Batch 98/240, MSE = 0.002040
# Epoch 1, Batch 99/240, MSE = 0.002095
# Epoch 1, Batch 100/240, MSE = 0.002084
# Epoch 1, Batch 101/240, MSE = 0.002109
# Epoch 1, Batch 102/240, MSE = 0.002098
# Epoch 1, Batch 103/240, MSE = 0.002134
# Epoch 1, Batch 104/240, MSE = 0.002145
# Epoch 1, Batch 105/240, MSE = 0.002067
# Epoch 1, Batch 106/240, MSE = 0.002108
# Epoch 1, Batch 107/240, MSE = 0.002037
# Epoch 1, Batch 108/240, MSE = 0.002080
# Epoch 1, Batch 109/240, MSE = 0.002120
# Epoch 1, Batch 110/240, MSE = 0.002106
# Epoch 1, Batch 111/240, MSE = 0.002169
# Epoch 1, Batch 112/240, MSE = 0.002086
# Epoch 1, Batch 113/240, MSE = 0.002069
# Epoch 1, Batch 114/240, MSE = 0.001985
# Epoch 1, Batch 115/240, MSE = 0.002047
# Epoch 1, Batch 116/240, MSE = 0.002152
# Epoch 1, Batch 117/240, MSE = 0.002278
# Epoch 1, Batch 118/240, MSE = 0.002110
# Epoch 1, Batch 119/240, MSE = 0.001947
# Epoch 1, Batch 120/240, MSE = 0.001946
# Epoch 1, Batch 121/240, MSE = 0.001952
# Epoch 1, Batch 122/240, MSE = 0.002155
# Epoch 1, Batch 123/240, MSE = 0.002134
# Epoch 1, Batch 124/240, MSE = 0.002104
# Epoch 1, Batch 125/240, MSE = 0.002125
# Epoch 1, Batch 126/240, MSE = 0.002258
# Epoch 1, Batch 127/240, MSE = 0.002124
# Epoch 1, Batch 128/240, MSE = 0.002158
# Epoch 1, Batch 129/240, MSE = 0.002099
# Epoch 1, Batch 130/240, MSE = 0.002079
# Epoch 1, Batch 131/240, MSE = 0.002236
# Epoch 1, Batch 132/240, MSE = 0.002274
# Epoch 1, Batch 133/240, MSE = 0.002171
# Epoch 1, Batch 134/240, MSE = 0.002133
# Epoch 1, Batch 135/240, MSE = 0.002114
# Epoch 1, Batch 136/240, MSE = 0.002053
# Epoch 1, Batch 137/240, MSE = 0.002142
# Epoch 1, Batch 138/240, MSE = 0.002113
# Epoch 1, Batch 139/240, MSE = 0.002094
# Epoch 1, Batch 140/240, MSE = 0.002017
# Epoch 1, Batch 141/240, MSE = 0.002090
# Epoch 1, Batch 142/240, MSE = 0.002059
# Epoch 1, Batch 143/240, MSE = 0.002024
# Epoch 1, Batch 144/240, MSE = 0.001967
# Epoch 1, Batch 145/240, MSE = 0.002135
# Epoch 1, Batch 146/240, MSE = 0.002033
# Epoch 1, Batch 147/240, MSE = 0.002038
# Epoch 1, Batch 148/240, MSE = 0.002230
# Epoch 1, Batch 149/240, MSE = 0.002092
# Epoch 1, Batch 150/240, MSE = 0.001979
# Epoch 1, Batch 151/240, MSE = 0.002009
# Epoch 1, Batch 152/240, MSE = 0.002113
# Epoch 1, Batch 153/240, MSE = 0.002186
# Epoch 1, Batch 154/240, MSE = 0.002060
# Epoch 1, Batch 155/240, MSE = 0.002172
# Epoch 1, Batch 156/240, MSE = 0.002107
# Epoch 1, Batch 157/240, MSE = 0.001989
# Epoch 1, Batch 158/240, MSE = 0.002144
# Epoch 1, Batch 159/240, MSE = 0.002192
# Epoch 1, Batch 160/240, MSE = 0.002068
# Epoch 1, Batch 161/240, MSE = 0.002014
# Epoch 1, Batch 162/240, MSE = 0.002029
# Epoch 1, Batch 163/240, MSE = 0.002167
# Epoch 1, Batch 164/240, MSE = 0.002119
# Epoch 1, Batch 165/240, MSE = 0.002129
# Epoch 1, Batch 166/240, MSE = 0.002174
# Epoch 1, Batch 167/240, MSE = 0.002109
# Epoch 1, Batch 168/240, MSE = 0.001966
# Epoch 1, Batch 169/240, MSE = 0.002141
# Epoch 1, Batch 170/240, MSE = 0.002175
# Epoch 1, Batch 171/240, MSE = 0.002073
# Epoch 1, Batch 172/240, MSE = 0.002021
# Epoch 1, Batch 173/240, MSE = 0.002110
# Epoch 1, Batch 174/240, MSE = 0.002131
# Epoch 1, Batch 175/240, MSE = 0.002159
# Epoch 1, Batch 176/240, MSE = 0.002158
# Epoch 1, Batch 177/240, MSE = 0.002225
# Epoch 1, Batch 178/240, MSE = 0.002164
# Epoch 1, Batch 179/240, MSE = 0.002088
# Epoch 1, Batch 180/240, MSE = 0.002035
# Epoch 1, Batch 181/240, MSE = 0.002150
# Epoch 1, Batch 182/240, MSE = 0.002070
# Epoch 1, Batch 183/240, MSE = 0.002069
# Epoch 1, Batch 184/240, MSE = 0.002079
# Epoch 1, Batch 185/240, MSE = 0.002050
# Epoch 1, Batch 186/240, MSE = 0.002128
# Epoch 1, Batch 187/240, MSE = 0.002069
# Epoch 1, Batch 188/240, MSE = 0.002230
# Epoch 1, Batch 189/240, MSE = 0.002118
# Epoch 1, Batch 190/240, MSE = 0.002133
# Epoch 1, Batch 191/240, MSE = 0.001978
# Epoch 1, Batch 192/240, MSE = 0.002160
# Epoch 1, Batch 193/240, MSE = 0.002043
# Epoch 1, Batch 194/240, MSE = 0.002106
# Epoch 1, Batch 195/240, MSE = 0.001932
# Epoch 1, Batch 196/240, MSE = 0.002281
# Epoch 1, Batch 197/240, MSE = 0.002079
# Epoch 1, Batch 198/240, MSE = 0.002088
# Epoch 1, Batch 199/240, MSE = 0.002133
# Epoch 1, Batch 200/240, MSE = 0.002261
# Epoch 1, Batch 201/240, MSE = 0.002154
# Epoch 1, Batch 202/240, MSE = 0.002081
# Epoch 1, Batch 203/240, MSE = 0.001952
# Epoch 1, Batch 204/240, MSE = 0.002130
# Epoch 1, Batch 205/240, MSE = 0.002106
# Epoch 1, Batch 206/240, MSE = 0.002037
# Epoch 1, Batch 207/240, MSE = 0.002003
# Epoch 1, Batch 208/240, MSE = 0.002110
# Epoch 1, Batch 209/240, MSE = 0.002043
# Epoch 1, Batch 210/240, MSE = 0.002123
# Epoch 1, Batch 211/240, MSE = 0.001964
# Epoch 1, Batch 212/240, MSE = 0.001985
# Epoch 1, Batch 213/240, MSE = 0.002077
# Epoch 1, Batch 214/240, MSE = 0.002158
# Epoch 1, Batch 215/240, MSE = 0.002014
# Epoch 1, Batch 216/240, MSE = 0.002088
# Epoch 1, Batch 217/240, MSE = 0.002116
# Epoch 1, Batch 218/240, MSE = 0.001977
# Epoch 1, Batch 219/240, MSE = 0.002084
# Epoch 1, Batch 220/240, MSE = 0.002148
# Epoch 1, Batch 221/240, MSE = 0.001993
# Epoch 1, Batch 222/240, MSE = 0.002023
# Epoch 1, Batch 223/240, MSE = 0.002112
# Epoch 1, Batch 224/240, MSE = 0.002035
# Epoch 1, Batch 225/240, MSE = 0.002053
# Epoch 1, Batch 226/240, MSE = 0.002121
# Epoch 1, Batch 227/240, MSE = 0.002053
# Epoch 1, Batch 228/240, MSE = 0.002083
# Epoch 1, Batch 229/240, MSE = 0.002005
# Epoch 1, Batch 230/240, MSE = 0.002024
# Epoch 1, Batch 231/240, MSE = 0.002126
# Epoch 1, Batch 232/240, MSE = 0.002104
# Epoch 1, Batch 233/240, MSE = 0.002018
# Epoch 1, Batch 234/240, MSE = 0.002062
# Epoch 1, Batch 235/240, MSE = 0.001990
# Epoch 1, Batch 236/240, MSE = 0.002054
# Epoch 1, Batch 237/240, MSE = 0.002230
# Epoch 1, Batch 238/240, MSE = 0.002217
# Epoch 1, Batch 239/240, MSE = 0.001968
# Epoch 1, Batch 240/240, MSE = 0.002021
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.023117
# Epoch 1, Batch 2/240, MSE = 0.000979
# Epoch 1, Batch 3/240, MSE = 0.001222
# Epoch 1, Batch 4/240, MSE = 0.001169
# Epoch 1, Batch 5/240, MSE = 0.000874
# Epoch 1, Batch 6/240, MSE = 0.000786
# Epoch 1, Batch 7/240, MSE = 0.001128
# Epoch 1, Batch 8/240, MSE = 0.000829
# Epoch 1, Batch 9/240, MSE = 0.001208
# Epoch 1, Batch 10/240, MSE = 0.001165
# Epoch 1, Batch 11/240, MSE = 0.001051
# Epoch 1, Batch 12/240, MSE = 0.000756
# Epoch 1, Batch 13/240, MSE = 0.001016
# Epoch 1, Batch 14/240, MSE = 0.001068
# Epoch 1, Batch 15/240, MSE = 0.000849
# Epoch 1, Batch 16/240, MSE = 0.000904
# Epoch 1, Batch 17/240, MSE = 0.000997
# Epoch 1, Batch 18/240, MSE = 0.001270
# Epoch 1, Batch 19/240, MSE = 0.000884
# Epoch 1, Batch 20/240, MSE = 0.000981
# Epoch 1, Batch 21/240, MSE = 0.000942
# Epoch 1, Batch 22/240, MSE = 0.000953
# Epoch 1, Batch 23/240, MSE = 0.000827
# Epoch 1, Batch 24/240, MSE = 0.000789
# Epoch 1, Batch 25/240, MSE = 0.000764
# Epoch 1, Batch 26/240, MSE = 0.000726
# Epoch 1, Batch 27/240, MSE = 0.000712
# Epoch 1, Batch 28/240, MSE = 0.000712
# Epoch 1, Batch 29/240, MSE = 0.000760
# Epoch 1, Batch 30/240, MSE = 0.000813
# Epoch 1, Batch 31/240, MSE = 0.000849
# Epoch 1, Batch 32/240, MSE = 0.000719
# Epoch 1, Batch 33/240, MSE = 0.000696
# Epoch 1, Batch 34/240, MSE = 0.000638
# Epoch 1, Batch 35/240, MSE = 0.000612
# Epoch 1, Batch 36/240, MSE = 0.000600
# Epoch 1, Batch 37/240, MSE = 0.000582
# Epoch 1, Batch 38/240, MSE = 0.000536
# Epoch 1, Batch 39/240, MSE = 0.000584
# Epoch 1, Batch 40/240, MSE = 0.000483
# Epoch 1, Batch 41/240, MSE = 0.000501
# Epoch 1, Batch 42/240, MSE = 0.000600
# Epoch 1, Batch 43/240, MSE = 0.000468
# Epoch 1, Batch 44/240, MSE = 0.000506
# Epoch 1, Batch 45/240, MSE = 0.000563
# Epoch 1, Batch 46/240, MSE = 0.000448
# Epoch 1, Batch 47/240, MSE = 0.000440
# Epoch 1, Batch 48/240, MSE = 0.000456
# Epoch 1, Batch 49/240, MSE = 0.000484
# Epoch 1, Batch 50/240, MSE = 0.000444
# Epoch 1, Batch 51/240, MSE = 0.000423
# Epoch 1, Batch 52/240, MSE = 0.000452
# Epoch 1, Batch 53/240, MSE = 0.000427
# Epoch 1, Batch 54/240, MSE = 0.000426
# Epoch 1, Batch 55/240, MSE = 0.000411
# Epoch 1, Batch 56/240, MSE = 0.000380
# Epoch 1, Batch 57/240, MSE = 0.000411
# Epoch 1, Batch 58/240, MSE = 0.000401
# Epoch 1, Batch 59/240, MSE = 0.000412
# Epoch 1, Batch 60/240, MSE = 0.000402
# Epoch 1, Batch 61/240, MSE = 0.000387
# Epoch 1, Batch 62/240, MSE = 0.000371
# Epoch 1, Batch 63/240, MSE = 0.000363
# Epoch 1, Batch 64/240, MSE = 0.000394
# Epoch 1, Batch 65/240, MSE = 0.000379
# Epoch 1, Batch 66/240, MSE = 0.000387
# Epoch 1, Batch 67/240, MSE = 0.000417
# Epoch 1, Batch 68/240, MSE = 0.000371
# Epoch 1, Batch 69/240, MSE = 0.000373
# Epoch 1, Batch 70/240, MSE = 0.000401
# Epoch 1, Batch 71/240, MSE = 0.000371
# Epoch 1, Batch 72/240, MSE = 0.000352
# Epoch 1, Batch 73/240, MSE = 0.000367
# Epoch 1, Batch 74/240, MSE = 0.000363
# Epoch 1, Batch 75/240, MSE = 0.000374
# Epoch 1, Batch 76/240, MSE = 0.000376
# Epoch 1, Batch 77/240, MSE = 0.000373
# Epoch 1, Batch 78/240, MSE = 0.000404
# Epoch 1, Batch 79/240, MSE = 0.000380
# Epoch 1, Batch 80/240, MSE = 0.000403
# Epoch 1, Batch 81/240, MSE = 0.000390
# Epoch 1, Batch 82/240, MSE = 0.000358
# Epoch 1, Batch 83/240, MSE = 0.000365
# Epoch 1, Batch 84/240, MSE = 0.000367
# Epoch 1, Batch 85/240, MSE = 0.000392
# Epoch 1, Batch 86/240, MSE = 0.000370
# Epoch 1, Batch 87/240, MSE = 0.000378
# Epoch 1, Batch 88/240, MSE = 0.000392
# Epoch 1, Batch 89/240, MSE = 0.000328
# Epoch 1, Batch 90/240, MSE = 0.000378
# Epoch 1, Batch 91/240, MSE = 0.000381
# Epoch 1, Batch 92/240, MSE = 0.000362
# Epoch 1, Batch 93/240, MSE = 0.000381
# Epoch 1, Batch 94/240, MSE = 0.000372
# Epoch 1, Batch 95/240, MSE = 0.000382
# Epoch 1, Batch 96/240, MSE = 0.000376
# Epoch 1, Batch 97/240, MSE = 0.000371
# Epoch 1, Batch 98/240, MSE = 0.000374
# Epoch 1, Batch 99/240, MSE = 0.000390
# Epoch 1, Batch 100/240, MSE = 0.000352
# Epoch 1, Batch 101/240, MSE = 0.000367
# Epoch 1, Batch 102/240, MSE = 0.000373
# Epoch 1, Batch 103/240, MSE = 0.000367
# Epoch 1, Batch 104/240, MSE = 0.000349
# Epoch 1, Batch 105/240, MSE = 0.000355
# Epoch 1, Batch 106/240, MSE = 0.000355
# Epoch 1, Batch 107/240, MSE = 0.000364
# Epoch 1, Batch 108/240, MSE = 0.000371
# Epoch 1, Batch 109/240, MSE = 0.000363
# Epoch 1, Batch 110/240, MSE = 0.000370
# Epoch 1, Batch 111/240, MSE = 0.000356
# Epoch 1, Batch 112/240, MSE = 0.000378
# Epoch 1, Batch 113/240, MSE = 0.000355
# Epoch 1, Batch 114/240, MSE = 0.000375
# Epoch 1, Batch 115/240, MSE = 0.000370
# Epoch 1, Batch 116/240, MSE = 0.000348
# Epoch 1, Batch 117/240, MSE = 0.000363
# Epoch 1, Batch 118/240, MSE = 0.000365
# Epoch 1, Batch 119/240, MSE = 0.000372
# Epoch 1, Batch 120/240, MSE = 0.000398
# Epoch 1, Batch 121/240, MSE = 0.000376
# Epoch 1, Batch 122/240, MSE = 0.000371
# Epoch 1, Batch 123/240, MSE = 0.000370
# Epoch 1, Batch 124/240, MSE = 0.000370
# Epoch 1, Batch 125/240, MSE = 0.000365
# Epoch 1, Batch 126/240, MSE = 0.000372
# Epoch 1, Batch 127/240, MSE = 0.000373
# Epoch 1, Batch 128/240, MSE = 0.000371
# Epoch 1, Batch 129/240, MSE = 0.000360
# Epoch 1, Batch 130/240, MSE = 0.000381
# Epoch 1, Batch 131/240, MSE = 0.000387
# Epoch 1, Batch 132/240, MSE = 0.000397
# Epoch 1, Batch 133/240, MSE = 0.000393
# Epoch 1, Batch 134/240, MSE = 0.000355
# Epoch 1, Batch 135/240, MSE = 0.000373
# Epoch 1, Batch 136/240, MSE = 0.000349
# Epoch 1, Batch 137/240, MSE = 0.000354
# Epoch 1, Batch 138/240, MSE = 0.000367
# Epoch 1, Batch 139/240, MSE = 0.000381
# Epoch 1, Batch 140/240, MSE = 0.000367
# Epoch 1, Batch 141/240, MSE = 0.000369
# Epoch 1, Batch 142/240, MSE = 0.000396
# Epoch 1, Batch 143/240, MSE = 0.000362
# Epoch 1, Batch 144/240, MSE = 0.000397
# Epoch 1, Batch 145/240, MSE = 0.000360
# Epoch 1, Batch 146/240, MSE = 0.000385
# Epoch 1, Batch 147/240, MSE = 0.000376
# Epoch 1, Batch 148/240, MSE = 0.000385
# Epoch 1, Batch 149/240, MSE = 0.000392
# Epoch 1, Batch 150/240, MSE = 0.000344
# Epoch 1, Batch 151/240, MSE = 0.000384
# Epoch 1, Batch 152/240, MSE = 0.000378
# Epoch 1, Batch 153/240, MSE = 0.000378
# Epoch 1, Batch 154/240, MSE = 0.000368
# Epoch 1, Batch 155/240, MSE = 0.000373
# Epoch 1, Batch 156/240, MSE = 0.000365
# Epoch 1, Batch 157/240, MSE = 0.000370
# Epoch 1, Batch 158/240, MSE = 0.000345
# Epoch 1, Batch 159/240, MSE = 0.000389
# Epoch 1, Batch 160/240, MSE = 0.000388
# Epoch 1, Batch 161/240, MSE = 0.000384
# Epoch 1, Batch 162/240, MSE = 0.000395
# Epoch 1, Batch 163/240, MSE = 0.000352
# Epoch 1, Batch 164/240, MSE = 0.000390
# Epoch 1, Batch 165/240, MSE = 0.000395
# Epoch 1, Batch 166/240, MSE = 0.000383
# Epoch 1, Batch 167/240, MSE = 0.000368
# Epoch 1, Batch 168/240, MSE = 0.000381
# Epoch 1, Batch 169/240, MSE = 0.000362
# Epoch 1, Batch 170/240, MSE = 0.000373
# Epoch 1, Batch 171/240, MSE = 0.000352
# Epoch 1, Batch 172/240, MSE = 0.000374
# Epoch 1, Batch 173/240, MSE = 0.000368
# Epoch 1, Batch 174/240, MSE = 0.000358
# Epoch 1, Batch 175/240, MSE = 0.000361
# Epoch 1, Batch 176/240, MSE = 0.000344
# Epoch 1, Batch 177/240, MSE = 0.000366
# Epoch 1, Batch 178/240, MSE = 0.000366
# Epoch 1, Batch 179/240, MSE = 0.000359
# Epoch 1, Batch 180/240, MSE = 0.000388
# Epoch 1, Batch 181/240, MSE = 0.000372
# Epoch 1, Batch 182/240, MSE = 0.000358
# Epoch 1, Batch 183/240, MSE = 0.000381
# Epoch 1, Batch 184/240, MSE = 0.000387
# Epoch 1, Batch 185/240, MSE = 0.000384
# Epoch 1, Batch 186/240, MSE = 0.000356
# Epoch 1, Batch 187/240, MSE = 0.000379
# Epoch 1, Batch 188/240, MSE = 0.000365
# Epoch 1, Batch 189/240, MSE = 0.000363
# Epoch 1, Batch 190/240, MSE = 0.000357
# Epoch 1, Batch 191/240, MSE = 0.000363
# Epoch 1, Batch 192/240, MSE = 0.000384
# Epoch 1, Batch 193/240, MSE = 0.000361
# Epoch 1, Batch 194/240, MSE = 0.000358
# Epoch 1, Batch 195/240, MSE = 0.000373
# Epoch 1, Batch 196/240, MSE = 0.000372
# Epoch 1, Batch 197/240, MSE = 0.000390
# Epoch 1, Batch 198/240, MSE = 0.000369
# Epoch 1, Batch 199/240, MSE = 0.000376
# Epoch 1, Batch 200/240, MSE = 0.000397
# Epoch 1, Batch 201/240, MSE = 0.000353
# Epoch 1, Batch 202/240, MSE = 0.000358
# Epoch 1, Batch 203/240, MSE = 0.000366
# Epoch 1, Batch 204/240, MSE = 0.000371
# Epoch 1, Batch 205/240, MSE = 0.000337
# Epoch 1, Batch 206/240, MSE = 0.000369
# Epoch 1, Batch 207/240, MSE = 0.000376
# Epoch 1, Batch 208/240, MSE = 0.000354
# Epoch 1, Batch 209/240, MSE = 0.000375
# Epoch 1, Batch 210/240, MSE = 0.000342
# Epoch 1, Batch 211/240, MSE = 0.000389
# Epoch 1, Batch 212/240, MSE = 0.000405
# Epoch 1, Batch 213/240, MSE = 0.000379
# Epoch 1, Batch 214/240, MSE = 0.000359
# Epoch 1, Batch 215/240, MSE = 0.000390
# Epoch 1, Batch 216/240, MSE = 0.000375
# Epoch 1, Batch 217/240, MSE = 0.000384
# Epoch 1, Batch 218/240, MSE = 0.000361
# Epoch 1, Batch 219/240, MSE = 0.000380
# Epoch 1, Batch 220/240, MSE = 0.000359
# Epoch 1, Batch 221/240, MSE = 0.000357
# Epoch 1, Batch 222/240, MSE = 0.000371
# Epoch 1, Batch 223/240, MSE = 0.000337
# Epoch 1, Batch 224/240, MSE = 0.000381
# Epoch 1, Batch 225/240, MSE = 0.000364
# Epoch 1, Batch 226/240, MSE = 0.000376
# Epoch 1, Batch 227/240, MSE = 0.000371
# Epoch 1, Batch 228/240, MSE = 0.000383
# Epoch 1, Batch 229/240, MSE = 0.000352
# Epoch 1, Batch 230/240, MSE = 0.000383
# Epoch 1, Batch 231/240, MSE = 0.000377
# Epoch 1, Batch 232/240, MSE = 0.000373
# Epoch 1, Batch 233/240, MSE = 0.000363
# Epoch 1, Batch 234/240, MSE = 0.000380
# Epoch 1, Batch 235/240, MSE = 0.000375
# Epoch 1, Batch 236/240, MSE = 0.000379
# Epoch 1, Batch 237/240, MSE = 0.000362
# Epoch 1, Batch 238/240, MSE = 0.000370
# Epoch 1, Batch 239/240, MSE = 0.000350
# Epoch 1, Batch 240/240, MSE = 0.000379
#
# ============================================================
# Epoch 2/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 1984)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.013308
# Epoch 1, Batch 2/240, MSE = 0.013462
# Epoch 1, Batch 3/240, MSE = 0.013229
# Epoch 1, Batch 4/240, MSE = 0.014020
# Epoch 1, Batch 5/240, MSE = 0.012765
# Epoch 1, Batch 6/240, MSE = 0.012328
# Epoch 1, Batch 7/240, MSE = 0.012343
# Epoch 1, Batch 8/240, MSE = 0.013145
# Epoch 1, Batch 9/240, MSE = 0.013087
# Epoch 1, Batch 10/240, MSE = 0.013697
# Epoch 1, Batch 11/240, MSE = 0.013681
# Epoch 1, Batch 12/240, MSE = 0.013646
# Epoch 1, Batch 13/240, MSE = 0.013823
# Epoch 1, Batch 14/240, MSE = 0.013171
# Epoch 1, Batch 15/240, MSE = 0.012940
# Epoch 1, Batch 16/240, MSE = 0.013895
# Epoch 1, Batch 17/240, MSE = 0.012977
# Epoch 1, Batch 18/240, MSE = 0.013137
# Epoch 1, Batch 19/240, MSE = 0.012757
# Epoch 1, Batch 20/240, MSE = 0.013220
# Epoch 1, Batch 21/240, MSE = 0.012687
# Epoch 1, Batch 22/240, MSE = 0.013183
# Epoch 1, Batch 23/240, MSE = 0.012738
# Epoch 1, Batch 24/240, MSE = 0.013164
# Epoch 1, Batch 25/240, MSE = 0.013179
# Epoch 1, Batch 26/240, MSE = 0.013002
# Epoch 1, Batch 27/240, MSE = 0.013876
# Epoch 1, Batch 28/240, MSE = 0.013880
# Epoch 1, Batch 29/240, MSE = 0.013406
# Epoch 1, Batch 30/240, MSE = 0.012674
# Epoch 1, Batch 31/240, MSE = 0.013273
# Epoch 1, Batch 32/240, MSE = 0.013703
# Epoch 1, Batch 33/240, MSE = 0.012518
# Epoch 1, Batch 34/240, MSE = 0.013545
# Epoch 1, Batch 35/240, MSE = 0.013461
# Epoch 1, Batch 36/240, MSE = 0.012879
# Epoch 1, Batch 37/240, MSE = 0.013408
# Epoch 1, Batch 38/240, MSE = 0.013126
# Epoch 1, Batch 39/240, MSE = 0.013369
# Epoch 1, Batch 40/240, MSE = 0.013621
# Epoch 1, Batch 41/240, MSE = 0.012284
# Epoch 1, Batch 42/240, MSE = 0.013046
# Epoch 1, Batch 43/240, MSE = 0.012701
# Epoch 1, Batch 44/240, MSE = 0.012532
# Epoch 1, Batch 45/240, MSE = 0.013134
# Epoch 1, Batch 46/240, MSE = 0.012335
# Epoch 1, Batch 47/240, MSE = 0.012767
# Epoch 1, Batch 48/240, MSE = 0.013323
# Epoch 1, Batch 49/240, MSE = 0.012827
# Epoch 1, Batch 50/240, MSE = 0.013345
# Epoch 1, Batch 51/240, MSE = 0.013141
# Epoch 1, Batch 52/240, MSE = 0.012839
# Epoch 1, Batch 53/240, MSE = 0.012959
# Epoch 1, Batch 54/240, MSE = 0.013506
# Epoch 1, Batch 55/240, MSE = 0.012701
# Epoch 1, Batch 56/240, MSE = 0.012780
# Epoch 1, Batch 57/240, MSE = 0.013494
# Epoch 1, Batch 58/240, MSE = 0.012869
# Epoch 1, Batch 59/240, MSE = 0.011647
# Epoch 1, Batch 60/240, MSE = 0.012879
# Epoch 1, Batch 61/240, MSE = 0.013115
# Epoch 1, Batch 62/240, MSE = 0.013305
# Epoch 1, Batch 63/240, MSE = 0.012612
# Epoch 1, Batch 64/240, MSE = 0.012110
# Epoch 1, Batch 65/240, MSE = 0.012101
# Epoch 1, Batch 66/240, MSE = 0.012485
# Epoch 1, Batch 67/240, MSE = 0.012618
# Epoch 1, Batch 68/240, MSE = 0.012500
# Epoch 1, Batch 69/240, MSE = 0.013135
# Epoch 1, Batch 70/240, MSE = 0.012620
# Epoch 1, Batch 71/240, MSE = 0.012889
# Epoch 1, Batch 72/240, MSE = 0.012478
# Epoch 1, Batch 73/240, MSE = 0.012196
# Epoch 1, Batch 74/240, MSE = 0.012682
# Epoch 1, Batch 75/240, MSE = 0.012762
# Epoch 1, Batch 76/240, MSE = 0.012769
# Epoch 1, Batch 77/240, MSE = 0.013052
# Epoch 1, Batch 78/240, MSE = 0.012291
# Epoch 1, Batch 79/240, MSE = 0.012659
# Epoch 1, Batch 80/240, MSE = 0.011927
# Epoch 1, Batch 81/240, MSE = 0.011935
# Epoch 1, Batch 82/240, MSE = 0.012624
# Epoch 1, Batch 83/240, MSE = 0.011574
# Epoch 1, Batch 84/240, MSE = 0.012519
# Epoch 1, Batch 85/240, MSE = 0.011919
# Epoch 1, Batch 86/240, MSE = 0.012579
# Epoch 1, Batch 87/240, MSE = 0.012274
# Epoch 1, Batch 88/240, MSE = 0.012060
# Epoch 1, Batch 89/240, MSE = 0.011818
# Epoch 1, Batch 90/240, MSE = 0.012489
# Epoch 1, Batch 91/240, MSE = 0.012178
# Epoch 1, Batch 92/240, MSE = 0.012224
# Epoch 1, Batch 93/240, MSE = 0.011990
# Epoch 1, Batch 94/240, MSE = 0.012440
# Epoch 1, Batch 95/240, MSE = 0.012362
# Epoch 1, Batch 96/240, MSE = 0.012596
# Epoch 1, Batch 97/240, MSE = 0.011881
# Epoch 1, Batch 98/240, MSE = 0.011915
# Epoch 1, Batch 99/240, MSE = 0.013422
# Epoch 1, Batch 100/240, MSE = 0.011975
# Epoch 1, Batch 101/240, MSE = 0.012089
# Epoch 1, Batch 102/240, MSE = 0.011498
# Epoch 1, Batch 103/240, MSE = 0.011306
# Epoch 1, Batch 104/240, MSE = 0.012293
# Epoch 1, Batch 105/240, MSE = 0.011809
# Epoch 1, Batch 106/240, MSE = 0.012433
# Epoch 1, Batch 107/240, MSE = 0.011800
# Epoch 1, Batch 108/240, MSE = 0.011509
# Epoch 1, Batch 109/240, MSE = 0.011768
# Epoch 1, Batch 110/240, MSE = 0.011677
# Epoch 1, Batch 111/240, MSE = 0.011722
# Epoch 1, Batch 112/240, MSE = 0.011515
# Epoch 1, Batch 113/240, MSE = 0.011912
# Epoch 1, Batch 114/240, MSE = 0.011568
# Epoch 1, Batch 115/240, MSE = 0.011828
# Epoch 1, Batch 116/240, MSE = 0.011580
# Epoch 1, Batch 117/240, MSE = 0.011040
# Epoch 1, Batch 118/240, MSE = 0.011979
# Epoch 1, Batch 119/240, MSE = 0.011514
# Epoch 1, Batch 120/240, MSE = 0.011836
# Epoch 1, Batch 121/240, MSE = 0.011250
# Epoch 1, Batch 122/240, MSE = 0.012198
# Epoch 1, Batch 123/240, MSE = 0.012002
# Epoch 1, Batch 124/240, MSE = 0.011336
# Epoch 1, Batch 125/240, MSE = 0.011898
# Epoch 1, Batch 126/240, MSE = 0.011650
# Epoch 1, Batch 127/240, MSE = 0.012085
# Epoch 1, Batch 128/240, MSE = 0.012237
# Epoch 1, Batch 129/240, MSE = 0.011936
# Epoch 1, Batch 130/240, MSE = 0.011206
# Epoch 1, Batch 131/240, MSE = 0.011428
# Epoch 1, Batch 132/240, MSE = 0.012677
# Epoch 1, Batch 133/240, MSE = 0.011470
# Epoch 1, Batch 134/240, MSE = 0.011255
# Epoch 1, Batch 135/240, MSE = 0.011168
# Epoch 1, Batch 136/240, MSE = 0.012222
# Epoch 1, Batch 137/240, MSE = 0.011312
# Epoch 1, Batch 138/240, MSE = 0.011686
# Epoch 1, Batch 139/240, MSE = 0.011173
# Epoch 1, Batch 140/240, MSE = 0.011646
# Epoch 1, Batch 141/240, MSE = 0.011532
# Epoch 1, Batch 142/240, MSE = 0.011456
# Epoch 1, Batch 143/240, MSE = 0.012081
# Epoch 1, Batch 144/240, MSE = 0.011590
# Epoch 1, Batch 145/240, MSE = 0.011090
# Epoch 1, Batch 146/240, MSE = 0.011541
# Epoch 1, Batch 147/240, MSE = 0.012024
# Epoch 1, Batch 148/240, MSE = 0.011216
# Epoch 1, Batch 149/240, MSE = 0.012375
# Epoch 1, Batch 150/240, MSE = 0.011335
# Epoch 1, Batch 151/240, MSE = 0.011526
# Epoch 1, Batch 152/240, MSE = 0.011092
# Epoch 1, Batch 153/240, MSE = 0.010934
# Epoch 1, Batch 154/240, MSE = 0.011893
# Epoch 1, Batch 155/240, MSE = 0.010973
# Epoch 1, Batch 156/240, MSE = 0.010762
# Epoch 1, Batch 157/240, MSE = 0.011354
# Epoch 1, Batch 158/240, MSE = 0.011885
# Epoch 1, Batch 159/240, MSE = 0.011060
# Epoch 1, Batch 160/240, MSE = 0.010528
# Epoch 1, Batch 161/240, MSE = 0.010648
# Epoch 1, Batch 162/240, MSE = 0.010844
# Epoch 1, Batch 163/240, MSE = 0.011302
# Epoch 1, Batch 164/240, MSE = 0.011586
# Epoch 1, Batch 165/240, MSE = 0.010432
# Epoch 1, Batch 166/240, MSE = 0.011726
# Epoch 1, Batch 167/240, MSE = 0.011192
# Epoch 1, Batch 168/240, MSE = 0.011543
# Epoch 1, Batch 169/240, MSE = 0.011286
# Epoch 1, Batch 170/240, MSE = 0.010844
# Epoch 1, Batch 171/240, MSE = 0.011031
# Epoch 1, Batch 172/240, MSE = 0.010634
# Epoch 1, Batch 173/240, MSE = 0.010866
# Epoch 1, Batch 174/240, MSE = 0.010890
# Epoch 1, Batch 175/240, MSE = 0.010552
# Epoch 1, Batch 176/240, MSE = 0.010900
# Epoch 1, Batch 177/240, MSE = 0.011423
# Epoch 1, Batch 178/240, MSE = 0.011549
# Epoch 1, Batch 179/240, MSE = 0.010985
# Epoch 1, Batch 180/240, MSE = 0.011523
# Epoch 1, Batch 181/240, MSE = 0.010506
# Epoch 1, Batch 182/240, MSE = 0.011677
# Epoch 1, Batch 183/240, MSE = 0.010950
# Epoch 1, Batch 184/240, MSE = 0.010384
# Epoch 1, Batch 185/240, MSE = 0.010938
# Epoch 1, Batch 186/240, MSE = 0.010917
# Epoch 1, Batch 187/240, MSE = 0.010592
# Epoch 1, Batch 188/240, MSE = 0.010946
# Epoch 1, Batch 189/240, MSE = 0.011123
# Epoch 1, Batch 190/240, MSE = 0.009765
# Epoch 1, Batch 191/240, MSE = 0.010037
# Epoch 1, Batch 192/240, MSE = 0.010905
# Epoch 1, Batch 193/240, MSE = 0.010755
# Epoch 1, Batch 194/240, MSE = 0.010711
# Epoch 1, Batch 195/240, MSE = 0.010542
# Epoch 1, Batch 196/240, MSE = 0.010863
# Epoch 1, Batch 197/240, MSE = 0.010922
# Epoch 1, Batch 198/240, MSE = 0.010437
# Epoch 1, Batch 199/240, MSE = 0.010149
# Epoch 1, Batch 200/240, MSE = 0.011019
# Epoch 1, Batch 201/240, MSE = 0.010972
# Epoch 1, Batch 202/240, MSE = 0.010585
# Epoch 1, Batch 203/240, MSE = 0.010126
# Epoch 1, Batch 204/240, MSE = 0.009958
# Epoch 1, Batch 205/240, MSE = 0.010315
# Epoch 1, Batch 206/240, MSE = 0.010783
# Epoch 1, Batch 207/240, MSE = 0.010744
# Epoch 1, Batch 208/240, MSE = 0.010483
# Epoch 1, Batch 209/240, MSE = 0.010614
# Epoch 1, Batch 210/240, MSE = 0.011008
# Epoch 1, Batch 211/240, MSE = 0.010495
# Epoch 1, Batch 212/240, MSE = 0.011182
# Epoch 1, Batch 213/240, MSE = 0.010325
# Epoch 1, Batch 214/240, MSE = 0.010367
# Epoch 1, Batch 215/240, MSE = 0.010102
# Epoch 1, Batch 216/240, MSE = 0.010690
# Epoch 1, Batch 217/240, MSE = 0.010277
# Epoch 1, Batch 218/240, MSE = 0.010001
# Epoch 1, Batch 219/240, MSE = 0.010076
# Epoch 1, Batch 220/240, MSE = 0.010729
# Epoch 1, Batch 221/240, MSE = 0.010666
# Epoch 1, Batch 222/240, MSE = 0.010157
# Epoch 1, Batch 223/240, MSE = 0.010099
# Epoch 1, Batch 224/240, MSE = 0.010100
# Epoch 1, Batch 225/240, MSE = 0.009682
# Epoch 1, Batch 226/240, MSE = 0.010633
# Epoch 1, Batch 227/240, MSE = 0.011014
# Epoch 1, Batch 228/240, MSE = 0.009851
# Epoch 1, Batch 229/240, MSE = 0.010551
# Epoch 1, Batch 230/240, MSE = 0.010702
# Epoch 1, Batch 231/240, MSE = 0.010338
# Epoch 1, Batch 232/240, MSE = 0.010626
# Epoch 1, Batch 233/240, MSE = 0.010143
# Epoch 1, Batch 234/240, MSE = 0.010092
# Epoch 1, Batch 235/240, MSE = 0.010650
# Epoch 1, Batch 236/240, MSE = 0.009454
# Epoch 1, Batch 237/240, MSE = 0.010144
# Epoch 1, Batch 238/240, MSE = 0.010080
# Epoch 1, Batch 239/240, MSE = 0.010053
# Epoch 1, Batch 240/240, MSE = 0.010226
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.003185
# Epoch 1, Batch 2/240, MSE = 0.003104
# Epoch 1, Batch 3/240, MSE = 0.003116
# Epoch 1, Batch 4/240, MSE = 0.003134
# Epoch 1, Batch 5/240, MSE = 0.003212
# Epoch 1, Batch 6/240, MSE = 0.003262
# Epoch 1, Batch 7/240, MSE = 0.003167
# Epoch 1, Batch 8/240, MSE = 0.003226
# Epoch 1, Batch 9/240, MSE = 0.003234
# Epoch 1, Batch 10/240, MSE = 0.003174
# Epoch 1, Batch 11/240, MSE = 0.002923
# Epoch 1, Batch 12/240, MSE = 0.002892
# Epoch 1, Batch 13/240, MSE = 0.003059
# Epoch 1, Batch 14/240, MSE = 0.003118
# Epoch 1, Batch 15/240, MSE = 0.003084
# Epoch 1, Batch 16/240, MSE = 0.003242
# Epoch 1, Batch 17/240, MSE = 0.003343
# Epoch 1, Batch 18/240, MSE = 0.003211
# Epoch 1, Batch 19/240, MSE = 0.003288
# Epoch 1, Batch 20/240, MSE = 0.003198
# Epoch 1, Batch 21/240, MSE = 0.003126
# Epoch 1, Batch 22/240, MSE = 0.003010
# Epoch 1, Batch 23/240, MSE = 0.002934
# Epoch 1, Batch 24/240, MSE = 0.003005
# Epoch 1, Batch 25/240, MSE = 0.003101
# Epoch 1, Batch 26/240, MSE = 0.003268
# Epoch 1, Batch 27/240, MSE = 0.003180
# Epoch 1, Batch 28/240, MSE = 0.003384
# Epoch 1, Batch 29/240, MSE = 0.003155
# Epoch 1, Batch 30/240, MSE = 0.003072
# Epoch 1, Batch 31/240, MSE = 0.002820
# Epoch 1, Batch 32/240, MSE = 0.003070
# Epoch 1, Batch 33/240, MSE = 0.003015
# Epoch 1, Batch 34/240, MSE = 0.003176
# Epoch 1, Batch 35/240, MSE = 0.003193
# Epoch 1, Batch 36/240, MSE = 0.003308
# Epoch 1, Batch 37/240, MSE = 0.003174
# Epoch 1, Batch 38/240, MSE = 0.002846
# Epoch 1, Batch 39/240, MSE = 0.003075
# Epoch 1, Batch 40/240, MSE = 0.003285
# Epoch 1, Batch 41/240, MSE = 0.003013
# Epoch 1, Batch 42/240, MSE = 0.003118
# Epoch 1, Batch 43/240, MSE = 0.002978
# Epoch 1, Batch 44/240, MSE = 0.002901
# Epoch 1, Batch 45/240, MSE = 0.003221
# Epoch 1, Batch 46/240, MSE = 0.003130
# Epoch 1, Batch 47/240, MSE = 0.003200
# Epoch 1, Batch 48/240, MSE = 0.003217
# Epoch 1, Batch 49/240, MSE = 0.003092
# Epoch 1, Batch 50/240, MSE = 0.003161
# Epoch 1, Batch 51/240, MSE = 0.002994
# Epoch 1, Batch 52/240, MSE = 0.003252
# Epoch 1, Batch 53/240, MSE = 0.003061
# Epoch 1, Batch 54/240, MSE = 0.003132
# Epoch 1, Batch 55/240, MSE = 0.002969
# Epoch 1, Batch 56/240, MSE = 0.003174
# Epoch 1, Batch 57/240, MSE = 0.002995
# Epoch 1, Batch 58/240, MSE = 0.003123
# Epoch 1, Batch 59/240, MSE = 0.003192
# Epoch 1, Batch 60/240, MSE = 0.002981
# Epoch 1, Batch 61/240, MSE = 0.003342
# Epoch 1, Batch 62/240, MSE = 0.003025
# Epoch 1, Batch 63/240, MSE = 0.003078
# Epoch 1, Batch 64/240, MSE = 0.003262
# Epoch 1, Batch 65/240, MSE = 0.002940
# Epoch 1, Batch 66/240, MSE = 0.003159
# Epoch 1, Batch 67/240, MSE = 0.003106
# Epoch 1, Batch 68/240, MSE = 0.003102
# Epoch 1, Batch 69/240, MSE = 0.003190
# Epoch 1, Batch 70/240, MSE = 0.003015
# Epoch 1, Batch 71/240, MSE = 0.003307
# Epoch 1, Batch 72/240, MSE = 0.003093
# Epoch 1, Batch 73/240, MSE = 0.003048
# Epoch 1, Batch 74/240, MSE = 0.003170
# Epoch 1, Batch 75/240, MSE = 0.003017
# Epoch 1, Batch 76/240, MSE = 0.002984
# Epoch 1, Batch 77/240, MSE = 0.003223
# Epoch 1, Batch 78/240, MSE = 0.003056
# Epoch 1, Batch 79/240, MSE = 0.003107
# Epoch 1, Batch 80/240, MSE = 0.003179
# Epoch 1, Batch 81/240, MSE = 0.003170
# Epoch 1, Batch 82/240, MSE = 0.002981
# Epoch 1, Batch 83/240, MSE = 0.003129
# Epoch 1, Batch 84/240, MSE = 0.003112
# Epoch 1, Batch 85/240, MSE = 0.002979
# Epoch 1, Batch 86/240, MSE = 0.003117
# Epoch 1, Batch 87/240, MSE = 0.003112
# Epoch 1, Batch 88/240, MSE = 0.003012
# Epoch 1, Batch 89/240, MSE = 0.003211
# Epoch 1, Batch 90/240, MSE = 0.003041
# Epoch 1, Batch 91/240, MSE = 0.002907
# Epoch 1, Batch 92/240, MSE = 0.003223
# Epoch 1, Batch 93/240, MSE = 0.003002
# Epoch 1, Batch 94/240, MSE = 0.003373
# Epoch 1, Batch 95/240, MSE = 0.002989
# Epoch 1, Batch 96/240, MSE = 0.003172
# Epoch 1, Batch 97/240, MSE = 0.003304
# Epoch 1, Batch 98/240, MSE = 0.002974
# Epoch 1, Batch 99/240, MSE = 0.003175
# Epoch 1, Batch 100/240, MSE = 0.003074
# Epoch 1, Batch 101/240, MSE = 0.002897
# Epoch 1, Batch 102/240, MSE = 0.002938
# Epoch 1, Batch 103/240, MSE = 0.003269
# Epoch 1, Batch 104/240, MSE = 0.003046
# Epoch 1, Batch 105/240, MSE = 0.003013
# Epoch 1, Batch 106/240, MSE = 0.003004
# Epoch 1, Batch 107/240, MSE = 0.003020
# Epoch 1, Batch 108/240, MSE = 0.003425
# Epoch 1, Batch 109/240, MSE = 0.003182
# Epoch 1, Batch 110/240, MSE = 0.002966
# Epoch 1, Batch 111/240, MSE = 0.003131
# Epoch 1, Batch 112/240, MSE = 0.002985
# Epoch 1, Batch 113/240, MSE = 0.003254
# Epoch 1, Batch 114/240, MSE = 0.003032
# Epoch 1, Batch 115/240, MSE = 0.003153
# Epoch 1, Batch 116/240, MSE = 0.003100
# Epoch 1, Batch 117/240, MSE = 0.002995
# Epoch 1, Batch 118/240, MSE = 0.002884
# Epoch 1, Batch 119/240, MSE = 0.003286
# Epoch 1, Batch 120/240, MSE = 0.003007
# Epoch 1, Batch 121/240, MSE = 0.003067
# Epoch 1, Batch 122/240, MSE = 0.003140
# Epoch 1, Batch 123/240, MSE = 0.003283
# Epoch 1, Batch 124/240, MSE = 0.003110
# Epoch 1, Batch 125/240, MSE = 0.003124
# Epoch 1, Batch 126/240, MSE = 0.003101
# Epoch 1, Batch 127/240, MSE = 0.003085
# Epoch 1, Batch 128/240, MSE = 0.003162
# Epoch 1, Batch 129/240, MSE = 0.003137
# Epoch 1, Batch 130/240, MSE = 0.003556
# Epoch 1, Batch 131/240, MSE = 0.002840
# Epoch 1, Batch 132/240, MSE = 0.002991
# Epoch 1, Batch 133/240, MSE = 0.003095
# Epoch 1, Batch 134/240, MSE = 0.003068
# Epoch 1, Batch 135/240, MSE = 0.003145
# Epoch 1, Batch 136/240, MSE = 0.003227
# Epoch 1, Batch 137/240, MSE = 0.003334
# Epoch 1, Batch 138/240, MSE = 0.003056
# Epoch 1, Batch 139/240, MSE = 0.003046
# Epoch 1, Batch 140/240, MSE = 0.003066
# Epoch 1, Batch 141/240, MSE = 0.003253
# Epoch 1, Batch 142/240, MSE = 0.003196
# Epoch 1, Batch 143/240, MSE = 0.003273
# Epoch 1, Batch 144/240, MSE = 0.002911
# Epoch 1, Batch 145/240, MSE = 0.002963
# Epoch 1, Batch 146/240, MSE = 0.003073
# Epoch 1, Batch 147/240, MSE = 0.003265
# Epoch 1, Batch 148/240, MSE = 0.002954
# Epoch 1, Batch 149/240, MSE = 0.003061
# Epoch 1, Batch 150/240, MSE = 0.002947
# Epoch 1, Batch 151/240, MSE = 0.003124
# Epoch 1, Batch 152/240, MSE = 0.003103
# Epoch 1, Batch 153/240, MSE = 0.003098
# Epoch 1, Batch 154/240, MSE = 0.003227
# Epoch 1, Batch 155/240, MSE = 0.002897
# Epoch 1, Batch 156/240, MSE = 0.003068
# Epoch 1, Batch 157/240, MSE = 0.003170
# Epoch 1, Batch 158/240, MSE = 0.003063
# Epoch 1, Batch 159/240, MSE = 0.002957
# Epoch 1, Batch 160/240, MSE = 0.003141
# Epoch 1, Batch 161/240, MSE = 0.003160
# Epoch 1, Batch 162/240, MSE = 0.003129
# Epoch 1, Batch 163/240, MSE = 0.003042
# Epoch 1, Batch 164/240, MSE = 0.003021
# Epoch 1, Batch 165/240, MSE = 0.003200
# Epoch 1, Batch 166/240, MSE = 0.003024
# Epoch 1, Batch 167/240, MSE = 0.003192
# Epoch 1, Batch 168/240, MSE = 0.002963
# Epoch 1, Batch 169/240, MSE = 0.003231
# Epoch 1, Batch 170/240, MSE = 0.003079
# Epoch 1, Batch 171/240, MSE = 0.003074
# Epoch 1, Batch 172/240, MSE = 0.003253
# Epoch 1, Batch 173/240, MSE = 0.003030
# Epoch 1, Batch 174/240, MSE = 0.003030
# Epoch 1, Batch 175/240, MSE = 0.003098
# Epoch 1, Batch 176/240, MSE = 0.003042
# Epoch 1, Batch 177/240, MSE = 0.003122
# Epoch 1, Batch 178/240, MSE = 0.002709
# Epoch 1, Batch 179/240, MSE = 0.002998
# Epoch 1, Batch 180/240, MSE = 0.002889
# Epoch 1, Batch 181/240, MSE = 0.003152
# Epoch 1, Batch 182/240, MSE = 0.003030
# Epoch 1, Batch 183/240, MSE = 0.003138
# Epoch 1, Batch 184/240, MSE = 0.003170
# Epoch 1, Batch 185/240, MSE = 0.003082
# Epoch 1, Batch 186/240, MSE = 0.002964
# Epoch 1, Batch 187/240, MSE = 0.003025
# Epoch 1, Batch 188/240, MSE = 0.002952
# Epoch 1, Batch 189/240, MSE = 0.002984
# Epoch 1, Batch 190/240, MSE = 0.003037
# Epoch 1, Batch 191/240, MSE = 0.002916
# Epoch 1, Batch 192/240, MSE = 0.003097
# Epoch 1, Batch 193/240, MSE = 0.002844
# Epoch 1, Batch 194/240, MSE = 0.003157
# Epoch 1, Batch 195/240, MSE = 0.003085
# Epoch 1, Batch 196/240, MSE = 0.003188
# Epoch 1, Batch 197/240, MSE = 0.003074
# Epoch 1, Batch 198/240, MSE = 0.003141
# Epoch 1, Batch 199/240, MSE = 0.003080
# Epoch 1, Batch 200/240, MSE = 0.002881
# Epoch 1, Batch 201/240, MSE = 0.003112
# Epoch 1, Batch 202/240, MSE = 0.003011
# Epoch 1, Batch 203/240, MSE = 0.003004
# Epoch 1, Batch 204/240, MSE = 0.003135
# Epoch 1, Batch 205/240, MSE = 0.003048
# Epoch 1, Batch 206/240, MSE = 0.002873
# Epoch 1, Batch 207/240, MSE = 0.003062
# Epoch 1, Batch 208/240, MSE = 0.003130
# Epoch 1, Batch 209/240, MSE = 0.002998
# Epoch 1, Batch 210/240, MSE = 0.003062
# Epoch 1, Batch 211/240, MSE = 0.002890
# Epoch 1, Batch 212/240, MSE = 0.002852
# Epoch 1, Batch 213/240, MSE = 0.002980
# Epoch 1, Batch 214/240, MSE = 0.003077
# Epoch 1, Batch 215/240, MSE = 0.002920
# Epoch 1, Batch 216/240, MSE = 0.002993
# Epoch 1, Batch 217/240, MSE = 0.003130
# Epoch 1, Batch 218/240, MSE = 0.002891
# Epoch 1, Batch 219/240, MSE = 0.003180
# Epoch 1, Batch 220/240, MSE = 0.002900
# Epoch 1, Batch 221/240, MSE = 0.002921
# Epoch 1, Batch 222/240, MSE = 0.003190
# Epoch 1, Batch 223/240, MSE = 0.003107
# Epoch 1, Batch 224/240, MSE = 0.003141
# Epoch 1, Batch 225/240, MSE = 0.003090
# Epoch 1, Batch 226/240, MSE = 0.003063
# Epoch 1, Batch 227/240, MSE = 0.003044
# Epoch 1, Batch 228/240, MSE = 0.003050
# Epoch 1, Batch 229/240, MSE = 0.003027
# Epoch 1, Batch 230/240, MSE = 0.003057
# Epoch 1, Batch 231/240, MSE = 0.003122
# Epoch 1, Batch 232/240, MSE = 0.003004
# Epoch 1, Batch 233/240, MSE = 0.002978
# Epoch 1, Batch 234/240, MSE = 0.003068
# Epoch 1, Batch 235/240, MSE = 0.002975
# Epoch 1, Batch 236/240, MSE = 0.003091
# Epoch 1, Batch 237/240, MSE = 0.003160
# Epoch 1, Batch 238/240, MSE = 0.002907
# Epoch 1, Batch 239/240, MSE = 0.003004
# Epoch 1, Batch 240/240, MSE = 0.003304
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.000784
# Epoch 1, Batch 2/240, MSE = 0.000767
# Epoch 1, Batch 3/240, MSE = 0.000745
# Epoch 1, Batch 4/240, MSE = 0.000705
# Epoch 1, Batch 5/240, MSE = 0.000731
# Epoch 1, Batch 6/240, MSE = 0.000771
# Epoch 1, Batch 7/240, MSE = 0.000726
# Epoch 1, Batch 8/240, MSE = 0.000712
# Epoch 1, Batch 9/240, MSE = 0.000744
# Epoch 1, Batch 10/240, MSE = 0.000749
# Epoch 1, Batch 11/240, MSE = 0.000757
# Epoch 1, Batch 12/240, MSE = 0.000718
# Epoch 1, Batch 13/240, MSE = 0.000750
# Epoch 1, Batch 14/240, MSE = 0.000660
# Epoch 1, Batch 15/240, MSE = 0.000738
# Epoch 1, Batch 16/240, MSE = 0.000706
# Epoch 1, Batch 17/240, MSE = 0.000759
# Epoch 1, Batch 18/240, MSE = 0.000739
# Epoch 1, Batch 19/240, MSE = 0.000745
# Epoch 1, Batch 20/240, MSE = 0.000708
# ...
# Epoch 1, Batch 69/240, MSE = 0.000144
# Epoch 1, Batch 70/240, MSE = 0.000153
# Epoch 1, Batch 71/240, MSE = 0.000145
# Epoch 1, Batch 72/240, MSE = 0.000145
# Epoch 1, Batch 73/240, MSE = 0.000148
# Epoch 1, Batch 74/240, MSE = 0.000147
# Epoch 1, Batch 75/240, MSE = 0.000153
# Epoch 1, Batch 76/240, MSE = 0.000158
# Epoch 1, Batch 77/240, MSE = 0.000141
# Epoch 1, Batch 78/240, MSE = 0.000152
# Epoch 1, Batch 79/240, MSE = 0.000156
# Epoch 1, Batch 80/240, MSE = 0.000138
# Epoch 1, Batch 81/240, MSE = 0.000159
# Epoch 1, Batch 82/240, MSE = 0.000150
# Epoch 1, Batch 83/240, MSE = 0.000151
# Epoch 1, Batch 84/240, MSE = 0.000141
# Epoch 1, Batch 85/240, MSE = 0.000155
# Epoch 1, Batch 86/240, MSE = 0.000149
# Epoch 1, Batch 87/240, MSE = 0.000147
# Epoch 1, Batch 88/240, MSE = 0.000146
# Epoch 1, Batch 89/240, MSE = 0.000153
# Epoch 1, Batch 90/240, MSE = 0.000139
# Epoch 1, Batch 91/240, MSE = 0.000140
# Epoch 1, Batch 92/240, MSE = 0.000143
# Epoch 1, Batch 93/240, MSE = 0.000141
# Epoch 1, Batch 94/240, MSE = 0.000146
# Epoch 1, Batch 95/240, MSE = 0.000145
# Epoch 1, Batch 96/240, MSE = 0.000159
# Epoch 1, Batch 97/240, MSE = 0.000155
# Epoch 1, Batch 98/240, MSE = 0.000139
# Epoch 1, Batch 99/240, MSE = 0.000146
# Epoch 1, Batch 100/240, MSE = 0.000152
# Epoch 1, Batch 101/240, MSE = 0.000133
# Epoch 1, Batch 102/240, MSE = 0.000136
# Epoch 1, Batch 103/240, MSE = 0.000139
# Epoch 1, Batch 104/240, MSE = 0.000151
# Epoch 1, Batch 105/240, MSE = 0.000149
# Epoch 1, Batch 106/240, MSE = 0.000158
# Epoch 1, Batch 107/240, MSE = 0.000143
# Epoch 1, Batch 108/240, MSE = 0.000145
# Epoch 1, Batch 109/240, MSE = 0.000142
# Epoch 1, Batch 110/240, MSE = 0.000149
# Epoch 1, Batch 111/240, MSE = 0.000133
# Epoch 1, Batch 112/240, MSE = 0.000133
# Epoch 1, Batch 113/240, MSE = 0.000143
# Epoch 1, Batch 114/240, MSE = 0.000150
# Epoch 1, Batch 115/240, MSE = 0.000147
# Epoch 1, Batch 116/240, MSE = 0.000146
# Epoch 1, Batch 117/240, MSE = 0.000135
# Epoch 1, Batch 118/240, MSE = 0.000138
# Epoch 1, Batch 119/240, MSE = 0.000144
# Epoch 1, Batch 120/240, MSE = 0.000160
# Epoch 1, Batch 121/240, MSE = 0.000126
# Epoch 1, Batch 122/240, MSE = 0.000148
# Epoch 1, Batch 123/240, MSE = 0.000145
# Epoch 1, Batch 124/240, MSE = 0.000134
# Epoch 1, Batch 125/240, MSE = 0.000140
# Epoch 1, Batch 126/240, MSE = 0.000139
# Epoch 1, Batch 127/240, MSE = 0.000142
# Epoch 1, Batch 128/240, MSE = 0.000137
# Epoch 1, Batch 129/240, MSE = 0.000155
# Epoch 1, Batch 130/240, MSE = 0.000152
# Epoch 1, Batch 131/240, MSE = 0.000144
# Epoch 1, Batch 132/240, MSE = 0.000146
# Epoch 1, Batch 133/240, MSE = 0.000134
# Epoch 1, Batch 134/240, MSE = 0.000128
# Epoch 1, Batch 135/240, MSE = 0.000146
# Epoch 1, Batch 136/240, MSE = 0.000147
# Epoch 1, Batch 137/240, MSE = 0.000137
# Epoch 1, Batch 138/240, MSE = 0.000136
# Epoch 1, Batch 139/240, MSE = 0.000132
# Epoch 1, Batch 140/240, MSE = 0.000151
# Epoch 1, Batch 141/240, MSE = 0.000136
# Epoch 1, Batch 142/240, MSE = 0.000145
# Epoch 1, Batch 143/240, MSE = 0.000135
# Epoch 1, Batch 144/240, MSE = 0.000130
# Epoch 1, Batch 145/240, MSE = 0.000137
# Epoch 1, Batch 146/240, MSE = 0.000135
# Epoch 1, Batch 147/240, MSE = 0.000139
# Epoch 1, Batch 148/240, MSE = 0.000142
# Epoch 1, Batch 149/240, MSE = 0.000148
# Epoch 1, Batch 150/240, MSE = 0.000138
# Epoch 1, Batch 151/240, MSE = 0.000137
# Epoch 1, Batch 152/240, MSE = 0.000144
# Epoch 1, Batch 153/240, MSE = 0.000140
# Epoch 1, Batch 154/240, MSE = 0.000129
# Epoch 1, Batch 155/240, MSE = 0.000123
# Epoch 1, Batch 156/240, MSE = 0.000147
# Epoch 1, Batch 157/240, MSE = 0.000135
# Epoch 1, Batch 158/240, MSE = 0.000142
# Epoch 1, Batch 159/240, MSE = 0.000141
# Epoch 1, Batch 160/240, MSE = 0.000137
# Epoch 1, Batch 161/240, MSE = 0.000129
# Epoch 1, Batch 162/240, MSE = 0.000134
# Epoch 1, Batch 163/240, MSE = 0.000144
# Epoch 1, Batch 164/240, MSE = 0.000141
# Epoch 1, Batch 165/240, MSE = 0.000139
# Epoch 1, Batch 166/240, MSE = 0.000125
# Epoch 1, Batch 167/240, MSE = 0.000141
# Epoch 1, Batch 168/240, MSE = 0.000135
# Epoch 1, Batch 169/240, MSE = 0.000126
# Epoch 1, Batch 170/240, MSE = 0.000136
# Epoch 1, Batch 171/240, MSE = 0.000136
# Epoch 1, Batch 172/240, MSE = 0.000134
# Epoch 1, Batch 173/240, MSE = 0.000136
# Epoch 1, Batch 174/240, MSE = 0.000139
# Epoch 1, Batch 175/240, MSE = 0.000126
# Epoch 1, Batch 176/240, MSE = 0.000146
# Epoch 1, Batch 177/240, MSE = 0.000131
# Epoch 1, Batch 178/240, MSE = 0.000136
# Epoch 1, Batch 179/240, MSE = 0.000139
# Epoch 1, Batch 180/240, MSE = 0.000144
# Epoch 1, Batch 181/240, MSE = 0.000147
# Epoch 1, Batch 182/240, MSE = 0.000148
# Epoch 1, Batch 183/240, MSE = 0.000121
# Epoch 1, Batch 184/240, MSE = 0.000134
# Epoch 1, Batch 185/240, MSE = 0.000144
# Epoch 1, Batch 186/240, MSE = 0.000136
# Epoch 1, Batch 187/240, MSE = 0.000136
# Epoch 1, Batch 188/240, MSE = 0.000141
# Epoch 1, Batch 189/240, MSE = 0.000141
# Epoch 1, Batch 190/240, MSE = 0.000123
# Epoch 1, Batch 191/240, MSE = 0.000131
# Epoch 1, Batch 192/240, MSE = 0.000128
# Epoch 1, Batch 193/240, MSE = 0.000133
# Epoch 1, Batch 194/240, MSE = 0.000130
# Epoch 1, Batch 195/240, MSE = 0.000138
# Epoch 1, Batch 196/240, MSE = 0.000128
# Epoch 1, Batch 197/240, MSE = 0.000127
# Epoch 1, Batch 198/240, MSE = 0.000131
# Epoch 1, Batch 199/240, MSE = 0.000121
# Epoch 1, Batch 200/240, MSE = 0.000125
# Epoch 1, Batch 201/240, MSE = 0.000131
# Epoch 1, Batch 202/240, MSE = 0.000130
# Epoch 1, Batch 203/240, MSE = 0.000125
# Epoch 1, Batch 204/240, MSE = 0.000138
# Epoch 1, Batch 205/240, MSE = 0.000132
# Epoch 1, Batch 206/240, MSE = 0.000144
# Epoch 1, Batch 207/240, MSE = 0.000116
# Epoch 1, Batch 208/240, MSE = 0.000136
# Epoch 1, Batch 209/240, MSE = 0.000124
# Epoch 1, Batch 210/240, MSE = 0.000129
# Epoch 1, Batch 211/240, MSE = 0.000125
# Epoch 1, Batch 212/240, MSE = 0.000125
# Epoch 1, Batch 213/240, MSE = 0.000126
# Epoch 1, Batch 214/240, MSE = 0.000141
# Epoch 1, Batch 215/240, MSE = 0.000136
# Epoch 1, Batch 216/240, MSE = 0.000143
# Epoch 1, Batch 217/240, MSE = 0.000125
# Epoch 1, Batch 218/240, MSE = 0.000123
# Epoch 1, Batch 219/240, MSE = 0.000131
# Epoch 1, Batch 220/240, MSE = 0.000123
# Epoch 1, Batch 221/240, MSE = 0.000129
# Epoch 1, Batch 222/240, MSE = 0.000134
# Epoch 1, Batch 223/240, MSE = 0.000140
# Epoch 1, Batch 224/240, MSE = 0.000120
# Epoch 1, Batch 225/240, MSE = 0.000131
# Epoch 1, Batch 226/240, MSE = 0.000139
# Epoch 1, Batch 227/240, MSE = 0.000139
# Epoch 1, Batch 228/240, MSE = 0.000128
# Epoch 1, Batch 229/240, MSE = 0.000132
# Epoch 1, Batch 230/240, MSE = 0.000130
# Epoch 1, Batch 231/240, MSE = 0.000129
# Epoch 1, Batch 232/240, MSE = 0.000127
# Epoch 1, Batch 233/240, MSE = 0.000142
# Epoch 1, Batch 234/240, MSE = 0.000131
# Epoch 1, Batch 235/240, MSE = 0.000131
# Epoch 1, Batch 236/240, MSE = 0.000127
# Epoch 1, Batch 237/240, MSE = 0.000143
# Epoch 1, Batch 238/240, MSE = 0.000119
# Epoch 1, Batch 239/240, MSE = 0.000133
# Epoch 1, Batch 240/240, MSE = 0.000120
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.003766
# Epoch 1, Batch 2/240, MSE = 0.003476
# Epoch 1, Batch 3/240, MSE = 0.003817
# Epoch 1, Batch 4/240, MSE = 0.003548
# Epoch 1, Batch 5/240, MSE = 0.003702
# Epoch 1, Batch 6/240, MSE = 0.003763
# Epoch 1, Batch 7/240, MSE = 0.003595
# Epoch 1, Batch 8/240, MSE = 0.003523
# Epoch 1, Batch 9/240, MSE = 0.003558
# Epoch 1, Batch 10/240, MSE = 0.003666
# Epoch 1, Batch 11/240, MSE = 0.003731
# Epoch 1, Batch 12/240, MSE = 0.003977
# Epoch 1, Batch 13/240, MSE = 0.003503
# Epoch 1, Batch 14/240, MSE = 0.003883
# Epoch 1, Batch 15/240, MSE = 0.003654
# Epoch 1, Batch 16/240, MSE = 0.003444
# Epoch 1, Batch 17/240, MSE = 0.003647
# Epoch 1, Batch 18/240, MSE = 0.003629
# Epoch 1, Batch 19/240, MSE = 0.003397
# Epoch 1, Batch 20/240, MSE = 0.003952
# Epoch 1, Batch 21/240, MSE = 0.003547
# Epoch 1, Batch 22/240, MSE = 0.003686
# Epoch 1, Batch 23/240, MSE = 0.003646
# Epoch 1, Batch 24/240, MSE = 0.003608
# Epoch 1, Batch 25/240, MSE = 0.003860
# Epoch 1, Batch 26/240, MSE = 0.003867
# Epoch 1, Batch 27/240, MSE = 0.003817
# Epoch 1, Batch 28/240, MSE = 0.003745
# Epoch 1, Batch 29/240, MSE = 0.003433
# Epoch 1, Batch 30/240, MSE = 0.003706
# Epoch 1, Batch 31/240, MSE = 0.003482
# Epoch 1, Batch 32/240, MSE = 0.003403
# Epoch 1, Batch 33/240, MSE = 0.003725
# Epoch 1, Batch 34/240, MSE = 0.003748
# Epoch 1, Batch 35/240, MSE = 0.003717
# Epoch 1, Batch 36/240, MSE = 0.003429
# Epoch 1, Batch 37/240, MSE = 0.003441
# Epoch 1, Batch 38/240, MSE = 0.003468
# Epoch 1, Batch 39/240, MSE = 0.003426
# Epoch 1, Batch 40/240, MSE = 0.003706
# Epoch 1, Batch 41/240, MSE = 0.003639
# Epoch 1, Batch 42/240, MSE = 0.003499
# Epoch 1, Batch 43/240, MSE = 0.003604
# Epoch 1, Batch 44/240, MSE = 0.003511
# Epoch 1, Batch 45/240, MSE = 0.003588
# Epoch 1, Batch 46/240, MSE = 0.003987
# Epoch 1, Batch 47/240, MSE = 0.003627
# Epoch 1, Batch 48/240, MSE = 0.003846
# Epoch 1, Batch 49/240, MSE = 0.003612
# Epoch 1, Batch 50/240, MSE = 0.003777
# Epoch 1, Batch 51/240, MSE = 0.003676
# Epoch 1, Batch 52/240, MSE = 0.003592
# Epoch 1, Batch 53/240, MSE = 0.003713
# Epoch 1, Batch 54/240, MSE = 0.003493
# Epoch 1, Batch 55/240, MSE = 0.003786
# Epoch 1, Batch 56/240, MSE = 0.003210
# Epoch 1, Batch 57/240, MSE = 0.003502
# Epoch 1, Batch 58/240, MSE = 0.003575
# Epoch 1, Batch 59/240, MSE = 0.003585
# Epoch 1, Batch 60/240, MSE = 0.003597
# Epoch 1, Batch 61/240, MSE = 0.003403
# Epoch 1, Batch 62/240, MSE = 0.003359
# Epoch 1, Batch 63/240, MSE = 0.003428
# Epoch 1, Batch 64/240, MSE = 0.003252
# Epoch 1, Batch 65/240, MSE = 0.003633
# Epoch 1, Batch 66/240, MSE = 0.003516
# Epoch 1, Batch 67/240, MSE = 0.003530
# Epoch 1, Batch 68/240, MSE = 0.003605
# Epoch 1, Batch 69/240, MSE = 0.003525
# Epoch 1, Batch 70/240, MSE = 0.003469
# Epoch 1, Batch 71/240, MSE = 0.003494
# Epoch 1, Batch 72/240, MSE = 0.003426
# Epoch 1, Batch 73/240, MSE = 0.003464
# Epoch 1, Batch 74/240, MSE = 0.003750
# Epoch 1, Batch 75/240, MSE = 0.003562
# Epoch 1, Batch 76/240, MSE = 0.003443
# Epoch 1, Batch 77/240, MSE = 0.003557
# Epoch 1, Batch 78/240, MSE = 0.003570
# Epoch 1, Batch 79/240, MSE = 0.003401
# Epoch 1, Batch 80/240, MSE = 0.003458
# Epoch 1, Batch 81/240, MSE = 0.003528
# Epoch 1, Batch 82/240, MSE = 0.003407
# Epoch 1, Batch 83/240, MSE = 0.003605
# Epoch 1, Batch 84/240, MSE = 0.003620
# Epoch 1, Batch 85/240, MSE = 0.003604
# Epoch 1, Batch 86/240, MSE = 0.003539
# Epoch 1, Batch 87/240, MSE = 0.003348
# Epoch 1, Batch 88/240, MSE = 0.003556
# Epoch 1, Batch 89/240, MSE = 0.003497
# Epoch 1, Batch 90/240, MSE = 0.003310
# Epoch 1, Batch 91/240, MSE = 0.003413
# Epoch 1, Batch 92/240, MSE = 0.003575
# Epoch 1, Batch 93/240, MSE = 0.003453
# Epoch 1, Batch 94/240, MSE = 0.003455
# Epoch 1, Batch 95/240, MSE = 0.003423
# Epoch 1, Batch 96/240, MSE = 0.003361
# Epoch 1, Batch 97/240, MSE = 0.003680
# Epoch 1, Batch 98/240, MSE = 0.003905
# Epoch 1, Batch 99/240, MSE = 0.003443
# Epoch 1, Batch 100/240, MSE = 0.003342
# Epoch 1, Batch 101/240, MSE = 0.003481
# Epoch 1, Batch 102/240, MSE = 0.003772
# Epoch 1, Batch 103/240, MSE = 0.003378
# Epoch 1, Batch 104/240, MSE = 0.003611
# Epoch 1, Batch 105/240, MSE = 0.003415
# Epoch 1, Batch 106/240, MSE = 0.003462
# Epoch 1, Batch 107/240, MSE = 0.003320
# Epoch 1, Batch 108/240, MSE = 0.003323
# Epoch 1, Batch 109/240, MSE = 0.003317
# Epoch 1, Batch 110/240, MSE = 0.003598
# Epoch 1, Batch 111/240, MSE = 0.003414
# Epoch 1, Batch 112/240, MSE = 0.003392
# Epoch 1, Batch 113/240, MSE = 0.003504
# Epoch 1, Batch 114/240, MSE = 0.003505
# Epoch 1, Batch 115/240, MSE = 0.003606
# Epoch 1, Batch 116/240, MSE = 0.003472
# Epoch 1, Batch 117/240, MSE = 0.003230
# Epoch 1, Batch 118/240, MSE = 0.003573
# Epoch 1, Batch 119/240, MSE = 0.003368
# Epoch 1, Batch 120/240, MSE = 0.003513
# Epoch 1, Batch 121/240, MSE = 0.003049
# Epoch 1, Batch 122/240, MSE = 0.003541
# Epoch 1, Batch 123/240, MSE = 0.003374
# Epoch 1, Batch 124/240, MSE = 0.003597
# Epoch 1, Batch 125/240, MSE = 0.003294
# Epoch 1, Batch 126/240, MSE = 0.003514
# Epoch 1, Batch 127/240, MSE = 0.003405
# Epoch 1, Batch 128/240, MSE = 0.003693
# Epoch 1, Batch 129/240, MSE = 0.003382
# Epoch 1, Batch 130/240, MSE = 0.003881
# Epoch 1, Batch 131/240, MSE = 0.003545
# Epoch 1, Batch 132/240, MSE = 0.003405
# Epoch 1, Batch 133/240, MSE = 0.003447
# Epoch 1, Batch 134/240, MSE = 0.003209
# Epoch 1, Batch 135/240, MSE = 0.003515
# Epoch 1, Batch 136/240, MSE = 0.003183
# Epoch 1, Batch 137/240, MSE = 0.003427
# Epoch 1, Batch 138/240, MSE = 0.003158
# Epoch 1, Batch 139/240, MSE = 0.003444
# Epoch 1, Batch 140/240, MSE = 0.003430
# Epoch 1, Batch 141/240, MSE = 0.003477
# Epoch 1, Batch 142/240, MSE = 0.003278
# Epoch 1, Batch 143/240, MSE = 0.003137
# Epoch 1, Batch 144/240, MSE = 0.003589
# Epoch 1, Batch 145/240, MSE = 0.003441
# Epoch 1, Batch 146/240, MSE = 0.003590
# Epoch 1, Batch 147/240, MSE = 0.003699
# Epoch 1, Batch 148/240, MSE = 0.003314
# Epoch 1, Batch 149/240, MSE = 0.003108
# Epoch 1, Batch 150/240, MSE = 0.003288
# Epoch 1, Batch 151/240, MSE = 0.003116
# Epoch 1, Batch 152/240, MSE = 0.003518
# Epoch 1, Batch 153/240, MSE = 0.003271
# Epoch 1, Batch 154/240, MSE = 0.003653
# Epoch 1, Batch 155/240, MSE = 0.003630
# Epoch 1, Batch 156/240, MSE = 0.003270
# Epoch 1, Batch 157/240, MSE = 0.003212
# Epoch 1, Batch 158/240, MSE = 0.003442
# Epoch 1, Batch 159/240, MSE = 0.003262
# Epoch 1, Batch 160/240, MSE = 0.003642
# Epoch 1, Batch 161/240, MSE = 0.003400
# Epoch 1, Batch 162/240, MSE = 0.003306
# Epoch 1, Batch 163/240, MSE = 0.003312
# Epoch 1, Batch 164/240, MSE = 0.003361
# Epoch 1, Batch 165/240, MSE = 0.003424
# Epoch 1, Batch 166/240, MSE = 0.003728
# Epoch 1, Batch 167/240, MSE = 0.003378
# Epoch 1, Batch 168/240, MSE = 0.003202
# Epoch 1, Batch 169/240, MSE = 0.003588
# Epoch 1, Batch 170/240, MSE = 0.003254
# Epoch 1, Batch 171/240, MSE = 0.003333
# Epoch 1, Batch 172/240, MSE = 0.003292
# Epoch 1, Batch 173/240, MSE = 0.003078
# Epoch 1, Batch 174/240, MSE = 0.003265
# Epoch 1, Batch 175/240, MSE = 0.003438
# Epoch 1, Batch 176/240, MSE = 0.003466
# Epoch 1, Batch 177/240, MSE = 0.003474
# Epoch 1, Batch 178/240, MSE = 0.003601
# Epoch 1, Batch 179/240, MSE = 0.003076
# Epoch 1, Batch 180/240, MSE = 0.003260
# Epoch 1, Batch 181/240, MSE = 0.003234
# Epoch 1, Batch 182/240, MSE = 0.003232
# Epoch 1, Batch 183/240, MSE = 0.003506
# Epoch 1, Batch 184/240, MSE = 0.003284
# Epoch 1, Batch 185/240, MSE = 0.003573
# Epoch 1, Batch 186/240, MSE = 0.002920
# Epoch 1, Batch 187/240, MSE = 0.003105
# Epoch 1, Batch 188/240, MSE = 0.003397
# Epoch 1, Batch 189/240, MSE = 0.003451
# Epoch 1, Batch 190/240, MSE = 0.003596
# Epoch 1, Batch 191/240, MSE = 0.003212
# Epoch 1, Batch 192/240, MSE = 0.003305
# Epoch 1, Batch 193/240, MSE = 0.003157
# Epoch 1, Batch 194/240, MSE = 0.003391
# Epoch 1, Batch 195/240, MSE = 0.003354
# Epoch 1, Batch 196/240, MSE = 0.003090
# Epoch 1, Batch 197/240, MSE = 0.003289
# Epoch 1, Batch 198/240, MSE = 0.003161
# Epoch 1, Batch 199/240, MSE = 0.003407
# Epoch 1, Batch 200/240, MSE = 0.003524
# Epoch 1, Batch 201/240, MSE = 0.003389
# Epoch 1, Batch 202/240, MSE = 0.003065
# Epoch 1, Batch 203/240, MSE = 0.003465
# Epoch 1, Batch 204/240, MSE = 0.003178
# Epoch 1, Batch 205/240, MSE = 0.003507
# Epoch 1, Batch 206/240, MSE = 0.003014
# Epoch 1, Batch 207/240, MSE = 0.003384
# Epoch 1, Batch 208/240, MSE = 0.003346
# Epoch 1, Batch 209/240, MSE = 0.003259
# Epoch 1, Batch 210/240, MSE = 0.003454
# Epoch 1, Batch 211/240, MSE = 0.003243
# Epoch 1, Batch 212/240, MSE = 0.003155
# Epoch 1, Batch 213/240, MSE = 0.003174
# Epoch 1, Batch 214/240, MSE = 0.003168
# Epoch 1, Batch 215/240, MSE = 0.003368
# Epoch 1, Batch 216/240, MSE = 0.003471
# Epoch 1, Batch 217/240, MSE = 0.003154
# Epoch 1, Batch 218/240, MSE = 0.003252
# Epoch 1, Batch 219/240, MSE = 0.003335
# Epoch 1, Batch 220/240, MSE = 0.003060
# Epoch 1, Batch 221/240, MSE = 0.003183
# Epoch 1, Batch 222/240, MSE = 0.003556
# Epoch 1, Batch 223/240, MSE = 0.003395
# Epoch 1, Batch 224/240, MSE = 0.003314
# Epoch 1, Batch 225/240, MSE = 0.003135
# Epoch 1, Batch 226/240, MSE = 0.003330
# Epoch 1, Batch 227/240, MSE = 0.003400
# Epoch 1, Batch 228/240, MSE = 0.002909
# Epoch 1, Batch 229/240, MSE = 0.003317
# Epoch 1, Batch 230/240, MSE = 0.003082
# Epoch 1, Batch 231/240, MSE = 0.003508
# Epoch 1, Batch 232/240, MSE = 0.003261
# Epoch 1, Batch 233/240, MSE = 0.003102
# Epoch 1, Batch 234/240, MSE = 0.003140
# Epoch 1, Batch 235/240, MSE = 0.003010
# Epoch 1, Batch 236/240, MSE = 0.003090
# Epoch 1, Batch 237/240, MSE = 0.003050
# Epoch 1, Batch 238/240, MSE = 0.003362
# Epoch 1, Batch 239/240, MSE = 0.003038
# Epoch 1, Batch 240/240, MSE = 0.003437
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -10    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# 8. 길이 맞추기
target_len = len(clean_iq)
if len(iq_reconstructed) != target_len:
    iq_reconstructed = resample(iq_reconstructed, target_len)

print(f"✅ IQ signal resampled: {iq_reconstructed.shape}")

# 🔧 길이 보정: Resample (Zero-padding 대신!)
from scipy.signal import resample
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (2048)
if len(iq_reconstructed) != target_len:
    original_len = len(iq_reconstructed)
    iq_reconstructed = resample(iq_reconstructed, target_len)
    print(f"   🔧 Resampled: {original_len} → {target_len} samples (Sinc interpolation)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")

print(f"   Energy before scaling: |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

# 8. 에너지 정규화 (Energy Normalization) ⭐
# iSTFT 후 신호 에너지가 손실되므로, 원본 noisy IQ의 에너지에 맞춰 복원
energy_noisy = np.sqrt(np.mean(np.abs(noisy_iq)**2))
energy_reconstructed = np.sqrt(np.mean(np.abs(iq_reconstructed)**2))

if energy_reconstructed > 1e-10:  # 0으로 나누기 방지
    scale_factor = energy_noisy / energy_reconstructed
    iq_reconstructed = iq_reconstructed * scale_factor
    print(f"   Energy scaling: {energy_noisy:.6f} / {energy_reconstructed:.6f} = {scale_factor:.2f}x")
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")
else:
    print(f"   ⚠️  Warning: Reconstructed signal energy too low, no scaling applied")

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -10 dB
#
# === Normalization Parameters ===
# Real: min=-1.070449, max=1.105765, range=2.176214
# Imag: min=-1.170616, max=1.105214, range=2.275831
# Restored norm: real_min=0.0968, real_max=0.9447
# Restored norm: imag_min=0.0761, imag_max=0.9708
# After denorm:  real_min=-0.859749, real_max=0.985487
# After denorm:  imag_min=-0.997403, imag_max=1.038831
# ✅ IQ signal reconstructed: (2048,)
# ✅ IQ signal resampled: (2048,)
#    ✅ Length already matches: 2048 samples
#    Energy before scaling: |mean|=1.655828, |max|=250.521709
#    Energy scaling: 3.306670 / 7.480073 = 0.44x
#    Energy after scaling:  |mean|=0.731982, |max|=110.746578
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.5032
# Restored flat: min=0.0761, max=0.9708, mean=0.5033
# Difference:    MSE=0.002942
# /tmp/ipykernel_36679/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0000, max=0.0138
# Zxx_restored (magnitude): min=0.0097, max=1.2357
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, "clean", sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, "noisy", sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, "restored", sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3 successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3 failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=2.9359, |max|=9.0538
# Reconstructed:   len=2048, |mean|=0.7320, |max|=110.7466
#
# MSE Comparison:
# Clean vs Noisy:        9.890895
# Clean vs Reconstructed: 11.070269
# Noisy vs Reconstructed: 19.442602
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 1880.00
# ⚠️  Noisy signal (len=2048)    → Code: 42, Peak: 1966.29
# 🔧 Restored (len=2048)   → Code: 42, Peak: 706.68
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       42 ✅ CORRECT
# Restored Decoded:    42 ✅ CORRECT
# ============================================================
#
# Peak Comparison:
# Clean Peak:    1880.00
# Noisy Peak:    1966.29 (104.6% of clean)
# Restored Peak: 706.68 (37.6% of clean)
#
# ✅ SUCCESS: BAMv3 successfully restored the correct symbol!

# %%
########################################
##  8. 정량적 성능 평가 (다중 샘플)  ##
########################################

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION")
print("="*70)

# 테스트 파라미터
NUM_TEST_SAMPLES = 100  # 테스트할 샘플 수
TEST_SNR_LEVELS = [-25, -20, -15, -10, -5]  # 다양한 SNR 레벨

results = {snr: {'correct': 0, 'total': 0, 'mse': [], 'peak_ratio': []} for snr in TEST_SNR_LEVELS}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        # 랜덤 심볼 선택
        test_sym = np.random.randint(0, 512)
        
        # 1. 클린 IQ
        clean_iq_test = X_clean_iq[test_sym]
        
        # 2. 노이즈 추가
        noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
        
        # 3. Complex 스펙트로그램 생성
        noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
        
        # 4. BAMv3 복원 (compress -> decompress)
        compressed = model.compress(noisy_flat.reshape(1, -1))
        restored_flat = model.decompress(compressed).flatten()
        
        # 5. 역변환
        mid = len(restored_flat) // 2
        real_restored_norm = restored_flat[:mid].reshape(noisy_params['shape'])
        imag_restored_norm = restored_flat[mid:].reshape(noisy_params['shape'])
        
        # 역정규화
        real_restored = real_restored_norm * (noisy_params['r_max'] - noisy_params['r_min']) + noisy_params['r_min']
        imag_restored = imag_restored_norm * (noisy_params['i_max'] - noisy_params['i_min']) + noisy_params['i_min']
        
        # Complex 재결합
        Zxx_restored = real_restored + 1j * imag_restored
        
        # 6. 역 STFT
        # ⭐ Step 1: Zero-padding으로 원래 주파수 크기 복원
        Zxx_full = np.zeros(noisy_params['original_shape'], dtype=complex)
        Zxx_full[noisy_params['freq_indices'], :] = Zxx_restored

        # ⭐ Step 2: 주파수 축 언시프트
        # IQ 신호 복원
        iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)
        
        target_len = len(clean_iq_test)
        if len(iq_restored) != target_len:
            iq_restored = resample(iq_restored, target_len)
        
        # 7. Dechirp
        try:
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, "clean", sf, fs, bw)
            code_restored, peak_restored = estimate_symbol_custom(iq_restored, "restored", sf, fs, bw)
            
            # 정확도 체크
            if code_restored == test_sym:
                results[snr]['correct'] += 1
            results[snr]['total'] += 1
            
            # Peak ratio
            if peak_clean > 0:
                results[snr]['peak_ratio'].append(peak_restored / peak_clean)
            
            # MSE 계산
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['total'] += 1
    
    # 중간 결과 출력
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"  ✓ Accuracy: {results[snr]['correct']}/{results[snr]['total']} = {acc:.1f}%")
    print(f"  ✓ Avg MSE: {avg_mse:.6f}")
    print(f"  ✓ Avg Peak Ratio: {avg_peak:.2%}")

# 최종 결과 요약
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)

print(f"\n{'SNR (dB)':<10} {'Accuracy':<15} {'MSE':<15} {'Peak Ratio':<15}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"{snr:<10} {acc:>6.1f}%{'':<8} {avg_mse:>8.6f}{'':<6} {avg_peak:>6.1%}{'':<8}")

# 전체 평균
total_correct = sum(r['correct'] for r in results.values())
total_samples = sum(r['total'] for r in results.values())
overall_acc = total_correct / total_samples * 100

print("─"*70)
print(f"{'Overall':<10} {overall_acc:>6.1f}%")
print("="*70)

# 시각화
plt.figure(figsize=(15, 4))

# 1. Accuracy vs SNR
plt.subplot(1, 3, 1)
snrs = TEST_SNR_LEVELS
accs = [results[snr]['correct'] / results[snr]['total'] * 100 for snr in snrs]
plt.plot(snrs, accs, 'o-', linewidth=2, markersize=8)
plt.xlabel('SNR (dB)')
plt.ylabel('Accuracy (%)')
plt.title('Symbol Classification Accuracy')
plt.grid(True, alpha=0.3)
plt.ylim([0, 105])

# 2. MSE vs SNR
plt.subplot(1, 3, 2)
mses = [np.mean(results[snr]['mse']) for snr in snrs]
plt.plot(snrs, mses, 's-', linewidth=2, markersize=8, color='orange')
plt.xlabel('SNR (dB)')
plt.ylabel('MSE')
plt.title('Reconstruction MSE')
plt.grid(True, alpha=0.3)
plt.yscale('log')

# 3. Peak Ratio vs SNR
plt.subplot(1, 3, 3)
peaks = [np.mean(results[snr]['peak_ratio']) * 100 for snr in snrs]
plt.plot(snrs, peaks, '^-', linewidth=2, markersize=8, color='green')
plt.xlabel('SNR (dB)')
plt.ylabel('Peak Ratio (%)')
plt.title('Peak Recovery Ratio')
plt.grid(True, alpha=0.3)
plt.axhline(y=100, color='r', linestyle='--', alpha=0.5, label='Perfect (100%)')
plt.legend()

plt.tight_layout()
plt.show()

print(f"\n✅ Quantitative evaluation complete!")
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION
# ======================================================================
#
# 🧪 Testing with 100 samples at each SNR level...
# SNR levels: [-25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_36679/4087263723.py:100: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Accuracy: 9/100 = 9.0%
#   ✓ Avg MSE: 450.589727
#   ✓ Avg Peak Ratio: 1549.79%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 30/100 = 30.0%
#   ✓ Avg MSE: 167.359858
#   ✓ Avg Peak Ratio: 483.29%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 57/100 = 57.0%
#   ✓ Avg MSE: 54.600584
#   ✓ Avg Peak Ratio: 515.88%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 61/100 = 61.0%
#   ✓ Avg MSE: 26.088049
#   ✓ Avg Peak Ratio: 321.11%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 77/100 = 77.0%
#   ✓ Avg MSE: 11.946315
#   ✓ Avg Peak Ratio: 99.80%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR (dB)   Accuracy        MSE             Peak Ratio
# ──────────────────────────────────────────────────────────────────────
# -25           9.0%         450.589727       1549.8%
# -20          30.0%         167.359858       483.3%
# -15          57.0%         54.600584       515.9%
# -10          61.0%         26.088049       321.1%
# -5           77.0%         11.946315        99.8%
# ──────────────────────────────────────────────────────────────────────
# Overall      46.8%
# ======================================================================
# ✅ Quantitative evaluation complete!
