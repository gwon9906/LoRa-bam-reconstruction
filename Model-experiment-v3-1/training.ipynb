# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import spectrogram, istft
from scipy.signal import resample

# ⭐ STFT 파라미터를 전역 상수로 정의 (일관성 보장!)
STFT_PARAMS = {
    'nperseg': 192,
    'noverlap': 144,
    'nfft': 512,
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    """
    복소 IQ 신호로부터 Complex 스펙트로그램 생성 (Phase 정보 보존)
    
    주요 개선사항:
    - STFT 파라미터를 전역 상수로 관리
    - 원본 shape 및 주파수 인덱스 저장
    - ISTFT 복원에 필요한 모든 정보 포함
    """
    # Complex 스펙트로그램 계산
    f, t, Zxx = spectrogram(
        iq_signal, 
        fs=fs, 
        window=STFT_PARAMS['window'],
        nperseg=STFT_PARAMS['nperseg'], 
        noverlap=STFT_PARAMS['noverlap'],
        nfft=STFT_PARAMS['nfft'], 
        mode='complex',
        return_onesided=False
    )
    
    # 주파수 축 시프트 (DC를 중앙으로)
    f_shifted = np.fft.fftshift(f)
    Zxx_shifted = np.fft.fftshift(Zxx, axes=0)
    
    # ⭐ 원본 shape 저장 (ISTFT 복원에 필수!)
    original_shape = Zxx_shifted.shape
    
    # 대역폭만큼 크롭
    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]  # ⭐ 크롭된 주파수 인덱스 저장
    Zxx_cropped = Zxx_shifted[mask, :]
    
    # Real/Imag 분리
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag
    
    # 개별 정규화 (0-1 범위)
    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()
    
    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)
    
    # Real/Imag 통합 (Flatten)
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])
    
    # ⭐ 역변환을 위한 모든 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'cropped_shape': Zxx_cropped.shape,
        'original_shape': original_shape,      # 추가: 원본 크기
        'freq_indices': freq_indices,          # 추가: 주파수 인덱스
        'stft_params': STFT_PARAMS.copy()     # 추가: STFT 파라미터
    }
    
    return combined_flat, norm_params


def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    복원된 스펙트로그램으로부터 IQ 신호 재구성
    
    주요 개선사항:
    - Zero-padding으로 원래 주파수 크기 복원
    - STFT와 동일한 파라미터로 ISTFT 수행
    - 정확한 주파수 배치
    """
    # 1. Real/Imag 분리 및 reshape
    mid = len(restored_flat) // 2
    real_restored_norm = restored_flat[:mid].reshape(norm_params['cropped_shape'])
    imag_restored_norm = restored_flat[mid:].reshape(norm_params['cropped_shape'])
    
    # 2. 역정규화
    real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
    imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']
    
    # 3. Complex 재결합
    Zxx_cropped = real_restored + 1j * imag_restored
    
    # 4. ⭐ Zero-padding으로 원래 주파수 크기 복원 (중요!)
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped
    
    # 5. 주파수 축 언시프트 (ISTFT를 위해)
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)
    
    # 6. ⭐ STFT와 동일한 파라미터로 ISTFT 수행 (핵심!)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted, 
        fs=fs, 
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],     # ✅ STFT와 동일
        noverlap=stft_params['noverlap'],   # ✅ STFT와 동일
        nfft=stft_params['nfft'],           # ✅ STFT와 동일
        input_onesided=False
    )
    
    return iq_restored


print("✅ 수정된 Complex 스펙트로그램 함수 정의 완료 (Phase 보존 + 올바른 ISTFT)")
print(f"\n파라미터 설정:")
for key, val in STFT_PARAMS.items():
    print(f"  {key}: {val}")
# Out:
# ✅ Complex 스펙트로그램 함수가 정의되었습니다 (Phase 보존)

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf, bw)
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (Ultra-low SNR에 집중)
SNR_MIN = -25
SNR_MAX = -5
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)
            
            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 4096, 2048, 1024]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (128, 31)
# Input dim (Real+Imag): 7936
# Model architecture: 7936 → 4096 → 2048 → 1024
# Compression ratio: 7.8x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True  # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 20
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 7936 → 4096 → 2048 → 1024
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.029589
# Epoch 1, Batch 2/240, MSE = 0.023422
# Epoch 1, Batch 3/240, MSE = 0.024870
# Epoch 1, Batch 4/240, MSE = 0.024688
# Epoch 1, Batch 5/240, MSE = 0.024315
# Epoch 1, Batch 6/240, MSE = 0.022236
# Epoch 1, Batch 7/240, MSE = 0.023865
# Epoch 1, Batch 8/240, MSE = 0.023546
# Epoch 1, Batch 9/240, MSE = 0.024909
# Epoch 1, Batch 10/240, MSE = 0.023090
# Epoch 1, Batch 11/240, MSE = 0.022299
# Epoch 1, Batch 12/240, MSE = 0.023427
# Epoch 1, Batch 13/240, MSE = 0.022447
# Epoch 1, Batch 14/240, MSE = 0.022058
# Epoch 1, Batch 15/240, MSE = 0.021237
# Epoch 1, Batch 16/240, MSE = 0.022554
# Epoch 1, Batch 17/240, MSE = 0.022494
# Epoch 1, Batch 18/240, MSE = 0.021470
# Epoch 1, Batch 19/240, MSE = 0.021052
# Epoch 1, Batch 20/240, MSE = 0.023945
# Epoch 1, Batch 21/240, MSE = 0.022179
# Epoch 1, Batch 22/240, MSE = 0.022771
# Epoch 1, Batch 23/240, MSE = 0.021635
# Epoch 1, Batch 24/240, MSE = 0.022053
# Epoch 1, Batch 25/240, MSE = 0.021031
# Epoch 1, Batch 26/240, MSE = 0.022014
# Epoch 1, Batch 27/240, MSE = 0.022014
# Epoch 1, Batch 28/240, MSE = 0.024098
# Epoch 1, Batch 29/240, MSE = 0.022446
# Epoch 1, Batch 30/240, MSE = 0.021286
# Epoch 1, Batch 31/240, MSE = 0.020633
# Epoch 1, Batch 32/240, MSE = 0.022274
# Epoch 1, Batch 33/240, MSE = 0.021984
# Epoch 1, Batch 34/240, MSE = 0.021635
# Epoch 1, Batch 35/240, MSE = 0.019767
# Epoch 1, Batch 36/240, MSE = 0.020003
# Epoch 1, Batch 37/240, MSE = 0.021720
# Epoch 1, Batch 38/240, MSE = 0.021067
# Epoch 1, Batch 39/240, MSE = 0.021542
# Epoch 1, Batch 40/240, MSE = 0.019891
# Epoch 1, Batch 41/240, MSE = 0.020291
# Epoch 1, Batch 42/240, MSE = 0.020820
# Epoch 1, Batch 43/240, MSE = 0.022497
# Epoch 1, Batch 44/240, MSE = 0.021840
# Epoch 1, Batch 45/240, MSE = 0.020489
# Epoch 1, Batch 46/240, MSE = 0.021991
# Epoch 1, Batch 47/240, MSE = 0.020195
# Epoch 1, Batch 48/240, MSE = 0.021661
# Epoch 1, Batch 49/240, MSE = 0.021947
# Epoch 1, Batch 50/240, MSE = 0.020399
# Epoch 1, Batch 51/240, MSE = 0.020453
# Epoch 1, Batch 52/240, MSE = 0.020951
# Epoch 1, Batch 53/240, MSE = 0.020123
# Epoch 1, Batch 54/240, MSE = 0.020811
# Epoch 1, Batch 55/240, MSE = 0.019783
# Epoch 1, Batch 56/240, MSE = 0.018766
# Epoch 1, Batch 57/240, MSE = 0.019713
# Epoch 1, Batch 58/240, MSE = 0.020513
# Epoch 1, Batch 59/240, MSE = 0.020104
# Epoch 1, Batch 60/240, MSE = 0.019571
# Epoch 1, Batch 61/240, MSE = 0.020936
# Epoch 1, Batch 62/240, MSE = 0.021349
# Epoch 1, Batch 63/240, MSE = 0.021222
# Epoch 1, Batch 64/240, MSE = 0.019115
# Epoch 1, Batch 65/240, MSE = 0.020754
# Epoch 1, Batch 66/240, MSE = 0.019545
# Epoch 1, Batch 67/240, MSE = 0.019926
# Epoch 1, Batch 68/240, MSE = 0.020658
# Epoch 1, Batch 69/240, MSE = 0.019682
# Epoch 1, Batch 70/240, MSE = 0.020860
# Epoch 1, Batch 71/240, MSE = 0.020186
# Epoch 1, Batch 72/240, MSE = 0.021086
# Epoch 1, Batch 73/240, MSE = 0.020109
# Epoch 1, Batch 74/240, MSE = 0.018138
# Epoch 1, Batch 75/240, MSE = 0.019729
# Epoch 1, Batch 76/240, MSE = 0.019078
# Epoch 1, Batch 77/240, MSE = 0.019188
# Epoch 1, Batch 78/240, MSE = 0.019471
# Epoch 1, Batch 79/240, MSE = 0.018903
# Epoch 1, Batch 80/240, MSE = 0.018679
# Epoch 1, Batch 81/240, MSE = 0.018316
# Epoch 1, Batch 82/240, MSE = 0.019325
# Epoch 1, Batch 83/240, MSE = 0.019634
# Epoch 1, Batch 84/240, MSE = 0.019125
# Epoch 1, Batch 85/240, MSE = 0.019302
# Epoch 1, Batch 86/240, MSE = 0.018176
# Epoch 1, Batch 87/240, MSE = 0.018073
# Epoch 1, Batch 88/240, MSE = 0.018775
# Epoch 1, Batch 89/240, MSE = 0.019109
# Epoch 1, Batch 90/240, MSE = 0.018505
# Epoch 1, Batch 91/240, MSE = 0.018880
# Epoch 1, Batch 92/240, MSE = 0.018442
# Epoch 1, Batch 93/240, MSE = 0.017834
# Epoch 1, Batch 94/240, MSE = 0.018615
# Epoch 1, Batch 95/240, MSE = 0.018292
# Epoch 1, Batch 96/240, MSE = 0.017180
# Epoch 1, Batch 97/240, MSE = 0.019184
# Epoch 1, Batch 98/240, MSE = 0.018181
# Epoch 1, Batch 99/240, MSE = 0.018524
# Epoch 1, Batch 100/240, MSE = 0.017958
# Epoch 1, Batch 101/240, MSE = 0.018203
# Epoch 1, Batch 102/240, MSE = 0.017405
# Epoch 1, Batch 103/240, MSE = 0.018740
# Epoch 1, Batch 104/240, MSE = 0.017288
# Epoch 1, Batch 105/240, MSE = 0.018559
# Epoch 1, Batch 106/240, MSE = 0.018111
# Epoch 1, Batch 107/240, MSE = 0.018119
# Epoch 1, Batch 108/240, MSE = 0.017741
# Epoch 1, Batch 109/240, MSE = 0.017823
# Epoch 1, Batch 110/240, MSE = 0.018179
# Epoch 1, Batch 111/240, MSE = 0.017804
# Epoch 1, Batch 112/240, MSE = 0.016253
# Epoch 1, Batch 113/240, MSE = 0.016825
# Epoch 1, Batch 114/240, MSE = 0.018106
# Epoch 1, Batch 115/240, MSE = 0.017203
# Epoch 1, Batch 116/240, MSE = 0.018186
# Epoch 1, Batch 117/240, MSE = 0.017172
# Epoch 1, Batch 118/240, MSE = 0.017002
# Epoch 1, Batch 119/240, MSE = 0.017476
# Epoch 1, Batch 120/240, MSE = 0.017404
# Epoch 1, Batch 121/240, MSE = 0.015572
# Epoch 1, Batch 122/240, MSE = 0.015168
# Epoch 1, Batch 123/240, MSE = 0.017569
# Epoch 1, Batch 124/240, MSE = 0.018176
# Epoch 1, Batch 125/240, MSE = 0.016799
# Epoch 1, Batch 126/240, MSE = 0.016380
# Epoch 1, Batch 127/240, MSE = 0.017401
# Epoch 1, Batch 128/240, MSE = 0.016833
# Epoch 1, Batch 129/240, MSE = 0.017415
# Epoch 1, Batch 130/240, MSE = 0.015887
# Epoch 1, Batch 131/240, MSE = 0.017250
# Epoch 1, Batch 132/240, MSE = 0.016228
# Epoch 1, Batch 133/240, MSE = 0.016105
# Epoch 1, Batch 134/240, MSE = 0.016715
# Epoch 1, Batch 135/240, MSE = 0.016049
# Epoch 1, Batch 136/240, MSE = 0.016510
# Epoch 1, Batch 137/240, MSE = 0.015443
# Epoch 1, Batch 138/240, MSE = 0.015237
# Epoch 1, Batch 139/240, MSE = 0.015343
# Epoch 1, Batch 140/240, MSE = 0.015355
# Epoch 1, Batch 141/240, MSE = 0.015604
# Epoch 1, Batch 142/240, MSE = 0.016415
# Epoch 1, Batch 143/240, MSE = 0.015708
# Epoch 1, Batch 144/240, MSE = 0.015002
# Epoch 1, Batch 145/240, MSE = 0.015185
# Epoch 1, Batch 146/240, MSE = 0.014895
# Epoch 1, Batch 147/240, MSE = 0.016017
# Epoch 1, Batch 148/240, MSE = 0.015693
# Epoch 1, Batch 149/240, MSE = 0.015778
# Epoch 1, Batch 150/240, MSE = 0.013915
# Epoch 1, Batch 151/240, MSE = 0.014792
# Epoch 1, Batch 152/240, MSE = 0.015141
# Epoch 1, Batch 153/240, MSE = 0.015096
# Epoch 1, Batch 154/240, MSE = 0.015147
# Epoch 1, Batch 155/240, MSE = 0.013971
# Epoch 1, Batch 156/240, MSE = 0.014534
# Epoch 1, Batch 157/240, MSE = 0.014307
# Epoch 1, Batch 158/240, MSE = 0.014222
# Epoch 1, Batch 159/240, MSE = 0.015430
# Epoch 1, Batch 160/240, MSE = 0.013801
# Epoch 1, Batch 161/240, MSE = 0.014707
# Epoch 1, Batch 162/240, MSE = 0.013677
# Epoch 1, Batch 163/240, MSE = 0.014229
# Epoch 1, Batch 164/240, MSE = 0.014574
# Epoch 1, Batch 165/240, MSE = 0.014716
# Epoch 1, Batch 166/240, MSE = 0.013949
# Epoch 1, Batch 167/240, MSE = 0.014101
# Epoch 1, Batch 168/240, MSE = 0.013412
# Epoch 1, Batch 169/240, MSE = 0.013476
# Epoch 1, Batch 170/240, MSE = 0.014118
# Epoch 1, Batch 171/240, MSE = 0.014554
# Epoch 1, Batch 172/240, MSE = 0.013016
# Epoch 1, Batch 173/240, MSE = 0.012772
# Epoch 1, Batch 174/240, MSE = 0.012893
# Epoch 1, Batch 175/240, MSE = 0.013088
# Epoch 1, Batch 176/240, MSE = 0.014172
# Epoch 1, Batch 177/240, MSE = 0.013295
# Epoch 1, Batch 178/240, MSE = 0.014464
# Epoch 1, Batch 179/240, MSE = 0.013440
# Epoch 1, Batch 180/240, MSE = 0.013551
# Epoch 1, Batch 181/240, MSE = 0.013498
# Epoch 1, Batch 182/240, MSE = 0.014550
# Epoch 1, Batch 183/240, MSE = 0.011829
# Epoch 1, Batch 184/240, MSE = 0.013429
# Epoch 1, Batch 185/240, MSE = 0.013095
# Epoch 1, Batch 186/240, MSE = 0.012772
# Epoch 1, Batch 187/240, MSE = 0.013936
# Epoch 1, Batch 188/240, MSE = 0.013518
# Epoch 1, Batch 189/240, MSE = 0.012856
# Epoch 1, Batch 190/240, MSE = 0.014300
# Epoch 1, Batch 191/240, MSE = 0.012225
# Epoch 1, Batch 192/240, MSE = 0.012602
# Epoch 1, Batch 193/240, MSE = 0.012345
# Epoch 1, Batch 194/240, MSE = 0.011938
# Epoch 1, Batch 195/240, MSE = 0.012923
# Epoch 1, Batch 196/240, MSE = 0.012235
# Epoch 1, Batch 197/240, MSE = 0.013142
# Epoch 1, Batch 198/240, MSE = 0.011653
# Epoch 1, Batch 199/240, MSE = 0.012204
# Epoch 1, Batch 200/240, MSE = 0.012338
# Epoch 1, Batch 201/240, MSE = 0.012622
# Epoch 1, Batch 202/240, MSE = 0.012331
# Epoch 1, Batch 203/240, MSE = 0.013122
# Epoch 1, Batch 204/240, MSE = 0.012610
# Epoch 1, Batch 205/240, MSE = 0.011760
# Epoch 1, Batch 206/240, MSE = 0.011687
# Epoch 1, Batch 207/240, MSE = 0.011702
# Epoch 1, Batch 208/240, MSE = 0.011693
# Epoch 1, Batch 209/240, MSE = 0.011441
# Epoch 1, Batch 210/240, MSE = 0.011218
# Epoch 1, Batch 211/240, MSE = 0.011326
# Epoch 1, Batch 212/240, MSE = 0.011907
# Epoch 1, Batch 213/240, MSE = 0.010075
# Epoch 1, Batch 214/240, MSE = 0.010363
# Epoch 1, Batch 215/240, MSE = 0.011938
# Epoch 1, Batch 216/240, MSE = 0.011871
# Epoch 1, Batch 217/240, MSE = 0.012424
# Epoch 1, Batch 218/240, MSE = 0.012156
# Epoch 1, Batch 219/240, MSE = 0.011252
# Epoch 1, Batch 220/240, MSE = 0.011068
# Epoch 1, Batch 221/240, MSE = 0.010961
# Epoch 1, Batch 222/240, MSE = 0.010978
# Epoch 1, Batch 223/240, MSE = 0.011808
# Epoch 1, Batch 224/240, MSE = 0.010994
# Epoch 1, Batch 225/240, MSE = 0.011329
# Epoch 1, Batch 226/240, MSE = 0.011239
# Epoch 1, Batch 227/240, MSE = 0.010834
# Epoch 1, Batch 228/240, MSE = 0.011296
# Epoch 1, Batch 229/240, MSE = 0.011112
# Epoch 1, Batch 230/240, MSE = 0.010817
# Epoch 1, Batch 231/240, MSE = 0.010590
# Epoch 1, Batch 232/240, MSE = 0.010174
# Epoch 1, Batch 233/240, MSE = 0.010128
# Epoch 1, Batch 234/240, MSE = 0.010913
# Epoch 1, Batch 235/240, MSE = 0.010680
# Epoch 1, Batch 236/240, MSE = 0.009338
# Epoch 1, Batch 237/240, MSE = 0.010449
# Epoch 1, Batch 238/240, MSE = 0.010906
# Epoch 1, Batch 239/240, MSE = 0.010063
# Epoch 1, Batch 240/240, MSE = 0.010883
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.038978
# Epoch 1, Batch 2/240, MSE = 0.029721
# Epoch 1, Batch 3/240, MSE = 0.029039
# Epoch 1, Batch 4/240, MSE = 0.028221
# Epoch 1, Batch 5/240, MSE = 0.028254
# Epoch 1, Batch 6/240, MSE = 0.029275
# Epoch 1, Batch 7/240, MSE = 0.027422
# Epoch 1, Batch 8/240, MSE = 0.026089
# Epoch 1, Batch 9/240, MSE = 0.029399
# Epoch 1, Batch 10/240, MSE = 0.026712
# Epoch 1, Batch 11/240, MSE = 0.026541
# Epoch 1, Batch 12/240, MSE = 0.029327
# Epoch 1, Batch 13/240, MSE = 0.029719
# Epoch 1, Batch 14/240, MSE = 0.026763
# Epoch 1, Batch 15/240, MSE = 0.026381
# Epoch 1, Batch 16/240, MSE = 0.026576
# Epoch 1, Batch 17/240, MSE = 0.025231
# Epoch 1, Batch 18/240, MSE = 0.026107
# Epoch 1, Batch 19/240, MSE = 0.026218
# Epoch 1, Batch 20/240, MSE = 0.026372
# Epoch 1, Batch 21/240, MSE = 0.027235
# Epoch 1, Batch 22/240, MSE = 0.026745
# Epoch 1, Batch 23/240, MSE = 0.026022
# Epoch 1, Batch 24/240, MSE = 0.025840
# Epoch 1, Batch 25/240, MSE = 0.025999
# Epoch 1, Batch 26/240, MSE = 0.026868
# Epoch 1, Batch 27/240, MSE = 0.027732
# Epoch 1, Batch 28/240, MSE = 0.025347
# Epoch 1, Batch 29/240, MSE = 0.027986
# Epoch 1, Batch 30/240, MSE = 0.025410
# Epoch 1, Batch 31/240, MSE = 0.027134
# Epoch 1, Batch 32/240, MSE = 0.026177
# Epoch 1, Batch 33/240, MSE = 0.026042
# Epoch 1, Batch 34/240, MSE = 0.026369
# Epoch 1, Batch 35/240, MSE = 0.025841
# Epoch 1, Batch 36/240, MSE = 0.025977
# Epoch 1, Batch 37/240, MSE = 0.027751
# Epoch 1, Batch 38/240, MSE = 0.024870
# Epoch 1, Batch 39/240, MSE = 0.025844
# Epoch 1, Batch 40/240, MSE = 0.026136
# Epoch 1, Batch 41/240, MSE = 0.026624
# Epoch 1, Batch 42/240, MSE = 0.026945
# Epoch 1, Batch 43/240, MSE = 0.025983
# Epoch 1, Batch 44/240, MSE = 0.025308
# Epoch 1, Batch 45/240, MSE = 0.023934
# Epoch 1, Batch 46/240, MSE = 0.027378
# Epoch 1, Batch 47/240, MSE = 0.026339
# Epoch 1, Batch 48/240, MSE = 0.027664
# Epoch 1, Batch 49/240, MSE = 0.025306
# Epoch 1, Batch 50/240, MSE = 0.025861
# Epoch 1, Batch 51/240, MSE = 0.026669
# Epoch 1, Batch 52/240, MSE = 0.025383
# Epoch 1, Batch 53/240, MSE = 0.024547
# Epoch 1, Batch 54/240, MSE = 0.025933
# Epoch 1, Batch 55/240, MSE = 0.025819
# Epoch 1, Batch 56/240, MSE = 0.023905
# Epoch 1, Batch 57/240, MSE = 0.024469
# Epoch 1, Batch 58/240, MSE = 0.025995
# Epoch 1, Batch 59/240, MSE = 0.026488
# Epoch 1, Batch 60/240, MSE = 0.026129
# Epoch 1, Batch 61/240, MSE = 0.026812
# Epoch 1, Batch 62/240, MSE = 0.024856
# Epoch 1, Batch 63/240, MSE = 0.025169
# Epoch 1, Batch 64/240, MSE = 0.023882
# Epoch 1, Batch 65/240, MSE = 0.022812
# Epoch 1, Batch 66/240, MSE = 0.024822
# Epoch 1, Batch 67/240, MSE = 0.029111
# Epoch 1, Batch 68/240, MSE = 0.026999
# Epoch 1, Batch 69/240, MSE = 0.026062
# Epoch 1, Batch 70/240, MSE = 0.026476
# Epoch 1, Batch 71/240, MSE = 0.024124
# Epoch 1, Batch 72/240, MSE = 0.029091
# Epoch 1, Batch 73/240, MSE = 0.024719
# Epoch 1, Batch 74/240, MSE = 0.026635
# Epoch 1, Batch 75/240, MSE = 0.023086
# Epoch 1, Batch 76/240, MSE = 0.024066
# Epoch 1, Batch 77/240, MSE = 0.025476
# Epoch 1, Batch 78/240, MSE = 0.024856
# Epoch 1, Batch 79/240, MSE = 0.024628
# Epoch 1, Batch 80/240, MSE = 0.024494
# Epoch 1, Batch 81/240, MSE = 0.025459
# Epoch 1, Batch 82/240, MSE = 0.024916
# Epoch 1, Batch 83/240, MSE = 0.025097
# Epoch 1, Batch 84/240, MSE = 0.025878
# Epoch 1, Batch 85/240, MSE = 0.025858
# Epoch 1, Batch 86/240, MSE = 0.025604
# Epoch 1, Batch 87/240, MSE = 0.026809
# Epoch 1, Batch 88/240, MSE = 0.024669
# Epoch 1, Batch 89/240, MSE = 0.025894
# Epoch 1, Batch 90/240, MSE = 0.023602
# Epoch 1, Batch 91/240, MSE = 0.025355
# Epoch 1, Batch 92/240, MSE = 0.024631
# Epoch 1, Batch 93/240, MSE = 0.024539
# Epoch 1, Batch 94/240, MSE = 0.024275
# Epoch 1, Batch 95/240, MSE = 0.024920
# Epoch 1, Batch 96/240, MSE = 0.024728
# Epoch 1, Batch 97/240, MSE = 0.023540
# Epoch 1, Batch 98/240, MSE = 0.025963
# Epoch 1, Batch 99/240, MSE = 0.025109
# Epoch 1, Batch 100/240, MSE = 0.024593
# Epoch 1, Batch 101/240, MSE = 0.025165
# Epoch 1, Batch 102/240, MSE = 0.024868
# Epoch 1, Batch 103/240, MSE = 0.024451
# Epoch 1, Batch 104/240, MSE = 0.024030
# Epoch 1, Batch 105/240, MSE = 0.026476
# Epoch 1, Batch 106/240, MSE = 0.025877
# Epoch 1, Batch 107/240, MSE = 0.023351
# Epoch 1, Batch 108/240, MSE = 0.024517
# Epoch 1, Batch 109/240, MSE = 0.027030
# Epoch 1, Batch 110/240, MSE = 0.023568
# Epoch 1, Batch 111/240, MSE = 0.023263
# Epoch 1, Batch 112/240, MSE = 0.023512
# Epoch 1, Batch 113/240, MSE = 0.022856
# Epoch 1, Batch 114/240, MSE = 0.022486
# Epoch 1, Batch 115/240, MSE = 0.023217
# Epoch 1, Batch 116/240, MSE = 0.024305
# Epoch 1, Batch 117/240, MSE = 0.023488
# Epoch 1, Batch 118/240, MSE = 0.024121
# Epoch 1, Batch 119/240, MSE = 0.025917
# Epoch 1, Batch 120/240, MSE = 0.023942
# Epoch 1, Batch 121/240, MSE = 0.021829
# Epoch 1, Batch 122/240, MSE = 0.023811
# Epoch 1, Batch 123/240, MSE = 0.023942
# Epoch 1, Batch 124/240, MSE = 0.023204
# Epoch 1, Batch 125/240, MSE = 0.023764
# Epoch 1, Batch 126/240, MSE = 0.022669
# Epoch 1, Batch 127/240, MSE = 0.024281
# Epoch 1, Batch 128/240, MSE = 0.025089
# Epoch 1, Batch 129/240, MSE = 0.023232
# Epoch 1, Batch 130/240, MSE = 0.023350
# Epoch 1, Batch 131/240, MSE = 0.023748
# Epoch 1, Batch 132/240, MSE = 0.021977
# Epoch 1, Batch 133/240, MSE = 0.022358
# Epoch 1, Batch 134/240, MSE = 0.021576
# Epoch 1, Batch 135/240, MSE = 0.022971
# Epoch 1, Batch 136/240, MSE = 0.022050
# Epoch 1, Batch 137/240, MSE = 0.020868
# Epoch 1, Batch 138/240, MSE = 0.024382
# Epoch 1, Batch 139/240, MSE = 0.022773
# Epoch 1, Batch 140/240, MSE = 0.025016
# Epoch 1, Batch 141/240, MSE = 0.024329
# Epoch 1, Batch 142/240, MSE = 0.022452
# Epoch 1, Batch 143/240, MSE = 0.024940
# Epoch 1, Batch 144/240, MSE = 0.024048
# Epoch 1, Batch 145/240, MSE = 0.021799
# Epoch 1, Batch 146/240, MSE = 0.021134
# Epoch 1, Batch 147/240, MSE = 0.021884
# Epoch 1, Batch 148/240, MSE = 0.022494
# Epoch 1, Batch 149/240, MSE = 0.020810
# Epoch 1, Batch 150/240, MSE = 0.022253
# Epoch 1, Batch 151/240, MSE = 0.021720
# Epoch 1, Batch 152/240, MSE = 0.020351
# Epoch 1, Batch 153/240, MSE = 0.021969
# Epoch 1, Batch 154/240, MSE = 0.022562
# Epoch 1, Batch 155/240, MSE = 0.022529
# Epoch 1, Batch 156/240, MSE = 0.021625
# Epoch 1, Batch 157/240, MSE = 0.021468
# Epoch 1, Batch 158/240, MSE = 0.020547
# Epoch 1, Batch 159/240, MSE = 0.021897
# Epoch 1, Batch 160/240, MSE = 0.020727
# Epoch 1, Batch 161/240, MSE = 0.022623
# Epoch 1, Batch 162/240, MSE = 0.022384
# Epoch 1, Batch 163/240, MSE = 0.021994
# Epoch 1, Batch 164/240, MSE = 0.021719
# Epoch 1, Batch 165/240, MSE = 0.020806
# Epoch 1, Batch 166/240, MSE = 0.021396
# Epoch 1, Batch 167/240, MSE = 0.020723
# Epoch 1, Batch 168/240, MSE = 0.021136
# Epoch 1, Batch 169/240, MSE = 0.023167
# Epoch 1, Batch 170/240, MSE = 0.021331
# Epoch 1, Batch 171/240, MSE = 0.022404
# Epoch 1, Batch 172/240, MSE = 0.021543
# Epoch 1, Batch 173/240, MSE = 0.023101
# Epoch 1, Batch 174/240, MSE = 0.020296
# Epoch 1, Batch 175/240, MSE = 0.021154
# Epoch 1, Batch 176/240, MSE = 0.021053
# Epoch 1, Batch 177/240, MSE = 0.021095
# Epoch 1, Batch 178/240, MSE = 0.020809
# Epoch 1, Batch 179/240, MSE = 0.021097
# Epoch 1, Batch 180/240, MSE = 0.020172
# Epoch 1, Batch 181/240, MSE = 0.020655
# Epoch 1, Batch 182/240, MSE = 0.024220
# Epoch 1, Batch 183/240, MSE = 0.021045
# Epoch 1, Batch 184/240, MSE = 0.019811
# Epoch 1, Batch 185/240, MSE = 0.021411
# Epoch 1, Batch 186/240, MSE = 0.019807
# Epoch 1, Batch 187/240, MSE = 0.022810
# Epoch 1, Batch 188/240, MSE = 0.020774
# Epoch 1, Batch 189/240, MSE = 0.020341
# Epoch 1, Batch 190/240, MSE = 0.019801
# Epoch 1, Batch 191/240, MSE = 0.020453
# Epoch 1, Batch 192/240, MSE = 0.019245
# Epoch 1, Batch 193/240, MSE = 0.019823
# Epoch 1, Batch 194/240, MSE = 0.020702
# Epoch 1, Batch 195/240, MSE = 0.019403
# Epoch 1, Batch 196/240, MSE = 0.020404
# Epoch 1, Batch 197/240, MSE = 0.021326
# Epoch 1, Batch 198/240, MSE = 0.018979
# Epoch 1, Batch 199/240, MSE = 0.019109
# Epoch 1, Batch 200/240, MSE = 0.019207
# Epoch 1, Batch 201/240, MSE = 0.019247
# Epoch 1, Batch 202/240, MSE = 0.019948
# Epoch 1, Batch 203/240, MSE = 0.019617
# Epoch 1, Batch 204/240, MSE = 0.020724
# Epoch 1, Batch 205/240, MSE = 0.018233
# Epoch 1, Batch 206/240, MSE = 0.019600
# Epoch 1, Batch 207/240, MSE = 0.021074
# Epoch 1, Batch 208/240, MSE = 0.019777
# Epoch 1, Batch 209/240, MSE = 0.020711
# Epoch 1, Batch 210/240, MSE = 0.019048
# Epoch 1, Batch 211/240, MSE = 0.019373
# Epoch 1, Batch 212/240, MSE = 0.020734
# Epoch 1, Batch 213/240, MSE = 0.020572
# Epoch 1, Batch 214/240, MSE = 0.020306
# Epoch 1, Batch 215/240, MSE = 0.019887
# Epoch 1, Batch 216/240, MSE = 0.019614
# Epoch 1, Batch 217/240, MSE = 0.019280
# Epoch 1, Batch 218/240, MSE = 0.019475
# Epoch 1, Batch 219/240, MSE = 0.019111
# Epoch 1, Batch 220/240, MSE = 0.017776
# Epoch 1, Batch 221/240, MSE = 0.018798
# Epoch 1, Batch 222/240, MSE = 0.018854
# Epoch 1, Batch 223/240, MSE = 0.018835
# Epoch 1, Batch 224/240, MSE = 0.020711
# Epoch 1, Batch 225/240, MSE = 0.018620
# Epoch 1, Batch 226/240, MSE = 0.019326
# Epoch 1, Batch 227/240, MSE = 0.018441
# Epoch 1, Batch 228/240, MSE = 0.017198
# Epoch 1, Batch 229/240, MSE = 0.019504
# Epoch 1, Batch 230/240, MSE = 0.020411
# Epoch 1, Batch 231/240, MSE = 0.025205
# Epoch 1, Batch 232/240, MSE = 0.021044
# Epoch 1, Batch 233/240, MSE = 0.019480
# Epoch 1, Batch 234/240, MSE = 0.020442
# Epoch 1, Batch 235/240, MSE = 0.019529
# Epoch 1, Batch 236/240, MSE = 0.019858
# Epoch 1, Batch 237/240, MSE = 0.018639
# Epoch 1, Batch 238/240, MSE = 0.017962
# Epoch 1, Batch 239/240, MSE = 0.017564
# Epoch 1, Batch 240/240, MSE = 0.018852
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.049921
# Epoch 1, Batch 2/240, MSE = 0.020184
# Epoch 1, Batch 3/240, MSE = 0.020389
# Epoch 1, Batch 4/240, MSE = 0.018351
# Epoch 1, Batch 5/240, MSE = 0.018377
# Epoch 1, Batch 6/240, MSE = 0.019434
# Epoch 1, Batch 7/240, MSE = 0.017959
# Epoch 1, Batch 8/240, MSE = 0.017785
# Epoch 1, Batch 9/240, MSE = 0.017204
# Epoch 1, Batch 10/240, MSE = 0.018598
# Epoch 1, Batch 11/240, MSE = 0.016666
# Epoch 1, Batch 12/240, MSE = 0.017247
# Epoch 1, Batch 13/240, MSE = 0.017943
# Epoch 1, Batch 14/240, MSE = 0.015470
# Epoch 1, Batch 15/240, MSE = 0.016127
# Epoch 1, Batch 16/240, MSE = 0.015312
# Epoch 1, Batch 17/240, MSE = 0.016315
# Epoch 1, Batch 18/240, MSE = 0.016964
# Epoch 1, Batch 19/240, MSE = 0.016559
# Epoch 1, Batch 20/240, MSE = 0.016346
# Epoch 1, Batch 21/240, MSE = 0.015926
# Epoch 1, Batch 22/240, MSE = 0.014509
# Epoch 1, Batch 23/240, MSE = 0.015358
# Epoch 1, Batch 24/240, MSE = 0.015693
# Epoch 1, Batch 25/240, MSE = 0.015609
# Epoch 1, Batch 26/240, MSE = 0.016660
# Epoch 1, Batch 27/240, MSE = 0.015295
# Epoch 1, Batch 28/240, MSE = 0.015580
# Epoch 1, Batch 29/240, MSE = 0.015692
# Epoch 1, Batch 30/240, MSE = 0.016319
# Epoch 1, Batch 31/240, MSE = 0.015135
# Epoch 1, Batch 32/240, MSE = 0.015908
# Epoch 1, Batch 33/240, MSE = 0.014148
# Epoch 1, Batch 34/240, MSE = 0.017013
# Epoch 1, Batch 35/240, MSE = 0.015036
# Epoch 1, Batch 36/240, MSE = 0.016082
# Epoch 1, Batch 37/240, MSE = 0.015544
# Epoch 1, Batch 38/240, MSE = 0.016370
# Epoch 1, Batch 39/240, MSE = 0.016186
# Epoch 1, Batch 40/240, MSE = 0.015179
# Epoch 1, Batch 41/240, MSE = 0.014555
# Epoch 1, Batch 42/240, MSE = 0.015621
# Epoch 1, Batch 43/240, MSE = 0.014888
# Epoch 1, Batch 44/240, MSE = 0.016752
# Epoch 1, Batch 45/240, MSE = 0.014687
# Epoch 1, Batch 46/240, MSE = 0.014509
# Epoch 1, Batch 47/240, MSE = 0.015601
# Epoch 1, Batch 48/240, MSE = 0.016777
# Epoch 1, Batch 49/240, MSE = 0.015848
# Epoch 1, Batch 50/240, MSE = 0.015231
# Epoch 1, Batch 51/240, MSE = 0.015492
# Epoch 1, Batch 52/240, MSE = 0.015673
# Epoch 1, Batch 53/240, MSE = 0.015521
# Epoch 1, Batch 54/240, MSE = 0.016487
# Epoch 1, Batch 55/240, MSE = 0.015183
# Epoch 1, Batch 56/240, MSE = 0.014175
# Epoch 1, Batch 57/240, MSE = 0.016322
# Epoch 1, Batch 58/240, MSE = 0.015838
# Epoch 1, Batch 59/240, MSE = 0.016257
# Epoch 1, Batch 60/240, MSE = 0.014163
# Epoch 1, Batch 61/240, MSE = 0.014542
# Epoch 1, Batch 62/240, MSE = 0.015514
# Epoch 1, Batch 63/240, MSE = 0.015037
# Epoch 1, Batch 64/240, MSE = 0.015378
# Epoch 1, Batch 65/240, MSE = 0.016028
# Epoch 1, Batch 66/240, MSE = 0.015475
# Epoch 1, Batch 67/240, MSE = 0.014448
# Epoch 1, Batch 68/240, MSE = 0.015262
# Epoch 1, Batch 69/240, MSE = 0.015761
# Epoch 1, Batch 70/240, MSE = 0.016208
# Epoch 1, Batch 71/240, MSE = 0.015877
# Epoch 1, Batch 72/240, MSE = 0.014982
# Epoch 1, Batch 73/240, MSE = 0.015440
# Epoch 1, Batch 74/240, MSE = 0.016449
# Epoch 1, Batch 75/240, MSE = 0.016082
# Epoch 1, Batch 76/240, MSE = 0.014085
# Epoch 1, Batch 77/240, MSE = 0.015343
# Epoch 1, Batch 78/240, MSE = 0.016066
# Epoch 1, Batch 79/240, MSE = 0.016158
# Epoch 1, Batch 80/240, MSE = 0.015632
# Epoch 1, Batch 81/240, MSE = 0.015516
# Epoch 1, Batch 82/240, MSE = 0.014832
# Epoch 1, Batch 83/240, MSE = 0.014649
# Epoch 1, Batch 84/240, MSE = 0.014902
# Epoch 1, Batch 85/240, MSE = 0.015593
# Epoch 1, Batch 86/240, MSE = 0.015478
# Epoch 1, Batch 87/240, MSE = 0.015622
# Epoch 1, Batch 88/240, MSE = 0.014789
# Epoch 1, Batch 89/240, MSE = 0.014782
# Epoch 1, Batch 90/240, MSE = 0.015140
# Epoch 1, Batch 91/240, MSE = 0.015960
# Epoch 1, Batch 92/240, MSE = 0.016661
# Epoch 1, Batch 93/240, MSE = 0.016092
# Epoch 1, Batch 94/240, MSE = 0.015009
# Epoch 1, Batch 95/240, MSE = 0.014509
# Epoch 1, Batch 96/240, MSE = 0.014768
# Epoch 1, Batch 97/240, MSE = 0.016575
# Epoch 1, Batch 98/240, MSE = 0.013582
# Epoch 1, Batch 99/240, MSE = 0.016060
# Epoch 1, Batch 100/240, MSE = 0.015545
# Epoch 1, Batch 101/240, MSE = 0.014833
# Epoch 1, Batch 102/240, MSE = 0.014936
# Epoch 1, Batch 103/240, MSE = 0.015730
# Epoch 1, Batch 104/240, MSE = 0.016761
# Epoch 1, Batch 105/240, MSE = 0.015289
# Epoch 1, Batch 106/240, MSE = 0.016385
# Epoch 1, Batch 107/240, MSE = 0.015077
# Epoch 1, Batch 108/240, MSE = 0.014789
# Epoch 1, Batch 109/240, MSE = 0.014764
# Epoch 1, Batch 110/240, MSE = 0.015150
# Epoch 1, Batch 111/240, MSE = 0.015681
# Epoch 1, Batch 112/240, MSE = 0.016097
# Epoch 1, Batch 113/240, MSE = 0.015470
# Epoch 1, Batch 114/240, MSE = 0.014050
# Epoch 1, Batch 115/240, MSE = 0.015792
# Epoch 1, Batch 116/240, MSE = 0.015288
# Epoch 1, Batch 117/240, MSE = 0.015571
# Epoch 1, Batch 118/240, MSE = 0.015264
# Epoch 1, Batch 119/240, MSE = 0.015291
# Epoch 1, Batch 120/240, MSE = 0.014617
# Epoch 1, Batch 121/240, MSE = 0.015153
# Epoch 1, Batch 122/240, MSE = 0.015081
# Epoch 1, Batch 123/240, MSE = 0.015677
# Epoch 1, Batch 124/240, MSE = 0.014851
# Epoch 1, Batch 125/240, MSE = 0.015350
# Epoch 1, Batch 126/240, MSE = 0.016672
# Epoch 1, Batch 127/240, MSE = 0.015347
# Epoch 1, Batch 128/240, MSE = 0.015852
# Epoch 1, Batch 129/240, MSE = 0.015773
# Epoch 1, Batch 130/240, MSE = 0.016129
# Epoch 1, Batch 131/240, MSE = 0.015387
# Epoch 1, Batch 132/240, MSE = 0.014785
# Epoch 1, Batch 133/240, MSE = 0.015629
# Epoch 1, Batch 134/240, MSE = 0.015865
# Epoch 1, Batch 135/240, MSE = 0.015806
# Epoch 1, Batch 136/240, MSE = 0.014419
# Epoch 1, Batch 137/240, MSE = 0.015551
# Epoch 1, Batch 138/240, MSE = 0.015871
# Epoch 1, Batch 139/240, MSE = 0.016314
# Epoch 1, Batch 140/240, MSE = 0.016107
# Epoch 1, Batch 141/240, MSE = 0.014232
# Epoch 1, Batch 142/240, MSE = 0.015461
# Epoch 1, Batch 143/240, MSE = 0.014385
# Epoch 1, Batch 144/240, MSE = 0.015115
# Epoch 1, Batch 145/240, MSE = 0.015647
# Epoch 1, Batch 146/240, MSE = 0.014449
# Epoch 1, Batch 147/240, MSE = 0.013981
# Epoch 1, Batch 148/240, MSE = 0.015451
# Epoch 1, Batch 149/240, MSE = 0.015718
# Epoch 1, Batch 150/240, MSE = 0.015769
# Epoch 1, Batch 151/240, MSE = 0.014973
# Epoch 1, Batch 152/240, MSE = 0.016113
# Epoch 1, Batch 153/240, MSE = 0.015442
# Epoch 1, Batch 154/240, MSE = 0.015635
# Epoch 1, Batch 155/240, MSE = 0.013642
# Epoch 1, Batch 156/240, MSE = 0.014470
# Epoch 1, Batch 157/240, MSE = 0.014711
# Epoch 1, Batch 158/240, MSE = 0.015731
# Epoch 1, Batch 159/240, MSE = 0.014957
# Epoch 1, Batch 160/240, MSE = 0.016288
# Epoch 1, Batch 161/240, MSE = 0.015471
# Epoch 1, Batch 162/240, MSE = 0.016155
# Epoch 1, Batch 163/240, MSE = 0.016887
# Epoch 1, Batch 164/240, MSE = 0.014702
# Epoch 1, Batch 165/240, MSE = 0.014226
# Epoch 1, Batch 166/240, MSE = 0.015203
# Epoch 1, Batch 167/240, MSE = 0.015677
# Epoch 1, Batch 168/240, MSE = 0.015328
# Epoch 1, Batch 169/240, MSE = 0.014789
# Epoch 1, Batch 170/240, MSE = 0.014546
# Epoch 1, Batch 171/240, MSE = 0.015236
# Epoch 1, Batch 172/240, MSE = 0.014542
# Epoch 1, Batch 173/240, MSE = 0.015493
# Epoch 1, Batch 174/240, MSE = 0.015531
# Epoch 1, Batch 175/240, MSE = 0.015280
# Epoch 1, Batch 176/240, MSE = 0.014826
# Epoch 1, Batch 177/240, MSE = 0.014954
# Epoch 1, Batch 178/240, MSE = 0.016558
# Epoch 1, Batch 179/240, MSE = 0.013831
# Epoch 1, Batch 180/240, MSE = 0.014774
# Epoch 1, Batch 181/240, MSE = 0.014537
# Epoch 1, Batch 182/240, MSE = 0.014633
# Epoch 1, Batch 183/240, MSE = 0.014603
# Epoch 1, Batch 184/240, MSE = 0.014615
# Epoch 1, Batch 185/240, MSE = 0.014753
# Epoch 1, Batch 186/240, MSE = 0.014554
# Epoch 1, Batch 187/240, MSE = 0.014644
# Epoch 1, Batch 188/240, MSE = 0.015399
# Epoch 1, Batch 189/240, MSE = 0.014515
# Epoch 1, Batch 190/240, MSE = 0.014469
# Epoch 1, Batch 191/240, MSE = 0.015147
# Epoch 1, Batch 192/240, MSE = 0.014763
# Epoch 1, Batch 193/240, MSE = 0.014768
# Epoch 1, Batch 194/240, MSE = 0.014453
# Epoch 1, Batch 195/240, MSE = 0.014421
# Epoch 1, Batch 196/240, MSE = 0.014604
# Epoch 1, Batch 197/240, MSE = 0.014571
# Epoch 1, Batch 198/240, MSE = 0.014386
# Epoch 1, Batch 199/240, MSE = 0.014215
# Epoch 1, Batch 200/240, MSE = 0.014558
# Epoch 1, Batch 201/240, MSE = 0.014238
# Epoch 1, Batch 202/240, MSE = 0.013745
# Epoch 1, Batch 203/240, MSE = 0.013784
# Epoch 1, Batch 204/240, MSE = 0.014190
# Epoch 1, Batch 205/240, MSE = 0.014142
# Epoch 1, Batch 206/240, MSE = 0.014667
# Epoch 1, Batch 207/240, MSE = 0.013973
# Epoch 1, Batch 208/240, MSE = 0.013483
# Epoch 1, Batch 209/240, MSE = 0.014115
# Epoch 1, Batch 210/240, MSE = 0.014354
# Epoch 1, Batch 211/240, MSE = 0.016172
# Epoch 1, Batch 212/240, MSE = 0.015913
# Epoch 1, Batch 213/240, MSE = 0.013977
# Epoch 1, Batch 214/240, MSE = 0.014704
# Epoch 1, Batch 215/240, MSE = 0.014532
# Epoch 1, Batch 216/240, MSE = 0.014482
# Epoch 1, Batch 217/240, MSE = 0.014510
# Epoch 1, Batch 218/240, MSE = 0.013667
# Epoch 1, Batch 219/240, MSE = 0.015664
# Epoch 1, Batch 220/240, MSE = 0.014464
# Epoch 1, Batch 221/240, MSE = 0.013386
# Epoch 1, Batch 222/240, MSE = 0.014963
# Epoch 1, Batch 223/240, MSE = 0.015218
# Epoch 1, Batch 224/240, MSE = 0.015426
# Epoch 1, Batch 225/240, MSE = 0.015295
# Epoch 1, Batch 226/240, MSE = 0.014580
# Epoch 1, Batch 227/240, MSE = 0.013916
# Epoch 1, Batch 228/240, MSE = 0.013778
# Epoch 1, Batch 229/240, MSE = 0.013404
# Epoch 1, Batch 230/240, MSE = 0.014722
# Epoch 1, Batch 231/240, MSE = 0.014850
# Epoch 1, Batch 232/240, MSE = 0.013916
# Epoch 1, Batch 233/240, MSE = 0.013766
# Epoch 1, Batch 234/240, MSE = 0.014910
# Epoch 1, Batch 235/240, MSE = 0.014362
# Epoch 1, Batch 236/240, MSE = 0.013975
# Epoch 1, Batch 237/240, MSE = 0.014836
# Epoch 1, Batch 238/240, MSE = 0.014171
# Epoch 1, Batch 239/240, MSE = 0.014095
# Epoch 1, Batch 240/240, MSE = 0.013981
#
# ============================================================
# Epoch 2/20
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.011243
# Epoch 1, Batch 2/240, MSE = 0.010555
# Epoch 1, Batch 3/240, MSE = 0.010739
# Epoch 1, Batch 4/240, MSE = 0.010036
# Epoch 1, Batch 5/240, MSE = 0.010647
# Epoch 1, Batch 6/240, MSE = 0.010456
# Epoch 1, Batch 7/240, MSE = 0.010206
# Epoch 1, Batch 8/240, MSE = 0.009905
# Epoch 1, Batch 9/240, MSE = 0.010201
# Epoch 1, Batch 10/240, MSE = 0.009752
# Epoch 1, Batch 11/240, MSE = 0.010148
# Epoch 1, Batch 12/240, MSE = 0.010548
# Epoch 1, Batch 13/240, MSE = 0.012966
# Epoch 1, Batch 14/240, MSE = 0.009980
# Epoch 1, Batch 15/240, MSE = 0.009565
# Epoch 1, Batch 16/240, MSE = 0.009445
# Epoch 1, Batch 17/240, MSE = 0.009273
# Epoch 1, Batch 18/240, MSE = 0.009920
# Epoch 1, Batch 19/240, MSE = 0.009388
# Epoch 1, Batch 20/240, MSE = 0.009811
# Epoch 1, Batch 21/240, MSE = 0.008851
# Epoch 1, Batch 22/240, MSE = 0.009793
# Epoch 1, Batch 23/240, MSE = 0.009178
# Epoch 1, Batch 24/240, MSE = 0.009623
# Epoch 1, Batch 25/240, MSE = 0.009266
# Epoch 1, Batch 26/240, MSE = 0.009555
# Epoch 1, Batch 27/240, MSE = 0.009164
# Epoch 1, Batch 28/240, MSE = 0.008738
# Epoch 1, Batch 29/240, MSE = 0.009198
# Epoch 1, Batch 30/240, MSE = 0.009986
# Epoch 1, Batch 31/240, MSE = 0.009036
# Epoch 1, Batch 32/240, MSE = 0.008931
# Epoch 1, Batch 33/240, MSE = 0.008498
# Epoch 1, Batch 34/240, MSE = 0.009241
# Epoch 1, Batch 35/240, MSE = 0.009059
# Epoch 1, Batch 36/240, MSE = 0.009043
# Epoch 1, Batch 37/240, MSE = 0.009192
# Epoch 1, Batch 38/240, MSE = 0.009322
# Epoch 1, Batch 39/240, MSE = 0.008800
# Epoch 1, Batch 40/240, MSE = 0.008255
# Epoch 1, Batch 41/240, MSE = 0.008609
# Epoch 1, Batch 42/240, MSE = 0.009568
# Epoch 1, Batch 43/240, MSE = 0.009416
# Epoch 1, Batch 44/240, MSE = 0.010308
# Epoch 1, Batch 45/240, MSE = 0.009436
# Epoch 1, Batch 46/240, MSE = 0.008379
# Epoch 1, Batch 47/240, MSE = 0.008126
# Epoch 1, Batch 48/240, MSE = 0.008507
# Epoch 1, Batch 49/240, MSE = 0.008502
# Epoch 1, Batch 50/240, MSE = 0.008594
# Epoch 1, Batch 51/240, MSE = 0.008340
# Epoch 1, Batch 52/240, MSE = 0.008050
# Epoch 1, Batch 53/240, MSE = 0.008342
# Epoch 1, Batch 54/240, MSE = 0.007795
# Epoch 1, Batch 55/240, MSE = 0.007923
# Epoch 1, Batch 56/240, MSE = 0.008758
# Epoch 1, Batch 57/240, MSE = 0.007771
# Epoch 1, Batch 58/240, MSE = 0.007889
# Epoch 1, Batch 59/240, MSE = 0.007706
# Epoch 1, Batch 60/240, MSE = 0.008292
# Epoch 1, Batch 61/240, MSE = 0.007813
# Epoch 1, Batch 62/240, MSE = 0.007791
# Epoch 1, Batch 63/240, MSE = 0.007669
# Epoch 1, Batch 64/240, MSE = 0.007605
# Epoch 1, Batch 65/240, MSE = 0.007881
# Epoch 1, Batch 66/240, MSE = 0.007577
# Epoch 1, Batch 67/240, MSE = 0.007944
# Epoch 1, Batch 68/240, MSE = 0.007611
# Epoch 1, Batch 69/240, MSE = 0.007770
# Epoch 1, Batch 70/240, MSE = 0.007394
# Epoch 1, Batch 71/240, MSE = 0.007402
# Epoch 1, Batch 72/240, MSE = 0.007716
# Epoch 1, Batch 73/240, MSE = 0.007061
# Epoch 1, Batch 74/240, MSE = 0.008266
# Epoch 1, Batch 75/240, MSE = 0.007498
# Epoch 1, Batch 76/240, MSE = 0.006974
# Epoch 1, Batch 77/240, MSE = 0.008069
# Epoch 1, Batch 78/240, MSE = 0.007251
# Epoch 1, Batch 79/240, MSE = 0.007727
# Epoch 1, Batch 80/240, MSE = 0.007243
# Epoch 1, Batch 81/240, MSE = 0.007918
# Epoch 1, Batch 82/240, MSE = 0.006741
# Epoch 1, Batch 83/240, MSE = 0.007319
# Epoch 1, Batch 84/240, MSE = 0.006846
# Epoch 1, Batch 85/240, MSE = 0.006892
# Epoch 1, Batch 86/240, MSE = 0.006929
# Epoch 1, Batch 87/240, MSE = 0.006297
# Epoch 1, Batch 88/240, MSE = 0.007192
# Epoch 1, Batch 89/240, MSE = 0.006670
# Epoch 1, Batch 90/240, MSE = 0.006990
# Epoch 1, Batch 91/240, MSE = 0.006559
# Epoch 1, Batch 92/240, MSE = 0.006642
# Epoch 1, Batch 93/240, MSE = 0.006894
# Epoch 1, Batch 94/240, MSE = 0.006909
# Epoch 1, Batch 95/240, MSE = 0.007007
# Epoch 1, Batch 96/240, MSE = 0.006409
# Epoch 1, Batch 97/240, MSE = 0.006746
# Epoch 1, Batch 98/240, MSE = 0.006477
# Epoch 1, Batch 99/240, MSE = 0.006863
# Epoch 1, Batch 100/240, MSE = 0.006537
# Epoch 1, Batch 101/240, MSE = 0.006536
# Epoch 1, Batch 102/240, MSE = 0.006344
# Epoch 1, Batch 103/240, MSE = 0.006640
# Epoch 1, Batch 104/240, MSE = 0.006138
# Epoch 1, Batch 105/240, MSE = 0.006545
# Epoch 1, Batch 106/240, MSE = 0.006311
# Epoch 1, Batch 107/240, MSE = 0.006540
# Epoch 1, Batch 108/240, MSE = 0.005856
# Epoch 1, Batch 109/240, MSE = 0.006247
# Epoch 1, Batch 110/240, MSE = 0.006068
# Epoch 1, Batch 111/240, MSE = 0.006213
# Epoch 1, Batch 112/240, MSE = 0.006438
# Epoch 1, Batch 113/240, MSE = 0.005987
# Epoch 1, Batch 114/240, MSE = 0.006179
# Epoch 1, Batch 115/240, MSE = 0.006324
# Epoch 1, Batch 116/240, MSE = 0.006387
# Epoch 1, Batch 117/240, MSE = 0.006085
# Epoch 1, Batch 118/240, MSE = 0.006036
# Epoch 1, Batch 119/240, MSE = 0.005537
# Epoch 1, Batch 120/240, MSE = 0.006069
# Epoch 1, Batch 121/240, MSE = 0.006137
# Epoch 1, Batch 122/240, MSE = 0.005844
# Epoch 1, Batch 123/240, MSE = 0.006220
# Epoch 1, Batch 124/240, MSE = 0.006168
# Epoch 1, Batch 125/240, MSE = 0.006298
# Epoch 1, Batch 126/240, MSE = 0.005843
# Epoch 1, Batch 127/240, MSE = 0.005906
# Epoch 1, Batch 128/240, MSE = 0.005817
# Epoch 1, Batch 129/240, MSE = 0.005782
# Epoch 1, Batch 130/240, MSE = 0.005796
# Epoch 1, Batch 131/240, MSE = 0.005737
# Epoch 1, Batch 132/240, MSE = 0.005775
# Epoch 1, Batch 133/240, MSE = 0.005883
# Epoch 1, Batch 134/240, MSE = 0.005429
# Epoch 1, Batch 135/240, MSE = 0.005436
# Epoch 1, Batch 136/240, MSE = 0.005650
# Epoch 1, Batch 137/240, MSE = 0.005427
# Epoch 1, Batch 138/240, MSE = 0.005380
# Epoch 1, Batch 139/240, MSE = 0.005629
# Epoch 1, Batch 140/240, MSE = 0.005748
# Epoch 1, Batch 141/240, MSE = 0.005327
# Epoch 1, Batch 142/240, MSE = 0.005481
# Epoch 1, Batch 143/240, MSE = 0.005373
# Epoch 1, Batch 144/240, MSE = 0.005341
# Epoch 1, Batch 145/240, MSE = 0.005051
# Epoch 1, Batch 146/240, MSE = 0.004968
# Epoch 1, Batch 147/240, MSE = 0.004939
# Epoch 1, Batch 148/240, MSE = 0.004987
# Epoch 1, Batch 149/240, MSE = 0.004979
# Epoch 1, Batch 150/240, MSE = 0.005402
# Epoch 1, Batch 151/240, MSE = 0.005372
# Epoch 1, Batch 152/240, MSE = 0.005110
# Epoch 1, Batch 153/240, MSE = 0.005237
# Epoch 1, Batch 154/240, MSE = 0.005240
# Epoch 1, Batch 155/240, MSE = 0.005133
# Epoch 1, Batch 156/240, MSE = 0.005323
# Epoch 1, Batch 157/240, MSE = 0.005007
# Epoch 1, Batch 158/240, MSE = 0.004865
# Epoch 1, Batch 159/240, MSE = 0.005036
# Epoch 1, Batch 160/240, MSE = 0.005178
# Epoch 1, Batch 161/240, MSE = 0.004496
# Epoch 1, Batch 162/240, MSE = 0.005209
# Epoch 1, Batch 163/240, MSE = 0.004732
# Epoch 1, Batch 164/240, MSE = 0.004855
# Epoch 1, Batch 165/240, MSE = 0.004932
# Epoch 1, Batch 166/240, MSE = 0.004831
# Epoch 1, Batch 167/240, MSE = 0.004665
# Epoch 1, Batch 168/240, MSE = 0.004541
# Epoch 1, Batch 169/240, MSE = 0.004272
# Epoch 1, Batch 170/240, MSE = 0.004646
# Epoch 1, Batch 171/240, MSE = 0.005023
# Epoch 1, Batch 172/240, MSE = 0.004075
# Epoch 1, Batch 173/240, MSE = 0.004481
# Epoch 1, Batch 174/240, MSE = 0.004804
# Epoch 1, Batch 175/240, MSE = 0.004921
# Epoch 1, Batch 176/240, MSE = 0.004391
# Epoch 1, Batch 177/240, MSE = 0.004518
# Epoch 1, Batch 178/240, MSE = 0.004481
# Epoch 1, Batch 179/240, MSE = 0.004226
# Epoch 1, Batch 180/240, MSE = 0.004445
# Epoch 1, Batch 181/240, MSE = 0.004715
# Epoch 1, Batch 182/240, MSE = 0.004314
# Epoch 1, Batch 183/240, MSE = 0.004471
# Epoch 1, Batch 184/240, MSE = 0.004820
# Epoch 1, Batch 185/240, MSE = 0.004598
# Epoch 1, Batch 186/240, MSE = 0.004319
# Epoch 1, Batch 187/240, MSE = 0.004230
# Epoch 1, Batch 188/240, MSE = 0.004377
# Epoch 1, Batch 189/240, MSE = 0.004242
# Epoch 1, Batch 190/240, MSE = 0.004200
# Epoch 1, Batch 191/240, MSE = 0.004332
# Epoch 1, Batch 192/240, MSE = 0.004143
# Epoch 1, Batch 193/240, MSE = 0.003937
# Epoch 1, Batch 194/240, MSE = 0.004203
# Epoch 1, Batch 195/240, MSE = 0.004184
# Epoch 1, Batch 196/240, MSE = 0.004099
# Epoch 1, Batch 197/240, MSE = 0.004268
# Epoch 1, Batch 198/240, MSE = 0.003933
# Epoch 1, Batch 199/240, MSE = 0.004213
# Epoch 1, Batch 200/240, MSE = 0.004102
# Epoch 1, Batch 201/240, MSE = 0.004059
# Epoch 1, Batch 202/240, MSE = 0.003897
# Epoch 1, Batch 203/240, MSE = 0.004200
# Epoch 1, Batch 204/240, MSE = 0.003855
# Epoch 1, Batch 205/240, MSE = 0.004089
# Epoch 1, Batch 206/240, MSE = 0.004256
# Epoch 1, Batch 207/240, MSE = 0.003984
# Epoch 1, Batch 208/240, MSE = 0.004018
# Epoch 1, Batch 209/240, MSE = 0.003750
# Epoch 1, Batch 210/240, MSE = 0.003847
# Epoch 1, Batch 211/240, MSE = 0.003769
# Epoch 1, Batch 212/240, MSE = 0.003994
# Epoch 1, Batch 213/240, MSE = 0.003407
# Epoch 1, Batch 214/240, MSE = 0.003791
# Epoch 1, Batch 215/240, MSE = 0.003927
# Epoch 1, Batch 216/240, MSE = 0.003758
# Epoch 1, Batch 217/240, MSE = 0.003909
# Epoch 1, Batch 218/240, MSE = 0.003641
# Epoch 1, Batch 219/240, MSE = 0.003810
# Epoch 1, Batch 220/240, MSE = 0.003766
# Epoch 1, Batch 221/240, MSE = 0.003596
# Epoch 1, Batch 222/240, MSE = 0.003361
# Epoch 1, Batch 223/240, MSE = 0.003524
# Epoch 1, Batch 224/240, MSE = 0.003372
# Epoch 1, Batch 225/240, MSE = 0.003813
# Epoch 1, Batch 226/240, MSE = 0.003711
# Epoch 1, Batch 227/240, MSE = 0.003490
# Epoch 1, Batch 228/240, MSE = 0.003476
# Epoch 1, Batch 229/240, MSE = 0.003563
# Epoch 1, Batch 230/240, MSE = 0.003414
# Epoch 1, Batch 231/240, MSE = 0.003360
# Epoch 1, Batch 232/240, MSE = 0.003481
# Epoch 1, Batch 233/240, MSE = 0.003247
# Epoch 1, Batch 234/240, MSE = 0.003218
# Epoch 1, Batch 235/240, MSE = 0.003312
# Epoch 1, Batch 236/240, MSE = 0.003261
# Epoch 1, Batch 237/240, MSE = 0.003298
# Epoch 1, Batch 238/240, MSE = 0.003353
# Epoch 1, Batch 239/240, MSE = 0.003509
# Epoch 1, Batch 240/240, MSE = 0.003262
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.028861
# Epoch 1, Batch 2/240, MSE = 0.028774
# Epoch 1, Batch 3/240, MSE = 0.029711
# Epoch 1, Batch 4/240, MSE = 0.029559
# Epoch 1, Batch 5/240, MSE = 0.030779
# Epoch 1, Batch 6/240, MSE = 0.030837
# Epoch 1, Batch 7/240, MSE = 0.032145
# Epoch 1, Batch 8/240, MSE = 0.029500
# Epoch 1, Batch 9/240, MSE = 0.029427
# Epoch 1, Batch 10/240, MSE = 0.028621
# Epoch 1, Batch 11/240, MSE = 0.029952
# Epoch 1, Batch 12/240, MSE = 0.029137
# Epoch 1, Batch 13/240, MSE = 0.031228
# Epoch 1, Batch 14/240, MSE = 0.029823
# Epoch 1, Batch 15/240, MSE = 0.029433
# Epoch 1, Batch 16/240, MSE = 0.029536
# Epoch 1, Batch 17/240, MSE = 0.028966
# Epoch 1, Batch 18/240, MSE = 0.027889
# Epoch 1, Batch 19/240, MSE = 0.028261
# Epoch 1, Batch 20/240, MSE = 0.028635
# Epoch 1, Batch 21/240, MSE = 0.028869
# Epoch 1, Batch 22/240, MSE = 0.028292
# Epoch 1, Batch 23/240, MSE = 0.029550
# Epoch 1, Batch 24/240, MSE = 0.026684
# Epoch 1, Batch 25/240, MSE = 0.028430
# Epoch 1, Batch 26/240, MSE = 0.029752
# Epoch 1, Batch 27/240, MSE = 0.028281
# Epoch 1, Batch 28/240, MSE = 0.027098
# Epoch 1, Batch 29/240, MSE = 0.029743
# Epoch 1, Batch 30/240, MSE = 0.030062
# Epoch 1, Batch 31/240, MSE = 0.027901
# Epoch 1, Batch 32/240, MSE = 0.027669
# Epoch 1, Batch 33/240, MSE = 0.027319
# Epoch 1, Batch 34/240, MSE = 0.028005
# Epoch 1, Batch 35/240, MSE = 0.029520
# Epoch 1, Batch 36/240, MSE = 0.028864
# Epoch 1, Batch 37/240, MSE = 0.026788
# Epoch 1, Batch 38/240, MSE = 0.028344
# Epoch 1, Batch 39/240, MSE = 0.027743
# Epoch 1, Batch 40/240, MSE = 0.027031
# Epoch 1, Batch 41/240, MSE = 0.026500
# Epoch 1, Batch 42/240, MSE = 0.029148
# Epoch 1, Batch 43/240, MSE = 0.026914
# Epoch 1, Batch 44/240, MSE = 0.028367
# Epoch 1, Batch 45/240, MSE = 0.028073
# Epoch 1, Batch 46/240, MSE = 0.028657
# Epoch 1, Batch 47/240, MSE = 0.027879
# Epoch 1, Batch 48/240, MSE = 0.027044
# Epoch 1, Batch 49/240, MSE = 0.026754
# Epoch 1, Batch 50/240, MSE = 0.027194
# Epoch 1, Batch 51/240, MSE = 0.027125
# Epoch 1, Batch 52/240, MSE = 0.025693
# Epoch 1, Batch 53/240, MSE = 0.024358
# Epoch 1, Batch 54/240, MSE = 0.026582
# Epoch 1, Batch 55/240, MSE = 0.027182
# Epoch 1, Batch 56/240, MSE = 0.026955
# Epoch 1, Batch 57/240, MSE = 0.025777
# Epoch 1, Batch 58/240, MSE = 0.025475
# Epoch 1, Batch 59/240, MSE = 0.027560
# Epoch 1, Batch 60/240, MSE = 0.026082
# Epoch 1, Batch 61/240, MSE = 0.025551
# Epoch 1, Batch 62/240, MSE = 0.025835
# Epoch 1, Batch 63/240, MSE = 0.024115
# Epoch 1, Batch 64/240, MSE = 0.027481
# Epoch 1, Batch 65/240, MSE = 0.026234
# Epoch 1, Batch 66/240, MSE = 0.025079
# Epoch 1, Batch 67/240, MSE = 0.026595
# Epoch 1, Batch 68/240, MSE = 0.027845
# Epoch 1, Batch 69/240, MSE = 0.024900
# Epoch 1, Batch 70/240, MSE = 0.024923
# Epoch 1, Batch 71/240, MSE = 0.025411
# Epoch 1, Batch 72/240, MSE = 0.023767
# Epoch 1, Batch 73/240, MSE = 0.023385
# Epoch 1, Batch 74/240, MSE = 0.025035
# Epoch 1, Batch 75/240, MSE = 0.025126
# Epoch 1, Batch 76/240, MSE = 0.026237
# Epoch 1, Batch 77/240, MSE = 0.024260
# Epoch 1, Batch 78/240, MSE = 0.025174
# Epoch 1, Batch 79/240, MSE = 0.023673
# Epoch 1, Batch 80/240, MSE = 0.024704
# Epoch 1, Batch 81/240, MSE = 0.023717
# Epoch 1, Batch 82/240, MSE = 0.024070
# Epoch 1, Batch 83/240, MSE = 0.025093
# Epoch 1, Batch 84/240, MSE = 0.025609
# Epoch 1, Batch 85/240, MSE = 0.025943
# Epoch 1, Batch 86/240, MSE = 0.023383
# Epoch 1, Batch 87/240, MSE = 0.025068
# Epoch 1, Batch 88/240, MSE = 0.023196
# Epoch 1, Batch 89/240, MSE = 0.022794
# Epoch 1, Batch 90/240, MSE = 0.024312
# Epoch 1, Batch 91/240, MSE = 0.023392
# Epoch 1, Batch 92/240, MSE = 0.024351
# Epoch 1, Batch 93/240, MSE = 0.022955
# Epoch 1, Batch 94/240, MSE = 0.024082
# Epoch 1, Batch 95/240, MSE = 0.023402
# Epoch 1, Batch 96/240, MSE = 0.021712
# Epoch 1, Batch 97/240, MSE = 0.022497
# Epoch 1, Batch 98/240, MSE = 0.023066
# Epoch 1, Batch 99/240, MSE = 0.023783
# Epoch 1, Batch 100/240, MSE = 0.021985
# Epoch 1, Batch 101/240, MSE = 0.022430
# Epoch 1, Batch 102/240, MSE = 0.022374
# Epoch 1, Batch 103/240, MSE = 0.023122
# Epoch 1, Batch 104/240, MSE = 0.021564
# Epoch 1, Batch 105/240, MSE = 0.024359
# Epoch 1, Batch 106/240, MSE = 0.020202
# Epoch 1, Batch 107/240, MSE = 0.021793
# Epoch 1, Batch 108/240, MSE = 0.022513
# Epoch 1, Batch 109/240, MSE = 0.024968
# Epoch 1, Batch 110/240, MSE = 0.021874
# Epoch 1, Batch 111/240, MSE = 0.022013
# Epoch 1, Batch 112/240, MSE = 0.022919
# Epoch 1, Batch 113/240, MSE = 0.022611
# Epoch 1, Batch 114/240, MSE = 0.024230
# Epoch 1, Batch 115/240, MSE = 0.020256
# Epoch 1, Batch 116/240, MSE = 0.022588
# Epoch 1, Batch 117/240, MSE = 0.021945
# Epoch 1, Batch 118/240, MSE = 0.023083
# Epoch 1, Batch 119/240, MSE = 0.020671
# Epoch 1, Batch 120/240, MSE = 0.021255
# Epoch 1, Batch 121/240, MSE = 0.020396
# Epoch 1, Batch 122/240, MSE = 0.020929
# Epoch 1, Batch 123/240, MSE = 0.020520
# Epoch 1, Batch 124/240, MSE = 0.022023
# Epoch 1, Batch 125/240, MSE = 0.021823
# Epoch 1, Batch 126/240, MSE = 0.019673
# Epoch 1, Batch 127/240, MSE = 0.021015
# Epoch 1, Batch 128/240, MSE = 0.022363
# Epoch 1, Batch 129/240, MSE = 0.020589
# Epoch 1, Batch 130/240, MSE = 0.020191
# Epoch 1, Batch 131/240, MSE = 0.021085
# Epoch 1, Batch 132/240, MSE = 0.021895
# Epoch 1, Batch 133/240, MSE = 0.019398
# Epoch 1, Batch 134/240, MSE = 0.021248
# Epoch 1, Batch 135/240, MSE = 0.019482
# Epoch 1, Batch 136/240, MSE = 0.021590
# Epoch 1, Batch 137/240, MSE = 0.021470
# Epoch 1, Batch 138/240, MSE = 0.020125
# Epoch 1, Batch 139/240, MSE = 0.019922
# Epoch 1, Batch 140/240, MSE = 0.018986
# Epoch 1, Batch 141/240, MSE = 0.020332
# Epoch 1, Batch 142/240, MSE = 0.019596
# Epoch 1, Batch 143/240, MSE = 0.019879
# Epoch 1, Batch 144/240, MSE = 0.019949
# Epoch 1, Batch 145/240, MSE = 0.020304
# Epoch 1, Batch 146/240, MSE = 0.020218
# Epoch 1, Batch 147/240, MSE = 0.018879
# Epoch 1, Batch 148/240, MSE = 0.020945
# Epoch 1, Batch 149/240, MSE = 0.018619
# Epoch 1, Batch 150/240, MSE = 0.019518
# Epoch 1, Batch 151/240, MSE = 0.018698
# Epoch 1, Batch 152/240, MSE = 0.019363
# Epoch 1, Batch 153/240, MSE = 0.018761
# Epoch 1, Batch 154/240, MSE = 0.018850
# Epoch 1, Batch 155/240, MSE = 0.020540
# Epoch 1, Batch 156/240, MSE = 0.019789
# Epoch 1, Batch 157/240, MSE = 0.018415
# Epoch 1, Batch 158/240, MSE = 0.018520
# Epoch 1, Batch 159/240, MSE = 0.018834
# Epoch 1, Batch 160/240, MSE = 0.018549
# Epoch 1, Batch 161/240, MSE = 0.019226
# Epoch 1, Batch 162/240, MSE = 0.017799
# Epoch 1, Batch 163/240, MSE = 0.017736
# Epoch 1, Batch 164/240, MSE = 0.019291
# Epoch 1, Batch 165/240, MSE = 0.017731
# Epoch 1, Batch 166/240, MSE = 0.018924
# Epoch 1, Batch 167/240, MSE = 0.018681
# Epoch 1, Batch 168/240, MSE = 0.019195
# Epoch 1, Batch 169/240, MSE = 0.018232
# Epoch 1, Batch 170/240, MSE = 0.019381
# Epoch 1, Batch 171/240, MSE = 0.018986
# Epoch 1, Batch 172/240, MSE = 0.018254
# Epoch 1, Batch 173/240, MSE = 0.017201
# Epoch 1, Batch 174/240, MSE = 0.017055
# Epoch 1, Batch 175/240, MSE = 0.017962
# Epoch 1, Batch 176/240, MSE = 0.016403
# Epoch 1, Batch 177/240, MSE = 0.017607
# Epoch 1, Batch 178/240, MSE = 0.018679
# Epoch 1, Batch 179/240, MSE = 0.018254
# Epoch 1, Batch 180/240, MSE = 0.017332
# Epoch 1, Batch 181/240, MSE = 0.017744
# Epoch 1, Batch 182/240, MSE = 0.016659
# Epoch 1, Batch 183/240, MSE = 0.017502
# Epoch 1, Batch 184/240, MSE = 0.017387
# Epoch 1, Batch 185/240, MSE = 0.017539
# Epoch 1, Batch 186/240, MSE = 0.016497
# Epoch 1, Batch 187/240, MSE = 0.017452
# Epoch 1, Batch 188/240, MSE = 0.016819
# Epoch 1, Batch 189/240, MSE = 0.017703
# Epoch 1, Batch 190/240, MSE = 0.017653
# Epoch 1, Batch 191/240, MSE = 0.016829
# Epoch 1, Batch 192/240, MSE = 0.016672
# Epoch 1, Batch 193/240, MSE = 0.018090
# Epoch 1, Batch 194/240, MSE = 0.016716
# Epoch 1, Batch 195/240, MSE = 0.016512
# Epoch 1, Batch 196/240, MSE = 0.017925
# Epoch 1, Batch 197/240, MSE = 0.016059
# Epoch 1, Batch 198/240, MSE = 0.016311
# Epoch 1, Batch 199/240, MSE = 0.016583
# Epoch 1, Batch 200/240, MSE = 0.018433
# Epoch 1, Batch 201/240, MSE = 0.014684
# Epoch 1, Batch 202/240, MSE = 0.017464
# Epoch 1, Batch 203/240, MSE = 0.017406
# Epoch 1, Batch 204/240, MSE = 0.016722
# Epoch 1, Batch 205/240, MSE = 0.016828
# Epoch 1, Batch 206/240, MSE = 0.016289
# Epoch 1, Batch 207/240, MSE = 0.015573
# Epoch 1, Batch 208/240, MSE = 0.016319
# Epoch 1, Batch 209/240, MSE = 0.015414
# Epoch 1, Batch 210/240, MSE = 0.016019
# Epoch 1, Batch 211/240, MSE = 0.015907
# Epoch 1, Batch 212/240, MSE = 0.015634
# Epoch 1, Batch 213/240, MSE = 0.016334
# Epoch 1, Batch 214/240, MSE = 0.016324
# Epoch 1, Batch 215/240, MSE = 0.014832
# Epoch 1, Batch 216/240, MSE = 0.015520
# Epoch 1, Batch 217/240, MSE = 0.013858
# Epoch 1, Batch 218/240, MSE = 0.015287
# Epoch 1, Batch 219/240, MSE = 0.015788
# Epoch 1, Batch 220/240, MSE = 0.014805
# Epoch 1, Batch 221/240, MSE = 0.015246
# Epoch 1, Batch 222/240, MSE = 0.015496
# Epoch 1, Batch 223/240, MSE = 0.014860
# Epoch 1, Batch 224/240, MSE = 0.014822
# Epoch 1, Batch 225/240, MSE = 0.015112
# Epoch 1, Batch 226/240, MSE = 0.015670
# Epoch 1, Batch 227/240, MSE = 0.014360
# Epoch 1, Batch 228/240, MSE = 0.014720
# Epoch 1, Batch 229/240, MSE = 0.014781
# Epoch 1, Batch 230/240, MSE = 0.015001
# Epoch 1, Batch 231/240, MSE = 0.014724
# Epoch 1, Batch 232/240, MSE = 0.013627
# Epoch 1, Batch 233/240, MSE = 0.015321
# Epoch 1, Batch 234/240, MSE = 0.015948
# Epoch 1, Batch 235/240, MSE = 0.014022
# Epoch 1, Batch 236/240, MSE = 0.014723
# Epoch 1, Batch 237/240, MSE = 0.013525
# Epoch 1, Batch 238/240, MSE = 0.013952
# Epoch 1, Batch 239/240, MSE = 0.014328
# Epoch 1, Batch 240/240, MSE = 0.014641
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.048446
# Epoch 1, Batch 2/240, MSE = 0.050072
# Epoch 1, Batch 3/240, MSE = 0.047627
# Epoch 1, Batch 4/240, MSE = 0.049819
# Epoch 1, Batch 5/240, MSE = 0.047085
# Epoch 1, Batch 6/240, MSE = 0.048477
# Epoch 1, Batch 7/240, MSE = 0.046397
# Epoch 1, Batch 8/240, MSE = 0.049960
# Epoch 1, Batch 9/240, MSE = 0.050708
# Epoch 1, Batch 10/240, MSE = 0.048999
# Epoch 1, Batch 11/240, MSE = 0.053686
# Epoch 1, Batch 12/240, MSE = 0.050384
# Epoch 1, Batch 13/240, MSE = 0.047309
# Epoch 1, Batch 14/240, MSE = 0.044553
# Epoch 1, Batch 15/240, MSE = 0.051113
# Epoch 1, Batch 16/240, MSE = 0.043825
# Epoch 1, Batch 17/240, MSE = 0.045692
# Epoch 1, Batch 18/240, MSE = 0.043508
# Epoch 1, Batch 19/240, MSE = 0.049154
# Epoch 1, Batch 20/240, MSE = 0.048284
# ...
# Epoch 1, Batch 69/240, MSE = 0.000150
# Epoch 1, Batch 70/240, MSE = 0.000146
# Epoch 1, Batch 71/240, MSE = 0.000159
# Epoch 1, Batch 72/240, MSE = 0.000156
# Epoch 1, Batch 73/240, MSE = 0.000164
# Epoch 1, Batch 74/240, MSE = 0.000146
# Epoch 1, Batch 75/240, MSE = 0.000169
# Epoch 1, Batch 76/240, MSE = 0.000171
# Epoch 1, Batch 77/240, MSE = 0.000153
# Epoch 1, Batch 78/240, MSE = 0.000149
# Epoch 1, Batch 79/240, MSE = 0.000176
# Epoch 1, Batch 80/240, MSE = 0.000164
# Epoch 1, Batch 81/240, MSE = 0.000153
# Epoch 1, Batch 82/240, MSE = 0.000165
# Epoch 1, Batch 83/240, MSE = 0.000163
# Epoch 1, Batch 84/240, MSE = 0.000150
# Epoch 1, Batch 85/240, MSE = 0.000147
# Epoch 1, Batch 86/240, MSE = 0.000142
# Epoch 1, Batch 87/240, MSE = 0.000175
# Epoch 1, Batch 88/240, MSE = 0.000152
# Epoch 1, Batch 89/240, MSE = 0.000140
# Epoch 1, Batch 90/240, MSE = 0.000138
# Epoch 1, Batch 91/240, MSE = 0.000142
# Epoch 1, Batch 92/240, MSE = 0.000156
# Epoch 1, Batch 93/240, MSE = 0.000151
# Epoch 1, Batch 94/240, MSE = 0.000147
# Epoch 1, Batch 95/240, MSE = 0.000146
# Epoch 1, Batch 96/240, MSE = 0.000141
# Epoch 1, Batch 97/240, MSE = 0.000152
# Epoch 1, Batch 98/240, MSE = 0.000138
# Epoch 1, Batch 99/240, MSE = 0.000153
# Epoch 1, Batch 100/240, MSE = 0.000136
# Epoch 1, Batch 101/240, MSE = 0.000139
# Epoch 1, Batch 102/240, MSE = 0.000157
# Epoch 1, Batch 103/240, MSE = 0.000155
# Epoch 1, Batch 104/240, MSE = 0.000151
# Epoch 1, Batch 105/240, MSE = 0.000149
# Epoch 1, Batch 106/240, MSE = 0.000160
# Epoch 1, Batch 107/240, MSE = 0.000155
# Epoch 1, Batch 108/240, MSE = 0.000146
# Epoch 1, Batch 109/240, MSE = 0.000158
# Epoch 1, Batch 110/240, MSE = 0.000146
# Epoch 1, Batch 111/240, MSE = 0.000155
# Epoch 1, Batch 112/240, MSE = 0.000140
# Epoch 1, Batch 113/240, MSE = 0.000156
# Epoch 1, Batch 114/240, MSE = 0.000135
# Epoch 1, Batch 115/240, MSE = 0.000129
# Epoch 1, Batch 116/240, MSE = 0.000166
# Epoch 1, Batch 117/240, MSE = 0.000157
# Epoch 1, Batch 118/240, MSE = 0.000159
# Epoch 1, Batch 119/240, MSE = 0.000140
# Epoch 1, Batch 120/240, MSE = 0.000147
# Epoch 1, Batch 121/240, MSE = 0.000143
# Epoch 1, Batch 122/240, MSE = 0.000149
# Epoch 1, Batch 123/240, MSE = 0.000156
# Epoch 1, Batch 124/240, MSE = 0.000135
# Epoch 1, Batch 125/240, MSE = 0.000154
# Epoch 1, Batch 126/240, MSE = 0.000150
# Epoch 1, Batch 127/240, MSE = 0.000153
# Epoch 1, Batch 128/240, MSE = 0.000162
# Epoch 1, Batch 129/240, MSE = 0.000157
# Epoch 1, Batch 130/240, MSE = 0.000166
# Epoch 1, Batch 131/240, MSE = 0.000149
# Epoch 1, Batch 132/240, MSE = 0.000153
# Epoch 1, Batch 133/240, MSE = 0.000146
# Epoch 1, Batch 134/240, MSE = 0.000152
# Epoch 1, Batch 135/240, MSE = 0.000155
# Epoch 1, Batch 136/240, MSE = 0.000143
# Epoch 1, Batch 137/240, MSE = 0.000145
# Epoch 1, Batch 138/240, MSE = 0.000138
# Epoch 1, Batch 139/240, MSE = 0.000154
# Epoch 1, Batch 140/240, MSE = 0.000147
# Epoch 1, Batch 141/240, MSE = 0.000156
# Epoch 1, Batch 142/240, MSE = 0.000160
# Epoch 1, Batch 143/240, MSE = 0.000153
# Epoch 1, Batch 144/240, MSE = 0.000143
# Epoch 1, Batch 145/240, MSE = 0.000142
# Epoch 1, Batch 146/240, MSE = 0.000145
# Epoch 1, Batch 147/240, MSE = 0.000154
# Epoch 1, Batch 148/240, MSE = 0.000153
# Epoch 1, Batch 149/240, MSE = 0.000163
# Epoch 1, Batch 150/240, MSE = 0.000149
# Epoch 1, Batch 151/240, MSE = 0.000154
# Epoch 1, Batch 152/240, MSE = 0.000153
# Epoch 1, Batch 153/240, MSE = 0.000147
# Epoch 1, Batch 154/240, MSE = 0.000137
# Epoch 1, Batch 155/240, MSE = 0.000154
# Epoch 1, Batch 156/240, MSE = 0.000148
# Epoch 1, Batch 157/240, MSE = 0.000143
# Epoch 1, Batch 158/240, MSE = 0.000137
# Epoch 1, Batch 159/240, MSE = 0.000154
# Epoch 1, Batch 160/240, MSE = 0.000150
# Epoch 1, Batch 161/240, MSE = 0.000146
# Epoch 1, Batch 162/240, MSE = 0.000155
# Epoch 1, Batch 163/240, MSE = 0.000159
# Epoch 1, Batch 164/240, MSE = 0.000159
# Epoch 1, Batch 165/240, MSE = 0.000138
# Epoch 1, Batch 166/240, MSE = 0.000153
# Epoch 1, Batch 167/240, MSE = 0.000140
# Epoch 1, Batch 168/240, MSE = 0.000152
# Epoch 1, Batch 169/240, MSE = 0.000140
# Epoch 1, Batch 170/240, MSE = 0.000165
# Epoch 1, Batch 171/240, MSE = 0.000147
# Epoch 1, Batch 172/240, MSE = 0.000158
# Epoch 1, Batch 173/240, MSE = 0.000139
# Epoch 1, Batch 174/240, MSE = 0.000148
# Epoch 1, Batch 175/240, MSE = 0.000153
# Epoch 1, Batch 176/240, MSE = 0.000146
# Epoch 1, Batch 177/240, MSE = 0.000162
# Epoch 1, Batch 178/240, MSE = 0.000151
# Epoch 1, Batch 179/240, MSE = 0.000149
# Epoch 1, Batch 180/240, MSE = 0.000146
# Epoch 1, Batch 181/240, MSE = 0.000148
# Epoch 1, Batch 182/240, MSE = 0.000140
# Epoch 1, Batch 183/240, MSE = 0.000148
# Epoch 1, Batch 184/240, MSE = 0.000145
# Epoch 1, Batch 185/240, MSE = 0.000142
# Epoch 1, Batch 186/240, MSE = 0.000134
# Epoch 1, Batch 187/240, MSE = 0.000150
# Epoch 1, Batch 188/240, MSE = 0.000140
# Epoch 1, Batch 189/240, MSE = 0.000139
# Epoch 1, Batch 190/240, MSE = 0.000141
# Epoch 1, Batch 191/240, MSE = 0.000145
# Epoch 1, Batch 192/240, MSE = 0.000141
# Epoch 1, Batch 193/240, MSE = 0.000138
# Epoch 1, Batch 194/240, MSE = 0.000157
# Epoch 1, Batch 195/240, MSE = 0.000151
# Epoch 1, Batch 196/240, MSE = 0.000147
# Epoch 1, Batch 197/240, MSE = 0.000150
# Epoch 1, Batch 198/240, MSE = 0.000150
# Epoch 1, Batch 199/240, MSE = 0.000134
# Epoch 1, Batch 200/240, MSE = 0.000141
# Epoch 1, Batch 201/240, MSE = 0.000143
# Epoch 1, Batch 202/240, MSE = 0.000144
# Epoch 1, Batch 203/240, MSE = 0.000149
# Epoch 1, Batch 204/240, MSE = 0.000150
# Epoch 1, Batch 205/240, MSE = 0.000148
# Epoch 1, Batch 206/240, MSE = 0.000139
# Epoch 1, Batch 207/240, MSE = 0.000159
# Epoch 1, Batch 208/240, MSE = 0.000155
# Epoch 1, Batch 209/240, MSE = 0.000155
# Epoch 1, Batch 210/240, MSE = 0.000150
# Epoch 1, Batch 211/240, MSE = 0.000146
# Epoch 1, Batch 212/240, MSE = 0.000142
# Epoch 1, Batch 213/240, MSE = 0.000142
# Epoch 1, Batch 214/240, MSE = 0.000133
# Epoch 1, Batch 215/240, MSE = 0.000141
# Epoch 1, Batch 216/240, MSE = 0.000154
# Epoch 1, Batch 217/240, MSE = 0.000144
# Epoch 1, Batch 218/240, MSE = 0.000139
# Epoch 1, Batch 219/240, MSE = 0.000146
# Epoch 1, Batch 220/240, MSE = 0.000158
# Epoch 1, Batch 221/240, MSE = 0.000153
# Epoch 1, Batch 222/240, MSE = 0.000136
# Epoch 1, Batch 223/240, MSE = 0.000155
# Epoch 1, Batch 224/240, MSE = 0.000156
# Epoch 1, Batch 225/240, MSE = 0.000153
# Epoch 1, Batch 226/240, MSE = 0.000142
# Epoch 1, Batch 227/240, MSE = 0.000147
# Epoch 1, Batch 228/240, MSE = 0.000137
# Epoch 1, Batch 229/240, MSE = 0.000156
# Epoch 1, Batch 230/240, MSE = 0.000146
# Epoch 1, Batch 231/240, MSE = 0.000150
# Epoch 1, Batch 232/240, MSE = 0.000149
# Epoch 1, Batch 233/240, MSE = 0.000159
# Epoch 1, Batch 234/240, MSE = 0.000146
# Epoch 1, Batch 235/240, MSE = 0.000142
# Epoch 1, Batch 236/240, MSE = 0.000153
# Epoch 1, Batch 237/240, MSE = 0.000147
# Epoch 1, Batch 238/240, MSE = 0.000147
# Epoch 1, Batch 239/240, MSE = 0.000133
# Epoch 1, Batch 240/240, MSE = 0.000145
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.000880
# Epoch 1, Batch 2/240, MSE = 0.000911
# Epoch 1, Batch 3/240, MSE = 0.001002
# Epoch 1, Batch 4/240, MSE = 0.000940
# Epoch 1, Batch 5/240, MSE = 0.000965
# Epoch 1, Batch 6/240, MSE = 0.000929
# Epoch 1, Batch 7/240, MSE = 0.001000
# Epoch 1, Batch 8/240, MSE = 0.001029
# Epoch 1, Batch 9/240, MSE = 0.000832
# Epoch 1, Batch 10/240, MSE = 0.000902
# Epoch 1, Batch 11/240, MSE = 0.000922
# Epoch 1, Batch 12/240, MSE = 0.000948
# Epoch 1, Batch 13/240, MSE = 0.000875
# Epoch 1, Batch 14/240, MSE = 0.000895
# Epoch 1, Batch 15/240, MSE = 0.000895
# Epoch 1, Batch 16/240, MSE = 0.000941
# Epoch 1, Batch 17/240, MSE = 0.000817
# Epoch 1, Batch 18/240, MSE = 0.000913
# Epoch 1, Batch 19/240, MSE = 0.000907
# Epoch 1, Batch 20/240, MSE = 0.000910
# Epoch 1, Batch 21/240, MSE = 0.000968
# Epoch 1, Batch 22/240, MSE = 0.001017
# Epoch 1, Batch 23/240, MSE = 0.000855
# Epoch 1, Batch 24/240, MSE = 0.000989
# Epoch 1, Batch 25/240, MSE = 0.000935
# Epoch 1, Batch 26/240, MSE = 0.000867
# Epoch 1, Batch 27/240, MSE = 0.000859
# Epoch 1, Batch 28/240, MSE = 0.000897
# Epoch 1, Batch 29/240, MSE = 0.001052
# Epoch 1, Batch 30/240, MSE = 0.000943
# Epoch 1, Batch 31/240, MSE = 0.000955
# Epoch 1, Batch 32/240, MSE = 0.000995
# Epoch 1, Batch 33/240, MSE = 0.000980
# Epoch 1, Batch 34/240, MSE = 0.001023
# Epoch 1, Batch 35/240, MSE = 0.000931
# Epoch 1, Batch 36/240, MSE = 0.000948
# Epoch 1, Batch 37/240, MSE = 0.001040
# Epoch 1, Batch 38/240, MSE = 0.000984
# Epoch 1, Batch 39/240, MSE = 0.000953
# Epoch 1, Batch 40/240, MSE = 0.000996
# Epoch 1, Batch 41/240, MSE = 0.000836
# Epoch 1, Batch 42/240, MSE = 0.000946
# Epoch 1, Batch 43/240, MSE = 0.000809
# Epoch 1, Batch 44/240, MSE = 0.000953
# Epoch 1, Batch 45/240, MSE = 0.000886
# Epoch 1, Batch 46/240, MSE = 0.000897
# Epoch 1, Batch 47/240, MSE = 0.000990
# Epoch 1, Batch 48/240, MSE = 0.000978
# Epoch 1, Batch 49/240, MSE = 0.000839
# Epoch 1, Batch 50/240, MSE = 0.000950
# Epoch 1, Batch 51/240, MSE = 0.000949
# Epoch 1, Batch 52/240, MSE = 0.000913
# Epoch 1, Batch 53/240, MSE = 0.000921
# Epoch 1, Batch 54/240, MSE = 0.000860
# Epoch 1, Batch 55/240, MSE = 0.000924
# Epoch 1, Batch 56/240, MSE = 0.000903
# Epoch 1, Batch 57/240, MSE = 0.000834
# Epoch 1, Batch 58/240, MSE = 0.000921
# Epoch 1, Batch 59/240, MSE = 0.000889
# Epoch 1, Batch 60/240, MSE = 0.000798
# Epoch 1, Batch 61/240, MSE = 0.000922
# Epoch 1, Batch 62/240, MSE = 0.000943
# Epoch 1, Batch 63/240, MSE = 0.000914
# Epoch 1, Batch 64/240, MSE = 0.000890
# Epoch 1, Batch 65/240, MSE = 0.000974
# Epoch 1, Batch 66/240, MSE = 0.000982
# Epoch 1, Batch 67/240, MSE = 0.000976
# Epoch 1, Batch 68/240, MSE = 0.000826
# Epoch 1, Batch 69/240, MSE = 0.000915
# Epoch 1, Batch 70/240, MSE = 0.000955
# Epoch 1, Batch 71/240, MSE = 0.001003
# Epoch 1, Batch 72/240, MSE = 0.000944
# Epoch 1, Batch 73/240, MSE = 0.001000
# Epoch 1, Batch 74/240, MSE = 0.000923
# Epoch 1, Batch 75/240, MSE = 0.000915
# Epoch 1, Batch 76/240, MSE = 0.000954
# Epoch 1, Batch 77/240, MSE = 0.000938
# Epoch 1, Batch 78/240, MSE = 0.000900
# Epoch 1, Batch 79/240, MSE = 0.000906
# Epoch 1, Batch 80/240, MSE = 0.000911
# Epoch 1, Batch 81/240, MSE = 0.000904
# Epoch 1, Batch 82/240, MSE = 0.000861
# Epoch 1, Batch 83/240, MSE = 0.000820
# Epoch 1, Batch 84/240, MSE = 0.000872
# Epoch 1, Batch 85/240, MSE = 0.000954
# Epoch 1, Batch 86/240, MSE = 0.000848
# Epoch 1, Batch 87/240, MSE = 0.000877
# Epoch 1, Batch 88/240, MSE = 0.000909
# Epoch 1, Batch 89/240, MSE = 0.000810
# Epoch 1, Batch 90/240, MSE = 0.000848
# Epoch 1, Batch 91/240, MSE = 0.000894
# Epoch 1, Batch 92/240, MSE = 0.000845
# Epoch 1, Batch 93/240, MSE = 0.000861
# Epoch 1, Batch 94/240, MSE = 0.000833
# Epoch 1, Batch 95/240, MSE = 0.000824
# Epoch 1, Batch 96/240, MSE = 0.000895
# Epoch 1, Batch 97/240, MSE = 0.000916
# Epoch 1, Batch 98/240, MSE = 0.000907
# Epoch 1, Batch 99/240, MSE = 0.000949
# Epoch 1, Batch 100/240, MSE = 0.000897
# Epoch 1, Batch 101/240, MSE = 0.000790
# Epoch 1, Batch 102/240, MSE = 0.000990
# Epoch 1, Batch 103/240, MSE = 0.000953
# Epoch 1, Batch 104/240, MSE = 0.000893
# Epoch 1, Batch 105/240, MSE = 0.000923
# Epoch 1, Batch 106/240, MSE = 0.000922
# Epoch 1, Batch 107/240, MSE = 0.000873
# Epoch 1, Batch 108/240, MSE = 0.000933
# Epoch 1, Batch 109/240, MSE = 0.000931
# Epoch 1, Batch 110/240, MSE = 0.000854
# Epoch 1, Batch 111/240, MSE = 0.000959
# Epoch 1, Batch 112/240, MSE = 0.000883
# Epoch 1, Batch 113/240, MSE = 0.000867
# Epoch 1, Batch 114/240, MSE = 0.000815
# Epoch 1, Batch 115/240, MSE = 0.001024
# Epoch 1, Batch 116/240, MSE = 0.000947
# Epoch 1, Batch 117/240, MSE = 0.000926
# Epoch 1, Batch 118/240, MSE = 0.000887
# Epoch 1, Batch 119/240, MSE = 0.000846
# Epoch 1, Batch 120/240, MSE = 0.000892
# Epoch 1, Batch 121/240, MSE = 0.000876
# Epoch 1, Batch 122/240, MSE = 0.000896
# Epoch 1, Batch 123/240, MSE = 0.000794
# Epoch 1, Batch 124/240, MSE = 0.000848
# Epoch 1, Batch 125/240, MSE = 0.000924
# Epoch 1, Batch 126/240, MSE = 0.000854
# Epoch 1, Batch 127/240, MSE = 0.000798
# Epoch 1, Batch 128/240, MSE = 0.000895
# Epoch 1, Batch 129/240, MSE = 0.000911
# Epoch 1, Batch 130/240, MSE = 0.000914
# Epoch 1, Batch 131/240, MSE = 0.000809
# Epoch 1, Batch 132/240, MSE = 0.000826
# Epoch 1, Batch 133/240, MSE = 0.000827
# Epoch 1, Batch 134/240, MSE = 0.000915
# Epoch 1, Batch 135/240, MSE = 0.000846
# Epoch 1, Batch 136/240, MSE = 0.000928
# Epoch 1, Batch 137/240, MSE = 0.000859
# Epoch 1, Batch 138/240, MSE = 0.000836
# Epoch 1, Batch 139/240, MSE = 0.000835
# Epoch 1, Batch 140/240, MSE = 0.000873
# Epoch 1, Batch 141/240, MSE = 0.000871
# Epoch 1, Batch 142/240, MSE = 0.000985
# Epoch 1, Batch 143/240, MSE = 0.000868
# Epoch 1, Batch 144/240, MSE = 0.000836
# Epoch 1, Batch 145/240, MSE = 0.000923
# Epoch 1, Batch 146/240, MSE = 0.000861
# Epoch 1, Batch 147/240, MSE = 0.000828
# Epoch 1, Batch 148/240, MSE = 0.000874
# Epoch 1, Batch 149/240, MSE = 0.000866
# Epoch 1, Batch 150/240, MSE = 0.000886
# Epoch 1, Batch 151/240, MSE = 0.000916
# Epoch 1, Batch 152/240, MSE = 0.000831
# Epoch 1, Batch 153/240, MSE = 0.000854
# Epoch 1, Batch 154/240, MSE = 0.000970
# Epoch 1, Batch 155/240, MSE = 0.000877
# Epoch 1, Batch 156/240, MSE = 0.000981
# Epoch 1, Batch 157/240, MSE = 0.000849
# Epoch 1, Batch 158/240, MSE = 0.000872
# Epoch 1, Batch 159/240, MSE = 0.000879
# Epoch 1, Batch 160/240, MSE = 0.000924
# Epoch 1, Batch 161/240, MSE = 0.000846
# Epoch 1, Batch 162/240, MSE = 0.000813
# Epoch 1, Batch 163/240, MSE = 0.000948
# Epoch 1, Batch 164/240, MSE = 0.000899
# Epoch 1, Batch 165/240, MSE = 0.000842
# Epoch 1, Batch 166/240, MSE = 0.000879
# Epoch 1, Batch 167/240, MSE = 0.000893
# Epoch 1, Batch 168/240, MSE = 0.000768
# Epoch 1, Batch 169/240, MSE = 0.000835
# Epoch 1, Batch 170/240, MSE = 0.000998
# Epoch 1, Batch 171/240, MSE = 0.000863
# Epoch 1, Batch 172/240, MSE = 0.000833
# Epoch 1, Batch 173/240, MSE = 0.000869
# Epoch 1, Batch 174/240, MSE = 0.000834
# Epoch 1, Batch 175/240, MSE = 0.000857
# Epoch 1, Batch 176/240, MSE = 0.000817
# Epoch 1, Batch 177/240, MSE = 0.000804
# Epoch 1, Batch 178/240, MSE = 0.000881
# Epoch 1, Batch 179/240, MSE = 0.000921
# Epoch 1, Batch 180/240, MSE = 0.000835
# Epoch 1, Batch 181/240, MSE = 0.000960
# Epoch 1, Batch 182/240, MSE = 0.000860
# Epoch 1, Batch 183/240, MSE = 0.000883
# Epoch 1, Batch 184/240, MSE = 0.000734
# Epoch 1, Batch 185/240, MSE = 0.000854
# Epoch 1, Batch 186/240, MSE = 0.000908
# Epoch 1, Batch 187/240, MSE = 0.000843
# Epoch 1, Batch 188/240, MSE = 0.000911
# Epoch 1, Batch 189/240, MSE = 0.000757
# Epoch 1, Batch 190/240, MSE = 0.000875
# Epoch 1, Batch 191/240, MSE = 0.000788
# Epoch 1, Batch 192/240, MSE = 0.000831
# Epoch 1, Batch 193/240, MSE = 0.000911
# Epoch 1, Batch 194/240, MSE = 0.000792
# Epoch 1, Batch 195/240, MSE = 0.000896
# Epoch 1, Batch 196/240, MSE = 0.000830
# Epoch 1, Batch 197/240, MSE = 0.000804
# Epoch 1, Batch 198/240, MSE = 0.000800
# Epoch 1, Batch 199/240, MSE = 0.000872
# Epoch 1, Batch 200/240, MSE = 0.000850
# Epoch 1, Batch 201/240, MSE = 0.000880
# Epoch 1, Batch 202/240, MSE = 0.000876
# Epoch 1, Batch 203/240, MSE = 0.000891
# Epoch 1, Batch 204/240, MSE = 0.000870
# Epoch 1, Batch 205/240, MSE = 0.000847
# Epoch 1, Batch 206/240, MSE = 0.000858
# Epoch 1, Batch 207/240, MSE = 0.000891
# Epoch 1, Batch 208/240, MSE = 0.000780
# Epoch 1, Batch 209/240, MSE = 0.000844
# Epoch 1, Batch 210/240, MSE = 0.000818
# Epoch 1, Batch 211/240, MSE = 0.000902
# Epoch 1, Batch 212/240, MSE = 0.000859
# Epoch 1, Batch 213/240, MSE = 0.000815
# Epoch 1, Batch 214/240, MSE = 0.000937
# Epoch 1, Batch 215/240, MSE = 0.000904
# Epoch 1, Batch 216/240, MSE = 0.000898
# Epoch 1, Batch 217/240, MSE = 0.000927
# Epoch 1, Batch 218/240, MSE = 0.000731
# Epoch 1, Batch 219/240, MSE = 0.000839
# Epoch 1, Batch 220/240, MSE = 0.000876
# Epoch 1, Batch 221/240, MSE = 0.000751
# Epoch 1, Batch 222/240, MSE = 0.000856
# Epoch 1, Batch 223/240, MSE = 0.000896
# Epoch 1, Batch 224/240, MSE = 0.000803
# Epoch 1, Batch 225/240, MSE = 0.000859
# Epoch 1, Batch 226/240, MSE = 0.000853
# Epoch 1, Batch 227/240, MSE = 0.000889
# Epoch 1, Batch 228/240, MSE = 0.000886
# Epoch 1, Batch 229/240, MSE = 0.000812
# Epoch 1, Batch 230/240, MSE = 0.000770
# Epoch 1, Batch 231/240, MSE = 0.000796
# Epoch 1, Batch 232/240, MSE = 0.000858
# Epoch 1, Batch 233/240, MSE = 0.000800
# Epoch 1, Batch 234/240, MSE = 0.000883
# Epoch 1, Batch 235/240, MSE = 0.000742
# Epoch 1, Batch 236/240, MSE = 0.000899
# Epoch 1, Batch 237/240, MSE = 0.000769
# Epoch 1, Batch 238/240, MSE = 0.000789
# Epoch 1, Batch 239/240, MSE = 0.000862
# Epoch 1, Batch 240/240, MSE = 0.000876
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -10    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# 8. 길이 맞추기
target_len = len(clean_iq_test)
if len(iq_reconstructed) != target_len:
    iq_reconstructed = resample(iq_reconstructed, target_len)

print(f"✅ IQ signal resampled: {iq_reconstructed.shape}")

# 🔧 길이 보정: Resample (Zero-padding 대신!)
from scipy.signal import resample
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (2048)
if len(iq_reconstructed) != target_len:
    original_len = len(iq_reconstructed)
    iq_reconstructed = resample(iq_reconstructed, target_len)
    print(f"   🔧 Resampled: {original_len} → {target_len} samples (Sinc interpolation)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")

print(f"   Energy before scaling: |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

# 8. 에너지 정규화 (Energy Normalization) ⭐
# iSTFT 후 신호 에너지가 손실되므로, 원본 noisy IQ의 에너지에 맞춰 복원
energy_noisy = np.sqrt(np.mean(np.abs(noisy_iq)**2))
energy_reconstructed = np.sqrt(np.mean(np.abs(iq_reconstructed)**2))

if energy_reconstructed > 1e-10:  # 0으로 나누기 방지
    scale_factor = energy_noisy / energy_reconstructed
    iq_reconstructed = iq_reconstructed * scale_factor
    print(f"   Energy scaling: {energy_noisy:.6f} / {energy_reconstructed:.6f} = {scale_factor:.2f}x")
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")
else:
    print(f"   ⚠️  Warning: Reconstructed signal energy too low, no scaling applied")

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -10 dB
#
# === Normalization Parameters ===
# Real: min=-0.012984, max=0.014749, range=0.027732
# Imag: min=-0.014891, max=0.011461, range=0.026352
# Restored norm: real_min=-0.0072, real_max=1.0216
# Restored norm: imag_min=0.0186, imag_max=0.9882
# After denorm:  real_min=-0.013184, real_max=0.015348
# After denorm:  imag_min=-0.014401, imag_max=0.011150
# ✅ IQ signal reconstructed (before resampling): (1920,)
#    🔧 Resampled: 1920 → 2048 samples (Sinc interpolation)
#    Energy before scaling: |mean|=0.014866, |max|=0.047642
#    Energy scaling: 3.331285 / 0.016862 = 197.57x
#    Energy after scaling:  |mean|=2.937006, |max|=9.412498
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.5165
# Restored flat: min=-0.0072, max=1.0216, mean=0.5167
# Difference:    MSE=0.000271
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0001, max=0.0159
# Zxx_restored (magnitude): min=0.0000, max=0.0159
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, "clean", sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, "noisy", sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, "restored", sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3 successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3 failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=2.9491, |max|=9.0070
# Reconstructed:   len=2048, |mean|=2.9370, |max|=9.4125
#
# MSE Comparison:
# Clean vs Noisy:        10.065023
# Clean vs Reconstructed: 11.741361
# Noisy vs Reconstructed: 22.433434
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 1880.00
# ⚠️  Noisy signal (len=2048)    → Code: 42, Peak: 1886.24
# 🔧 Restored (len=2048)   → Code: 25, Peak: 733.39
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       42 ✅ CORRECT
# Restored Decoded:    25 ❌ WRONG
# ============================================================
#
# Peak Comparison:
# Clean Peak:    1880.00
# Noisy Peak:    1886.24 (100.3% of clean)
# Restored Peak: 733.39 (39.0% of clean)
#
# ❌ FAILURE: BAMv3 failed to restore the correct symbol

# %%
########################################
##  8. 정량적 성능 평가 (다중 샘플)  ##
########################################

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION")
print("="*70)

# 테스트 파라미터
NUM_TEST_SAMPLES = 100  # 테스트할 샘플 수
TEST_SNR_LEVELS = [-25, -20, -15, -10, -5]  # 다양한 SNR 레벨

results = {snr: {'correct': 0, 'total': 0, 'mse': [], 'peak_ratio': []} for snr in TEST_SNR_LEVELS}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        # 랜덤 심볼 선택
        test_sym = np.random.randint(0, 512)
        
        # 1. 클린 IQ
        clean_iq_test = X_clean_iq[test_sym]
        
        # 2. 노이즈 추가
        noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
        
        # 3. Complex 스펙트로그램 생성
        noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
        
        # 4. BAMv3 복원 (compress -> decompress)
        compressed = model.compress(noisy_flat.reshape(1, -1))
        restored_flat = model.decompress(compressed).flatten()
        
        # 5. 역변환
        mid = len(restored_flat) // 2
        real_restored_norm = restored_flat[:mid].reshape(noisy_params['shape'])
        imag_restored_norm = restored_flat[mid:].reshape(noisy_params['shape'])
        
        # 역정규화
        real_restored = real_restored_norm * (noisy_params['r_max'] - noisy_params['r_min']) + noisy_params['r_min']
        imag_restored = imag_restored_norm * (noisy_params['i_max'] - noisy_params['i_min']) + noisy_params['i_min']
        
        # Complex 재결합
        Zxx_restored = real_restored + 1j * imag_restored
        
        # 6. 역 STFT
        # ⭐ Step 1: Zero-padding으로 원래 주파수 크기 복원
        Zxx_full = np.zeros(noisy_params['original_shape'], dtype=complex)
        Zxx_full[noisy_params['freq_indices'], :] = Zxx_restored

        # ⭐ Step 2: 주파수 축 언시프트
        Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

        # ⭐ Step 3: STFT와 동일한 파라미터로 ISTFT 수행
        
        iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)
        
        # 7. 길이 맞추기
        target_len = len(clean_iq_test)
        if len(iq_restored) != target_len:
            iq_restored = resample(iq_restored, target_len)
        
        # 7. Dechirp
        try:
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, "clean", sf, fs, bw)
            code_restored, peak_restored = estimate_symbol_custom(iq_restored, "restored", sf, fs, bw)
            
            # 정확도 체크
            if code_restored == test_sym:
                results[snr]['correct'] += 1
            results[snr]['total'] += 1
            
            # Peak ratio
            if peak_clean > 0:
                results[snr]['peak_ratio'].append(peak_restored / peak_clean)
            
            # MSE 계산
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['total'] += 1
    
    # 중간 결과 출력
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"  ✓ Accuracy: {results[snr]['correct']}/{results[snr]['total']} = {acc:.1f}%")
    print(f"  ✓ Avg MSE: {avg_mse:.6f}")
    print(f"  ✓ Avg Peak Ratio: {avg_peak:.2%}")

# 최종 결과 요약
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)

print(f"\n{'SNR (dB)':<10} {'Accuracy':<15} {'MSE':<15} {'Peak Ratio':<15}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    acc = results[snr]['correct'] / results[snr]['total'] * 100
    avg_mse = np.mean(results[snr]['mse']) if results[snr]['mse'] else 0
    avg_peak = np.mean(results[snr]['peak_ratio']) if results[snr]['peak_ratio'] else 0
    
    print(f"{snr:<10} {acc:>6.1f}%{'':<8} {avg_mse:>8.6f}{'':<6} {avg_peak:>6.1%}{'':<8}")

# 전체 평균
total_correct = sum(r['correct'] for r in results.values())
total_samples = sum(r['total'] for r in results.values())
overall_acc = total_correct / total_samples * 100

print("─"*70)
print(f"{'Overall':<10} {overall_acc:>6.1f}%")
print("="*70)

# 시각화
plt.figure(figsize=(15, 4))

# 1. Accuracy vs SNR
plt.subplot(1, 3, 1)
snrs = TEST_SNR_LEVELS
accs = [results[snr]['correct'] / results[snr]['total'] * 100 for snr in snrs]
plt.plot(snrs, accs, 'o-', linewidth=2, markersize=8)
plt.xlabel('SNR (dB)')
plt.ylabel('Accuracy (%)')
plt.title('Symbol Classification Accuracy')
plt.grid(True, alpha=0.3)
plt.ylim([0, 105])

# 2. MSE vs SNR
plt.subplot(1, 3, 2)
mses = [np.mean(results[snr]['mse']) for snr in snrs]
plt.plot(snrs, mses, 's-', linewidth=2, markersize=8, color='orange')
plt.xlabel('SNR (dB)')
plt.ylabel('MSE')
plt.title('Reconstruction MSE')
plt.grid(True, alpha=0.3)
plt.yscale('log')

# 3. Peak Ratio vs SNR
plt.subplot(1, 3, 3)
peaks = [np.mean(results[snr]['peak_ratio']) * 100 for snr in snrs]
plt.plot(snrs, peaks, '^-', linewidth=2, markersize=8, color='green')
plt.xlabel('SNR (dB)')
plt.ylabel('Peak Ratio (%)')
plt.title('Peak Recovery Ratio')
plt.grid(True, alpha=0.3)
plt.axhline(y=100, color='r', linestyle='--', alpha=0.5, label='Perfect (100%)')
plt.legend()

plt.tight_layout()
plt.show()

print(f"\n✅ Quantitative evaluation complete!")
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION
# ======================================================================
#
# 🧪 Testing with 100 samples at each SNR level...
# SNR levels: [-25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 0/100 = 0.0%
#   ✓ Avg MSE: 1.006159
#   ✓ Avg Peak Ratio: 4.20%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 0/100 = 0.0%
#   ✓ Avg MSE: 1.001921
#   ✓ Avg Peak Ratio: 3.83%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 4/100 = 4.0%
#   ✓ Avg MSE: 1.000598
#   ✓ Avg Peak Ratio: 1.35%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 3/100 = 3.0%
#   ✓ Avg MSE: 1.000271
#   ✓ Avg Peak Ratio: 3.14%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Accuracy: 4/100 = 4.0%
#   ✓ Avg MSE: 1.000176
#   ✓ Avg Peak Ratio: 0.73%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR (dB)   Accuracy        MSE             Peak Ratio
# ──────────────────────────────────────────────────────────────────────
# -25           0.0%         1.006159         4.2%
# -20           0.0%         1.001921         3.8%
# -15           4.0%         1.000598         1.4%
# -10           3.0%         1.000271         3.1%
# -5            4.0%         1.000176         0.7%
# ──────────────────────────────────────────────────────────────────────
# Overall       2.2%
# ======================================================================
# ✅ Quantitative evaluation complete!
