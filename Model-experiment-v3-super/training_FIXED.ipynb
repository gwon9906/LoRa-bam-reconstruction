# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거
# - 노이즈 범위 줄임(5~-5db)

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'nfft': 512,      
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    nfft     = STFT_PARAMS['nfft']  # <--- 변수 가져오기
    window   = STFT_PARAMS['window']

    # 2. stft 호출 시 nfft 전달
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        nfft=nfft,              # <--- 꼭 넣어주세요!
        boundary=None,
        padded=False,
        return_onesided=False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        nfft=stft_params['nfft'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf=sf, bw=bw, OSF=OSF)
fs = lora.fs   # = bw * OSF
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (SNR에 집중)
SNR_MIN = -7.5
SNR_MAX = 0
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)
    
    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")
    
    X_noisy_flat_list = []
    norm_params_list = []
    
    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)
            
            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)
            
            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)
    
    X_noisy_flat = np.array(X_noisy_flat_list)
    
    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")
    
    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 4096, 2048, 512]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (128, 31)
# Input dim (Real+Imag): 7936
# Model architecture: 7936 → 4096 → 2048 → 512
# Compression ratio: 15.5x
# Layers: 3 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")
    
    # 학습 파라미터
    num_epochs = 30
    batch_size = 64
    
    all_layer_losses = [[] for _ in range(len(layers)-1)]
    
    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")
        
        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)
        
        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)
        
        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)
    
    print("\n=== Training Complete ===")
    
    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]
    
    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)
    
    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 7936 → 4096 → 2048 → 512
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
#
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.017817
# Epoch 1, Batch 2/240, MSE = 0.012134
# Epoch 1, Batch 3/240, MSE = 0.011685
# Epoch 1, Batch 4/240, MSE = 0.011812
# Epoch 1, Batch 5/240, MSE = 0.011708
# Epoch 1, Batch 6/240, MSE = 0.011472
# Epoch 1, Batch 7/240, MSE = 0.012169
# Epoch 1, Batch 8/240, MSE = 0.011876
# Epoch 1, Batch 9/240, MSE = 0.012040
# Epoch 1, Batch 10/240, MSE = 0.011704
# Epoch 1, Batch 11/240, MSE = 0.011530
# Epoch 1, Batch 12/240, MSE = 0.011952
# Epoch 1, Batch 13/240, MSE = 0.012062
# Epoch 1, Batch 14/240, MSE = 0.011784
# Epoch 1, Batch 15/240, MSE = 0.011708
# Epoch 1, Batch 16/240, MSE = 0.011345
# Epoch 1, Batch 17/240, MSE = 0.011480
# Epoch 1, Batch 18/240, MSE = 0.011827
# Epoch 1, Batch 19/240, MSE = 0.011729
# Epoch 1, Batch 20/240, MSE = 0.011768
# Epoch 1, Batch 21/240, MSE = 0.011662
# Epoch 1, Batch 22/240, MSE = 0.011697
# Epoch 1, Batch 23/240, MSE = 0.011060
# Epoch 1, Batch 24/240, MSE = 0.010887
# Epoch 1, Batch 25/240, MSE = 0.011701
# Epoch 1, Batch 26/240, MSE = 0.011400
# Epoch 1, Batch 27/240, MSE = 0.011013
# Epoch 1, Batch 28/240, MSE = 0.011515
# Epoch 1, Batch 29/240, MSE = 0.011439
# Epoch 1, Batch 30/240, MSE = 0.011489
# Epoch 1, Batch 31/240, MSE = 0.011645
# Epoch 1, Batch 32/240, MSE = 0.011059
# Epoch 1, Batch 33/240, MSE = 0.011257
# Epoch 1, Batch 34/240, MSE = 0.011336
# Epoch 1, Batch 35/240, MSE = 0.011324
# Epoch 1, Batch 36/240, MSE = 0.011137
# Epoch 1, Batch 37/240, MSE = 0.011289
# Epoch 1, Batch 38/240, MSE = 0.010918
# Epoch 1, Batch 39/240, MSE = 0.011135
# Epoch 1, Batch 40/240, MSE = 0.011197
# Epoch 1, Batch 41/240, MSE = 0.011129
# Epoch 1, Batch 42/240, MSE = 0.010972
# Epoch 1, Batch 43/240, MSE = 0.010987
# Epoch 1, Batch 44/240, MSE = 0.010837
# Epoch 1, Batch 45/240, MSE = 0.010724
# Epoch 1, Batch 46/240, MSE = 0.010985
# Epoch 1, Batch 47/240, MSE = 0.011122
# Epoch 1, Batch 48/240, MSE = 0.010775
# Epoch 1, Batch 49/240, MSE = 0.011042
# Epoch 1, Batch 50/240, MSE = 0.010992
# Epoch 1, Batch 51/240, MSE = 0.010677
# Epoch 1, Batch 52/240, MSE = 0.011108
# Epoch 1, Batch 53/240, MSE = 0.010931
# Epoch 1, Batch 54/240, MSE = 0.010804
# Epoch 1, Batch 55/240, MSE = 0.010721
# Epoch 1, Batch 56/240, MSE = 0.010960
# Epoch 1, Batch 57/240, MSE = 0.010742
# Epoch 1, Batch 58/240, MSE = 0.010864
# Epoch 1, Batch 59/240, MSE = 0.011200
# Epoch 1, Batch 60/240, MSE = 0.010925
# Epoch 1, Batch 61/240, MSE = 0.010621
# Epoch 1, Batch 62/240, MSE = 0.010799
# Epoch 1, Batch 63/240, MSE = 0.010587
# Epoch 1, Batch 64/240, MSE = 0.010461
# Epoch 1, Batch 65/240, MSE = 0.010883
# Epoch 1, Batch 66/240, MSE = 0.010498
# Epoch 1, Batch 67/240, MSE = 0.010623
# Epoch 1, Batch 68/240, MSE = 0.011365
# Epoch 1, Batch 69/240, MSE = 0.010618
# Epoch 1, Batch 70/240, MSE = 0.010659
# Epoch 1, Batch 71/240, MSE = 0.011003
# Epoch 1, Batch 72/240, MSE = 0.010674
# Epoch 1, Batch 73/240, MSE = 0.010278
# Epoch 1, Batch 74/240, MSE = 0.010597
# Epoch 1, Batch 75/240, MSE = 0.010562
# Epoch 1, Batch 76/240, MSE = 0.010423
# Epoch 1, Batch 77/240, MSE = 0.010436
# Epoch 1, Batch 78/240, MSE = 0.010168
# Epoch 1, Batch 79/240, MSE = 0.010334
# Epoch 1, Batch 80/240, MSE = 0.010290
# Epoch 1, Batch 81/240, MSE = 0.010372
# Epoch 1, Batch 82/240, MSE = 0.010529
# Epoch 1, Batch 83/240, MSE = 0.011044
# Epoch 1, Batch 84/240, MSE = 0.010072
# Epoch 1, Batch 85/240, MSE = 0.010238
# Epoch 1, Batch 86/240, MSE = 0.010483
# Epoch 1, Batch 87/240, MSE = 0.010438
# Epoch 1, Batch 88/240, MSE = 0.010636
# Epoch 1, Batch 89/240, MSE = 0.010214
# Epoch 1, Batch 90/240, MSE = 0.010310
# Epoch 1, Batch 91/240, MSE = 0.010559
# Epoch 1, Batch 92/240, MSE = 0.010085
# Epoch 1, Batch 93/240, MSE = 0.010475
# Epoch 1, Batch 94/240, MSE = 0.010213
# Epoch 1, Batch 95/240, MSE = 0.010159
# Epoch 1, Batch 96/240, MSE = 0.009934
# Epoch 1, Batch 97/240, MSE = 0.009889
# Epoch 1, Batch 98/240, MSE = 0.009878
# Epoch 1, Batch 99/240, MSE = 0.010274
# Epoch 1, Batch 100/240, MSE = 0.009965
# Epoch 1, Batch 101/240, MSE = 0.009892
# Epoch 1, Batch 102/240, MSE = 0.009662
# Epoch 1, Batch 103/240, MSE = 0.009949
# Epoch 1, Batch 104/240, MSE = 0.009823
# Epoch 1, Batch 105/240, MSE = 0.009839
# Epoch 1, Batch 106/240, MSE = 0.009742
# Epoch 1, Batch 107/240, MSE = 0.009987
# Epoch 1, Batch 108/240, MSE = 0.009943
# Epoch 1, Batch 109/240, MSE = 0.010119
# Epoch 1, Batch 110/240, MSE = 0.009940
# Epoch 1, Batch 111/240, MSE = 0.009502
# Epoch 1, Batch 112/240, MSE = 0.009753
# Epoch 1, Batch 113/240, MSE = 0.009709
# Epoch 1, Batch 114/240, MSE = 0.009709
# Epoch 1, Batch 115/240, MSE = 0.009440
# Epoch 1, Batch 116/240, MSE = 0.009596
# Epoch 1, Batch 117/240, MSE = 0.009382
# Epoch 1, Batch 118/240, MSE = 0.009875
# Epoch 1, Batch 119/240, MSE = 0.009843
# Epoch 1, Batch 120/240, MSE = 0.009618
# Epoch 1, Batch 121/240, MSE = 0.009516
# Epoch 1, Batch 122/240, MSE = 0.009439
# Epoch 1, Batch 123/240, MSE = 0.009622
# Epoch 1, Batch 124/240, MSE = 0.009540
# Epoch 1, Batch 125/240, MSE = 0.009478
# Epoch 1, Batch 126/240, MSE = 0.009746
# Epoch 1, Batch 127/240, MSE = 0.009523
# Epoch 1, Batch 128/240, MSE = 0.009240
# Epoch 1, Batch 129/240, MSE = 0.009813
# Epoch 1, Batch 130/240, MSE = 0.009472
# Epoch 1, Batch 131/240, MSE = 0.009210
# Epoch 1, Batch 132/240, MSE = 0.009728
# Epoch 1, Batch 133/240, MSE = 0.009514
# Epoch 1, Batch 134/240, MSE = 0.009312
# Epoch 1, Batch 135/240, MSE = 0.009392
# Epoch 1, Batch 136/240, MSE = 0.009850
# Epoch 1, Batch 137/240, MSE = 0.009262
# Epoch 1, Batch 138/240, MSE = 0.009644
# Epoch 1, Batch 139/240, MSE = 0.009506
# Epoch 1, Batch 140/240, MSE = 0.009359
# Epoch 1, Batch 141/240, MSE = 0.009446
# Epoch 1, Batch 142/240, MSE = 0.009304
# Epoch 1, Batch 143/240, MSE = 0.009493
# Epoch 1, Batch 144/240, MSE = 0.009057
# Epoch 1, Batch 145/240, MSE = 0.009178
# Epoch 1, Batch 146/240, MSE = 0.008908
# Epoch 1, Batch 147/240, MSE = 0.008822
# Epoch 1, Batch 148/240, MSE = 0.009139
# Epoch 1, Batch 149/240, MSE = 0.009415
# Epoch 1, Batch 150/240, MSE = 0.009230
# Epoch 1, Batch 151/240, MSE = 0.009045
# Epoch 1, Batch 152/240, MSE = 0.009093
# Epoch 1, Batch 153/240, MSE = 0.009223
# Epoch 1, Batch 154/240, MSE = 0.009382
# Epoch 1, Batch 155/240, MSE = 0.009083
# Epoch 1, Batch 156/240, MSE = 0.009246
# Epoch 1, Batch 157/240, MSE = 0.009247
# Epoch 1, Batch 158/240, MSE = 0.008889
# Epoch 1, Batch 159/240, MSE = 0.008917
# Epoch 1, Batch 160/240, MSE = 0.008956
# Epoch 1, Batch 161/240, MSE = 0.008693
# Epoch 1, Batch 162/240, MSE = 0.009039
# Epoch 1, Batch 163/240, MSE = 0.008936
# Epoch 1, Batch 164/240, MSE = 0.008722
# Epoch 1, Batch 165/240, MSE = 0.008690
# Epoch 1, Batch 166/240, MSE = 0.008664
# Epoch 1, Batch 167/240, MSE = 0.008929
# Epoch 1, Batch 168/240, MSE = 0.008495
# Epoch 1, Batch 169/240, MSE = 0.008389
# Epoch 1, Batch 170/240, MSE = 0.008434
# Epoch 1, Batch 171/240, MSE = 0.008695
# Epoch 1, Batch 172/240, MSE = 0.008728
# Epoch 1, Batch 173/240, MSE = 0.008624
# Epoch 1, Batch 174/240, MSE = 0.008534
# Epoch 1, Batch 175/240, MSE = 0.008586
# Epoch 1, Batch 176/240, MSE = 0.008763
# Epoch 1, Batch 177/240, MSE = 0.008554
# Epoch 1, Batch 178/240, MSE = 0.008717
# Epoch 1, Batch 179/240, MSE = 0.008706
# Epoch 1, Batch 180/240, MSE = 0.008409
# Epoch 1, Batch 181/240, MSE = 0.008539
# Epoch 1, Batch 182/240, MSE = 0.008307
# Epoch 1, Batch 183/240, MSE = 0.008490
# Epoch 1, Batch 184/240, MSE = 0.008248
# Epoch 1, Batch 185/240, MSE = 0.008551
# Epoch 1, Batch 186/240, MSE = 0.008145
# Epoch 1, Batch 187/240, MSE = 0.008290
# Epoch 1, Batch 188/240, MSE = 0.008342
# Epoch 1, Batch 189/240, MSE = 0.008121
# Epoch 1, Batch 190/240, MSE = 0.008249
# Epoch 1, Batch 191/240, MSE = 0.008250
# Epoch 1, Batch 192/240, MSE = 0.008222
# Epoch 1, Batch 193/240, MSE = 0.008373
# Epoch 1, Batch 194/240, MSE = 0.008133
# Epoch 1, Batch 195/240, MSE = 0.008149
# Epoch 1, Batch 196/240, MSE = 0.008227
# Epoch 1, Batch 197/240, MSE = 0.008094
# Epoch 1, Batch 198/240, MSE = 0.008143
# Epoch 1, Batch 199/240, MSE = 0.008219
# Epoch 1, Batch 200/240, MSE = 0.009608
# Epoch 1, Batch 201/240, MSE = 0.008092
# Epoch 1, Batch 202/240, MSE = 0.007925
# Epoch 1, Batch 203/240, MSE = 0.007901
# Epoch 1, Batch 204/240, MSE = 0.008227
# Epoch 1, Batch 205/240, MSE = 0.008087
# Epoch 1, Batch 206/240, MSE = 0.008045
# Epoch 1, Batch 207/240, MSE = 0.007961
# Epoch 1, Batch 208/240, MSE = 0.007823
# Epoch 1, Batch 209/240, MSE = 0.007680
# Epoch 1, Batch 210/240, MSE = 0.008098
# Epoch 1, Batch 211/240, MSE = 0.007857
# Epoch 1, Batch 212/240, MSE = 0.007722
# Epoch 1, Batch 213/240, MSE = 0.007842
# Epoch 1, Batch 214/240, MSE = 0.007808
# Epoch 1, Batch 215/240, MSE = 0.007879
# Epoch 1, Batch 216/240, MSE = 0.008008
# Epoch 1, Batch 217/240, MSE = 0.007556
# Epoch 1, Batch 218/240, MSE = 0.007722
# Epoch 1, Batch 219/240, MSE = 0.007732
# Epoch 1, Batch 220/240, MSE = 0.008015
# Epoch 1, Batch 221/240, MSE = 0.007841
# Epoch 1, Batch 222/240, MSE = 0.007648
# Epoch 1, Batch 223/240, MSE = 0.007767
# Epoch 1, Batch 224/240, MSE = 0.007698
# Epoch 1, Batch 225/240, MSE = 0.007632
# Epoch 1, Batch 226/240, MSE = 0.007213
# Epoch 1, Batch 227/240, MSE = 0.007690
# Epoch 1, Batch 228/240, MSE = 0.007582
# Epoch 1, Batch 229/240, MSE = 0.007237
# Epoch 1, Batch 230/240, MSE = 0.007610
# Epoch 1, Batch 231/240, MSE = 0.007820
# Epoch 1, Batch 232/240, MSE = 0.007600
# Epoch 1, Batch 233/240, MSE = 0.007330
# Epoch 1, Batch 234/240, MSE = 0.007496
# Epoch 1, Batch 235/240, MSE = 0.007473
# Epoch 1, Batch 236/240, MSE = 0.007163
# Epoch 1, Batch 237/240, MSE = 0.007154
# Epoch 1, Batch 238/240, MSE = 0.007258
# Epoch 1, Batch 239/240, MSE = 0.007077
# Epoch 1, Batch 240/240, MSE = 0.007195
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.025302
# Epoch 1, Batch 2/240, MSE = 0.010719
# Epoch 1, Batch 3/240, MSE = 0.011228
# Epoch 1, Batch 4/240, MSE = 0.011056
# Epoch 1, Batch 5/240, MSE = 0.010341
# Epoch 1, Batch 6/240, MSE = 0.010877
# Epoch 1, Batch 7/240, MSE = 0.010730
# Epoch 1, Batch 8/240, MSE = 0.010281
# Epoch 1, Batch 9/240, MSE = 0.010355
# Epoch 1, Batch 10/240, MSE = 0.010212
# Epoch 1, Batch 11/240, MSE = 0.010304
# Epoch 1, Batch 12/240, MSE = 0.010707
# Epoch 1, Batch 13/240, MSE = 0.010044
# Epoch 1, Batch 14/240, MSE = 0.010058
# Epoch 1, Batch 15/240, MSE = 0.010248
# Epoch 1, Batch 16/240, MSE = 0.010234
# Epoch 1, Batch 17/240, MSE = 0.010215
# Epoch 1, Batch 18/240, MSE = 0.010174
# Epoch 1, Batch 19/240, MSE = 0.010318
# Epoch 1, Batch 20/240, MSE = 0.009419
# Epoch 1, Batch 21/240, MSE = 0.009757
# Epoch 1, Batch 22/240, MSE = 0.009721
# Epoch 1, Batch 23/240, MSE = 0.009851
# Epoch 1, Batch 24/240, MSE = 0.009733
# Epoch 1, Batch 25/240, MSE = 0.009625
# Epoch 1, Batch 26/240, MSE = 0.009531
# Epoch 1, Batch 27/240, MSE = 0.009640
# Epoch 1, Batch 28/240, MSE = 0.009669
# Epoch 1, Batch 29/240, MSE = 0.009596
# Epoch 1, Batch 30/240, MSE = 0.009534
# Epoch 1, Batch 31/240, MSE = 0.009506
# Epoch 1, Batch 32/240, MSE = 0.009626
# Epoch 1, Batch 33/240, MSE = 0.009565
# Epoch 1, Batch 34/240, MSE = 0.009739
# Epoch 1, Batch 35/240, MSE = 0.009715
# Epoch 1, Batch 36/240, MSE = 0.009527
# Epoch 1, Batch 37/240, MSE = 0.009538
# Epoch 1, Batch 38/240, MSE = 0.009548
# Epoch 1, Batch 39/240, MSE = 0.009938
# Epoch 1, Batch 40/240, MSE = 0.009543
# Epoch 1, Batch 41/240, MSE = 0.009631
# Epoch 1, Batch 42/240, MSE = 0.009695
# Epoch 1, Batch 43/240, MSE = 0.009568
# Epoch 1, Batch 44/240, MSE = 0.009659
# Epoch 1, Batch 45/240, MSE = 0.009480
# Epoch 1, Batch 46/240, MSE = 0.009569
# Epoch 1, Batch 47/240, MSE = 0.009536
# Epoch 1, Batch 48/240, MSE = 0.009600
# Epoch 1, Batch 49/240, MSE = 0.009620
# Epoch 1, Batch 50/240, MSE = 0.009330
# Epoch 1, Batch 51/240, MSE = 0.009415
# Epoch 1, Batch 52/240, MSE = 0.009485
# Epoch 1, Batch 53/240, MSE = 0.009289
# Epoch 1, Batch 54/240, MSE = 0.009383
# Epoch 1, Batch 55/240, MSE = 0.009503
# Epoch 1, Batch 56/240, MSE = 0.009503
# Epoch 1, Batch 57/240, MSE = 0.009510
# Epoch 1, Batch 58/240, MSE = 0.009369
# Epoch 1, Batch 59/240, MSE = 0.009338
# Epoch 1, Batch 60/240, MSE = 0.009335
# Epoch 1, Batch 61/240, MSE = 0.009505
# Epoch 1, Batch 62/240, MSE = 0.009574
# Epoch 1, Batch 63/240, MSE = 0.009597
# Epoch 1, Batch 64/240, MSE = 0.009479
# Epoch 1, Batch 65/240, MSE = 0.009495
# Epoch 1, Batch 66/240, MSE = 0.009259
# Epoch 1, Batch 67/240, MSE = 0.009749
# Epoch 1, Batch 68/240, MSE = 0.009563
# Epoch 1, Batch 69/240, MSE = 0.009306
# Epoch 1, Batch 70/240, MSE = 0.009271
# Epoch 1, Batch 71/240, MSE = 0.009545
# Epoch 1, Batch 72/240, MSE = 0.009413
# Epoch 1, Batch 73/240, MSE = 0.009279
# Epoch 1, Batch 74/240, MSE = 0.009265
# Epoch 1, Batch 75/240, MSE = 0.009621
# Epoch 1, Batch 76/240, MSE = 0.009391
# Epoch 1, Batch 77/240, MSE = 0.009622
# Epoch 1, Batch 78/240, MSE = 0.009603
# Epoch 1, Batch 79/240, MSE = 0.009451
# Epoch 1, Batch 80/240, MSE = 0.009478
# Epoch 1, Batch 81/240, MSE = 0.009611
# Epoch 1, Batch 82/240, MSE = 0.009207
# Epoch 1, Batch 83/240, MSE = 0.009566
# Epoch 1, Batch 84/240, MSE = 0.009181
# Epoch 1, Batch 85/240, MSE = 0.009173
# Epoch 1, Batch 86/240, MSE = 0.009460
# Epoch 1, Batch 87/240, MSE = 0.009541
# Epoch 1, Batch 88/240, MSE = 0.009196
# Epoch 1, Batch 89/240, MSE = 0.009373
# Epoch 1, Batch 90/240, MSE = 0.009448
# Epoch 1, Batch 91/240, MSE = 0.009259
# Epoch 1, Batch 92/240, MSE = 0.009159
# Epoch 1, Batch 93/240, MSE = 0.009734
# Epoch 1, Batch 94/240, MSE = 0.009287
# Epoch 1, Batch 95/240, MSE = 0.009351
# Epoch 1, Batch 96/240, MSE = 0.009337
# Epoch 1, Batch 97/240, MSE = 0.009114
# Epoch 1, Batch 98/240, MSE = 0.009436
# Epoch 1, Batch 99/240, MSE = 0.009204
# Epoch 1, Batch 100/240, MSE = 0.009203
# Epoch 1, Batch 101/240, MSE = 0.009095
# Epoch 1, Batch 102/240, MSE = 0.008875
# Epoch 1, Batch 103/240, MSE = 0.009158
# Epoch 1, Batch 104/240, MSE = 0.009186
# Epoch 1, Batch 105/240, MSE = 0.009197
# Epoch 1, Batch 106/240, MSE = 0.008946
# Epoch 1, Batch 107/240, MSE = 0.009144
# Epoch 1, Batch 108/240, MSE = 0.009314
# Epoch 1, Batch 109/240, MSE = 0.009251
# Epoch 1, Batch 110/240, MSE = 0.009753
# Epoch 1, Batch 111/240, MSE = 0.009078
# Epoch 1, Batch 112/240, MSE = 0.009028
# Epoch 1, Batch 113/240, MSE = 0.009050
# Epoch 1, Batch 114/240, MSE = 0.009263
# Epoch 1, Batch 115/240, MSE = 0.009366
# Epoch 1, Batch 116/240, MSE = 0.009486
# Epoch 1, Batch 117/240, MSE = 0.009270
# Epoch 1, Batch 118/240, MSE = 0.009496
# Epoch 1, Batch 119/240, MSE = 0.009522
# Epoch 1, Batch 120/240, MSE = 0.009514
# Epoch 1, Batch 121/240, MSE = 0.009062
# Epoch 1, Batch 122/240, MSE = 0.009275
# Epoch 1, Batch 123/240, MSE = 0.009131
# Epoch 1, Batch 124/240, MSE = 0.009183
# Epoch 1, Batch 125/240, MSE = 0.009250
# Epoch 1, Batch 126/240, MSE = 0.009061
# Epoch 1, Batch 127/240, MSE = 0.009195
# Epoch 1, Batch 128/240, MSE = 0.009277
# Epoch 1, Batch 129/240, MSE = 0.009110
# Epoch 1, Batch 130/240, MSE = 0.009323
# Epoch 1, Batch 131/240, MSE = 0.009125
# Epoch 1, Batch 132/240, MSE = 0.009348
# Epoch 1, Batch 133/240, MSE = 0.008977
# Epoch 1, Batch 134/240, MSE = 0.009189
# Epoch 1, Batch 135/240, MSE = 0.009090
# Epoch 1, Batch 136/240, MSE = 0.009127
# Epoch 1, Batch 137/240, MSE = 0.009096
# Epoch 1, Batch 138/240, MSE = 0.009078
# Epoch 1, Batch 139/240, MSE = 0.009262
# Epoch 1, Batch 140/240, MSE = 0.008691
# Epoch 1, Batch 141/240, MSE = 0.009133
# Epoch 1, Batch 142/240, MSE = 0.009337
# Epoch 1, Batch 143/240, MSE = 0.009175
# Epoch 1, Batch 144/240, MSE = 0.008853
# Epoch 1, Batch 145/240, MSE = 0.008849
# Epoch 1, Batch 146/240, MSE = 0.009007
# Epoch 1, Batch 147/240, MSE = 0.009083
# Epoch 1, Batch 148/240, MSE = 0.009118
# Epoch 1, Batch 149/240, MSE = 0.009094
# Epoch 1, Batch 150/240, MSE = 0.008782
# Epoch 1, Batch 151/240, MSE = 0.009052
# Epoch 1, Batch 152/240, MSE = 0.009219
# Epoch 1, Batch 153/240, MSE = 0.009223
# Epoch 1, Batch 154/240, MSE = 0.009162
# Epoch 1, Batch 155/240, MSE = 0.009103
# Epoch 1, Batch 156/240, MSE = 0.009618
# Epoch 1, Batch 157/240, MSE = 0.009157
# Epoch 1, Batch 158/240, MSE = 0.008981
# Epoch 1, Batch 159/240, MSE = 0.009133
# Epoch 1, Batch 160/240, MSE = 0.008846
# Epoch 1, Batch 161/240, MSE = 0.008771
# Epoch 1, Batch 162/240, MSE = 0.008943
# Epoch 1, Batch 163/240, MSE = 0.009306
# Epoch 1, Batch 164/240, MSE = 0.008969
# Epoch 1, Batch 165/240, MSE = 0.008944
# Epoch 1, Batch 166/240, MSE = 0.009099
# Epoch 1, Batch 167/240, MSE = 0.009010
# Epoch 1, Batch 168/240, MSE = 0.009060
# Epoch 1, Batch 169/240, MSE = 0.008887
# Epoch 1, Batch 170/240, MSE = 0.009215
# Epoch 1, Batch 171/240, MSE = 0.009132
# Epoch 1, Batch 172/240, MSE = 0.008850
# Epoch 1, Batch 173/240, MSE = 0.009028
# Epoch 1, Batch 174/240, MSE = 0.009074
# Epoch 1, Batch 175/240, MSE = 0.008830
# Epoch 1, Batch 176/240, MSE = 0.008940
# Epoch 1, Batch 177/240, MSE = 0.008838
# Epoch 1, Batch 178/240, MSE = 0.008864
# Epoch 1, Batch 179/240, MSE = 0.008924
# Epoch 1, Batch 180/240, MSE = 0.008763
# Epoch 1, Batch 181/240, MSE = 0.008567
# Epoch 1, Batch 182/240, MSE = 0.008894
# Epoch 1, Batch 183/240, MSE = 0.008917
# Epoch 1, Batch 184/240, MSE = 0.008726
# Epoch 1, Batch 185/240, MSE = 0.008640
# Epoch 1, Batch 186/240, MSE = 0.009459
# Epoch 1, Batch 187/240, MSE = 0.011305
# Epoch 1, Batch 188/240, MSE = 0.009893
# Epoch 1, Batch 189/240, MSE = 0.009154
# Epoch 1, Batch 190/240, MSE = 0.008886
# Epoch 1, Batch 191/240, MSE = 0.008674
# Epoch 1, Batch 192/240, MSE = 0.008788
# Epoch 1, Batch 193/240, MSE = 0.008831
# Epoch 1, Batch 194/240, MSE = 0.009056
# Epoch 1, Batch 195/240, MSE = 0.009472
# Epoch 1, Batch 196/240, MSE = 0.009427
# Epoch 1, Batch 197/240, MSE = 0.008721
# Epoch 1, Batch 198/240, MSE = 0.008718
# Epoch 1, Batch 199/240, MSE = 0.008609
# Epoch 1, Batch 200/240, MSE = 0.008675
# Epoch 1, Batch 201/240, MSE = 0.008757
# Epoch 1, Batch 202/240, MSE = 0.008780
# Epoch 1, Batch 203/240, MSE = 0.008703
# Epoch 1, Batch 204/240, MSE = 0.008907
# Epoch 1, Batch 205/240, MSE = 0.008963
# Epoch 1, Batch 206/240, MSE = 0.008456
# Epoch 1, Batch 207/240, MSE = 0.008632
# Epoch 1, Batch 208/240, MSE = 0.008631
# Epoch 1, Batch 209/240, MSE = 0.008805
# Epoch 1, Batch 210/240, MSE = 0.008825
# Epoch 1, Batch 211/240, MSE = 0.009361
# Epoch 1, Batch 212/240, MSE = 0.008723
# Epoch 1, Batch 213/240, MSE = 0.008698
# Epoch 1, Batch 214/240, MSE = 0.008628
# Epoch 1, Batch 215/240, MSE = 0.008666
# Epoch 1, Batch 216/240, MSE = 0.008435
# Epoch 1, Batch 217/240, MSE = 0.008533
# Epoch 1, Batch 218/240, MSE = 0.008563
# Epoch 1, Batch 219/240, MSE = 0.008684
# Epoch 1, Batch 220/240, MSE = 0.008507
# Epoch 1, Batch 221/240, MSE = 0.008680
# Epoch 1, Batch 222/240, MSE = 0.008741
# Epoch 1, Batch 223/240, MSE = 0.008851
# Epoch 1, Batch 224/240, MSE = 0.009243
# Epoch 1, Batch 225/240, MSE = 0.009922
# Epoch 1, Batch 226/240, MSE = 0.009510
# Epoch 1, Batch 227/240, MSE = 0.008447
# Epoch 1, Batch 228/240, MSE = 0.008498
# Epoch 1, Batch 229/240, MSE = 0.008609
# Epoch 1, Batch 230/240, MSE = 0.008581
# Epoch 1, Batch 231/240, MSE = 0.008378
# Epoch 1, Batch 232/240, MSE = 0.008543
# Epoch 1, Batch 233/240, MSE = 0.008928
# Epoch 1, Batch 234/240, MSE = 0.008320
# Epoch 1, Batch 235/240, MSE = 0.008436
# Epoch 1, Batch 236/240, MSE = 0.008705
# Epoch 1, Batch 237/240, MSE = 0.008511
# Epoch 1, Batch 238/240, MSE = 0.008388
# Epoch 1, Batch 239/240, MSE = 0.008564
# Epoch 1, Batch 240/240, MSE = 0.008376
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.046942
# Epoch 1, Batch 2/240, MSE = 0.004697
# Epoch 1, Batch 3/240, MSE = 0.005323
# Epoch 1, Batch 4/240, MSE = 0.004684
# Epoch 1, Batch 5/240, MSE = 0.005169
# Epoch 1, Batch 6/240, MSE = 0.004786
# Epoch 1, Batch 7/240, MSE = 0.004597
# Epoch 1, Batch 8/240, MSE = 0.005041
# Epoch 1, Batch 9/240, MSE = 0.005746
# Epoch 1, Batch 10/240, MSE = 0.005545
# Epoch 1, Batch 11/240, MSE = 0.006812
# Epoch 1, Batch 12/240, MSE = 0.005395
# Epoch 1, Batch 13/240, MSE = 0.005104
# Epoch 1, Batch 14/240, MSE = 0.004331
# Epoch 1, Batch 15/240, MSE = 0.008069
# Epoch 1, Batch 16/240, MSE = 0.005886
# Epoch 1, Batch 17/240, MSE = 0.004663
# Epoch 1, Batch 18/240, MSE = 0.003996
# Epoch 1, Batch 19/240, MSE = 0.003835
# Epoch 1, Batch 20/240, MSE = 0.004059
# Epoch 1, Batch 21/240, MSE = 0.004079
# Epoch 1, Batch 22/240, MSE = 0.003998
# Epoch 1, Batch 23/240, MSE = 0.003917
# Epoch 1, Batch 24/240, MSE = 0.003952
# Epoch 1, Batch 25/240, MSE = 0.004154
# Epoch 1, Batch 26/240, MSE = 0.004036
# Epoch 1, Batch 27/240, MSE = 0.003544
# Epoch 1, Batch 28/240, MSE = 0.003157
# Epoch 1, Batch 29/240, MSE = 0.003600
# Epoch 1, Batch 30/240, MSE = 0.003586
# Epoch 1, Batch 31/240, MSE = 0.003364
# Epoch 1, Batch 32/240, MSE = 0.003491
# Epoch 1, Batch 33/240, MSE = 0.003138
# Epoch 1, Batch 34/240, MSE = 0.003150
# Epoch 1, Batch 35/240, MSE = 0.003156
# Epoch 1, Batch 36/240, MSE = 0.003368
# Epoch 1, Batch 37/240, MSE = 0.003582
# Epoch 1, Batch 38/240, MSE = 0.003368
# Epoch 1, Batch 39/240, MSE = 0.003141
# Epoch 1, Batch 40/240, MSE = 0.003049
# Epoch 1, Batch 41/240, MSE = 0.003128
# Epoch 1, Batch 42/240, MSE = 0.003031
# Epoch 1, Batch 43/240, MSE = 0.003032
# Epoch 1, Batch 44/240, MSE = 0.002989
# Epoch 1, Batch 45/240, MSE = 0.002898
# Epoch 1, Batch 46/240, MSE = 0.003006
# Epoch 1, Batch 47/240, MSE = 0.002987
# Epoch 1, Batch 48/240, MSE = 0.002930
# Epoch 1, Batch 49/240, MSE = 0.002897
# Epoch 1, Batch 50/240, MSE = 0.002897
# Epoch 1, Batch 51/240, MSE = 0.002869
# Epoch 1, Batch 52/240, MSE = 0.002979
# Epoch 1, Batch 53/240, MSE = 0.002926
# Epoch 1, Batch 54/240, MSE = 0.002957
# Epoch 1, Batch 55/240, MSE = 0.003061
# Epoch 1, Batch 56/240, MSE = 0.002908
# Epoch 1, Batch 57/240, MSE = 0.002887
# Epoch 1, Batch 58/240, MSE = 0.002891
# Epoch 1, Batch 59/240, MSE = 0.002881
# Epoch 1, Batch 60/240, MSE = 0.003059
# Epoch 1, Batch 61/240, MSE = 0.003043
# Epoch 1, Batch 62/240, MSE = 0.003143
# Epoch 1, Batch 63/240, MSE = 0.002899
# Epoch 1, Batch 64/240, MSE = 0.002929
# Epoch 1, Batch 65/240, MSE = 0.002864
# Epoch 1, Batch 66/240, MSE = 0.002869
# Epoch 1, Batch 67/240, MSE = 0.002850
# Epoch 1, Batch 68/240, MSE = 0.002818
# Epoch 1, Batch 69/240, MSE = 0.002903
# Epoch 1, Batch 70/240, MSE = 0.002888
# Epoch 1, Batch 71/240, MSE = 0.002885
# Epoch 1, Batch 72/240, MSE = 0.002940
# Epoch 1, Batch 73/240, MSE = 0.002973
# Epoch 1, Batch 74/240, MSE = 0.002902
# Epoch 1, Batch 75/240, MSE = 0.002892
# Epoch 1, Batch 76/240, MSE = 0.002922
# Epoch 1, Batch 77/240, MSE = 0.003090
# Epoch 1, Batch 78/240, MSE = 0.003008
# Epoch 1, Batch 79/240, MSE = 0.002861
# Epoch 1, Batch 80/240, MSE = 0.002891
# Epoch 1, Batch 81/240, MSE = 0.002963
# Epoch 1, Batch 82/240, MSE = 0.003049
# Epoch 1, Batch 83/240, MSE = 0.002907
# Epoch 1, Batch 84/240, MSE = 0.002873
# Epoch 1, Batch 85/240, MSE = 0.002930
# Epoch 1, Batch 86/240, MSE = 0.002825
# Epoch 1, Batch 87/240, MSE = 0.002970
# Epoch 1, Batch 88/240, MSE = 0.002950
# Epoch 1, Batch 89/240, MSE = 0.002878
# Epoch 1, Batch 90/240, MSE = 0.002941
# Epoch 1, Batch 91/240, MSE = 0.002913
# Epoch 1, Batch 92/240, MSE = 0.002858
# Epoch 1, Batch 93/240, MSE = 0.002865
# Epoch 1, Batch 94/240, MSE = 0.002880
# Epoch 1, Batch 95/240, MSE = 0.002934
# Epoch 1, Batch 96/240, MSE = 0.002910
# Epoch 1, Batch 97/240, MSE = 0.002962
# Epoch 1, Batch 98/240, MSE = 0.002936
# Epoch 1, Batch 99/240, MSE = 0.002880
# Epoch 1, Batch 100/240, MSE = 0.002897
# Epoch 1, Batch 101/240, MSE = 0.002840
# Epoch 1, Batch 102/240, MSE = 0.002891
# Epoch 1, Batch 103/240, MSE = 0.002862
# Epoch 1, Batch 104/240, MSE = 0.002951
# Epoch 1, Batch 105/240, MSE = 0.002872
# Epoch 1, Batch 106/240, MSE = 0.003041
# Epoch 1, Batch 107/240, MSE = 0.002984
# Epoch 1, Batch 108/240, MSE = 0.002964
# Epoch 1, Batch 109/240, MSE = 0.002920
# Epoch 1, Batch 110/240, MSE = 0.002922
# Epoch 1, Batch 111/240, MSE = 0.002943
# Epoch 1, Batch 112/240, MSE = 0.003033
# Epoch 1, Batch 113/240, MSE = 0.002944
# Epoch 1, Batch 114/240, MSE = 0.002956
# Epoch 1, Batch 115/240, MSE = 0.002878
# Epoch 1, Batch 116/240, MSE = 0.002902
# Epoch 1, Batch 117/240, MSE = 0.002955
# Epoch 1, Batch 118/240, MSE = 0.002908
# Epoch 1, Batch 119/240, MSE = 0.002894
# Epoch 1, Batch 120/240, MSE = 0.002936
# Epoch 1, Batch 121/240, MSE = 0.002961
# Epoch 1, Batch 122/240, MSE = 0.002884
# Epoch 1, Batch 123/240, MSE = 0.002932
# Epoch 1, Batch 124/240, MSE = 0.002914
# Epoch 1, Batch 125/240, MSE = 0.002927
# Epoch 1, Batch 126/240, MSE = 0.002865
# Epoch 1, Batch 127/240, MSE = 0.002978
# Epoch 1, Batch 128/240, MSE = 0.002869
# Epoch 1, Batch 129/240, MSE = 0.003029
# Epoch 1, Batch 130/240, MSE = 0.002929
# Epoch 1, Batch 131/240, MSE = 0.002967
# Epoch 1, Batch 132/240, MSE = 0.002897
# Epoch 1, Batch 133/240, MSE = 0.002839
# Epoch 1, Batch 134/240, MSE = 0.002894
# Epoch 1, Batch 135/240, MSE = 0.002820
# Epoch 1, Batch 136/240, MSE = 0.002960
# Epoch 1, Batch 137/240, MSE = 0.002894
# Epoch 1, Batch 138/240, MSE = 0.002958
# Epoch 1, Batch 139/240, MSE = 0.002854
# Epoch 1, Batch 140/240, MSE = 0.002932
# Epoch 1, Batch 141/240, MSE = 0.003012
# Epoch 1, Batch 142/240, MSE = 0.002831
# Epoch 1, Batch 143/240, MSE = 0.002943
# Epoch 1, Batch 144/240, MSE = 0.002932
# Epoch 1, Batch 145/240, MSE = 0.002863
# Epoch 1, Batch 146/240, MSE = 0.002887
# Epoch 1, Batch 147/240, MSE = 0.002957
# Epoch 1, Batch 148/240, MSE = 0.002824
# Epoch 1, Batch 149/240, MSE = 0.003005
# Epoch 1, Batch 150/240, MSE = 0.002933
# Epoch 1, Batch 151/240, MSE = 0.002901
# Epoch 1, Batch 152/240, MSE = 0.002876
# Epoch 1, Batch 153/240, MSE = 0.002862
# Epoch 1, Batch 154/240, MSE = 0.002923
# Epoch 1, Batch 155/240, MSE = 0.002971
# Epoch 1, Batch 156/240, MSE = 0.002936
# Epoch 1, Batch 157/240, MSE = 0.002874
# Epoch 1, Batch 158/240, MSE = 0.002949
# Epoch 1, Batch 159/240, MSE = 0.002951
# Epoch 1, Batch 160/240, MSE = 0.002973
# Epoch 1, Batch 161/240, MSE = 0.003002
# Epoch 1, Batch 162/240, MSE = 0.002915
# Epoch 1, Batch 163/240, MSE = 0.002860
# Epoch 1, Batch 164/240, MSE = 0.002905
# Epoch 1, Batch 165/240, MSE = 0.002944
# Epoch 1, Batch 166/240, MSE = 0.002920
# Epoch 1, Batch 167/240, MSE = 0.002965
# Epoch 1, Batch 168/240, MSE = 0.002879
# Epoch 1, Batch 169/240, MSE = 0.002905
# Epoch 1, Batch 170/240, MSE = 0.002831
# Epoch 1, Batch 171/240, MSE = 0.002914
# Epoch 1, Batch 172/240, MSE = 0.002851
# Epoch 1, Batch 173/240, MSE = 0.002927
# Epoch 1, Batch 174/240, MSE = 0.002814
# Epoch 1, Batch 175/240, MSE = 0.002883
# Epoch 1, Batch 176/240, MSE = 0.002781
# Epoch 1, Batch 177/240, MSE = 0.002868
# Epoch 1, Batch 178/240, MSE = 0.002857
# Epoch 1, Batch 179/240, MSE = 0.002940
# Epoch 1, Batch 180/240, MSE = 0.003075
# Epoch 1, Batch 181/240, MSE = 0.002899
# Epoch 1, Batch 182/240, MSE = 0.003076
# Epoch 1, Batch 183/240, MSE = 0.002905
# Epoch 1, Batch 184/240, MSE = 0.002961
# Epoch 1, Batch 185/240, MSE = 0.002925
# Epoch 1, Batch 186/240, MSE = 0.002877
# Epoch 1, Batch 187/240, MSE = 0.002870
# Epoch 1, Batch 188/240, MSE = 0.002895
# Epoch 1, Batch 189/240, MSE = 0.002866
# Epoch 1, Batch 190/240, MSE = 0.002899
# Epoch 1, Batch 191/240, MSE = 0.002906
# Epoch 1, Batch 192/240, MSE = 0.002800
# Epoch 1, Batch 193/240, MSE = 0.002909
# Epoch 1, Batch 194/240, MSE = 0.002936
# Epoch 1, Batch 195/240, MSE = 0.002860
# Epoch 1, Batch 196/240, MSE = 0.002897
# Epoch 1, Batch 197/240, MSE = 0.003015
# Epoch 1, Batch 198/240, MSE = 0.003194
# Epoch 1, Batch 199/240, MSE = 0.002976
# Epoch 1, Batch 200/240, MSE = 0.002868
# Epoch 1, Batch 201/240, MSE = 0.003014
# Epoch 1, Batch 202/240, MSE = 0.002874
# Epoch 1, Batch 203/240, MSE = 0.002909
# Epoch 1, Batch 204/240, MSE = 0.002889
# Epoch 1, Batch 205/240, MSE = 0.002893
# Epoch 1, Batch 206/240, MSE = 0.002918
# Epoch 1, Batch 207/240, MSE = 0.002906
# Epoch 1, Batch 208/240, MSE = 0.002916
# Epoch 1, Batch 209/240, MSE = 0.002873
# Epoch 1, Batch 210/240, MSE = 0.002751
# Epoch 1, Batch 211/240, MSE = 0.002917
# Epoch 1, Batch 212/240, MSE = 0.002858
# Epoch 1, Batch 213/240, MSE = 0.003012
# Epoch 1, Batch 214/240, MSE = 0.002871
# Epoch 1, Batch 215/240, MSE = 0.002940
# Epoch 1, Batch 216/240, MSE = 0.002862
# Epoch 1, Batch 217/240, MSE = 0.002859
# Epoch 1, Batch 218/240, MSE = 0.002846
# Epoch 1, Batch 219/240, MSE = 0.002900
# Epoch 1, Batch 220/240, MSE = 0.002900
# Epoch 1, Batch 221/240, MSE = 0.002911
# Epoch 1, Batch 222/240, MSE = 0.002920
# Epoch 1, Batch 223/240, MSE = 0.002861
# Epoch 1, Batch 224/240, MSE = 0.002960
# Epoch 1, Batch 225/240, MSE = 0.002903
# Epoch 1, Batch 226/240, MSE = 0.002946
# Epoch 1, Batch 227/240, MSE = 0.002976
# Epoch 1, Batch 228/240, MSE = 0.002878
# Epoch 1, Batch 229/240, MSE = 0.002912
# Epoch 1, Batch 230/240, MSE = 0.002957
# Epoch 1, Batch 231/240, MSE = 0.002943
# Epoch 1, Batch 232/240, MSE = 0.002926
# Epoch 1, Batch 233/240, MSE = 0.002909
# Epoch 1, Batch 234/240, MSE = 0.002839
# Epoch 1, Batch 235/240, MSE = 0.002859
# Epoch 1, Batch 236/240, MSE = 0.002803
# Epoch 1, Batch 237/240, MSE = 0.002844
# Epoch 1, Batch 238/240, MSE = 0.002865
# Epoch 1, Batch 239/240, MSE = 0.002906
# Epoch 1, Batch 240/240, MSE = 0.002825
#
# ============================================================
# Epoch 2/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/3 ---
# Epoch 1, Batch 1/240, MSE = 0.007234
# Epoch 1, Batch 2/240, MSE = 0.007019
# Epoch 1, Batch 3/240, MSE = 0.007077
# Epoch 1, Batch 4/240, MSE = 0.007301
# Epoch 1, Batch 5/240, MSE = 0.007021
# Epoch 1, Batch 6/240, MSE = 0.006898
# Epoch 1, Batch 7/240, MSE = 0.007042
# Epoch 1, Batch 8/240, MSE = 0.007107
# Epoch 1, Batch 9/240, MSE = 0.007117
# Epoch 1, Batch 10/240, MSE = 0.007110
# Epoch 1, Batch 11/240, MSE = 0.007082
# Epoch 1, Batch 12/240, MSE = 0.006979
# Epoch 1, Batch 13/240, MSE = 0.007006
# Epoch 1, Batch 14/240, MSE = 0.007080
# Epoch 1, Batch 15/240, MSE = 0.007055
# Epoch 1, Batch 16/240, MSE = 0.006907
# Epoch 1, Batch 17/240, MSE = 0.007006
# Epoch 1, Batch 18/240, MSE = 0.006854
# Epoch 1, Batch 19/240, MSE = 0.006632
# Epoch 1, Batch 20/240, MSE = 0.006732
# Epoch 1, Batch 21/240, MSE = 0.006645
# Epoch 1, Batch 22/240, MSE = 0.006551
# Epoch 1, Batch 23/240, MSE = 0.006452
# Epoch 1, Batch 24/240, MSE = 0.006762
# Epoch 1, Batch 25/240, MSE = 0.006572
# Epoch 1, Batch 26/240, MSE = 0.006925
# Epoch 1, Batch 27/240, MSE = 0.006510
# Epoch 1, Batch 28/240, MSE = 0.006720
# Epoch 1, Batch 29/240, MSE = 0.006657
# Epoch 1, Batch 30/240, MSE = 0.006794
# Epoch 1, Batch 31/240, MSE = 0.006567
# Epoch 1, Batch 32/240, MSE = 0.006735
# Epoch 1, Batch 33/240, MSE = 0.006572
# Epoch 1, Batch 34/240, MSE = 0.006537
# Epoch 1, Batch 35/240, MSE = 0.006368
# Epoch 1, Batch 36/240, MSE = 0.006615
# Epoch 1, Batch 37/240, MSE = 0.006601
# Epoch 1, Batch 38/240, MSE = 0.006735
# Epoch 1, Batch 39/240, MSE = 0.006358
# Epoch 1, Batch 40/240, MSE = 0.006372
# Epoch 1, Batch 41/240, MSE = 0.006146
# Epoch 1, Batch 42/240, MSE = 0.006471
# Epoch 1, Batch 43/240, MSE = 0.006234
# Epoch 1, Batch 44/240, MSE = 0.006618
# Epoch 1, Batch 45/240, MSE = 0.006348
# Epoch 1, Batch 46/240, MSE = 0.006267
# Epoch 1, Batch 47/240, MSE = 0.006133
# Epoch 1, Batch 48/240, MSE = 0.006230
# Epoch 1, Batch 49/240, MSE = 0.006397
# Epoch 1, Batch 50/240, MSE = 0.006376
# Epoch 1, Batch 51/240, MSE = 0.005967
# Epoch 1, Batch 52/240, MSE = 0.006291
# Epoch 1, Batch 53/240, MSE = 0.006279
# Epoch 1, Batch 54/240, MSE = 0.006270
# Epoch 1, Batch 55/240, MSE = 0.006339
# Epoch 1, Batch 56/240, MSE = 0.006279
# Epoch 1, Batch 57/240, MSE = 0.006164
# Epoch 1, Batch 58/240, MSE = 0.006228
# Epoch 1, Batch 59/240, MSE = 0.005926
# Epoch 1, Batch 60/240, MSE = 0.006314
# Epoch 1, Batch 61/240, MSE = 0.006123
# Epoch 1, Batch 62/240, MSE = 0.005807
# Epoch 1, Batch 63/240, MSE = 0.006203
# Epoch 1, Batch 64/240, MSE = 0.006145
# Epoch 1, Batch 65/240, MSE = 0.005674
# Epoch 1, Batch 66/240, MSE = 0.006048
# Epoch 1, Batch 67/240, MSE = 0.005993
# Epoch 1, Batch 68/240, MSE = 0.005764
# Epoch 1, Batch 69/240, MSE = 0.006013
# Epoch 1, Batch 70/240, MSE = 0.005778
# Epoch 1, Batch 71/240, MSE = 0.005973
# Epoch 1, Batch 72/240, MSE = 0.005886
# Epoch 1, Batch 73/240, MSE = 0.005975
# Epoch 1, Batch 74/240, MSE = 0.005699
# Epoch 1, Batch 75/240, MSE = 0.005658
# Epoch 1, Batch 76/240, MSE = 0.005807
# Epoch 1, Batch 77/240, MSE = 0.005847
# Epoch 1, Batch 78/240, MSE = 0.005787
# Epoch 1, Batch 79/240, MSE = 0.005922
# Epoch 1, Batch 80/240, MSE = 0.005912
# Epoch 1, Batch 81/240, MSE = 0.005906
# Epoch 1, Batch 82/240, MSE = 0.005776
# Epoch 1, Batch 83/240, MSE = 0.005711
# Epoch 1, Batch 84/240, MSE = 0.005753
# Epoch 1, Batch 85/240, MSE = 0.005485
# Epoch 1, Batch 86/240, MSE = 0.005778
# Epoch 1, Batch 87/240, MSE = 0.005723
# Epoch 1, Batch 88/240, MSE = 0.005816
# Epoch 1, Batch 89/240, MSE = 0.005611
# Epoch 1, Batch 90/240, MSE = 0.005445
# Epoch 1, Batch 91/240, MSE = 0.005466
# Epoch 1, Batch 92/240, MSE = 0.005384
# Epoch 1, Batch 93/240, MSE = 0.005586
# Epoch 1, Batch 94/240, MSE = 0.005430
# Epoch 1, Batch 95/240, MSE = 0.005537
# Epoch 1, Batch 96/240, MSE = 0.005522
# Epoch 1, Batch 97/240, MSE = 0.005215
# Epoch 1, Batch 98/240, MSE = 0.005466
# Epoch 1, Batch 99/240, MSE = 0.005459
# Epoch 1, Batch 100/240, MSE = 0.005512
# Epoch 1, Batch 101/240, MSE = 0.005420
# Epoch 1, Batch 102/240, MSE = 0.005144
# Epoch 1, Batch 103/240, MSE = 0.005552
# Epoch 1, Batch 104/240, MSE = 0.005242
# Epoch 1, Batch 105/240, MSE = 0.005456
# Epoch 1, Batch 106/240, MSE = 0.005131
# Epoch 1, Batch 107/240, MSE = 0.005330
# Epoch 1, Batch 108/240, MSE = 0.005476
# Epoch 1, Batch 109/240, MSE = 0.005293
# Epoch 1, Batch 110/240, MSE = 0.004946
# Epoch 1, Batch 111/240, MSE = 0.005441
# Epoch 1, Batch 112/240, MSE = 0.005368
# Epoch 1, Batch 113/240, MSE = 0.005201
# Epoch 1, Batch 114/240, MSE = 0.005205
# Epoch 1, Batch 115/240, MSE = 0.005018
# Epoch 1, Batch 116/240, MSE = 0.005159
# Epoch 1, Batch 117/240, MSE = 0.004996
# Epoch 1, Batch 118/240, MSE = 0.005260
# Epoch 1, Batch 119/240, MSE = 0.005249
# Epoch 1, Batch 120/240, MSE = 0.005185
# Epoch 1, Batch 121/240, MSE = 0.005041
# Epoch 1, Batch 122/240, MSE = 0.004945
# Epoch 1, Batch 123/240, MSE = 0.005113
# Epoch 1, Batch 124/240, MSE = 0.005104
# Epoch 1, Batch 125/240, MSE = 0.004892
# Epoch 1, Batch 126/240, MSE = 0.005309
# Epoch 1, Batch 127/240, MSE = 0.005165
# Epoch 1, Batch 128/240, MSE = 0.005092
# Epoch 1, Batch 129/240, MSE = 0.005006
# Epoch 1, Batch 130/240, MSE = 0.004942
# Epoch 1, Batch 131/240, MSE = 0.004951
# Epoch 1, Batch 132/240, MSE = 0.004980
# Epoch 1, Batch 133/240, MSE = 0.005042
# Epoch 1, Batch 134/240, MSE = 0.004827
# Epoch 1, Batch 135/240, MSE = 0.004662
# Epoch 1, Batch 136/240, MSE = 0.004900
# Epoch 1, Batch 137/240, MSE = 0.004822
# Epoch 1, Batch 138/240, MSE = 0.005011
# Epoch 1, Batch 139/240, MSE = 0.004810
# Epoch 1, Batch 140/240, MSE = 0.004867
# Epoch 1, Batch 141/240, MSE = 0.004941
# Epoch 1, Batch 142/240, MSE = 0.005156
# Epoch 1, Batch 143/240, MSE = 0.004901
# Epoch 1, Batch 144/240, MSE = 0.004804
# Epoch 1, Batch 145/240, MSE = 0.004902
# Epoch 1, Batch 146/240, MSE = 0.004652
# Epoch 1, Batch 147/240, MSE = 0.005017
# Epoch 1, Batch 148/240, MSE = 0.004740
# Epoch 1, Batch 149/240, MSE = 0.004573
# Epoch 1, Batch 150/240, MSE = 0.004778
# Epoch 1, Batch 151/240, MSE = 0.004897
# Epoch 1, Batch 152/240, MSE = 0.004415
# Epoch 1, Batch 153/240, MSE = 0.004775
# Epoch 1, Batch 154/240, MSE = 0.004641
# Epoch 1, Batch 155/240, MSE = 0.004583
# Epoch 1, Batch 156/240, MSE = 0.004599
# Epoch 1, Batch 157/240, MSE = 0.004787
# Epoch 1, Batch 158/240, MSE = 0.004606
# Epoch 1, Batch 159/240, MSE = 0.004323
# Epoch 1, Batch 160/240, MSE = 0.004300
# Epoch 1, Batch 161/240, MSE = 0.004566
# Epoch 1, Batch 162/240, MSE = 0.004541
# Epoch 1, Batch 163/240, MSE = 0.004785
# Epoch 1, Batch 164/240, MSE = 0.004499
# Epoch 1, Batch 165/240, MSE = 0.004635
# Epoch 1, Batch 166/240, MSE = 0.004388
# Epoch 1, Batch 167/240, MSE = 0.004373
# Epoch 1, Batch 168/240, MSE = 0.004387
# Epoch 1, Batch 169/240, MSE = 0.004424
# Epoch 1, Batch 170/240, MSE = 0.004643
# Epoch 1, Batch 171/240, MSE = 0.004608
# Epoch 1, Batch 172/240, MSE = 0.004390
# Epoch 1, Batch 173/240, MSE = 0.004509
# Epoch 1, Batch 174/240, MSE = 0.004310
# Epoch 1, Batch 175/240, MSE = 0.004276
# Epoch 1, Batch 176/240, MSE = 0.004390
# Epoch 1, Batch 177/240, MSE = 0.004401
# Epoch 1, Batch 178/240, MSE = 0.004246
# Epoch 1, Batch 179/240, MSE = 0.004371
# Epoch 1, Batch 180/240, MSE = 0.004223
# Epoch 1, Batch 181/240, MSE = 0.004301
# Epoch 1, Batch 182/240, MSE = 0.004219
# Epoch 1, Batch 183/240, MSE = 0.004352
# Epoch 1, Batch 184/240, MSE = 0.004208
# Epoch 1, Batch 185/240, MSE = 0.004442
# Epoch 1, Batch 186/240, MSE = 0.004188
# Epoch 1, Batch 187/240, MSE = 0.004297
# Epoch 1, Batch 188/240, MSE = 0.004376
# Epoch 1, Batch 189/240, MSE = 0.003913
# Epoch 1, Batch 190/240, MSE = 0.004208
# Epoch 1, Batch 191/240, MSE = 0.004336
# Epoch 1, Batch 192/240, MSE = 0.004061
# Epoch 1, Batch 193/240, MSE = 0.004161
# Epoch 1, Batch 194/240, MSE = 0.004238
# Epoch 1, Batch 195/240, MSE = 0.004117
# Epoch 1, Batch 196/240, MSE = 0.004016
# Epoch 1, Batch 197/240, MSE = 0.004175
# Epoch 1, Batch 198/240, MSE = 0.004027
# Epoch 1, Batch 199/240, MSE = 0.004002
# Epoch 1, Batch 200/240, MSE = 0.004180
# Epoch 1, Batch 201/240, MSE = 0.004040
# Epoch 1, Batch 202/240, MSE = 0.003817
# Epoch 1, Batch 203/240, MSE = 0.003992
# Epoch 1, Batch 204/240, MSE = 0.004032
# Epoch 1, Batch 205/240, MSE = 0.003841
# Epoch 1, Batch 206/240, MSE = 0.004233
# Epoch 1, Batch 207/240, MSE = 0.004103
# Epoch 1, Batch 208/240, MSE = 0.004114
# Epoch 1, Batch 209/240, MSE = 0.003919
# Epoch 1, Batch 210/240, MSE = 0.003953
# Epoch 1, Batch 211/240, MSE = 0.003917
# Epoch 1, Batch 212/240, MSE = 0.003918
# Epoch 1, Batch 213/240, MSE = 0.003834
# Epoch 1, Batch 214/240, MSE = 0.003982
# Epoch 1, Batch 215/240, MSE = 0.003867
# Epoch 1, Batch 216/240, MSE = 0.003834
# Epoch 1, Batch 217/240, MSE = 0.003859
# Epoch 1, Batch 218/240, MSE = 0.003836
# Epoch 1, Batch 219/240, MSE = 0.003826
# Epoch 1, Batch 220/240, MSE = 0.003771
# Epoch 1, Batch 221/240, MSE = 0.003876
# Epoch 1, Batch 222/240, MSE = 0.003929
# Epoch 1, Batch 223/240, MSE = 0.003870
# Epoch 1, Batch 224/240, MSE = 0.003848
# Epoch 1, Batch 225/240, MSE = 0.003805
# Epoch 1, Batch 226/240, MSE = 0.003855
# Epoch 1, Batch 227/240, MSE = 0.003741
# Epoch 1, Batch 228/240, MSE = 0.003721
# Epoch 1, Batch 229/240, MSE = 0.003884
# Epoch 1, Batch 230/240, MSE = 0.003708
# Epoch 1, Batch 231/240, MSE = 0.003891
# Epoch 1, Batch 232/240, MSE = 0.003738
# Epoch 1, Batch 233/240, MSE = 0.003724
# Epoch 1, Batch 234/240, MSE = 0.003667
# Epoch 1, Batch 235/240, MSE = 0.003696
# Epoch 1, Batch 236/240, MSE = 0.003889
# Epoch 1, Batch 237/240, MSE = 0.003497
# Epoch 1, Batch 238/240, MSE = 0.003607
# Epoch 1, Batch 239/240, MSE = 0.003683
# Epoch 1, Batch 240/240, MSE = 0.003418
#
# --- Training Layer 2/3 ---
# Epoch 1, Batch 1/240, MSE = 0.014988
# Epoch 1, Batch 2/240, MSE = 0.015921
# Epoch 1, Batch 3/240, MSE = 0.015101
# Epoch 1, Batch 4/240, MSE = 0.014692
# Epoch 1, Batch 5/240, MSE = 0.016682
# Epoch 1, Batch 6/240, MSE = 0.015999
# Epoch 1, Batch 7/240, MSE = 0.016681
# Epoch 1, Batch 8/240, MSE = 0.018132
# Epoch 1, Batch 9/240, MSE = 0.015576
# Epoch 1, Batch 10/240, MSE = 0.019648
# Epoch 1, Batch 11/240, MSE = 0.015925
# Epoch 1, Batch 12/240, MSE = 0.015380
# Epoch 1, Batch 13/240, MSE = 0.015323
# Epoch 1, Batch 14/240, MSE = 0.022502
# Epoch 1, Batch 15/240, MSE = 0.017934
# Epoch 1, Batch 16/240, MSE = 0.015859
# Epoch 1, Batch 17/240, MSE = 0.017025
# Epoch 1, Batch 18/240, MSE = 0.018692
# Epoch 1, Batch 19/240, MSE = 0.014894
# Epoch 1, Batch 20/240, MSE = 0.015569
# Epoch 1, Batch 21/240, MSE = 0.019819
# Epoch 1, Batch 22/240, MSE = 0.016948
# Epoch 1, Batch 23/240, MSE = 0.015980
# Epoch 1, Batch 24/240, MSE = 0.016091
# Epoch 1, Batch 25/240, MSE = 0.020203
# Epoch 1, Batch 26/240, MSE = 0.020151
# Epoch 1, Batch 27/240, MSE = 0.022128
# Epoch 1, Batch 28/240, MSE = 0.017291
# Epoch 1, Batch 29/240, MSE = 0.016171
# Epoch 1, Batch 30/240, MSE = 0.014286
# Epoch 1, Batch 31/240, MSE = 0.017258
# Epoch 1, Batch 32/240, MSE = 0.019565
# Epoch 1, Batch 33/240, MSE = 0.016421
# Epoch 1, Batch 34/240, MSE = 0.016760
# Epoch 1, Batch 35/240, MSE = 0.015728
# Epoch 1, Batch 36/240, MSE = 0.014547
# Epoch 1, Batch 37/240, MSE = 0.014474
# Epoch 1, Batch 38/240, MSE = 0.015199
# Epoch 1, Batch 39/240, MSE = 0.014418
# Epoch 1, Batch 40/240, MSE = 0.013454
# Epoch 1, Batch 41/240, MSE = 0.014783
# Epoch 1, Batch 42/240, MSE = 0.014483
# Epoch 1, Batch 43/240, MSE = 0.014609
# Epoch 1, Batch 44/240, MSE = 0.013789
# Epoch 1, Batch 45/240, MSE = 0.019228
# Epoch 1, Batch 46/240, MSE = 0.017060
# Epoch 1, Batch 47/240, MSE = 0.017711
# Epoch 1, Batch 48/240, MSE = 0.020727
# Epoch 1, Batch 49/240, MSE = 0.017769
# Epoch 1, Batch 50/240, MSE = 0.019772
# Epoch 1, Batch 51/240, MSE = 0.014249
# Epoch 1, Batch 52/240, MSE = 0.016979
# Epoch 1, Batch 53/240, MSE = 0.018094
# Epoch 1, Batch 54/240, MSE = 0.026249
# Epoch 1, Batch 55/240, MSE = 0.018924
# Epoch 1, Batch 56/240, MSE = 0.017669
# Epoch 1, Batch 57/240, MSE = 0.016988
# Epoch 1, Batch 58/240, MSE = 0.014585
# Epoch 1, Batch 59/240, MSE = 0.014500
# Epoch 1, Batch 60/240, MSE = 0.017167
# Epoch 1, Batch 61/240, MSE = 0.016869
# Epoch 1, Batch 62/240, MSE = 0.016428
# Epoch 1, Batch 63/240, MSE = 0.017993
# Epoch 1, Batch 64/240, MSE = 0.017518
# Epoch 1, Batch 65/240, MSE = 0.017681
# Epoch 1, Batch 66/240, MSE = 0.015545
# Epoch 1, Batch 67/240, MSE = 0.013634
# Epoch 1, Batch 68/240, MSE = 0.013481
# Epoch 1, Batch 69/240, MSE = 0.014112
# Epoch 1, Batch 70/240, MSE = 0.015732
# Epoch 1, Batch 71/240, MSE = 0.016665
# Epoch 1, Batch 72/240, MSE = 0.020597
# Epoch 1, Batch 73/240, MSE = 0.014576
# Epoch 1, Batch 74/240, MSE = 0.017819
# Epoch 1, Batch 75/240, MSE = 0.017022
# Epoch 1, Batch 76/240, MSE = 0.021516
# Epoch 1, Batch 77/240, MSE = 0.015611
# Epoch 1, Batch 78/240, MSE = 0.019142
# Epoch 1, Batch 79/240, MSE = 0.018147
# Epoch 1, Batch 80/240, MSE = 0.014302
# Epoch 1, Batch 81/240, MSE = 0.014758
# Epoch 1, Batch 82/240, MSE = 0.015299
# Epoch 1, Batch 83/240, MSE = 0.014294
# Epoch 1, Batch 84/240, MSE = 0.016374
# Epoch 1, Batch 85/240, MSE = 0.015809
# Epoch 1, Batch 86/240, MSE = 0.015860
# Epoch 1, Batch 87/240, MSE = 0.017061
# Epoch 1, Batch 88/240, MSE = 0.015439
# Epoch 1, Batch 89/240, MSE = 0.014751
# Epoch 1, Batch 90/240, MSE = 0.014018
# Epoch 1, Batch 91/240, MSE = 0.019246
# Epoch 1, Batch 92/240, MSE = 0.019238
# Epoch 1, Batch 93/240, MSE = 0.014574
# Epoch 1, Batch 94/240, MSE = 0.015294
# Epoch 1, Batch 95/240, MSE = 0.015754
# Epoch 1, Batch 96/240, MSE = 0.014145
# Epoch 1, Batch 97/240, MSE = 0.014521
# Epoch 1, Batch 98/240, MSE = 0.013154
# Epoch 1, Batch 99/240, MSE = 0.012947
# Epoch 1, Batch 100/240, MSE = 0.013835
# Epoch 1, Batch 101/240, MSE = 0.018458
# Epoch 1, Batch 102/240, MSE = 0.015786
# Epoch 1, Batch 103/240, MSE = 0.019287
# Epoch 1, Batch 104/240, MSE = 0.019249
# Epoch 1, Batch 105/240, MSE = 0.015619
# Epoch 1, Batch 106/240, MSE = 0.017792
# Epoch 1, Batch 107/240, MSE = 0.013136
# Epoch 1, Batch 108/240, MSE = 0.012567
# Epoch 1, Batch 109/240, MSE = 0.013449
# Epoch 1, Batch 110/240, MSE = 0.014785
# Epoch 1, Batch 111/240, MSE = 0.016902
# Epoch 1, Batch 112/240, MSE = 0.013758
# Epoch 1, Batch 113/240, MSE = 0.015487
# Epoch 1, Batch 114/240, MSE = 0.013013
# Epoch 1, Batch 115/240, MSE = 0.013412
# Epoch 1, Batch 116/240, MSE = 0.015163
# Epoch 1, Batch 117/240, MSE = 0.016212
# Epoch 1, Batch 118/240, MSE = 0.018148
# Epoch 1, Batch 119/240, MSE = 0.014248
# Epoch 1, Batch 120/240, MSE = 0.014237
# Epoch 1, Batch 121/240, MSE = 0.016545
# Epoch 1, Batch 122/240, MSE = 0.013977
# Epoch 1, Batch 123/240, MSE = 0.013946
# Epoch 1, Batch 124/240, MSE = 0.015599
# Epoch 1, Batch 125/240, MSE = 0.013814
# Epoch 1, Batch 126/240, MSE = 0.016408
# Epoch 1, Batch 127/240, MSE = 0.014137
# Epoch 1, Batch 128/240, MSE = 0.017382
# Epoch 1, Batch 129/240, MSE = 0.018757
# Epoch 1, Batch 130/240, MSE = 0.014269
# Epoch 1, Batch 131/240, MSE = 0.012779
# Epoch 1, Batch 132/240, MSE = 0.012408
# Epoch 1, Batch 133/240, MSE = 0.012821
# Epoch 1, Batch 134/240, MSE = 0.014604
# Epoch 1, Batch 135/240, MSE = 0.015380
# Epoch 1, Batch 136/240, MSE = 0.016007
# Epoch 1, Batch 137/240, MSE = 0.012197
# Epoch 1, Batch 138/240, MSE = 0.011752
# Epoch 1, Batch 139/240, MSE = 0.011911
# Epoch 1, Batch 140/240, MSE = 0.011952
# Epoch 1, Batch 141/240, MSE = 0.014543
# Epoch 1, Batch 142/240, MSE = 0.014147
# Epoch 1, Batch 143/240, MSE = 0.014190
# Epoch 1, Batch 144/240, MSE = 0.015718
# Epoch 1, Batch 145/240, MSE = 0.012829
# Epoch 1, Batch 146/240, MSE = 0.015123
# Epoch 1, Batch 147/240, MSE = 0.016154
# Epoch 1, Batch 148/240, MSE = 0.015259
# Epoch 1, Batch 149/240, MSE = 0.014067
# Epoch 1, Batch 150/240, MSE = 0.012105
# Epoch 1, Batch 151/240, MSE = 0.012495
# Epoch 1, Batch 152/240, MSE = 0.019713
# Epoch 1, Batch 153/240, MSE = 0.015759
# Epoch 1, Batch 154/240, MSE = 0.011894
# Epoch 1, Batch 155/240, MSE = 0.011844
# Epoch 1, Batch 156/240, MSE = 0.013141
# Epoch 1, Batch 157/240, MSE = 0.012391
# Epoch 1, Batch 158/240, MSE = 0.011639
# Epoch 1, Batch 159/240, MSE = 0.013320
# Epoch 1, Batch 160/240, MSE = 0.012744
# Epoch 1, Batch 161/240, MSE = 0.011062
# Epoch 1, Batch 162/240, MSE = 0.011483
# Epoch 1, Batch 163/240, MSE = 0.011430
# Epoch 1, Batch 164/240, MSE = 0.011629
# Epoch 1, Batch 165/240, MSE = 0.011983
# Epoch 1, Batch 166/240, MSE = 0.012789
# Epoch 1, Batch 167/240, MSE = 0.014692
# Epoch 1, Batch 168/240, MSE = 0.012735
# Epoch 1, Batch 169/240, MSE = 0.012507
# Epoch 1, Batch 170/240, MSE = 0.014151
# Epoch 1, Batch 171/240, MSE = 0.018240
# Epoch 1, Batch 172/240, MSE = 0.012348
# Epoch 1, Batch 173/240, MSE = 0.018580
# Epoch 1, Batch 174/240, MSE = 0.015014
# Epoch 1, Batch 175/240, MSE = 0.014364
# Epoch 1, Batch 176/240, MSE = 0.015037
# Epoch 1, Batch 177/240, MSE = 0.011549
# Epoch 1, Batch 178/240, MSE = 0.011165
# Epoch 1, Batch 179/240, MSE = 0.011488
# Epoch 1, Batch 180/240, MSE = 0.011771
# Epoch 1, Batch 181/240, MSE = 0.016170
# Epoch 1, Batch 182/240, MSE = 0.017974
# Epoch 1, Batch 183/240, MSE = 0.011653
# Epoch 1, Batch 184/240, MSE = 0.010920
# Epoch 1, Batch 185/240, MSE = 0.011669
# Epoch 1, Batch 186/240, MSE = 0.014369
# Epoch 1, Batch 187/240, MSE = 0.010962
# Epoch 1, Batch 188/240, MSE = 0.010891
# Epoch 1, Batch 189/240, MSE = 0.014266
# Epoch 1, Batch 190/240, MSE = 0.015657
# Epoch 1, Batch 191/240, MSE = 0.014918
# Epoch 1, Batch 192/240, MSE = 0.011656
# Epoch 1, Batch 193/240, MSE = 0.011362
# Epoch 1, Batch 194/240, MSE = 0.014660
# Epoch 1, Batch 195/240, MSE = 0.013933
# Epoch 1, Batch 196/240, MSE = 0.012630
# Epoch 1, Batch 197/240, MSE = 0.015301
# Epoch 1, Batch 198/240, MSE = 0.017172
# Epoch 1, Batch 199/240, MSE = 0.014717
# Epoch 1, Batch 200/240, MSE = 0.013395
# Epoch 1, Batch 201/240, MSE = 0.012471
# Epoch 1, Batch 202/240, MSE = 0.013199
# Epoch 1, Batch 203/240, MSE = 0.017650
# Epoch 1, Batch 204/240, MSE = 0.011608
# Epoch 1, Batch 205/240, MSE = 0.010421
# Epoch 1, Batch 206/240, MSE = 0.010663
# Epoch 1, Batch 207/240, MSE = 0.010169
# Epoch 1, Batch 208/240, MSE = 0.011484
# Epoch 1, Batch 209/240, MSE = 0.013272
# Epoch 1, Batch 210/240, MSE = 0.012452
# Epoch 1, Batch 211/240, MSE = 0.012548
# Epoch 1, Batch 212/240, MSE = 0.010444
# Epoch 1, Batch 213/240, MSE = 0.011108
# Epoch 1, Batch 214/240, MSE = 0.011890
# Epoch 1, Batch 215/240, MSE = 0.011553
# Epoch 1, Batch 216/240, MSE = 0.013147
# Epoch 1, Batch 217/240, MSE = 0.012183
# Epoch 1, Batch 218/240, MSE = 0.012500
# Epoch 1, Batch 219/240, MSE = 0.013672
# Epoch 1, Batch 220/240, MSE = 0.016070
# Epoch 1, Batch 221/240, MSE = 0.010613
# Epoch 1, Batch 222/240, MSE = 0.011581
# Epoch 1, Batch 223/240, MSE = 0.015573
# Epoch 1, Batch 224/240, MSE = 0.012713
# Epoch 1, Batch 225/240, MSE = 0.010950
# Epoch 1, Batch 226/240, MSE = 0.011400
# Epoch 1, Batch 227/240, MSE = 0.012936
# Epoch 1, Batch 228/240, MSE = 0.013631
# Epoch 1, Batch 229/240, MSE = 0.010689
# Epoch 1, Batch 230/240, MSE = 0.011752
# Epoch 1, Batch 231/240, MSE = 0.012461
# Epoch 1, Batch 232/240, MSE = 0.013712
# Epoch 1, Batch 233/240, MSE = 0.012337
# Epoch 1, Batch 234/240, MSE = 0.014710
# Epoch 1, Batch 235/240, MSE = 0.014069
# Epoch 1, Batch 236/240, MSE = 0.015081
# Epoch 1, Batch 237/240, MSE = 0.012084
# Epoch 1, Batch 238/240, MSE = 0.012886
# Epoch 1, Batch 239/240, MSE = 0.010200
# Epoch 1, Batch 240/240, MSE = 0.012632
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.114314
# Epoch 1, Batch 2/240, MSE = 0.102602
# Epoch 1, Batch 3/240, MSE = 0.104296
# Epoch 1, Batch 4/240, MSE = 0.086669
# Epoch 1, Batch 5/240, MSE = 0.106566
# Epoch 1, Batch 6/240, MSE = 0.100972
# Epoch 1, Batch 7/240, MSE = 0.099224
# Epoch 1, Batch 8/240, MSE = 0.113892
# Epoch 1, Batch 9/240, MSE = 0.104332
# Epoch 1, Batch 10/240, MSE = 0.108469
# Epoch 1, Batch 11/240, MSE = 0.106990
# Epoch 1, Batch 12/240, MSE = 0.121030
# Epoch 1, Batch 13/240, MSE = 0.122013
# Epoch 1, Batch 14/240, MSE = 0.104984
# Epoch 1, Batch 15/240, MSE = 0.105584
# Epoch 1, Batch 16/240, MSE = 0.099523
# Epoch 1, Batch 17/240, MSE = 0.114678
# Epoch 1, Batch 18/240, MSE = 0.092982
# Epoch 1, Batch 19/240, MSE = 0.112205
# Epoch 1, Batch 20/240, MSE = 0.102790
# ...
# Epoch 1, Batch 69/240, MSE = 0.000142
# Epoch 1, Batch 70/240, MSE = 0.000133
# Epoch 1, Batch 71/240, MSE = 0.000127
# Epoch 1, Batch 72/240, MSE = 0.000135
# Epoch 1, Batch 73/240, MSE = 0.000125
# Epoch 1, Batch 74/240, MSE = 0.000134
# Epoch 1, Batch 75/240, MSE = 0.000135
# Epoch 1, Batch 76/240, MSE = 0.000130
# Epoch 1, Batch 77/240, MSE = 0.000135
# Epoch 1, Batch 78/240, MSE = 0.000124
# Epoch 1, Batch 79/240, MSE = 0.000145
# Epoch 1, Batch 80/240, MSE = 0.000122
# Epoch 1, Batch 81/240, MSE = 0.000125
# Epoch 1, Batch 82/240, MSE = 0.000134
# Epoch 1, Batch 83/240, MSE = 0.000124
# Epoch 1, Batch 84/240, MSE = 0.000140
# Epoch 1, Batch 85/240, MSE = 0.000137
# Epoch 1, Batch 86/240, MSE = 0.000141
# Epoch 1, Batch 87/240, MSE = 0.000124
# Epoch 1, Batch 88/240, MSE = 0.000129
# Epoch 1, Batch 89/240, MSE = 0.000138
# Epoch 1, Batch 90/240, MSE = 0.000131
# Epoch 1, Batch 91/240, MSE = 0.000135
# Epoch 1, Batch 92/240, MSE = 0.000133
# Epoch 1, Batch 93/240, MSE = 0.000143
# Epoch 1, Batch 94/240, MSE = 0.000144
# Epoch 1, Batch 95/240, MSE = 0.000135
# Epoch 1, Batch 96/240, MSE = 0.000135
# Epoch 1, Batch 97/240, MSE = 0.000130
# Epoch 1, Batch 98/240, MSE = 0.000130
# Epoch 1, Batch 99/240, MSE = 0.000121
# Epoch 1, Batch 100/240, MSE = 0.000129
# Epoch 1, Batch 101/240, MSE = 0.000127
# Epoch 1, Batch 102/240, MSE = 0.000115
# Epoch 1, Batch 103/240, MSE = 0.000126
# Epoch 1, Batch 104/240, MSE = 0.000149
# Epoch 1, Batch 105/240, MSE = 0.000149
# Epoch 1, Batch 106/240, MSE = 0.000128
# Epoch 1, Batch 107/240, MSE = 0.000140
# Epoch 1, Batch 108/240, MSE = 0.000129
# Epoch 1, Batch 109/240, MSE = 0.000122
# Epoch 1, Batch 110/240, MSE = 0.000127
# Epoch 1, Batch 111/240, MSE = 0.000148
# Epoch 1, Batch 112/240, MSE = 0.000129
# Epoch 1, Batch 113/240, MSE = 0.000128
# Epoch 1, Batch 114/240, MSE = 0.000128
# Epoch 1, Batch 115/240, MSE = 0.000138
# Epoch 1, Batch 116/240, MSE = 0.000128
# Epoch 1, Batch 117/240, MSE = 0.000125
# Epoch 1, Batch 118/240, MSE = 0.000141
# Epoch 1, Batch 119/240, MSE = 0.000129
# Epoch 1, Batch 120/240, MSE = 0.000131
# Epoch 1, Batch 121/240, MSE = 0.000132
# Epoch 1, Batch 122/240, MSE = 0.000140
# Epoch 1, Batch 123/240, MSE = 0.000142
# Epoch 1, Batch 124/240, MSE = 0.000127
# Epoch 1, Batch 125/240, MSE = 0.000134
# Epoch 1, Batch 126/240, MSE = 0.000141
# Epoch 1, Batch 127/240, MSE = 0.000144
# Epoch 1, Batch 128/240, MSE = 0.000128
# Epoch 1, Batch 129/240, MSE = 0.000126
# Epoch 1, Batch 130/240, MSE = 0.000116
# Epoch 1, Batch 131/240, MSE = 0.000134
# Epoch 1, Batch 132/240, MSE = 0.000144
# Epoch 1, Batch 133/240, MSE = 0.000120
# Epoch 1, Batch 134/240, MSE = 0.000131
# Epoch 1, Batch 135/240, MSE = 0.000148
# Epoch 1, Batch 136/240, MSE = 0.000129
# Epoch 1, Batch 137/240, MSE = 0.000130
# Epoch 1, Batch 138/240, MSE = 0.000126
# Epoch 1, Batch 139/240, MSE = 0.000132
# Epoch 1, Batch 140/240, MSE = 0.000133
# Epoch 1, Batch 141/240, MSE = 0.000127
# Epoch 1, Batch 142/240, MSE = 0.000136
# Epoch 1, Batch 143/240, MSE = 0.000136
# Epoch 1, Batch 144/240, MSE = 0.000121
# Epoch 1, Batch 145/240, MSE = 0.000142
# Epoch 1, Batch 146/240, MSE = 0.000121
# Epoch 1, Batch 147/240, MSE = 0.000141
# Epoch 1, Batch 148/240, MSE = 0.000130
# Epoch 1, Batch 149/240, MSE = 0.000150
# Epoch 1, Batch 150/240, MSE = 0.000119
# Epoch 1, Batch 151/240, MSE = 0.000128
# Epoch 1, Batch 152/240, MSE = 0.000137
# Epoch 1, Batch 153/240, MSE = 0.000127
# Epoch 1, Batch 154/240, MSE = 0.000125
# Epoch 1, Batch 155/240, MSE = 0.000126
# Epoch 1, Batch 156/240, MSE = 0.000128
# Epoch 1, Batch 157/240, MSE = 0.000140
# Epoch 1, Batch 158/240, MSE = 0.000127
# Epoch 1, Batch 159/240, MSE = 0.000133
# Epoch 1, Batch 160/240, MSE = 0.000129
# Epoch 1, Batch 161/240, MSE = 0.000129
# Epoch 1, Batch 162/240, MSE = 0.000134
# Epoch 1, Batch 163/240, MSE = 0.000123
# Epoch 1, Batch 164/240, MSE = 0.000126
# Epoch 1, Batch 165/240, MSE = 0.000136
# Epoch 1, Batch 166/240, MSE = 0.000134
# Epoch 1, Batch 167/240, MSE = 0.000139
# Epoch 1, Batch 168/240, MSE = 0.000122
# Epoch 1, Batch 169/240, MSE = 0.000144
# Epoch 1, Batch 170/240, MSE = 0.000137
# Epoch 1, Batch 171/240, MSE = 0.000124
# Epoch 1, Batch 172/240, MSE = 0.000124
# Epoch 1, Batch 173/240, MSE = 0.000134
# Epoch 1, Batch 174/240, MSE = 0.000134
# Epoch 1, Batch 175/240, MSE = 0.000133
# Epoch 1, Batch 176/240, MSE = 0.000120
# Epoch 1, Batch 177/240, MSE = 0.000137
# Epoch 1, Batch 178/240, MSE = 0.000119
# Epoch 1, Batch 179/240, MSE = 0.000136
# Epoch 1, Batch 180/240, MSE = 0.000125
# Epoch 1, Batch 181/240, MSE = 0.000129
# Epoch 1, Batch 182/240, MSE = 0.000138
# Epoch 1, Batch 183/240, MSE = 0.000125
# Epoch 1, Batch 184/240, MSE = 0.000130
# Epoch 1, Batch 185/240, MSE = 0.000139
# Epoch 1, Batch 186/240, MSE = 0.000122
# Epoch 1, Batch 187/240, MSE = 0.000132
# Epoch 1, Batch 188/240, MSE = 0.000131
# Epoch 1, Batch 189/240, MSE = 0.000130
# Epoch 1, Batch 190/240, MSE = 0.000131
# Epoch 1, Batch 191/240, MSE = 0.000136
# Epoch 1, Batch 192/240, MSE = 0.000123
# Epoch 1, Batch 193/240, MSE = 0.000128
# Epoch 1, Batch 194/240, MSE = 0.000121
# Epoch 1, Batch 195/240, MSE = 0.000128
# Epoch 1, Batch 196/240, MSE = 0.000131
# Epoch 1, Batch 197/240, MSE = 0.000129
# Epoch 1, Batch 198/240, MSE = 0.000129
# Epoch 1, Batch 199/240, MSE = 0.000127
# Epoch 1, Batch 200/240, MSE = 0.000125
# Epoch 1, Batch 201/240, MSE = 0.000124
# Epoch 1, Batch 202/240, MSE = 0.000117
# Epoch 1, Batch 203/240, MSE = 0.000136
# Epoch 1, Batch 204/240, MSE = 0.000126
# Epoch 1, Batch 205/240, MSE = 0.000124
# Epoch 1, Batch 206/240, MSE = 0.000138
# Epoch 1, Batch 207/240, MSE = 0.000130
# Epoch 1, Batch 208/240, MSE = 0.000132
# Epoch 1, Batch 209/240, MSE = 0.000120
# Epoch 1, Batch 210/240, MSE = 0.000134
# Epoch 1, Batch 211/240, MSE = 0.000123
# Epoch 1, Batch 212/240, MSE = 0.000123
# Epoch 1, Batch 213/240, MSE = 0.000127
# Epoch 1, Batch 214/240, MSE = 0.000116
# Epoch 1, Batch 215/240, MSE = 0.000132
# Epoch 1, Batch 216/240, MSE = 0.000119
# Epoch 1, Batch 217/240, MSE = 0.000129
# Epoch 1, Batch 218/240, MSE = 0.000131
# Epoch 1, Batch 219/240, MSE = 0.000126
# Epoch 1, Batch 220/240, MSE = 0.000119
# Epoch 1, Batch 221/240, MSE = 0.000120
# Epoch 1, Batch 222/240, MSE = 0.000115
# Epoch 1, Batch 223/240, MSE = 0.000138
# Epoch 1, Batch 224/240, MSE = 0.000125
# Epoch 1, Batch 225/240, MSE = 0.000125
# Epoch 1, Batch 226/240, MSE = 0.000136
# Epoch 1, Batch 227/240, MSE = 0.000144
# Epoch 1, Batch 228/240, MSE = 0.000133
# Epoch 1, Batch 229/240, MSE = 0.000136
# Epoch 1, Batch 230/240, MSE = 0.000128
# Epoch 1, Batch 231/240, MSE = 0.000123
# Epoch 1, Batch 232/240, MSE = 0.000126
# Epoch 1, Batch 233/240, MSE = 0.000134
# Epoch 1, Batch 234/240, MSE = 0.000123
# Epoch 1, Batch 235/240, MSE = 0.000128
# Epoch 1, Batch 236/240, MSE = 0.000124
# Epoch 1, Batch 237/240, MSE = 0.000131
# Epoch 1, Batch 238/240, MSE = 0.000115
# Epoch 1, Batch 239/240, MSE = 0.000122
# Epoch 1, Batch 240/240, MSE = 0.000122
#
# --- Training Layer 3/3 ---
# Epoch 1, Batch 1/240, MSE = 0.009932
# Epoch 1, Batch 2/240, MSE = 0.010212
# Epoch 1, Batch 3/240, MSE = 0.010023
# Epoch 1, Batch 4/240, MSE = 0.011303
# Epoch 1, Batch 5/240, MSE = 0.010548
# Epoch 1, Batch 6/240, MSE = 0.010377
# Epoch 1, Batch 7/240, MSE = 0.010570
# Epoch 1, Batch 8/240, MSE = 0.010381
# Epoch 1, Batch 9/240, MSE = 0.010456
# Epoch 1, Batch 10/240, MSE = 0.010527
# Epoch 1, Batch 11/240, MSE = 0.010043
# Epoch 1, Batch 12/240, MSE = 0.011077
# Epoch 1, Batch 13/240, MSE = 0.009746
# Epoch 1, Batch 14/240, MSE = 0.010869
# Epoch 1, Batch 15/240, MSE = 0.011515
# Epoch 1, Batch 16/240, MSE = 0.010562
# Epoch 1, Batch 17/240, MSE = 0.010014
# Epoch 1, Batch 18/240, MSE = 0.009578
# Epoch 1, Batch 19/240, MSE = 0.009452
# Epoch 1, Batch 20/240, MSE = 0.011678
# Epoch 1, Batch 21/240, MSE = 0.010300
# Epoch 1, Batch 22/240, MSE = 0.010253
# Epoch 1, Batch 23/240, MSE = 0.010025
# Epoch 1, Batch 24/240, MSE = 0.009631
# Epoch 1, Batch 25/240, MSE = 0.010951
# Epoch 1, Batch 26/240, MSE = 0.011167
# Epoch 1, Batch 27/240, MSE = 0.010370
# Epoch 1, Batch 28/240, MSE = 0.010475
# Epoch 1, Batch 29/240, MSE = 0.009355
# Epoch 1, Batch 30/240, MSE = 0.010232
# Epoch 1, Batch 31/240, MSE = 0.010589
# Epoch 1, Batch 32/240, MSE = 0.010588
# Epoch 1, Batch 33/240, MSE = 0.009735
# Epoch 1, Batch 34/240, MSE = 0.010938
# Epoch 1, Batch 35/240, MSE = 0.009695
# Epoch 1, Batch 36/240, MSE = 0.011090
# Epoch 1, Batch 37/240, MSE = 0.010526
# Epoch 1, Batch 38/240, MSE = 0.009834
# Epoch 1, Batch 39/240, MSE = 0.009791
# Epoch 1, Batch 40/240, MSE = 0.010512
# Epoch 1, Batch 41/240, MSE = 0.010398
# Epoch 1, Batch 42/240, MSE = 0.010633
# Epoch 1, Batch 43/240, MSE = 0.010143
# Epoch 1, Batch 44/240, MSE = 0.011089
# Epoch 1, Batch 45/240, MSE = 0.010430
# Epoch 1, Batch 46/240, MSE = 0.009495
# Epoch 1, Batch 47/240, MSE = 0.011081
# Epoch 1, Batch 48/240, MSE = 0.010452
# Epoch 1, Batch 49/240, MSE = 0.010016
# Epoch 1, Batch 50/240, MSE = 0.009724
# Epoch 1, Batch 51/240, MSE = 0.010918
# Epoch 1, Batch 52/240, MSE = 0.011254
# Epoch 1, Batch 53/240, MSE = 0.010178
# Epoch 1, Batch 54/240, MSE = 0.009614
# Epoch 1, Batch 55/240, MSE = 0.011336
# Epoch 1, Batch 56/240, MSE = 0.010498
# Epoch 1, Batch 57/240, MSE = 0.010124
# Epoch 1, Batch 58/240, MSE = 0.009419
# Epoch 1, Batch 59/240, MSE = 0.010247
# Epoch 1, Batch 60/240, MSE = 0.009565
# Epoch 1, Batch 61/240, MSE = 0.008954
# Epoch 1, Batch 62/240, MSE = 0.010373
# Epoch 1, Batch 63/240, MSE = 0.010555
# Epoch 1, Batch 64/240, MSE = 0.010500
# Epoch 1, Batch 65/240, MSE = 0.009762
# Epoch 1, Batch 66/240, MSE = 0.010129
# Epoch 1, Batch 67/240, MSE = 0.010241
# Epoch 1, Batch 68/240, MSE = 0.010876
# Epoch 1, Batch 69/240, MSE = 0.010313
# Epoch 1, Batch 70/240, MSE = 0.010311
# Epoch 1, Batch 71/240, MSE = 0.009698
# Epoch 1, Batch 72/240, MSE = 0.010250
# Epoch 1, Batch 73/240, MSE = 0.010575
# Epoch 1, Batch 74/240, MSE = 0.009626
# Epoch 1, Batch 75/240, MSE = 0.010231
# Epoch 1, Batch 76/240, MSE = 0.010641
# Epoch 1, Batch 77/240, MSE = 0.009279
# Epoch 1, Batch 78/240, MSE = 0.010245
# Epoch 1, Batch 79/240, MSE = 0.009939
# Epoch 1, Batch 80/240, MSE = 0.010876
# Epoch 1, Batch 81/240, MSE = 0.010417
# Epoch 1, Batch 82/240, MSE = 0.010247
# Epoch 1, Batch 83/240, MSE = 0.009865
# Epoch 1, Batch 84/240, MSE = 0.010394
# Epoch 1, Batch 85/240, MSE = 0.010145
# Epoch 1, Batch 86/240, MSE = 0.010703
# Epoch 1, Batch 87/240, MSE = 0.009883
# Epoch 1, Batch 88/240, MSE = 0.011055
# Epoch 1, Batch 89/240, MSE = 0.009753
# Epoch 1, Batch 90/240, MSE = 0.010917
# Epoch 1, Batch 91/240, MSE = 0.010504
# Epoch 1, Batch 92/240, MSE = 0.009812
# Epoch 1, Batch 93/240, MSE = 0.009368
# Epoch 1, Batch 94/240, MSE = 0.010810
# Epoch 1, Batch 95/240, MSE = 0.009649
# Epoch 1, Batch 96/240, MSE = 0.010258
# Epoch 1, Batch 97/240, MSE = 0.010457
# Epoch 1, Batch 98/240, MSE = 0.009604
# Epoch 1, Batch 99/240, MSE = 0.010777
# Epoch 1, Batch 100/240, MSE = 0.011357
# Epoch 1, Batch 101/240, MSE = 0.009843
# Epoch 1, Batch 102/240, MSE = 0.010436
# Epoch 1, Batch 103/240, MSE = 0.009746
# Epoch 1, Batch 104/240, MSE = 0.009767
# Epoch 1, Batch 105/240, MSE = 0.009714
# Epoch 1, Batch 106/240, MSE = 0.010614
# Epoch 1, Batch 107/240, MSE = 0.009800
# Epoch 1, Batch 108/240, MSE = 0.010910
# Epoch 1, Batch 109/240, MSE = 0.010338
# Epoch 1, Batch 110/240, MSE = 0.010648
# Epoch 1, Batch 111/240, MSE = 0.009547
# Epoch 1, Batch 112/240, MSE = 0.010299
# Epoch 1, Batch 113/240, MSE = 0.010053
# Epoch 1, Batch 114/240, MSE = 0.010398
# Epoch 1, Batch 115/240, MSE = 0.010850
# Epoch 1, Batch 116/240, MSE = 0.010094
# Epoch 1, Batch 117/240, MSE = 0.010387
# Epoch 1, Batch 118/240, MSE = 0.011139
# Epoch 1, Batch 119/240, MSE = 0.010491
# Epoch 1, Batch 120/240, MSE = 0.011016
# Epoch 1, Batch 121/240, MSE = 0.009965
# Epoch 1, Batch 122/240, MSE = 0.010928
# Epoch 1, Batch 123/240, MSE = 0.010200
# Epoch 1, Batch 124/240, MSE = 0.010539
# Epoch 1, Batch 125/240, MSE = 0.010122
# Epoch 1, Batch 126/240, MSE = 0.011113
# Epoch 1, Batch 127/240, MSE = 0.010307
# Epoch 1, Batch 128/240, MSE = 0.011162
# Epoch 1, Batch 129/240, MSE = 0.009631
# Epoch 1, Batch 130/240, MSE = 0.010433
# Epoch 1, Batch 131/240, MSE = 0.010332
# Epoch 1, Batch 132/240, MSE = 0.010350
# Epoch 1, Batch 133/240, MSE = 0.010496
# Epoch 1, Batch 134/240, MSE = 0.010455
# Epoch 1, Batch 135/240, MSE = 0.009114
# Epoch 1, Batch 136/240, MSE = 0.010616
# Epoch 1, Batch 137/240, MSE = 0.010348
# Epoch 1, Batch 138/240, MSE = 0.009846
# Epoch 1, Batch 139/240, MSE = 0.010231
# Epoch 1, Batch 140/240, MSE = 0.009783
# Epoch 1, Batch 141/240, MSE = 0.010161
# Epoch 1, Batch 142/240, MSE = 0.009514
# Epoch 1, Batch 143/240, MSE = 0.010460
# Epoch 1, Batch 144/240, MSE = 0.009647
# Epoch 1, Batch 145/240, MSE = 0.010694
# Epoch 1, Batch 146/240, MSE = 0.010118
# Epoch 1, Batch 147/240, MSE = 0.010204
# Epoch 1, Batch 148/240, MSE = 0.009633
# Epoch 1, Batch 149/240, MSE = 0.010289
# Epoch 1, Batch 150/240, MSE = 0.009956
# Epoch 1, Batch 151/240, MSE = 0.010781
# Epoch 1, Batch 152/240, MSE = 0.011346
# Epoch 1, Batch 153/240, MSE = 0.009629
# Epoch 1, Batch 154/240, MSE = 0.009731
# Epoch 1, Batch 155/240, MSE = 0.009999
# Epoch 1, Batch 156/240, MSE = 0.010072
# Epoch 1, Batch 157/240, MSE = 0.010289
# Epoch 1, Batch 158/240, MSE = 0.009639
# Epoch 1, Batch 159/240, MSE = 0.010071
# Epoch 1, Batch 160/240, MSE = 0.009575
# Epoch 1, Batch 161/240, MSE = 0.010642
# Epoch 1, Batch 162/240, MSE = 0.010685
# Epoch 1, Batch 163/240, MSE = 0.009580
# Epoch 1, Batch 164/240, MSE = 0.010099
# Epoch 1, Batch 165/240, MSE = 0.009800
# Epoch 1, Batch 166/240, MSE = 0.010143
# Epoch 1, Batch 167/240, MSE = 0.010364
# Epoch 1, Batch 168/240, MSE = 0.011266
# Epoch 1, Batch 169/240, MSE = 0.009899
# Epoch 1, Batch 170/240, MSE = 0.010334
# Epoch 1, Batch 171/240, MSE = 0.009513
# Epoch 1, Batch 172/240, MSE = 0.009873
# Epoch 1, Batch 173/240, MSE = 0.009702
# Epoch 1, Batch 174/240, MSE = 0.010552
# Epoch 1, Batch 175/240, MSE = 0.010934
# Epoch 1, Batch 176/240, MSE = 0.009835
# Epoch 1, Batch 177/240, MSE = 0.009697
# Epoch 1, Batch 178/240, MSE = 0.010150
# Epoch 1, Batch 179/240, MSE = 0.010842
# Epoch 1, Batch 180/240, MSE = 0.009923
# Epoch 1, Batch 181/240, MSE = 0.010230
# Epoch 1, Batch 182/240, MSE = 0.010519
# Epoch 1, Batch 183/240, MSE = 0.010085
# Epoch 1, Batch 184/240, MSE = 0.010217
# Epoch 1, Batch 185/240, MSE = 0.010209
# Epoch 1, Batch 186/240, MSE = 0.010432
# Epoch 1, Batch 187/240, MSE = 0.010044
# Epoch 1, Batch 188/240, MSE = 0.008488
# Epoch 1, Batch 189/240, MSE = 0.010079
# Epoch 1, Batch 190/240, MSE = 0.010505
# Epoch 1, Batch 191/240, MSE = 0.009148
# Epoch 1, Batch 192/240, MSE = 0.010856
# Epoch 1, Batch 193/240, MSE = 0.009443
# Epoch 1, Batch 194/240, MSE = 0.010361
# Epoch 1, Batch 195/240, MSE = 0.010502
# Epoch 1, Batch 196/240, MSE = 0.009557
# Epoch 1, Batch 197/240, MSE = 0.009898
# Epoch 1, Batch 198/240, MSE = 0.010279
# Epoch 1, Batch 199/240, MSE = 0.010480
# Epoch 1, Batch 200/240, MSE = 0.010777
# Epoch 1, Batch 201/240, MSE = 0.010042
# Epoch 1, Batch 202/240, MSE = 0.009942
# Epoch 1, Batch 203/240, MSE = 0.010045
# Epoch 1, Batch 204/240, MSE = 0.010093
# Epoch 1, Batch 205/240, MSE = 0.009548
# Epoch 1, Batch 206/240, MSE = 0.010346
# Epoch 1, Batch 207/240, MSE = 0.010067
# Epoch 1, Batch 208/240, MSE = 0.009937
# Epoch 1, Batch 209/240, MSE = 0.009702
# Epoch 1, Batch 210/240, MSE = 0.009666
# Epoch 1, Batch 211/240, MSE = 0.010402
# Epoch 1, Batch 212/240, MSE = 0.011309
# Epoch 1, Batch 213/240, MSE = 0.010101
# Epoch 1, Batch 214/240, MSE = 0.011027
# Epoch 1, Batch 215/240, MSE = 0.010261
# Epoch 1, Batch 216/240, MSE = 0.010291
# Epoch 1, Batch 217/240, MSE = 0.010414
# Epoch 1, Batch 218/240, MSE = 0.010053
# Epoch 1, Batch 219/240, MSE = 0.011012
# Epoch 1, Batch 220/240, MSE = 0.010357
# Epoch 1, Batch 221/240, MSE = 0.010120
# Epoch 1, Batch 222/240, MSE = 0.010700
# Epoch 1, Batch 223/240, MSE = 0.010117
# Epoch 1, Batch 224/240, MSE = 0.010849
# Epoch 1, Batch 225/240, MSE = 0.010101
# Epoch 1, Batch 226/240, MSE = 0.009602
# Epoch 1, Batch 227/240, MSE = 0.010345
# Epoch 1, Batch 228/240, MSE = 0.010247
# Epoch 1, Batch 229/240, MSE = 0.009449
# Epoch 1, Batch 230/240, MSE = 0.010456
# Epoch 1, Batch 231/240, MSE = 0.010570
# Epoch 1, Batch 232/240, MSE = 0.009666
# Epoch 1, Batch 233/240, MSE = 0.010927
# Epoch 1, Batch 234/240, MSE = 0.009431
# Epoch 1, Batch 235/240, MSE = 0.010234
# Epoch 1, Batch 236/240, MSE = 0.009466
# Epoch 1, Batch 237/240, MSE = 0.010125
# Epoch 1, Batch 238/240, MSE = 0.010393
# Epoch 1, Batch 239/240, MSE = 0.010578
# Epoch 1, Batch 240/240, MSE = 0.009290
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)
    
    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")
    
    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Layer 2 weights saved to: weights_bamv3_complex/weights_layer_2.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"
    
    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")
    
    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")
        
        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")
        
        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")
            
            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -30    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# -------------------------------------------------------------
# [최종 수정] 길이 보정 및 에너지 정규화
# -------------------------------------------------------------

# 1. 🔧 길이 보정: Resample (필수!)
# 딥러닝 모델 출력(시간축 압축됨)을 원래 LoRa 심볼 길이(2048)로 복원
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (예: 2048)
cur_len = len(iq_reconstructed)

if cur_len != target_len:
    if cur_len > target_len:
        # 🔪 TRIM: 가운데 부분만 남기기 (시간 정렬 유지)
        diff = cur_len - target_len
        start = diff // 2
        end = start + target_len
        iq_reconstructed = iq_reconstructed[start:end]
        print(f"   🔧 Trimmed: {cur_len} -> {target_len} samples (center slice)")
    else:
        # 🩹 PADDING: 앞/뒤로 0 채우기 (대칭 padding)
        diff = target_len - cur_len
        pad_left = diff // 2
        pad_right = diff - pad_left
        iq_reconstructed = np.pad(
            iq_reconstructed,
            (pad_left, pad_right),
            mode="constant",
            constant_values=0,
        )
        print(f"   🔧 Padded: {cur_len} -> {target_len} samples (zero padding)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")


# 2. ⭐ 에너지 정규화: Standardization (수정됨!)
# 기존(Noisy 에너지 기준)은 위험하므로, 통신 표준인 'Unit Power (std=1)'로 변경
# 이렇게 하면 신호 크기가 적절하게 맞춰져서 디코더가 가장 잘 인식합니다.

iq_std = np.std(iq_reconstructed)

if iq_std > 1e-12:  # 0 나누기 방지 (신호가 살아있는 경우)
    # 평균을 0으로, 표준편차를 1로 맞춤 (Z-score normalization과 유사)
    iq_reconstructed = (iq_reconstructed - np.mean(iq_reconstructed)) / iq_std
    
    print(f"   🔧 Normalized to Unit Power (std=1.0)")
    # 확인용 출력
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

else:
    # 신호가 거의 0인 경우 (복원 실패 또는 무음 구간)
    print(f"   ⚠️ Warning: Reconstructed signal is essentially silence. No scaling applied.")

# -------------------------------------------------------------

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -30 dB
#
# === Normalization Parameters ===
# Real: min=-7.550393, max=9.564432, range=17.114825
# Imag: min=-7.676424, max=9.672865, range=17.349289
# Restored norm: real_min=0.1124, real_max=0.8062
# Restored norm: imag_min=0.1052, imag_max=0.7632
# After denorm:  real_min=-5.626892, real_max=6.247081
# After denorm:  imag_min=-5.851278, imag_max=5.564614
# ✅ IQ signal reconstructed: (2048,)
#    ✅ Length already matches: 2048 samples
#    🔧 Normalized to Unit Power (std=1.0)
#    Energy after scaling:  |mean|=0.385835, |max|=38.804361
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.4414
# Restored flat: min=0.1052, max=0.8062, mean=0.4420
# Difference:    MSE=0.009921
# /tmp/ipykernel_8310/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0004, max=0.0917
# Zxx_restored (magnitude): min=0.0435, max=6.2495
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3_huber successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3_huber failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=27.8951, |max|=84.6343
# Reconstructed:   len=2048, |mean|=0.3858, |max|=38.8044
#
# MSE Comparison:
# Clean vs Noisy:        994.974479
# Clean vs Reconstructed: 1.980683
# Noisy vs Reconstructed: 989.325047
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 4194303.99
# ⚠️  Noisy signal (len=2048)    → Code: 98, Peak: 27868830.93
# 🔧 Restored (len=2048)   → Code: 30, Peak: 20716.32
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       98 ❌ WRONG
# Restored Decoded:    30 ❌ WRONG
# ============================================================
#
# Peak Comparison:
# Clean Peak:    4194303.99
# Noisy Peak:    27868830.93 (664.4% of clean)
# Restored Peak: 20716.32 (0.5% of clean)
#
# ❌ FAILURE: BAMv3_huber failed to restore the correct symbol

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)")
print("="*70)

# 1. 테스트 파라미터 설정 ( -30dB 추가 완료 )
NUM_TEST_SAMPLES = 1000  # 샘플 수
TEST_SNR_LEVELS = [-30, -25, -20, -15, -10, -5]  # ⭐ -30dB 추가됨!

# 결과 저장용 딕셔너리
results = {
    snr: {
        'bam_correct': 0, 'bam_total': 0, 'bam_mse': [], 'bam_peak_ratio': [],
        'base_correct': 0, 'base_total': 0, 'base_peak_ratio': [],
    }
    for snr in TEST_SNR_LEVELS
}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")
    
    for i in range(NUM_TEST_SAMPLES):
        try:
            # 랜덤 심볼 선택
            test_sym = np.random.randint(0, 512)
            
            # 1. 클린 IQ & 노이즈 추가
            clean_iq_test = X_clean_iq[test_sym]
            noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)
            
            # 2. Complex 스펙트로그램 생성
            noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)
            
            # 3. BAMv3 복원 (Compress -> Decompress)
            compressed = model.compress(noisy_flat.reshape(1, -1))
            restored_flat = model.decompress(compressed).flatten()
            
            # 4. IQ 신호 재구성 (1차)
            iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)

            # ====================================================
            # ⭐ [수정] 길이 보정: Trim / Padding + 에너지 정규화
            # ====================================================
            target_len = len(clean_iq_test)
            cur_len = len(iq_restored)

            # (1) 길이 보정: resample 금지, trim / padding만 사용
            if cur_len != target_len:
                if cur_len > target_len:
                    # 가운데 기준으로 잘라서 타이밍 유지
                    diff = cur_len - target_len
                    start = diff // 2
                    end = start + target_len
                    iq_restored = iq_restored[start:end]
                    # print(f"   🔧 Trimmed: {cur_len} -> {target_len}")
                else:
                    # 부족하면 앞/뒤에 0 패딩 (대칭 padding)
                    diff = target_len - cur_len
                    pad_left = diff // 2
                    pad_right = diff - pad_left
                    iq_restored = np.pad(
                        iq_restored,
                        (pad_left, pad_right),
                        mode="constant",
                        constant_values=0,
                    )
                    # print(f"   🔧 Padded: {cur_len} -> {target_len}")
            # else:
            #     print(f"   ✅ Length already matches: {target_len}")

            # (2) 에너지 정규화 (mean/std 표준화 X, power만 맞춤)
            power = np.mean(np.abs(iq_restored) ** 2)
            if power > 1e-12:
                iq_restored = iq_restored / np.sqrt(power)
            # ====================================================

            # 5. Dechirp 및 심볼 추정 (Baseline vs BAM)
            # 기준: 클린 신호
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, sf, fs, bw)
            
            # Baseline: noisy 신호
            code_base, peak_base = estimate_symbol_custom(noisy_iq_test, sf, fs, bw)
            
            # BAM 경로: 복원된 IQ
            code_bam, peak_bam = estimate_symbol_custom(iq_restored, sf, fs, bw)
            
            # -----------------------------
            # 결과 기록
            # -----------------------------
            # 1) Baseline Accuracy
            if code_base == test_sym: results[snr]['base_correct'] += 1
            results[snr]['base_total'] += 1
            
            # 2) BAM Accuracy
            if code_bam == test_sym: results[snr]['bam_correct'] += 1
            results[snr]['bam_total'] += 1
            
            # 3) Peak Ratio
            if peak_clean > 0:
                results[snr]['base_peak_ratio'].append(peak_base / peak_clean)
                results[snr]['bam_peak_ratio'].append(peak_bam / peak_clean)
            
            # 4) MSE (복원 품질)
            # MSE 계산 시에는 크기(Scale) 차이 때문에 정규화된 것끼리 비교하거나, 
            # 단순히 복원력 확인용으로만 참고합니다.
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['bam_mse'].append(mse)
            
        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['base_total'] += 1
            results[snr]['bam_total'] += 1
    
    # 중간 결과 출력
    base_acc = (results[snr]['base_correct'] / results[snr]['base_total'] * 100) if results[snr]['base_total'] > 0 else 0
    bam_acc = (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100) if results[snr]['bam_total'] > 0 else 0
    
    print(f"  ✓ Baseline Acc : {base_acc:.1f}%")
    print(f"  ✓ BAM Accuracy : {bam_acc:.1f}%")

# 최종 결과 요약 출력 및 그래프 그리기 (기존 코드와 동일)
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)
print(f"\n{'SNR':<6} {'Base Acc':<10} {'BAM Acc':<10} {'Improvement':<12}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    b_acc = results[snr]['base_correct'] / results[snr]['base_total'] * 100
    m_acc = results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
    imp = m_acc - b_acc
    print(f"{snr:<6} {b_acc:>8.1f}%  {m_acc:>8.1f}%  {imp:>+10.1f}%p")

# 그래프 그리기
plt.figure(figsize=(10, 5))
snrs = TEST_SNR_LEVELS
base_accs = [results[s]['base_correct']/results[s]['base_total']*100 for s in snrs]
bam_accs = [results[s]['bam_correct']/results[s]['bam_total']*100 for s in snrs]

plt.plot(snrs, base_accs, 'o--', label='Standard LoRa (Baseline)', color='gray')
plt.plot(snrs, bam_accs, 's-', label='Proposed BAMv3', color='red', linewidth=2)
plt.axvline(x=-20, color='orange', linestyle=':', label='LoRa Limit (-20dB)')

plt.xlabel('SNR (dB)')
plt.ylabel('Symbol Accuracy (%)')
plt.title('Decoding Performance: Baseline vs BAMv3')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)
# ======================================================================
#
# 🧪 Testing with 1000 samples at each SNR level...
# SNR levels: [-30, -25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -30 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_8310/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Baseline Acc : 2.7%
#   ✓ BAM Accuracy : 5.4%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 17.0%
#   ✓ BAM Accuracy : 28.6%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 81.8%
#   ✓ BAM Accuracy : 81.3%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 99.1%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 100.0%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 100.0%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR    Base Acc   BAM Acc    Improvement
# ──────────────────────────────────────────────────────────────────────
# -30         2.7%       5.4%        +2.7%p
# -25        17.0%      28.6%       +11.6%p
# -20        81.8%      81.3%        -0.5%p
# -15       100.0%      99.1%        -0.9%p
# -10       100.0%     100.0%        +0.0%p
# -5        100.0%     100.0%        +0.0%p
