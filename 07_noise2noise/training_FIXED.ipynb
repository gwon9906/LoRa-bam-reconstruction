# %% [markdown]
# # BAMv3 실험: 노이즈→노이즈 학습
#
# **Ultra-low SNR 환경을 위한 Robust Feature Learning**
# - Self-supervised 학습 방식
# - 다양한 SNR에서 일관된 패턴 학습
# - 병목 효과로 랜덤 노이즈 제거
# - 노이즈 범위 줄임(0~-7.5db)
# - 아키텍쳐 구조(7936 → 2048 → 512)

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.LoRa import LoRa, MultiBAMv3
import importlib
import utils.my_lora_utils
importlib.reload(utils.my_lora_utils)
from utils.my_lora_utils import *

print(utils.my_lora_utils.__file__)
# Out:
# /home/gwon9906/LoRa-bam-reconstruction/utils/my_lora_utils.py

# %%
from scipy.signal import stft, istft

STFT_PARAMS = {
    'nperseg': 128,
    'noverlap': 64,
    'nfft': 512,
    'window': 'hann'
}

def generate_complex_spectrogram(iq_signal, fs, bw=250_000):
    nperseg  = STFT_PARAMS['nperseg']
    noverlap = STFT_PARAMS['noverlap']
    nfft     = STFT_PARAMS['nfft']
    window   = STFT_PARAMS['window']

    # 2. stft 호출 시 nfft 전달
    f, t, Zxx = stft(
        iq_signal,
        fs=fs,
        window=window,
        nperseg=nperseg,
        noverlap=noverlap,
        nfft=nfft,
        boundary=None,
        padded=False,
        return_onesided=False
    )

    # 2) 주파수축 shift 후 BW 크롭
    f_shifted    = np.fft.fftshift(f)
    Zxx_shifted  = np.fft.fftshift(Zxx, axes=0)
    original_shape = Zxx_shifted.shape

    mask = (f_shifted >= -bw/2) & (f_shifted < bw/2)
    freq_indices = np.where(mask)[0]
    Zxx_cropped  = Zxx_shifted[mask, :]   # (F_bw, T)

    # 3) Real / Imag 분리 + min-max 정규화
    real_part = Zxx_cropped.real
    imag_part = Zxx_cropped.imag

    r_min, r_max = real_part.min(), real_part.max()
    i_min, i_max = imag_part.min(), imag_part.max()

    real_norm = (real_part - r_min) / (r_max - r_min + 1e-12)
    imag_norm = (imag_part - i_min) / (i_max - i_min + 1e-12)

    # 4) 플랫 벡터로 합치기
    real_flat = real_norm.flatten()
    imag_flat = imag_norm.flatten()
    combined_flat = np.concatenate([real_flat, imag_flat])

    # 5) 복원을 위한 메타 정보 저장
    norm_params = {
        'r_min': r_min, 'r_max': r_max,
        'i_min': i_min, 'i_max': i_max,
        'shape': Zxx_cropped.shape,        # (F_bw, T)
        'original_shape': original_shape,  # full Zxx shape
        'freq_indices': freq_indices,
        'stft_params': STFT_PARAMS.copy(),
        'orig_len': len(iq_signal),        # 원래 IQ 길이 (예: 2048)
    }

    return combined_flat, norm_params

def reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs):
    """
    BAM 복원 스펙트로그램(flat) → complex STFT → ISTFT → IQ 신호
    (재학습 버전용)
    """
    cropped_shape = norm_params['shape']   # (F_bw, T)
    mid = len(restored_flat) // 2

    # 1) Real/Imag 복원 + reshape
    real_restored_norm = restored_flat[:mid].reshape(cropped_shape)
    imag_restored_norm = restored_flat[mid:].reshape(cropped_shape)

    # 2) 역정규화
    real_restored = (
        real_restored_norm * (norm_params['r_max'] - norm_params['r_min'])
        + norm_params['r_min']
    )
    imag_restored = (
        imag_restored_norm * (norm_params['i_max'] - norm_params['i_min'])
        + norm_params['i_min']
    )

    Zxx_cropped = real_restored + 1j * imag_restored   # (F_bw, T)

    # 3) full STFT 행렬로 복원
    Zxx_full = np.zeros(norm_params['original_shape'], dtype=complex)
    Zxx_full[norm_params['freq_indices'], :] = Zxx_cropped

    # 4) ifftshift로 원래 STFT 형태로 되돌림
    Zxx_unshifted = np.fft.ifftshift(Zxx_full, axes=0)

    # 5) ISTFT (STFT와 완전히 동일한 파라미터 사용)
    stft_params = norm_params['stft_params']
    _, iq_restored = istft(
        Zxx_unshifted,
        fs=fs,
        window=stft_params['window'],
        nperseg=stft_params['nperseg'],
        noverlap=stft_params['noverlap'],
        nfft=stft_params['nfft'],
        input_onesided=False,
        boundary=None,
    )

    # 6) 길이 보정 (pad/crop만, resample 사용 ❌)
    target_len = norm_params.get('orig_len', len(iq_restored))

    if len(iq_restored) > target_len:
        iq_restored = iq_restored[:target_len]
    elif len(iq_restored) < target_len:
        iq_restored = np.pad(iq_restored, (0, target_len - len(iq_restored)), mode='edge')

    return iq_restored

# %%
# LoRa 파라미터 설정
sf = 9
bw = 250_000  # 250 kHz
OSF = 4
fs = int(bw * OSF)  # 1 MHz

print(f"SF = {sf}, BW = {bw/1e3:.1f} kHz, fs = {fs/1e6:.3f} MHz")

# LoRa 인스턴스 생성 (on-the-fly 노이즈 추가용)
lora = LoRa(sf=sf, bw=bw, OSF=OSF)
fs = lora.fs   # = bw * OSF
# Out:
# SF = 9, BW = 250.0 kHz, fs = 1.000 MHz

# %%
########################################
##  1. 클린 IQ 데이터 로드            ##
########################################

base_dir = "dataset_v3_sf9_bw250k"
iq_dir = os.path.join(base_dir, "clean_iq")

print("Loading clean IQ data...")
iq_files = sorted(glob.glob(os.path.join(iq_dir, "*.npy")))
print(f"Found {len(iq_files)} clean IQ files")

# 클린 IQ 로드
iq_data_list = []
for f in iq_files:
    x_clean = np.load(f)  # complex IQ
    iq_data_list.append(x_clean)

X_clean_iq = np.array(iq_data_list)
print(f"Clean IQ shape: {X_clean_iq.shape}, dtype: {X_clean_iq.dtype}")
# Out:
# Loading clean IQ data...
# Found 512 clean IQ files
# Clean IQ shape: (512, 2048), dtype: complex64

# %%
########################################
##  2. 데이터 증강 함수 정의          ##
########################################

# SNR 범위 설정 (SNR에 집중)
SNR_MIN = -7.5
SNR_MAX = 0
AUGMENT_FACTOR = 30  # 각 클린 IQ를 30배로 증강

def augment_dataset(X_clean_iq, augment_factor=30):
    """
    클린 IQ를 N배로 증강 (매번 다른 랜덤 노이즈 추가)
    Complex 스펙트로그램 사용 (Phase 정보 보존)

    Returns:
        X_noisy_flat: (512*augment_factor, input_dim) 형태
        norm_params_list: 각 샘플의 역정규화 파라미터
    """
    print(f"\nGenerating {len(X_clean_iq)} × {augment_factor} = {len(X_clean_iq) * augment_factor} augmented samples...")

    X_noisy_flat_list = []
    norm_params_list = []

    for clean_iq in X_clean_iq:
        for _ in range(augment_factor):
            # 랜덤 SNR 선택
            snr = np.random.randint(SNR_MIN, SNR_MAX + 1)

            # 노이즈 추가
            noisy_iq = lora.awgn_iq(clean_iq, snr)

            # Complex 스펙트로그램 생성 (Phase 보존)
            spec_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)
            X_noisy_flat_list.append(spec_flat)
            norm_params_list.append(norm_params)

    X_noisy_flat = np.array(X_noisy_flat_list)

    print(f"Augmented dataset shape: {X_noisy_flat.shape}")
    print(f"  - Real/Imag combined (Phase preserved)")

    return X_noisy_flat, norm_params_list

print(f"✅ Complex augmentation function defined: {AUGMENT_FACTOR}x per clean IQ")
# Out:
# ✅ Complex augmentation function defined: 30x per clean IQ

# %%
########################################
##  3. 모델 아키텍처 설정             ##
########################################

# Complex 스펙트로그램 shape 확인을 위한 테스트 (1개만)
test_spec_flat, test_params = generate_complex_spectrogram(X_clean_iq[0], fs, bw)
input_dim = test_spec_flat.shape[0]  # Real + Imag 통합 (2배)

# 점진적 압축: 7936 → 4096 → 3072 → 2048
layers = [input_dim, 2048, 512]

print(f"Complex spectrogram shape: {test_params['shape']}")
print(f"Input dim (Real+Imag): {input_dim}")
print(f"Model architecture: {' → '.join(map(str, layers))}")
print(f"Compression ratio: {input_dim / layers[-1]:.1f}x")
print(f"Layers: {len(layers)-1} BAM layers (더 부드러운 압축)")
# Out:
# Complex spectrogram shape: (128, 31)
# Input dim (Real+Imag): 7936
# Model architecture: 7936 → 2048 → 512
# Compression ratio: 15.5x
# Layers: 2 BAM layers (더 부드러운 압축)

# %%
########################################
##  4. BAMv3 Complex 30배 증강 학습  ##
########################################

print(f"\n=== Training BAMv3 Model (Complex Spectrogram) ===")
print(f"Architecture: {' → '.join(map(str, layers))}")
print(f"Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)")

# BAMv3 모델 생성 (학습률 조정: 3-layer BAM에 적합한 lr)
model = MultiBAMv3(layers_dims=layers, eta=5e-4)

# 학습 플래그
TRAIN = True # 테스트 전에는 False

if TRAIN:
    print("\n=== Starting Training with On-the-fly Complex Augmentation ===")
    print(f"Base samples: {len(X_clean_iq)}")
    print(f"Augmentation factor: {AUGMENT_FACTOR}x")
    print(f"Total per epoch: {len(X_clean_iq) * AUGMENT_FACTOR}")

    # 학습 파라미터
    num_epochs = 30
    batch_size = 64

    all_layer_losses = [[] for _ in range(len(layers)-1)]

    # 매 epoch마다 새로운 노이즈로 증강
    for epoch in range(num_epochs):
        print(f"\n{'='*60}")
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"{'='*60}")

        # 30배 증강된 Complex 데이터 생성 (매 epoch마다 다른 노이즈!)
        X_augmented, _ = augment_dataset(X_clean_iq, AUGMENT_FACTOR)

        # 1 epoch만 학습 (이미 증강된 데이터로)
        layer_losses = model.train(X_augmented, num_epochs=1, batch_size=batch_size)

        # Loss 기록
        for i, losses in enumerate(layer_losses):
            all_layer_losses[i].extend(losses)

    print("\n=== Training Complete ===")

    # Loss 플롯 (각 layer별)
    fig, axes = plt.subplots(1, len(all_layer_losses), figsize=(15, 4))
    if len(all_layer_losses) == 1:
        axes = [axes]

    for i, losses in enumerate(all_layer_losses):
        axes[i].plot(losses)
        axes[i].set_xlabel('Batch')
        axes[i].set_ylabel('MSE Loss')
        axes[i].set_title(f'Layer {i+1} Training Loss (Complex)')
        axes[i].grid(True)

    plt.tight_layout()
    plt.show()
else:
    print("\nTraining skipped (TRAIN=False)")
# Out:
# === Training BAMv3 Model (Complex Spectrogram) ===
# Architecture: 7936 → 2048 → 512
# Strategy: On-the-fly 30x Augmentation per Epoch (Phase Preserved)
# === Starting Training with On-the-fly Complex Augmentation ===
# Base samples: 512
# Augmentation factor: 30x
# Total per epoch: 15360
#
# ============================================================
# Epoch 1/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/2 ---
# Epoch 1, Batch 1/240, MSE = 0.023036
# Epoch 1, Batch 2/240, MSE = 0.013375
# Epoch 1, Batch 3/240, MSE = 0.013759
# Epoch 1, Batch 4/240, MSE = 0.013410
# Epoch 1, Batch 5/240, MSE = 0.013598
# Epoch 1, Batch 6/240, MSE = 0.013268
# Epoch 1, Batch 7/240, MSE = 0.013421
# Epoch 1, Batch 8/240, MSE = 0.013520
# Epoch 1, Batch 9/240, MSE = 0.013457
# Epoch 1, Batch 10/240, MSE = 0.013476
# Epoch 1, Batch 11/240, MSE = 0.013165
# Epoch 1, Batch 12/240, MSE = 0.013267
# Epoch 1, Batch 13/240, MSE = 0.013366
# Epoch 1, Batch 14/240, MSE = 0.013694
# Epoch 1, Batch 15/240, MSE = 0.013694
# Epoch 1, Batch 16/240, MSE = 0.013217
# Epoch 1, Batch 17/240, MSE = 0.013579
# Epoch 1, Batch 18/240, MSE = 0.013615
# Epoch 1, Batch 19/240, MSE = 0.013390
# Epoch 1, Batch 20/240, MSE = 0.012976
# Epoch 1, Batch 21/240, MSE = 0.012798
# Epoch 1, Batch 22/240, MSE = 0.012870
# Epoch 1, Batch 23/240, MSE = 0.013238
# Epoch 1, Batch 24/240, MSE = 0.013254
# Epoch 1, Batch 25/240, MSE = 0.013216
# Epoch 1, Batch 26/240, MSE = 0.013063
# Epoch 1, Batch 27/240, MSE = 0.012661
# Epoch 1, Batch 28/240, MSE = 0.012958
# Epoch 1, Batch 29/240, MSE = 0.012967
# Epoch 1, Batch 30/240, MSE = 0.013073
# Epoch 1, Batch 31/240, MSE = 0.012870
# Epoch 1, Batch 32/240, MSE = 0.013205
# Epoch 1, Batch 33/240, MSE = 0.013273
# Epoch 1, Batch 34/240, MSE = 0.012801
# Epoch 1, Batch 35/240, MSE = 0.013139
# Epoch 1, Batch 36/240, MSE = 0.013480
# Epoch 1, Batch 37/240, MSE = 0.012862
# Epoch 1, Batch 38/240, MSE = 0.012911
# Epoch 1, Batch 39/240, MSE = 0.012797
# Epoch 1, Batch 40/240, MSE = 0.012790
# Epoch 1, Batch 41/240, MSE = 0.012714
# Epoch 1, Batch 42/240, MSE = 0.013063
# Epoch 1, Batch 43/240, MSE = 0.012852
# Epoch 1, Batch 44/240, MSE = 0.013432
# Epoch 1, Batch 45/240, MSE = 0.012544
# Epoch 1, Batch 46/240, MSE = 0.012570
# Epoch 1, Batch 47/240, MSE = 0.012362
# Epoch 1, Batch 48/240, MSE = 0.012853
# Epoch 1, Batch 49/240, MSE = 0.012670
# Epoch 1, Batch 50/240, MSE = 0.012795
# Epoch 1, Batch 51/240, MSE = 0.012681
# Epoch 1, Batch 52/240, MSE = 0.012728
# Epoch 1, Batch 53/240, MSE = 0.012556
# Epoch 1, Batch 54/240, MSE = 0.012825
# Epoch 1, Batch 55/240, MSE = 0.012928
# Epoch 1, Batch 56/240, MSE = 0.012348
# Epoch 1, Batch 57/240, MSE = 0.012539
# Epoch 1, Batch 58/240, MSE = 0.013211
# Epoch 1, Batch 59/240, MSE = 0.012509
# Epoch 1, Batch 60/240, MSE = 0.012670
# Epoch 1, Batch 61/240, MSE = 0.012739
# Epoch 1, Batch 62/240, MSE = 0.012840
# Epoch 1, Batch 63/240, MSE = 0.013158
# Epoch 1, Batch 64/240, MSE = 0.012426
# Epoch 1, Batch 65/240, MSE = 0.012664
# Epoch 1, Batch 66/240, MSE = 0.012359
# Epoch 1, Batch 67/240, MSE = 0.012860
# Epoch 1, Batch 68/240, MSE = 0.012821
# Epoch 1, Batch 69/240, MSE = 0.012535
# Epoch 1, Batch 70/240, MSE = 0.013209
# Epoch 1, Batch 71/240, MSE = 0.013110
# Epoch 1, Batch 72/240, MSE = 0.012624
# Epoch 1, Batch 73/240, MSE = 0.012824
# Epoch 1, Batch 74/240, MSE = 0.012715
# Epoch 1, Batch 75/240, MSE = 0.012838
# Epoch 1, Batch 76/240, MSE = 0.012385
# Epoch 1, Batch 77/240, MSE = 0.012408
# Epoch 1, Batch 78/240, MSE = 0.012164
# Epoch 1, Batch 79/240, MSE = 0.012454
# Epoch 1, Batch 80/240, MSE = 0.012498
# Epoch 1, Batch 81/240, MSE = 0.012448
# Epoch 1, Batch 82/240, MSE = 0.012525
# Epoch 1, Batch 83/240, MSE = 0.012369
# Epoch 1, Batch 84/240, MSE = 0.012696
# Epoch 1, Batch 85/240, MSE = 0.012455
# Epoch 1, Batch 86/240, MSE = 0.012541
# Epoch 1, Batch 87/240, MSE = 0.012589
# Epoch 1, Batch 88/240, MSE = 0.012733
# Epoch 1, Batch 89/240, MSE = 0.012142
# Epoch 1, Batch 90/240, MSE = 0.012359
# Epoch 1, Batch 91/240, MSE = 0.012081
# Epoch 1, Batch 92/240, MSE = 0.012586
# Epoch 1, Batch 93/240, MSE = 0.012425
# Epoch 1, Batch 94/240, MSE = 0.012444
# Epoch 1, Batch 95/240, MSE = 0.012068
# Epoch 1, Batch 96/240, MSE = 0.012410
# Epoch 1, Batch 97/240, MSE = 0.012153
# Epoch 1, Batch 98/240, MSE = 0.012310
# Epoch 1, Batch 99/240, MSE = 0.011807
# Epoch 1, Batch 100/240, MSE = 0.012327
# Epoch 1, Batch 101/240, MSE = 0.012083
# Epoch 1, Batch 102/240, MSE = 0.012306
# Epoch 1, Batch 103/240, MSE = 0.012274
# Epoch 1, Batch 104/240, MSE = 0.011954
# Epoch 1, Batch 105/240, MSE = 0.011824
# Epoch 1, Batch 106/240, MSE = 0.012339
# Epoch 1, Batch 107/240, MSE = 0.012344
# Epoch 1, Batch 108/240, MSE = 0.011841
# Epoch 1, Batch 109/240, MSE = 0.011851
# Epoch 1, Batch 110/240, MSE = 0.012014
# Epoch 1, Batch 111/240, MSE = 0.011930
# Epoch 1, Batch 112/240, MSE = 0.012464
# Epoch 1, Batch 113/240, MSE = 0.011992
# Epoch 1, Batch 114/240, MSE = 0.011916
# Epoch 1, Batch 115/240, MSE = 0.012496
# Epoch 1, Batch 116/240, MSE = 0.011830
# Epoch 1, Batch 117/240, MSE = 0.012258
# Epoch 1, Batch 118/240, MSE = 0.011697
# Epoch 1, Batch 119/240, MSE = 0.011777
# Epoch 1, Batch 120/240, MSE = 0.011815
# Epoch 1, Batch 121/240, MSE = 0.011661
# Epoch 1, Batch 122/240, MSE = 0.011732
# Epoch 1, Batch 123/240, MSE = 0.012070
# Epoch 1, Batch 124/240, MSE = 0.012162
# Epoch 1, Batch 125/240, MSE = 0.012187
# Epoch 1, Batch 126/240, MSE = 0.012386
# Epoch 1, Batch 127/240, MSE = 0.011946
# Epoch 1, Batch 128/240, MSE = 0.012026
# Epoch 1, Batch 129/240, MSE = 0.011455
# Epoch 1, Batch 130/240, MSE = 0.011831
# Epoch 1, Batch 131/240, MSE = 0.011912
# Epoch 1, Batch 132/240, MSE = 0.012083
# Epoch 1, Batch 133/240, MSE = 0.012005
# Epoch 1, Batch 134/240, MSE = 0.011799
# Epoch 1, Batch 135/240, MSE = 0.012001
# Epoch 1, Batch 136/240, MSE = 0.012053
# Epoch 1, Batch 137/240, MSE = 0.011670
# Epoch 1, Batch 138/240, MSE = 0.011532
# Epoch 1, Batch 139/240, MSE = 0.011767
# Epoch 1, Batch 140/240, MSE = 0.011458
# Epoch 1, Batch 141/240, MSE = 0.011152
# Epoch 1, Batch 142/240, MSE = 0.012052
# Epoch 1, Batch 143/240, MSE = 0.011341
# Epoch 1, Batch 144/240, MSE = 0.011625
# Epoch 1, Batch 145/240, MSE = 0.011585
# Epoch 1, Batch 146/240, MSE = 0.011527
# Epoch 1, Batch 147/240, MSE = 0.011539
# Epoch 1, Batch 148/240, MSE = 0.011866
# Epoch 1, Batch 149/240, MSE = 0.011763
# Epoch 1, Batch 150/240, MSE = 0.011860
# Epoch 1, Batch 151/240, MSE = 0.011313
# Epoch 1, Batch 152/240, MSE = 0.011509
# Epoch 1, Batch 153/240, MSE = 0.011768
# Epoch 1, Batch 154/240, MSE = 0.011486
# Epoch 1, Batch 155/240, MSE = 0.011730
# Epoch 1, Batch 156/240, MSE = 0.011914
# Epoch 1, Batch 157/240, MSE = 0.011452
# Epoch 1, Batch 158/240, MSE = 0.011537
# Epoch 1, Batch 159/240, MSE = 0.011483
# Epoch 1, Batch 160/240, MSE = 0.011484
# Epoch 1, Batch 161/240, MSE = 0.011257
# Epoch 1, Batch 162/240, MSE = 0.011448
# Epoch 1, Batch 163/240, MSE = 0.011135
# Epoch 1, Batch 164/240, MSE = 0.011584
# Epoch 1, Batch 165/240, MSE = 0.011613
# Epoch 1, Batch 166/240, MSE = 0.011553
# Epoch 1, Batch 167/240, MSE = 0.011380
# Epoch 1, Batch 168/240, MSE = 0.011481
# Epoch 1, Batch 169/240, MSE = 0.011457
# Epoch 1, Batch 170/240, MSE = 0.011114
# Epoch 1, Batch 171/240, MSE = 0.011404
# Epoch 1, Batch 172/240, MSE = 0.011494
# Epoch 1, Batch 173/240, MSE = 0.011102
# Epoch 1, Batch 174/240, MSE = 0.011060
# Epoch 1, Batch 175/240, MSE = 0.011048
# Epoch 1, Batch 176/240, MSE = 0.011241
# Epoch 1, Batch 177/240, MSE = 0.010928
# Epoch 1, Batch 178/240, MSE = 0.010887
# Epoch 1, Batch 179/240, MSE = 0.010981
# Epoch 1, Batch 180/240, MSE = 0.011592
# Epoch 1, Batch 181/240, MSE = 0.011282
# Epoch 1, Batch 182/240, MSE = 0.010978
# Epoch 1, Batch 183/240, MSE = 0.011137
# Epoch 1, Batch 184/240, MSE = 0.011056
# Epoch 1, Batch 185/240, MSE = 0.011229
# Epoch 1, Batch 186/240, MSE = 0.011171
# Epoch 1, Batch 187/240, MSE = 0.011098
# Epoch 1, Batch 188/240, MSE = 0.011260
# Epoch 1, Batch 189/240, MSE = 0.010637
# Epoch 1, Batch 190/240, MSE = 0.010311
# Epoch 1, Batch 191/240, MSE = 0.010701
# Epoch 1, Batch 192/240, MSE = 0.010681
# Epoch 1, Batch 193/240, MSE = 0.010713
# Epoch 1, Batch 194/240, MSE = 0.010814
# Epoch 1, Batch 195/240, MSE = 0.011196
# Epoch 1, Batch 196/240, MSE = 0.010746
# Epoch 1, Batch 197/240, MSE = 0.010870
# Epoch 1, Batch 198/240, MSE = 0.010728
# Epoch 1, Batch 199/240, MSE = 0.010771
# Epoch 1, Batch 200/240, MSE = 0.010997
# Epoch 1, Batch 201/240, MSE = 0.010880
# Epoch 1, Batch 202/240, MSE = 0.010389
# Epoch 1, Batch 203/240, MSE = 0.010942
# Epoch 1, Batch 204/240, MSE = 0.010370
# Epoch 1, Batch 205/240, MSE = 0.010713
# Epoch 1, Batch 206/240, MSE = 0.010628
# Epoch 1, Batch 207/240, MSE = 0.010945
# Epoch 1, Batch 208/240, MSE = 0.010497
# Epoch 1, Batch 209/240, MSE = 0.010985
# Epoch 1, Batch 210/240, MSE = 0.010818
# Epoch 1, Batch 211/240, MSE = 0.010654
# Epoch 1, Batch 212/240, MSE = 0.010543
# Epoch 1, Batch 213/240, MSE = 0.010417
# Epoch 1, Batch 214/240, MSE = 0.010773
# Epoch 1, Batch 215/240, MSE = 0.010274
# Epoch 1, Batch 216/240, MSE = 0.010590
# Epoch 1, Batch 217/240, MSE = 0.010733
# Epoch 1, Batch 218/240, MSE = 0.010507
# Epoch 1, Batch 219/240, MSE = 0.010600
# Epoch 1, Batch 220/240, MSE = 0.010440
# Epoch 1, Batch 221/240, MSE = 0.010260
# Epoch 1, Batch 222/240, MSE = 0.010559
# Epoch 1, Batch 223/240, MSE = 0.009994
# Epoch 1, Batch 224/240, MSE = 0.010185
# Epoch 1, Batch 225/240, MSE = 0.010438
# Epoch 1, Batch 226/240, MSE = 0.009969
# Epoch 1, Batch 227/240, MSE = 0.010395
# Epoch 1, Batch 228/240, MSE = 0.010052
# Epoch 1, Batch 229/240, MSE = 0.010158
# Epoch 1, Batch 230/240, MSE = 0.010383
# Epoch 1, Batch 231/240, MSE = 0.010425
# Epoch 1, Batch 232/240, MSE = 0.010297
# Epoch 1, Batch 233/240, MSE = 0.010052
# Epoch 1, Batch 234/240, MSE = 0.010201
# Epoch 1, Batch 235/240, MSE = 0.010516
# Epoch 1, Batch 236/240, MSE = 0.009986
# Epoch 1, Batch 237/240, MSE = 0.010492
# Epoch 1, Batch 238/240, MSE = 0.010123
# Epoch 1, Batch 239/240, MSE = 0.010301
# Epoch 1, Batch 240/240, MSE = 0.010035
#
# --- Training Layer 2/2 ---
# Epoch 1, Batch 1/240, MSE = 0.058693
# Epoch 1, Batch 2/240, MSE = 0.014762
# Epoch 1, Batch 3/240, MSE = 0.015135
# Epoch 1, Batch 4/240, MSE = 0.015289
# Epoch 1, Batch 5/240, MSE = 0.013782
# Epoch 1, Batch 6/240, MSE = 0.014210
# Epoch 1, Batch 7/240, MSE = 0.014550
# Epoch 1, Batch 8/240, MSE = 0.014474
# Epoch 1, Batch 9/240, MSE = 0.014806
# Epoch 1, Batch 10/240, MSE = 0.014531
# Epoch 1, Batch 11/240, MSE = 0.014696
# Epoch 1, Batch 12/240, MSE = 0.015787
# Epoch 1, Batch 13/240, MSE = 0.014416
# Epoch 1, Batch 14/240, MSE = 0.014771
# Epoch 1, Batch 15/240, MSE = 0.015154
# Epoch 1, Batch 16/240, MSE = 0.015137
# Epoch 1, Batch 17/240, MSE = 0.013853
# Epoch 1, Batch 18/240, MSE = 0.013451
# Epoch 1, Batch 19/240, MSE = 0.014808
# Epoch 1, Batch 20/240, MSE = 0.013847
# Epoch 1, Batch 21/240, MSE = 0.013453
# Epoch 1, Batch 22/240, MSE = 0.013451
# Epoch 1, Batch 23/240, MSE = 0.013604
# Epoch 1, Batch 24/240, MSE = 0.013473
# Epoch 1, Batch 25/240, MSE = 0.013754
# Epoch 1, Batch 26/240, MSE = 0.013517
# Epoch 1, Batch 27/240, MSE = 0.012894
# Epoch 1, Batch 28/240, MSE = 0.013522
# Epoch 1, Batch 29/240, MSE = 0.013009
# Epoch 1, Batch 30/240, MSE = 0.013182
# Epoch 1, Batch 31/240, MSE = 0.013171
# Epoch 1, Batch 32/240, MSE = 0.013264
# Epoch 1, Batch 33/240, MSE = 0.012736
# Epoch 1, Batch 34/240, MSE = 0.012926
# Epoch 1, Batch 35/240, MSE = 0.012807
# Epoch 1, Batch 36/240, MSE = 0.013206
# Epoch 1, Batch 37/240, MSE = 0.012934
# Epoch 1, Batch 38/240, MSE = 0.012656
# Epoch 1, Batch 39/240, MSE = 0.012743
# Epoch 1, Batch 40/240, MSE = 0.012853
# Epoch 1, Batch 41/240, MSE = 0.012814
# Epoch 1, Batch 42/240, MSE = 0.012572
# Epoch 1, Batch 43/240, MSE = 0.012966
# Epoch 1, Batch 44/240, MSE = 0.012674
# Epoch 1, Batch 45/240, MSE = 0.012408
# Epoch 1, Batch 46/240, MSE = 0.012984
# Epoch 1, Batch 47/240, MSE = 0.012382
# Epoch 1, Batch 48/240, MSE = 0.012938
# Epoch 1, Batch 49/240, MSE = 0.012476
# Epoch 1, Batch 50/240, MSE = 0.012604
# Epoch 1, Batch 51/240, MSE = 0.012613
# Epoch 1, Batch 52/240, MSE = 0.012209
# Epoch 1, Batch 53/240, MSE = 0.012326
# Epoch 1, Batch 54/240, MSE = 0.012443
# Epoch 1, Batch 55/240, MSE = 0.012935
# Epoch 1, Batch 56/240, MSE = 0.012786
# Epoch 1, Batch 57/240, MSE = 0.012363
# Epoch 1, Batch 58/240, MSE = 0.012431
# Epoch 1, Batch 59/240, MSE = 0.012781
# Epoch 1, Batch 60/240, MSE = 0.012407
# Epoch 1, Batch 61/240, MSE = 0.012485
# Epoch 1, Batch 62/240, MSE = 0.012645
# Epoch 1, Batch 63/240, MSE = 0.012750
# Epoch 1, Batch 64/240, MSE = 0.012122
# Epoch 1, Batch 65/240, MSE = 0.012884
# Epoch 1, Batch 66/240, MSE = 0.012261
# Epoch 1, Batch 67/240, MSE = 0.012387
# Epoch 1, Batch 68/240, MSE = 0.012744
# Epoch 1, Batch 69/240, MSE = 0.012703
# Epoch 1, Batch 70/240, MSE = 0.012477
# Epoch 1, Batch 71/240, MSE = 0.012511
# Epoch 1, Batch 72/240, MSE = 0.013023
# Epoch 1, Batch 73/240, MSE = 0.012174
# Epoch 1, Batch 74/240, MSE = 0.012431
# Epoch 1, Batch 75/240, MSE = 0.012797
# Epoch 1, Batch 76/240, MSE = 0.012753
# Epoch 1, Batch 77/240, MSE = 0.012577
# Epoch 1, Batch 78/240, MSE = 0.012157
# Epoch 1, Batch 79/240, MSE = 0.012193
# Epoch 1, Batch 80/240, MSE = 0.012496
# Epoch 1, Batch 81/240, MSE = 0.012454
# Epoch 1, Batch 82/240, MSE = 0.012590
# Epoch 1, Batch 83/240, MSE = 0.012614
# Epoch 1, Batch 84/240, MSE = 0.012633
# Epoch 1, Batch 85/240, MSE = 0.012521
# Epoch 1, Batch 86/240, MSE = 0.012495
# Epoch 1, Batch 87/240, MSE = 0.012370
# Epoch 1, Batch 88/240, MSE = 0.012824
# Epoch 1, Batch 89/240, MSE = 0.012621
# Epoch 1, Batch 90/240, MSE = 0.013083
# Epoch 1, Batch 91/240, MSE = 0.012732
# Epoch 1, Batch 92/240, MSE = 0.012671
# Epoch 1, Batch 93/240, MSE = 0.012622
# Epoch 1, Batch 94/240, MSE = 0.012747
# Epoch 1, Batch 95/240, MSE = 0.012403
# Epoch 1, Batch 96/240, MSE = 0.012533
# Epoch 1, Batch 97/240, MSE = 0.012601
# Epoch 1, Batch 98/240, MSE = 0.012990
# Epoch 1, Batch 99/240, MSE = 0.012450
# Epoch 1, Batch 100/240, MSE = 0.012418
# Epoch 1, Batch 101/240, MSE = 0.012676
# Epoch 1, Batch 102/240, MSE = 0.012834
# Epoch 1, Batch 103/240, MSE = 0.012690
# Epoch 1, Batch 104/240, MSE = 0.012894
# Epoch 1, Batch 105/240, MSE = 0.012719
# Epoch 1, Batch 106/240, MSE = 0.012761
# Epoch 1, Batch 107/240, MSE = 0.012711
# Epoch 1, Batch 108/240, MSE = 0.012781
# Epoch 1, Batch 109/240, MSE = 0.013121
# Epoch 1, Batch 110/240, MSE = 0.012784
# Epoch 1, Batch 111/240, MSE = 0.012510
# Epoch 1, Batch 112/240, MSE = 0.012755
# Epoch 1, Batch 113/240, MSE = 0.012318
# Epoch 1, Batch 114/240, MSE = 0.012157
# Epoch 1, Batch 115/240, MSE = 0.012181
# Epoch 1, Batch 116/240, MSE = 0.012647
# Epoch 1, Batch 117/240, MSE = 0.012141
# Epoch 1, Batch 118/240, MSE = 0.012783
# Epoch 1, Batch 119/240, MSE = 0.012504
# Epoch 1, Batch 120/240, MSE = 0.012195
# Epoch 1, Batch 121/240, MSE = 0.012238
# Epoch 1, Batch 122/240, MSE = 0.012783
# Epoch 1, Batch 123/240, MSE = 0.012801
# Epoch 1, Batch 124/240, MSE = 0.012638
# Epoch 1, Batch 125/240, MSE = 0.012666
# Epoch 1, Batch 126/240, MSE = 0.012515
# Epoch 1, Batch 127/240, MSE = 0.012252
# Epoch 1, Batch 128/240, MSE = 0.012771
# Epoch 1, Batch 129/240, MSE = 0.012673
# Epoch 1, Batch 130/240, MSE = 0.012519
# Epoch 1, Batch 131/240, MSE = 0.012430
# Epoch 1, Batch 132/240, MSE = 0.012582
# Epoch 1, Batch 133/240, MSE = 0.012565
# Epoch 1, Batch 134/240, MSE = 0.012650
# Epoch 1, Batch 135/240, MSE = 0.012686
# Epoch 1, Batch 136/240, MSE = 0.012303
# Epoch 1, Batch 137/240, MSE = 0.012549
# Epoch 1, Batch 138/240, MSE = 0.012771
# Epoch 1, Batch 139/240, MSE = 0.012658
# Epoch 1, Batch 140/240, MSE = 0.012345
# Epoch 1, Batch 141/240, MSE = 0.012421
# Epoch 1, Batch 142/240, MSE = 0.012810
# Epoch 1, Batch 143/240, MSE = 0.012460
# Epoch 1, Batch 144/240, MSE = 0.012526
# Epoch 1, Batch 145/240, MSE = 0.012699
# Epoch 1, Batch 146/240, MSE = 0.012383
# Epoch 1, Batch 147/240, MSE = 0.012719
# Epoch 1, Batch 148/240, MSE = 0.012602
# Epoch 1, Batch 149/240, MSE = 0.012783
# Epoch 1, Batch 150/240, MSE = 0.012297
# Epoch 1, Batch 151/240, MSE = 0.012899
# Epoch 1, Batch 152/240, MSE = 0.012559
# Epoch 1, Batch 153/240, MSE = 0.012574
# Epoch 1, Batch 154/240, MSE = 0.011962
# Epoch 1, Batch 155/240, MSE = 0.012803
# Epoch 1, Batch 156/240, MSE = 0.012625
# Epoch 1, Batch 157/240, MSE = 0.012442
# Epoch 1, Batch 158/240, MSE = 0.013032
# Epoch 1, Batch 159/240, MSE = 0.012553
# Epoch 1, Batch 160/240, MSE = 0.012516
# Epoch 1, Batch 161/240, MSE = 0.012572
# Epoch 1, Batch 162/240, MSE = 0.012317
# Epoch 1, Batch 163/240, MSE = 0.012482
# Epoch 1, Batch 164/240, MSE = 0.012549
# Epoch 1, Batch 165/240, MSE = 0.012331
# Epoch 1, Batch 166/240, MSE = 0.012725
# Epoch 1, Batch 167/240, MSE = 0.012037
# Epoch 1, Batch 168/240, MSE = 0.012590
# Epoch 1, Batch 169/240, MSE = 0.012286
# Epoch 1, Batch 170/240, MSE = 0.012990
# Epoch 1, Batch 171/240, MSE = 0.012905
# Epoch 1, Batch 172/240, MSE = 0.013505
# Epoch 1, Batch 173/240, MSE = 0.013309
# Epoch 1, Batch 174/240, MSE = 0.012890
# Epoch 1, Batch 175/240, MSE = 0.012301
# Epoch 1, Batch 176/240, MSE = 0.012422
# Epoch 1, Batch 177/240, MSE = 0.012646
# Epoch 1, Batch 178/240, MSE = 0.012382
# Epoch 1, Batch 179/240, MSE = 0.012807
# Epoch 1, Batch 180/240, MSE = 0.012455
# Epoch 1, Batch 181/240, MSE = 0.012963
# Epoch 1, Batch 182/240, MSE = 0.012324
# Epoch 1, Batch 183/240, MSE = 0.012598
# Epoch 1, Batch 184/240, MSE = 0.012305
# Epoch 1, Batch 185/240, MSE = 0.012195
# Epoch 1, Batch 186/240, MSE = 0.012302
# Epoch 1, Batch 187/240, MSE = 0.012631
# Epoch 1, Batch 188/240, MSE = 0.012464
# Epoch 1, Batch 189/240, MSE = 0.012546
# Epoch 1, Batch 190/240, MSE = 0.012639
# Epoch 1, Batch 191/240, MSE = 0.012672
# Epoch 1, Batch 192/240, MSE = 0.012413
# Epoch 1, Batch 193/240, MSE = 0.012456
# Epoch 1, Batch 194/240, MSE = 0.012521
# Epoch 1, Batch 195/240, MSE = 0.012218
# Epoch 1, Batch 196/240, MSE = 0.012570
# Epoch 1, Batch 197/240, MSE = 0.012090
# Epoch 1, Batch 198/240, MSE = 0.012624
# Epoch 1, Batch 199/240, MSE = 0.012680
# Epoch 1, Batch 200/240, MSE = 0.012869
# Epoch 1, Batch 201/240, MSE = 0.012392
# Epoch 1, Batch 202/240, MSE = 0.012247
# Epoch 1, Batch 203/240, MSE = 0.012414
# Epoch 1, Batch 204/240, MSE = 0.012341
# Epoch 1, Batch 205/240, MSE = 0.012562
# Epoch 1, Batch 206/240, MSE = 0.012176
# Epoch 1, Batch 207/240, MSE = 0.012458
# Epoch 1, Batch 208/240, MSE = 0.012513
# Epoch 1, Batch 209/240, MSE = 0.012499
# Epoch 1, Batch 210/240, MSE = 0.012613
# Epoch 1, Batch 211/240, MSE = 0.012758
# Epoch 1, Batch 212/240, MSE = 0.012908
# Epoch 1, Batch 213/240, MSE = 0.012756
# Epoch 1, Batch 214/240, MSE = 0.012779
# Epoch 1, Batch 215/240, MSE = 0.012959
# Epoch 1, Batch 216/240, MSE = 0.012566
# Epoch 1, Batch 217/240, MSE = 0.012721
# Epoch 1, Batch 218/240, MSE = 0.012502
# Epoch 1, Batch 219/240, MSE = 0.012385
# Epoch 1, Batch 220/240, MSE = 0.012164
# Epoch 1, Batch 221/240, MSE = 0.012807
# Epoch 1, Batch 222/240, MSE = 0.012528
# Epoch 1, Batch 223/240, MSE = 0.012483
# Epoch 1, Batch 224/240, MSE = 0.012209
# Epoch 1, Batch 225/240, MSE = 0.012419
# Epoch 1, Batch 226/240, MSE = 0.012740
# Epoch 1, Batch 227/240, MSE = 0.012464
# Epoch 1, Batch 228/240, MSE = 0.012079
# Epoch 1, Batch 229/240, MSE = 0.012222
# Epoch 1, Batch 230/240, MSE = 0.012465
# Epoch 1, Batch 231/240, MSE = 0.012570
# Epoch 1, Batch 232/240, MSE = 0.012376
# Epoch 1, Batch 233/240, MSE = 0.012092
# Epoch 1, Batch 234/240, MSE = 0.012436
# Epoch 1, Batch 235/240, MSE = 0.013205
# Epoch 1, Batch 236/240, MSE = 0.012312
# Epoch 1, Batch 237/240, MSE = 0.012561
# Epoch 1, Batch 238/240, MSE = 0.012660
# Epoch 1, Batch 239/240, MSE = 0.012407
# Epoch 1, Batch 240/240, MSE = 0.012019
#
# ============================================================
# Epoch 2/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/2 ---
# Epoch 1, Batch 1/240, MSE = 0.009916
# Epoch 1, Batch 2/240, MSE = 0.010241
# Epoch 1, Batch 3/240, MSE = 0.009813
# Epoch 1, Batch 4/240, MSE = 0.009707
# Epoch 1, Batch 5/240, MSE = 0.009981
# Epoch 1, Batch 6/240, MSE = 0.009722
# Epoch 1, Batch 7/240, MSE = 0.009571
# Epoch 1, Batch 8/240, MSE = 0.009991
# Epoch 1, Batch 9/240, MSE = 0.009743
# Epoch 1, Batch 10/240, MSE = 0.009966
# Epoch 1, Batch 11/240, MSE = 0.009450
# Epoch 1, Batch 12/240, MSE = 0.010062
# Epoch 1, Batch 13/240, MSE = 0.009534
# Epoch 1, Batch 14/240, MSE = 0.009595
# Epoch 1, Batch 15/240, MSE = 0.009575
# Epoch 1, Batch 16/240, MSE = 0.009547
# Epoch 1, Batch 17/240, MSE = 0.009728
# Epoch 1, Batch 18/240, MSE = 0.009638
# Epoch 1, Batch 19/240, MSE = 0.009204
# Epoch 1, Batch 20/240, MSE = 0.009653
# Epoch 1, Batch 21/240, MSE = 0.009856
# Epoch 1, Batch 22/240, MSE = 0.009740
# Epoch 1, Batch 23/240, MSE = 0.009556
# Epoch 1, Batch 24/240, MSE = 0.009909
# Epoch 1, Batch 25/240, MSE = 0.009523
# Epoch 1, Batch 26/240, MSE = 0.009212
# Epoch 1, Batch 27/240, MSE = 0.009421
# Epoch 1, Batch 28/240, MSE = 0.009215
# Epoch 1, Batch 29/240, MSE = 0.009158
# Epoch 1, Batch 30/240, MSE = 0.009430
# Epoch 1, Batch 31/240, MSE = 0.009395
# Epoch 1, Batch 32/240, MSE = 0.009442
# Epoch 1, Batch 33/240, MSE = 0.009518
# Epoch 1, Batch 34/240, MSE = 0.009612
# Epoch 1, Batch 35/240, MSE = 0.009340
# Epoch 1, Batch 36/240, MSE = 0.009306
# Epoch 1, Batch 37/240, MSE = 0.009006
# Epoch 1, Batch 38/240, MSE = 0.009086
# Epoch 1, Batch 39/240, MSE = 0.009175
# Epoch 1, Batch 40/240, MSE = 0.009276
# Epoch 1, Batch 41/240, MSE = 0.009088
# Epoch 1, Batch 42/240, MSE = 0.009522
# Epoch 1, Batch 43/240, MSE = 0.009381
# Epoch 1, Batch 44/240, MSE = 0.009186
# Epoch 1, Batch 45/240, MSE = 0.009186
# Epoch 1, Batch 46/240, MSE = 0.009176
# Epoch 1, Batch 47/240, MSE = 0.009102
# Epoch 1, Batch 48/240, MSE = 0.009222
# Epoch 1, Batch 49/240, MSE = 0.009114
# Epoch 1, Batch 50/240, MSE = 0.009203
# Epoch 1, Batch 51/240, MSE = 0.008992
# Epoch 1, Batch 52/240, MSE = 0.008889
# Epoch 1, Batch 53/240, MSE = 0.009243
# Epoch 1, Batch 54/240, MSE = 0.009164
# Epoch 1, Batch 55/240, MSE = 0.008459
# Epoch 1, Batch 56/240, MSE = 0.008547
# Epoch 1, Batch 57/240, MSE = 0.009121
# Epoch 1, Batch 58/240, MSE = 0.008962
# Epoch 1, Batch 59/240, MSE = 0.009076
# Epoch 1, Batch 60/240, MSE = 0.008798
# Epoch 1, Batch 61/240, MSE = 0.008789
# Epoch 1, Batch 62/240, MSE = 0.009075
# Epoch 1, Batch 63/240, MSE = 0.009119
# Epoch 1, Batch 64/240, MSE = 0.008515
# Epoch 1, Batch 65/240, MSE = 0.008684
# Epoch 1, Batch 66/240, MSE = 0.009074
# Epoch 1, Batch 67/240, MSE = 0.008706
# Epoch 1, Batch 68/240, MSE = 0.008860
# Epoch 1, Batch 69/240, MSE = 0.008824
# Epoch 1, Batch 70/240, MSE = 0.009117
# Epoch 1, Batch 71/240, MSE = 0.008696
# Epoch 1, Batch 72/240, MSE = 0.008611
# Epoch 1, Batch 73/240, MSE = 0.008949
# Epoch 1, Batch 74/240, MSE = 0.008546
# Epoch 1, Batch 75/240, MSE = 0.008518
# Epoch 1, Batch 76/240, MSE = 0.008772
# Epoch 1, Batch 77/240, MSE = 0.008991
# Epoch 1, Batch 78/240, MSE = 0.008745
# Epoch 1, Batch 79/240, MSE = 0.008329
# Epoch 1, Batch 80/240, MSE = 0.008784
# Epoch 1, Batch 81/240, MSE = 0.008369
# Epoch 1, Batch 82/240, MSE = 0.008238
# Epoch 1, Batch 83/240, MSE = 0.008491
# Epoch 1, Batch 84/240, MSE = 0.008427
# Epoch 1, Batch 85/240, MSE = 0.008928
# Epoch 1, Batch 86/240, MSE = 0.008629
# Epoch 1, Batch 87/240, MSE = 0.007941
# Epoch 1, Batch 88/240, MSE = 0.008506
# Epoch 1, Batch 89/240, MSE = 0.008662
# Epoch 1, Batch 90/240, MSE = 0.008340
# Epoch 1, Batch 91/240, MSE = 0.008185
# Epoch 1, Batch 92/240, MSE = 0.008478
# Epoch 1, Batch 93/240, MSE = 0.007823
# Epoch 1, Batch 94/240, MSE = 0.008263
# Epoch 1, Batch 95/240, MSE = 0.008625
# Epoch 1, Batch 96/240, MSE = 0.008161
# Epoch 1, Batch 97/240, MSE = 0.007947
# Epoch 1, Batch 98/240, MSE = 0.008419
# Epoch 1, Batch 99/240, MSE = 0.008208
# Epoch 1, Batch 100/240, MSE = 0.008234
# Epoch 1, Batch 101/240, MSE = 0.007946
# Epoch 1, Batch 102/240, MSE = 0.007933
# Epoch 1, Batch 103/240, MSE = 0.007887
# Epoch 1, Batch 104/240, MSE = 0.008309
# Epoch 1, Batch 105/240, MSE = 0.008049
# Epoch 1, Batch 106/240, MSE = 0.007999
# Epoch 1, Batch 107/240, MSE = 0.007921
# Epoch 1, Batch 108/240, MSE = 0.007769
# Epoch 1, Batch 109/240, MSE = 0.007658
# Epoch 1, Batch 110/240, MSE = 0.007912
# Epoch 1, Batch 111/240, MSE = 0.007704
# Epoch 1, Batch 112/240, MSE = 0.007832
# Epoch 1, Batch 113/240, MSE = 0.008017
# Epoch 1, Batch 114/240, MSE = 0.008325
# Epoch 1, Batch 115/240, MSE = 0.007676
# Epoch 1, Batch 116/240, MSE = 0.007772
# Epoch 1, Batch 117/240, MSE = 0.007933
# Epoch 1, Batch 118/240, MSE = 0.007623
# Epoch 1, Batch 119/240, MSE = 0.008134
# Epoch 1, Batch 120/240, MSE = 0.007828
# Epoch 1, Batch 121/240, MSE = 0.007836
# Epoch 1, Batch 122/240, MSE = 0.007904
# Epoch 1, Batch 123/240, MSE = 0.007831
# Epoch 1, Batch 124/240, MSE = 0.007932
# Epoch 1, Batch 125/240, MSE = 0.007636
# Epoch 1, Batch 126/240, MSE = 0.007384
# Epoch 1, Batch 127/240, MSE = 0.007517
# Epoch 1, Batch 128/240, MSE = 0.007289
# Epoch 1, Batch 129/240, MSE = 0.007854
# Epoch 1, Batch 130/240, MSE = 0.007570
# Epoch 1, Batch 131/240, MSE = 0.007392
# Epoch 1, Batch 132/240, MSE = 0.007768
# Epoch 1, Batch 133/240, MSE = 0.007630
# Epoch 1, Batch 134/240, MSE = 0.007707
# Epoch 1, Batch 135/240, MSE = 0.007075
# Epoch 1, Batch 136/240, MSE = 0.007286
# Epoch 1, Batch 137/240, MSE = 0.007648
# Epoch 1, Batch 138/240, MSE = 0.007429
# Epoch 1, Batch 139/240, MSE = 0.007245
# Epoch 1, Batch 140/240, MSE = 0.007713
# Epoch 1, Batch 141/240, MSE = 0.007340
# Epoch 1, Batch 142/240, MSE = 0.007479
# Epoch 1, Batch 143/240, MSE = 0.007472
# Epoch 1, Batch 144/240, MSE = 0.007488
# Epoch 1, Batch 145/240, MSE = 0.007225
# Epoch 1, Batch 146/240, MSE = 0.007238
# Epoch 1, Batch 147/240, MSE = 0.007186
# Epoch 1, Batch 148/240, MSE = 0.007332
# Epoch 1, Batch 149/240, MSE = 0.007288
# Epoch 1, Batch 150/240, MSE = 0.007101
# Epoch 1, Batch 151/240, MSE = 0.007229
# Epoch 1, Batch 152/240, MSE = 0.007640
# Epoch 1, Batch 153/240, MSE = 0.007251
# Epoch 1, Batch 154/240, MSE = 0.007335
# Epoch 1, Batch 155/240, MSE = 0.007266
# Epoch 1, Batch 156/240, MSE = 0.007234
# Epoch 1, Batch 157/240, MSE = 0.007261
# Epoch 1, Batch 158/240, MSE = 0.006587
# Epoch 1, Batch 159/240, MSE = 0.007293
# Epoch 1, Batch 160/240, MSE = 0.007046
# Epoch 1, Batch 161/240, MSE = 0.006926
# Epoch 1, Batch 162/240, MSE = 0.007197
# Epoch 1, Batch 163/240, MSE = 0.007112
# Epoch 1, Batch 164/240, MSE = 0.007112
# Epoch 1, Batch 165/240, MSE = 0.006863
# Epoch 1, Batch 166/240, MSE = 0.006628
# Epoch 1, Batch 167/240, MSE = 0.007200
# Epoch 1, Batch 168/240, MSE = 0.007205
# Epoch 1, Batch 169/240, MSE = 0.007027
# Epoch 1, Batch 170/240, MSE = 0.006938
# Epoch 1, Batch 171/240, MSE = 0.007037
# Epoch 1, Batch 172/240, MSE = 0.007099
# Epoch 1, Batch 173/240, MSE = 0.006878
# Epoch 1, Batch 174/240, MSE = 0.006834
# Epoch 1, Batch 175/240, MSE = 0.006645
# Epoch 1, Batch 176/240, MSE = 0.006872
# Epoch 1, Batch 177/240, MSE = 0.006695
# Epoch 1, Batch 178/240, MSE = 0.006861
# Epoch 1, Batch 179/240, MSE = 0.006559
# Epoch 1, Batch 180/240, MSE = 0.006940
# Epoch 1, Batch 181/240, MSE = 0.007058
# Epoch 1, Batch 182/240, MSE = 0.006522
# Epoch 1, Batch 183/240, MSE = 0.006791
# Epoch 1, Batch 184/240, MSE = 0.006740
# Epoch 1, Batch 185/240, MSE = 0.006727
# Epoch 1, Batch 186/240, MSE = 0.006711
# Epoch 1, Batch 187/240, MSE = 0.006511
# Epoch 1, Batch 188/240, MSE = 0.006828
# Epoch 1, Batch 189/240, MSE = 0.006555
# Epoch 1, Batch 190/240, MSE = 0.006633
# Epoch 1, Batch 191/240, MSE = 0.006591
# Epoch 1, Batch 192/240, MSE = 0.006794
# Epoch 1, Batch 193/240, MSE = 0.006885
# Epoch 1, Batch 194/240, MSE = 0.006373
# Epoch 1, Batch 195/240, MSE = 0.006759
# Epoch 1, Batch 196/240, MSE = 0.006665
# Epoch 1, Batch 197/240, MSE = 0.006493
# Epoch 1, Batch 198/240, MSE = 0.006571
# Epoch 1, Batch 199/240, MSE = 0.006473
# Epoch 1, Batch 200/240, MSE = 0.006436
# Epoch 1, Batch 201/240, MSE = 0.006183
# Epoch 1, Batch 202/240, MSE = 0.006160
# Epoch 1, Batch 203/240, MSE = 0.006459
# Epoch 1, Batch 204/240, MSE = 0.006312
# Epoch 1, Batch 205/240, MSE = 0.006523
# Epoch 1, Batch 206/240, MSE = 0.006486
# Epoch 1, Batch 207/240, MSE = 0.006439
# Epoch 1, Batch 208/240, MSE = 0.006587
# Epoch 1, Batch 209/240, MSE = 0.006081
# Epoch 1, Batch 210/240, MSE = 0.006288
# Epoch 1, Batch 211/240, MSE = 0.006331
# Epoch 1, Batch 212/240, MSE = 0.006147
# Epoch 1, Batch 213/240, MSE = 0.006268
# Epoch 1, Batch 214/240, MSE = 0.006302
# Epoch 1, Batch 215/240, MSE = 0.006181
# Epoch 1, Batch 216/240, MSE = 0.006045
# Epoch 1, Batch 217/240, MSE = 0.006165
# Epoch 1, Batch 218/240, MSE = 0.006137
# Epoch 1, Batch 219/240, MSE = 0.006037
# Epoch 1, Batch 220/240, MSE = 0.005783
# Epoch 1, Batch 221/240, MSE = 0.005978
# Epoch 1, Batch 222/240, MSE = 0.005928
# Epoch 1, Batch 223/240, MSE = 0.006254
# Epoch 1, Batch 224/240, MSE = 0.005817
# Epoch 1, Batch 225/240, MSE = 0.005967
# Epoch 1, Batch 226/240, MSE = 0.006109
# Epoch 1, Batch 227/240, MSE = 0.005754
# Epoch 1, Batch 228/240, MSE = 0.006151
# Epoch 1, Batch 229/240, MSE = 0.006161
# Epoch 1, Batch 230/240, MSE = 0.006030
# Epoch 1, Batch 231/240, MSE = 0.005970
# Epoch 1, Batch 232/240, MSE = 0.005778
# Epoch 1, Batch 233/240, MSE = 0.006009
# Epoch 1, Batch 234/240, MSE = 0.005918
# Epoch 1, Batch 235/240, MSE = 0.005891
# Epoch 1, Batch 236/240, MSE = 0.006110
# Epoch 1, Batch 237/240, MSE = 0.005884
# Epoch 1, Batch 238/240, MSE = 0.005878
# Epoch 1, Batch 239/240, MSE = 0.005870
# Epoch 1, Batch 240/240, MSE = 0.005948
#
# --- Training Layer 2/2 ---
# Epoch 1, Batch 1/240, MSE = 0.026990
# Epoch 1, Batch 2/240, MSE = 0.026381
# Epoch 1, Batch 3/240, MSE = 0.026467
# Epoch 1, Batch 4/240, MSE = 0.025882
# Epoch 1, Batch 5/240, MSE = 0.026510
# Epoch 1, Batch 6/240, MSE = 0.026077
# Epoch 1, Batch 7/240, MSE = 0.026206
# Epoch 1, Batch 8/240, MSE = 0.026717
# Epoch 1, Batch 9/240, MSE = 0.026906
# Epoch 1, Batch 10/240, MSE = 0.026980
# Epoch 1, Batch 11/240, MSE = 0.026403
# Epoch 1, Batch 12/240, MSE = 0.026693
# Epoch 1, Batch 13/240, MSE = 0.026058
# Epoch 1, Batch 14/240, MSE = 0.027181
# Epoch 1, Batch 15/240, MSE = 0.026560
# Epoch 1, Batch 16/240, MSE = 0.026250
# Epoch 1, Batch 17/240, MSE = 0.025983
# Epoch 1, Batch 18/240, MSE = 0.027284
# Epoch 1, Batch 19/240, MSE = 0.026798
# Epoch 1, Batch 20/240, MSE = 0.026288
# Epoch 1, Batch 21/240, MSE = 0.027122
# Epoch 1, Batch 22/240, MSE = 0.026397
# Epoch 1, Batch 23/240, MSE = 0.025900
# Epoch 1, Batch 24/240, MSE = 0.026818
# Epoch 1, Batch 25/240, MSE = 0.026612
# Epoch 1, Batch 26/240, MSE = 0.026624
# Epoch 1, Batch 27/240, MSE = 0.025768
# Epoch 1, Batch 28/240, MSE = 0.026210
# Epoch 1, Batch 29/240, MSE = 0.027017
# Epoch 1, Batch 30/240, MSE = 0.026893
# Epoch 1, Batch 31/240, MSE = 0.026175
# Epoch 1, Batch 32/240, MSE = 0.026664
# Epoch 1, Batch 33/240, MSE = 0.026320
# Epoch 1, Batch 34/240, MSE = 0.026021
# Epoch 1, Batch 35/240, MSE = 0.027060
# Epoch 1, Batch 36/240, MSE = 0.026582
# Epoch 1, Batch 37/240, MSE = 0.026846
# Epoch 1, Batch 38/240, MSE = 0.026717
# Epoch 1, Batch 39/240, MSE = 0.026360
# Epoch 1, Batch 40/240, MSE = 0.026752
# Epoch 1, Batch 41/240, MSE = 0.026589
# Epoch 1, Batch 42/240, MSE = 0.026546
# Epoch 1, Batch 43/240, MSE = 0.026704
# Epoch 1, Batch 44/240, MSE = 0.026254
# Epoch 1, Batch 45/240, MSE = 0.026403
# Epoch 1, Batch 46/240, MSE = 0.026711
# Epoch 1, Batch 47/240, MSE = 0.026361
# Epoch 1, Batch 48/240, MSE = 0.026629
# Epoch 1, Batch 49/240, MSE = 0.026686
# Epoch 1, Batch 50/240, MSE = 0.025395
# Epoch 1, Batch 51/240, MSE = 0.026585
# Epoch 1, Batch 52/240, MSE = 0.026113
# Epoch 1, Batch 53/240, MSE = 0.025900
# Epoch 1, Batch 54/240, MSE = 0.026510
# Epoch 1, Batch 55/240, MSE = 0.027326
# Epoch 1, Batch 56/240, MSE = 0.026510
# Epoch 1, Batch 57/240, MSE = 0.026828
# Epoch 1, Batch 58/240, MSE = 0.025984
# Epoch 1, Batch 59/240, MSE = 0.026161
# Epoch 1, Batch 60/240, MSE = 0.025939
# Epoch 1, Batch 61/240, MSE = 0.026820
# Epoch 1, Batch 62/240, MSE = 0.026010
# Epoch 1, Batch 63/240, MSE = 0.025632
# Epoch 1, Batch 64/240, MSE = 0.026813
# Epoch 1, Batch 65/240, MSE = 0.026148
# Epoch 1, Batch 66/240, MSE = 0.026407
# Epoch 1, Batch 67/240, MSE = 0.025597
# Epoch 1, Batch 68/240, MSE = 0.026373
# Epoch 1, Batch 69/240, MSE = 0.026571
# Epoch 1, Batch 70/240, MSE = 0.026532
# Epoch 1, Batch 71/240, MSE = 0.026543
# Epoch 1, Batch 72/240, MSE = 0.025789
# Epoch 1, Batch 73/240, MSE = 0.026517
# Epoch 1, Batch 74/240, MSE = 0.025675
# Epoch 1, Batch 75/240, MSE = 0.026279
# Epoch 1, Batch 76/240, MSE = 0.026639
# Epoch 1, Batch 77/240, MSE = 0.026215
# Epoch 1, Batch 78/240, MSE = 0.026156
# Epoch 1, Batch 79/240, MSE = 0.025659
# Epoch 1, Batch 80/240, MSE = 0.026484
# Epoch 1, Batch 81/240, MSE = 0.025920
# Epoch 1, Batch 82/240, MSE = 0.025964
# Epoch 1, Batch 83/240, MSE = 0.026796
# Epoch 1, Batch 84/240, MSE = 0.026375
# Epoch 1, Batch 85/240, MSE = 0.025498
# Epoch 1, Batch 86/240, MSE = 0.026819
# Epoch 1, Batch 87/240, MSE = 0.026788
# Epoch 1, Batch 88/240, MSE = 0.026565
# Epoch 1, Batch 89/240, MSE = 0.026309
# Epoch 1, Batch 90/240, MSE = 0.025639
# Epoch 1, Batch 91/240, MSE = 0.025723
# Epoch 1, Batch 92/240, MSE = 0.026450
# Epoch 1, Batch 93/240, MSE = 0.026367
# Epoch 1, Batch 94/240, MSE = 0.025768
# Epoch 1, Batch 95/240, MSE = 0.026101
# Epoch 1, Batch 96/240, MSE = 0.026340
# Epoch 1, Batch 97/240, MSE = 0.025615
# Epoch 1, Batch 98/240, MSE = 0.026688
# Epoch 1, Batch 99/240, MSE = 0.025818
# Epoch 1, Batch 100/240, MSE = 0.026352
# Epoch 1, Batch 101/240, MSE = 0.026330
# Epoch 1, Batch 102/240, MSE = 0.025933
# Epoch 1, Batch 103/240, MSE = 0.026190
# Epoch 1, Batch 104/240, MSE = 0.026324
# Epoch 1, Batch 105/240, MSE = 0.025561
# Epoch 1, Batch 106/240, MSE = 0.025860
# Epoch 1, Batch 107/240, MSE = 0.025472
# Epoch 1, Batch 108/240, MSE = 0.025039
# Epoch 1, Batch 109/240, MSE = 0.026430
# Epoch 1, Batch 110/240, MSE = 0.026086
# Epoch 1, Batch 111/240, MSE = 0.025438
# Epoch 1, Batch 112/240, MSE = 0.026075
# Epoch 1, Batch 113/240, MSE = 0.025205
# Epoch 1, Batch 114/240, MSE = 0.025844
# Epoch 1, Batch 115/240, MSE = 0.025987
# Epoch 1, Batch 116/240, MSE = 0.025964
# Epoch 1, Batch 117/240, MSE = 0.025885
# Epoch 1, Batch 118/240, MSE = 0.026287
# Epoch 1, Batch 119/240, MSE = 0.025410
# Epoch 1, Batch 120/240, MSE = 0.025790
# Epoch 1, Batch 121/240, MSE = 0.025800
# Epoch 1, Batch 122/240, MSE = 0.025692
# Epoch 1, Batch 123/240, MSE = 0.025781
# Epoch 1, Batch 124/240, MSE = 0.025639
# Epoch 1, Batch 125/240, MSE = 0.025769
# Epoch 1, Batch 126/240, MSE = 0.025238
# Epoch 1, Batch 127/240, MSE = 0.025557
# Epoch 1, Batch 128/240, MSE = 0.025203
# Epoch 1, Batch 129/240, MSE = 0.025209
# Epoch 1, Batch 130/240, MSE = 0.025852
# Epoch 1, Batch 131/240, MSE = 0.025605
# Epoch 1, Batch 132/240, MSE = 0.025711
# Epoch 1, Batch 133/240, MSE = 0.025153
# Epoch 1, Batch 134/240, MSE = 0.026296
# Epoch 1, Batch 135/240, MSE = 0.025134
# Epoch 1, Batch 136/240, MSE = 0.025175
# Epoch 1, Batch 137/240, MSE = 0.025725
# Epoch 1, Batch 138/240, MSE = 0.025433
# Epoch 1, Batch 139/240, MSE = 0.024649
# Epoch 1, Batch 140/240, MSE = 0.025782
# Epoch 1, Batch 141/240, MSE = 0.024945
# Epoch 1, Batch 142/240, MSE = 0.025519
# Epoch 1, Batch 143/240, MSE = 0.025453
# Epoch 1, Batch 144/240, MSE = 0.025489
# Epoch 1, Batch 145/240, MSE = 0.025238
# Epoch 1, Batch 146/240, MSE = 0.024909
# Epoch 1, Batch 147/240, MSE = 0.025890
# Epoch 1, Batch 148/240, MSE = 0.025251
# Epoch 1, Batch 149/240, MSE = 0.025894
# Epoch 1, Batch 150/240, MSE = 0.025251
# Epoch 1, Batch 151/240, MSE = 0.025470
# Epoch 1, Batch 152/240, MSE = 0.025474
# Epoch 1, Batch 153/240, MSE = 0.025035
# Epoch 1, Batch 154/240, MSE = 0.024973
# Epoch 1, Batch 155/240, MSE = 0.025246
# Epoch 1, Batch 156/240, MSE = 0.025306
# Epoch 1, Batch 157/240, MSE = 0.025892
# Epoch 1, Batch 158/240, MSE = 0.025392
# Epoch 1, Batch 159/240, MSE = 0.025095
# Epoch 1, Batch 160/240, MSE = 0.024807
# Epoch 1, Batch 161/240, MSE = 0.025860
# Epoch 1, Batch 162/240, MSE = 0.025288
# Epoch 1, Batch 163/240, MSE = 0.025767
# Epoch 1, Batch 164/240, MSE = 0.026003
# Epoch 1, Batch 165/240, MSE = 0.025416
# Epoch 1, Batch 166/240, MSE = 0.025675
# Epoch 1, Batch 167/240, MSE = 0.024833
# Epoch 1, Batch 168/240, MSE = 0.025195
# Epoch 1, Batch 169/240, MSE = 0.024853
# Epoch 1, Batch 170/240, MSE = 0.025729
# Epoch 1, Batch 171/240, MSE = 0.025156
# Epoch 1, Batch 172/240, MSE = 0.025118
# Epoch 1, Batch 173/240, MSE = 0.025192
# Epoch 1, Batch 174/240, MSE = 0.025546
# Epoch 1, Batch 175/240, MSE = 0.024391
# Epoch 1, Batch 176/240, MSE = 0.025099
# Epoch 1, Batch 177/240, MSE = 0.024129
# Epoch 1, Batch 178/240, MSE = 0.025006
# Epoch 1, Batch 179/240, MSE = 0.024866
# Epoch 1, Batch 180/240, MSE = 0.024664
# Epoch 1, Batch 181/240, MSE = 0.024787
# Epoch 1, Batch 182/240, MSE = 0.025344
# Epoch 1, Batch 183/240, MSE = 0.024729
# Epoch 1, Batch 184/240, MSE = 0.024624
# Epoch 1, Batch 185/240, MSE = 0.025196
# Epoch 1, Batch 186/240, MSE = 0.024980
# Epoch 1, Batch 187/240, MSE = 0.025148
# Epoch 1, Batch 188/240, MSE = 0.024465
# Epoch 1, Batch 189/240, MSE = 0.025133
# Epoch 1, Batch 190/240, MSE = 0.024862
# Epoch 1, Batch 191/240, MSE = 0.024810
# Epoch 1, Batch 192/240, MSE = 0.024413
# Epoch 1, Batch 193/240, MSE = 0.024689
# Epoch 1, Batch 194/240, MSE = 0.024738
# Epoch 1, Batch 195/240, MSE = 0.024265
# Epoch 1, Batch 196/240, MSE = 0.024880
# Epoch 1, Batch 197/240, MSE = 0.025517
# Epoch 1, Batch 198/240, MSE = 0.025433
# Epoch 1, Batch 199/240, MSE = 0.024835
# Epoch 1, Batch 200/240, MSE = 0.024796
# Epoch 1, Batch 201/240, MSE = 0.025290
# Epoch 1, Batch 202/240, MSE = 0.025109
# Epoch 1, Batch 203/240, MSE = 0.024869
# Epoch 1, Batch 204/240, MSE = 0.025191
# Epoch 1, Batch 205/240, MSE = 0.024970
# Epoch 1, Batch 206/240, MSE = 0.024958
# Epoch 1, Batch 207/240, MSE = 0.024854
# Epoch 1, Batch 208/240, MSE = 0.024877
# Epoch 1, Batch 209/240, MSE = 0.025019
# Epoch 1, Batch 210/240, MSE = 0.024423
# Epoch 1, Batch 211/240, MSE = 0.024243
# Epoch 1, Batch 212/240, MSE = 0.024499
# Epoch 1, Batch 213/240, MSE = 0.024207
# Epoch 1, Batch 214/240, MSE = 0.024454
# Epoch 1, Batch 215/240, MSE = 0.023634
# Epoch 1, Batch 216/240, MSE = 0.024307
# Epoch 1, Batch 217/240, MSE = 0.024709
# Epoch 1, Batch 218/240, MSE = 0.024197
# Epoch 1, Batch 219/240, MSE = 0.023967
# Epoch 1, Batch 220/240, MSE = 0.024301
# Epoch 1, Batch 221/240, MSE = 0.024352
# Epoch 1, Batch 222/240, MSE = 0.024047
# Epoch 1, Batch 223/240, MSE = 0.024258
# Epoch 1, Batch 224/240, MSE = 0.023981
# Epoch 1, Batch 225/240, MSE = 0.024544
# Epoch 1, Batch 226/240, MSE = 0.024137
# Epoch 1, Batch 227/240, MSE = 0.024439
# Epoch 1, Batch 228/240, MSE = 0.023896
# Epoch 1, Batch 229/240, MSE = 0.024637
# Epoch 1, Batch 230/240, MSE = 0.024575
# Epoch 1, Batch 231/240, MSE = 0.024276
# Epoch 1, Batch 232/240, MSE = 0.024302
# Epoch 1, Batch 233/240, MSE = 0.023806
# Epoch 1, Batch 234/240, MSE = 0.023976
# Epoch 1, Batch 235/240, MSE = 0.024033
# Epoch 1, Batch 236/240, MSE = 0.024725
# Epoch 1, Batch 237/240, MSE = 0.024190
# Epoch 1, Batch 238/240, MSE = 0.025210
# Epoch 1, Batch 239/240, MSE = 0.024094
# Epoch 1, Batch 240/240, MSE = 0.024305
#
# ============================================================
# Epoch 3/30
# ============================================================
#
# Generating 512 × 30 = 15360 augmented samples...
# Augmented dataset shape: (15360, 7936)
#   - Real/Imag combined (Phase preserved)
#
# --- Training Layer 1/2 ---
# Epoch 1, Batch 1/240, MSE = 0.005773
# Epoch 1, Batch 2/240, MSE = 0.005474
# Epoch 1, Batch 3/240, MSE = 0.005776
# Epoch 1, Batch 4/240, MSE = 0.005971
# Epoch 1, Batch 5/240, MSE = 0.005524
# Epoch 1, Batch 6/240, MSE = 0.005767
# Epoch 1, Batch 7/240, MSE = 0.005653
# Epoch 1, Batch 8/240, MSE = 0.005403
# Epoch 1, Batch 9/240, MSE = 0.005852
# Epoch 1, Batch 10/240, MSE = 0.005783
# Epoch 1, Batch 11/240, MSE = 0.005333
# Epoch 1, Batch 12/240, MSE = 0.005449
# Epoch 1, Batch 13/240, MSE = 0.005682
# Epoch 1, Batch 14/240, MSE = 0.005405
# Epoch 1, Batch 15/240, MSE = 0.005421
# Epoch 1, Batch 16/240, MSE = 0.005630
# Epoch 1, Batch 17/240, MSE = 0.005677
# Epoch 1, Batch 18/240, MSE = 0.005914
# Epoch 1, Batch 19/240, MSE = 0.005794
# Epoch 1, Batch 20/240, MSE = 0.005548
# Epoch 1, Batch 21/240, MSE = 0.005584
# Epoch 1, Batch 22/240, MSE = 0.005444
# Epoch 1, Batch 23/240, MSE = 0.005563
# Epoch 1, Batch 24/240, MSE = 0.005435
# Epoch 1, Batch 25/240, MSE = 0.005549
# Epoch 1, Batch 26/240, MSE = 0.005516
# Epoch 1, Batch 27/240, MSE = 0.005462
# Epoch 1, Batch 28/240, MSE = 0.005592
# Epoch 1, Batch 29/240, MSE = 0.005530
# Epoch 1, Batch 30/240, MSE = 0.005401
# Epoch 1, Batch 31/240, MSE = 0.005542
# Epoch 1, Batch 32/240, MSE = 0.005185
# Epoch 1, Batch 33/240, MSE = 0.005343
# Epoch 1, Batch 34/240, MSE = 0.005440
# Epoch 1, Batch 35/240, MSE = 0.005211
# Epoch 1, Batch 36/240, MSE = 0.005254
# Epoch 1, Batch 37/240, MSE = 0.005487
# Epoch 1, Batch 38/240, MSE = 0.005375
# Epoch 1, Batch 39/240, MSE = 0.005199
# Epoch 1, Batch 40/240, MSE = 0.005440
# Epoch 1, Batch 41/240, MSE = 0.005250
# Epoch 1, Batch 42/240, MSE = 0.005207
# Epoch 1, Batch 43/240, MSE = 0.005218
# Epoch 1, Batch 44/240, MSE = 0.004796
# Epoch 1, Batch 45/240, MSE = 0.005015
# Epoch 1, Batch 46/240, MSE = 0.005009
# Epoch 1, Batch 47/240, MSE = 0.005325
# Epoch 1, Batch 48/240, MSE = 0.005254
# Epoch 1, Batch 49/240, MSE = 0.005071
# Epoch 1, Batch 50/240, MSE = 0.005069
# Epoch 1, Batch 51/240, MSE = 0.004969
# Epoch 1, Batch 52/240, MSE = 0.005185
# Epoch 1, Batch 53/240, MSE = 0.005065
# Epoch 1, Batch 54/240, MSE = 0.004779
# Epoch 1, Batch 55/240, MSE = 0.005006
# Epoch 1, Batch 56/240, MSE = 0.004998
# Epoch 1, Batch 57/240, MSE = 0.005082
# Epoch 1, Batch 58/240, MSE = 0.004729
# Epoch 1, Batch 59/240, MSE = 0.005028
# Epoch 1, Batch 60/240, MSE = 0.004803
# Epoch 1, Batch 61/240, MSE = 0.005033
# Epoch 1, Batch 62/240, MSE = 0.004685
# Epoch 1, Batch 63/240, MSE = 0.005130
# Epoch 1, Batch 64/240, MSE = 0.004939
# Epoch 1, Batch 65/240, MSE = 0.005026
# Epoch 1, Batch 66/240, MSE = 0.004942
# Epoch 1, Batch 67/240, MSE = 0.004879
# Epoch 1, Batch 68/240, MSE = 0.005030
# Epoch 1, Batch 69/240, MSE = 0.005217
# Epoch 1, Batch 70/240, MSE = 0.005015
# Epoch 1, Batch 71/240, MSE = 0.004799
# Epoch 1, Batch 72/240, MSE = 0.004821
# Epoch 1, Batch 73/240, MSE = 0.004909
# Epoch 1, Batch 74/240, MSE = 0.004870
# Epoch 1, Batch 75/240, MSE = 0.004935
# Epoch 1, Batch 76/240, MSE = 0.004803
# Epoch 1, Batch 77/240, MSE = 0.004953
# Epoch 1, Batch 78/240, MSE = 0.004700
# Epoch 1, Batch 79/240, MSE = 0.004765
# Epoch 1, Batch 80/240, MSE = 0.004747
# Epoch 1, Batch 81/240, MSE = 0.004632
# Epoch 1, Batch 82/240, MSE = 0.004583
# Epoch 1, Batch 83/240, MSE = 0.004918
# Epoch 1, Batch 84/240, MSE = 0.004575
# Epoch 1, Batch 85/240, MSE = 0.004659
# Epoch 1, Batch 86/240, MSE = 0.004416
# Epoch 1, Batch 87/240, MSE = 0.004708
# Epoch 1, Batch 88/240, MSE = 0.004559
# Epoch 1, Batch 89/240, MSE = 0.004620
# Epoch 1, Batch 90/240, MSE = 0.004813
# Epoch 1, Batch 91/240, MSE = 0.004537
# Epoch 1, Batch 92/240, MSE = 0.004900
# Epoch 1, Batch 93/240, MSE = 0.004608
# Epoch 1, Batch 94/240, MSE = 0.004512
# Epoch 1, Batch 95/240, MSE = 0.004792
# Epoch 1, Batch 96/240, MSE = 0.004431
# Epoch 1, Batch 97/240, MSE = 0.004437
# Epoch 1, Batch 98/240, MSE = 0.004638
# Epoch 1, Batch 99/240, MSE = 0.004444
# Epoch 1, Batch 100/240, MSE = 0.004635
# Epoch 1, Batch 101/240, MSE = 0.004524
# Epoch 1, Batch 102/240, MSE = 0.004673
# Epoch 1, Batch 103/240, MSE = 0.004757
# Epoch 1, Batch 104/240, MSE = 0.004184
# Epoch 1, Batch 105/240, MSE = 0.004623
# Epoch 1, Batch 106/240, MSE = 0.004593
# Epoch 1, Batch 107/240, MSE = 0.004320
# Epoch 1, Batch 108/240, MSE = 0.004458
# Epoch 1, Batch 109/240, MSE = 0.004450
# Epoch 1, Batch 110/240, MSE = 0.004814
# Epoch 1, Batch 111/240, MSE = 0.004540
# Epoch 1, Batch 112/240, MSE = 0.004350
# Epoch 1, Batch 113/240, MSE = 0.004374
# Epoch 1, Batch 114/240, MSE = 0.004728
# Epoch 1, Batch 115/240, MSE = 0.004612
# Epoch 1, Batch 116/240, MSE = 0.004210
# Epoch 1, Batch 117/240, MSE = 0.004145
# Epoch 1, Batch 118/240, MSE = 0.004062
# Epoch 1, Batch 119/240, MSE = 0.004299
# Epoch 1, Batch 120/240, MSE = 0.004340
# Epoch 1, Batch 121/240, MSE = 0.004157
# Epoch 1, Batch 122/240, MSE = 0.004384
# Epoch 1, Batch 123/240, MSE = 0.004214
# Epoch 1, Batch 124/240, MSE = 0.004229
# Epoch 1, Batch 125/240, MSE = 0.004408
# Epoch 1, Batch 126/240, MSE = 0.004379
# Epoch 1, Batch 127/240, MSE = 0.004272
# Epoch 1, Batch 128/240, MSE = 0.004390
# Epoch 1, Batch 129/240, MSE = 0.004147
# Epoch 1, Batch 130/240, MSE = 0.004336
# Epoch 1, Batch 131/240, MSE = 0.004071
# Epoch 1, Batch 132/240, MSE = 0.004126
# Epoch 1, Batch 133/240, MSE = 0.004317
# Epoch 1, Batch 134/240, MSE = 0.004489
# Epoch 1, Batch 135/240, MSE = 0.004284
# Epoch 1, Batch 136/240, MSE = 0.004137
# Epoch 1, Batch 137/240, MSE = 0.004136
# Epoch 1, Batch 138/240, MSE = 0.004238
# Epoch 1, Batch 139/240, MSE = 0.004156
# Epoch 1, Batch 140/240, MSE = 0.004239
# Epoch 1, Batch 141/240, MSE = 0.004375
# Epoch 1, Batch 142/240, MSE = 0.003830
# Epoch 1, Batch 143/240, MSE = 0.003872
# Epoch 1, Batch 144/240, MSE = 0.004053
# Epoch 1, Batch 145/240, MSE = 0.004256
# Epoch 1, Batch 146/240, MSE = 0.004242
# Epoch 1, Batch 147/240, MSE = 0.004184
# Epoch 1, Batch 148/240, MSE = 0.004243
# Epoch 1, Batch 149/240, MSE = 0.004116
# Epoch 1, Batch 150/240, MSE = 0.004141
# Epoch 1, Batch 151/240, MSE = 0.003963
# Epoch 1, Batch 152/240, MSE = 0.004077
# Epoch 1, Batch 153/240, MSE = 0.003965
# Epoch 1, Batch 154/240, MSE = 0.004096
# Epoch 1, Batch 155/240, MSE = 0.003860
# Epoch 1, Batch 156/240, MSE = 0.004194
# Epoch 1, Batch 157/240, MSE = 0.003808
# Epoch 1, Batch 158/240, MSE = 0.003788
# Epoch 1, Batch 159/240, MSE = 0.003983
# Epoch 1, Batch 160/240, MSE = 0.004000
# Epoch 1, Batch 161/240, MSE = 0.003981
# Epoch 1, Batch 162/240, MSE = 0.003965
# Epoch 1, Batch 163/240, MSE = 0.003983
# Epoch 1, Batch 164/240, MSE = 0.004006
# Epoch 1, Batch 165/240, MSE = 0.003829
# Epoch 1, Batch 166/240, MSE = 0.004170
# Epoch 1, Batch 167/240, MSE = 0.003924
# Epoch 1, Batch 168/240, MSE = 0.003831
# Epoch 1, Batch 169/240, MSE = 0.003912
# Epoch 1, Batch 170/240, MSE = 0.003901
# Epoch 1, Batch 171/240, MSE = 0.003794
# Epoch 1, Batch 172/240, MSE = 0.003844
# Epoch 1, Batch 173/240, MSE = 0.004133
# Epoch 1, Batch 174/240, MSE = 0.004094
# Epoch 1, Batch 175/240, MSE = 0.003980
# Epoch 1, Batch 176/240, MSE = 0.003803
# Epoch 1, Batch 177/240, MSE = 0.003747
# Epoch 1, Batch 178/240, MSE = 0.004078
# Epoch 1, Batch 179/240, MSE = 0.003854
# Epoch 1, Batch 180/240, MSE = 0.003871
# Epoch 1, Batch 181/240, MSE = 0.003729
# Epoch 1, Batch 182/240, MSE = 0.003817
# Epoch 1, Batch 183/240, MSE = 0.003776
# Epoch 1, Batch 184/240, MSE = 0.003840
# Epoch 1, Batch 185/240, MSE = 0.003760
# Epoch 1, Batch 186/240, MSE = 0.003825
# Epoch 1, Batch 187/240, MSE = 0.003593
# Epoch 1, Batch 188/240, MSE = 0.003912
# Epoch 1, Batch 189/240, MSE = 0.003724
# Epoch 1, Batch 190/240, MSE = 0.003823
# Epoch 1, Batch 191/240, MSE = 0.003833
# Epoch 1, Batch 192/240, MSE = 0.003908
# Epoch 1, Batch 193/240, MSE = 0.003508
# Epoch 1, Batch 194/240, MSE = 0.003772
# Epoch 1, Batch 195/240, MSE = 0.003629
# Epoch 1, Batch 196/240, MSE = 0.003548
# Epoch 1, Batch 197/240, MSE = 0.003691
# Epoch 1, Batch 198/240, MSE = 0.003554
# Epoch 1, Batch 199/240, MSE = 0.003849
# Epoch 1, Batch 200/240, MSE = 0.003857
# Epoch 1, Batch 201/240, MSE = 0.003321
# Epoch 1, Batch 202/240, MSE = 0.003584
# Epoch 1, Batch 203/240, MSE = 0.003677
# Epoch 1, Batch 204/240, MSE = 0.003762
# Epoch 1, Batch 205/240, MSE = 0.003771
# Epoch 1, Batch 206/240, MSE = 0.003596
# Epoch 1, Batch 207/240, MSE = 0.003631
# Epoch 1, Batch 208/240, MSE = 0.003485
# Epoch 1, Batch 209/240, MSE = 0.003638
# Epoch 1, Batch 210/240, MSE = 0.003486
# Epoch 1, Batch 211/240, MSE = 0.003408
# Epoch 1, Batch 212/240, MSE = 0.003442
# Epoch 1, Batch 213/240, MSE = 0.003660
# Epoch 1, Batch 214/240, MSE = 0.003620
# Epoch 1, Batch 215/240, MSE = 0.003739
# Epoch 1, Batch 216/240, MSE = 0.003709
# Epoch 1, Batch 217/240, MSE = 0.003485
# Epoch 1, Batch 218/240, MSE = 0.003523
# Epoch 1, Batch 219/240, MSE = 0.003393
# Epoch 1, Batch 220/240, MSE = 0.003503
# Epoch 1, Batch 221/240, MSE = 0.003355
# Epoch 1, Batch 222/240, MSE = 0.003291
# Epoch 1, Batch 223/240, MSE = 0.003525
# Epoch 1, Batch 224/240, MSE = 0.003449
# Epoch 1, Batch 225/240, MSE = 0.003567
# Epoch 1, Batch 226/240, MSE = 0.003556
# Epoch 1, Batch 227/240, MSE = 0.003369
# Epoch 1, Batch 228/240, MSE = 0.003481
# Epoch 1, Batch 229/240, MSE = 0.003715
# Epoch 1, Batch 230/240, MSE = 0.003314
# Epoch 1, Batch 231/240, MSE = 0.003461
# Epoch 1, Batch 232/240, MSE = 0.003559
# Epoch 1, Batch 233/240, MSE = 0.003550
# Epoch 1, Batch 234/240, MSE = 0.003480
# Epoch 1, Batch 235/240, MSE = 0.003352
# Epoch 1, Batch 236/240, MSE = 0.003445
# Epoch 1, Batch 237/240, MSE = 0.003439
# Epoch 1, Batch 238/240, MSE = 0.003367
# Epoch 1, Batch 239/240, MSE = 0.003518
# Epoch 1, Batch 240/240, MSE = 0.003201
#
# --- Training Layer 2/2 ---
# Epoch 1, Batch 1/240, MSE = 0.034408
# Epoch 1, Batch 2/240, MSE = 0.034738
# Epoch 1, Batch 3/240, MSE = 0.035320
# Epoch 1, Batch 4/240, MSE = 0.034575
# Epoch 1, Batch 5/240, MSE = 0.035211
# Epoch 1, Batch 6/240, MSE = 0.035614
# Epoch 1, Batch 7/240, MSE = 0.035241
# Epoch 1, Batch 8/240, MSE = 0.035078
# Epoch 1, Batch 9/240, MSE = 0.035236
# Epoch 1, Batch 10/240, MSE = 0.035269
# Epoch 1, Batch 11/240, MSE = 0.034577
# Epoch 1, Batch 12/240, MSE = 0.033624
# Epoch 1, Batch 13/240, MSE = 0.034788
# ...
# Epoch 1, Batch 69/240, MSE = 0.000049
# Epoch 1, Batch 70/240, MSE = 0.000051
# Epoch 1, Batch 71/240, MSE = 0.000048
# Epoch 1, Batch 72/240, MSE = 0.000050
# Epoch 1, Batch 73/240, MSE = 0.000050
# Epoch 1, Batch 74/240, MSE = 0.000052
# Epoch 1, Batch 75/240, MSE = 0.000052
# Epoch 1, Batch 76/240, MSE = 0.000054
# Epoch 1, Batch 77/240, MSE = 0.000050
# Epoch 1, Batch 78/240, MSE = 0.000053
# Epoch 1, Batch 79/240, MSE = 0.000053
# Epoch 1, Batch 80/240, MSE = 0.000055
# Epoch 1, Batch 81/240, MSE = 0.000051
# Epoch 1, Batch 82/240, MSE = 0.000054
# Epoch 1, Batch 83/240, MSE = 0.000054
# Epoch 1, Batch 84/240, MSE = 0.000050
# Epoch 1, Batch 85/240, MSE = 0.000049
# Epoch 1, Batch 86/240, MSE = 0.000047
# Epoch 1, Batch 87/240, MSE = 0.000052
# Epoch 1, Batch 88/240, MSE = 0.000055
# Epoch 1, Batch 89/240, MSE = 0.000053
# Epoch 1, Batch 90/240, MSE = 0.000054
# Epoch 1, Batch 91/240, MSE = 0.000053
# Epoch 1, Batch 92/240, MSE = 0.000051
# Epoch 1, Batch 93/240, MSE = 0.000052
# Epoch 1, Batch 94/240, MSE = 0.000049
# Epoch 1, Batch 95/240, MSE = 0.000050
# Epoch 1, Batch 96/240, MSE = 0.000054
# Epoch 1, Batch 97/240, MSE = 0.000045
# Epoch 1, Batch 98/240, MSE = 0.000051
# Epoch 1, Batch 99/240, MSE = 0.000049
# Epoch 1, Batch 100/240, MSE = 0.000053
# Epoch 1, Batch 101/240, MSE = 0.000052
# Epoch 1, Batch 102/240, MSE = 0.000051
# Epoch 1, Batch 103/240, MSE = 0.000053
# Epoch 1, Batch 104/240, MSE = 0.000056
# Epoch 1, Batch 105/240, MSE = 0.000046
# Epoch 1, Batch 106/240, MSE = 0.000053
# Epoch 1, Batch 107/240, MSE = 0.000050
# Epoch 1, Batch 108/240, MSE = 0.000051
# Epoch 1, Batch 109/240, MSE = 0.000051
# Epoch 1, Batch 110/240, MSE = 0.000057
# Epoch 1, Batch 111/240, MSE = 0.000047
# Epoch 1, Batch 112/240, MSE = 0.000053
# Epoch 1, Batch 113/240, MSE = 0.000051
# Epoch 1, Batch 114/240, MSE = 0.000049
# Epoch 1, Batch 115/240, MSE = 0.000056
# Epoch 1, Batch 116/240, MSE = 0.000054
# Epoch 1, Batch 117/240, MSE = 0.000051
# Epoch 1, Batch 118/240, MSE = 0.000049
# Epoch 1, Batch 119/240, MSE = 0.000049
# Epoch 1, Batch 120/240, MSE = 0.000052
# Epoch 1, Batch 121/240, MSE = 0.000048
# Epoch 1, Batch 122/240, MSE = 0.000050
# Epoch 1, Batch 123/240, MSE = 0.000054
# Epoch 1, Batch 124/240, MSE = 0.000053
# Epoch 1, Batch 125/240, MSE = 0.000049
# Epoch 1, Batch 126/240, MSE = 0.000048
# Epoch 1, Batch 127/240, MSE = 0.000049
# Epoch 1, Batch 128/240, MSE = 0.000047
# Epoch 1, Batch 129/240, MSE = 0.000055
# Epoch 1, Batch 130/240, MSE = 0.000050
# Epoch 1, Batch 131/240, MSE = 0.000053
# Epoch 1, Batch 132/240, MSE = 0.000053
# Epoch 1, Batch 133/240, MSE = 0.000051
# Epoch 1, Batch 134/240, MSE = 0.000051
# Epoch 1, Batch 135/240, MSE = 0.000048
# Epoch 1, Batch 136/240, MSE = 0.000056
# Epoch 1, Batch 137/240, MSE = 0.000053
# Epoch 1, Batch 138/240, MSE = 0.000056
# Epoch 1, Batch 139/240, MSE = 0.000054
# Epoch 1, Batch 140/240, MSE = 0.000047
# Epoch 1, Batch 141/240, MSE = 0.000045
# Epoch 1, Batch 142/240, MSE = 0.000051
# Epoch 1, Batch 143/240, MSE = 0.000043
# Epoch 1, Batch 144/240, MSE = 0.000052
# Epoch 1, Batch 145/240, MSE = 0.000051
# Epoch 1, Batch 146/240, MSE = 0.000053
# Epoch 1, Batch 147/240, MSE = 0.000048
# Epoch 1, Batch 148/240, MSE = 0.000053
# Epoch 1, Batch 149/240, MSE = 0.000048
# Epoch 1, Batch 150/240, MSE = 0.000049
# Epoch 1, Batch 151/240, MSE = 0.000053
# Epoch 1, Batch 152/240, MSE = 0.000051
# Epoch 1, Batch 153/240, MSE = 0.000051
# Epoch 1, Batch 154/240, MSE = 0.000049
# Epoch 1, Batch 155/240, MSE = 0.000055
# Epoch 1, Batch 156/240, MSE = 0.000052
# Epoch 1, Batch 157/240, MSE = 0.000052
# Epoch 1, Batch 158/240, MSE = 0.000054
# Epoch 1, Batch 159/240, MSE = 0.000054
# Epoch 1, Batch 160/240, MSE = 0.000052
# Epoch 1, Batch 161/240, MSE = 0.000047
# Epoch 1, Batch 162/240, MSE = 0.000049
# Epoch 1, Batch 163/240, MSE = 0.000050
# Epoch 1, Batch 164/240, MSE = 0.000053
# Epoch 1, Batch 165/240, MSE = 0.000051
# Epoch 1, Batch 166/240, MSE = 0.000057
# Epoch 1, Batch 167/240, MSE = 0.000058
# Epoch 1, Batch 168/240, MSE = 0.000054
# Epoch 1, Batch 169/240, MSE = 0.000047
# Epoch 1, Batch 170/240, MSE = 0.000052
# Epoch 1, Batch 171/240, MSE = 0.000051
# Epoch 1, Batch 172/240, MSE = 0.000052
# Epoch 1, Batch 173/240, MSE = 0.000051
# Epoch 1, Batch 174/240, MSE = 0.000049
# Epoch 1, Batch 175/240, MSE = 0.000047
# Epoch 1, Batch 176/240, MSE = 0.000053
# Epoch 1, Batch 177/240, MSE = 0.000051
# Epoch 1, Batch 178/240, MSE = 0.000052
# Epoch 1, Batch 179/240, MSE = 0.000051
# Epoch 1, Batch 180/240, MSE = 0.000049
# Epoch 1, Batch 181/240, MSE = 0.000052
# Epoch 1, Batch 182/240, MSE = 0.000050
# Epoch 1, Batch 183/240, MSE = 0.000053
# Epoch 1, Batch 184/240, MSE = 0.000055
# Epoch 1, Batch 185/240, MSE = 0.000049
# Epoch 1, Batch 186/240, MSE = 0.000054
# Epoch 1, Batch 187/240, MSE = 0.000049
# Epoch 1, Batch 188/240, MSE = 0.000051
# Epoch 1, Batch 189/240, MSE = 0.000052
# Epoch 1, Batch 190/240, MSE = 0.000054
# Epoch 1, Batch 191/240, MSE = 0.000048
# Epoch 1, Batch 192/240, MSE = 0.000049
# Epoch 1, Batch 193/240, MSE = 0.000055
# Epoch 1, Batch 194/240, MSE = 0.000047
# Epoch 1, Batch 195/240, MSE = 0.000053
# Epoch 1, Batch 196/240, MSE = 0.000050
# Epoch 1, Batch 197/240, MSE = 0.000049
# Epoch 1, Batch 198/240, MSE = 0.000053
# Epoch 1, Batch 199/240, MSE = 0.000055
# Epoch 1, Batch 200/240, MSE = 0.000053
# Epoch 1, Batch 201/240, MSE = 0.000053
# Epoch 1, Batch 202/240, MSE = 0.000050
# Epoch 1, Batch 203/240, MSE = 0.000052
# Epoch 1, Batch 204/240, MSE = 0.000049
# Epoch 1, Batch 205/240, MSE = 0.000048
# Epoch 1, Batch 206/240, MSE = 0.000050
# Epoch 1, Batch 207/240, MSE = 0.000049
# Epoch 1, Batch 208/240, MSE = 0.000048
# Epoch 1, Batch 209/240, MSE = 0.000050
# Epoch 1, Batch 210/240, MSE = 0.000055
# Epoch 1, Batch 211/240, MSE = 0.000056
# Epoch 1, Batch 212/240, MSE = 0.000052
# Epoch 1, Batch 213/240, MSE = 0.000050
# Epoch 1, Batch 214/240, MSE = 0.000050
# Epoch 1, Batch 215/240, MSE = 0.000052
# Epoch 1, Batch 216/240, MSE = 0.000050
# Epoch 1, Batch 217/240, MSE = 0.000047
# Epoch 1, Batch 218/240, MSE = 0.000047
# Epoch 1, Batch 219/240, MSE = 0.000055
# Epoch 1, Batch 220/240, MSE = 0.000053
# Epoch 1, Batch 221/240, MSE = 0.000050
# Epoch 1, Batch 222/240, MSE = 0.000048
# Epoch 1, Batch 223/240, MSE = 0.000050
# Epoch 1, Batch 224/240, MSE = 0.000052
# Epoch 1, Batch 225/240, MSE = 0.000054
# Epoch 1, Batch 226/240, MSE = 0.000052
# Epoch 1, Batch 227/240, MSE = 0.000053
# Epoch 1, Batch 228/240, MSE = 0.000052
# Epoch 1, Batch 229/240, MSE = 0.000046
# Epoch 1, Batch 230/240, MSE = 0.000050
# Epoch 1, Batch 231/240, MSE = 0.000047
# Epoch 1, Batch 232/240, MSE = 0.000048
# Epoch 1, Batch 233/240, MSE = 0.000052
# Epoch 1, Batch 234/240, MSE = 0.000052
# Epoch 1, Batch 235/240, MSE = 0.000048
# Epoch 1, Batch 236/240, MSE = 0.000050
# Epoch 1, Batch 237/240, MSE = 0.000051
# Epoch 1, Batch 238/240, MSE = 0.000052
# Epoch 1, Batch 239/240, MSE = 0.000048
# Epoch 1, Batch 240/240, MSE = 0.000051
#
# --- Training Layer 2/2 ---
# Epoch 1, Batch 1/240, MSE = 0.011554
# Epoch 1, Batch 2/240, MSE = 0.010980
# Epoch 1, Batch 3/240, MSE = 0.010150
# Epoch 1, Batch 4/240, MSE = 0.010310
# Epoch 1, Batch 5/240, MSE = 0.010999
# Epoch 1, Batch 6/240, MSE = 0.010590
# Epoch 1, Batch 7/240, MSE = 0.011245
# Epoch 1, Batch 8/240, MSE = 0.010093
# Epoch 1, Batch 9/240, MSE = 0.011197
# Epoch 1, Batch 10/240, MSE = 0.011986
# Epoch 1, Batch 11/240, MSE = 0.010318
# Epoch 1, Batch 12/240, MSE = 0.010379
# Epoch 1, Batch 13/240, MSE = 0.010702
# Epoch 1, Batch 14/240, MSE = 0.010573
# Epoch 1, Batch 15/240, MSE = 0.010706
# Epoch 1, Batch 16/240, MSE = 0.010105
# Epoch 1, Batch 17/240, MSE = 0.011160
# Epoch 1, Batch 18/240, MSE = 0.010188
# Epoch 1, Batch 19/240, MSE = 0.011230
# Epoch 1, Batch 20/240, MSE = 0.010955
# Epoch 1, Batch 21/240, MSE = 0.010183
# Epoch 1, Batch 22/240, MSE = 0.011387
# Epoch 1, Batch 23/240, MSE = 0.011061
# Epoch 1, Batch 24/240, MSE = 0.010789
# Epoch 1, Batch 25/240, MSE = 0.009884
# Epoch 1, Batch 26/240, MSE = 0.009986
# Epoch 1, Batch 27/240, MSE = 0.010220
# Epoch 1, Batch 28/240, MSE = 0.010492
# Epoch 1, Batch 29/240, MSE = 0.010931
# Epoch 1, Batch 30/240, MSE = 0.011359
# Epoch 1, Batch 31/240, MSE = 0.010199
# Epoch 1, Batch 32/240, MSE = 0.010963
# Epoch 1, Batch 33/240, MSE = 0.010173
# Epoch 1, Batch 34/240, MSE = 0.011187
# Epoch 1, Batch 35/240, MSE = 0.010944
# Epoch 1, Batch 36/240, MSE = 0.010710
# Epoch 1, Batch 37/240, MSE = 0.009814
# Epoch 1, Batch 38/240, MSE = 0.010560
# Epoch 1, Batch 39/240, MSE = 0.010189
# Epoch 1, Batch 40/240, MSE = 0.010275
# Epoch 1, Batch 41/240, MSE = 0.010650
# Epoch 1, Batch 42/240, MSE = 0.009425
# Epoch 1, Batch 43/240, MSE = 0.010002
# Epoch 1, Batch 44/240, MSE = 0.010180
# Epoch 1, Batch 45/240, MSE = 0.010261
# Epoch 1, Batch 46/240, MSE = 0.011016
# Epoch 1, Batch 47/240, MSE = 0.009380
# Epoch 1, Batch 48/240, MSE = 0.010887
# Epoch 1, Batch 49/240, MSE = 0.010830
# Epoch 1, Batch 50/240, MSE = 0.009885
# Epoch 1, Batch 51/240, MSE = 0.011115
# Epoch 1, Batch 52/240, MSE = 0.009647
# Epoch 1, Batch 53/240, MSE = 0.011322
# Epoch 1, Batch 54/240, MSE = 0.010169
# Epoch 1, Batch 55/240, MSE = 0.009630
# Epoch 1, Batch 56/240, MSE = 0.010375
# Epoch 1, Batch 57/240, MSE = 0.010968
# Epoch 1, Batch 58/240, MSE = 0.010348
# Epoch 1, Batch 59/240, MSE = 0.011021
# Epoch 1, Batch 60/240, MSE = 0.010286
# Epoch 1, Batch 61/240, MSE = 0.011068
# Epoch 1, Batch 62/240, MSE = 0.009573
# Epoch 1, Batch 63/240, MSE = 0.010761
# Epoch 1, Batch 64/240, MSE = 0.011529
# Epoch 1, Batch 65/240, MSE = 0.010165
# Epoch 1, Batch 66/240, MSE = 0.011139
# Epoch 1, Batch 67/240, MSE = 0.010260
# Epoch 1, Batch 68/240, MSE = 0.010733
# Epoch 1, Batch 69/240, MSE = 0.010663
# Epoch 1, Batch 70/240, MSE = 0.009726
# Epoch 1, Batch 71/240, MSE = 0.009997
# Epoch 1, Batch 72/240, MSE = 0.010978
# Epoch 1, Batch 73/240, MSE = 0.009915
# Epoch 1, Batch 74/240, MSE = 0.011661
# Epoch 1, Batch 75/240, MSE = 0.011402
# Epoch 1, Batch 76/240, MSE = 0.010871
# Epoch 1, Batch 77/240, MSE = 0.012149
# Epoch 1, Batch 78/240, MSE = 0.009654
# Epoch 1, Batch 79/240, MSE = 0.011228
# Epoch 1, Batch 80/240, MSE = 0.011389
# Epoch 1, Batch 81/240, MSE = 0.011445
# Epoch 1, Batch 82/240, MSE = 0.009600
# Epoch 1, Batch 83/240, MSE = 0.010908
# Epoch 1, Batch 84/240, MSE = 0.010646
# Epoch 1, Batch 85/240, MSE = 0.011138
# Epoch 1, Batch 86/240, MSE = 0.010165
# Epoch 1, Batch 87/240, MSE = 0.010263
# Epoch 1, Batch 88/240, MSE = 0.011320
# Epoch 1, Batch 89/240, MSE = 0.010033
# Epoch 1, Batch 90/240, MSE = 0.011125
# Epoch 1, Batch 91/240, MSE = 0.010406
# Epoch 1, Batch 92/240, MSE = 0.011158
# Epoch 1, Batch 93/240, MSE = 0.011227
# Epoch 1, Batch 94/240, MSE = 0.012088
# Epoch 1, Batch 95/240, MSE = 0.010338
# Epoch 1, Batch 96/240, MSE = 0.010557
# Epoch 1, Batch 97/240, MSE = 0.009999
# Epoch 1, Batch 98/240, MSE = 0.010720
# Epoch 1, Batch 99/240, MSE = 0.009585
# Epoch 1, Batch 100/240, MSE = 0.010630
# Epoch 1, Batch 101/240, MSE = 0.010410
# Epoch 1, Batch 102/240, MSE = 0.011020
# Epoch 1, Batch 103/240, MSE = 0.010221
# Epoch 1, Batch 104/240, MSE = 0.010705
# Epoch 1, Batch 105/240, MSE = 0.010756
# Epoch 1, Batch 106/240, MSE = 0.010990
# Epoch 1, Batch 107/240, MSE = 0.010139
# Epoch 1, Batch 108/240, MSE = 0.010636
# Epoch 1, Batch 109/240, MSE = 0.010622
# Epoch 1, Batch 110/240, MSE = 0.011512
# Epoch 1, Batch 111/240, MSE = 0.010582
# Epoch 1, Batch 112/240, MSE = 0.009569
# Epoch 1, Batch 113/240, MSE = 0.010312
# Epoch 1, Batch 114/240, MSE = 0.010127
# Epoch 1, Batch 115/240, MSE = 0.011511
# Epoch 1, Batch 116/240, MSE = 0.011000
# Epoch 1, Batch 117/240, MSE = 0.010753
# Epoch 1, Batch 118/240, MSE = 0.009792
# Epoch 1, Batch 119/240, MSE = 0.010198
# Epoch 1, Batch 120/240, MSE = 0.010407
# Epoch 1, Batch 121/240, MSE = 0.010454
# Epoch 1, Batch 122/240, MSE = 0.010172
# Epoch 1, Batch 123/240, MSE = 0.010537
# Epoch 1, Batch 124/240, MSE = 0.011411
# Epoch 1, Batch 125/240, MSE = 0.010373
# Epoch 1, Batch 126/240, MSE = 0.010721
# Epoch 1, Batch 127/240, MSE = 0.009619
# Epoch 1, Batch 128/240, MSE = 0.011222
# Epoch 1, Batch 129/240, MSE = 0.010980
# Epoch 1, Batch 130/240, MSE = 0.009820
# Epoch 1, Batch 131/240, MSE = 0.011464
# Epoch 1, Batch 132/240, MSE = 0.010862
# Epoch 1, Batch 133/240, MSE = 0.011318
# Epoch 1, Batch 134/240, MSE = 0.009808
# Epoch 1, Batch 135/240, MSE = 0.009536
# Epoch 1, Batch 136/240, MSE = 0.010679
# Epoch 1, Batch 137/240, MSE = 0.010938
# Epoch 1, Batch 138/240, MSE = 0.010752
# Epoch 1, Batch 139/240, MSE = 0.011438
# Epoch 1, Batch 140/240, MSE = 0.010431
# Epoch 1, Batch 141/240, MSE = 0.011252
# Epoch 1, Batch 142/240, MSE = 0.010803
# Epoch 1, Batch 143/240, MSE = 0.009988
# Epoch 1, Batch 144/240, MSE = 0.010776
# Epoch 1, Batch 145/240, MSE = 0.010171
# Epoch 1, Batch 146/240, MSE = 0.009993
# Epoch 1, Batch 147/240, MSE = 0.010242
# Epoch 1, Batch 148/240, MSE = 0.010553
# Epoch 1, Batch 149/240, MSE = 0.011116
# Epoch 1, Batch 150/240, MSE = 0.010938
# Epoch 1, Batch 151/240, MSE = 0.011945
# Epoch 1, Batch 152/240, MSE = 0.010522
# Epoch 1, Batch 153/240, MSE = 0.010838
# Epoch 1, Batch 154/240, MSE = 0.010161
# Epoch 1, Batch 155/240, MSE = 0.011308
# Epoch 1, Batch 156/240, MSE = 0.010661
# Epoch 1, Batch 157/240, MSE = 0.010921
# Epoch 1, Batch 158/240, MSE = 0.010065
# Epoch 1, Batch 159/240, MSE = 0.010304
# Epoch 1, Batch 160/240, MSE = 0.010815
# Epoch 1, Batch 161/240, MSE = 0.010622
# Epoch 1, Batch 162/240, MSE = 0.010494
# Epoch 1, Batch 163/240, MSE = 0.012177
# Epoch 1, Batch 164/240, MSE = 0.010650
# Epoch 1, Batch 165/240, MSE = 0.010013
# Epoch 1, Batch 166/240, MSE = 0.009859
# Epoch 1, Batch 167/240, MSE = 0.010729
# Epoch 1, Batch 168/240, MSE = 0.011212
# Epoch 1, Batch 169/240, MSE = 0.011091
# Epoch 1, Batch 170/240, MSE = 0.010039
# Epoch 1, Batch 171/240, MSE = 0.010060
# Epoch 1, Batch 172/240, MSE = 0.010182
# Epoch 1, Batch 173/240, MSE = 0.010556
# Epoch 1, Batch 174/240, MSE = 0.009922
# Epoch 1, Batch 175/240, MSE = 0.009856
# Epoch 1, Batch 176/240, MSE = 0.010246
# Epoch 1, Batch 177/240, MSE = 0.010439
# Epoch 1, Batch 178/240, MSE = 0.010721
# Epoch 1, Batch 179/240, MSE = 0.010899
# Epoch 1, Batch 180/240, MSE = 0.011490
# Epoch 1, Batch 181/240, MSE = 0.010897
# Epoch 1, Batch 182/240, MSE = 0.010499
# Epoch 1, Batch 183/240, MSE = 0.011217
# Epoch 1, Batch 184/240, MSE = 0.011063
# Epoch 1, Batch 185/240, MSE = 0.010842
# Epoch 1, Batch 186/240, MSE = 0.010285
# Epoch 1, Batch 187/240, MSE = 0.010716
# Epoch 1, Batch 188/240, MSE = 0.009393
# Epoch 1, Batch 189/240, MSE = 0.010568
# Epoch 1, Batch 190/240, MSE = 0.010650
# Epoch 1, Batch 191/240, MSE = 0.010935
# Epoch 1, Batch 192/240, MSE = 0.009904
# Epoch 1, Batch 193/240, MSE = 0.010177
# Epoch 1, Batch 194/240, MSE = 0.010442
# Epoch 1, Batch 195/240, MSE = 0.010246
# Epoch 1, Batch 196/240, MSE = 0.011746
# Epoch 1, Batch 197/240, MSE = 0.010980
# Epoch 1, Batch 198/240, MSE = 0.010648
# Epoch 1, Batch 199/240, MSE = 0.011260
# Epoch 1, Batch 200/240, MSE = 0.011503
# Epoch 1, Batch 201/240, MSE = 0.011032
# Epoch 1, Batch 202/240, MSE = 0.010279
# Epoch 1, Batch 203/240, MSE = 0.009671
# Epoch 1, Batch 204/240, MSE = 0.011784
# Epoch 1, Batch 205/240, MSE = 0.010098
# Epoch 1, Batch 206/240, MSE = 0.010214
# Epoch 1, Batch 207/240, MSE = 0.011336
# Epoch 1, Batch 208/240, MSE = 0.009991
# Epoch 1, Batch 209/240, MSE = 0.011007
# Epoch 1, Batch 210/240, MSE = 0.011007
# Epoch 1, Batch 211/240, MSE = 0.011442
# Epoch 1, Batch 212/240, MSE = 0.011394
# Epoch 1, Batch 213/240, MSE = 0.009983
# Epoch 1, Batch 214/240, MSE = 0.011342
# Epoch 1, Batch 215/240, MSE = 0.010914
# Epoch 1, Batch 216/240, MSE = 0.010874
# Epoch 1, Batch 217/240, MSE = 0.011956
# Epoch 1, Batch 218/240, MSE = 0.010393
# Epoch 1, Batch 219/240, MSE = 0.010671
# Epoch 1, Batch 220/240, MSE = 0.010926
# Epoch 1, Batch 221/240, MSE = 0.010037
# Epoch 1, Batch 222/240, MSE = 0.010879
# Epoch 1, Batch 223/240, MSE = 0.011592
# Epoch 1, Batch 224/240, MSE = 0.011785
# Epoch 1, Batch 225/240, MSE = 0.010902
# Epoch 1, Batch 226/240, MSE = 0.010359
# Epoch 1, Batch 227/240, MSE = 0.010180
# Epoch 1, Batch 228/240, MSE = 0.010991
# Epoch 1, Batch 229/240, MSE = 0.011087
# Epoch 1, Batch 230/240, MSE = 0.011211
# Epoch 1, Batch 231/240, MSE = 0.010826
# Epoch 1, Batch 232/240, MSE = 0.009558
# Epoch 1, Batch 233/240, MSE = 0.010554
# Epoch 1, Batch 234/240, MSE = 0.010831
# Epoch 1, Batch 235/240, MSE = 0.010384
# Epoch 1, Batch 236/240, MSE = 0.011314
# Epoch 1, Batch 237/240, MSE = 0.010619
# Epoch 1, Batch 238/240, MSE = 0.011034
# Epoch 1, Batch 239/240, MSE = 0.010704
# Epoch 1, Batch 240/240, MSE = 0.010435
#
# === Training Complete ===

# %%
########################################
##  5. 모델 저장                     ##
########################################

import torch

if TRAIN:
    # 모델 저장 폴더
    weight_folder = "weights_bamv3_complex"
    os.makedirs(weight_folder, exist_ok=True)

    # 각 layer의 weight 저장
    for i, bam in enumerate(model.bams):
        weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
        np.save(weight_path, bam.W.cpu().numpy())
        print(f"✅ Layer {i} weights saved to: {weight_path}")

    # 아키텍처 정보 저장
    config = {
        'layers': layers,
        'eta': 5e-4,
        'sf': sf,
        'bw': bw,
        'fs': fs,
        'mode': 'complex'  # Complex 방식 표시
    }
    config_path = os.path.join(weight_folder, "model_config.npy")
    np.save(config_path, config)
    print(f"✅ Config saved to: {config_path}")

print("\n=== How to Load Model ===")
print("""
# 모델 로드 예시:
config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
for i, bam in enumerate(model.bams):
    bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))
""")
# Out:
# ✅ Layer 0 weights saved to: weights_bamv3_complex/weights_layer_0.npy
# ✅ Layer 1 weights saved to: weights_bamv3_complex/weights_layer_1.npy
# ✅ Config saved to: weights_bamv3_complex/model_config.npy
#
# === How to Load Model ===
#
# # 모델 로드 예시:
# config = np.load('weights_bamv3_complex/model_config.npy', allow_pickle=True).item()
# model = MultiBAMv3(layers_dims=config['layers'], eta=config['eta'])
# for i, bam in enumerate(model.bams):
#     bam.W = torch.tensor(np.load(f'weights_bamv3_complex/weights_layer_{i}.npy'))

# %%
########################################
##  5-1. 학습된 모델 로드 (TRAIN=False일 때)  ##
########################################

import torch

# TRAIN=False인 경우에만 저장된 모델 로드
if not TRAIN:
    weight_folder = "weights_bamv3_complex"

    # Config 파일이 존재하는지 확인
    config_path = os.path.join(weight_folder, "model_config.npy")

    if os.path.exists(config_path):
        print(f"\n=== Loading Pre-trained Model ===")

        # Config 로드
        config = np.load(config_path, allow_pickle=True).item()
        print(f"Loaded config: {config}")

        # 아키텍처가 동일한지 확인
        if config['layers'] == layers:
            # 각 layer의 weight 로드
            for i, bam in enumerate(model.bams):
                weight_path = os.path.join(weight_folder, f"weights_layer_{i}.npy")
                if os.path.exists(weight_path):
                    loaded_weight = np.load(weight_path)
                    # 🔧 디바이스 지정 추가! (CPU/CUDA 자동 감지)
                    bam.W = torch.tensor(loaded_weight, dtype=torch.float32).to(bam.device)
                    print(f"✅ Layer {i} weights loaded from: {weight_path} (device: {bam.device})")
                else:
                    print(f"❌ Warning: {weight_path} not found!")

            print(f"✅ Model successfully loaded from {weight_folder}")
        else:
            print(f"❌ Warning: Architecture mismatch!")
            print(f"   Current: {layers}")
            print(f"   Saved:   {config['layers']}")
    else:
        print(f"❌ Warning: No pre-trained model found in {weight_folder}")
        print(f"   Please set TRAIN=True to train a new model first.")
else:
    print("\n=== Using Newly Trained Model ===")
    print("Model weights from training will be used.")
# Out:
# === Using Newly Trained Model ===
# Model weights from training will be used.

# %%
########################################
##  6. 테스트: Complex 복원 및 IQ 재구성  ##
########################################

# 테스트 샘플 선택
test_symbol = 42  # 테스트할 심볼 (0~511)
test_snr = -20    # 테스트 SNR

print(f"\n=== Testing Complex Reconstruction ===")
print(f"Test symbol: {test_symbol}, SNR: {test_snr} dB")

# 1. 클린 IQ 생성
clean_iq = X_clean_iq[test_symbol]

# 2. 노이즈 추가
noisy_iq = lora.awgn_iq(clean_iq, test_snr)

# 3. Complex 스펙트로그램 생성
noisy_flat, norm_params = generate_complex_spectrogram(noisy_iq, fs, bw)

# 4. BAM 압축/복원
compressed = model.compress(noisy_flat.reshape(1, -1))
restored_flat = model.decompress(compressed).flatten()

# 5. Real/Imag 분리 및 역정규화 (학습 시와 동일한 스케일 사용)
mid = len(restored_flat) // 2
real_restored_norm = restored_flat[:mid].reshape(norm_params['shape'])
imag_restored_norm = restored_flat[mid:].reshape(norm_params['shape'])

# 🔍 정규화 파라미터 확인
print(f"\n=== Normalization Parameters ===")
print(f"Real: min={norm_params['r_min']:.6f}, max={norm_params['r_max']:.6f}, range={norm_params['r_max']-norm_params['r_min']:.6f}")
print(f"Imag: min={norm_params['i_min']:.6f}, max={norm_params['i_max']:.6f}, range={norm_params['i_max']-norm_params['i_min']:.6f}")
print(f"Restored norm: real_min={real_restored_norm.min():.4f}, real_max={real_restored_norm.max():.4f}")
print(f"Restored norm: imag_min={imag_restored_norm.min():.4f}, imag_max={imag_restored_norm.max():.4f}")

# 역정규화 (Noisy 범위 사용 - 학습 시와 일관성 유지)
real_restored = real_restored_norm * (norm_params['r_max'] - norm_params['r_min']) + norm_params['r_min']
imag_restored = imag_restored_norm * (norm_params['i_max'] - norm_params['i_min']) + norm_params['i_min']

print(f"After denorm:  real_min={real_restored.min():.6f}, real_max={real_restored.max():.6f}")
print(f"After denorm:  imag_min={imag_restored.min():.6f}, imag_max={imag_restored.max():.6f}")

# 6. Complex 재결합
Zxx_restored = real_restored + 1j * imag_restored

# 7. IQ 신호 복원
iq_reconstructed = reconstruct_iq_from_spectrogram(restored_flat, norm_params, fs)

print(f"✅ IQ signal reconstructed: {iq_reconstructed.shape}")

# -------------------------------------------------------------
# [최종 수정] 길이 보정 및 에너지 정규화
# -------------------------------------------------------------

# 1. 🔧 길이 보정: Resample (필수!)
# 딥러닝 모델 출력(시간축 압축됨)을 원래 LoRa 심볼 길이(2048)로 복원
target_len = len(clean_iq)  # 원본 LoRa symbol 길이 (예: 2048)
cur_len = len(iq_reconstructed)

if cur_len != target_len:
    if cur_len > target_len:
        # 🔪 TRIM: 가운데 부분만 남기기 (시간 정렬 유지)
        diff = cur_len - target_len
        start = diff // 2
        end = start + target_len
        iq_reconstructed = iq_reconstructed[start:end]
        print(f"   🔧 Trimmed: {cur_len} -> {target_len} samples (center slice)")
    else:
        # 🩹 PADDING: 앞/뒤로 0 채우기 (대칭 padding)
        diff = target_len - cur_len
        pad_left = diff // 2
        pad_right = diff - pad_left
        iq_reconstructed = np.pad(
            iq_reconstructed,
            (pad_left, pad_right),
            mode="constant",
            constant_values=0,
        )
        print(f"   🔧 Padded: {cur_len} -> {target_len} samples (zero padding)")
else:
    print(f"   ✅ Length already matches: {target_len} samples")


# 2. ⭐ 에너지 정규화: Standardization (수정됨!)
# 기존(Noisy 에너지 기준)은 위험하므로, 통신 표준인 'Unit Power (std=1)'로 변경
# 이렇게 하면 신호 크기가 적절하게 맞춰져서 디코더가 가장 잘 인식합니다.

iq_std = np.std(iq_reconstructed)

if iq_std > 1e-12:  # 0 나누기 방지 (신호가 살아있는 경우)
    # 평균을 0으로, 표준편차를 1로 맞춤 (Z-score normalization과 유사)
    iq_reconstructed = (iq_reconstructed - np.mean(iq_reconstructed)) / iq_std

    print(f"   🔧 Normalized to Unit Power (std=1.0)")
    # 확인용 출력
    print(f"   Energy after scaling:  |mean|={np.abs(iq_reconstructed).mean():.6f}, |max|={np.abs(iq_reconstructed).max():.6f}")

else:
    # 신호가 거의 0인 경우 (복원 실패 또는 무음 구간)
    print(f"   ⚠️ Warning: Reconstructed signal is essentially silence. No scaling applied.")

# -------------------------------------------------------------

# 🔍 디버깅: 값 확인
print(f"\n=== Debug: Values Check ===")
print(f"Noisy flat:    min={noisy_flat.min():.4f}, max={noisy_flat.max():.4f}, mean={noisy_flat.mean():.4f}")
print(f"Restored flat: min={restored_flat.min():.4f}, max={restored_flat.max():.4f}, mean={restored_flat.mean():.4f}")
mse_diff = ((noisy_flat - restored_flat)**2).mean()
print(f"Difference:    MSE={mse_diff:.6f}")

# 시각화: Magnitude 스펙트로그램 비교 (모두 같은 파라미터 + BW 크롭)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Noisy 스펙트로그램 (BW 크롭 적용)
f_n, t_n, Zxx_noisy_full = spectrogram(noisy_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_n = np.fft.fftshift(f_n)
Zxx_noisy_full = np.fft.fftshift(Zxx_noisy_full, axes=0)
mask_n = (f_n >= -bw/2) & (f_n < bw/2)
Zxx_noisy = Zxx_noisy_full[mask_n, :]
im1 = axes[0].imshow(np.abs(Zxx_noisy), aspect='auto', cmap='viridis', origin='lower')
axes[0].set_title(f'Noisy (SNR={test_snr}dB)')
plt.colorbar(im1, ax=axes[0])

# Restored 스펙트로그램 (이미 크롭됨)
im2 = axes[1].imshow(np.abs(Zxx_restored), aspect='auto', cmap='viridis', origin='lower')
axes[1].set_title('BAMv3 Restored')
plt.colorbar(im2, ax=axes[1])

# Clean 스펙트로그램 (BW 크롭 적용)
f_c, t_c, Zxx_clean_full = spectrogram(clean_iq, fs, window='hann', nperseg=128, noverlap=64, nfft=512, mode='complex', return_onesided=False)
f_c = np.fft.fftshift(f_c)
Zxx_clean_full = np.fft.fftshift(Zxx_clean_full, axes=0)
mask_c = (f_c >= -bw/2) & (f_c < bw/2)
Zxx_clean = Zxx_clean_full[mask_c, :]
im3 = axes[2].imshow(np.abs(Zxx_clean), aspect='auto', cmap='viridis', origin='lower')
axes[2].set_title('Clean (Original)')
plt.colorbar(im3, ax=axes[2])

plt.tight_layout()
plt.show()

# 🔍 스펙트로그램 magnitude 확인
print(f"\n=== Spectrogram Magnitude Check ===")
print(f"Zxx_noisy (magnitude):    min={np.abs(Zxx_noisy).min():.4f}, max={np.abs(Zxx_noisy).max():.4f}")
print(f"Zxx_restored (magnitude): min={np.abs(Zxx_restored).min():.4f}, max={np.abs(Zxx_restored).max():.4f}")
print(f"Zxx_clean (magnitude):    min={np.abs(Zxx_clean).min():.4f}, max={np.abs(Zxx_clean).max():.4f}")
# Out:
# === Testing Complex Reconstruction ===
# Test symbol: 42, SNR: -20 dB
#
# === Normalization Parameters ===
# Real: min=-3.237164, max=3.979398, range=7.216562
# Imag: min=-2.996797, max=4.104196, range=7.100994
# Restored norm: real_min=0.0605, real_max=0.7845
# Restored norm: imag_min=0.0674, imag_max=0.7937
# After denorm:  real_min=-2.800390, real_max=2.424288
# After denorm:  imag_min=-2.518365, imag_max=2.639119
# ✅ IQ signal reconstructed: (2048,)
#    ✅ Length already matches: 2048 samples
#    🔧 Normalized to Unit Power (std=1.0)
#    Energy after scaling:  |mean|=0.612582, |max|=22.826980
#
# === Debug: Values Check ===
# Noisy flat:    min=0.0000, max=1.0000, mean=0.4353
# Restored flat: min=0.0605, max=0.7937, mean=0.4353
# Difference:    MSE=0.006443
# /tmp/ipykernel_15596/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
# === Spectrogram Magnitude Check ===
# Zxx_noisy (magnitude):    min=0.0002, max=0.0386
# Zxx_restored (magnitude): min=0.0280, max=2.8144
# Zxx_clean (magnitude):    min=0.0000, max=0.0092

# %%
########################################
##  7. Dechirp 및 Code 복원 평가     ##
########################################

from utils.my_lora_utils import estimate_symbol_custom

print("\n=== Dechirp Code Reconstruction Test ===")

# 🔍 IQ 신호 차이 분석
print(f"\n=== IQ Signal Analysis ===")
print(f"Clean IQ:        len={len(clean_iq)}, |mean|={np.abs(clean_iq).mean():.4f}, |max|={np.abs(clean_iq).max():.4f}")
print(f"Noisy IQ:        len={len(noisy_iq)}, |mean|={np.abs(noisy_iq).mean():.4f}, |max|={np.abs(noisy_iq).max():.4f}")
print(f"Reconstructed:   len={len(iq_reconstructed)}, |mean|={np.abs(iq_reconstructed).mean():.4f}, |max|={np.abs(iq_reconstructed).max():.4f}")

# MSE 비교 (길이 맞춤)
min_len = min(len(clean_iq), len(noisy_iq), len(iq_reconstructed))
mse_clean_noisy = np.mean(np.abs(clean_iq[:min_len] - noisy_iq[:min_len])**2)
mse_clean_recon = np.mean(np.abs(clean_iq[:min_len] - iq_reconstructed[:min_len])**2)
mse_noisy_recon = np.mean(np.abs(noisy_iq[:min_len] - iq_reconstructed[:min_len])**2)

print(f"\nMSE Comparison:")
print(f"Clean vs Noisy:        {mse_clean_noisy:.6f}")
print(f"Clean vs Reconstructed: {mse_clean_recon:.6f}")
print(f"Noisy vs Reconstructed: {mse_noisy_recon:.6f}")

# Dechirp 및 심볼 복원 테스트
print(f"\n=== Dechirp Symbol Decoding ===")

# 1. 원본 클린 신호 Dechirp
code_clean, peak_clean = estimate_symbol_custom(clean_iq, sf, fs, bw)
print(f"✅ Clean signal (len={len(clean_iq)})    → Code: {code_clean}, Peak: {peak_clean:.2f}")

# 2. 노이즈 신호 Dechirp
code_noisy, peak_noisy = estimate_symbol_custom(noisy_iq, sf, fs, bw)
print(f"⚠️  Noisy signal (len={len(noisy_iq)})    → Code: {code_noisy}, Peak: {peak_noisy:.2f}")

# 3. BAM 복원 신호 Dechirp (Resample 적용 완료!)
code_restored, peak_restored = estimate_symbol_custom(iq_reconstructed, sf, fs, bw)
print(f"🔧 Restored (len={len(iq_reconstructed)})   → Code: {code_restored}, Peak: {peak_restored:.2f}")

# 성능 평가
print(f"\n{'='*60}")
print(f"Performance Evaluation:")
print(f"{'='*60}")
print(f"Ground Truth Symbol: {test_symbol}")
print(f"Clean Decoded:       {code_clean} {'✅ CORRECT' if code_clean == test_symbol else '❌ WRONG'}")
print(f"Noisy Decoded:       {code_noisy} {'✅ CORRECT' if code_noisy == test_symbol else '❌ WRONG'}")
print(f"Restored Decoded:    {code_restored} {'✅ CORRECT' if code_restored == test_symbol else '❌ WRONG'}")
print(f"{'='*60}")

# Peak 비교
print(f"\nPeak Comparison:")
print(f"Clean Peak:    {peak_clean:.2f}")
print(f"Noisy Peak:    {peak_noisy:.2f} ({peak_noisy/peak_clean*100:.1f}% of clean)")
print(f"Restored Peak: {peak_restored:.2f} ({peak_restored/peak_clean*100:.1f}% of clean)")

if code_restored == test_symbol:
    print(f"\n✅ SUCCESS: BAMv3_huber successfully restored the correct symbol!")
else:
    print(f"\n❌ FAILURE: BAMv3_huber failed to restore the correct symbol")
# Out:
# === Dechirp Code Reconstruction Test ===
#
# === IQ Signal Analysis ===
# Clean IQ:        len=2048, |mean|=1.0000, |max|=1.0000
# Noisy IQ:        len=2048, |mean|=9.0422, |max|=29.4870
# Reconstructed:   len=2048, |mean|=0.6126, |max|=22.8270
#
# MSE Comparison:
# Clean vs Noisy:        102.603244
# Clean vs Reconstructed: 1.593557
# Noisy vs Reconstructed: 100.055965
#
# === Dechirp Symbol Decoding ===
# ✅ Clean signal (len=2048)    → Code: 42, Peak: 4194303.99
# ⚠️  Noisy signal (len=2048)    → Code: 42, Peak: 6760455.07
# 🔧 Restored (len=2048)   → Code: 42, Peak: 151514.87
#
# ============================================================
# Performance Evaluation:
# ============================================================
# Ground Truth Symbol: 42
# Clean Decoded:       42 ✅ CORRECT
# Noisy Decoded:       42 ✅ CORRECT
# Restored Decoded:    42 ✅ CORRECT
# ============================================================
#
# Peak Comparison:
# Clean Peak:    4194303.99
# Noisy Peak:    6760455.07 (161.2% of clean)
# Restored Peak: 151514.87 (3.6% of clean)
#
# ✅ SUCCESS: BAMv3_huber successfully restored the correct symbol!

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import resample

print("\n" + "="*70)
print("📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)")
print("="*70)

# 1. 테스트 파라미터 설정 ( -30dB 추가 완료 )
NUM_TEST_SAMPLES = 1000  # 샘플 수
TEST_SNR_LEVELS = [-30, -25, -20, -15, -10, -5]  # ⭐ -30dB 추가됨!

# 결과 저장용 딕셔너리
results = {
    snr: {
        'bam_correct': 0, 'bam_total': 0, 'bam_mse': [], 'bam_peak_ratio': [],
        'base_correct': 0, 'base_total': 0, 'base_peak_ratio': [],
    }
    for snr in TEST_SNR_LEVELS
}

print(f"\n🧪 Testing with {NUM_TEST_SAMPLES} samples at each SNR level...")
print(f"SNR levels: {TEST_SNR_LEVELS} dB\n")

for snr in TEST_SNR_LEVELS:
    print(f"\n{'─'*70}")
    print(f"Testing SNR = {snr} dB")
    print(f"{'─'*70}")

    for i in range(NUM_TEST_SAMPLES):
        try:
            # 랜덤 심볼 선택
            test_sym = np.random.randint(0, 512)

            # 1. 클린 IQ & 노이즈 추가
            clean_iq_test = X_clean_iq[test_sym]
            noisy_iq_test = lora.awgn_iq(clean_iq_test, snr)

            # 2. Complex 스펙트로그램 생성
            noisy_flat, noisy_params = generate_complex_spectrogram(noisy_iq_test, fs, bw)

            # 3. BAMv3 복원 (Compress -> Decompress)
            compressed = model.compress(noisy_flat.reshape(1, -1))
            restored_flat = model.decompress(compressed).flatten()

            # 4. IQ 신호 재구성 (1차)
            iq_restored = reconstruct_iq_from_spectrogram(restored_flat, noisy_params, fs)

            # ====================================================
            # ⭐ [수정] 길이 보정: Trim / Padding + 에너지 정규화
            # ====================================================
            target_len = len(clean_iq_test)
            cur_len = len(iq_restored)

            # (1) 길이 보정: resample 금지, trim / padding만 사용
            if cur_len != target_len:
                if cur_len > target_len:
                    # 가운데 기준으로 잘라서 타이밍 유지
                    diff = cur_len - target_len
                    start = diff // 2
                    end = start + target_len
                    iq_restored = iq_restored[start:end]
                    # print(f"   🔧 Trimmed: {cur_len} -> {target_len}")
                else:
                    # 부족하면 앞/뒤에 0 패딩 (대칭 padding)
                    diff = target_len - cur_len
                    pad_left = diff // 2
                    pad_right = diff - pad_left
                    iq_restored = np.pad(
                        iq_restored,
                        (pad_left, pad_right),
                        mode="constant",
                        constant_values=0,
                    )
                    # print(f"   🔧 Padded: {cur_len} -> {target_len}")
            # else:
            #     print(f"   ✅ Length already matches: {target_len}")

            # (2) 에너지 정규화 (mean/std 표준화 X, power만 맞춤)
            power = np.mean(np.abs(iq_restored) ** 2)
            if power > 1e-12:
                iq_restored = iq_restored / np.sqrt(power)
            # ====================================================

            # 5. Dechirp 및 심볼 추정 (Baseline vs BAM)
            # 기준: 클린 신호
            code_clean, peak_clean = estimate_symbol_custom(clean_iq_test, sf, fs, bw)

            # Baseline: noisy 신호
            code_base, peak_base = estimate_symbol_custom(noisy_iq_test, sf, fs, bw)

            # BAM 경로: 복원된 IQ
            code_bam, peak_bam = estimate_symbol_custom(iq_restored, sf, fs, bw)

            # -----------------------------
            # 결과 기록
            # -----------------------------
            # 1) Baseline Accuracy
            if code_base == test_sym: results[snr]['base_correct'] += 1
            results[snr]['base_total'] += 1

            # 2) BAM Accuracy
            if code_bam == test_sym: results[snr]['bam_correct'] += 1
            results[snr]['bam_total'] += 1

            # 3) Peak Ratio
            if peak_clean > 0:
                results[snr]['base_peak_ratio'].append(peak_base / peak_clean)
                results[snr]['bam_peak_ratio'].append(peak_bam / peak_clean)

            # 4) MSE (복원 품질)
            # MSE 계산 시에는 크기(Scale) 차이 때문에 정규화된 것끼리 비교하거나,
            # 단순히 복원력 확인용으로만 참고합니다.
            mse = np.mean(np.abs(iq_restored - clean_iq_test)**2)
            results[snr]['bam_mse'].append(mse)

        except Exception as e:
            print(f"  ⚠️ Error at sample {i}: {e}")
            results[snr]['base_total'] += 1
            results[snr]['bam_total'] += 1

    # 중간 결과 출력
    base_acc = (results[snr]['base_correct'] / results[snr]['base_total'] * 100) if results[snr]['base_total'] > 0 else 0
    bam_acc = (results[snr]['bam_correct'] / results[snr]['bam_total'] * 100) if results[snr]['bam_total'] > 0 else 0

    print(f"  ✓ Baseline Acc : {base_acc:.1f}%")
    print(f"  ✓ BAM Accuracy : {bam_acc:.1f}%")

# 최종 결과 요약 출력 및 그래프 그리기 (기존 코드와 동일)
print("\n" + "="*70)
print("📈 FINAL RESULTS SUMMARY")
print("="*70)
print(f"\n{'SNR':<6} {'Base Acc':<10} {'BAM Acc':<10} {'Improvement':<12}")
print("─"*70)

for snr in TEST_SNR_LEVELS:
    b_acc = results[snr]['base_correct'] / results[snr]['base_total'] * 100
    m_acc = results[snr]['bam_correct'] / results[snr]['bam_total'] * 100
    imp = m_acc - b_acc
    print(f"{snr:<6} {b_acc:>8.1f}%  {m_acc:>8.1f}%  {imp:>+10.1f}%p")

# 그래프 그리기
plt.figure(figsize=(10, 5))
snrs = TEST_SNR_LEVELS
base_accs = [results[s]['base_correct']/results[s]['base_total']*100 for s in snrs]
bam_accs = [results[s]['bam_correct']/results[s]['bam_total']*100 for s in snrs]

plt.plot(snrs, base_accs, 'o--', label='Standard LoRa (Baseline)', color='gray')
plt.plot(snrs, bam_accs, 's-', label='Proposed BAMv3', color='red', linewidth=2)
plt.axvline(x=-20, color='orange', linestyle=':', label='LoRa Limit (-20dB)')

plt.xlabel('SNR (dB)')
plt.ylabel('Symbol Accuracy (%)')
plt.title('Decoding Performance: Baseline vs BAMv3')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ======================================================================
# 📊 QUANTITATIVE PERFORMANCE EVALUATION (Baseline vs BAM)
# ======================================================================
#
# 🧪 Testing with 1000 samples at each SNR level...
# SNR levels: [-30, -25, -20, -15, -10, -5] dB
#
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -30 dB
# ──────────────────────────────────────────────────────────────────────
# /tmp/ipykernel_15596/2141263655.py:99: UserWarning: NOLA condition failed, STFT may not be invertible. Possibly due to missing boundary
#   _, iq_restored = istft(
#   ✓ Baseline Acc : 3.5%
#   ✓ BAM Accuracy : 7.1%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -25 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 18.7%
#   ✓ BAM Accuracy : 27.8%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -20 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 80.4%
#   ✓ BAM Accuracy : 81.4%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -15 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 99.9%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -10 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 100.0%
#
# ──────────────────────────────────────────────────────────────────────
# Testing SNR = -5 dB
# ──────────────────────────────────────────────────────────────────────
#   ✓ Baseline Acc : 100.0%
#   ✓ BAM Accuracy : 100.0%
#
# ======================================================================
# 📈 FINAL RESULTS SUMMARY
# ======================================================================
#
# SNR    Base Acc   BAM Acc    Improvement
# ──────────────────────────────────────────────────────────────────────
# -30         3.5%       7.1%        +3.6%p
# -25        18.7%      27.8%        +9.1%p
# -20        80.4%      81.4%        +1.0%p
# -15       100.0%      99.9%        -0.1%p
# -10       100.0%     100.0%        +0.0%p
# -5        100.0%     100.0%        +0.0%p
